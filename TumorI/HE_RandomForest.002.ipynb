# %% [markdown]
# # Random Forest Classifier
# Center patches from two H&E slides.
# Patches are 224 x 224.
# Ypos example: D1  18K patches
# Yneg example: E5  20K patches
# Feature extraction by CellProfiler, segment nuclei, measure shape and neighbors.
# Same 68 features for both.
#
# In notebook 001, we managed to train a RF, getting past NaN issues.
# Here, run a simple cross validation.
# Also, fit to train data and test on test data.
#
# The model was 61% accurate in cross-validation.
# These results may not generalize so don't overrate this result.
# All patches come from only two slide images, one Ypos and one Yneg.
# The tumors may differ in ways besides Ychr.
#
# Our data have one row per nuclei (called 'object').
# This classifier classified each nuclei (and its patch ranked high in importance).
# We really want to classify patches, not objects.
# We could classify patches by counting objects.
# But let's see if CellProfiler could output stats per patch instead of per object.

# %%
import numpy as np
import pandas as pd
import sklearn
print(sklearn.__version__)
# Out:
# 1.0.2

# %%
def make_dataframe(filename):
    df = pd.read_csv(filename,dtype=np.float32)  # remove dtype?
    count1 = df.isnull().sum().sum()
    print('Zero out this many NaN:', count1)
    df = df.fillna(0)
    count2 = df.isnull().sum().sum()
    print('Now how many NaN?:', count2)
    print('Largest value:', df.max().max())
    print('Smallest:', df.min().min())
    return df

# %%
FILENAME_YPOS = '/home/jrm/Martinez/CellProfilerRuns/CP_20220417_Ypos/Nuclei.CP_20220417_Ypos.csv'
feature_vec_Ypos = make_dataframe(FILENAME_YPOS)
feature_vec_Ypos
# Out:
# Zero out this many NaN: 35
# Now how many NaN?: 0
# Largest value: 19328.0
# Smallest: -89.999825
#        ImageNumber  ObjectNumber  AreaShape_Area  AreaShape_BoundingBoxArea  \
# 0              1.0           1.0           843.0                     1394.0
# 1              1.0           2.0          1089.0                     2432.0
# 2              1.0           3.0          2532.0                     7020.0
# 3              1.0           4.0           967.0                     1806.0
# 4              1.0           5.0          2509.0                     7656.0
# ...            ...           ...             ...                        ...
# 18133       1434.0          14.0          2221.0                     3600.0
# 18134       1434.0          15.0           605.0                     2014.0
# 18135       1434.0          16.0           665.0                     1224.0
# 18136       1434.0          17.0          1995.0                     3072.0
# 18137       1434.0          18.0           955.0                     1892.0
#
#        AreaShape_BoundingBoxMaximum_X  AreaShape_BoundingBoxMaximum_Y  \
# 0                                38.0                            59.0
# 1                               121.0                            64.0
# 2                                65.0                           147.0
# 3                               179.0                           115.0
# 4                               118.0                           134.0
# ...                               ...                             ...
# 18133                           157.0                           224.0
# 18134                           100.0                           218.0
# 18135                            41.0                           217.0
# 18136                           208.0                           224.0
# 18137                            60.0                           224.0
#
#        AreaShape_BoundingBoxMinimum_X  AreaShape_BoundingBoxMinimum_Y  \
# 0                                 4.0                            18.0
# 1                                83.0                             0.0
# 2                                 0.0                            39.0
# 3                               158.0                            29.0
# 4                                60.0                             2.0
# ...                               ...                             ...
# 18133                           112.0                           144.0
# 18134                            47.0                           180.0
# 18135                             7.0                           181.0
# 18136                           160.0                           160.0
# 18137                            16.0                           181.0
#
#        AreaShape_Center_X  AreaShape_Center_Y  ...  Location_Center_Y  \
# 0               22.590748           34.474495  ...          34.474495
# 1              104.489441           31.939394  ...          31.939394
# 2               30.254740           93.802528  ...          93.802528
# 3              167.997925           70.884178  ...          70.884178
# 4               85.536865           71.314865  ...          71.314865
# ...                   ...                 ...  ...                ...
# 18133          134.861328          191.363800  ...         191.363800
# 18134           72.646278          200.705780  ...         200.705780
# 18135           22.075188          199.330826  ...         199.330826
# 18136          185.139343          189.518799  ...         189.518799
# 18137           39.464920          206.289001  ...         206.289001
#
#        Location_Center_Z  Neighbors_AngleBetweenNeighbors_Expanded  \
# 0                    0.0                                 52.354198
# 1                    0.0                                 84.178970
# 2                    0.0                                 75.474617
# 3                    0.0                                115.062004
# 4                    0.0                                137.543488
# ...                  ...                                       ...
# 18133                0.0                                 60.717670
# 18134                0.0                                 57.875278
# 18135                0.0                                 79.765228
# 18136                0.0                                 63.777115
# 18137                0.0                                148.628036
#
#        Neighbors_FirstClosestDistance_Expanded  \
# 0                                    59.501389
# 1                                    43.707657
# 2                                    59.501389
# 3                                    51.082310
# 4                                    43.707657
# ...                                        ...
# 18133                                50.313515
# 18134                                33.664047
# 18135                                18.758469
# 18136                                50.313515
# 18137                                18.758469
#
#        Neighbors_FirstClosestObjectNumber_Expanded  \
# 0                                              3.0
# 1                                              5.0
# 2                                              1.0
# 3                                              6.0
# 4                                              2.0
# ...                                            ...
# 18133                                         17.0
# 18134                                         18.0
# 18135                                         18.0
# 18136                                         14.0
# 18137                                         16.0
#
#        Neighbors_NumberOfNeighbors_Expanded  \
# 0                                       2.0
# 1                                       3.0
# 2                                       4.0
# 3                                       3.0
# 4                                       6.0
# ...                                     ...
# 18133                                   5.0
# 18134                                   4.0
# 18135                                   2.0
# 18136                                   3.0
# 18137                                   4.0
#
#        Neighbors_PercentTouching_Expanded  \
# 0                               70.562767
# 1                               78.797470
# 2                               78.444443
# 3                               66.080399
# 4                               93.320236
# ...                                   ...
# 18133                           82.692307
# 18134                           84.482758
# 18135                           77.419357
# 18136                           57.333332
# 18137                           75.357140
#
#        Neighbors_SecondClosestDistance_Expanded  \
# 0                                     72.924950
# 1                                     74.513222
# 2                                     59.648666
# 3                                     74.513222
# 4                                     59.648666
# ...                                         ...
# 18133                                 54.764091
# 18134                                 45.451160
# 18135                                 38.419117
# 18136                                 53.246357
# 18137                                 33.664047
#
#        Neighbors_SecondClosestObjectNumber_Expanded  Number_Object_Number
# 0                                               5.0                   1.0
# 1                                               4.0                   2.0
# 2                                               5.0                   3.0
# 3                                               2.0                   4.0
# 4                                               3.0                   5.0
# ...                                             ...                   ...
# 18133                                          13.0                  14.0
# 18134                                          11.0                  15.0
# 18135                                          11.0                  16.0
# 18136                                          13.0                  17.0
# 18137                                          15.0                  18.0
#
# [18138 rows x 68 columns]

# %%
FILENAME_YNEG = '/home/jrm/Martinez/CellProfilerRuns/CP_20220417_Yneg/Nuclei.CP_20220417_Yneg.csv'
feature_vec_Yneg = make_dataframe(FILENAME_YNEG)
feature_vec_Yneg
# Out:
# Zero out this many NaN: 20
# Now how many NaN?: 0
# Largest value: 25110.0
# Smallest: -89.99928
#        ImageNumber  ObjectNumber  AreaShape_Area  AreaShape_BoundingBoxArea  \
# 0              1.0           1.0           522.0                     1260.0
# 1              1.0           2.0          4162.0                     5607.0
# 2              1.0           3.0           699.0                     1806.0
# 3              1.0           4.0          1160.0                     2970.0
# 4              1.0           5.0           525.0                      812.0
# ...            ...           ...             ...                        ...
# 19676       1434.0          15.0          1902.0                     4292.0
# 19677       1434.0          16.0          1237.0                     2464.0
# 19678       1434.0          17.0           619.0                     1116.0
# 19679       1434.0          18.0           548.0                      799.0
# 19680       1434.0          19.0           825.0                     1540.0
#
#        AreaShape_BoundingBoxMaximum_X  AreaShape_BoundingBoxMaximum_Y  \
# 0                                52.0                            30.0
# 1                               136.0                            63.0
# 2                               187.0                            42.0
# 3                                86.0                            93.0
# 4                                28.0                           102.0
# ...                               ...                             ...
# 19676                           155.0                           224.0
# 19677                            67.0                           222.0
# 19678                            71.0                           224.0
# 19679                           124.0                           224.0
# 19680                           224.0                           224.0
#
#        AreaShape_BoundingBoxMinimum_X  AreaShape_BoundingBoxMinimum_Y  \
# 0                                10.0                             0.0
# 1                                47.0                             0.0
# 2                               144.0                             0.0
# 3                                31.0                            39.0
# 4                                 0.0                            73.0
# ...                               ...                             ...
# 19676                            97.0                           150.0
# 19677                            11.0                           178.0
# 19678                            35.0                           193.0
# 19679                            77.0                           207.0
# 19680                           154.0                           202.0
#
#        AreaShape_Center_X  AreaShape_Center_Y  ...  Location_Center_Y  \
# 0               35.624519           10.103448  ...          10.103448
# 1               94.156418           27.335415  ...          27.335415
# 2              165.296143           15.801145  ...          15.801145
# 3               58.443104           68.788795  ...          68.788795
# 4               10.695238           88.080002  ...          88.080002
# ...                   ...                 ...  ...                ...
# 19676          123.790749          186.090424  ...         186.090424
# 19677           36.443008          198.021011  ...         198.021011
# 19678           57.436188          211.848145  ...         211.848145
# 19679           98.649635          216.675186  ...         216.675186
# 19680          187.179398          216.797577  ...         216.797577
#
#        Location_Center_Z  Neighbors_AngleBetweenNeighbors_Expanded  \
# 0                    0.0                                 52.348301
# 1                    0.0                                 65.665215
# 2                    0.0                                 78.999229
# 3                    0.0                                 26.785013
# 4                    0.0                                 67.267570
# ...                  ...                                       ...
# 19676                0.0                                 34.170803
# 19677                0.0                                 98.946457
# 19678                0.0                                153.307632
# 19679                0.0                                122.564507
# 19680                0.0                                 78.841599
#
#        Neighbors_FirstClosestDistance_Expanded  \
# 0                                    61.014439
# 1                                    54.718487
# 2                                    71.271278
# 3                                    38.306911
# 4                                    22.964008
# ...                                        ...
# 19676                                16.905943
# 19677                                25.149639
# 19678                                25.149639
# 19679                                39.682652
# 19680                                34.732708
#
#        Neighbors_FirstClosestObjectNumber_Expanded  \
# 0                                              2.0
# 1                                              4.0
# 2                                              6.0
# 3                                              7.0
# 4                                              8.0
# ...                                            ...
# 19676                                         13.0
# 19677                                         17.0
# 19678                                         16.0
# 19679                                         15.0
# 19680                                         14.0
#
#        Neighbors_NumberOfNeighbors_Expanded  \
# 0                                       3.0
# 1                                       4.0
# 2                                       2.0
# 3                                       5.0
# 4                                       2.0
# ...                                     ...
# 19676                                   8.0
# 19677                                   4.0
# 19678                                   3.0
# 19679                                   2.0
# 19680                                   3.0
#
#        Neighbors_PercentTouching_Expanded  \
# 0                               51.724136
# 1                               79.500000
# 2                               52.264809
# 3                              100.000000
# 4                               72.727272
# ...                                   ...
# 19676                           91.735535
# 19677                           70.300751
# 19678                           78.181816
# 19679                           71.165642
# 19680                           54.205608
#
#        Neighbors_SecondClosestDistance_Expanded  \
# 0                                     62.971436
# 1                                     61.014439
# 2                                     72.070114
# 3                                     51.534393
# 4                                     24.466272
# ...                                         ...
# 19676                                 37.599354
# 19677                                 46.310112
# 19678                                 41.495163
# 19679                                 41.495163
# 19680                                 55.665649
#
#        Neighbors_SecondClosestObjectNumber_Expanded  Number_Object_Number
# 0                                               4.0                   1.0
# 1                                               1.0                   2.0
# 2                                               2.0                   3.0
# 3                                               5.0                   4.0
# 4                                               7.0                   5.0
# ...                                             ...                   ...
# 19676                                          11.0                  15.0
# 19677                                          12.0                  16.0
# 19678                                          18.0                  17.0
# 19679                                          17.0                  18.0
# 19680                                          13.0                  19.0
#
# [19681 rows x 68 columns]

# %%
Ypos_rows,Ypos_cols = feature_vec_Ypos.shape
Yneg_rows,Yneg_cols = feature_vec_Yneg.shape
if Ypos_cols == Yneg_cols:
    print('The dataframes are compatible.')
else:
    print('ERROR! Column counts do not match.')
# Out:
# The dataframes are compatible.

# %%
feature_vec_all = pd.concat ( [feature_vec_Ypos, feature_vec_Yneg], ignore_index=True )
feature_vec_all
# Out:
#        ImageNumber  ObjectNumber  AreaShape_Area  AreaShape_BoundingBoxArea  \
# 0              1.0           1.0           843.0                     1394.0
# 1              1.0           2.0          1089.0                     2432.0
# 2              1.0           3.0          2532.0                     7020.0
# 3              1.0           4.0           967.0                     1806.0
# 4              1.0           5.0          2509.0                     7656.0
# ...            ...           ...             ...                        ...
# 37814       1434.0          15.0          1902.0                     4292.0
# 37815       1434.0          16.0          1237.0                     2464.0
# 37816       1434.0          17.0           619.0                     1116.0
# 37817       1434.0          18.0           548.0                      799.0
# 37818       1434.0          19.0           825.0                     1540.0
#
#        AreaShape_BoundingBoxMaximum_X  AreaShape_BoundingBoxMaximum_Y  \
# 0                                38.0                            59.0
# 1                               121.0                            64.0
# 2                                65.0                           147.0
# 3                               179.0                           115.0
# 4                               118.0                           134.0
# ...                               ...                             ...
# 37814                           155.0                           224.0
# 37815                            67.0                           222.0
# 37816                            71.0                           224.0
# 37817                           124.0                           224.0
# 37818                           224.0                           224.0
#
#        AreaShape_BoundingBoxMinimum_X  AreaShape_BoundingBoxMinimum_Y  \
# 0                                 4.0                            18.0
# 1                                83.0                             0.0
# 2                                 0.0                            39.0
# 3                               158.0                            29.0
# 4                                60.0                             2.0
# ...                               ...                             ...
# 37814                            97.0                           150.0
# 37815                            11.0                           178.0
# 37816                            35.0                           193.0
# 37817                            77.0                           207.0
# 37818                           154.0                           202.0
#
#        AreaShape_Center_X  AreaShape_Center_Y  ...  Location_Center_Y  \
# 0               22.590748           34.474495  ...          34.474495
# 1              104.489441           31.939394  ...          31.939394
# 2               30.254740           93.802528  ...          93.802528
# 3              167.997925           70.884178  ...          70.884178
# 4               85.536865           71.314865  ...          71.314865
# ...                   ...                 ...  ...                ...
# 37814          123.790749          186.090424  ...         186.090424
# 37815           36.443008          198.021011  ...         198.021011
# 37816           57.436188          211.848145  ...         211.848145
# 37817           98.649635          216.675186  ...         216.675186
# 37818          187.179398          216.797577  ...         216.797577
#
#        Location_Center_Z  Neighbors_AngleBetweenNeighbors_Expanded  \
# 0                    0.0                                 52.354198
# 1                    0.0                                 84.178970
# 2                    0.0                                 75.474617
# 3                    0.0                                115.062004
# 4                    0.0                                137.543488
# ...                  ...                                       ...
# 37814                0.0                                 34.170803
# 37815                0.0                                 98.946457
# 37816                0.0                                153.307632
# 37817                0.0                                122.564507
# 37818                0.0                                 78.841599
#
#        Neighbors_FirstClosestDistance_Expanded  \
# 0                                    59.501389
# 1                                    43.707657
# 2                                    59.501389
# 3                                    51.082310
# 4                                    43.707657
# ...                                        ...
# 37814                                16.905943
# 37815                                25.149639
# 37816                                25.149639
# 37817                                39.682652
# 37818                                34.732708
#
#        Neighbors_FirstClosestObjectNumber_Expanded  \
# 0                                              3.0
# 1                                              5.0
# 2                                              1.0
# 3                                              6.0
# 4                                              2.0
# ...                                            ...
# 37814                                         13.0
# 37815                                         17.0
# 37816                                         16.0
# 37817                                         15.0
# 37818                                         14.0
#
#        Neighbors_NumberOfNeighbors_Expanded  \
# 0                                       2.0
# 1                                       3.0
# 2                                       4.0
# 3                                       3.0
# 4                                       6.0
# ...                                     ...
# 37814                                   8.0
# 37815                                   4.0
# 37816                                   3.0
# 37817                                   2.0
# 37818                                   3.0
#
#        Neighbors_PercentTouching_Expanded  \
# 0                               70.562767
# 1                               78.797470
# 2                               78.444443
# 3                               66.080399
# 4                               93.320236
# ...                                   ...
# 37814                           91.735535
# 37815                           70.300751
# 37816                           78.181816
# 37817                           71.165642
# 37818                           54.205608
#
#        Neighbors_SecondClosestDistance_Expanded  \
# 0                                     72.924950
# 1                                     74.513222
# 2                                     59.648666
# 3                                     74.513222
# 4                                     59.648666
# ...                                         ...
# 37814                                 37.599354
# 37815                                 46.310112
# 37816                                 41.495163
# 37817                                 41.495163
# 37818                                 55.665649
#
#        Neighbors_SecondClosestObjectNumber_Expanded  Number_Object_Number
# 0                                               5.0                   1.0
# 1                                               4.0                   2.0
# 2                                               5.0                   3.0
# 3                                               2.0                   4.0
# 4                                               3.0                   5.0
# ...                                             ...                   ...
# 37814                                          11.0                  15.0
# 37815                                          12.0                  16.0
# 37816                                          18.0                  17.0
# 37817                                          17.0                  18.0
# 37818                                          13.0                  19.0
#
# [37819 rows x 68 columns]

# %%
# Was silly to convert numpy to pandas when we need numpy eventually
#label_vec_Ypos = pd.DataFrame (np.ones(Ypos_rows,dtype=int))
#label_vec_Yneg = pd.DataFrame (np.zeros(Yneg_rows,dtype=int))
#label_vec_all = pd.concat ( [label_vec_Ypos, label_vec_Yneg], ignore_index=True )
label_vec_Ypos = np.ones(Ypos_rows,dtype=int)
label_vec_Yneg = np.zeros(Yneg_rows,dtype=int)
label_vec_all = np.concatenate ( [label_vec_Ypos, label_vec_Yneg] )
label_vec_all
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
# Was looking for which data rows caused NaN errors during fit().
#feature_vec_all = feature_vec_Ypos[:1226]
#label_vec_all =     label_vec_Ypos[:1226]
#print(feature_vec_all.shape)
#pd.set_option('display.max_rows', None)
#print(feature_vec_all.iloc[-1])
#label_vec_all.shape

# %%
from sklearn.model_selection import train_test_split
#Xtrain,Xtest,ytrain,ytest = train_test_split(feature_vec_all, label_vec_all.ravel(), test_size=100, random_state=41)
# Default test size is 25%
Xtrain,Xtest,ytrain,ytest = train_test_split(feature_vec_all, label_vec_all.ravel(), random_state=42)
print('Xtrain',Xtrain.shape,'ytrain',ytrain.shape)
print('Xtest',Xtest.shape,'ytest',ytest.shape)
# Out:
# Xtrain (28364, 68) ytrain (28364,)
# Xtest (9455, 68) ytest (9455,)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()

# %%
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=42)
n_scores = cross_val_score(model, Xtrain, ytrain, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
print('Accuracy: %.3f (%.3f)' % (np.mean(n_scores), np.std(n_scores)))
# Out:
# Accuracy: 0.609 (0.009)

# %%
model.fit(Xtrain,ytrain)
ypred = model.predict(Xtest)
#for i in range(len(ypred)):
#    print('Actual',ytest[i],'Predict',ypred[i])

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(ytest, ypred)
cm
# Out:
# array([[3334, 1604],
#        [2049, 2468]])

# %%
print('The impurity-based feature importances.')
names = model.feature_names_in_
importances = model.feature_importances_
pairs = np.column_stack( (names,importances) )
sorted(pairs, key = lambda e:e[1], reverse=True)
# Out:
# The impurity-based feature importances.
# [array(['AreaShape_Orientation', 0.03129507536909002], dtype=object),
#  array(['AreaShape_MeanRadius', 0.020069586896440193], dtype=object),
#  array(['ImageNumber', 0.019144306218596994], dtype=object),
#  array(['Neighbors_SecondClosestDistance_Expanded', 0.018853010253342056],
#        dtype=object),
#  array(['AreaShape_Solidity', 0.018016707752642105], dtype=object),
#  array(['Neighbors_FirstClosestDistance_Expanded', 0.017743964215453215],
#        dtype=object),
#  array(['AreaShape_Extent', 0.01749113895867147], dtype=object),
#  array(['AreaShape_Compactness', 0.017351841191621486], dtype=object),
#  array(['AreaShape_FormFactor', 0.01718101943401564], dtype=object),
#  array(['AreaShape_Zernike_0_0', 0.01687326268082619], dtype=object),
#  array(['AreaShape_Zernike_9_1', 0.01673088614226464], dtype=object),
#  array(['AreaShape_Zernike_8_8', 0.016663620777941576], dtype=object),
#  array(['AreaShape_Zernike_4_0', 0.01665080621415337], dtype=object),
#  array(['Neighbors_AngleBetweenNeighbors_Expanded', 0.016624370798034756],
#        dtype=object),
#  array(['AreaShape_Zernike_9_7', 0.016528234634418434], dtype=object),
#  array(['AreaShape_Zernike_9_3', 0.01652216916374827], dtype=object),
#  array(['AreaShape_Zernike_7_3', 0.01628468384389533], dtype=object),
#  array(['AreaShape_Zernike_4_4', 0.016267740999574776], dtype=object),
#  array(['AreaShape_Zernike_8_4', 0.01622808610878125], dtype=object),
#  array(['AreaShape_Zernike_7_7', 0.01621735077668459], dtype=object),
#  array(['AreaShape_Zernike_6_4', 0.016195569640898654], dtype=object),
#  array(['AreaShape_Zernike_8_2', 0.01611413827418755], dtype=object),
#  array(['AreaShape_Zernike_5_3', 0.016110466119073158], dtype=object),
#  array(['AreaShape_Zernike_2_0', 0.016106544378687523], dtype=object),
#  array(['AreaShape_Zernike_6_2', 0.016063845359952585], dtype=object),
#  array(['AreaShape_Zernike_8_0', 0.016055453792898897], dtype=object),
#  array(['AreaShape_Zernike_5_1', 0.016054724227549323], dtype=object),
#  array(['AreaShape_Zernike_3_3', 0.01600418946290234], dtype=object),
#  array(['AreaShape_Zernike_8_6', 0.015957480045359306], dtype=object),
#  array(['AreaShape_Zernike_6_0', 0.015910827587190216], dtype=object),
#  array(['AreaShape_Zernike_2_2', 0.015881531559487044], dtype=object),
#  array(['AreaShape_Zernike_6_6', 0.015842453010376713], dtype=object),
#  array(['AreaShape_MinFeretDiameter', 0.015802132731949723], dtype=object),
#  array(['AreaShape_Zernike_9_5', 0.01579997295535405], dtype=object),
#  array(['AreaShape_Zernike_5_5', 0.015711300380781414], dtype=object),
#  array(['AreaShape_Zernike_4_2', 0.01570156677804702], dtype=object),
#  array(['AreaShape_MinorAxisLength', 0.015669304102833344], dtype=object),
#  array(['AreaShape_Zernike_7_1', 0.015604409358056999], dtype=object),
#  array(['AreaShape_Zernike_7_5', 0.015563561443408702], dtype=object),
#  array(['AreaShape_Zernike_9_9', 0.01547567547674147], dtype=object),
#  array(['AreaShape_Zernike_1_1', 0.015416206037454772], dtype=object),
#  array(['AreaShape_Zernike_3_1', 0.015337839451446704], dtype=object),
#  array(['AreaShape_MaximumRadius', 0.01515033287158756], dtype=object),
#  array(['AreaShape_Eccentricity', 0.015042562295470067], dtype=object),
#  array(['Location_Center_X', 0.014307445217801027], dtype=object),
#  array(['Location_Center_Y', 0.014232394166860243], dtype=object),
#  array(['AreaShape_EquivalentDiameter', 0.014068560099499241], dtype=object),
#  array(['AreaShape_Center_Y', 0.014028736577890666], dtype=object),
#  array(['AreaShape_Center_X', 0.014013343050696125], dtype=object),
#  array(['AreaShape_MajorAxisLength', 0.01325016865537255], dtype=object),
#  array(['AreaShape_BoundingBoxArea', 0.01318709638259724], dtype=object),
#  array(['AreaShape_ConvexArea', 0.012918015978111678], dtype=object),
#  array(['AreaShape_Area', 0.012819473813949555], dtype=object),
#  array(['AreaShape_Perimeter', 0.012766592612546984], dtype=object),
#  array(['AreaShape_MaxFeretDiameter', 0.01272455585494523], dtype=object),
#  array(['Neighbors_PercentTouching_Expanded', 0.012562494147436003],
#        dtype=object),
#  array(['AreaShape_BoundingBoxMinimum_X', 0.011991689745838195],
#        dtype=object),
#  array(['AreaShape_BoundingBoxMaximum_Y', 0.011676355247353262],
#        dtype=object),
#  array(['AreaShape_BoundingBoxMaximum_X', 0.011650205089266931],
#        dtype=object),
#  array(['Neighbors_FirstClosestObjectNumber_Expanded',
#         0.011052842409024046], dtype=object),
#  array(['Neighbors_SecondClosestObjectNumber_Expanded',
#         0.010965119602923106], dtype=object),
#  array(['AreaShape_BoundingBoxMinimum_Y', 0.010859043584408956],
#        dtype=object),
#  array(['ObjectNumber', 0.009254639790403729], dtype=object),
#  array(['AreaShape_MedianRadius', 0.009189862897540656], dtype=object),
#  array(['Number_Object_Number', 0.009180724882123868], dtype=object),
#  array(['Neighbors_NumberOfNeighbors_Expanded', 0.005875480068160613],
#        dtype=object),
#  array(['AreaShape_EulerNumber', 0.00011521035335857745], dtype=object),
#  array(['Location_Center_Z', 0.0], dtype=object)]
