# %% [markdown]
# # Random Forest
#
# Similar to notebook 01 but using only columns with Nucleus in the name.

# %%
MAX_DEPTH = 8
N_ESTIMATORS = 500
CHOOSE_EVERY = 10
SAVE_MEM = True

# %%
from datetime import datetime
print(datetime.now())
from platform import python_version
print('Python',python_version())
import csv
import numpy as np
import pandas as pd
import matplotlib as plt
import random
import sklearn   # pip install --upgrade scikit-learn
print('sklearn',sklearn.__version__)
# The model
from sklearn.ensemble import RandomForestClassifier
# Out:
# 2022-08-01 16:30:38.523553
# Python 3.8.10
# sklearn 1.0.2

# %%
# Patch data.
# This is the patch-level csv file: one row per patch, with nucleus totals from CellProfiler.
FILENAME='Process100_Image.csv'
# This directory contains one Image.csv file per patient.
# These csv files were slimmed to remove give-away columns.
# These csv files do contain high-RBC patches; consider filtering them.
BASE_PATH='/home/jrm/Adjeroh/Glioma/August_Run/CellProfilerPerPatient/'  # alien

# Patient data.
# Each patch filename indicates patient/case [0:19] and WSI [0:23].
# For example: TCGA-06-0129-01Z-00-DX1_5400_5100.png
LEN_PATIENT_ID = 19
FOLDS_META_FILE = '/home/jrm/Adjeroh/Glioma/August_Run/TrainValidSplits/aug_train_valid_splits.csv'
NUM_FOLDS = 5

# %% [markdown]
# ## Data loading functions

# %%
METADATA = pd.read_csv(FOLDS_META_FILE)
METADATA
# Out:
#      Fold  Split                 Case  Class
# 0       0  Train  TCGA-02-0004-01Z-00      0
# 1       0  Train  TCGA-02-0010-01Z-00      0
# 2       0  Train  TCGA-14-0789-01Z-00      0
# 3       0  Train  TCGA-02-0025-01Z-00      0
# 4       0  Train  TCGA-02-0033-01Z-00      0
# ..    ...    ...                  ...    ...
# 630     4  Valid  TCGA-S9-A7J2-01Z-00      5
# 631     4  Valid  TCGA-02-0430-01Z-00      0
# 632     4  Valid  TCGA-28-1746-01Z-00      0
# 633     4  Valid  TCGA-HT-7676-01Z-00      1
# 634     4  Valid  TCGA-CS-5397-01Z-00      3
#
# [635 rows x 4 columns]

# %%
def get_metadata_one_fold(fold,is_train):
    df = METADATA.loc[METADATA['Fold']==fold]
    if is_train:
        df = df.loc[df['Split']=='Train']
    else:
        df = df.loc[df['Split']=='Valid']
    patients = df['Case'].tolist()
    labels = df['Class'].tolist()
    return patients,labels

# %%
# Given a patient name, load the Image.csv file.
# Expect a string that matches a directory name, like 'TCGA-S9-A6UB-01Z-00'
# Returns a numpy array.
def load_one_patient_data(filepath):
    # Reading csv file, skip row 1 = column headers
    ary = np.loadtxt(filepath,skiprows=1,delimiter=',')
    return ary

# %%
def load_all_patients_data(patients,labels,save_mem=False):
    X = None  # dataframe with 5000 feature columns, one row per patch
    y = None  # list of labels = cancer class for each row
    z = None  # list of patient name for each row
    count=0
    for patient in patients:
        label = labels[count]
        count += 1
        directory = patient+'/'
        filepath=BASE_PATH+directory+FILENAME
        Xall = load_one_patient_data(filepath)
        if (save_mem):
            Xi = Xall[0::CHOOSE_EVERY].copy()  # e.g. choose every tenth patch
        else:
            Xi = Xall
        yi = np.full(shape=len(Xi), fill_value=label, dtype=np.int8)
        zi = [patient]*len(Xi)  # same ID for all patches from one patient
        if X is None:
            X = Xi
            y = yi
            z = zi
        else:
            X = np.concatenate( (X, Xi) )
            y = np.concatenate( (y, yi) )
            z = np.concatenate( (z, zi) )
    # X combines all patches of all WSI for all patients requested.
    # For debugging, we'll add column headers to the dataframe.
    X = pd.DataFrame(X)
    directory = patients[0] + '/'   # first patient is as good as any
    filepath=BASE_PATH+directory+FILENAME
    with open(filepath) as infile:
        rows = csv.reader(infile)
        for row in rows:
            header = row    # first row has column headers
            break
    X.columns = header
    if 'ImageNumber' in X.columns:
        X = X.drop(columns=['ImageNumber'])
    return X,y,z   # patch data, patch labels, patch patient names

# %%
# This is slow, probably due to concatenating dataframes.
# Consider a rewrite that concatenates csv before constructing a dataframe.
def load_train_valid_set(fold):
    patients,labels = get_metadata_one_fold(fold,True) # True=train
    X_train,y_train,z_train = load_all_patients_data(patients,labels,SAVE_MEM) 
    patients,labels = get_metadata_one_fold(fold,False) # False=valid
    X_valid,y_valid,z_valid = load_all_patients_data(patients,labels,False) # should always be False
    return X_train,y_train,z_train,X_valid,y_valid,z_valid

# %% [markdown]
# ## Aggregation functions

# %%
# Each patch votes on the class for its WSI.
# Later, weight each patch label by the confidence i.e. score
def aggregate_accuracy(y_pred,y_valid,z_valid):
    L = len(y_pred)
    if L != len(y_valid) or L != len(z_valid):
        raise Exception('Lengths do not match')
    correct = {}
    incorrect = {}
    patients = np.unique(z_valid)
    for patient in patients:
        correct[patient]=0  # accumulate correct votes on patches
        incorrect[patient]=0  # accumulate incorrect votes
    for i in range(L):
        patient = z_valid[i]
        label =   y_valid[i]
        pred =    y_pred[i]
        if pred == label:
            correct[patient] += 1
        else:
            incorrect[patient] += 1
    numerator = 0
    denominator = 0
    for patient in patients:
        denominator += 1
        if correct[patient]>incorrect[patient]:
            numerator += 1
    accuracy = float(0)
    if denominator>0:
        accuracy = 100.0*numerator/denominator 
    return accuracy

# %% [markdown]
# ## Main loop: Load, Classify, Report

# %%
def important_features(model):
    # Prereqs: fit().
    names = model.feature_names_in_
    importances = model.feature_importances_
    pairs = np.column_stack( (names,importances) )
    top_array = sorted(pairs, key = lambda e:e[1], reverse=True)
    # There must be a way to do this witout a loop!
    top_list = []
    for i in top_array:
         top_list.append((i[1],i[0]))  # 0=feature_name, 1=importance
    top_df = pd.DataFrame(top_list)
    return top_df

# %%
patch_accuracies = []   # summary statistics
patient_accuracies = [] # summary statistics

for fold in range(NUM_FOLDS):
    print()
    print(datetime.now(),'Fold',fold,'Loading...')
    X_train,y_train,z_train,X_valid,y_valid,z_valid = load_train_valid_set(fold)    
    print('Train lengths X,y,z:',X_train.shape,len(y_train),len(z_train))
    print('Valid lengths X,y,z:',X_valid.shape,len(y_valid),len(z_valid))
    
    print(datetime.now(),'Fold',fold,'Reduce columns...')
    good_cols = [c for c in X_train.columns if 'Nucleus' in c]
    X_train = X_train[good_cols]
    X_valid = X_valid[good_cols]
    print('Train lengths X,y,z:',X_train.shape,len(y_train),len(z_train))
    print('Valid lengths X,y,z:',X_valid.shape,len(y_valid),len(z_valid))

    # The shuffle is not strictly necessary with RF.
    # CNN models are sensitive to train set order but RF models are not. 
    # print(datetime.now(),'Shuffle...')
    # X_train,y_train = sklearn.shuffle(X_train,y_train)

    print(datetime.now(),'Fold',fold,'Train...')
    # min_samples_leaf=1 (default) led to overfitting
    rfc = RandomForestClassifier(max_depth=MAX_DEPTH,n_estimators=N_ESTIMATORS)
    rfc.fit(X_train,y_train)  # slow
    
    print(datetime.now(),'Fold',fold,'Ranked feature imporances...')
    top = important_features(rfc)
    #pd.set_option('display.max_rows', None)
    print(top.loc[:10])
    
    print(datetime.now(),'Fold',fold,'Evaluate...')
    y_pred = rfc.predict(X_train)
    matches = np.count_nonzero(y_train==y_pred)
    accuracy_t = 100.0 * matches / len(y_pred)
    print('Fold',fold,'Patch-level Training Accuracy:',accuracy_t)
    
    print(datetime.now(),'Validate...')
    y_pred = rfc.predict(X_valid)
    matches = np.count_nonzero(y_valid==y_pred)
    accuracy_v = 100.0 * matches / len(y_pred)
    print('Fold',fold,'Patch-level Validation Accuracy:',accuracy_v)
    patch_accuracies.append(accuracy_v)
    
    accuracy_p = aggregate_accuracy(y_pred,y_valid,z_valid)
    patient_accuracies.append(accuracy_p)
    print('Fold',fold,'Patient-level Validation Accuracy:',accuracy_p)
    
    # This shouldn't be necessary but it seems to reduce memory footprint.
    X_train=None
    X_valid=None
    y_train=None
    y_valid=None
    z_train=None
    z_valid=None
    y_pred = None
    matches = None
# Out:
# 2022-08-01 16:30:39.122806 Fold 0 Loading...
# Train lengths X,y,z: (7592, 5301) 7592 7592
# Valid lengths X,y,z: (15500, 5301) 15500 15500
# 2022-08-01 16:31:46.194724 Fold 0 Reduce columns...
# Train lengths X,y,z: (7592, 1951) 7592 7592
# Valid lengths X,y,z: (15500, 1951) 15500 15500
# 2022-08-01 16:31:46.296779 Fold 0 Train...
# 2022-08-01 16:32:38.995196 Fold 0 Ranked feature imporances...
#            0                                                  1
# 0   0.020651                Median_Nucleus_AreaShape_MeanRadius
# 1   0.014665                  Mean_Nucleus_AreaShape_MeanRadius
# 2   0.011524  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_5...
# 3   0.010940               Mean_Nucleus_AreaShape_MaximumRadius
# 4   0.010546                Mean_Nucleus_AreaShape_MedianRadius
# 5   0.010051  Median_Nucleus_AreaShape_InertiaTensorEigenval...
# 6   0.009772  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_7...
# 7   0.009071           Median_Nucleus_AreaShape_MinorAxisLength
# 8   0.008322          Median_Nucleus_AreaShape_MinFeretDiameter
# 9   0.008171  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_3...
# 10  0.008088  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_5_0...
# 2022-08-01 16:32:39.026935 Fold 0 Evaluate...
# Fold 0 Patch-level Training Accuracy: 79.88672286617492
# 2022-08-01 16:32:39.502728 Validate...
# Fold 0 Patch-level Validation Accuracy: 57.70967741935484
# Fold 0 Patient-level Validation Accuracy: 42.30769230769231
#
# 2022-08-01 16:32:40.496238 Fold 1 Loading...
# Train lengths X,y,z: (6490, 5301) 6490 6490
# Valid lengths X,y,z: (26463, 5301) 26463 26463
# 2022-08-01 16:33:49.342486 Fold 1 Reduce columns...
# Train lengths X,y,z: (6490, 1951) 6490 6490
# Valid lengths X,y,z: (26463, 1951) 26463 26463
# 2022-08-01 16:33:49.505095 Fold 1 Train...
# 2022-08-01 16:34:35.296689 Fold 1 Ranked feature imporances...
#            0                                                  1
# 0   0.012836  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_5_0...
# 1   0.011628                  Mean_Nucleus_AreaShape_MeanRadius
# 2   0.011619               Mean_Nucleus_AreaShape_MaximumRadius
# 3   0.011051  Median_Nucleus_AreaShape_InertiaTensorEigenval...
# 4   0.010664                Median_Nucleus_AreaShape_MeanRadius
# 5   0.009916              Median_Nucleus_AreaShape_MedianRadius
# 6   0.009681  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_4...
# 7   0.009483  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_5...
# 8   0.008394  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_7...
# 9   0.008238  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_5_0...
# 10  0.008014  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_3...
# 2022-08-01 16:34:35.350487 Fold 1 Evaluate...
# Fold 1 Patch-level Training Accuracy: 83.00462249614792
# 2022-08-01 16:34:35.797804 Validate...
# Fold 1 Patch-level Validation Accuracy: 58.79152023580093
# Fold 1 Patient-level Validation Accuracy: 30.76923076923077
#
# 2022-08-01 16:34:37.521618 Fold 2 Loading...
# Train lengths X,y,z: (7212, 5301) 7212 7212
# Valid lengths X,y,z: (19305, 5301) 19305 19305
# 2022-08-01 16:35:49.498444 Fold 2 Reduce columns...
# Train lengths X,y,z: (7212, 1951) 7212 7212
# Valid lengths X,y,z: (19305, 1951) 19305 19305
# 2022-08-01 16:35:50.028262 Fold 2 Train...
# 2022-08-01 16:36:42.419749 Fold 2 Ranked feature imporances...
#            0                                                  1
# 0   0.012812                Median_Nucleus_AreaShape_MeanRadius
# 1   0.012672             Median_Nucleus_AreaShape_MaximumRadius
# 2   0.012269               Mean_Nucleus_AreaShape_MaximumRadius
# 3   0.012106           Median_Nucleus_AreaShape_MinorAxisLength
# 4   0.011978                  Mean_Nucleus_AreaShape_MeanRadius
# 5   0.011844              Median_Nucleus_AreaShape_MedianRadius
# 6   0.010455             Mean_Nucleus_AreaShape_MinorAxisLength
# 7   0.010094  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_5_0...
# 8   0.009320  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_7...
# 9   0.009317          Median_Nucleus_AreaShape_MinFeretDiameter
# 10  0.009117                Mean_Nucleus_AreaShape_MedianRadius
# 2022-08-01 16:36:42.526170 Fold 2 Evaluate...
# Fold 2 Patch-level Training Accuracy: 81.91902384914032
# 2022-08-01 16:36:42.998825 Validate...
# Fold 2 Patch-level Validation Accuracy: 57.23905723905724
# Fold 2 Patient-level Validation Accuracy: 36.0
#
# 2022-08-01 16:36:44.297766 Fold 3 Loading...
# Train lengths X,y,z: (7493, 5301) 7493 7493
# Valid lengths X,y,z: (16471, 5301) 16471 16471
# 2022-08-01 16:37:53.903840 Fold 3 Reduce columns...
# Train lengths X,y,z: (7493, 1951) 7493 7493
# Valid lengths X,y,z: (16471, 1951) 16471 16471
# 2022-08-01 16:37:54.298867 Fold 3 Train...
# 2022-08-01 16:38:49.479779 Fold 3 Ranked feature imporances...
#            0                                                  1
# 0   0.013119           Median_Nucleus_AreaShape_MinorAxisLength
# 1   0.013066          Median_Nucleus_AreaShape_MinFeretDiameter
# 2   0.012825               Mean_Nucleus_AreaShape_MaximumRadius
# 3   0.011407  Median_Nucleus_AreaShape_InertiaTensorEigenval...
# 4   0.011170                Median_Nucleus_AreaShape_MeanRadius
# 5   0.010192                  Mean_Nucleus_AreaShape_MeanRadius
# 6   0.010189             Median_Nucleus_AreaShape_MaximumRadius
# 7   0.008575                Mean_Nucleus_AreaShape_MedianRadius
# 8   0.008439              Median_Nucleus_AreaShape_MedianRadius
# 9   0.007775      Median_Nucleus_Texture_Entropy_Eosin_7_02_256
# 10  0.007734  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_7...
# 2022-08-01 16:38:49.550717 Fold 3 Evaluate...
# Fold 3 Patch-level Training Accuracy: 81.20912851995196
# 2022-08-01 16:38:50.180074 Validate...
# Fold 3 Patch-level Validation Accuracy: 59.23137635844818
# Fold 3 Patient-level Validation Accuracy: 48.0
#
# 2022-08-01 16:38:51.627541 Fold 4 Loading...
# Train lengths X,y,z: (7817, 5301) 7817 7817
# Valid lengths X,y,z: (13209, 5301) 13209 13209
# 2022-08-01 16:40:00.818269 Fold 4 Reduce columns...
# Train lengths X,y,z: (7817, 1951) 7817 7817
# Valid lengths X,y,z: (13209, 1951) 13209 13209
# 2022-08-01 16:40:00.917958 Fold 4 Train...
# 2022-08-01 16:40:58.970356 Fold 4 Ranked feature imporances...
#            0                                                  1
# 0   0.016500               Mean_Nucleus_AreaShape_MaximumRadius
# 1   0.016457                Median_Nucleus_AreaShape_MeanRadius
# 2   0.013342                Mean_Nucleus_AreaShape_MedianRadius
# 3   0.012559                  Mean_Nucleus_AreaShape_MeanRadius
# 4   0.011707           Median_Nucleus_AreaShape_MinorAxisLength
# 5   0.011483              Median_Nucleus_AreaShape_MedianRadius
# 6   0.010481  Median_Nucleus_AreaShape_InertiaTensorEigenval...
# 7   0.009399             Median_Nucleus_AreaShape_MaximumRadius
# 8   0.008718  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_5...
# 9   0.008443  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_7...
# 10  0.008349  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_4_0...
# 2022-08-01 16:40:59.184643 Fold 4 Evaluate...
# Fold 4 Patch-level Training Accuracy: 81.56581808878086
# 2022-08-01 16:40:59.851194 Validate...
# Fold 4 Patch-level Validation Accuracy: 50.44287985464456
# Fold 4 Patient-level Validation Accuracy: 44.0

# %%
print(datetime.now())
print('Cross validation patch-level accuracy:',patch_accuracies)
print('mean:',np.mean(patch_accuracies),'std:',np.std(patch_accuracies))
print('Cross validation patient-level accuracy:',patient_accuracies)
print('mean:',np.mean(patient_accuracies),'std:',np.std(patient_accuracies))
# Out:
# 2022-08-01 16:41:16.639349
# Cross validation patch-level accuracy: [57.70967741935484, 58.79152023580093, 57.23905723905724, 59.23137635844818, 50.44287985464456]
# mean: 56.682902221461156 std: 3.2013261379081106
# Cross validation patient-level accuracy: [42.30769230769231, 30.76923076923077, 36.0, 48.0, 44.0]
# mean: 40.21538461538462 std: 6.10410667855627
