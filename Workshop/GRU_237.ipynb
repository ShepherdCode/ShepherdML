# %% [markdown]
# # GRU 237
# Test the RNA length effect.

# %%
NC_FILENAME='ncRNA.gc34.processed.fasta'
PC_FILENAME='pcRNA.gc34.processed.fasta'
DATAPATH=""
try:
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
    NC_FILENAME = DATAPATH+NC_FILENAME
    PC_FILENAME = DATAPATH+PC_FILENAME
except:
    IN_COLAB = False
    DATAPATH="" 

EPOCHS=100  # use 2 for debug, 200 for real
K=3
VOCABULARY_SIZE=4**K+1   # e.g. K=3 => 64 DNA K-mers + 'NNN'
EMBED_DIMEN=16
FILENAME='GRU237'
NEURONS=32
ACT="tanh"
DROP=0.5
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import StratifiedKFold
import tensorflow as tf
from tensorflow import keras
from keras.wrappers.scikit_learn import KerasRegressor
from keras.models import Sequential
from keras.layers import Bidirectional
from keras.layers import GRU
from keras.layers import Dense
from keras.layers import LayerNormalization
import time
dt='float32'
tf.keras.backend.set_floatx(dt)

# %% [markdown]
# ## Build model

# %%
def compile_model(model):
    adam_default_learn_rate = 0.001
    schedule = tf.keras.optimizers.schedules.ExponentialDecay(
        initial_learning_rate = adam_default_learn_rate*10,
        #decay_steps=100000, decay_rate=0.96, staircase=True)
        decay_steps=10000, decay_rate=0.99, staircase=True)
    # learn rate = initial_learning_rate * decay_rate ^ (step / decay_steps)
    alrd = tf.keras.optimizers.Adam(learning_rate=schedule)
    bc=tf.keras.losses.BinaryCrossentropy(from_logits=False)
    print("COMPILE...")
    #model.compile(loss=bc, optimizer=alrd, metrics=["accuracy"])
    model.compile(loss=bc, optimizer="adam", metrics=["accuracy"])
    print("...COMPILED")
    return model

def build_model():
    embed_layer  = keras.layers.Embedding(
        #VOCABULARY_SIZE, EMBED_DIMEN, input_length=1000, input_length=1000, mask_zero=True)
        #input_dim=[None,VOCABULARY_SIZE], output_dim=EMBED_DIMEN, mask_zero=True)
        input_dim=VOCABULARY_SIZE, output_dim=EMBED_DIMEN, mask_zero=True)
    #rnn1_layer = keras.layers.Bidirectional(
    rnn1_layer = keras.layers.GRU(NEURONS, return_sequences=True, 
          input_shape=[1000,EMBED_DIMEN], activation=ACT, dropout=DROP)#)#bi
    #rnn2_layer = keras.layers.Bidirectional(
    rnn2_layer = keras.layers.GRU(NEURONS, return_sequences=False, 
        activation=ACT, dropout=DROP)#)#bi
    dense1_layer = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt)
    #drop1_layer = keras.layers.Dropout(DROP)
    dense2_layer = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt)
    #drop2_layer = keras.layers.Dropout(DROP)
    output_layer = keras.layers.Dense(1, activation="sigmoid", dtype=dt)
    mlp = keras.models.Sequential()
    mlp.add(embed_layer)
    mlp.add(rnn1_layer)
    mlp.add(rnn2_layer)
    mlp.add(dense1_layer)
    #mlp.add(drop1_layer)
    mlp.add(dense2_layer)
    #mlp.add(drop2_layer)
    mlp.add(output_layer)
    mlpc = compile_model(mlp)
    return mlpc

# %% [markdown]
# ## Load and partition sequences

# %%
# Assume file was preprocessed to contain one line per seq.
# Prefer Pandas dataframe but df does not support append.
# For conversion to tensor, must avoid python lists.
def load_fasta(filename,label):
    DEFLINE='>'
    labels=[]
    seqs=[]
    lens=[]
    nums=[]
    num=0
    with open (filename,'r') as infile:
        for line in infile:
            if line[0]!=DEFLINE:
                seq=line.rstrip()
                num += 1   # first seqnum is 1
                seqlen=len(seq)
                nums.append(num)
                labels.append(label)
                seqs.append(seq)
                lens.append(seqlen)
    df1=pd.DataFrame(nums,columns=['seqnum'])
    df2=pd.DataFrame(labels,columns=['class'])
    df3=pd.DataFrame(seqs,columns=['sequence'])
    df4=pd.DataFrame(lens,columns=['seqlen'])
    df=pd.concat((df1,df2,df3,df4),axis=1)
    return df

def separate_X_and_y(data):
    y=   data[['class']].copy()
    X=   data.drop(columns=['class','seqnum','seqlen'])
    return (X,y)

# %% [markdown]
# ## Make K-mers

# %%
def make_kmer_table(K):
    npad='N'*K
    shorter_kmers=['']
    for i in range(K):
        longer_kmers=[]
        for mer in shorter_kmers:
            longer_kmers.append(mer+'A')
            longer_kmers.append(mer+'C')
            longer_kmers.append(mer+'G')
            longer_kmers.append(mer+'T')
        shorter_kmers = longer_kmers
    all_kmers = shorter_kmers
    kmer_dict = {}
    kmer_dict[npad]=0
    value=1
    for mer in all_kmers:
        kmer_dict[mer]=value
        value += 1
    return kmer_dict

KMER_TABLE=make_kmer_table(K)

def strings_to_vectors(data,uniform_len):
    all_seqs=[]
    for seq in data['sequence']:
        i=0
        seqlen=len(seq)
        kmers=[]
        while i < seqlen-K+1 -1:  # stop at minus one for spaced seed
            #kmer=seq[i:i+2]+seq[i+3:i+5]    # SPACED SEED 2/1/2 for K=4
            kmer=seq[i:i+K]  
            i += 1
            value=KMER_TABLE[kmer]
            kmers.append(value)
        pad_val=0
        while i < uniform_len:
            kmers.append(pad_val)
            i += 1
        all_seqs.append(kmers)
    pd2d=pd.DataFrame(all_seqs)
    return pd2d   # return 2D dataframe, uniform dimensions

# %%
def make_kmers(MAXLEN,train_set):
    (X_train_all,y_train_all)=separate_X_and_y(train_set)
    X_train_kmers=strings_to_vectors(X_train_all,MAXLEN)
    # From pandas dataframe to numpy to list to numpy
    num_seqs=len(X_train_kmers)
    tmp_seqs=[]
    for i in range(num_seqs):
        kmer_sequence=X_train_kmers.iloc[i]
        tmp_seqs.append(kmer_sequence)
    X_train_kmers=np.array(tmp_seqs)
    tmp_seqs=None
    labels=y_train_all.to_numpy()
    return (X_train_kmers,labels)

# %%
def make_frequencies(Xin):
    Xout=[]
    VOCABULARY_SIZE= 4**K + 1  # plus one for 'NNN'
    for seq in Xin:
        freqs =[0] * VOCABULARY_SIZE
        total = 0
        for kmerval in seq:
            freqs[kmerval] += 1
            total += 1
        for c in range(VOCABULARY_SIZE):
            freqs[c] = freqs[c]/total
        Xout.append(freqs)
    Xnum = np.asarray(Xout)
    return (Xnum)
def make_slice(data_set,min_len,max_len):
    slice = data_set.query('seqlen <= '+str(max_len)+' & seqlen>= '+str(min_len))
    return slice

# %% [markdown]
# ## Cross validation

# %%
bestname=DATAPATH+FILENAME+".best"
def just_train(X,y): # give me training set
    model=build_model()
    print(model.summary())
    mycallbacks = [keras.callbacks.ModelCheckpoint(
        filepath=bestname, save_best_only=True, 
        monitor='accuracy', mode='max')]   
    print("FIT")
    start_time=time.time()
    history=model.fit(X_train, y_train, # batch_size=10, default=32 works nicely
            epochs=EPOCHS, verbose=1,  # verbose=1 for ascii art, verbose=0 for none
            callbacks=mycallbacks )  # no validation data
    end_time=time.time()
    elapsed_time=(end_time-start_time)                        
    print("Train %d epochs, %d sec"%(EPOCHS,elapsed_time))
    pd.DataFrame(history.history).plot(figsize=(8,5))
    plt.grid(True)
    plt.gca().set_ylim(0,1)
    plt.show()
def just_evaluate(X,y):  # give me validation set
    best_model=keras.models.load_model(bestname)
    scores = best_model.evaluate(X, y, verbose=0)
    print("%s: %.2f%%" % (best_model.metrics_names[1], scores[1]*100))

# %% [markdown]
# ## Train on RNA length-based slice

# %%
#      A    B    C     D     E     F
# 200, 500, 750, 1000, 1500, 3000, 30000 
print("Load data from files.")
nc_seq=load_fasta(NC_FILENAME,0)
pc_seq=load_fasta(PC_FILENAME,1)
train_set=pd.concat((nc_seq,pc_seq),axis=0)
nc_seq=None
pc_seq=None
def get_x_and_y(train_set,minlen,maxlen):
  subset=make_slice(train_set,minlen,maxlen)
  (X_set,y_set)=make_kmers(maxlen,subset)
  print("Shape of X is "+str(X_set.shape))
  L=len(X_set)
  T=int(0.80*L+0.5)
  print("Total %d, Train portion %d"%(L,T))
  X_train=X_set[:T]
  y_train=y_set[:T]
  X_valid=X_set[T:]
  y_valid=y_set[T:]
  return (X_train,y_train,X_valid,y_valid)

MINLEN=1000
MAXLEN=1500
(X_train,y_train,X_valid_A,y_valid_A)=get_x_and_y(train_set,200,500)
(X_train,y_train,X_valid_B,y_valid_B)=get_x_and_y(train_set,500,750)
(X_train,y_train,X_valid_C,y_valid_C)=get_x_and_y(train_set,750,1000)
(X_train,y_train,X_valid_D,y_valid_D)=get_x_and_y(train_set,1000,1500)
(X_train,y_train,X_valid_E,y_valid_E)=get_x_and_y(train_set,1500,3000)
(X_train,y_train,X_valid_F,y_valid_F)=get_x_and_y(train_set,3000,30000)
(X_train,y_train,X_valid,y_valid)=get_x_and_y(train_set,MINLEN,MAXLEN)
print("Loaded")
# Out:
# Load data from files.
# Shape of X is (4516, 500)
# Total 4516, Train portion 3613
# Shape of X is (7198, 750)
# Total 7198, Train portion 5758
# Shape of X is (4456, 1000)
# Total 4456, Train portion 3565
# Shape of X is (4580, 1500)
# Total 4580, Train portion 3664
# Shape of X is (7446, 3000)
# Total 7446, Train portion 5957
# Shape of X is (3900, 30000)
# Total 3900, Train portion 3120
# Shape of X is (4580, 1500)
# Total 4580, Train portion 3664
# Loaded

# %%
print ("Train on ",MINLEN,"-",MAXLEN)
just_train(X_train,y_train)
# Out:
# Train on  1000 - 1500
# COMPILE...
# ...COMPILED
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_5 (Embedding)      (None, None, 16)          1040
# _________________________________________________________________
# gru_10 (GRU)                 (None, None, 32)          4800
# _________________________________________________________________
# gru_11 (GRU)                 (None, 32)                6336
# _________________________________________________________________
# dense_15 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_16 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 14,321
# Trainable params: 14,321
# Non-trainable params: 0
# _________________________________________________________________
# None
# FIT
# Epoch 1/100
# 115/115 [==============================] - ETA: 0s - loss: 0.6821 - accuracy: 0.5639INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU237.best/assets
# 115/115 [==============================] - 25s 217ms/step - loss: 0.6821 - accuracy: 0.5639
# Epoch 2/100
# 115/115 [==============================] - ETA: 0s - loss: 0.6661 - accuracy: 0.5942INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU237.best/assets
# 115/115 [==============================] - 27s 233ms/step - loss: 0.6661 - accuracy: 0.5942
# Epoch 3/100
# 115/115 [==============================] - ETA: 0s - loss: 0.6603 - accuracy: 0.6067INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU237.best/assets
# 115/115 [==============================] - 25s 218ms/step - loss: 0.6603 - accuracy: 0.6067
# Epoch 4/100
# 115/115 [==============================] - ETA: 0s - loss: 0.6517 - accuracy: 0.6250INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU237.best/assets
# 115/115 [==============================] - 27s 237ms/step - loss: 0.6517 - accuracy: 0.6250
# Epoch 5/100
# 115/115 [==============================] - ETA: 0s - loss: 0.6451 - accuracy: 0.6376INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU237.best/assets
# 115/115 [==============================] - 25s 216ms/step - loss: 0.6451 - accuracy: 0.6376
# Epoch 6/100
# 115/115 [==============================] - 11s 95ms/step - loss: 0.6528 - accuracy: 0.6294
# Epoch 7/100
# 115/115 [==============================] - 11s 93ms/step - loss: 0.6450 - accuracy: 0.6351
# Epoch 8/100
# 115/115 [==============================] - 11s 94ms/step - loss: 0.6419 - accuracy: 0.6362
# Epoch 9/100
# 115/115 [==============================] - ETA: 0s - loss: 0.6383 - accuracy: 0.6419INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU237.best/assets
# 115/115 [==============================] - 25s 215ms/step - loss: 0.6383 - accuracy: 0.6419
# Epoch 10/100
# 115/115 [==============================] - ETA: 0s - loss: 0.6413 - accuracy: 0.6422INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU237.best/assets
# 115/115 [==============================] - 29s 249ms/step - loss: 0.6413 - accuracy: 0.6422
# Epoch 11/100
# 115/115 [==============================] - 11s 94ms/step - loss: 0.6368 - accuracy: 0.6416
# Epoch 12/100
# 115/115 [==============================] - 11s 94ms/step - loss: 0.6477 - accuracy: 0.6324
# Epoch 13/100
# 115/115 [==============================] - 11s 94ms/step - loss: 0.6416 - accuracy: 0.6346
# Epoch 14/100
# 115/115 [==============================] - ETA: 0s - loss: 0.6269 - accuracy: 0.6624INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU237.best/assets
# 115/115 [==============================] - 25s 217ms/step - loss: 0.6269 - accuracy: 0.6624
# Epoch 15/100
# 115/115 [==============================] - 11s 94ms/step - loss: 0.6287 - accuracy: 0.6569
# Epoch 16/100
# 115/115 [==============================] - 11s 94ms/step - loss: 0.6230 - accuracy: 0.6588
# Epoch 17/100
# 115/115 [==============================] - 11s 96ms/step - loss: 0.6672 - accuracy: 0.5950
# Epoch 18/100
# 115/115 [==============================] - 11s 95ms/step - loss: 0.6671 - accuracy: 0.5980
# Epoch 19/100
# 115/115 [==============================] - 11s 96ms/step - loss: 0.6586 - accuracy: 0.6171
# Epoch 20/100
# 115/115 [==============================] - 11s 96ms/step - loss: 0.6547 - accuracy: 0.6236
# Epoch 21/100
# 115/115 [==============================] - 11s 96ms/step - loss: 0.6541 - accuracy: 0.6193
# Epoch 22/100
# 115/115 [==============================] - 11s 95ms/step - loss: 0.6563 - accuracy: 0.6182
# Epoch 23/100
# 115/115 [==============================] - 11s 95ms/step - loss: 0.6481 - accuracy: 0.6280
# Epoch 24/100
# 115/115 [==============================] - 11s 96ms/step - loss: 0.6439 - accuracy: 0.6362
# Epoch 25/100
# 115/115 [==============================] - 11s 95ms/step - loss: 0.6396 - accuracy: 0.6460
# Epoch 26/100
# 115/115 [==============================] - 11s 96ms/step - loss: 0.6342 - accuracy: 0.6463
# Epoch 27/100
# 115/115 [==============================] - ETA: 0s - loss: 0.6012 - accuracy: 0.6771INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU237.best/assets
# 115/115 [==============================] - 25s 217ms/step - loss: 0.6012 - accuracy: 0.6771
# Epoch 28/100
# 115/115 [==============================] - ETA: 0s - loss: 0.5888 - accuracy: 0.6957INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU237.best/assets
# 115/115 [==============================] - 28s 246ms/step - loss: 0.5888 - accuracy: 0.6957
# Epoch 29/100
# 115/115 [==============================] - ETA: 0s - loss: 0.5491 - accuracy: 0
FO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU237.best/assets
# 115/115 [==============================] - 25s 217ms/step - loss: 0.3560 - accuracy: 0.8540
# Epoch 73/100
# 115/115 [==============================] - 11s 94ms/step - loss: 0.3642 - accuracy: 0.8444
# Epoch 74/100
# 115/115 [==============================] - 11s 95ms/step - loss: 0.3576 - accuracy: 0.8496
# Epoch 75/100
# 115/115 [==============================] - 11s 94ms/step - loss: 0.3539 - accuracy: 0.8499
# Epoch 76/100
# 115/115 [==============================] - 11s 95ms/step - loss: 0.3572 - accuracy: 0.8395
# Epoch 77/100
# 115/115 [==============================] - 11s 95ms/step - loss: 0.3557 - accuracy: 0.8496
# Epoch 78/100
# 115/115 [==============================] - 11s 96ms/step - loss: 0.3540 - accuracy: 0.8496
# Epoch 79/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3476 - accuracy: 0.8589INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU237.best/assets
# 115/115 [==============================] - 28s 241ms/step - loss: 0.3476 - accuracy: 0.8589
# Epoch 80/100
# 115/115 [==============================] - 11s 95ms/step - loss: 0.3595 - accuracy: 0.8496
# Epoch 81/100
# 115/115 [==============================] - 11s 95ms/step - loss: 0.3527 - accuracy: 0.8477
# Epoch 82/100
# 115/115 [==============================] - 11s 94ms/step - loss: 0.3642 - accuracy: 0.8417
# Epoch 83/100
# 115/115 [==============================] - 11s 94ms/step - loss: 0.3413 - accuracy: 0.8570
# Epoch 84/100
# 115/115 [==============================] - 11s 94ms/step - loss: 0.3505 - accuracy: 0.8466
# Epoch 85/100
# 115/115 [==============================] - 11s 94ms/step - loss: 0.3445 - accuracy: 0.8493
# Epoch 86/100
# 115/115 [==============================] - 11s 94ms/step - loss: 0.3493 - accuracy: 0.8521
# Epoch 87/100
# 115/115 [==============================] - 11s 93ms/step - loss: 0.3528 - accuracy: 0.8551
# Epoch 88/100
# 115/115 [==============================] - 11s 94ms/step - loss: 0.3532 - accuracy: 0.8485
# Epoch 89/100
# 115/115 [==============================] - 11s 94ms/step - loss: 0.3444 - accuracy: 0.8556
# Epoch 90/100
# 115/115 [==============================] - 11s 93ms/step - loss: 0.3505 - accuracy: 0.8466
# Epoch 91/100
# 115/115 [==============================] - 11s 95ms/step - loss: 0.3478 - accuracy: 0.8469
# Epoch 92/100
# 115/115 [==============================] - 11s 95ms/step - loss: 0.3416 - accuracy: 0.8534
# Epoch 93/100
# 115/115 [==============================] - 11s 96ms/step - loss: 0.3376 - accuracy: 0.8567
# Epoch 94/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3404 - accuracy: 0.8600INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU237.best/assets
# 115/115 [==============================] - 25s 216ms/step - loss: 0.3404 - accuracy: 0.8600
# Epoch 95/100
# 115/115 [==============================] - 11s 92ms/step - loss: 0.3367 - accuracy: 0.8562
# Epoch 96/100
# 115/115 [==============================] - 11s 92ms/step - loss: 0.3325 - accuracy: 0.8597
# Epoch 97/100
# 115/115 [==============================] - 11s 91ms/step - loss: 0.3406 - accuracy: 0.8521
# Epoch 98/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3278 - accuracy: 0.8614INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU237.best/assets
# 115/115 [==============================] - 27s 235ms/step - loss: 0.3278 - accuracy: 0.8614
# Epoch 99/100
# 115/115 [==============================] - 11s 92ms/step - loss: 0.3366 - accuracy: 0.8543
# Epoch 100/100
# 115/115 [==============================] - 11s 92ms/step - loss: 0.3390 - accuracy: 0.8564
# Train 100 epochs, 1559 sec

# %%
print ("Evaluate on A")
just_evaluate(X_valid_A,y_valid_A) 
print ("Evaluate on B")
just_evaluate(X_valid_B,y_valid_B)  
print ("Evaluate on C")
just_evaluate(X_valid_C,y_valid_C)  
print ("Evaluate on D")
just_evaluate(X_valid_D,y_valid_D)  
print ("Evaluate on E")
just_evaluate(X_valid_E,y_valid_E)  
print ("Evaluate on F")
just_evaluate(X_valid_F,y_valid_F)  

print ("Done")
# Out:
# Evaluate on A
# accuracy: 69.99%
# Evaluate on B
# accuracy: 73.68%
# Evaluate on C
# accuracy: 81.37%
# Evaluate on D
# accuracy: 81.33%
# Evaluate on E
# accuracy: 81.33%
# Evaluate on F
# accuracy: 69.74%
# Done
