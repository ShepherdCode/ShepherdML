# %% [markdown]
# # GRU 238
# Test the RNA length effect.

# %%
NC_FILENAME='ncRNA.gc34.processed.fasta'
PC_FILENAME='pcRNA.gc34.processed.fasta'
DATAPATH=""
try:
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
    NC_FILENAME = DATAPATH+NC_FILENAME
    PC_FILENAME = DATAPATH+PC_FILENAME
except:
    IN_COLAB = False
    DATAPATH="" 

EPOCHS=100  # use 2 for debug, 200 for real
K=3
VOCABULARY_SIZE=4**K+1   # e.g. K=3 => 64 DNA K-mers + 'NNN'
EMBED_DIMEN=16
FILENAME='GRU238'
NEURONS=32
ACT="tanh"
DROP=0.5
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import StratifiedKFold
import tensorflow as tf
from tensorflow import keras
from keras.wrappers.scikit_learn import KerasRegressor
from keras.models import Sequential
from keras.layers import Bidirectional
from keras.layers import GRU
from keras.layers import Dense
from keras.layers import LayerNormalization
import time
dt='float32'
tf.keras.backend.set_floatx(dt)

# %% [markdown]
# ## Build model

# %%
def compile_model(model):
    adam_default_learn_rate = 0.001
    schedule = tf.keras.optimizers.schedules.ExponentialDecay(
        initial_learning_rate = adam_default_learn_rate*10,
        #decay_steps=100000, decay_rate=0.96, staircase=True)
        decay_steps=10000, decay_rate=0.99, staircase=True)
    # learn rate = initial_learning_rate * decay_rate ^ (step / decay_steps)
    alrd = tf.keras.optimizers.Adam(learning_rate=schedule)
    bc=tf.keras.losses.BinaryCrossentropy(from_logits=False)
    print("COMPILE...")
    #model.compile(loss=bc, optimizer=alrd, metrics=["accuracy"])
    model.compile(loss=bc, optimizer="adam", metrics=["accuracy"])
    print("...COMPILED")
    return model

def build_model():
    embed_layer  = keras.layers.Embedding(
        #VOCABULARY_SIZE, EMBED_DIMEN, input_length=1000, input_length=1000, mask_zero=True)
        #input_dim=[None,VOCABULARY_SIZE], output_dim=EMBED_DIMEN, mask_zero=True)
        input_dim=VOCABULARY_SIZE, output_dim=EMBED_DIMEN, mask_zero=True)
    #rnn1_layer = keras.layers.Bidirectional(
    rnn1_layer = keras.layers.GRU(NEURONS, return_sequences=True, 
          input_shape=[1000,EMBED_DIMEN], activation=ACT, dropout=DROP)#)#bi
    #rnn2_layer = keras.layers.Bidirectional(
    rnn2_layer = keras.layers.GRU(NEURONS, return_sequences=False, 
        activation=ACT, dropout=DROP)#)#bi
    dense1_layer = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt)
    #drop1_layer = keras.layers.Dropout(DROP)
    dense2_layer = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt)
    #drop2_layer = keras.layers.Dropout(DROP)
    output_layer = keras.layers.Dense(1, activation="sigmoid", dtype=dt)
    mlp = keras.models.Sequential()
    mlp.add(embed_layer)
    mlp.add(rnn1_layer)
    mlp.add(rnn2_layer)
    mlp.add(dense1_layer)
    #mlp.add(drop1_layer)
    mlp.add(dense2_layer)
    #mlp.add(drop2_layer)
    mlp.add(output_layer)
    mlpc = compile_model(mlp)
    return mlpc

# %% [markdown]
# ## Load and partition sequences

# %%
# Assume file was preprocessed to contain one line per seq.
# Prefer Pandas dataframe but df does not support append.
# For conversion to tensor, must avoid python lists.
def load_fasta(filename,label):
    DEFLINE='>'
    labels=[]
    seqs=[]
    lens=[]
    nums=[]
    num=0
    with open (filename,'r') as infile:
        for line in infile:
            if line[0]!=DEFLINE:
                seq=line.rstrip()
                num += 1   # first seqnum is 1
                seqlen=len(seq)
                nums.append(num)
                labels.append(label)
                seqs.append(seq)
                lens.append(seqlen)
    df1=pd.DataFrame(nums,columns=['seqnum'])
    df2=pd.DataFrame(labels,columns=['class'])
    df3=pd.DataFrame(seqs,columns=['sequence'])
    df4=pd.DataFrame(lens,columns=['seqlen'])
    df=pd.concat((df1,df2,df3,df4),axis=1)
    return df

def separate_X_and_y(data):
    y=   data[['class']].copy()
    X=   data.drop(columns=['class','seqnum','seqlen'])
    return (X,y)

# %% [markdown]
# ## Make K-mers

# %%
def make_kmer_table(K):
    npad='N'*K
    shorter_kmers=['']
    for i in range(K):
        longer_kmers=[]
        for mer in shorter_kmers:
            longer_kmers.append(mer+'A')
            longer_kmers.append(mer+'C')
            longer_kmers.append(mer+'G')
            longer_kmers.append(mer+'T')
        shorter_kmers = longer_kmers
    all_kmers = shorter_kmers
    kmer_dict = {}
    kmer_dict[npad]=0
    value=1
    for mer in all_kmers:
        kmer_dict[mer]=value
        value += 1
    return kmer_dict

KMER_TABLE=make_kmer_table(K)

def strings_to_vectors(data,uniform_len):
    all_seqs=[]
    for seq in data['sequence']:
        i=0
        seqlen=len(seq)
        kmers=[]
        while i < seqlen-K+1 -1:  # stop at minus one for spaced seed
            #kmer=seq[i:i+2]+seq[i+3:i+5]    # SPACED SEED 2/1/2 for K=4
            kmer=seq[i:i+K]  
            i += 1
            value=KMER_TABLE[kmer]
            kmers.append(value)
        pad_val=0
        while i < uniform_len:
            kmers.append(pad_val)
            i += 1
        all_seqs.append(kmers)
    pd2d=pd.DataFrame(all_seqs)
    return pd2d   # return 2D dataframe, uniform dimensions

# %%
def make_kmers(MAXLEN,train_set):
    (X_train_all,y_train_all)=separate_X_and_y(train_set)
    X_train_kmers=strings_to_vectors(X_train_all,MAXLEN)
    # From pandas dataframe to numpy to list to numpy
    num_seqs=len(X_train_kmers)
    tmp_seqs=[]
    for i in range(num_seqs):
        kmer_sequence=X_train_kmers.iloc[i]
        tmp_seqs.append(kmer_sequence)
    X_train_kmers=np.array(tmp_seqs)
    tmp_seqs=None
    labels=y_train_all.to_numpy()
    return (X_train_kmers,labels)

# %%
def make_frequencies(Xin):
    Xout=[]
    VOCABULARY_SIZE= 4**K + 1  # plus one for 'NNN'
    for seq in Xin:
        freqs =[0] * VOCABULARY_SIZE
        total = 0
        for kmerval in seq:
            freqs[kmerval] += 1
            total += 1
        for c in range(VOCABULARY_SIZE):
            freqs[c] = freqs[c]/total
        Xout.append(freqs)
    Xnum = np.asarray(Xout)
    return (Xnum)
def make_slice(data_set,min_len,max_len):
    slice = data_set.query('seqlen <= '+str(max_len)+' & seqlen>= '+str(min_len))
    return slice

# %% [markdown]
# ## Cross validation

# %%
bestname=DATAPATH+FILENAME+".best"
def just_train(X,y): # give me training set
    model=build_model()
    print(model.summary())
    mycallbacks = [keras.callbacks.ModelCheckpoint(
        filepath=bestname, save_best_only=True, 
        monitor='accuracy', mode='max')]   
    print("FIT")
    start_time=time.time()
    history=model.fit(X_train, y_train, # batch_size=10, default=32 works nicely
            epochs=EPOCHS, verbose=1,  # verbose=1 for ascii art, verbose=0 for none
            callbacks=mycallbacks )  # no validation data
    end_time=time.time()
    elapsed_time=(end_time-start_time)                        
    print("Train %d epochs, %d sec"%(EPOCHS,elapsed_time))
    pd.DataFrame(history.history).plot(figsize=(8,5))
    plt.grid(True)
    plt.gca().set_ylim(0,1)
    plt.show()
def just_evaluate(X,y):  # give me validation set
    best_model=keras.models.load_model(bestname)
    scores = best_model.evaluate(X, y, verbose=0)
    print("%s: %.2f%%" % (best_model.metrics_names[1], scores[1]*100))

# %% [markdown]
# ## Train on RNA length-based slice

# %%
#      A    B    C     D     E     F
# 200, 500, 750, 1000, 1500, 3000, 30000 
print("Load data from files.")
nc_seq=load_fasta(NC_FILENAME,0)
pc_seq=load_fasta(PC_FILENAME,1)
train_set=pd.concat((nc_seq,pc_seq),axis=0)
nc_seq=None
pc_seq=None
def get_x_and_y(train_set,minlen,maxlen):
  subset=make_slice(train_set,minlen,maxlen)
  (X_set,y_set)=make_kmers(maxlen,subset)
  print("Shape of X is "+str(X_set.shape))
  L=len(X_set)
  T=int(0.80*L+0.5)
  print("Total %d, Train portion %d"%(L,T))
  X_train=X_set[:T]
  y_train=y_set[:T]
  X_valid=X_set[T:]
  y_valid=y_set[T:]
  return (X_train,y_train,X_valid,y_valid)

MINLEN=500
MAXLEN=750
(X_train,y_train,X_valid_A,y_valid_A)=get_x_and_y(train_set,200,500)
(X_train,y_train,X_valid_B,y_valid_B)=get_x_and_y(train_set,500,750)
(X_train,y_train,X_valid_C,y_valid_C)=get_x_and_y(train_set,750,1000)
(X_train,y_train,X_valid_D,y_valid_D)=get_x_and_y(train_set,1000,1500)
(X_train,y_train,X_valid_E,y_valid_E)=get_x_and_y(train_set,1500,3000)
(X_train,y_train,X_valid_F,y_valid_F)=get_x_and_y(train_set,3000,30000)
(X_train,y_train,X_valid,y_valid)=get_x_and_y(train_set,MINLEN,MAXLEN)
print("Loaded")
# Out:
# Load data from files.
# Shape of X is (4516, 500)
# Total 4516, Train portion 3613
# Shape of X is (7198, 750)
# Total 7198, Train portion 5758
# Shape of X is (4456, 1000)
# Total 4456, Train portion 3565
# Shape of X is (4580, 1500)
# Total 4580, Train portion 3664
# Shape of X is (7446, 3000)
# Total 7446, Train portion 5957
# Shape of X is (3900, 30000)
# Total 3900, Train portion 3120
# Shape of X is (7198, 750)
# Total 7198, Train portion 5758
# Loaded

# %%
print ("Train on ",MINLEN,"-",MAXLEN)
just_train(X_train,y_train)
# Out:
# Train on  500 - 750
# COMPILE...
# ...COMPILED
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, None, 16)          1040
# _________________________________________________________________
# gru_4 (GRU)                  (None, None, 32)          4800
# _________________________________________________________________
# gru_5 (GRU)                  (None, 32)                6336
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_7 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 14,321
# Trainable params: 14,321
# Non-trainable params: 0
# _________________________________________________________________
# None
# FIT
# Epoch 1/100
# 180/180 [==============================] - ETA: 0s - loss: 0.5168 - accuracy: 0.7914INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU238.best/assets
# 180/180 [==============================] - 26s 145ms/step - loss: 0.5168 - accuracy: 0.7914
# Epoch 2/100
# 180/180 [==============================] - ETA: 0s - loss: 0.5039 - accuracy: 0.7939INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU238.best/assets
# 180/180 [==============================] - 27s 151ms/step - loss: 0.5039 - accuracy: 0.7939
# Epoch 3/100
# 180/180 [==============================] - 10s 57ms/step - loss: 0.4999 - accuracy: 0.7939
# Epoch 4/100
# 180/180 [==============================] - ETA: 0s - loss: 0.4991 - accuracy: 0.7945INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU238.best/assets
# 180/180 [==============================] - 26s 146ms/step - loss: 0.4991 - accuracy: 0.7945
# Epoch 5/100
# 180/180 [==============================] - 10s 57ms/step - loss: 0.4937 - accuracy: 0.7940
# Epoch 6/100
# 180/180 [==============================] - 10s 58ms/step - loss: 0.4914 - accuracy: 0.7942
# Epoch 7/100
# 180/180 [==============================] - 10s 57ms/step - loss: 0.4887 - accuracy: 0.7942
# Epoch 8/100
# 180/180 [==============================] - 10s 56ms/step - loss: 0.4848 - accuracy: 0.7942
# Epoch 9/100
# 180/180 [==============================] - 10s 57ms/step - loss: 0.4865 - accuracy: 0.7933
# Epoch 10/100
# 180/180 [==============================] - 10s 58ms/step - loss: 0.5032 - accuracy: 0.7921
# Epoch 11/100
# 180/180 [==============================] - 10s 57ms/step - loss: 0.4941 - accuracy: 0.7926
# Epoch 12/100
# 180/180 [==============================] - 10s 57ms/step - loss: 0.4888 - accuracy: 0.7933
# Epoch 13/100
# 180/180 [==============================] - ETA: 0s - loss: 0.4775 - accuracy: 0.7952INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU238.best/assets
# 180/180 [==============================] - 28s 154ms/step - loss: 0.4775 - accuracy: 0.7952
# Epoch 14/100
# 180/180 [==============================] - 10s 57ms/step - loss: 0.5011 - accuracy: 0.7942
# Epoch 15/100
# 180/180 [==============================] - 10s 56ms/step - loss: 0.5092 - accuracy: 0.7939
# Epoch 16/100
# 180/180 [==============================] - 10s 57ms/step - loss: 0.5086 - accuracy: 0.7939
# Epoch 17/100
# 180/180 [==============================] - 10s 56ms/step - loss: 0.5055 - accuracy: 0.7939
# Epoch 18/100
# 180/180 [==============================] - 10s 56ms/step - loss: 0.4941 - accuracy: 0.7949
# Epoch 19/100
# 180/180 [==============================] - ETA: 0s - loss: 0.4573 - accuracy: 0.7959INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU238.best/assets
# 180/180 [==============================] - 27s 149ms/step - loss: 0.4573 - accuracy: 0.7959
# Epoch 20/100
# 180/180 [==============================] - ETA: 0s - loss: 0.4189 - accuracy: 0.8190INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU238.best/assets
# 180/180 [==============================] - 27s 150ms/step - loss: 0.4189 - accuracy: 0.8190
# Epoch 21/100
# 180/180 [==============================] - ETA: 0s - loss: 0.4013 - accuracy: 0.8288INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU238.best/assets
# 180/180 [==============================] - 26s 142ms/step - loss: 0.4013 - accuracy: 0.8288
# Epoch 22/100
# 180/180 [==============================] - ETA: 0s - loss: 0.3806 - accuracy: 0.8390INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU238.best/assets
# 180/180 [==============================] - 27s 152ms/step - loss: 0.3806 - accuracy: 0.8390
# Epoch 23/100
# 180/180 [==============================] - ETA: 0s - loss: 0.3791 - accuracy: 0.8433INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU238.best/assets
# 180/180 [==============================] - 27s 148ms/step - loss: 0.3791 - accuracy: 0.8433
# Epoch 24/100
# 180/180 [==============================] - 10s 58ms/step - loss: 0.3820 - accuracy: 0.8397
# Epoch 25/100
# 180/180 [==============================] - ETA: 0s - loss: 0.3618 - accuracy: 0.8501INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU238.best/assets
# 180/180 [==============================] - 25s 141ms/step - loss: 0.3618 - accuracy: 0.8501
# Epoch 26/100
# 180/180 [==============================] - 10s 55ms/step - loss: 0.3706 - accuracy: 0.8472
# Epoch 27/100
# 180/180 [==============================] - 10s 56ms/step - loss: 0.3690 - accuracy: 0.8427
# Epoch 28/100
# 180/180 [==============================] - ETA: 0s - loss: 0.3582 - accuracy: 0.8536INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU238.best/assets
# 180/180 [==============================] - 28s 154ms/step - loss: 0.3582 - accuracy: 0.8536
# Epoch 29/100
# 180/180 [==============================] - 10s 56ms/step - loss: 0.3638 - accuracy: 0.8522
# Epoch 30/100
# 180/180 [==============================] - 11s 58ms/step - loss: 0.3621 - accuracy: 0.8508
# Epoch 31/100
# 180/180 [==============================] - 10s 58ms/step - loss: 0.3566 - accuracy: 0.8503
# Epoch 32/100
# 180/180 [==============================] - 11s 59ms/step - loss: 0.3641 - accuracy: 0.8505
# Epoch 33/100
# 180/180 [==============================] - 10s 57ms/step - loss: 0.3582 - accuracy: 0.8498
# Epoch 34/100
# 180/180 [==============================] - 10s 56ms/step - loss: 0.3546 - accuracy: 0.8508
# Epoch 35/100
# 180/180 [==============================] - ETA: 0s - loss: 0.3464 - accuracy: 0.8586INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU238.best/assets
# 180/180 [==============================] - 26s 147ms/step - loss: 0.3464 - accuracy: 0.8586
# Epoch 36/100
# 180/180 [==============================] - 10s 56ms/step - loss: 0.3497 - accuracy: 0.8541
# Epoch 37/100
# 180/180 [==============================] - 10s 56ms/step - loss: 0.3526 - accuracy: 0.8545
# Epoch 38/100
# 180/180 [==============================] - 10s 58ms/step - loss: 0.3514 - accuracy: 0.8545
# Epoch 39/100
# 180/180 [==============================] - 10s 56ms/step - loss: 0.3451 - accuracy: 0.8560
# Epoch 40/100
# 180/180 [==============================] - ETA: 0s - loss: 0.3454 - accuracy: 0.8605INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU238.best/assets
# 180/180 [==============================] - 26s 142ms/step - loss: 0.3454 - accuracy: 0.8605
# Epoch 41/100
# 180/180 [==============================] - 10s 56ms/step - loss: 0.3479 - accuracy: 0.8543
# Epoch 42/100
# 180/180 [==============================] - 11s 58ms/step - loss: 0.3469 - accuracy: 0.8532
# Epoch 43/100
# 180/180 [==============================] - 10s 58ms/step - loss: 0.3415 - accuracy: 0.8590
# Epoch 44/100
# 180/180 [==============================] - 10s 58ms/step - loss: 0.3462 - accuracy: 0.8534
# Epoch 45/100
# 180/180 [==============================] - 10s 57ms/step - loss: 0.3448 - accuracy: 0.8559
# Epoch 46/100
# 180/180 [==============================] - ETA: 0s - loss: 0.3419 - accuracy: 0.8607INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU238.best/assets
# 180/180 [==============================] - 28s 156ms/step - loss: 0.3419 - accuracy: 0.8607
# Epoch 47/100
# 180/180 [==============================] - 11s 59ms/step - loss: 0.3434 - accuracy: 0.8571
# Epoch 48/100
# 180/180 [==============================] - ETA: 0s - loss: 0.3437 - accuracy: 0.8616INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU238.best/assets
# 180/180 [==============================] - 28s 153ms/step - loss: 0.3437 - accuracy: 0.8616
# Epoch 49/100
# 180/180 [==============================] - 11s 59ms/step - loss: 0.3466 - accuracy: 0.8579
# Epoch 50/100
# 180/180 [==============================] - 11s 58ms/step - loss: 0.3340 - accuracy: 0.8607
# Epoch 51/100
# 180/180 [==============================] - 10s 58ms/step - loss: 0.3390 - accuracy: 0.8583
# Epoch 52/100
# 180/180 [==============================] - ETA: 0s - loss: 0.3320 - accuracy: 0.8628INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU238.best/assets
# 180/180 [==============================] - 28s 153ms/step - loss: 0.3320 - accuracy: 0.8628
# Epoch 53/100
# 180/180 [==============================] - ETA: 0s - loss: 0.3338 - accuracy: 0.8658INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU238.best/assets
# 180/180 [==============================] - 26s 146ms/step - loss: 0.3338 - accuracy: 0.8658
# Epoch 54/100
# 180/180 [==============================] - ETA: 0s - loss: 0.3338 - accuracy: 0.8661INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU238.best/assets
# 180/180 [==============================] - 28s 155ms/step - loss: 0.3338 - accuracy: 0.8661
# Epoch 55/100
# 180/180 [==============================] - ETA: 0s - loss: 0.3273 - accuracy: 0.8664INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU238.best/assets
# 180/180 [==============================] - 26s 146ms/step - loss: 0.3273 - accuracy: 0.8664
# Epoch 56/100
# 180/180 [==============================] - 10s 55ms/step - loss: 0.3350 - accuracy: 0.8607
# Epoch 57/100
# 180/180 [==============================] - ETA: 0s - loss: 0.3257 - accuracy: 0.8668INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU238.best/assets
# 180/180 [==============================] - 24s 136ms/step - loss: 0.3257 - accuracy: 0.8668
# Epoch 58/100
# 180/180 [==============================] - ETA: 0s - loss: 0.3244 - accuracy: 0.8696INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU238.best/assets
# 180/180 [==============================] - 27s 149ms/step - loss: 0.3244 - accuracy: 0.8696
# Epoch 59/100
# 180/180 [==============================] - 10s 55ms/step - loss: 0.3306 - accuracy: 0.8647
# Epoch 60/100
# 180/180 [==============================] - 10s 56ms/step - loss: 0.3264 - accuracy: 0.8689
# Epoch 61/100
# 180/180 [==============================] - 10s 56ms/step - loss: 0.3225 - accuracy: 0.8671
# Epoch 62/100
# 180/180 [==============================] - 10s 56ms/step - loss: 0.3269 - accuracy: 0.8642
# Epoch 63/100
# 180/180 [==============================] - 10s 56ms/step - loss: 0.3229 - accuracy: 0.8673
# Epoch 64/100
# 180/180 [==============================] - ETA: 0s - loss: 0.3189 - accuracy: 0.8697INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU238.best/assets
# 180/180 [==============================] - 27s 150ms/step - loss: 0.3189 - accuracy: 0.8697
# Epoch 65/100
# 180/180 [==============================] - 10s 57ms/step - loss: 0.3212 - accuracy: 0.8677
# Epoch 66/100
# 180/180 [==============================] - 10s 57ms/step - loss: 0.3235 - accuracy: 0.8609
# Epoch 67/100
# 180/180 [==============================] - ETA: 0s - loss: 0.3134 - accuracy: 0.8724INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU238.best/assets
# 180/180 [==============================] - 26s 144ms/step - loss: 0.3134 - accuracy: 0.8724
# Epoch 68/100
# 180/180 [==============================] - 11s 59ms/step - loss: 0.3212 - accuracy: 0.8689
# Epoch 69/100
# 180/180 [==============================] - 10s 58ms/step - loss: 0.3183 - accuracy: 0.8703
# Epoch 70/100
# 180/180 [==============================] - ETA: 0s - loss: 0.3121 - accuracy: 0.8730INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU238.best/assets
# 180/180 [==============================] - 28s 154ms/step - loss: 0.3121 - accuracy: 0.8730
# Epoch 71/100
# 180/180 [==============================] - 10s 57ms/step - loss: 0.3178 - accuracy: 0.8706
# Epoch 72/100
# 180/180 [==============================] - 10s 58ms/step - loss: 0.3124 - accuracy: 0.8711
# Epoch 73/100
# 180/180 [==============================] - ETA: 0s - loss: 0.3078 - accuracy: 0.8743INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU238.best/assets
# 180/180 [==============================] - 27s 150ms/step - loss: 0.3078 - accuracy: 0.8743
# Epoch 74/100
# 180/180 [==============================] - ETA: 0s - loss: 0.3095 - accuracy: 0.8744INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU238.best/assets
# 180/180 [==============================] - 27s 151ms/step - loss: 0.3095 - accuracy: 0.8744
# Epoch 75/100
# 180/180 [==============================] - 10s 57ms/step - loss: 0.3095 - accuracy: 0.8710
# Epoch 76/100
# 180/180 [==============================] - ETA: 0s - loss: 0.3036 - accuracy: 0.8762INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU238.best/assets
# 180/180 [==============================] - 25s 139ms/step - loss: 0.3036 - accuracy: 0.8762
# Epoch 77/100
# 180/180 [==============================] - 10s 56ms/step - loss: 0.3148 - accuracy: 0.8727
# Epoch 78/100
# 180/180 [==============================] - 10s 56ms/step - loss: 0.3058 - accuracy: 0.8751
# Epoch 79/100
# 180/180 [==============================] - ETA: 0s - loss: 0.2971 - accuracy: 0.8814INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU238.best/assets
# 180/180 [==============================] - 27s 148ms/step - loss: 0.2971 - accuracy: 0.8814
# Epoch 80/100
# 180/180 [==============================] - 10s 54ms/step - loss: 0.3066 - accuracy: 0.8753
# Epoch 81/100
# 180/180 [==============================] - 10s 56ms/step - loss: 0.2945 - accuracy: 0.8777
# Epoch 82/100
# 180/180 [==============================] - ETA: 0s - loss: 0.2957 - accuracy: 0.8816INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU238.best/assets
# 180/180 [==============================] - 26s 145ms/step - loss: 0.2957 - accuracy: 0.8816
# Epoch 83/100
# 180/180 [==============================] - 10s 58ms/step - loss: 0.2916 - accuracy: 0.8774
# Epoch 84/100
# 180/180 [==============================] - ETA: 0s - loss: 0.2900 - accuracy: 0.8819INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU238.best/assets
# 180/180 [==============================] - 25s 141ms/step - loss: 0.2900 - accuracy: 0.8819
# Epoch 85/100
# 180/180 [==============================] - ETA: 0s - loss: 0.2850 - accuracy: 0.8828INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU238.best/assets
# 180/180 [==============================] - 27s 152ms/step - loss: 0.2850 - accuracy: 0.8828
# Epoch 86/100
# 180/180 [==============================] - 10s 57ms/step - loss: 0.2987 - accuracy: 0.8781
# Epoch 87/100
# 180/180 [==============================] - ETA: 0s - loss: 0.2840 - accuracy: 0.8836INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU238.best/assets
# 180/180 [==============================] - 27s 150ms/step - loss: 0.2840 - accuracy: 0.8836
# Epoch 88/100
# 180/180 [==============================] - ETA: 0s - loss: 0.2744 - accuracy: 0.8904INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU238.best/assets
# 180/180 [==============================] - 26s 142ms/step - loss: 0.2744 - accuracy: 0.8904
# Epoch 89/100
# 180/180 [==============================] - 10s 57ms/step - loss: 0.2866 - accuracy: 0.8845
# Epoch 90/100
# 180/180 [==============================] - 10s 56ms/step - loss: 0.2745 - accuracy: 0.8889
# Epoch 91/100
# 180/180 [==============================] - ETA: 0s - loss: 0.2767 - accuracy: 0.8906INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU238.best/assets
# 180/180 [==============================] - 27s 150ms/step - loss: 0.2767 - accuracy: 0.8906
# Epoch 92/100
# 180/180 [==============================] - 10s 58ms/step - loss: 0.2765 - accuracy: 0.8882
# Epoch 93/100
# 180/180 [==============================] - ETA: 0s - loss: 0.2627 - accuracy: 0.8982INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU238.best/assets
# 180/180 [==============================] - 27s 153ms/step - loss: 0.2627 - accuracy: 0.8982
# Epoch 94/100
# 180/180 [==============================] - ETA: 0s - loss: 0.2597 - accuracy: 0.9012INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU238.best/assets
# 180/180 [==============================] - 26s 143ms/step - loss: 0.2597 - accuracy: 0.9012
# Epoch 95/100
# 180/180 [==============================] - 10s 56ms/step - loss: 0.2685 - accuracy: 0.8927
# Epoch 96/100
# 180/180 [==============================] - 10s 58ms/step - loss: 0.3224 - accuracy: 0.8720
# Epoch 97/100
# 180/180 [==============================] - 10s 57ms/step - loss: 0.3140 - accuracy: 0.8720
# Epoch 98/100
# 180/180 [==============================] - 10s 57ms/step - loss: 0.3116 - accuracy: 0.8751
# Epoch 99/100
# 180/180 [==============================] - 10s 57ms/step - loss: 0.3029 - accuracy: 0.8819
# Epoch 100/100
# 180/180 [==============================] - 10s 56ms/step - loss: 0.2963 - accuracy: 0.8796
# Train 100 epochs, 1626 sec

# %%
print ("Evaluate on A")
just_evaluate(X_valid_A,y_valid_A) 
print ("Evaluate on B")
just_evaluate(X_valid_B,y_valid_B)  
print ("Evaluate on C")
just_evaluate(X_valid_C,y_valid_C)  
print ("Evaluate on D")
just_evaluate(X_valid_D,y_valid_D)  
print ("Evaluate on E")
just_evaluate(X_valid_E,y_valid_E)  
print ("Evaluate on F")
just_evaluate(X_valid_F,y_valid_F)  

print ("Done")
# Out:
# Evaluate on A
# accuracy: 48.28%
# Evaluate on B
# accuracy: 60.28%
# Evaluate on C
# accuracy: 79.57%
# Evaluate on D
# accuracy: 84.39%
# Evaluate on E
# accuracy: 91.07%
# Evaluate on F
# accuracy: 92.18%
# Done
