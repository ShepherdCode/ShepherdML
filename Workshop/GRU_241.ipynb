# %% [markdown]
# # GRU 241
# Test the RNA length effect.

# %%
NC_FILENAME='ncRNA.gc34.processed.fasta'
PC_FILENAME='pcRNA.gc34.processed.fasta'
DATAPATH=""
try:
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
    NC_FILENAME = DATAPATH+NC_FILENAME
    PC_FILENAME = DATAPATH+PC_FILENAME
except:
    IN_COLAB = False
    DATAPATH="" 

EPOCHS=100  # use 2 for debug, 200 for real
K=3
VOCABULARY_SIZE=4**K+1   # e.g. K=3 => 64 DNA K-mers + 'NNN'
EMBED_DIMEN=16
FILENAME='GRU241'
NEURONS=16
ACT="tanh"
DROP=0.5
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import StratifiedKFold
import tensorflow as tf
from tensorflow import keras
from keras.wrappers.scikit_learn import KerasRegressor
from keras.models import Sequential
from keras.layers import Bidirectional
from keras.layers import GRU
from keras.layers import Dense
from keras.layers import LayerNormalization
import time
dt='float32'
tf.keras.backend.set_floatx(dt)

# %% [markdown]
# ## Build model

# %%
def compile_model(model):
    adam_default_learn_rate = 0.001
    schedule = tf.keras.optimizers.schedules.ExponentialDecay(
        initial_learning_rate = adam_default_learn_rate*10,
        #decay_steps=100000, decay_rate=0.96, staircase=True)
        decay_steps=10000, decay_rate=0.99, staircase=True)
    # learn rate = initial_learning_rate * decay_rate ^ (step / decay_steps)
    alrd = tf.keras.optimizers.Adam(learning_rate=schedule)
    bc=tf.keras.losses.BinaryCrossentropy(from_logits=False)
    print("COMPILE...")
    #model.compile(loss=bc, optimizer=alrd, metrics=["accuracy"])
    model.compile(loss=bc, optimizer="adam", metrics=["accuracy"])
    print("...COMPILED")
    return model

def build_model():
    embed_layer  = keras.layers.Embedding(
        #VOCABULARY_SIZE, EMBED_DIMEN, input_length=1000, input_length=1000, mask_zero=True)
        #input_dim=[None,VOCABULARY_SIZE], output_dim=EMBED_DIMEN, mask_zero=True)
        input_dim=VOCABULARY_SIZE, output_dim=EMBED_DIMEN, mask_zero=True)
    #rnn1_layer = keras.layers.Bidirectional(
    rnn1_layer = keras.layers.GRU(NEURONS, return_sequences=False,  #   True, 
          input_shape=[1000,EMBED_DIMEN], activation=ACT, dropout=DROP)#)#bi
    #rnn2_layer = keras.layers.Bidirectional(
    rnn2_layer = keras.layers.GRU(NEURONS, return_sequences=False, 
        activation=ACT, dropout=DROP)#)#bi
    dense1_layer = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt)
    drop1_layer = keras.layers.Dropout(DROP)
    #dense2_layer = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt)
    #drop2_layer = keras.layers.Dropout(DROP)
    output_layer = keras.layers.Dense(1, activation="sigmoid", dtype=dt)
    mlp = keras.models.Sequential()
    mlp.add(embed_layer)
    mlp.add(rnn1_layer)
    #mlp.add(rnn2_layer)
    mlp.add(dense1_layer)
    mlp.add(drop1_layer)
    #mlp.add(dense2_layer)
    #mlp.add(drop2_layer)
    mlp.add(output_layer)
    mlpc = compile_model(mlp)
    return mlpc

# %% [markdown]
# ## Load and partition sequences

# %%
# Assume file was preprocessed to contain one line per seq.
# Prefer Pandas dataframe but df does not support append.
# For conversion to tensor, must avoid python lists.
def load_fasta(filename,label):
    DEFLINE='>'
    labels=[]
    seqs=[]
    lens=[]
    nums=[]
    num=0
    with open (filename,'r') as infile:
        for line in infile:
            if line[0]!=DEFLINE:
                seq=line.rstrip()
                num += 1   # first seqnum is 1
                seqlen=len(seq)
                nums.append(num)
                labels.append(label)
                seqs.append(seq)
                lens.append(seqlen)
    df1=pd.DataFrame(nums,columns=['seqnum'])
    df2=pd.DataFrame(labels,columns=['class'])
    df3=pd.DataFrame(seqs,columns=['sequence'])
    df4=pd.DataFrame(lens,columns=['seqlen'])
    df=pd.concat((df1,df2,df3,df4),axis=1)
    return df

def separate_X_and_y(data):
    y=   data[['class']].copy()
    X=   data.drop(columns=['class','seqnum','seqlen'])
    return (X,y)

# %% [markdown]
# ## Make K-mers

# %%
def make_kmer_table(K):
    npad='N'*K
    shorter_kmers=['']
    for i in range(K):
        longer_kmers=[]
        for mer in shorter_kmers:
            longer_kmers.append(mer+'A')
            longer_kmers.append(mer+'C')
            longer_kmers.append(mer+'G')
            longer_kmers.append(mer+'T')
        shorter_kmers = longer_kmers
    all_kmers = shorter_kmers
    kmer_dict = {}
    kmer_dict[npad]=0
    value=1
    for mer in all_kmers:
        kmer_dict[mer]=value
        value += 1
    return kmer_dict

KMER_TABLE=make_kmer_table(K)

def strings_to_vectors(data,uniform_len):
    all_seqs=[]
    for seq in data['sequence']:
        i=0
        seqlen=len(seq)
        kmers=[]
        while i < seqlen-K+1 -1:  # stop at minus one for spaced seed
            #kmer=seq[i:i+2]+seq[i+3:i+5]    # SPACED SEED 2/1/2 for K=4
            kmer=seq[i:i+K]  
            i += 1
            value=KMER_TABLE[kmer]
            kmers.append(value)
        pad_val=0
        while i < uniform_len:
            kmers.append(pad_val)
            i += 1
        all_seqs.append(kmers)
    pd2d=pd.DataFrame(all_seqs)
    return pd2d   # return 2D dataframe, uniform dimensions

# %%
def make_kmers(MAXLEN,train_set):
    (X_train_all,y_train_all)=separate_X_and_y(train_set)
    X_train_kmers=strings_to_vectors(X_train_all,MAXLEN)
    # From pandas dataframe to numpy to list to numpy
    num_seqs=len(X_train_kmers)
    tmp_seqs=[]
    for i in range(num_seqs):
        kmer_sequence=X_train_kmers.iloc[i]
        tmp_seqs.append(kmer_sequence)
    X_train_kmers=np.array(tmp_seqs)
    tmp_seqs=None
    labels=y_train_all.to_numpy()
    return (X_train_kmers,labels)

# %%
def make_frequencies(Xin):
    Xout=[]
    VOCABULARY_SIZE= 4**K + 1  # plus one for 'NNN'
    for seq in Xin:
        freqs =[0] * VOCABULARY_SIZE
        total = 0
        for kmerval in seq:
            freqs[kmerval] += 1
            total += 1
        for c in range(VOCABULARY_SIZE):
            freqs[c] = freqs[c]/total
        Xout.append(freqs)
    Xnum = np.asarray(Xout)
    return (Xnum)
def make_slice(data_set,min_len,max_len):
    slice = data_set.query('seqlen < '+str(max_len)+' & seqlen>= '+str(min_len))
    return slice

# %% [markdown]
# ## Cross validation

# %%
bestname=DATAPATH+FILENAME+".best"
def just_train(X,y): # give me training set
    model=build_model()
    print(model.summary())
    mycallbacks = [keras.callbacks.ModelCheckpoint(
        filepath=bestname, save_best_only=True, 
        monitor='accuracy', mode='max')]   
    print("FIT")
    start_time=time.time()
    history=model.fit(X_train, y_train, # batch_size=10, default=32 works nicely
            epochs=EPOCHS, verbose=1,  # verbose=1 for ascii art, verbose=0 for none
            callbacks=mycallbacks )  # no validation data
    end_time=time.time()
    elapsed_time=(end_time-start_time)                        
    print("Train %d epochs, %d sec"%(EPOCHS,elapsed_time))
    pd.DataFrame(history.history).plot(figsize=(8,5))
    plt.grid(True)
    plt.gca().set_ylim(0,1)
    plt.show()
def just_evaluate(X,y):  # give me validation set
    best_model=keras.models.load_model(bestname)
    scores = best_model.evaluate(X, y, verbose=0)
    print("%s: %.2f%%" % (best_model.metrics_names[1], scores[1]*100))

# %% [markdown]
# ## Train on RNA length-based slice

# %%
#      A    B    C     D     E     F
# 200, 500, 750, 1000, 1500, 3000, 30000 
print("Load data from files.")
nc_seq=load_fasta(NC_FILENAME,0)
pc_seq=load_fasta(PC_FILENAME,1)
together=pd.concat((nc_seq,pc_seq),axis=0)
train_set=together.sample(frac=1)   # shuffle
together=None
nc_seq=None
pc_seq=None
def get_x_and_y(train_set,minlen,maxlen):
  subset=make_slice(train_set,minlen,maxlen)
  (X_set,y_set)=make_kmers(maxlen,subset)
  print("Shape of X is "+str(X_set.shape))
  L=len(X_set)
  T=int(0.80*L+0.5)
  print("Total %d, Train portion %d"%(L,T))
  X_train=X_set[:T]
  y_train=y_set[:T]
  X_valid=X_set[T:]
  y_valid=y_set[T:]
  return (X_train,y_train,X_valid,y_valid)

MINLEN=600
MAXLEN=900
(X_train,y_train,X_valid,y_valid)=get_x_and_y(train_set,MINLEN,MAXLEN)
print("Loaded")
# Out:
# Load data from files.
# Shape of X is (6442, 900)
# Total 6442, Train portion 5154
# Loaded

# %%
print ("Train on ",MINLEN,"-",MAXLEN)
just_train(X_train,y_train)
# Out:
# Train on  600 - 900
# COMPILE...
# ...COMPILED
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, None, 16)          1040
# _________________________________________________________________
# gru_2 (GRU)                  (None, 16)                1632
# _________________________________________________________________
# dense_2 (Dense)              (None, 16)                272
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 2,961
# Trainable params: 2,961
# Non-trainable params: 0
# _________________________________________________________________
# None
# FIT
# Epoch 1/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.6906 - accuracy: 0.5347INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU241.best/assets
# 162/162 [==============================] - 12s 76ms/step - loss: 0.6907 - accuracy: 0.5345
# Epoch 2/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.6705 - accuracy: 0.5920INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU241.best/assets
# 162/162 [==============================] - 12s 74ms/step - loss: 0.6705 - accuracy: 0.5918
# Epoch 3/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.6605 - accuracy: 0.6198INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU241.best/assets
# 162/162 [==============================] - 13s 82ms/step - loss: 0.6604 - accuracy: 0.6199
# Epoch 4/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.6514 - accuracy: 0.6357INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU241.best/assets
# 162/162 [==============================] - 12s 74ms/step - loss: 0.6514 - accuracy: 0.6358
# Epoch 5/100
# 162/162 [==============================] - 5s 29ms/step - loss: 0.6843 - accuracy: 0.5698
# Epoch 6/100
# 162/162 [==============================] - 5s 29ms/step - loss: 0.6746 - accuracy: 0.5726
# Epoch 7/100
# 162/162 [==============================] - 5s 30ms/step - loss: 0.6775 - accuracy: 0.5667
# Epoch 8/100
# 162/162 [==============================] - 5s 29ms/step - loss: 0.6602 - accuracy: 0.6083
# Epoch 9/100
# 162/162 [==============================] - 5s 29ms/step - loss: 0.6472 - accuracy: 0.6294
# Epoch 10/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.6414 - accuracy: 0.6392INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU241.best/assets
# 162/162 [==============================] - 13s 80ms/step - loss: 0.6413 - accuracy: 0.6391
# Epoch 11/100
# 162/162 [==============================] - 5s 29ms/step - loss: 0.6575 - accuracy: 0.6234
# Epoch 12/100
# 162/162 [==============================] - 5s 29ms/step - loss: 0.6484 - accuracy: 0.6197
# Epoch 13/100
# 162/162 [==============================] - 5s 29ms/step - loss: 0.6459 - accuracy: 0.6217
# Epoch 14/100
# 162/162 [==============================] - 5s 29ms/step - loss: 0.6460 - accuracy: 0.6277
# Epoch 15/100
# 162/162 [==============================] - 5s 30ms/step - loss: 0.6395 - accuracy: 0.6329
# Epoch 16/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.6378 - accuracy: 0.6394INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU241.best/assets
# 162/162 [==============================] - 12s 74ms/step - loss: 0.6378 - accuracy: 0.6393
# Epoch 17/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.6273 - accuracy: 0.6572INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU241.best/assets
# 162/162 [==============================] - 12s 73ms/step - loss: 0.6274 - accuracy: 0.6570
# Epoch 18/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.6006 - accuracy: 0.6871INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU241.best/assets
# 162/162 [==============================] - 13s 80ms/step - loss: 0.6006 - accuracy: 0.6870
# Epoch 19/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.5664 - accuracy: 0.7195INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU241.best/assets
# 162/162 [==============================] - 13s 78ms/step - loss: 0.5662 - accuracy: 0.7196
# Epoch 20/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.5236 - accuracy: 0.7541INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU241.best/assets
# 162/162 [==============================] - 12s 73ms/step - loss: 0.5236 - accuracy: 0.7542
# Epoch 21/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.5123 - accuracy: 0.7684INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU241.best/assets
# 162/162 [==============================] - 13s 79ms/step - loss: 0.5122 - accuracy: 0.7685
# Epoch 22/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.4944 - accuracy: 0.7737INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU241.best/assets
# 162/162 [==============================] - 12s 74ms/step - loss: 0.4945 - accuracy: 0.7736
# Epoch 23/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.4852 - accuracy: 0.7828INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU241.best/assets
# 162/162 [==============================] - 13s 81ms/step - loss: 0.4851 - accuracy: 0.7829
# Epoch 24/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.4774 - accuracy: 0.7882INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU241.best/assets
# 162/162 [==============================] - 12s 74ms/step - loss: 0.4775 - accuracy: 0.7881
# Epoch 25/100
# 162/162 [==============================] - 5s 30ms/step - loss: 0.4783 - accuracy: 0.7815
# Epoch 26/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.4643 - accuracy: 0.7906INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU241.best/assets
# 162/162 [==============================] - 12s 76ms/step - loss: 0.4644 - accuracy: 0.7905
# Epoch 27/100
# 162/162 [==============================] - 5s 30ms/step - loss: 0.4640 - accuracy: 0.7879
# Epoch 28/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.4536 - accuracy: 0.7948INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU241.best/assets
# 162/162 [==============================] - 14s 84ms/step - loss: 0.4538 - accuracy: 0.7947
# Epoch 29/100
# 162/162 [==============================] - 5s 30ms/step - loss: 0.4628 - accuracy: 0.7829
# Epoch 30/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.4502 - accuracy: 0.7974INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU241.best/assets
# 162/162 [==============================] - 13s 81ms/step - loss: 0.4501 - accuracy: 0.7974
# Epoch 31/100
# 162/162 [==============================] - 5s 30ms/step - loss: 0.4549 - accuracy: 0.7955
# Epoch 32/100
# 162/162 [==============================] - 5s 31ms/step - loss: 0.4482 - accuracy: 0.7955
# Epoch 33/100
# 162/162 [==============================] - 5s 31ms/step - loss: 0.4524 - accuracy: 0.7971
# Epoch 34/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.4402 - accuracy: 0.7995INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU241.best/assets
# 162/162 [==============================] - 12s 76ms/step - loss: 0.4402 - accuracy: 0.7994
# Epoch 35/100
# 162/162 [==============================] - 5s 31ms/step - loss: 0.4409 - accuracy: 0.7943
# Epoch 36/100
# 162/162 [==============================] - 5s 31ms/step - loss: 0.4423 - accuracy: 0.7961
# Epoch 37/100
# 162/162 [==============================] - ETA: 0s - loss: 0.4427 - accuracy: 0.8060INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU241.best/assets
# 162/162 [==============================] - 13s 83ms/step - loss: 0.4427 - accuracy: 0.8060
# Epoch 38/100
# 162/162 [==============================] - 5s 30ms/step - loss: 0.4429 - accuracy: 0.7945
# Epoch 39/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.4338 - accuracy: 0.8061INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU241.best/assets
# 162/162 [==============================] - 12s 77ms/step - loss: 0.4337 - accuracy: 0.8062
# Epoch 40/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.4340 - accuracy: 0.8071INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU241.best/assets
# 162/162 [==============================] - 13s 77ms/step - loss: 0.4340 - accuracy: 0.8071
# Epoch 41/100
# 162/162 [==============================] - 5s 31ms/step - loss: 0.4407 - accuracy: 0.7976
# Epoch 42/100
# 162/162 [==============================] - 5s 31ms/step - loss: 0.4324 - accuracy: 0.8035
# Epoch 43/100
# 162/162 [==============================] - 5s 31ms/step - loss: 0.4354 - accuracy: 0.8052
# Epoch 44/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.4294 - accuracy: 0.8094INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU241.best/assets
# 162/162 [==============================] - 14s 84ms/step - loss: 0.4293 - accuracy: 0.8095
# Epoch 45/100
# 162/162 [==============================] - 5s 31ms/step - loss: 0.4320 - accuracy: 0.8035
# Epoch 46/100
# 162/162 [==============================] - 5s 31ms/step - loss: 0.4343 - accuracy: 0.8029
# Epoch 47/100
# 162/162 [==============================] - 5s 31ms/step - loss: 0.4357 - accuracy: 0.8054
# Epoch 48/100
# 162/162 [==============================] - 5s 31ms/step - loss: 0.4296 - accuracy: 0.8038
# Epoch 49/100
# 162/162 [==============================] - 5s 31ms/step - loss: 0.4357 - accuracy: 0.7986
# Epoch 50/100
# 162/162 [==============================] - 5s 31ms/step - loss: 0.4273 - accuracy: 0.8054
# Epoch 51/100
# 162/162 [==============================] - 5s 32ms/step - loss: 0.4212 - accuracy: 0.8029
# Epoch 52/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.4225 - accuracy: 0.8108INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU241.best/assets
# 162/162 [==============================] - 13s 82ms/step - loss: 0.4227 - accuracy: 0.8106
# Epoch 53/100
# 162/162 [==============================] - 5s 31ms/step - loss: 0.4177 - accuracy: 0.8104
# Epoch 54/100
# 162/162 [==============================] - 5s 30ms/step - loss: 0.4243 - accuracy: 0.8052
# Epoch 55/100
# 162/162 [==============================] - 5s 30ms/step - loss: 0.4239 - accuracy: 0.8064
# Epoch 56/100
# 162/162 [==============================] - 5s 30ms/step - loss: 0.4255 - accuracy: 0.8069
# Epoch 57/100
# 162/162 [==============================] - 5s 31ms/step - loss: 0.4228 - accuracy: 0.8091
# Epoch 58/100
# 162/162 [==============================] - 5s 30ms/step - loss: 0.4228 - accuracy: 0.8064
# Epoch 59/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.4210 - accuracy: 0.8150INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU241.best/assets
# 162/162 [==============================] - 12s 75ms/step - loss: 0.4209 - accuracy: 0.8151
# Epoch 60/100
# 162/162 [==============================] - 5s 30ms/step - loss: 0.4185 - accuracy: 0.8089
# Epoch 61/100
# 162/162 [==============================] - 5s 30ms/step - loss: 0.4235 - accuracy: 0.8089
# Epoch 62/100
# 162/162 [==============================] - 5s 30ms/step - loss: 0.4190 - accuracy: 0.8120
# Epoch 63/100
# 162/162 [==============================] - 5s 30ms/step - loss: 0.4188 - accuracy: 0.8101
# Epoch 64/100
# 162/162 [==============================] - 5s 30ms/step - loss: 0.4157 - accuracy: 0.8095
# Epoch 65/100
# 162/162 [==============================] - 5s 30ms/step - loss: 0.4210 - accuracy: 0.8095
# Epoch 66/100
# 162/162 [==============================] - 5s 31ms/step - loss: 0.4177 - accuracy: 0.8112
# Epoch 67/100
# 162/162 [==============================] - 5s 32ms/step - loss: 0.4172 - accuracy: 0.8087
# Epoch 68/100
# 162/162 [==============================] - 5s 31ms/step - loss: 0.4184 - accuracy: 0.8120
# Epoch 69/100
# 162/162 [==============================] - 5s 30ms/step - loss: 0.4172 - accuracy: 0.8118
# Epoch 70/100
# 162/162 [==============================] - 5s 30ms/step - loss: 0.4103 - accuracy: 0.8077
# Epoch 71/100
# 162/162 [==============================] - 5s 30ms/step - loss: 0.4133 - accuracy: 0.8133
# Epoch 72/100
# 162/162 [==============================] - 5s 30ms/step - loss: 0.4108 - accuracy: 0.8087
# Epoch 73/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.4149 - accuracy: 0.8154INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU241.best/assets
# 162/162 [==============================] - 13s 80ms/step - loss: 0.4147 - accuracy: 0.8155
# Epoch 74/100
# 162/162 [==============================] - 5s 30ms/step - loss: 0.4123 - accuracy: 0.8137
# Epoch 75/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.4135 - accuracy: 0.8160INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU241.best/assets
# 162/162 [==============================] - 12s 74ms/step - loss: 0.4134 - accuracy: 0.8161
# Epoch 76/100
# 162/162 [==============================] - 5s 30ms/step - loss: 0.4171 - accuracy: 0.8038
# Epoch 77/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.4103 - accuracy: 0.8201INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU241.best/assets
# 162/162 [==============================] - 13s 80ms/step - loss: 0.4104 - accuracy: 0.8199
# Epoch 78/100
# 162/162 [==============================] - 5s 30ms/step - loss: 0.4149 - accuracy: 0.8114
# Epoch 79/100
# 162/162 [==============================] - 5s 31ms/step - loss: 0.4119 - accuracy: 0.8182
# Epoch 80/100
# 162/162 [==============================] - 5s 31ms/step - loss: 0.4101 - accuracy: 0.8178
# Epoch 81/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.3945 - accuracy: 0.8238INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU241.best/assets
# 162/162 [==============================] - 12s 74ms/step - loss: 0.3946 - accuracy: 0.8236
# Epoch 82/100
# 162/162 [==============================] - 5s 30ms/step - loss: 0.4125 - accuracy: 0.8155
# Epoch 83/100
# 162/162 [==============================] - 5s 30ms/step - loss: 0.4175 - accuracy: 0.8135
# Epoch 84/100
# 162/162 [==============================] - 5s 30ms/step - loss: 0.4088 - accuracy: 0.8155
# Epoch 85/100
# 162/162 [==============================] - 5s 30ms/step - loss: 0.4098 - accuracy: 0.8120
# Epoch 86/100
# 162/162 [==============================] - 5s 30ms/step - loss: 0.4005 - accuracy: 0.8190
# Epoch 87/100
# 162/162 [==============================] - 5s 29ms/step - loss: 0.4112 - accuracy: 0.8172
# Epoch 88/100
# 162/162 [==============================] - 5s 30ms/step - loss: 0.4057 - accuracy: 0.8172
# Epoch 89/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.4000 - accuracy: 0.8243INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU241.best/assets
# 162/162 [==============================] - 12s 75ms/step - loss: 0.4002 - accuracy: 0.8242
# Epoch 90/100
# 162/162 [==============================] - 5s 30ms/step - loss: 0.4102 - accuracy: 0.8172
# Epoch 91/100
# 162/162 [==============================] - 5s 30ms/step - loss: 0.4027 - accuracy: 0.8166
# Epoch 92/100
# 162/162 [==============================] - 5s 30ms/step - loss: 0.4043 - accuracy: 0.8217
# Epoch 93/100
# 162/162 [==============================] - 5s 30ms/step - loss: 0.4045 - accuracy: 0.8190
# Epoch 94/100
# 162/162 [==============================] - 5s 30ms/step - loss: 0.4026 - accuracy: 0.8234
# Epoch 95/100
# 162/162 [==============================] - 5s 29ms/step - loss: 0.4033 - accuracy: 0.8223
# Epoch 96/100
# 161/162 [============================>.] - ETA: 0s - loss: 0.3950 - accuracy: 0.8265INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU241.best/assets
# 162/162 [==============================] - 13s 82ms/step - loss: 0.3949 - accuracy: 0.8265
# Epoch 97/100
# 162/162 [==============================] - 5s 30ms/step - loss: 0.4025 - accuracy: 0.8217
# Epoch 98/100
# 162/162 [==============================] - 5s 30ms/step - loss: 0.4111 - accuracy: 0.8161
# Epoch 99/100
# 162/162 [==============================] - 5s 30ms/step - loss: 0.4014 - accuracy: 0.8215
# Epoch 100/100
# 162/162 [==============================] - 5s 30ms/step - loss: 0.4068 - accuracy: 0.8186
# Train 100 epochs, 726 sec

# %%
print ("Evaluate on A")
(X_train,y_train,X_valid_A,y_valid_A)=get_x_and_y(train_set,200,600)
just_evaluate(X_valid_A,y_valid_A) 
(X_valid_A,y_valid_A)=(None,None)
print ("Evaluate on B")
(X_train,y_train,X_valid_B,y_valid_B)=get_x_and_y(train_set,600,900)
just_evaluate(X_valid_B,y_valid_B)  
(X_valid_B,y_valid_B)=(None,None)
print ("Evaluate on C")
(X_train,y_train,X_valid_C,y_valid_C)=get_x_and_y(train_set,900,1300)
just_evaluate(X_valid_C,y_valid_C)  
(X_valid_C,y_valid_C)=(None,None)
print ("Evaluate on D")
(X_train,y_train,X_valid_D,y_valid_D)=get_x_and_y(train_set,1300,1900)
just_evaluate(X_valid_D,y_valid_D)  
(X_valid_D,y_valid_D)=(None,None)
print ("Evaluate on E")
(X_train,y_train,X_valid_E,y_valid_E)=get_x_and_y(train_set,1900,3000)
just_evaluate(X_valid_E,y_valid_E)  
(X_valid_E,y_valid_E)=(None,None)
print ("Evaluate on F")
(X_train,y_train,X_valid_F,y_valid_F)=get_x_and_y(train_set,3000,30000)
just_evaluate(X_valid_F,y_valid_F) 
(X_valid_F,y_valid_F)=(None,None) 

print ("Done")
# Out:
# Evaluate on A
# Shape of X is (8165, 600)
# Total 8165, Train portion 6532
# accuracy: 83.10%
# Evaluate on B
# Shape of X is (6442, 900)
# Total 6442, Train portion 5154
# accuracy: 81.44%
# Evaluate on C
# Shape of X is (4478, 1300)
# Total 4478, Train portion 3582
# accuracy: 81.03%
# Evaluate on D
# Shape of X is (4421, 1900)
# Total 4421, Train portion 3537
# accuracy: 81.11%
# Evaluate on E
# Shape of X is (4590, 3000)
# Total 4590, Train portion 3672
# accuracy: 84.53%
# Evaluate on F
# Shape of X is (3900, 30000)
# Total 3900, Train portion 3120
# accuracy: 85.26%
# Done
