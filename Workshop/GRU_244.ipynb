# %% [markdown]
# # GRU 244
# Test the RNA length effect.

# %%
NC_FILENAME='ncRNA.gc34.processed.fasta'
PC_FILENAME='pcRNA.gc34.processed.fasta'
DATAPATH=""
try:
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
    NC_FILENAME = DATAPATH+NC_FILENAME
    PC_FILENAME = DATAPATH+PC_FILENAME
except:
    IN_COLAB = False
    DATAPATH="" 

EPOCHS=100  # use 2 for debug, 200 for real
K=3
VOCABULARY_SIZE=4**K+1   # e.g. K=3 => 64 DNA K-mers + 'NNN'
EMBED_DIMEN=16
FILENAME='GRU244'
NEURONS=16
ACT="tanh"
DROP=0.5
# Out:
# Mounted at /content/drive/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import StratifiedKFold
import tensorflow as tf
from tensorflow import keras
from keras.wrappers.scikit_learn import KerasRegressor
from keras.models import Sequential
from keras.layers import Bidirectional
from keras.layers import GRU
from keras.layers import Dense
from keras.layers import LayerNormalization
import time
dt='float32'
tf.keras.backend.set_floatx(dt)

# %% [markdown]
# ## Build model

# %%
def compile_model(model):
    adam_default_learn_rate = 0.001
    schedule = tf.keras.optimizers.schedules.ExponentialDecay(
        initial_learning_rate = adam_default_learn_rate*10,
        #decay_steps=100000, decay_rate=0.96, staircase=True)
        decay_steps=10000, decay_rate=0.99, staircase=True)
    # learn rate = initial_learning_rate * decay_rate ^ (step / decay_steps)
    alrd = tf.keras.optimizers.Adam(learning_rate=schedule)
    bc=tf.keras.losses.BinaryCrossentropy(from_logits=False)
    print("COMPILE...")
    #model.compile(loss=bc, optimizer=alrd, metrics=["accuracy"])
    model.compile(loss=bc, optimizer="adam", metrics=["accuracy"])
    print("...COMPILED")
    return model

def build_model():
    embed_layer  = keras.layers.Embedding(
        #VOCABULARY_SIZE, EMBED_DIMEN, input_length=1000, input_length=1000, mask_zero=True)
        #input_dim=[None,VOCABULARY_SIZE], output_dim=EMBED_DIMEN, mask_zero=True)
        input_dim=VOCABULARY_SIZE, output_dim=EMBED_DIMEN, mask_zero=True)
    #rnn1_layer = keras.layers.Bidirectional(
    rnn1_layer = keras.layers.GRU(NEURONS, return_sequences=False,  #   True, 
          input_shape=[1000,EMBED_DIMEN], activation=ACT, dropout=DROP)#)#bi
    #rnn2_layer = keras.layers.Bidirectional(
    rnn2_layer = keras.layers.GRU(NEURONS, return_sequences=False, 
        activation=ACT, dropout=DROP)#)#bi
    dense1_layer = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt)
    drop1_layer = keras.layers.Dropout(DROP)
    #dense2_layer = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt)
    #drop2_layer = keras.layers.Dropout(DROP)
    output_layer = keras.layers.Dense(1, activation="sigmoid", dtype=dt)
    mlp = keras.models.Sequential()
    mlp.add(embed_layer)
    mlp.add(rnn1_layer)
    #mlp.add(rnn2_layer)
    mlp.add(dense1_layer)
    mlp.add(drop1_layer)
    #mlp.add(dense2_layer)
    #mlp.add(drop2_layer)
    mlp.add(output_layer)
    mlpc = compile_model(mlp)
    return mlpc

# %% [markdown]
# ## Load and partition sequences

# %%
# Assume file was preprocessed to contain one line per seq.
# Prefer Pandas dataframe but df does not support append.
# For conversion to tensor, must avoid python lists.
def load_fasta(filename,label):
    DEFLINE='>'
    labels=[]
    seqs=[]
    lens=[]
    nums=[]
    num=0
    with open (filename,'r') as infile:
        for line in infile:
            if line[0]!=DEFLINE:
                seq=line.rstrip()
                num += 1   # first seqnum is 1
                seqlen=len(seq)
                nums.append(num)
                labels.append(label)
                seqs.append(seq)
                lens.append(seqlen)
    df1=pd.DataFrame(nums,columns=['seqnum'])
    df2=pd.DataFrame(labels,columns=['class'])
    df3=pd.DataFrame(seqs,columns=['sequence'])
    df4=pd.DataFrame(lens,columns=['seqlen'])
    df=pd.concat((df1,df2,df3,df4),axis=1)
    return df

def separate_X_and_y(data):
    y=   data[['class']].copy()
    X=   data.drop(columns=['class','seqnum','seqlen'])
    return (X,y)

# %% [markdown]
# ## Make K-mers

# %%
def make_kmer_table(K):
    npad='N'*K
    shorter_kmers=['']
    for i in range(K):
        longer_kmers=[]
        for mer in shorter_kmers:
            longer_kmers.append(mer+'A')
            longer_kmers.append(mer+'C')
            longer_kmers.append(mer+'G')
            longer_kmers.append(mer+'T')
        shorter_kmers = longer_kmers
    all_kmers = shorter_kmers
    kmer_dict = {}
    kmer_dict[npad]=0
    value=1
    for mer in all_kmers:
        kmer_dict[mer]=value
        value += 1
    return kmer_dict

KMER_TABLE=make_kmer_table(K)

def strings_to_vectors(data,uniform_len):
    all_seqs=[]
    for seq in data['sequence']:
        i=0
        seqlen=len(seq)
        kmers=[]
        while i < seqlen-K+1 -1:  # stop at minus one for spaced seed
            #kmer=seq[i:i+2]+seq[i+3:i+5]    # SPACED SEED 2/1/2 for K=4
            kmer=seq[i:i+K]  
            i += 1
            value=KMER_TABLE[kmer]
            kmers.append(value)
        pad_val=0
        while i < uniform_len:
            kmers.append(pad_val)
            i += 1
        all_seqs.append(kmers)
    pd2d=pd.DataFrame(all_seqs)
    return pd2d   # return 2D dataframe, uniform dimensions

# %%
def make_kmers(MAXLEN,train_set):
    (X_train_all,y_train_all)=separate_X_and_y(train_set)
    X_train_kmers=strings_to_vectors(X_train_all,MAXLEN)
    # From pandas dataframe to numpy to list to numpy
    num_seqs=len(X_train_kmers)
    tmp_seqs=[]
    for i in range(num_seqs):
        kmer_sequence=X_train_kmers.iloc[i]
        tmp_seqs.append(kmer_sequence)
    X_train_kmers=np.array(tmp_seqs)
    tmp_seqs=None
    labels=y_train_all.to_numpy()
    return (X_train_kmers,labels)

# %%
def make_frequencies(Xin):
    Xout=[]
    VOCABULARY_SIZE= 4**K + 1  # plus one for 'NNN'
    for seq in Xin:
        freqs =[0] * VOCABULARY_SIZE
        total = 0
        for kmerval in seq:
            freqs[kmerval] += 1
            total += 1
        for c in range(VOCABULARY_SIZE):
            freqs[c] = freqs[c]/total
        Xout.append(freqs)
    Xnum = np.asarray(Xout)
    return (Xnum)
def make_slice(data_set,min_len,max_len):
    slice = data_set.query('seqlen < '+str(max_len)+' & seqlen>= '+str(min_len))
    return slice

# %% [markdown]
# ## Cross validation

# %%
bestname=DATAPATH+FILENAME+".best"
def just_train(X,y): # give me training set
    model=build_model()
    print(model.summary())
    mycallbacks = [keras.callbacks.ModelCheckpoint(
        filepath=bestname, save_best_only=True, 
        monitor='accuracy', mode='max')]   
    print("FIT")
    start_time=time.time()
    history=model.fit(X_train, y_train, # batch_size=10, default=32 works nicely
            epochs=EPOCHS, verbose=1,  # verbose=1 for ascii art, verbose=0 for none
            callbacks=mycallbacks )  # no validation data
    end_time=time.time()
    elapsed_time=(end_time-start_time)                        
    print("Train %d epochs, %d sec"%(EPOCHS,elapsed_time))
    pd.DataFrame(history.history).plot(figsize=(8,5))
    plt.grid(True)
    plt.gca().set_ylim(0,1)
    plt.show()
def just_evaluate(X,y):  # give me validation set
    best_model=keras.models.load_model(bestname)
    scores = best_model.evaluate(X, y, verbose=0)
    print("%s: %.2f%%" % (best_model.metrics_names[1], scores[1]*100))

# %% [markdown]
# ## Train on RNA length-based slice

# %%
#      A    B    C     D     E     F
# 200, 500, 750, 1000, 1500, 3000, 30000 
print("Load data from files.")
nc_seq=load_fasta(NC_FILENAME,0)
pc_seq=load_fasta(PC_FILENAME,1)
together=pd.concat((nc_seq,pc_seq),axis=0)
train_set=together.sample(frac=1)   # shuffle
together=None
nc_seq=None
pc_seq=None
def get_x_and_y(train_set,minlen,maxlen):
  subset=make_slice(train_set,minlen,maxlen)
  (X_set,y_set)=make_kmers(maxlen,subset)
  print("Shape of X is "+str(X_set.shape))
  L=len(X_set)
  T=int(0.80*L+0.5)
  print("Total %d, Train portion %d"%(L,T))
  X_train=X_set[:T]
  y_train=y_set[:T]
  X_valid=X_set[T:]
  y_valid=y_set[T:]
  return (X_train,y_train,X_valid,y_valid)

MINLEN=1900
MAXLEN=3000
(X_train,y_train,X_valid,y_valid)=get_x_and_y(train_set,MINLEN,MAXLEN)
print("Loaded")
# Out:
# Load data from files.
# Shape of X is (4590, 3000)
# Total 4590, Train portion 3672
# Loaded

# %%
print ("Train on ",MINLEN,"-",MAXLEN)
just_train(X_train,y_train)
# Out:
# Train on  1900 - 3000
# COMPILE...
# ...COMPILED
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, None, 16)          1040
# _________________________________________________________________
# gru (GRU)                    (None, 16)                1632
# _________________________________________________________________
# dense (Dense)                (None, 16)                272
# _________________________________________________________________
# dropout (Dropout)            (None, 16)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 2,961
# Trainable params: 2,961
# Non-trainable params: 0
# _________________________________________________________________
# None
# FIT
# Epoch 1/100
# 115/115 [==============================] - ETA: 0s - loss: 0.6648 - accuracy: 0.6370WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU244.best/assets
# 115/115 [==============================] - 20s 171ms/step - loss: 0.6648 - accuracy: 0.6370
# Epoch 2/100
# 115/115 [==============================] - ETA: 0s - loss: 0.6538 - accuracy: 0.6403INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU244.best/assets
# 115/115 [==============================] - 19s 166ms/step - loss: 0.6538 - accuracy: 0.6403
# Epoch 3/100
# 115/115 [==============================] - ETA: 0s - loss: 0.6516 - accuracy: 0.6405INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU244.best/assets
# 115/115 [==============================] - 19s 166ms/step - loss: 0.6516 - accuracy: 0.6405
# Epoch 4/100
# 115/115 [==============================] - ETA: 0s - loss: 0.6476 - accuracy: 0.6422INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU244.best/assets
# 115/115 [==============================] - 19s 168ms/step - loss: 0.6476 - accuracy: 0.6422
# Epoch 5/100
# 115/115 [==============================] - 11s 94ms/step - loss: 0.6485 - accuracy: 0.6397
# Epoch 6/100
# 115/115 [==============================] - ETA: 0s - loss: 0.6468 - accuracy: 0.6427INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU244.best/assets
# 115/115 [==============================] - 19s 166ms/step - loss: 0.6468 - accuracy: 0.6427
# Epoch 7/100
# 115/115 [==============================] - 11s 94ms/step - loss: 0.6452 - accuracy: 0.6381
# Epoch 8/100
# 115/115 [==============================] - 11s 94ms/step - loss: 0.6454 - accuracy: 0.6424
# Epoch 9/100
# 115/115 [==============================] - ETA: 0s - loss: 0.6401 - accuracy: 0.6473INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU244.best/assets
# 115/115 [==============================] - 19s 168ms/step - loss: 0.6401 - accuracy: 0.6473
# Epoch 10/100
# 115/115 [==============================] - 11s 94ms/step - loss: 0.6415 - accuracy: 0.6422
# Epoch 11/100
# 115/115 [==============================] - 11s 94ms/step - loss: 0.6430 - accuracy: 0.6454
# Epoch 12/100
# 115/115 [==============================] - 11s 95ms/step - loss: 0.6401 - accuracy: 0.6473
# Epoch 13/100
# 115/115 [==============================] - ETA: 0s - loss: 0.6404 - accuracy: 0.6484INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU244.best/assets
# 115/115 [==============================] - 19s 169ms/step - loss: 0.6404 - accuracy: 0.6484
# Epoch 14/100
# 115/115 [==============================] - 11s 96ms/step - loss: 0.6362 - accuracy: 0.6484
# Epoch 15/100
# 115/115 [==============================] - 11s 96ms/step - loss: 0.6392 - accuracy: 0.6473
# Epoch 16/100
# 115/115 [==============================] - 11s 95ms/step - loss: 0.6356 - accuracy: 0.6484
# Epoch 17/100
# 115/115 [==============================] - 11s 98ms/step - loss: 0.6381 - accuracy: 0.6462
# Epoch 18/100
# 115/115 [==============================] - 11s 96ms/step - loss: 0.6366 - accuracy: 0.6443
# Epoch 19/100
# 115/115 [==============================] - ETA: 0s - loss: 0.6341 - accuracy: 0.6563INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU244.best/assets
# 115/115 [==============================] - 20s 170ms/step - loss: 0.6341 - accuracy: 0.6563
# Epoch 20/100
# 115/115 [==============================] - 11s 96ms/step - loss: 0.6371 - accuracy: 0.6460
# Epoch 21/100
# 115/115 [==============================] - 11s 96ms/step - loss: 0.6350 - accuracy: 0.6495
# Epoch 22/100
# 115/115 [==============================] - 11s 96ms/step - loss: 0.6325 - accuracy: 0.6525
# Epoch 23/100
# 115/115 [==============================] - ETA: 0s - loss: 0.6308 - accuracy: 0.6582INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU244.best/assets
# 115/115 [==============================] - 19s 169ms/step - loss: 0.6308 - accuracy: 0.6582
# Epoch 24/100
# 115/115 [==============================] - 11s 96ms/step - loss: 0.6354 - accuracy: 0.6487
# Epoch 25/100
# 115/115 [==============================] - 11s 96ms/step - loss: 0.6324 - accuracy: 0.6506
# Epoch 26/100
# 115/115 [==============================] - 11s 96ms/step - loss: 0.6322 - accuracy: 0.6501
# Epoch 27/100
# 115/115 [==============================] - 11s 97ms/step - loss: 0.6300 - accuracy: 0.6536
# Epoch 28/100
# 115/115 [==============================] - 11s 96ms/step - loss: 0.6300 - accuracy: 0.6481
# Epoch 29/100
# 115/115 [==============================] - 11s 97ms/step - loss: 0.6274 - accuracy: 0.6539
# Epoch 30/100
# 115/115 [==============================] - 11s 97ms/step - loss: 0.6280 - accuracy: 0.6511
# Epoch 31/100
# 115/115 [==============================] - 11s 96ms/step - loss: 0.6279 - accuracy: 0.6514
# Epoch 32/100
# 115/115 [==============================] - 11s 97ms/step - loss: 0.6282 - accuracy: 0.6509
# Epoch 33/100
# 115/115 [==============================] - 11s 98ms/step - loss: 0.6290 - accuracy: 0.6509
# Epoch 34/100
# 115/115 [==============================] - 11s 97ms/step - loss: 0.6229 - accuracy: 0.6577
# Epoch 35/100
# 115/115 [==============================] - 11s 97ms/step - loss: 0.6252 - accuracy: 0.6580
# Epoch 36/100
# 115/115 [==============================] - 11s 97ms/step - loss: 0.6249 - accuracy: 0.6506
# Epoch 37/100
# 115/115 [==============================] - 11s 97ms/step - loss: 0.6286 - accuracy: 0.6541
# Epoch 38/100
# 115/115 [==============================] - 11s 97ms/step - loss: 0.6278 - accuracy: 0.6460
# Epoch 39/100
# 115/115 [==============================] - 11s 97ms/step - loss: 0.6282 - accuracy: 0.6522
# Epoch 40/100
# 115/115 [==============================] - 11s 97ms/step - loss: 0.6288 - accuracy: 0.6520
# Epoch 41/100
# 115/115 [==============================] - 11s 97ms/step - loss: 0.6266 - accuracy: 0.6533
# Epoch 42/100
# 115/115 [==============================] - 11s 98ms/step - loss: 0.6249 - accuracy: 0.6566
# Epoch 43/100
# 115/115 [==============================] - 11s 98ms/step - loss: 0.6230 - accuracy: 0.6514
# Epoch 44/100
# 115/115 [==============================] - 11s 97ms/step - loss: 0.6213 - accuracy: 0.6539
# Epoch 45/100
# 115/115 [==============================] - 11s 97ms/step - loss: 0.6244 - accuracy: 0.6550
# Epoch 46/100
# 115/115 [==============================] - 11s 97ms/step - loss: 0.6253 - accuracy: 0.6506
# Epoch 47/100
# 115/115 [==============================] - ETA: 0s - loss: 0.6229 - accuracy: 0.6623INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU244.best/assets
# 115/115 [==============================] - 20s 171ms/step - loss: 0.6229 - accuracy: 0.6623
# Epoch 48/100
# 115/115 [==============================] - 11s 97ms/step - loss: 0.6224 - accuracy: 0.6585
# Epoch 49/100
# 115/115 [==============================] - 11s 99ms/step - loss: 0.6252 - accuracy: 0.6566
# Epoch 50/100
# 115/115 [==============================] - 12s 100ms/step - loss: 0.6214 - accuracy: 0.6607
# Epoch 51/100
# 115/115 [==============================] - 11s 100ms/step - loss: 0.6243 - accuracy: 0.6536
# Epoch 52/100
# 115/115 [==============================] - 12s 100ms/step - loss: 0.6205 - accuracy: 0.6618
# Epoch 53/100
# 115/115 [==============================] - 11s 99ms/step - loss: 0.6205 - accuracy: 0.6588
# Epoch 54/100
# 115/115 [==============================] - 11s 99ms/step - loss: 0.6163 - accuracy: 0.6599
# Epoch 55/100
# 115/115 [==============================] - 11s 98ms/step - loss: 0.6224 - accuracy: 0.6509
# Epoch 56/100
# 115/115 [==============================] - 11s 99ms/step - loss: 0.6201 - accuracy: 0.6601
# Epoch 57/100
# 115/115 [==============================] - 11s 98ms/step - loss: 0.6199 - accuracy: 0.6580
# Epoch 58/100
# 115/115 [==============================] - 11s 98ms/step - loss: 0.6220 - accuracy: 0.6582
# Epoch 59/100
# 115/115 [==============================] - 11s 99ms/step - loss: 0.6135 - accuracy: 0.6590
# Epoch 60/100
# 115/115 [==============================] - 11s 98ms/step - loss: 0.6186 - accuracy: 0.6487
# Epoch 61/100
# 115/115 [==============================] - 11s 98ms/step - loss: 0.6140 - accuracy: 0.6555
# Epoch 62/100
# 115/115 [==============================] - 11s 99ms/step - loss: 0.6154 - accuracy: 0.6596
# Epoch 63/100
# 115/115 [==============================] - 11s 99ms/step - loss: 0.6194 - accuracy: 0.6609
# Epoch 64/100
# 115/115 [==============================] - 11s 98ms/step - loss: 0.6164 - accuracy: 0.6528
# Epoch 65/100
# 115/115 [==============================] - 12s 100ms/step - loss: 0.6184 - accuracy: 0.6552
# Epoch 66/100
# 115/115 [==============================] - 12s 100ms/step - loss: 0.6183 - accuracy: 0.6588
# Epoch 67/100
# 115/115 [==============================] - 11s 99ms/step - loss: 0.6143 - accuracy: 0.6618
# Epoch 68/100
# 115/115 [==============================] - 11s 100ms/step - loss: 0.6169 - accuracy: 0.6509
# Epoch 69/100
# 115/115 [==============================] - 12s 101ms/step - loss: 0.6176 - accuracy: 0.6599
# Epoch 70/100
# 115/115 [==============================] - 12s 101ms/step - loss: 0.6185 - accuracy: 0.6550
# Epoch 71/100
# 115/115 [==============================] - 11s 100ms/step - loss: 0.6143 - accuracy: 0.6623
# Epoch 72/100
# 115/115 [==============================] - ETA: 0s - loss: 0.6145 - accuracy: 0.6691INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU244.best/assets
# 115/115 [==============================] - 20s 174ms/step - loss: 0.6145 - accuracy: 0.6691
# Epoch 73/100
# 115/115 [==============================] - 11s 100ms/step - loss: 0.6159 - accuracy: 0.6637
# Epoch 74/100
# 115/115 [==============================] - 11s 99ms/step - loss: 0.6148 - accuracy: 0.6601
# Epoch 75/100
# 115/115 [==============================] - 11s 99ms/step - loss: 0.6145 - accuracy: 0.6560
# Epoch 76/100
# 115/115 [==============================] - 11s 100ms/step - loss: 0.6126 - accuracy: 0.6511
# Epoch 77/100
# 115/115 [==============================] - 11s 99ms/step - loss: 0.6123 - accuracy: 0.6569
# Epoch 78/100
# 115/115 [==============================] - 11s 100ms/step - loss: 0.6144 - accuracy: 0.6656
# Epoch 79/100
# 115/115 [==============================] - 11s 99ms/step - loss: 0.6102 - accuracy: 0.6650
# Epoch 80/100
# 115/115 [==============================] - 11s 99ms/step - loss: 0.6097 - accuracy: 0.6637
# Epoch 81/100
# 115/115 [==============================] - 11s 99ms/step - loss: 0.6137 - accuracy: 0.6629
# Epoch 82/100
# 115/115 [==============================] - 11s 100ms/step - loss: 0.6112 - accuracy: 0.6688
# Epoch 83/100
# 115/115 [==============================] - ETA: 0s - loss: 0.6051 - accuracy: 0.6721INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU244.best/assets
# 115/115 [==============================] - 20s 174ms/step - loss: 0.6051 - accuracy: 0.6721
# Epoch 84/100
# 115/115 [==============================] - 11s 100ms/step - loss: 0.6111 - accuracy: 0.6590
# Epoch 85/100
# 115/115 [==============================] - 11s 99ms/step - loss: 0.6111 - accuracy: 0.6694
# Epoch 86/100
# 115/115 [==============================] - 11s 100ms/step - loss: 0.6124 - accuracy: 0.6661
# Epoch 87/100
# 115/115 [==============================] - 11s 99ms/step - loss: 0.6101 - accuracy: 0.6661
# Epoch 88/100
# 115/115 [==============================] - 11s 100ms/step - loss: 0.6134 - accuracy: 0.6601
# Epoch 89/100
# 115/115 [==============================] - 11s 99ms/step - loss: 0.6090 - accuracy: 0.6612
# Epoch 90/100
# 115/115 [==============================] - 11s 99ms/step - loss: 0.6114 - accuracy: 0.6694
# Epoch 91/100
# 115/115 [==============================] - 11s 99ms/step - loss: 0.6106 - accuracy: 0.6637
# Epoch 92/100
# 115/115 [==============================] - 11s 100ms/step - loss: 0.6059 - accuracy: 0.6642
# Epoch 93/100
# 115/115 [==============================] - 11s 99ms/step - loss: 0.6071 - accuracy: 0.6650
# Epoch 94/100
# 115/115 [==============================] - 11s 100ms/step - loss: 0.6034 - accuracy: 0.6697
# Epoch 95/100
# 115/115 [==============================] - 12s 101ms/step - loss: 0.6172 - accuracy: 0.6571
# Epoch 96/100
# 115/115 [==============================] - 11s 100ms/step - loss: 0.6102 - accuracy: 0.6678
# Epoch 97/100
# 115/115 [==============================] - 12s 100ms/step - loss: 0.6082 - accuracy: 0.6620
# Epoch 98/100
# 115/115 [==============================] - 11s 99ms/step - loss: 0.6063 - accuracy: 0.6664
# Epoch 99/100
# 115/115 [==============================] - 11s 99ms/step - loss: 0.6011 - accuracy: 0.6664
# Epoch 100/100
# 115/115 [==============================] - 11s 99ms/step - loss: 0.6026 - accuracy: 0.6699
# Train 100 epochs, 1246 sec

# %%
print ("Evaluate on A")
(X_train,y_train,X_valid_A,y_valid_A)=get_x_and_y(train_set,200,600)
just_evaluate(X_valid_A,y_valid_A) 
(X_valid_A,y_valid_A)=(None,None)
print ("Evaluate on B")
(X_train,y_train,X_valid_B,y_valid_B)=get_x_and_y(train_set,600,900)
just_evaluate(X_valid_B,y_valid_B)  
(X_valid_B,y_valid_B)=(None,None)
print ("Evaluate on C")
(X_train,y_train,X_valid_C,y_valid_C)=get_x_and_y(train_set,900,1300)
just_evaluate(X_valid_C,y_valid_C)  
(X_valid_C,y_valid_C)=(None,None)
print ("Evaluate on D")
(X_train,y_train,X_valid_D,y_valid_D)=get_x_and_y(train_set,1300,1900)
just_evaluate(X_valid_D,y_valid_D)  
(X_valid_D,y_valid_D)=(None,None)
print ("Evaluate on E")
(X_train,y_train,X_valid_E,y_valid_E)=get_x_and_y(train_set,1900,3000)
just_evaluate(X_valid_E,y_valid_E)  
(X_valid_E,y_valid_E)=(None,None)
print ("Evaluate on F")
(X_train,y_train,X_valid_F,y_valid_F)=get_x_and_y(train_set,3000,30000)
just_evaluate(X_valid_F,y_valid_F) 
(X_valid_F,y_valid_F)=(None,None) 

print ("Done")
# Out:
# Evaluate on A
# Shape of X is (8165, 600)
# Total 8165, Train portion 6532
# accuracy: 31.90%
# Evaluate on B
# Shape of X is (6442, 900)
# Total 6442, Train portion 5154
# accuracy: 47.13%
# Evaluate on C
# Shape of X is (4478, 1300)
# Total 4478, Train portion 3582
# accuracy: 56.03%
# Evaluate on D
# Shape of X is (4421, 1900)
# Total 4421, Train portion 3537
# accuracy: 59.62%
# Evaluate on E
# Shape of X is (4590, 3000)
# Total 4590, Train portion 3672
# accuracy: 60.13%
# Evaluate on F
# Shape of X is (3900, 30000)
# Total 3900, Train portion 3120
# accuracy: 69.23%
# Done
