# %% [markdown]
# # GRU 240
# Test the RNA length effect.

# %%
NC_FILENAME='ncRNA.gc34.processed.fasta'
PC_FILENAME='pcRNA.gc34.processed.fasta'
DATAPATH=""
try:
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
    NC_FILENAME = DATAPATH+NC_FILENAME
    PC_FILENAME = DATAPATH+PC_FILENAME
except:
    IN_COLAB = False
    DATAPATH="" 

EPOCHS=100  # use 2 for debug, 200 for real
K=3
VOCABULARY_SIZE=4**K+1   # e.g. K=3 => 64 DNA K-mers + 'NNN'
EMBED_DIMEN=16
FILENAME='GRU240'
NEURONS=16
ACT="tanh"
DROP=0.5
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import StratifiedKFold
import tensorflow as tf
from tensorflow import keras
from keras.wrappers.scikit_learn import KerasRegressor
from keras.models import Sequential
from keras.layers import Bidirectional
from keras.layers import GRU
from keras.layers import Dense
from keras.layers import LayerNormalization
import time
dt='float32'
tf.keras.backend.set_floatx(dt)

# %% [markdown]
# ## Build model

# %%
def compile_model(model):
    adam_default_learn_rate = 0.001
    schedule = tf.keras.optimizers.schedules.ExponentialDecay(
        initial_learning_rate = adam_default_learn_rate*10,
        #decay_steps=100000, decay_rate=0.96, staircase=True)
        decay_steps=10000, decay_rate=0.99, staircase=True)
    # learn rate = initial_learning_rate * decay_rate ^ (step / decay_steps)
    alrd = tf.keras.optimizers.Adam(learning_rate=schedule)
    bc=tf.keras.losses.BinaryCrossentropy(from_logits=False)
    print("COMPILE...")
    #model.compile(loss=bc, optimizer=alrd, metrics=["accuracy"])
    model.compile(loss=bc, optimizer="adam", metrics=["accuracy"])
    print("...COMPILED")
    return model

def build_model():
    embed_layer  = keras.layers.Embedding(
        #VOCABULARY_SIZE, EMBED_DIMEN, input_length=1000, input_length=1000, mask_zero=True)
        #input_dim=[None,VOCABULARY_SIZE], output_dim=EMBED_DIMEN, mask_zero=True)
        input_dim=VOCABULARY_SIZE, output_dim=EMBED_DIMEN, mask_zero=True)
    #rnn1_layer = keras.layers.Bidirectional(
    rnn1_layer = keras.layers.GRU(NEURONS, return_sequences=False,  #   True, 
          input_shape=[1000,EMBED_DIMEN], activation=ACT, dropout=DROP)#)#bi
    #rnn2_layer = keras.layers.Bidirectional(
    rnn2_layer = keras.layers.GRU(NEURONS, return_sequences=False, 
        activation=ACT, dropout=DROP)#)#bi
    dense1_layer = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt)
    drop1_layer = keras.layers.Dropout(DROP)
    #dense2_layer = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt)
    #drop2_layer = keras.layers.Dropout(DROP)
    output_layer = keras.layers.Dense(1, activation="sigmoid", dtype=dt)
    mlp = keras.models.Sequential()
    mlp.add(embed_layer)
    mlp.add(rnn1_layer)
    #mlp.add(rnn2_layer)
    mlp.add(dense1_layer)
    mlp.add(drop1_layer)
    #mlp.add(dense2_layer)
    #mlp.add(drop2_layer)
    mlp.add(output_layer)
    mlpc = compile_model(mlp)
    return mlpc

# %% [markdown]
# ## Load and partition sequences

# %%
# Assume file was preprocessed to contain one line per seq.
# Prefer Pandas dataframe but df does not support append.
# For conversion to tensor, must avoid python lists.
def load_fasta(filename,label):
    DEFLINE='>'
    labels=[]
    seqs=[]
    lens=[]
    nums=[]
    num=0
    with open (filename,'r') as infile:
        for line in infile:
            if line[0]!=DEFLINE:
                seq=line.rstrip()
                num += 1   # first seqnum is 1
                seqlen=len(seq)
                nums.append(num)
                labels.append(label)
                seqs.append(seq)
                lens.append(seqlen)
    df1=pd.DataFrame(nums,columns=['seqnum'])
    df2=pd.DataFrame(labels,columns=['class'])
    df3=pd.DataFrame(seqs,columns=['sequence'])
    df4=pd.DataFrame(lens,columns=['seqlen'])
    df=pd.concat((df1,df2,df3,df4),axis=1)
    return df

def separate_X_and_y(data):
    y=   data[['class']].copy()
    X=   data.drop(columns=['class','seqnum','seqlen'])
    return (X,y)

# %% [markdown]
# ## Make K-mers

# %%
def make_kmer_table(K):
    npad='N'*K
    shorter_kmers=['']
    for i in range(K):
        longer_kmers=[]
        for mer in shorter_kmers:
            longer_kmers.append(mer+'A')
            longer_kmers.append(mer+'C')
            longer_kmers.append(mer+'G')
            longer_kmers.append(mer+'T')
        shorter_kmers = longer_kmers
    all_kmers = shorter_kmers
    kmer_dict = {}
    kmer_dict[npad]=0
    value=1
    for mer in all_kmers:
        kmer_dict[mer]=value
        value += 1
    return kmer_dict

KMER_TABLE=make_kmer_table(K)

def strings_to_vectors(data,uniform_len):
    all_seqs=[]
    for seq in data['sequence']:
        i=0
        seqlen=len(seq)
        kmers=[]
        while i < seqlen-K+1 -1:  # stop at minus one for spaced seed
            #kmer=seq[i:i+2]+seq[i+3:i+5]    # SPACED SEED 2/1/2 for K=4
            kmer=seq[i:i+K]  
            i += 1
            value=KMER_TABLE[kmer]
            kmers.append(value)
        pad_val=0
        while i < uniform_len:
            kmers.append(pad_val)
            i += 1
        all_seqs.append(kmers)
    pd2d=pd.DataFrame(all_seqs)
    return pd2d   # return 2D dataframe, uniform dimensions

# %%
def make_kmers(MAXLEN,train_set):
    (X_train_all,y_train_all)=separate_X_and_y(train_set)
    X_train_kmers=strings_to_vectors(X_train_all,MAXLEN)
    # From pandas dataframe to numpy to list to numpy
    num_seqs=len(X_train_kmers)
    tmp_seqs=[]
    for i in range(num_seqs):
        kmer_sequence=X_train_kmers.iloc[i]
        tmp_seqs.append(kmer_sequence)
    X_train_kmers=np.array(tmp_seqs)
    tmp_seqs=None
    labels=y_train_all.to_numpy()
    return (X_train_kmers,labels)

# %%
def make_frequencies(Xin):
    Xout=[]
    VOCABULARY_SIZE= 4**K + 1  # plus one for 'NNN'
    for seq in Xin:
        freqs =[0] * VOCABULARY_SIZE
        total = 0
        for kmerval in seq:
            freqs[kmerval] += 1
            total += 1
        for c in range(VOCABULARY_SIZE):
            freqs[c] = freqs[c]/total
        Xout.append(freqs)
    Xnum = np.asarray(Xout)
    return (Xnum)
def make_slice(data_set,min_len,max_len):
    slice = data_set.query('seqlen <= '+str(max_len)+' & seqlen>= '+str(min_len))
    return slice

# %% [markdown]
# ## Cross validation

# %%
bestname=DATAPATH+FILENAME+".best"
def just_train(X,y): # give me training set
    model=build_model()
    print(model.summary())
    mycallbacks = [keras.callbacks.ModelCheckpoint(
        filepath=bestname, save_best_only=True, 
        monitor='accuracy', mode='max')]   
    print("FIT")
    start_time=time.time()
    history=model.fit(X_train, y_train, # batch_size=10, default=32 works nicely
            epochs=EPOCHS, verbose=1,  # verbose=1 for ascii art, verbose=0 for none
            callbacks=mycallbacks )  # no validation data
    end_time=time.time()
    elapsed_time=(end_time-start_time)                        
    print("Train %d epochs, %d sec"%(EPOCHS,elapsed_time))
    pd.DataFrame(history.history).plot(figsize=(8,5))
    plt.grid(True)
    plt.gca().set_ylim(0,1)
    plt.show()
def just_evaluate(X,y):  # give me validation set
    best_model=keras.models.load_model(bestname)
    scores = best_model.evaluate(X, y, verbose=0)
    print("%s: %.2f%%" % (best_model.metrics_names[1], scores[1]*100))

# %% [markdown]
# ## Train on RNA length-based slice

# %%
#      A    B    C     D     E     F
# 200, 500, 750, 1000, 1500, 3000, 30000 
print("Load data from files.")
nc_seq=load_fasta(NC_FILENAME,0)
pc_seq=load_fasta(PC_FILENAME,1)
train_set=pd.concat((nc_seq,pc_seq),axis=0)
nc_seq=None
pc_seq=None
def get_x_and_y(train_set,minlen,maxlen):
  subset=make_slice(train_set,minlen,maxlen)
  (X_set,y_set)=make_kmers(maxlen,subset)
  print("Shape of X is "+str(X_set.shape))
  L=len(X_set)
  T=int(0.80*L+0.5)
  print("Total %d, Train portion %d"%(L,T))
  X_train=X_set[:T]
  y_train=y_set[:T]
  X_valid=X_set[T:]
  y_valid=y_set[T:]
  return (X_train,y_train,X_valid,y_valid)

MINLEN=200
MAXLEN=700
(X_train,y_train,X_valid,y_valid)=get_x_and_y(train_set,MINLEN,MAXLEN)
print("Loaded")
# Out:
# Load data from files.
# Shape of X is (10501, 700)
# Total 10501, Train portion 8401
# Loaded

# %%
print ("Train on ",MINLEN,"-",MAXLEN)
just_train(X_train,y_train)
# Out:
# Train on  200 - 700
# COMPILE...
# ...COMPILED
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, None, 16)          1040
# _________________________________________________________________
# gru_4 (GRU)                  (None, 16)                1632
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                272
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 2,961
# Trainable params: 2,961
# Non-trainable params: 0
# _________________________________________________________________
# None
# FIT
# Epoch 1/100
# 263/263 [==============================] - ETA: 0s - loss: 0.3151 - accuracy: 0.9235INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU240.best/assets
# 263/263 [==============================] - 20s 75ms/step - loss: 0.3151 - accuracy: 0.9235
# Epoch 2/100
# 263/263 [==============================] - ETA: 0s - loss: 0.2739 - accuracy: 0.9268INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU240.best/assets
# 263/263 [==============================] - 18s 70ms/step - loss: 0.2739 - accuracy: 0.9268
# Epoch 3/100
# 263/263 [==============================] - 8s 29ms/step - loss: 0.2716 - accuracy: 0.9268
# Epoch 4/100
# 263/263 [==============================] - 8s 29ms/step - loss: 0.2718 - accuracy: 0.9268
# Epoch 5/100
# 263/263 [==============================] - ETA: 0s - loss: 0.2667 - accuracy: 0.9269INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU240.best/assets
# 263/263 [==============================] - 18s 70ms/step - loss: 0.2667 - accuracy: 0.9269
# Epoch 6/100
# 263/263 [==============================] - ETA: 0s - loss: 0.2656 - accuracy: 0.9270INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU240.best/assets
# 263/263 [==============================] - 18s 70ms/step - loss: 0.2656 - accuracy: 0.9270
# Epoch 7/100
# 263/263 [==============================] - ETA: 0s - loss: 0.2602 - accuracy: 0.9272INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU240.best/assets
# 263/263 [==============================] - 18s 69ms/step - loss: 0.2602 - accuracy: 0.9272
# Epoch 8/100
# 263/263 [==============================] - ETA: 0s - loss: 0.2606 - accuracy: 0.9274INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU240.best/assets
# 263/263 [==============================] - 18s 69ms/step - loss: 0.2606 - accuracy: 0.9274
# Epoch 9/100
# 263/263 [==============================] - 8s 29ms/step - loss: 0.2595 - accuracy: 0.9273
# Epoch 10/100
# 263/263 [==============================] - 8s 29ms/step - loss: 0.2533 - accuracy: 0.9270
# Epoch 11/100
# 263/263 [==============================] - ETA: 0s - loss: 0.2516 - accuracy: 0.9275INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU240.best/assets
# 263/263 [==============================] - 18s 70ms/step - loss: 0.2516 - accuracy: 0.9275
# Epoch 12/100
# 263/263 [==============================] - 8s 29ms/step - loss: 0.2457 - accuracy: 0.9270
# Epoch 13/100
# 262/263 [============================>.] - ETA: 0s - loss: 0.2448 - accuracy: 0.9287INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU240.best/assets
# 263/263 [==============================] - 18s 70ms/step - loss: 0.2448 - accuracy: 0.9287
# Epoch 14/100
# 263/263 [==============================] - 8s 30ms/step - loss: 0.2426 - accuracy: 0.9267
# Epoch 15/100
# 263/263 [==============================] - 8s 30ms/step - loss: 0.2414 - accuracy: 0.9275
# Epoch 16/100
# 263/263 [==============================] - 8s 29ms/step - loss: 0.2415 - accuracy: 0.9280
# Epoch 17/100
# 263/263 [==============================] - 8s 29ms/step - loss: 0.2393 - accuracy: 0.9274
# Epoch 18/100
# 263/263 [==============================] - 8s 29ms/step - loss: 0.2374 - accuracy: 0.9272
# Epoch 19/100
# 263/263 [==============================] - 8s 29ms/step - loss: 0.2365 - accuracy: 0.9272
# Epoch 20/100
# 263/263 [==============================] - 8s 29ms/step - loss: 0.2373 - accuracy: 0.9263
# Epoch 21/100
# 263/263 [==============================] - 8s 29ms/step - loss: 0.2347 - accuracy: 0.9276
# Epoch 22/100
# 263/263 [==============================] - 8s 30ms/step - loss: 0.2321 - accuracy: 0.9275
# Epoch 23/100
# 263/263 [==============================] - 8s 29ms/step - loss: 0.2337 - accuracy: 0.9275
# Epoch 24/100
# 263/263 [==============================] - 8s 29ms/step - loss: 0.2303 - accuracy: 0.9282
# Epoch 25/100
# 263/263 [==============================] - 8s 29ms/step - loss: 0.2280 - accuracy: 0.9282
# Epoch 26/100
# 263/263 [==============================] - 8s 29ms/step - loss: 0.2289 - accuracy: 0.9287
# Epoch 27/100
# 263/263 [==============================] - ETA: 0s - loss: 0.2293 - accuracy: 0.9289INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU240.best/assets
# 263/263 [==============================] - 18s 70ms/step - loss: 0.2293 - accuracy: 0.9289
# Epoch 28/100
# 263/263 [==============================] - 8s 29ms/step - loss: 0.2230 - accuracy: 0.9287
# Epoch 29/100
# 263/263 [==============================] - 8s 29ms/step - loss: 0.2213 - accuracy: 0.9272
# Epoch 30/100
# 263/263 [==============================] - ETA: 0s - loss: 0.2112 - accuracy: 0.9298INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU240.best/assets
# 263/263 [==============================] - 18s 70ms/step - loss: 0.2112 - accuracy: 0.9298
# Epoch 31/100
# 262/263 [============================>.] - ETA: 0s - loss: 0.2053 - accuracy: 0.9313INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU240.best/assets
# 263/263 [==============================] - 19s 71ms/step - loss: 0.2057 - accuracy: 0.9312
# Epoch 32/100
# 263/263 [==============================] - ETA: 0s - loss: 0.2045 - accuracy: 0.9327INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU240.best/assets
# 263/263 [==============================] - 18s 70ms/step - loss: 0.2045 - accuracy: 0.9327
# Epoch 33/100
# 263/263 [==============================] - ETA: 0s - loss: 0.1988 - accuracy: 0.9341INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU240.best/assets
# 263/263 [==============================] - 18s 70ms/step - loss: 0.1988 - accuracy: 0.9341
# Epoch 34/100
# 263/263 [==============================] - ETA: 0s - loss: 0.1935 - accuracy: 0.9351INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU240.best/assets
# 263/263 [==============================] - 18s 70ms/step - loss: 0.1935 - accuracy: 0.9351
# Epoch 35/100
# 263/263 [==============================] - 8s 30ms/step - loss: 0.1940 - accuracy: 0.9348
# Epoch 36/100
# 263/263 [==============================] - 8s 29ms/step - loss: 0.1917 - accuracy: 0.9341
# Epoch 37/100
# 263/263 [==============================] - 8s 29ms/step - loss: 0.1888 - accuracy: 0.9349
# Epoch 38/100
# 263/263 [==============================] - ETA: 0s - loss: 0.1881 - accuracy: 0.9361INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU240.best/assets
# 263/263 [==============================] - 18s 70ms/step - loss: 0.1881 - accuracy: 0.9361
# Epoch 39/100
# 263/263 [==============================] - 8s 29ms/step - loss: 0.1888 - accuracy: 0.9347
# Epoch 40/100
# 263/263 [==============================] - 8s 29ms/step - loss: 0.1878 - accuracy: 0.9354
# Epoch 41/100
# 263/263 [==============================] - 8s 30ms/step - loss: 0.1867 - accuracy: 0.9343
# Epoch 42/100
# 263/263 [==============================] - 8s 29ms/step - loss: 0.1848 - accuracy: 0.9355
# Epoch 43/100
# 263/263 [==============================] - 8s 29ms/step - loss: 0.1857 - accuracy: 0.9355
# Epoch 44/100
# 263/263 [==============================] - 8s 30ms/step - loss: 0.1905 - accuracy: 0.9323
# Epoch 45/100
# 263/263 [==============================] - 8s 31ms/step - loss: 0.1840 - accuracy: 0.9344
# Epoch 46/100
# 263/263 [==============================] - ETA: 0s - loss: 0.1842 - accuracy: 0.9367INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU240.best/assets
# 263/263 [==============================] - 18s 70ms/step - loss: 0.1842 - accuracy: 0.9367
# Epoch 47/100
# 263/263 [==============================] - 8s 29ms/step - loss: 0.1824 - accuracy: 0.9347
# Epoch 48/100
# 263/263 [==============================] - 8s 30ms/step - loss: 0.1860 - accuracy: 0.9355
# Epoch 49/100
# 263/263 [==============================] - 8s 29ms/step - loss: 0.1869 - accuracy: 0.9360
# Epoch 50/100
# 263/263 [==============================] - 8s 30ms/step - loss: 0.1811 - accuracy: 0.9366
# Epoch 51/100
# 263/263 [==============================] - 8s 30ms/step - loss: 0.1811 - accuracy: 0.9330
# Epoch 52/100
# 263/263 [==============================] - 8s 30ms/step - loss: 0.1827 - accuracy: 0.9357
# Epoch 53/100
# 262/263 [============================>.] - ETA: 0s - loss: 0.1822 - accuracy: 0.9381INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU240.best/assets
# 263/263 [==============================] - 18s 70ms/step - loss: 0.1820 - accuracy: 0.9382
# Epoch 54/100
# 263/263 [==============================] - 8s 29ms/step - loss: 0.1814 - accuracy: 0.9372
# Epoch 55/100
# 263/263 [==============================] - 8s 30ms/step - loss: 0.1785 - accuracy: 0.9363
# Epoch 56/100
# 263/263 [==============================] - ETA: 0s - loss: 0.1823 - accuracy: 0.9383INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU240.best/assets
# 263/263 [==============================] - 18s 70ms/step - loss: 0.1823 - accuracy: 0.9383
# Epoch 57/100
# 263/263 [==============================] - 8s 30ms/step - loss: 0.1792 - accuracy: 0.9379
# Epoch 58/100
# 263/263 [==============================] - 8s 30ms/step - loss: 0.1811 - accuracy: 0.9357
# Epoch 59/100
# 263/263 [==============================] - 8s 29ms/step - loss: 0.1783 - accuracy: 0.9368
# Epoch 60/100
# 263/263 [==============================] - 8s 30ms/step - loss: 0.1793 - accuracy: 0.9369
# Epoch 61/100
# 263/263 [==============================] - 8s 30ms/step - loss: 0.1767 - accuracy: 0.9381
# Epoch 62/100
# 263/263 [==============================] - 8s 29ms/step - loss: 0.1809 - accuracy: 0.9348
# Epoch 63/100
# 263/263 [==============================] - 8s 29ms/step - loss: 0.1794 - accuracy: 0.9368
# Epoch 64/100
# 263/263 [==============================] - 8s 30ms/step - loss: 0.1768 - accuracy: 0.9364
# Epoch 65/100
# 263/263 [==============================] - 8s 30ms/step - loss: 0.1771 - accuracy: 0.9362
# Epoch 66/100
# 263/263 [==============================] - 8s 29ms/step - loss: 0.1744 - accuracy: 0.9352
# Epoch 67/100
# 263/263 [==============================] - 8s 30ms/step - loss: 0.1760 - accuracy: 0.9364
# Epoch 68/100
# 263/263 [==============================] - 8s 30ms/step - loss: 0.1746 - accuracy: 0.9363
# Epoch 69/100
# 263/263 [==============================] - 8s 30ms/step - loss: 0.1737 - accuracy: 0.9360
# Epoch 70/100
# 263/263 [==============================] - 8s 29ms/step - loss: 0.1744 - accuracy: 0.9366
# Epoch 71/100
# 263/263 [==============================] - 8s 29ms/step - loss: 0.1771 - accuracy: 0.9367
# Epoch 72/100
# 263/263 [==============================] - 8s 30ms/step - loss: 0.1754 - accuracy: 0.9377
# Epoch 73/100
# 262/263 [============================>.] - ETA: 0s - loss: 0.1708 - accuracy: 0.9387INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU240.best/assets
# 263/263 [==============================] - 18s 70ms/step - loss: 0.1709 - accuracy: 0.9387
# Epoch 74/100
# 263/263 [==============================] - 8s 30ms/step - loss: 0.1713 - accuracy: 0.9385
# Epoch 75/100
# 263/263 [==============================] - 8s 30ms/step - loss: 0.1714 - accuracy: 0.9370
# Epoch 76/100
# 263/263 [==============================] - 8s 29ms/step - loss: 0.1740 - accuracy: 0.9360
# Epoch 77/100
# 263/263 [==============================] - 8s 29ms/step - loss: 0.1700 - accuracy: 0.9382
# Epoch 78/100
# 263/263 [==============================] - 8s 30ms/step - loss: 0.1746 - accuracy: 0.9363
# Epoch 79/100
# 263/263 [==============================] - 8s 31ms/step - loss: 0.1683 - accuracy: 0.9380
# Epoch 80/100
# 263/263 [==============================] - 8s 30ms/step - loss: 0.1709 - accuracy: 0.9379
# Epoch 81/100
# 263/263 [==============================] - 8s 29ms/step - loss: 0.1723 - accuracy: 0.9379
# Epoch 82/100
# 262/263 [============================>.] - ETA: 0s - loss: 0.1706 - accuracy: 0.9394INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU240.best/assets
# 263/263 [==============================] - 18s 70ms/step - loss: 0.1704 - accuracy: 0.9394
# Epoch 83/100
# 263/263 [==============================] - 8s 30ms/step - loss: 0.1689 - accuracy: 0.9387
# Epoch 84/100
# 263/263 [==============================] - 8s 30ms/step - loss: 0.1649 - accuracy: 0.9382
# Epoch 85/100
# 263/263 [==============================] - 8s 29ms/step - loss: 0.1706 - accuracy: 0.9364
# Epoch 86/100
# 263/263 [==============================] - ETA: 0s - loss: 0.1672 - accuracy: 0.9399INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU240.best/assets
# 263/263 [==============================] - 18s 70ms/step - loss: 0.1672 - accuracy: 0.9399
# Epoch 87/100
# 263/263 [==============================] - 8s 30ms/step - loss: 0.1694 - accuracy: 0.9382
# Epoch 88/100
# 263/263 [==============================] - 8s 30ms/step - loss: 0.1700 - accuracy: 0.9376
# Epoch 89/100
# 263/263 [==============================] - 8s 30ms/step - loss: 0.1675 - accuracy: 0.9374
# Epoch 90/100
# 263/263 [==============================] - 8s 29ms/step - loss: 0.1697 - accuracy: 0.9393
# Epoch 91/100
# 263/263 [==============================] - 8s 29ms/step - loss: 0.1679 - accuracy: 0.9383
# Epoch 92/100
# 263/263 [==============================] - 8s 29ms/step - loss: 0.1703 - accuracy: 0.9392
# Epoch 93/100
# 263/263 [==============================] - 8s 29ms/step - loss: 0.1698 - accuracy: 0.9385
# Epoch 94/100
# 263/263 [==============================] - 8s 30ms/step - loss: 0.1663 - accuracy: 0.9397
# Epoch 95/100
# 263/263 [==============================] - 8s 29ms/step - loss: 0.1701 - accuracy: 0.9399
# Epoch 96/100
# 263/263 [==============================] - 8s 30ms/step - loss: 0.1653 - accuracy: 0.9369
# Epoch 97/100
# 263/263 [==============================] - 8s 29ms/step - loss: 0.1690 - accuracy: 0.9379
# Epoch 98/100
# 263/263 [==============================] - 8s 30ms/step - loss: 0.1649 - accuracy: 0.9383
# Epoch 99/100
# 263/263 [==============================] - ETA: 0s - loss: 0.1607 - accuracy: 0.9429INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU240.best/assets
# 263/263 [==============================] - 18s 70ms/step - loss: 0.1607 - accuracy: 0.9429
# Epoch 100/100
# 263/263 [==============================] - 8s 30ms/step - loss: 0.1668 - accuracy: 0.9386
# Train 100 epochs, 1018 sec

# %%
print ("Evaluate on A")
(X_train,y_train,X_valid_A,y_valid_A)=get_x_and_y(train_set,200,700)
just_evaluate(X_valid_A,y_valid_A) 
(X_valid_A,y_valid_A)=(None,None)
print ("Evaluate on B")
(X_train,y_train,X_valid_B,y_valid_B)=get_x_and_y(train_set,700,900)
just_evaluate(X_valid_B,y_valid_B)  
(X_valid_B,y_valid_B)=(None,None)
print ("Evaluate on C")
(X_train,y_train,X_valid_C,y_valid_C)=get_x_and_y(train_set,900,1200)
just_evaluate(X_valid_C,y_valid_C)  
(X_valid_C,y_valid_C)=(None,None)
print ("Evaluate on D")
(X_train,y_train,X_valid_D,y_valid_D)=get_x_and_y(train_set,1200,1700)
just_evaluate(X_valid_D,y_valid_D)  
(X_valid_D,y_valid_D)=(None,None)
print ("Evaluate on E")
(X_train,y_train,X_valid_E,y_valid_E)=get_x_and_y(train_set,1700,2500)
just_evaluate(X_valid_E,y_valid_E)  
(X_valid_E,y_valid_E)=(None,None)
print ("Evaluate on F")
(X_train,y_train,X_valid_F,y_valid_F)=get_x_and_y(train_set,2500,30000)
just_evaluate(X_valid_F,y_valid_F) 
(X_valid_F,y_valid_F)=(None,None) 

print ("Done")
# Out:
# Evaluate on A
# Shape of X is (10501, 700)
# Total 10501, Train portion 8401
# accuracy: 30.10%
# Evaluate on B
# Shape of X is (4148, 900)
# Total 4148, Train portion 3318
# accuracy: 66.51%
# Evaluate on C
# Shape of X is (3636, 1200)
# Total 3636, Train portion 2909
# accuracy: 80.47%
# Evaluate on D
# Shape of X is (3942, 1700)
# Total 3942, Train portion 3154
# accuracy: 92.26%
# Evaluate on E
# Shape of X is (4395, 2500)
# Total 4395, Train portion 3516
# accuracy: 97.61%
# Evaluate on F
# Shape of X is (5438, 30000)
# Total 5438, Train portion 4350
# accuracy: 99.63%
# Done
