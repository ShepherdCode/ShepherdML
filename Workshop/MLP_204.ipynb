# %% [markdown]
# # MLP 204
# * Operate on 16000 GenCode 34 seqs.
# * 5-way cross validation. Save best model per CV.
# * Report mean accuracy from final re-validation with best 5.
# * Use Adam with a learn rate decay schdule.

# %%
NC_FILENAME='ncRNA.gc34.processed.fasta'
PC_FILENAME='pcRNA.gc34.processed.fasta'
DATAPATH=""
try:
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
    NC_FILENAME = DATAPATH+NC_FILENAME
    PC_FILENAME = DATAPATH+PC_FILENAME
except:
    IN_COLAB = False
    DATAPATH="" 

EPOCHS=200
SPLITS=5
K=5
VOCABULARY_SIZE=4**K+1   # e.g. K=3 => 64 DNA K-mers + 'NNN'
EMBED_DIMEN=16
FILENAME='MLP204'
NEURONS=16
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import StratifiedKFold
import tensorflow as tf
from tensorflow import keras
from keras.wrappers.scikit_learn import KerasRegressor
from keras.models import Sequential
from keras.layers import Bidirectional
from keras.layers import GRU
from keras.layers import Dense
from keras.layers import LayerNormalization
import time
dt='float32'
tf.keras.backend.set_floatx(dt)

# %% [markdown]
# ## Build model

# %%
def compile_model(model):
    adam_default_learn_rate = 0.001
    schedule = tf.keras.optimizers.schedules.ExponentialDecay(
        initial_learning_rate = adam_default_learn_rate*10,
        #decay_steps=100000, decay_rate=0.96, staircase=True)
        decay_steps=10000, decay_rate=0.99, staircase=True)
    # learn rate = initial_learning_rate * decay_rate ^ (step / decay_steps)
    opt = tf.keras.optimizers.Adam(learning_rate=schedule)
    bc=tf.keras.losses.BinaryCrossentropy(from_logits=False)
    print("COMPILE...")
    model.compile(loss=bc, optimizer=opt, metrics=["accuracy"])
    print("...COMPILED")
    return model

def build_model(maxlen):
    act="sigmoid"
    #embed_layer  = keras.layers.Embedding(
    #    VOCABULARY_SIZE,EMBED_DIMEN,input_length=maxlen);
    dense1_layer = keras.layers.Dense(NEURONS, activation=act,dtype=dt,
                                      input_dim=VOCABULARY_SIZE)
    dense2_layer = keras.layers.Dense(NEURONS, activation=act,dtype=dt)
    #dense3_layer = keras.layers.Dense(NEURONS, activation=act,dtype=dt)
    output_layer = keras.layers.Dense(1,  activation="sigmoid",dtype=dt)
    mlp = keras.models.Sequential()
    #mlp.add(embed_layer)
    mlp.add(dense1_layer)
    mlp.add(dense2_layer)
    #mlp.add(dense3_layer)
    mlp.add(output_layer)
    mlpc = compile_model(mlp)
    return mlpc

# %% [markdown]
# ## Load and partition sequences

# %%
# Assume file was preprocessed to contain one line per seq.
# Prefer Pandas dataframe but df does not support append.
# For conversion to tensor, must avoid python lists.
def load_fasta(filename,label):
    DEFLINE='>'
    labels=[]
    seqs=[]
    lens=[]
    nums=[]
    num=0
    with open (filename,'r') as infile:
        for line in infile:
            if line[0]!=DEFLINE:
                seq=line.rstrip()
                num += 1   # first seqnum is 1
                seqlen=len(seq)
                nums.append(num)
                labels.append(label)
                seqs.append(seq)
                lens.append(seqlen)
    df1=pd.DataFrame(nums,columns=['seqnum'])
    df2=pd.DataFrame(labels,columns=['class'])
    df3=pd.DataFrame(seqs,columns=['sequence'])
    df4=pd.DataFrame(lens,columns=['seqlen'])
    df=pd.concat((df1,df2,df3,df4),axis=1)
    return df

def separate_X_and_y(data):
    y=   data[['class']].copy()
    X=   data.drop(columns=['class','seqnum','seqlen'])
    return (X,y)

# %% [markdown]
# ## Make K-mers

# %%
def make_kmer_table(K):
    npad='N'*K
    shorter_kmers=['']
    for i in range(K):
        longer_kmers=[]
        for mer in shorter_kmers:
            longer_kmers.append(mer+'A')
            longer_kmers.append(mer+'C')
            longer_kmers.append(mer+'G')
            longer_kmers.append(mer+'T')
        shorter_kmers = longer_kmers
    all_kmers = shorter_kmers
    kmer_dict = {}
    kmer_dict[npad]=0
    value=1
    for mer in all_kmers:
        kmer_dict[mer]=value
        value += 1
    return kmer_dict

KMER_TABLE=make_kmer_table(K)

def strings_to_vectors(data,uniform_len):
    all_seqs=[]
    for seq in data['sequence']:
        i=0
        seqlen=len(seq)
        kmers=[]
        while i < seqlen-K+1 -1:  # stop at minus one for spaced seed
            #kmer=seq[i:i+2]+seq[i+3:i+5]    # SPACED SEED 2/1/2 for K=4
            kmer=seq[i:i+K]  
            i += 1
            value=KMER_TABLE[kmer]
            kmers.append(value)
        pad_val=0
        while i < uniform_len:
            kmers.append(pad_val)
            i += 1
        all_seqs.append(kmers)
    pd2d=pd.DataFrame(all_seqs)
    return pd2d   # return 2D dataframe, uniform dimensions

# %%
def make_kmers(MAXLEN,train_set):
    (X_train_all,y_train_all)=separate_X_and_y(train_set)
    X_train_kmers=strings_to_vectors(X_train_all,MAXLEN)
    # From pandas dataframe to numpy to list to numpy
    num_seqs=len(X_train_kmers)
    tmp_seqs=[]
    for i in range(num_seqs):
        kmer_sequence=X_train_kmers.iloc[i]
        tmp_seqs.append(kmer_sequence)
    X_train_kmers=np.array(tmp_seqs)
    tmp_seqs=None
    labels=y_train_all.to_numpy()
    return (X_train_kmers,labels)

# %%
def make_frequencies(Xin):
    Xout=[]
    VOCABULARY_SIZE= 4**K + 1  # plus one for 'NNN'
    for seq in Xin:
        freqs =[0] * VOCABULARY_SIZE
        total = 0
        for kmerval in seq:
            freqs[kmerval] += 1
            total += 1
        for c in range(VOCABULARY_SIZE):
            freqs[c] = freqs[c]/total
        Xout.append(freqs)
    Xnum = np.asarray(Xout)
    return (Xnum)
def make_slice(data_set,min_len,max_len):
    slice = data_set.query('seqlen <= '+str(max_len)+' & seqlen>= '+str(min_len))
    return slice

# %% [markdown]
# ## Cross validation

# %%
def do_cross_validation(X,y,given_model):
    cv_scores = []
    fold=0
    splitter = ShuffleSplit(n_splits=SPLITS, test_size=0.1, random_state=37863)
    for train_index,valid_index in splitter.split(X):
        fold += 1
        X_train=X[train_index] # use iloc[] for dataframe
        y_train=y[train_index]
        X_valid=X[valid_index]
        y_valid=y[valid_index]        
        # Avoid continually improving the same model.
        model = compile_model(keras.models.clone_model(given_model))
        bestname=DATAPATH+FILENAME+".cv."+str(fold)+".best"
        mycallbacks = [keras.callbacks.ModelCheckpoint(
            filepath=bestname, save_best_only=True, 
            monitor='val_accuracy', mode='max')]   
        print("FIT")
        start_time=time.time()
        history=model.fit(X_train, y_train, # batch_size=10, default=32 works nicely
                epochs=EPOCHS, verbose=1,  # verbose=1 for ascii art, verbose=0 for none
                callbacks=mycallbacks,
                validation_data=(X_valid,y_valid) )
        end_time=time.time()
        elapsed_time=(end_time-start_time)                        
        print("Fold %d, %d epochs, %d sec"%(fold,EPOCHS,elapsed_time))
        pd.DataFrame(history.history).plot(figsize=(8,5))
        plt.grid(True)
        plt.gca().set_ylim(0,1)
        plt.show()
        best_model=keras.models.load_model(bestname)
        scores = best_model.evaluate(X_valid, y_valid, verbose=0)
        print("%s: %.2f%%" % (best_model.metrics_names[1], scores[1]*100))
        cv_scores.append(scores[1] * 100)  
    print()
    print("%d-way Cross Validation mean %.2f%% (+/- %.2f%%)" % (fold, np.mean(cv_scores), np.std(cv_scores)))

# %% [markdown]
# ## Train on RNA lengths 200-1Kb

# %%
MINLEN=200
MAXLEN=1000
print("Load data from files.")
nc_seq=load_fasta(NC_FILENAME,0)
pc_seq=load_fasta(PC_FILENAME,1)
train_set=pd.concat((nc_seq,pc_seq),axis=0)
nc_seq=None
pc_seq=None
print("Ready: train_set")
#train_set
print ("Compile the model")
model=build_model(MAXLEN)
print ("Summarize the model")
print(model.summary())  # Print this only once
model.save(DATAPATH+FILENAME+'.model')
print ("Data prep")
subset=make_slice(train_set,MINLEN,MAXLEN)# One array to two: X and y
print ("Data reshape")
(X_train,y_train)=make_kmers(MAXLEN,subset)
X_train=make_frequencies(X_train)
# Out:
# Load data from files.
# Ready: train_set
# Compile the model
# COMPILE...
# ...COMPILED
# Summarize the model
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 16)                16416
# _________________________________________________________________
# dense_7 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 16,705
# Trainable params: 16,705
# Non-trainable params: 0
# _________________________________________________________________
# None
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/MLP204.model/assets
# Data prep
# Data reshape

# %%
print ("Cross valiation")
do_cross_validation(X_train,y_train,model)  
print ("Done")
# Out:
# Cross valiation
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/200
# 443/453 [============================>.] - ETA: 0s - loss: 0.5716 - accuracy: 0.7015INFO:tensorflow:Assets written to: /content/drive/My Drive/data/MLP204.cv.1.best/assets
# 453/453 [==============================] - 2s 4ms/step - loss: 0.5692 - accuracy: 0.7034 - val_loss: 0.4683 - val_accuracy: 0.7834
# Epoch 2/200
# 435/453 [===========================>..] - ETA: 0s - loss: 0.4255 - accuracy: 0.8083INFO:tensorflow:Assets written to: /content/drive/My Drive/data/MLP204.cv.1.best/assets
# 453/453 [==============================] - 2s 4ms/step - loss: 0.4239 - accuracy: 0.8088 - val_loss: 0.3534 - val_accuracy: 0.8566
# Epoch 3/200
# 444/453 [============================>.] - ETA: 0s - loss: 0.3549 - accuracy: 0.8477INFO:tensorflow:Assets written to: /content/drive/My Drive/data/MLP204.cv.1.best/assets
# 453/453 [==============================] - 2s 4ms/step - loss: 0.3541 - accuracy: 0.8478 - val_loss: 0.3230 - val_accuracy: 0.8622
# Epoch 4/200
# 449/453 [============================>.] - ETA: 0s - loss: 0.3376 - accuracy: 0.8540INFO:tensorflow:Assets written to: /content/drive/My Drive/data/MLP204.cv.1.best/assets
# 453/453 [==============================] - 2s 4ms/step - loss: 0.3372 - accuracy: 0.8542 - val_loss: 0.3201 - val_accuracy: 0.8684
# Epoch 5/200
# 449/453 [============================>.] - ETA: 0s - loss: 0.3298 - accuracy: 0.8603INFO:tensorflow:Assets written to: /content/drive/My Drive/data/MLP204.cv.1.best/assets
# 453/453 [==============================] - 2s 4ms/step - loss: 0.3293 - accuracy: 0.8604 - val_loss: 0.3100 - val_accuracy: 0.8721
# Epoch 6/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3224 - accuracy: 0.8644 - val_loss: 0.3361 - val_accuracy: 0.8579
# Epoch 7/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3211 - accuracy: 0.8654 - val_loss: 0.3242 - val_accuracy: 0.8647
# Epoch 8/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3204 - accuracy: 0.8643 - val_loss: 0.3229 - val_accuracy: 0.8641
# Epoch 9/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3143 - accuracy: 0.8694 - val_loss: 0.3245 - val_accuracy: 0.8690
# Epoch 10/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3167 - accuracy: 0.8668 - val_loss: 0.3226 - val_accuracy: 0.8703
# Epoch 11/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3127 - accuracy: 0.8684 - val_loss: 0.3111 - val_accuracy: 0.8703
# Epoch 12/200
# 445/453 [============================>.] - ETA: 0s - loss: 0.3113 - accuracy: 0.8713INFO:tensorflow:Assets written to: /content/drive/My Drive/data/MLP204.cv.1.best/assets
# 453/453 [==============================] - 2s 5ms/step - loss: 0.3122 - accuracy: 0.8708 - val_loss: 0.3101 - val_accuracy: 0.8734
# Epoch 13/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3087 - accuracy: 0.8695 - val_loss: 0.3196 - val_accuracy: 0.8696
# Epoch 14/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3093 - accuracy: 0.8699 - val_loss: 0.3295 - val_accuracy: 0.8591
# Epoch 15/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3113 - accuracy: 0.8695 - val_loss: 0.3317 - val_accuracy: 0.8603
# Epoch 16/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3083 - accuracy: 0.8710 - val_loss: 0.3185 - val_accuracy: 0.8665
# Epoch 17/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3104 - accuracy: 0.8675 - val_loss: 0.3138 - val_accuracy: 0.8703
# Epoch 18/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3045 - accuracy: 0.8724 - val_loss: 0.3267 - val_accuracy: 0.8659
# Epoch 19/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3057 - accuracy: 0.8722 - val_loss: 0.3163 - val_accuracy: 0.8703
# Epoch 20/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3108 - accuracy: 0.8704 - val_loss: 0.3223 - val_accuracy: 0.8684
# Epoch 21/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3046 - accuracy: 0.8730 - val_loss: 0.3161 - val_accuracy: 0.8709
# Epoch 22/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3081 - accuracy: 0.8719 - val_loss: 0.3240 - val_accuracy: 0.8684
# Epoch 23/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3080 - accuracy: 0.8699 - val_loss: 0.3171 - val_accuracy: 0.8672
# Epoch 24/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3054 - accuracy: 0.8699 - val_loss: 0.3325 - val_accuracy: 0.8610
# Epoch 25/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3063 - accuracy: 0.8713 - val_loss: 0.3180 - val_accuracy: 0.8703
# Epoch 26/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3080 - accuracy: 0.8708 - val_loss: 0.3338 - val_accuracy: 0.8603
# Epoch 27/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3033 - accuracy: 0.8724 - val_loss: 0.3160 - val_accuracy: 0.8696
# Epoch 28/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3030 - accuracy: 0.8723 - val_loss: 0.3361 - val_accuracy: 0.8585
# Epoch 29/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3050 - accuracy: 0.8716 - val_loss: 0.3191 - val_accuracy: 0.8684
# Epoch 30/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3017 - accuracy: 0.8737 - val_loss: 0.3220 - val_accuracy: 0.8653
# Epoch 31/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3021 - accuracy: 0.8732 - val_loss: 0.3269 - val_accuracy: 0.8653
# Epoch 32/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3025 - accuracy: 0.8719 - val_loss: 0.3515 - val_accuracy: 0.8461
# Epoch 33/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3029 - accuracy: 0.8739 - val_loss: 0.3193 - val_accuracy: 0.8684
# Epoch 34/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3028 - accuracy: 0.8716 - val_loss: 0.3183 - val_accuracy: 0.8684
# Epoch 35/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3040 - accuracy: 0.8734 - val_loss: 0.3330 - val_accuracy: 0.8628
# Epoch 36/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3018 - accuracy: 0.8728 - val_loss: 0.3191 - val_accuracy: 0.8690
# Epoch 37/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3050 - accuracy: 0.8717 - val_loss: 0.3276 - val_accuracy: 0.8603
# Epoch 38/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3030 - accuracy: 0.8724 - val_loss: 0.3301 - val_accuracy: 0.8616
# Epoch 39/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3017 - accuracy: 0.8740 - val_loss: 0.3310 - val_accuracy: 0.8622
# Epoch 40/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3027 - accuracy: 0.8739 - val_loss: 0.3216 - val_accuracy: 0.8690
# Epoch 41/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3031 - accuracy: 0.8741 - val_loss: 0.3226 - val_accuracy: 0.8641
# Epoch 42/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3017 - accuracy: 0.8739 - val_loss: 0.3230 - val_accuracy: 0.8665
# Epoch 43/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3016 - accuracy: 0.8728 - val_loss: 0.3215 - val_accuracy: 0.8678
# Epoch 44/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3010 - accuracy: 0.8743 - val_loss: 0.3266 - val_accuracy: 0.8634
# Epoch 45/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3013 - accuracy: 0.8728 - val_loss: 0.3388 - val_accuracy: 0.8523
# Epoch 46/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3016 - accuracy: 0.8717 - val_loss: 0.3232 - val_accuracy: 0.8634
# Epoch 47/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3016 - accuracy: 0.8725 - val_loss: 0.3198 - val_accuracy: 0.8703
# Epoch 48/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3012 - accuracy: 0.8739 - val_loss: 0.3287 - val_accuracy: 0.8610
# Epoch 49/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3013 - accuracy: 0.8733 - val_loss: 0.3185 - val_accuracy: 0.8690
# Epoch 50/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3013 - accuracy: 0.8743 - val_loss: 0.3202 - val_accuracy: 0.8684
# Epoch 51/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3008 - accuracy: 0.8756 - val_loss: 0.3239 - val_accuracy: 0.8647
# Epoch 52/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3004 - accuracy: 0.8734 - val_loss: 0.3284 - val_accuracy: 0.8622
# Epoch 53/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3009 - accuracy: 0.8736 - val_loss: 0.3297 - val_accuracy: 0.8622
# Epoch 54/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3013 - accuracy: 0.8744 - val_loss: 0.3236 - val_accuracy: 0.8647
# Epoch 55/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3004 - accuracy: 0.8752 - val_loss: 0.3330 - val_accuracy: 0.8597
# Epoch 56/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2995 - accuracy: 0.8732 - val_loss: 0.3193 - val_accuracy: 0.8659
# Epoch 57/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2990 - accuracy: 0.8740 - val_loss: 0.3188 - val_accuracy: 0.8647
# Epoch 58/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2983 - accuracy: 0.8750 - val_loss: 0.3211 - val_accuracy: 0.8634
# Epoch 59/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2995 - accuracy: 0.8748 - val_loss: 0.3213 - val_accuracy: 0.8659
# Epoch 60/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2972 - accuracy: 0.8764 - val_loss: 0.3207 - val_accuracy: 0.8684
# Epoch 61/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2996 - accuracy: 0.8737 - val_loss: 0.3218 - val_accuracy: 0.8659
# Epoch 62/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2978 - accuracy: 0.8748 - val_loss: 0.3239 - val_accuracy: 0.8672
# Epoch 63/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2994 - accuracy: 0.8757 - val_loss: 0.3190 - val_accuracy: 0.8690
# Epoch 64/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2987 - accuracy: 0.8769 - val_loss: 0.3189 - val_accuracy: 0.8678
# Epoch 65/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2951 - accuracy: 0.8787 - val_loss: 0.3213 - val_accuracy: 0.8647
# Epoch 66/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2960 - accuracy: 0.8758 - val_loss: 0.3214 - val_accuracy: 0.8647
# Epoch 67/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2975 - accuracy: 0.8740 - val_loss: 0.3368 - val_accuracy: 0.8535
# Epoch 68/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2977 - accuracy: 0.8741 - val_loss: 0.3325 - val_accuracy: 0.8603
# Epoch 69/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2973 - accuracy: 0.8747 - val_loss: 0.3282 - val_accuracy: 0.8653
# Epoch 70/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2959 - accuracy: 0.8771 - val_loss: 0.3177 - val_accuracy: 0.8684
# Epoch 71/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2949 - accuracy: 0.8759 - val_loss: 0.3150 - val_accuracy: 0.8672
# Epoch 72/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2939 - accuracy: 0.8763 - val_loss: 0.3172 - val_accuracy: 0.8678
# Epoch 73/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2940 - accuracy: 0.8750 - val_loss: 0.3187 - val_accuracy: 0.8653
# Epoch 74/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2924 - accuracy: 0.8790 - val_loss: 0.3149 - val_accuracy: 0.8696
# Epoch 75/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2930 - accuracy: 0.8777 - val_loss: 0.3140 - val_accuracy: 0.8690
# Epoch 76/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2912 - accuracy: 0.8778 - val_loss: 0.3166 - val_accuracy: 0.8665
# Epoch 77/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2908 - accuracy: 0.8774 - val_loss: 0.3141 - val_accuracy: 0.8709
# Epoch 78/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2931 - accuracy: 0.8777 - val_loss: 0.3156 - val_accuracy: 0.8653
# Epoch 79/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2899 - accuracy: 0.8796 - val_loss: 0.3143 - val_accuracy: 0.8684
# Epoch 80/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2907 - accuracy: 0.8786 - val_loss: 0.3153 - val_accuracy: 0.8653
# Epoch 81/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2915 - accuracy: 0.8791 - val_loss: 0.3186 - val_accuracy: 0.8703
# Epoch 82/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2896 - accuracy: 0.8792 - val_loss: 0.3134 - val_accuracy: 0.8684
# Epoch 83/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2870 - accuracy: 0.8803 - val_loss: 0.3135 - val_accuracy: 0.8696
# Epoch 84/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2895 - accuracy: 0.8797 - val_loss: 0.3129 - val_accuracy: 0.8709
# Epoch 85/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2863 - accuracy: 0.8817 - val_loss: 0.3188 - val_accuracy: 0.8641
# Epoch 86/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2865 - accuracy: 0.8817 - val_loss: 0.3172 - val_accuracy: 0.8665
# Epoch 87/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2839 - accuracy: 0.8829 - val_loss: 0.3447 - val_accuracy: 0.8479
# Epoch 88/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2847 - accuracy: 0.8824 - val_loss: 0.3159 - val_accuracy: 0.8684
# Epoch 89/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2842 - accuracy: 0.8844 - val_loss: 0.3122 - val_accuracy: 0.8703
# Epoch 90/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2825 - accuracy: 0.8820 - val_loss: 0.3123 - val_accuracy: 0.8715
# Epoch 91/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2813 - accuracy: 0.8837 - val_loss: 0.3118 - val_accuracy: 0.8734
# Epoch 92/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2816 - accuracy: 0.8846 - val_loss: 0.3155 - val_accuracy: 0.8684
# Epoch 93/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2796 - accuracy: 0.8839 - val_loss: 0.3129 - val_accuracy: 0.8709
# Epoch 94/200
# 453/453 [==============================] - ETA: 0s - loss: 0.2799 - accuracy: 0.8848INFO:tensorflow:Assets written to: /content/drive/My Drive/data/MLP204.cv.1.best/assets
# 453/453 [==============================] - 2s 4ms/step - loss: 0.2799 - accuracy: 0.8848 - val_loss: 0.3102 - val_accuracy: 0.8759
# Epoch 95/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2789 - accuracy: 0.8841 - val_loss: 0.3193 - val_accuracy: 0.8696
# Epoch 96/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2788 - accuracy: 0.8837 - val_loss: 0.3125 - val_accuracy: 0.8734
# Epoch 97/200
# 441/453 [============================>.] - ETA: 0s - loss: 0.2750 - accuracy: 0.8863INFO:tensorflow:Assets written to: /content/drive/My Drive/data/MLP204.cv.1.best/assets
# 453/453 [==============================] - 2s 4ms/step - loss: 0.2771 - accuracy: 0.8856 - val_loss: 0.3097 - val_accuracy: 0.8765
# Epoch 98/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2765 - accuracy: 0.8849 - val_loss: 0.3142 - val_accuracy: 0.8684
# Epoch 99/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2756 - accuracy: 0.8852 - val_loss: 0.3084 - val_accuracy: 0.8759
# Epoch 100/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2755 - accuracy: 0.8859 - val_loss: 0.3128 - val_accuracy: 0.8740
# Epoch 101/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2746 - accuracy: 0.8872 - val_loss: 0.3100 - val_accuracy: 0.8715
# Epoch 102/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2743 - accuracy: 0.8870 - val_loss: 0.3122 - val_accuracy: 0.8721
# Epoch 103/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2734 - accuracy: 0.8868 - val_loss: 0.3075 - val_accuracy: 0.8709
# Epoch 104/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2729 - accuracy: 0.8879 - val_loss: 0.3118 - val_accuracy: 0.8734
# Epoch 105/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2728 - accuracy: 0.8897 - val_loss: 0.3085 - val_accuracy: 0.8684
# Epoch 106/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2725 - accuracy: 0.8872 - val_loss: 0.3116 - val_accuracy: 0.8709
# Epoch 107/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2716 - accuracy: 0.8890 - val_loss: 0.3485 - val_accuracy: 0.8516
# Epoch 108/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2711 - accuracy: 0.8882 - val_loss: 0.3095 - val_accuracy: 0.8703
# Epoch 109/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2694 - accuracy: 0.8917 - val_loss: 0.3101 - val_accuracy: 0.8734
# Epoch 110/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2699 - accuracy: 0.8893 - val_loss: 0.3143 - val_accuracy: 0.8690
# Epoch 111/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2675 - accuracy: 0.8904 - val_loss: 0.3104 - val_accuracy: 0.8709
# Epoch 112/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2698 - accuracy: 0.8893 - val_loss: 0.3090 - val_accuracy: 0.8696
# Epoch 113/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2674 - accuracy: 0.8930 - val_loss: 0.3178 - val_accuracy: 0.8703
# Epoch 114/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2676 - accuracy: 0.8902 - val_loss: 0.3119 - val_accuracy: 0.8665
# Epoch 115/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2665 - accuracy: 0.8899 - val_loss: 0.3166 - val_accuracy: 0.8659
# Epoch 116/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2648 - accuracy: 0.8908 - val_loss: 0.3141 - val_accuracy: 0.8746
# Epoch 117/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2659 - accuracy: 0.8928 - val_loss: 0.3120 - val_accuracy: 0.8715
# Epoch 118/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2637 - accuracy: 0.8935 - val_loss: 0.3097 - val_accuracy: 0.8715
# Epoch 119/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2632 - accuracy: 0.8926 - val_loss: 0.3104 - val_accuracy: 0.8703
# Epoch 120/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2619 - accuracy: 0.8913 - val_loss: 0.3108 - val_accuracy: 0.8647
# Epoch 121/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2629 - accuracy: 0.8922 - val_loss: 0.3141 - val_accuracy: 0.8659
# Epoch 122/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2609 - accuracy: 0.8943 - val_loss: 0.3116 - val_accuracy: 0.8715
# Epoch 123/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2591 - accuracy: 0.8943 - val_loss: 0.3146 - val_accuracy: 0.8703
# Epoch 124/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2605 - accuracy: 0.8953 - val_loss: 0.3105 - val_accuracy: 0.8734
# Epoch 125/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2590 - accuracy: 0.8953 - val_loss: 0.3124 - val_accuracy: 0.8740
# Epoch 126/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2588 - accuracy: 0.8940 - val_loss: 0.3121 - val_accuracy: 0.8752
# Epoch 127/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2584 - accuracy: 0.8951 - val_loss: 0.3164 - val_accuracy: 0.8684
# Epoch 128/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2580 - accuracy: 0.8941 - val_loss: 0.3185 - val_accuracy: 0.8734
# Epoch 129/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2569 - accuracy: 0.8966 - val_loss: 0.3169 - val_accuracy: 0.8709
# Epoch 130/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2562 - accuracy: 0.8958 - val_loss: 0.3118 - val_accuracy: 0.8665
# Epoch 131/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2563 - accuracy: 0.8959 - val_loss: 0.3214 - val_accuracy: 0.8665
# Epoch 132/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2526 - accuracy: 0.8967 - val_loss: 0.3197 - val_accuracy: 0.8678
# Epoch 133/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2540 - accuracy: 0.8968 - val_loss: 0.3160 - val_accuracy: 0.8734
# Epoch 134/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2545 - accuracy: 0.8973 - val_loss: 0.3126 - val_accuracy: 0.8727
# Epoch 135/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2530 - accuracy: 0.8975 - val_loss: 0.3184 - val_accuracy: 0.8678
# Epoch 136/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2521 - accuracy: 0.8970 - val_loss: 0.3142 - val_accuracy: 0.8709
# Epoch 137/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2510 - accuracy: 0.8994 - val_loss: 0.3239 - val_accuracy: 0.8690
# Epoch 138/200
# 453/453 [==============================] - 2s 3ms/step - loss: 0.2497 - accuracy: 0.8988 - val_loss: 0.3179 - val_accuracy: 0.8715
# Epoch 139/200
# 453/453 [==============================] - 2s 3ms/step - loss: 0.2495 - accuracy: 0.8982 - val_loss: 0.3223 - val_accuracy: 0.8721
# Epoch 140/200
# 453/453 [==============================] - 2s 3ms/step - loss: 0.2480 - accuracy: 0.8994 - val_loss: 0.3555 - val_accuracy: 0.8529
# Epoch 141/200
# 453/453 [==============================] - 2s 4ms/step - loss: 0.2494 - accuracy: 0.8982 - val_loss: 0.3180 - val_accuracy: 0.8696
# Epoch 142/200
# 453/453 [==============================] - 2s 3ms/step - loss: 0.2458 - accuracy: 0.9004 - val_loss: 0.3219 - val_accuracy: 0.8703
# Epoch 143/200
# 453/453 [==============================] - 2s 3ms/step - loss: 0.2452 - accuracy: 0.9004 - val_loss: 0.3234 - val_accuracy: 0.8672
# Epoch 144/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2429 - accuracy: 0.9022 - val_loss: 0.3236 - val_accuracy: 0.8634
# Epoch 145/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2430 - accuracy: 0.9009 - val_loss: 0.3321 - val_accuracy: 0.8659
# Epoch 146/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2421 - accuracy: 0.9022 - val_loss: 0.3326 - val_accuracy: 0.8659
# Epoch 147/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2404 - accuracy: 0.9006 - val_loss: 0.3174 - val_accuracy: 0.8690
# Epoch 148/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2397 - accuracy: 0.9020 - val_loss: 0.3269 - val_accuracy: 0.8703
# Epoch 149/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2395 - accuracy: 0.9046 - val_loss: 0.3225 - val_accuracy: 0.8672
# Epoch 150/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2372 - accuracy: 0.9049 - val_loss: 0.3242 - val_accuracy: 0.8684
# Epoch 151/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2368 - accuracy: 0.9040 - val_loss: 0.3198 - val_accuracy: 0.8721
# Epoch 152/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2355 - accuracy: 0.9055 - val_loss: 0.3449 - val_accuracy: 0.8610
# Epoch 153/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2339 - accuracy: 0.9042 - val_loss: 0.3282 - val_accuracy: 0.8715
# Epoch 154/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2342 - accuracy: 0.9035 - val_loss: 0.3585 - val_accuracy: 0.8516
# Epoch 155/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2350 - accuracy: 0.9052 - val_loss: 0.3253 - val_accuracy: 0.8696
# Epoch 156/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2303 - accuracy: 0.9093 - val_loss: 0.3229 - val_accuracy: 0.8721
# Epoch 157/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2279 - accuracy: 0.9084 - val_loss: 0.3342 - val_accuracy: 0.8703
# Epoch 158/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2305 - accuracy: 0.9067 - val_loss: 0.3304 - val_accuracy: 0.8690
# Epoch 159/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2264 - accuracy: 0.9109 - val_loss: 0.3260 - val_accuracy: 0.8721
# Epoch 160/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2244 - accuracy: 0.9113 - val_loss: 0.3269 - val_accuracy: 0.8703
# Epoch 161/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2230 - accuracy: 0.9089 - val_loss: 0.3289 - val_accuracy: 0.8684
# Epoch 162/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2200 - accuracy: 0.9115 - val_loss: 0.3318 - val_accuracy: 0.8734
# Epoch 163/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2203 - accuracy: 0.9113 - val_loss: 0.3315 - val_accuracy: 0.8715
# Epoch 164/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2191 - accuracy: 0.9129 - val_loss: 0.3343 - val_accuracy: 0.8690
# Epoch 165/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2163 - accuracy: 0.9132 - val_loss: 0.3279 - val_accuracy: 0.8696
# Epoch 166/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2151 - accuracy: 0.9153 - val_loss: 0.3336 - val_accuracy: 0.8759
# Epoch 167/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2160 - accuracy: 0.9129 - val_loss: 0.3326 - val_accuracy: 0.8703
# Epoch 168/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2117 - accuracy: 0.9160 - val_loss: 0.3516 - val_accuracy: 0.8610
# Epoch 169/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2108 - accuracy: 0.9160 - val_loss: 0.3446 - val_accuracy: 0.8659
# Epoch 170/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2096 - accuracy: 0.9169 - val_loss: 0.3381 - val_accuracy: 0.8703
# Epoch 171/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2062 - accuracy: 0.9184 - val_loss: 0.3449 - val_accuracy: 0.8684
# Epoch 172/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2041 - accuracy: 0.9193 - val_loss: 0.3810 - val_accuracy: 0.8634
# Epoch 173/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2023 - accuracy: 0.9210 - val_loss: 0.3501 - val_accuracy: 0.8653
# Epoch 174/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2006 - accuracy: 0.9195 - val_loss: 0.3540 - val_accuracy: 0.8684
# Epoch 175/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2006 - accuracy: 0.9202 - val_loss: 0.3561 - val_accuracy: 0.8653
# Epoch 176/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.1970 - accuracy: 0.9213 - val_loss: 0.3680 - val_accuracy: 0.8616
# Epoch 177/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.1961 - accuracy: 0.9238 - val_loss: 0.3567 - val_accuracy: 0.8703
# Epoch 178/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.1934 - accuracy: 0.9243 - val_loss: 0.4124 - val_accuracy: 0.8473
# Epoch 179/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.1899 - accuracy: 0.9257 - val_loss: 0.3656 - val_accuracy: 0.8579
# Epoch 180/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.1907 - accuracy: 0.9257 - val_loss: 0.3610 - val_accuracy: 0.8647
# Epoch 181/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.1891 - accuracy: 0.9260 - val_loss: 0.3747 - val_accuracy: 0.8634
# Epoch 182/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.1860 - accuracy: 0.9253 - val_loss: 0.3849 - val_accuracy: 0.8653
# Epoch 183/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.1831 - accuracy: 0.9294 - val_loss: 0.3670 - val_accuracy: 0.8628
# Epoch 184/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.1806 - accuracy: 0.9290 - val_loss: 0.3812 - val_accuracy: 0.8628
# Epoch 185/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.1794 - accuracy: 0.9296 - val_loss: 0.3759 - val_accuracy: 0.8641
# Epoch 186/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.1764 - accuracy: 0.9320 - val_loss: 0.3859 - val_accuracy: 0.8603
# Epoch 187/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.1780 - accuracy: 0.9304 - val_loss: 0.3902 - val_accuracy: 0.8616
# Epoch 188/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.1734 - accuracy: 0.9328 - val_loss: 0.3924 - val_accuracy: 0.8610
# Epoch 189/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.1718 - accuracy: 0.9332 - val_loss: 0.4017 - val_accuracy: 0.8591
# Epoch 190/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.1714 - accuracy: 0.9336 - val_loss: 0.4042 - val_accuracy: 0.8554
# Epoch 191/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.1690 - accuracy: 0.9331 - val_loss: 0.4246 - val_accuracy: 0.8399
# Epoch 192/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.1689 - accuracy: 0.9348 - val_loss: 0.4102 - val_accuracy: 0.8560
# Epoch 193/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.1668 - accuracy: 0.9362 - val_loss: 0.4184 - val_accuracy: 0.8616
# Epoch 194/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.1629 - accuracy: 0.9365 - val_loss: 0.4071 - val_accuracy: 0.8628
# Epoch 195/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.1644 - accuracy: 0.9364 - val_loss: 0.4189 - val_accuracy: 0.8616
# Epoch 196/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.1611 - accuracy: 0.9391 - val_loss: 0.4176 - val_accuracy: 0.8616
# Epoch 197/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.1586 - accuracy: 0.9402 - val_loss: 0.4231 - val_accuracy: 0.8672
# Epoch 198/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.1609 - accuracy: 0.9376 - val_loss: 0.4397 - val_accuracy: 0.8597
# Epoch 199/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.1570 - accuracy: 0.9393 - val_loss: 0.4283 - val_accuracy: 0.8448
# Epoch 200/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.1558 - accuracy: 0.9393 - val_loss: 0.4329 - val_accuracy: 0.8529
# Fold 1, 200 epochs, 277 sec
# accuracy: 87.65%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/200
# 440/453 [============================>.] - ETA: 0s - loss: 0.5778 - accuracy: 0.6947INFO:tensorflow:Assets written to: /content/drive/My Drive/data/MLP204.cv.2.best/assets
# 453/453 [==============================] - 2s 4ms/step - loss: 0.5753 - accuracy: 0.6974 - val_loss: 0.4969 - val_accuracy: 0.7610
# Epoch 2/200
# 439/453 [============================>.] - ETA: 0s - loss: 0.4285 - accuracy: 0.8068INFO:tensorflow:Assets written to: /content/drive/My Drive/data/MLP204.cv.2.best/assets
# 453/453 [==============================] - 2s 4ms/step - loss: 0.4273 - accuracy: 0.8075 - val_loss: 0.3899 - val_accuracy: 0.8281
# Epoch 3/200
# 446/453 [============================>.] - ETA: 0s - loss: 0.3526 - accuracy: 0.8493INFO:tensorflow:Assets written to: /content/drive/My Drive/data/MLP204.cv.2.best/assets
# 453/453 [==============================] - 2s 4ms/step - loss: 0.3517 - accuracy: 0.8499 - val_loss: 0.3732 - val_accuracy: 0.8442
# Epoch 4/200
# 441/453 [============================>.] - ETA: 0s - loss: 0.3297 - accuracy: 0.8611INFO:tensorflow:Assets written to: /content/drive/My Drive/data/MLP204.cv.2.best/assets
# 453/453 [==============================] - 2s 4ms/step - loss: 0.3301 - accuracy: 0.8613 - val_loss: 0.3742 - val_accuracy: 0.8492
# Epoch 5/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3227 - accuracy: 0.8648 - val_loss: 0.3665 - val_accuracy: 0.8479
# Epoch 6/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3188 - accuracy: 0.8638 - val_loss: 0.3996 - val_accuracy: 0.8343
# Epoch 7/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3178 - accuracy: 0.8633 - val_loss: 0.3838 - val_accuracy: 0.8454
# Epoch 8/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3119 - accuracy: 0.8662 - val_loss: 0.3644 - val_accuracy: 0.8479
# Epoch 9/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3096 - accuracy: 0.8687 - val_loss: 0.4208 - val_accuracy: 0.8274
# Epoch 10/200
# 440/453 [============================>.] - ETA: 0s - loss: 0.3111 - accuracy: 0.8705INFO:tensorflow:Assets written to: /content/drive/My Drive/data/MLP204.cv.2.best/assets
# 453/453 [==============================] - 2s 4ms/step - loss: 0.3108 - accuracy: 0.8704 - val_loss: 0.3753 - val_accuracy: 0.8498
# Epoch 11/200
# 448/453 [============================>.] - ETA: 0s - loss: 0.3056 - accuracy: 0.8735INFO:tensorflow:Assets written to: /content/drive/My Drive/data/MLP204.cv.2.best/assets
# 453/453 [==============================] - 2s 4ms/step - loss: 0.3061 - accuracy: 0.8734 - val_loss: 0.3645 - val_accuracy: 0.8510
# Epoch 12/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3042 - accuracy: 0.8719 - val_loss: 0.3718 - val_accuracy: 0.8467
# Epoch 13/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3034 - accuracy: 0.8719 - val_loss: 0.3727 - val_accuracy: 0.8498
# Epoch 14/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3050 - accuracy: 0.8693 - val_loss: 0.3666 - val_accuracy: 0.8510
# Epoch 15/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3054 - accuracy: 0.8702 - val_loss: 0.3664 - val_accuracy: 0.8492
# Epoch 16/200
# 445/453 [============================>.] - ETA: 0s - loss: 0.2999 - accuracy: 0.8716INFO:tensorflow:Assets written to: /content/drive/My Drive/data/MLP204.cv.2.best/assets
# 453/453 [==============================] - 2s 4ms/step - loss: 0.2996 - accuracy: 0.8717 - val_loss: 0.3686 - val_accuracy: 0.8535
# Epoch 17/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3024 - accuracy: 0.8709 - val_loss: 0.3701 - val_accuracy: 0.8498
# Epoch 18/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3008 - accuracy: 0.8726 - val_loss: 0.3691 - val_accuracy: 0.8485
# Epoch 19/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2999 - accuracy: 0.8730 - val_loss: 0.3761 - val_accuracy: 0.8498
# Epoch 20/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2980 - accuracy: 0.8748 - val_loss: 0.3734 - val_accuracy: 0.8467
# Epoch 21/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2983 - accuracy: 0.8724 - val_loss: 0.3727 - val_accuracy: 0.8492
# Epoch 22/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2963 - accuracy: 0.8751 - val_loss: 0.3768 - val_accuracy: 0.8535
# Epoch 23/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3022 - accuracy: 0.8716 - val_loss: 0.3944 - val_accuracy: 0.8405
# Epoch 24/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2995 - accuracy: 0.8735 - val_loss: 0.3772 - val_accuracy: 0.8498
# Epoch 25/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2968 - accuracy: 0.8730 - val_loss: 0.3905 - val_accuracy: 0.8436
# Epoch 26/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2998 - accuracy: 0.8708 - val_loss: 0.3715 - val_accuracy: 0.8492
# Epoch 27/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2970 - accuracy: 0.8740 - val_loss: 0.3769 - val_accuracy: 0.8454
# Epoch 28/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.3006 - accuracy: 0.8731 - val_loss: 0.3786 - val_accuracy: 0.8448
# Epoch 29/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2955 - accuracy: 0.8735 - val_loss: 0.3726 - val_accuracy: 0.8492
# Epoch 30/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2981 - accuracy: 0.8719 - val_loss: 0.3687 - val_accuracy: 0.8516
# Epoch 31/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2992 - accuracy: 0.8712 - val_loss: 0.3829 - val_accuracy: 0.8442
# Epoch 32/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2961 - accuracy: 0.8726 - val_loss: 0.3727 - val_accuracy: 0.8504
# Epoch 33/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2963 - accuracy: 0.8763 - val_loss: 0.3793 - val_accuracy: 0.8523
# Epoch 34/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2958 - accuracy: 0.8737 - val_loss: 0.3775 - val_accuracy: 0.8523
# Epoch 35/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2949 - accuracy: 0.8745 - val_loss: 0.3775 - val_accuracy: 0.8510
# Epoch 36/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2955 - accuracy: 0.8743 - val_loss: 0.3736 - val_accuracy: 0.8467
# Epoch 37/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2948 - accuracy: 0.8752 - val_loss: 0.3867 - val_accuracy: 0.8479
# Epoch 38/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2992 - accuracy: 0.8726 - val_loss: 0.3748 - val_accuracy: 0.8529
# Epoch 39/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2940 - accuracy: 0.8746 - val_loss: 0.3809 - val_accuracy: 0.8423
# Epoch 40/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2932 - accuracy: 0.8773 - val_loss: 0.3809 - val_accuracy: 0.8448
# Epoch 41/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2970 - accuracy: 0.8718 - val_loss: 0.3790 - val_accuracy: 0.8510
# Epoch 42/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2952 - accuracy: 0.8739 - val_loss: 0.3722 - val_accuracy: 0.8492
# Epoch 43/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2934 - accuracy: 0.8759 - val_loss: 0.3715 - val_accuracy: 0.8504
# Epoch 44/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2928 - accuracy: 0.8749 - val_loss: 0.3923 - val_accuracy: 0.8392
# Epoch 45/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2953 - accuracy: 0.8762 - val_loss: 0.3712 - val_accuracy: 0.8479
# Epoch 46/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2925 - accuracy: 0.8756 - val_loss: 0.3784 - val_accuracy: 0.8454
# Epoch 47/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2932 - accuracy: 0.8734 - val_loss: 0.3725 - val_accuracy: 0.8498
# Epoch 48/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2916 - accuracy: 0.8773 - val_loss: 0.3691 - val_accuracy: 0.8523
# Epoch 49/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2941 - accuracy: 0.8735 - val_loss: 0.3882 - val_accuracy: 0.8485
# Epoch 50/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2917 - accuracy: 0.8760 - val_loss: 0.3693 - val_accuracy: 0.8516
# Epoch 51/200
# 446/453 [============================>.] - ETA: 0s - loss: 0.2921 - accuracy: 0.8753INFO:tensorflow:Assets written to: /content/drive/My Drive/data/MLP204.cv.2.best/assets
# 453/453 [==============================] - 2s 4ms/step - loss: 0.2917 - accuracy: 0.8757 - val_loss: 0.3825 - val_accuracy: 0.8566
# Epoch 52/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2925 - accuracy: 0.8746 - val_loss: 0.3744 - val_accuracy: 0.8547
# Epoch 53/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2914 - accuracy: 0.8768 - val_loss: 0.3725 - val_accuracy: 0.8547
# Epoch 54/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2907 - accuracy: 0.8759 - val_loss: 0.3887 - val_accuracy: 0.8523
# Epoch 55/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2920 - accuracy: 0.8760 - val_loss: 0.3736 - val_accuracy: 0.8510
# Epoch 56/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2911 - accuracy: 0.8755 - val_loss: 0.3756 - val_accuracy: 0.8516
# Epoch 57/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2916 - accuracy: 0.8747 - val_loss: 0.3715 - val_accuracy: 0.8479
# Epoch 58/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2910 - accuracy: 0.8757 - val_loss: 0.3703 - val_accuracy: 0.8523
# Epoch 59/200
# 452/453 [============================>.] - ETA: 0s - loss: 0.2900 - accuracy: 0.8744INFO:tensorflow:Assets written to: /content/drive/My Drive/data/MLP204.cv.2.best/assets
# 453/453 [==============================] - 2s 5ms/step - loss: 0.2898 - accuracy: 0.8745 - val_loss: 0.3808 - val_accuracy: 0.8572
# Epoch 60/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2903 - accuracy: 0.8757 - val_loss: 0.3687 - val_accuracy: 0.8510
# Epoch 61/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2893 - accuracy: 0.8780 - val_loss: 0.3698 - val_accuracy: 0.8498
# Epoch 62/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2892 - accuracy: 0.8772 - val_loss: 0.3751 - val_accuracy: 0.8560
# Epoch 63/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2915 - accuracy: 0.8748 - val_loss: 0.3701 - val_accuracy: 0.8541
# Epoch 64/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2917 - accuracy: 0.8771 - val_loss: 0.3687 - val_accuracy: 0.8510
# Epoch 65/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2871 - accuracy: 0.8797 - val_loss: 0.3744 - val_accuracy: 0.8492
# Epoch 66/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2904 - accuracy: 0.8766 - val_loss: 0.3696 - val_accuracy: 0.8523
# Epoch 67/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2891 - accuracy: 0.8759 - val_loss: 0.3940 - val_accuracy: 0.8361
# Epoch 68/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2877 - accuracy: 0.8789 - val_loss: 0.3708 - val_accuracy: 0.8492
# Epoch 69/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2879 - accuracy: 0.8766 - val_loss: 0.3870 - val_accuracy: 0.8392
# Epoch 70/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2863 - accuracy: 0.8787 - val_loss: 0.3887 - val_accuracy: 0.8405
# Epoch 71/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2871 - accuracy: 0.8784 - val_loss: 0.3721 - val_accuracy: 0.8510
# Epoch 72/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2869 - accuracy: 0.8793 - val_loss: 0.3751 - val_accuracy: 0.8473
# Epoch 73/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2868 - accuracy: 0.8786 - val_loss: 0.3679 - val_accuracy: 0.8498
# Epoch 74/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2860 - accuracy: 0.8790 - val_loss: 0.3749 - val_accuracy: 0.8461
# Epoch 75/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2845 - accuracy: 0.8823 - val_loss: 0.3834 - val_accuracy: 0.8423
# Epoch 76/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2857 - accuracy: 0.8782 - val_loss: 0.4076 - val_accuracy: 0.8336
# Epoch 77/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2837 - accuracy: 0.8812 - val_loss: 0.3757 - val_accuracy: 0.8504
# Epoch 78/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2839 - accuracy: 0.8788 - val_loss: 0.3693 - val_accuracy: 0.8547
# Epoch 79/200
# 450/453 [============================>.] - ETA: 0s - loss: 0.2816 - accuracy: 0.8808INFO:tensorflow:Assets written to: /content/drive/My Drive/data/MLP204.cv.2.best/assets
# 453/453 [==============================] - 2s 4ms/step - loss: 0.2808 - accuracy: 0.8811 - val_loss: 0.3677 - val_accuracy: 0.8579
# Epoch 80/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2809 - accuracy: 0.8795 - val_loss: 0.3671 - val_accuracy: 0.8566
# Epoch 81/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2823 - accuracy: 0.8819 - val_loss: 0.3708 - val_accuracy: 0.8479
# Epoch 82/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2794 - accuracy: 0.8828 - val_loss: 0.3750 - val_accuracy: 0.8485
# Epoch 83/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2779 - accuracy: 0.8824 - val_loss: 0.3695 - val_accuracy: 0.8492
# Epoch 84/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2780 - accuracy: 0.8824 - val_loss: 0.3773 - val_accuracy: 0.8541
# Epoch 85/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2774 - accuracy: 0.8824 - val_loss: 0.3678 - val_accuracy: 0.8523
# Epoch 86/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2766 - accuracy: 0.8837 - val_loss: 0.3671 - val_accuracy: 0.8523
# Epoch 87/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2763 - accuracy: 0.8844 - val_loss: 0.3720 - val_accuracy: 0.8510
# Epoch 88/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2761 - accuracy: 0.8834 - val_loss: 0.3703 - val_accuracy: 0.8554
# Epoch 89/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2758 - accuracy: 0.8838 - val_loss: 0.3717 - val_accuracy: 0.8529
# Epoch 90/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2731 - accuracy: 0.8854 - val_loss: 0.3672 - val_accuracy: 0.8547
# Epoch 91/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2718 - accuracy: 0.8852 - val_loss: 0.3696 - val_accuracy: 0.8579
# Epoch 92/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2722 - accuracy: 0.8853 - val_loss: 0.3754 - val_accuracy: 0.8535
# Epoch 93/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2729 - accuracy: 0.8851 - val_loss: 0.3743 - val_accuracy: 0.8523
# Epoch 94/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2703 - accuracy: 0.8871 - val_loss: 0.3678 - val_accuracy: 0.8560
# Epoch 95/200
# 452/453 [============================>.] - ETA: 0s - loss: 0.2684 - accuracy: 0.8868INFO:tensorflow:Assets written to: /content/drive/My Drive/data/MLP204.cv.2.best/assets
# 453/453 [==============================] - 2s 4ms/step - loss: 0.2685 - accuracy: 0.8868 - val_loss: 0.3707 - val_accuracy: 0.8585
# Epoch 96/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2670 - accuracy: 0.8878 - val_loss: 0.3695 - val_accuracy: 0.8554
# Epoch 97/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2673 - accuracy: 0.8882 - val_loss: 0.3694 - val_accuracy: 0.8547
# Epoch 98/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2646 - accuracy: 0.8897 - val_loss: 0.3691 - val_accuracy: 0.8529
# Epoch 99/200
# 447/453 [============================>.] - ETA: 0s - loss: 0.2656 - accuracy: 0.8882INFO:tensorflow:Assets written to: /content/drive/My Drive/data/MLP204.cv.2.best/assets
# 453/453 [==============================] - 2s 4ms/step - loss: 0.2652 - accuracy: 0.8881 - val_loss: 0.3802 - val_accuracy: 0.8616
# Epoch 100/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2632 - accuracy: 0.8904 - val_loss: 0.3765 - val_accuracy: 0.8610
# Epoch 101/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2616 - accuracy: 0.8904 - val_loss: 0.3820 - val_accuracy: 0.8510
# Epoch 102/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2604 - accuracy: 0.8906 - val_loss: 0.3649 - val_accuracy: 0.8579
# Epoch 103/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2590 - accuracy: 0.8928 - val_loss: 0.3695 - val_accuracy: 0.8579
# Epoch 104/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2587 - accuracy: 0.8937 - val_loss: 0.3813 - val_accuracy: 0.8473
# Epoch 105/200
# 447/453 [============================>.] - ETA: 0s - loss: 0.2575 - accuracy: 0.8931INFO:tensorflow:Assets written to: /content/drive/My Drive/data/MLP204.cv.2.best/assets
# 453/453 [==============================] - 2s 4ms/step - loss: 0.2574 - accuracy: 0.8930 - val_loss: 0.3637 - val_accuracy: 0.8634
# Epoch 106/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2543 - accuracy: 0.8941 - val_loss: 0.3646 - val_accuracy: 0.8616
# Epoch 107/200
# ...
# Epoch 99/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2834 - accuracy: 0.8794 - val_loss: 0.3580 - val_accuracy: 0.8442
# Epoch 100/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2841 - accuracy: 0.8790 - val_loss: 0.3728 - val_accuracy: 0.8448
# Epoch 101/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2812 - accuracy: 0.8815 - val_loss: 0.3434 - val_accuracy: 0.8566
# Epoch 102/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2832 - accuracy: 0.8816 - val_loss: 0.3387 - val_accuracy: 0.8566
# Epoch 103/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2817 - accuracy: 0.8808 - val_loss: 0.3363 - val_accuracy: 0.8579
# Epoch 104/200
# 442/453 [============================>.] - ETA: 0s - loss: 0.2792 - accuracy: 0.8819INFO:tensorflow:Assets written to: /content/drive/My Drive/data/MLP204.cv.5.best/assets
# 453/453 [==============================] - 2s 4ms/step - loss: 0.2799 - accuracy: 0.8817 - val_loss: 0.3343 - val_accuracy: 0.8603
# Epoch 105/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2779 - accuracy: 0.8846 - val_loss: 0.3359 - val_accuracy: 0.8591
# Epoch 106/200
# 442/453 [============================>.] - ETA: 0s - loss: 0.2798 - accuracy: 0.8831INFO:tensorflow:Assets written to: /content/drive/My Drive/data/MLP204.cv.5.best/assets
# 453/453 [==============================] - 2s 4ms/step - loss: 0.2789 - accuracy: 0.8835 - val_loss: 0.3359 - val_accuracy: 0.8622
# Epoch 107/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2781 - accuracy: 0.8839 - val_loss: 0.3370 - val_accuracy: 0.8610
# Epoch 108/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2770 - accuracy: 0.8835 - val_loss: 0.3350 - val_accuracy: 0.8610
# Epoch 109/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2782 - accuracy: 0.8850 - val_loss: 0.3356 - val_accuracy: 0.8566
# Epoch 110/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2761 - accuracy: 0.8864 - val_loss: 0.3342 - val_accuracy: 0.8597
# Epoch 111/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2748 - accuracy: 0.8842 - val_loss: 0.3377 - val_accuracy: 0.8572
# Epoch 112/200
# 453/453 [==============================] - ETA: 0s - loss: 0.2728 - accuracy: 0.8835INFO:tensorflow:Assets written to: /content/drive/My Drive/data/MLP204.cv.5.best/assets
# 453/453 [==============================] - 2s 4ms/step - loss: 0.2728 - accuracy: 0.8835 - val_loss: 0.3349 - val_accuracy: 0.8641
# Epoch 113/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2728 - accuracy: 0.8873 - val_loss: 0.3305 - val_accuracy: 0.8628
# Epoch 114/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2703 - accuracy: 0.8884 - val_loss: 0.3381 - val_accuracy: 0.8591
# Epoch 115/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2717 - accuracy: 0.8857 - val_loss: 0.3402 - val_accuracy: 0.8579
# Epoch 116/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2690 - accuracy: 0.8884 - val_loss: 0.3312 - val_accuracy: 0.8634
# Epoch 117/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2685 - accuracy: 0.8887 - val_loss: 0.3506 - val_accuracy: 0.8572
# Epoch 118/200
# 442/453 [============================>.] - ETA: 0s - loss: 0.2682 - accuracy: 0.8893INFO:tensorflow:Assets written to: /content/drive/My Drive/data/MLP204.cv.5.best/assets
# 453/453 [==============================] - 2s 4ms/step - loss: 0.2684 - accuracy: 0.8892 - val_loss: 0.3338 - val_accuracy: 0.8647
# Epoch 119/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2661 - accuracy: 0.8890 - val_loss: 0.3333 - val_accuracy: 0.8585
# Epoch 120/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2649 - accuracy: 0.8911 - val_loss: 0.3406 - val_accuracy: 0.8585
# Epoch 121/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2634 - accuracy: 0.8915 - val_loss: 0.3449 - val_accuracy: 0.8579
# Epoch 122/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2618 - accuracy: 0.8904 - val_loss: 0.3349 - val_accuracy: 0.8610
# Epoch 123/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2622 - accuracy: 0.8907 - val_loss: 0.3330 - val_accuracy: 0.8647
# Epoch 124/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2597 - accuracy: 0.8937 - val_loss: 0.3622 - val_accuracy: 0.8579
# Epoch 125/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2599 - accuracy: 0.8938 - val_loss: 0.3379 - val_accuracy: 0.8610
# Epoch 126/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2589 - accuracy: 0.8955 - val_loss: 0.3367 - val_accuracy: 0.8647
# Epoch 127/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2567 - accuracy: 0.8950 - val_loss: 0.3407 - val_accuracy: 0.8572
# Epoch 128/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2590 - accuracy: 0.8929 - val_loss: 0.3330 - val_accuracy: 0.8634
# Epoch 129/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2559 - accuracy: 0.8953 - val_loss: 0.3388 - val_accuracy: 0.8585
# Epoch 130/200
# 442/453 [============================>.] - ETA: 0s - loss: 0.2551 - accuracy: 0.8945INFO:tensorflow:Assets written to: /content/drive/My Drive/data/MLP204.cv.5.best/assets
# 453/453 [==============================] - 2s 4ms/step - loss: 0.2553 - accuracy: 0.8945 - val_loss: 0.3298 - val_accuracy: 0.8653
# Epoch 131/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2544 - accuracy: 0.8966 - val_loss: 0.3401 - val_accuracy: 0.8603
# Epoch 132/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2534 - accuracy: 0.8980 - val_loss: 0.3346 - val_accuracy: 0.8591
# Epoch 133/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2518 - accuracy: 0.8981 - val_loss: 0.3576 - val_accuracy: 0.8541
# Epoch 134/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2532 - accuracy: 0.8944 - val_loss: 0.3458 - val_accuracy: 0.8579
# Epoch 135/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2515 - accuracy: 0.8971 - val_loss: 0.3394 - val_accuracy: 0.8610
# Epoch 136/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2501 - accuracy: 0.8981 - val_loss: 0.3394 - val_accuracy: 0.8597
# Epoch 137/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2493 - accuracy: 0.8983 - val_loss: 0.3403 - val_accuracy: 0.8634
# Epoch 138/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2465 - accuracy: 0.8995 - val_loss: 0.3370 - val_accuracy: 0.8616
# Epoch 139/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2477 - accuracy: 0.8984 - val_loss: 0.3412 - val_accuracy: 0.8566
# Epoch 140/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2458 - accuracy: 0.9000 - val_loss: 0.3323 - val_accuracy: 0.8641
# Epoch 141/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2431 - accuracy: 0.9021 - val_loss: 0.3365 - val_accuracy: 0.8616
# Epoch 142/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2440 - accuracy: 0.9011 - val_loss: 0.3401 - val_accuracy: 0.8585
# Epoch 143/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2451 - accuracy: 0.8999 - val_loss: 0.3576 - val_accuracy: 0.8510
# Epoch 144/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2410 - accuracy: 0.9021 - val_loss: 0.3371 - val_accuracy: 0.8603
# Epoch 145/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2415 - accuracy: 0.9019 - val_loss: 0.3486 - val_accuracy: 0.8585
# Epoch 146/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2384 - accuracy: 0.9027 - val_loss: 0.3475 - val_accuracy: 0.8622
# Epoch 147/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2393 - accuracy: 0.9036 - val_loss: 0.3431 - val_accuracy: 0.8585
# Epoch 148/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2386 - accuracy: 0.9031 - val_loss: 0.3397 - val_accuracy: 0.8603
# Epoch 149/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2393 - accuracy: 0.9047 - val_loss: 0.3431 - val_accuracy: 0.8628
# Epoch 150/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2375 - accuracy: 0.9034 - val_loss: 0.3460 - val_accuracy: 0.8634
# Epoch 151/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2351 - accuracy: 0.9046 - val_loss: 0.3472 - val_accuracy: 0.8535
# Epoch 152/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2343 - accuracy: 0.9057 - val_loss: 0.3384 - val_accuracy: 0.8622
# Epoch 153/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2333 - accuracy: 0.9061 - val_loss: 0.3487 - val_accuracy: 0.8523
# Epoch 154/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2323 - accuracy: 0.9057 - val_loss: 0.3401 - val_accuracy: 0.8597
# Epoch 155/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2294 - accuracy: 0.9074 - val_loss: 0.3440 - val_accuracy: 0.8603
# Epoch 156/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2326 - accuracy: 0.9060 - val_loss: 0.3415 - val_accuracy: 0.8628
# Epoch 157/200
# 441/453 [============================>.] - ETA: 0s - loss: 0.2321 - accuracy: 0.9067INFO:tensorflow:Assets written to: /content/drive/My Drive/data/MLP204.cv.5.best/assets
# 453/453 [==============================] - 2s 4ms/step - loss: 0.2317 - accuracy: 0.9069 - val_loss: 0.3408 - val_accuracy: 0.8672
# Epoch 158/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2282 - accuracy: 0.9091 - val_loss: 0.3577 - val_accuracy: 0.8510
# Epoch 159/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2288 - accuracy: 0.9071 - val_loss: 0.3468 - val_accuracy: 0.8610
# Epoch 160/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2287 - accuracy: 0.9073 - val_loss: 0.3483 - val_accuracy: 0.8585
# Epoch 161/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2278 - accuracy: 0.9087 - val_loss: 0.3524 - val_accuracy: 0.8628
# Epoch 162/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2250 - accuracy: 0.9088 - val_loss: 0.3523 - val_accuracy: 0.8541
# Epoch 163/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2216 - accuracy: 0.9124 - val_loss: 0.3518 - val_accuracy: 0.8597
# Epoch 164/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2232 - accuracy: 0.9091 - val_loss: 0.3437 - val_accuracy: 0.8641
# Epoch 165/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2213 - accuracy: 0.9120 - val_loss: 0.3555 - val_accuracy: 0.8610
# Epoch 166/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2202 - accuracy: 0.9107 - val_loss: 0.3593 - val_accuracy: 0.8579
# Epoch 167/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2233 - accuracy: 0.9101 - val_loss: 0.3653 - val_accuracy: 0.8541
# Epoch 168/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2181 - accuracy: 0.9134 - val_loss: 0.3475 - val_accuracy: 0.8591
# Epoch 169/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2172 - accuracy: 0.9129 - val_loss: 0.3737 - val_accuracy: 0.8516
# Epoch 170/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2163 - accuracy: 0.9126 - val_loss: 0.3674 - val_accuracy: 0.8523
# Epoch 171/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2140 - accuracy: 0.9150 - val_loss: 0.3748 - val_accuracy: 0.8547
# Epoch 172/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2128 - accuracy: 0.9153 - val_loss: 0.3715 - val_accuracy: 0.8616
# Epoch 173/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2143 - accuracy: 0.9148 - val_loss: 0.3851 - val_accuracy: 0.8461
# Epoch 174/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2134 - accuracy: 0.9149 - val_loss: 0.3625 - val_accuracy: 0.8579
# Epoch 175/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2114 - accuracy: 0.9155 - val_loss: 0.3934 - val_accuracy: 0.8461
# Epoch 176/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2113 - accuracy: 0.9169 - val_loss: 0.3675 - val_accuracy: 0.8597
# Epoch 177/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2101 - accuracy: 0.9175 - val_loss: 0.3709 - val_accuracy: 0.8547
# Epoch 178/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2072 - accuracy: 0.9166 - val_loss: 0.3894 - val_accuracy: 0.8535
# Epoch 179/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2078 - accuracy: 0.9187 - val_loss: 0.3703 - val_accuracy: 0.8560
# Epoch 180/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2071 - accuracy: 0.9178 - val_loss: 0.3813 - val_accuracy: 0.8572
# Epoch 181/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2063 - accuracy: 0.9167 - val_loss: 0.3686 - val_accuracy: 0.8597
# Epoch 182/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2039 - accuracy: 0.9188 - val_loss: 0.4053 - val_accuracy: 0.8461
# Epoch 183/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2036 - accuracy: 0.9193 - val_loss: 0.4164 - val_accuracy: 0.8392
# Epoch 184/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2030 - accuracy: 0.9193 - val_loss: 0.3723 - val_accuracy: 0.8585
# Epoch 185/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2030 - accuracy: 0.9202 - val_loss: 0.3977 - val_accuracy: 0.8529
# Epoch 186/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2015 - accuracy: 0.9207 - val_loss: 0.3809 - val_accuracy: 0.8591
# Epoch 187/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.2006 - accuracy: 0.9210 - val_loss: 0.3984 - val_accuracy: 0.8603
# Epoch 188/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.1980 - accuracy: 0.9224 - val_loss: 0.3908 - val_accuracy: 0.8572
# Epoch 189/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.1993 - accuracy: 0.9220 - val_loss: 0.3914 - val_accuracy: 0.8535
# Epoch 190/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.1985 - accuracy: 0.9185 - val_loss: 0.3988 - val_accuracy: 0.8603
# Epoch 191/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.1963 - accuracy: 0.9224 - val_loss: 0.3928 - val_accuracy: 0.8616
# Epoch 192/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.1967 - accuracy: 0.9214 - val_loss: 0.3954 - val_accuracy: 0.8529
# Epoch 193/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.1948 - accuracy: 0.9229 - val_loss: 0.3994 - val_accuracy: 0.8579
# Epoch 194/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.1924 - accuracy: 0.9246 - val_loss: 0.4024 - val_accuracy: 0.8473
# Epoch 195/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.1918 - accuracy: 0.9232 - val_loss: 0.4203 - val_accuracy: 0.8535
# Epoch 196/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.1906 - accuracy: 0.9264 - val_loss: 0.4181 - val_accuracy: 0.8560
# Epoch 197/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.1902 - accuracy: 0.9242 - val_loss: 0.3969 - val_accuracy: 0.8591
# Epoch 198/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.1917 - accuracy: 0.9240 - val_loss: 0.3949 - val_accuracy: 0.8498
# Epoch 199/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.1872 - accuracy: 0.9249 - val_loss: 0.4276 - val_accuracy: 0.8541
# Epoch 200/200
# 453/453 [==============================] - 1s 3ms/step - loss: 0.1858 - accuracy: 0.9267 - val_loss: 0.4527 - val_accuracy: 0.8560
# Fold 5, 200 epochs, 263 sec
# accuracy: 86.72%
#
# 5-way Cross Validation mean 86.79% (+/- 0.47%)
# Done
