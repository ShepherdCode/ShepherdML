# %% [markdown]
# # GRU 239
# Test the RNA length effect.

# %%
NC_FILENAME='ncRNA.gc34.processed.fasta'
PC_FILENAME='pcRNA.gc34.processed.fasta'
DATAPATH=""
try:
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
    NC_FILENAME = DATAPATH+NC_FILENAME
    PC_FILENAME = DATAPATH+PC_FILENAME
except:
    IN_COLAB = False
    DATAPATH="" 

EPOCHS=100  # use 2 for debug, 200 for real
K=3
VOCABULARY_SIZE=4**K+1   # e.g. K=3 => 64 DNA K-mers + 'NNN'
EMBED_DIMEN=16
FILENAME='GRU239'
NEURONS=32
ACT="tanh"
DROP=0.5
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import StratifiedKFold
import tensorflow as tf
from tensorflow import keras
from keras.wrappers.scikit_learn import KerasRegressor
from keras.models import Sequential
from keras.layers import Bidirectional
from keras.layers import GRU
from keras.layers import Dense
from keras.layers import LayerNormalization
import time
dt='float32'
tf.keras.backend.set_floatx(dt)

# %% [markdown]
# ## Build model

# %%
def compile_model(model):
    adam_default_learn_rate = 0.001
    schedule = tf.keras.optimizers.schedules.ExponentialDecay(
        initial_learning_rate = adam_default_learn_rate*10,
        #decay_steps=100000, decay_rate=0.96, staircase=True)
        decay_steps=10000, decay_rate=0.99, staircase=True)
    # learn rate = initial_learning_rate * decay_rate ^ (step / decay_steps)
    alrd = tf.keras.optimizers.Adam(learning_rate=schedule)
    bc=tf.keras.losses.BinaryCrossentropy(from_logits=False)
    print("COMPILE...")
    #model.compile(loss=bc, optimizer=alrd, metrics=["accuracy"])
    model.compile(loss=bc, optimizer="adam", metrics=["accuracy"])
    print("...COMPILED")
    return model

def build_model():
    embed_layer  = keras.layers.Embedding(
        #VOCABULARY_SIZE, EMBED_DIMEN, input_length=1000, input_length=1000, mask_zero=True)
        #input_dim=[None,VOCABULARY_SIZE], output_dim=EMBED_DIMEN, mask_zero=True)
        input_dim=VOCABULARY_SIZE, output_dim=EMBED_DIMEN, mask_zero=True)
    #rnn1_layer = keras.layers.Bidirectional(
    rnn1_layer = keras.layers.GRU(NEURONS, return_sequences=True, 
          input_shape=[1000,EMBED_DIMEN], activation=ACT, dropout=DROP)#)#bi
    #rnn2_layer = keras.layers.Bidirectional(
    rnn2_layer = keras.layers.GRU(NEURONS, return_sequences=False, 
        activation=ACT, dropout=DROP)#)#bi
    dense1_layer = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt)
    #drop1_layer = keras.layers.Dropout(DROP)
    dense2_layer = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt)
    #drop2_layer = keras.layers.Dropout(DROP)
    output_layer = keras.layers.Dense(1, activation="sigmoid", dtype=dt)
    mlp = keras.models.Sequential()
    mlp.add(embed_layer)
    mlp.add(rnn1_layer)
    mlp.add(rnn2_layer)
    mlp.add(dense1_layer)
    #mlp.add(drop1_layer)
    mlp.add(dense2_layer)
    #mlp.add(drop2_layer)
    mlp.add(output_layer)
    mlpc = compile_model(mlp)
    return mlpc

# %% [markdown]
# ## Load and partition sequences

# %%
# Assume file was preprocessed to contain one line per seq.
# Prefer Pandas dataframe but df does not support append.
# For conversion to tensor, must avoid python lists.
def load_fasta(filename,label):
    DEFLINE='>'
    labels=[]
    seqs=[]
    lens=[]
    nums=[]
    num=0
    with open (filename,'r') as infile:
        for line in infile:
            if line[0]!=DEFLINE:
                seq=line.rstrip()
                num += 1   # first seqnum is 1
                seqlen=len(seq)
                nums.append(num)
                labels.append(label)
                seqs.append(seq)
                lens.append(seqlen)
    df1=pd.DataFrame(nums,columns=['seqnum'])
    df2=pd.DataFrame(labels,columns=['class'])
    df3=pd.DataFrame(seqs,columns=['sequence'])
    df4=pd.DataFrame(lens,columns=['seqlen'])
    df=pd.concat((df1,df2,df3,df4),axis=1)
    return df

def separate_X_and_y(data):
    y=   data[['class']].copy()
    X=   data.drop(columns=['class','seqnum','seqlen'])
    return (X,y)

# %% [markdown]
# ## Make K-mers

# %%
def make_kmer_table(K):
    npad='N'*K
    shorter_kmers=['']
    for i in range(K):
        longer_kmers=[]
        for mer in shorter_kmers:
            longer_kmers.append(mer+'A')
            longer_kmers.append(mer+'C')
            longer_kmers.append(mer+'G')
            longer_kmers.append(mer+'T')
        shorter_kmers = longer_kmers
    all_kmers = shorter_kmers
    kmer_dict = {}
    kmer_dict[npad]=0
    value=1
    for mer in all_kmers:
        kmer_dict[mer]=value
        value += 1
    return kmer_dict

KMER_TABLE=make_kmer_table(K)

def strings_to_vectors(data,uniform_len):
    all_seqs=[]
    for seq in data['sequence']:
        i=0
        seqlen=len(seq)
        kmers=[]
        while i < seqlen-K+1 -1:  # stop at minus one for spaced seed
            #kmer=seq[i:i+2]+seq[i+3:i+5]    # SPACED SEED 2/1/2 for K=4
            kmer=seq[i:i+K]  
            i += 1
            value=KMER_TABLE[kmer]
            kmers.append(value)
        pad_val=0
        while i < uniform_len:
            kmers.append(pad_val)
            i += 1
        all_seqs.append(kmers)
    pd2d=pd.DataFrame(all_seqs)
    return pd2d   # return 2D dataframe, uniform dimensions

# %%
def make_kmers(MAXLEN,train_set):
    (X_train_all,y_train_all)=separate_X_and_y(train_set)
    X_train_kmers=strings_to_vectors(X_train_all,MAXLEN)
    # From pandas dataframe to numpy to list to numpy
    num_seqs=len(X_train_kmers)
    tmp_seqs=[]
    for i in range(num_seqs):
        kmer_sequence=X_train_kmers.iloc[i]
        tmp_seqs.append(kmer_sequence)
    X_train_kmers=np.array(tmp_seqs)
    tmp_seqs=None
    labels=y_train_all.to_numpy()
    return (X_train_kmers,labels)

# %%
def make_frequencies(Xin):
    Xout=[]
    VOCABULARY_SIZE= 4**K + 1  # plus one for 'NNN'
    for seq in Xin:
        freqs =[0] * VOCABULARY_SIZE
        total = 0
        for kmerval in seq:
            freqs[kmerval] += 1
            total += 1
        for c in range(VOCABULARY_SIZE):
            freqs[c] = freqs[c]/total
        Xout.append(freqs)
    Xnum = np.asarray(Xout)
    return (Xnum)
def make_slice(data_set,min_len,max_len):
    slice = data_set.query('seqlen <= '+str(max_len)+' & seqlen>= '+str(min_len))
    return slice

# %% [markdown]
# ## Cross validation

# %%
bestname=DATAPATH+FILENAME+".best"
def just_train(X,y): # give me training set
    model=build_model()
    print(model.summary())
    mycallbacks = [keras.callbacks.ModelCheckpoint(
        filepath=bestname, save_best_only=True, 
        monitor='accuracy', mode='max')]   
    print("FIT")
    start_time=time.time()
    history=model.fit(X_train, y_train, # batch_size=10, default=32 works nicely
            epochs=EPOCHS, verbose=1,  # verbose=1 for ascii art, verbose=0 for none
            callbacks=mycallbacks )  # no validation data
    end_time=time.time()
    elapsed_time=(end_time-start_time)                        
    print("Train %d epochs, %d sec"%(EPOCHS,elapsed_time))
    pd.DataFrame(history.history).plot(figsize=(8,5))
    plt.grid(True)
    plt.gca().set_ylim(0,1)
    plt.show()
def just_evaluate(X,y):  # give me validation set
    best_model=keras.models.load_model(bestname)
    scores = best_model.evaluate(X, y, verbose=0)
    print("%s: %.2f%%" % (best_model.metrics_names[1], scores[1]*100))

# %% [markdown]
# ## Train on RNA length-based slice

# %%
#      A    B    C     D     E     F
# 200, 500, 750, 1000, 1500, 3000, 30000 
print("Load data from files.")
nc_seq=load_fasta(NC_FILENAME,0)
pc_seq=load_fasta(PC_FILENAME,1)
train_set=pd.concat((nc_seq,pc_seq),axis=0)
nc_seq=None
pc_seq=None
def get_x_and_y(train_set,minlen,maxlen):
  subset=make_slice(train_set,minlen,maxlen)
  (X_set,y_set)=make_kmers(maxlen,subset)
  print("Shape of X is "+str(X_set.shape))
  L=len(X_set)
  T=int(0.80*L+0.5)
  print("Total %d, Train portion %d"%(L,T))
  X_train=X_set[:T]
  y_train=y_set[:T]
  X_valid=X_set[T:]
  y_valid=y_set[T:]
  return (X_train,y_train,X_valid,y_valid)

MINLEN=750
MAXLEN=1000
(X_train,y_train,X_valid_A,y_valid_A)=get_x_and_y(train_set,200,500)
(X_train,y_train,X_valid_B,y_valid_B)=get_x_and_y(train_set,500,750)
(X_train,y_train,X_valid_C,y_valid_C)=get_x_and_y(train_set,750,1000)
(X_train,y_train,X_valid_D,y_valid_D)=get_x_and_y(train_set,1000,1500)
(X_train,y_train,X_valid_E,y_valid_E)=get_x_and_y(train_set,1500,3000)
(X_train,y_train,X_valid_F,y_valid_F)=get_x_and_y(train_set,3000,30000)
(X_train,y_train,X_valid,y_valid)=get_x_and_y(train_set,MINLEN,MAXLEN)
print("Loaded")
# Out:
# Load data from files.
# Shape of X is (4516, 500)
# Total 4516, Train portion 3613
# Shape of X is (7198, 750)
# Total 7198, Train portion 5758
# Shape of X is (4456, 1000)
# Total 4456, Train portion 3565
# Shape of X is (4580, 1500)
# Total 4580, Train portion 3664
# Shape of X is (7446, 3000)
# Total 7446, Train portion 5957
# Shape of X is (3900, 30000)
# Total 3900, Train portion 3120
# Shape of X is (4456, 1000)
# Total 4456, Train portion 3565
# Loaded

# %%
print ("Train on ",MINLEN,"-",MAXLEN)
just_train(X_train,y_train)
# Out:
# Train on  750 - 1000
# COMPILE...
# ...COMPILED
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, None, 16)          1040
# _________________________________________________________________
# gru_2 (GRU)                  (None, None, 32)          4800
# _________________________________________________________________
# gru_3 (GRU)                  (None, 32)                6336
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 14,321
# Trainable params: 14,321
# Non-trainable params: 0
# _________________________________________________________________
# None
# FIT
# Epoch 1/100
# 112/112 [==============================] - ETA: 0s - loss: 0.6854 - accuracy: 0.5501INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU239.best/assets
# 112/112 [==============================] - 28s 250ms/step - loss: 0.6854 - accuracy: 0.5501
# Epoch 2/100
# 112/112 [==============================] - ETA: 0s - loss: 0.6649 - accuracy: 0.6042INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU239.best/assets
# 112/112 [==============================] - 28s 250ms/step - loss: 0.6649 - accuracy: 0.6042
# Epoch 3/100
# 112/112 [==============================] - ETA: 0s - loss: 0.6526 - accuracy: 0.6185INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU239.best/assets
# 112/112 [==============================] - 30s 264ms/step - loss: 0.6526 - accuracy: 0.6185
# Epoch 4/100
# 112/112 [==============================] - ETA: 0s - loss: 0.6547 - accuracy: 0.6292INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU239.best/assets
# 112/112 [==============================] - 29s 260ms/step - loss: 0.6547 - accuracy: 0.6292
# Epoch 5/100
# 112/112 [==============================] - 8s 72ms/step - loss: 0.6948 - accuracy: 0.5206
# Epoch 6/100
# 112/112 [==============================] - 8s 72ms/step - loss: 0.6902 - accuracy: 0.5450
# Epoch 7/100
# 112/112 [==============================] - 8s 72ms/step - loss: 0.6900 - accuracy: 0.5442
# Epoch 8/100
# 112/112 [==============================] - 8s 71ms/step - loss: 0.6896 - accuracy: 0.5459
# Epoch 9/100
# 112/112 [==============================] - 8s 74ms/step - loss: 0.6775 - accuracy: 0.5661
# Epoch 10/100
# 112/112 [==============================] - 8s 72ms/step - loss: 0.6450 - accuracy: 0.6281
# Epoch 11/100
# 112/112 [==============================] - ETA: 0s - loss: 0.6443 - accuracy: 0.6466INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU239.best/assets
# 112/112 [==============================] - 28s 249ms/step - loss: 0.6443 - accuracy: 0.6466
# Epoch 12/100
# 112/112 [==============================] - 8s 73ms/step - loss: 0.6741 - accuracy: 0.5888
# Epoch 13/100
# 112/112 [==============================] - 8s 74ms/step - loss: 0.6541 - accuracy: 0.6143
# Epoch 14/100
# 112/112 [==============================] - ETA: 0s - loss: 0.6440 - accuracy: 0.6485INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU239.best/assets
# 112/112 [==============================] - 30s 264ms/step - loss: 0.6440 - accuracy: 0.6485
# Epoch 15/100
# 112/112 [==============================] - ETA: 0s - loss: 0.6296 - accuracy: 0.6628INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU239.best/assets
# 112/112 [==============================] - 29s 258ms/step - loss: 0.6296 - accuracy: 0.6628
# Epoch 16/100
# 112/112 [==============================] - 8s 70ms/step - loss: 0.6739 - accuracy: 0.5857
# Epoch 17/100
# 112/112 [==============================] - 8s 70ms/step - loss: 0.6832 - accuracy: 0.5697
# Epoch 18/100
# 112/112 [==============================] - 8s 72ms/step - loss: 0.6938 - accuracy: 0.5374
# Epoch 19/100
# 112/112 [==============================] - 8s 73ms/step - loss: 0.6893 - accuracy: 0.5386
# Epoch 20/100
# 112/112 [==============================] - 8s 72ms/step - loss: 0.6886 - accuracy: 0.5461
# Epoch 21/100
# 112/112 [==============================] - 8s 73ms/step - loss: 0.6873 - accuracy: 0.5400
# Epoch 22/100
# 112/112 [==============================] - 8s 74ms/step - loss: 0.6907 - accuracy: 0.5386
# Epoch 23/100
# 112/112 [==============================] - 8s 72ms/step - loss: 0.6879 - accuracy: 0.5467
# Epoch 24/100
# 112/112 [==============================] - 8s 71ms/step - loss: 0.6836 - accuracy: 0.5568
# Epoch 25/100
# 112/112 [==============================] - 8s 72ms/step - loss: 0.6721 - accuracy: 0.5930
# Epoch 26/100
# 112/112 [==============================] - 8s 73ms/step - loss: 0.6627 - accuracy: 0.6048
# Epoch 27/100
# 112/112 [==============================] - 8s 74ms/step - loss: 0.6419 - accuracy: 0.6426
# Epoch 28/100
# 112/112 [==============================] - 8s 73ms/step - loss: 0.6528 - accuracy: 0.6412
# Epoch 29/100
# 112/112 [==============================] - 8s 74ms/step - loss: 0.6391 - accuracy: 0.6502
# Epoch 30/100
# 112/112 [==============================] - 8s 73ms/step - loss: 0.6395 - accuracy: 0.6471
# Epoch 31/100
# 112/112 [==============================] - 8s 73ms/step - loss: 0.6323 - accuracy: 0.6558
# Epoch 32/100
# 112/112 [==============================] - 8s 74ms/step - loss: 0.6396 - accuracy: 0.6513
# Epoch 33/100
# 112/112 [==============================] - 8s 73ms/step - loss: 0.6410 - accuracy: 0.6376
# Epoch 34/100
# 112/112 [==============================] - 8s 72ms/step - loss: 0.6364 - accuracy: 0.6418
# Epoch 35/100
# 112/112 [==============================] - 8s 74ms/step - loss: 0.6369 - accuracy: 0.6457
# Epoch 36/100
# 112/112 [==============================] - 8s 72ms/step - loss: 0.6320 - accuracy: 0.6516
# Epoch 37/100
# 112/112 [==============================] - 8s 71ms/step - loss: 0.6276 - accuracy: 0.6561
# Epoch 38/100
# 112/112 [==============================] - ETA: 0s - loss: 0.6094 - accuracy: 0.6881INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU239.best/assets
# 112/112 [==============================] - 29s 260ms/step - loss: 0.6094 - accuracy: 0.6881
# Epoch 39/100
# 112/112 [==============================] - ETA: 0s - loss: 0.5908 - accuracy: 0.6940INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU239.best/assets
# 112/112 [==============================] - 29s 261ms/step - loss: 0.5908 - accuracy: 0.6940
# Epoch 40/100
# 112/112 [==============================] - ETA: 0s - loss: 0.5731 - accuracy: 0.7178INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU239.best/assets
# 112/112 [==============================] - 28s 251ms/step - loss: 0.5731 - accuracy: 0.7178
# Epoch 41/100
# 112/112 [==============================] - ETA: 0s - loss: 0.5345 - accuracy: 0.7374INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU239.best/assets
# 112/112 [==============================] - 30s 264ms/step - loss: 0.5345 - accuracy: 0.7374
# Epoch 42/100
# 112/112 [==============================] - ETA: 0s - loss: 0.5138 - accuracy: 0.7467INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU239.best/assets
# 112/112 [==============================] - 29s 257ms/step - loss: 0.5138 - accuracy: 0.7467
# Epoch 43/100
# 112/112 [==============================] - ETA: 0s - loss: 0.5109 - accuracy: 0.7481INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU239.best/assets
# 112/112 [==============================] - 29s 259ms/step - loss: 0.5109 - accuracy: 0.7481
# Epoch 44/100
# 112/112 [==============================] - ETA: 0s - loss: 0.4920 - accuracy: 0.7705INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU239.best/assets
# 112/112 [==============================] - 28s 251ms/step - loss: 0.4920 - accuracy: 0.7705
# Epoch 45/100
# 112/112 [==============================] - ETA: 0s - loss: 0.4877 - accuracy: 0.7722INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU239.best/assets
# 112/112 [==============================] - 30s 268ms/step - loss: 0.4877 - accuracy: 0.7722
# Epoch 46/100
# 112/112 [==============================] - ETA: 0s - loss: 0.4660 - accuracy: 0.7750INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU239.best/assets
# 112/112 [==============================] - 29s 262ms/step - loss: 0.4660 - accuracy: 0.7750
# Epoch 47/100
# 112/112 [==============================] - ETA: 0s - loss: 0.4699 - accuracy: 0.7826INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU239.best/assets
# 112/112 [==============================] - 28s 250ms/step - loss: 0.4699 - accuracy: 0.7826
# Epoch 48/100
# 112/112 [==============================] - ETA: 0s - loss: 0.4648 - accuracy: 0.7849INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU239.best/assets
# 112/112 [==============================] - 29s 262ms/step - loss: 0.4648 - accuracy: 0.7849
# Epoch 49/100
# 112/112 [==============================] - 8s 73ms/step - loss: 0.4636 - accuracy: 0.7798
# Epoch 50/100
# 112/112 [==============================] - ETA: 0s - loss: 0.4557 - accuracy: 0.7888INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU239.best/assets
# 112/112 [==============================] - 29s 259ms/step - loss: 0.4557 - accuracy: 0.7888
# Epoch 51/100
# 112/112 [==============================] - ETA: 0s - loss: 0.4439 - accuracy: 0.7905INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU239.best/assets
# 112/112 [==============================] - 29s 257ms/step - loss: 0.4439 - accuracy: 0.7905
# Epoch 52/100
# 112/112 [==============================] - ETA: 0s - loss: 0.4476 - accuracy: 0.7916INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU239.best/assets
# 112/112 [==============================] - 29s 261ms/step - loss: 0.4476 - accuracy: 0.7916
# Epoch 53/100
# 112/112 [==============================] - 8s 73ms/step - loss: 0.4400 - accuracy: 0.7913
# Epoch 54/100
# 112/112 [==============================] - ETA: 0s - loss: 0.4434 - accuracy: 0.7938INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU239.best/assets
# 112/112 [==============================] - 28s 252ms/step - loss: 0.4434 - accuracy: 0.7938
# Epoch 55/100
# 112/112 [==============================] - 8s 72ms/step - loss: 0.4547 - accuracy: 0.7877
# Epoch 56/100
# 112/112 [==============================] - 8s 72ms/step - loss: 0.4401 - accuracy: 0.7919
# Epoch 57/100
# 112/112 [==============================] - ETA: 0s - loss: 0.4496 - accuracy: 0.7961INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU239.best/assets
# 112/112 [==============================] - 30s 265ms/step - loss: 0.4496 - accuracy: 0.7961
# Epoch 58/100
# 112/112 [==============================] - 8s 74ms/step - loss: 0.4528 - accuracy: 0.7899
# Epoch 59/100
# 112/112 [==============================] - 8s 73ms/step - loss: 0.4451 - accuracy: 0.7913
# Epoch 60/100
# 112/112 [==============================] - 8s 72ms/step - loss: 0.4435 - accuracy: 0.7961
# Epoch 61/100
# 112/112 [==============================] - ETA: 0s - loss: 0.4272 - accuracy: 0.8011INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU239.best/assets
# 112/112 [==============================] - 29s 261ms/step - loss: 0.4272 - accuracy: 0.8011
# Epoch 62/100
# 112/112 [==============================] - 8s 72ms/step - loss: 0.4373 - accuracy: 0.7935
# Epoch 63/100
# 112/112 [==============================] - ETA: 0s - loss: 0.4288 - accuracy: 0.8022INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU239.best/assets
# 112/112 [==============================] - 28s 249ms/step - loss: 0.4288 - accuracy: 0.8022
# Epoch 64/100
# 112/112 [==============================] - ETA: 0s - loss: 0.4251 - accuracy: 0.8025INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU239.best/assets
# 112/112 [==============================] - 29s 263ms/step - loss: 0.4251 - accuracy: 0.8025
# Epoch 65/100
# 112/112 [==============================] - ETA: 0s - loss: 0.4310 - accuracy: 0.8050INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU239.best/assets
# 112/112 [==============================] - 29s 260ms/step - loss: 0.4310 - accuracy: 0.8050
# Epoch 66/100
# 112/112 [==============================] - 8s 73ms/step - loss: 0.4257 - accuracy: 0.8050
# Epoch 67/100
# 112/112 [==============================] - ETA: 0s - loss: 0.4239 - accuracy: 0.8073INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU239.best/assets
# 112/112 [==============================] - 30s 267ms/step - loss: 0.4239 - accuracy: 0.8073
# Epoch 68/100
# 112/112 [==============================] - 8s 73ms/step - loss: 0.4235 - accuracy: 0.8025
# Epoch 69/100
# 112/112 [==============================] - ETA: 0s - loss: 0.4185 - accuracy: 0.8098INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU239.best/assets
# 112/112 [==============================] - 29s 261ms/step - loss: 0.4185 - accuracy: 0.8098
# Epoch 70/100
# 112/112 [==============================] - ETA: 0s - loss: 0.4161 - accuracy: 0.8129INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU239.best/assets
# 112/112 [==============================] - 28s 252ms/step - loss: 0.4161 - accuracy: 0.8129
# Epoch 71/100
# 112/112 [==============================] - 8s 71ms/step - loss: 0.4156 - accuracy: 0.8087
# Epoch 72/100
# 112/112 [==============================] - ETA: 0s - loss: 0.4144 - accuracy: 0.8143INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU239.best/assets
# 112/112 [==============================] - 30s 265ms/step - loss: 0.4144 - accuracy: 0.8143
# Epoch 73/100
# 112/112 [==============================] - 8s 74ms/step - loss: 0.4162 - accuracy: 0.8079
# Epoch 74/100
# 112/112 [==============================] - 8s 74ms/step - loss: 0.4077 - accuracy: 0.8135
# Epoch 75/100
# 112/112 [==============================] - 8s 72ms/step - loss: 0.4165 - accuracy: 0.8090
# Epoch 76/100
# 112/112 [==============================] - 8s 73ms/step - loss: 0.4126 - accuracy: 0.8143
# Epoch 77/100
# 112/112 [==============================] - ETA: 0s - loss: 0.4082 - accuracy: 0.8163INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU239.best/assets
# 112/112 [==============================] - 29s 261ms/step - loss: 0.4082 - accuracy: 0.8163
# Epoch 78/100
# 112/112 [==============================] - 8s 73ms/step - loss: 0.4113 - accuracy: 0.8121
# Epoch 79/100
# 112/112 [==============================] - ETA: 0s - loss: 0.3993 - accuracy: 0.8208INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU239.best/assets
# 112/112 [==============================] - 28s 251ms/step - loss: 0.3993 - accuracy: 0.8208
# Epoch 80/100
# 112/112 [==============================] - 8s 70ms/step - loss: 0.4094 - accuracy: 0.8154
# Epoch 81/100
# 112/112 [==============================] - 8s 72ms/step - loss: 0.4102 - accuracy: 0.8174
# Epoch 82/100
# 112/112 [==============================] - 8s 73ms/step - loss: 0.4113 - accuracy: 0.8129
# Epoch 83/100
# 112/112 [==============================] - 8s 73ms/step - loss: 0.4017 - accuracy: 0.8182
# Epoch 84/100
# 112/112 [==============================] - 8s 74ms/step - loss: 0.4082 - accuracy: 0.8165
# Epoch 85/100
# 112/112 [==============================] - 8s 71ms/step - loss: 0.4038 - accuracy: 0.8188
# Epoch 86/100
# 112/112 [==============================] - 8s 72ms/step - loss: 0.4049 - accuracy: 0.8165
# Epoch 87/100
# 112/112 [==============================] - 8s 75ms/step - loss: 0.4043 - accuracy: 0.8199
# Epoch 88/100
# 112/112 [==============================] - ETA: 0s - loss: 0.4011 - accuracy: 0.8213INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU239.best/assets
# 112/112 [==============================] - 29s 263ms/step - loss: 0.4011 - accuracy: 0.8213
# Epoch 89/100
# 112/112 [==============================] - 8s 72ms/step - loss: 0.4000 - accuracy: 0.8199
# Epoch 90/100
# 112/112 [==============================] - ETA: 0s - loss: 0.3938 - accuracy: 0.8269INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU239.best/assets
# 112/112 [==============================] - 29s 258ms/step - loss: 0.3938 - accuracy: 0.8269
# Epoch 91/100
# 112/112 [==============================] - 8s 71ms/step - loss: 0.3962 - accuracy: 0.8230
# Epoch 92/100
# 112/112 [==============================] - 8s 73ms/step - loss: 0.3996 - accuracy: 0.8171
# Epoch 93/100
# 112/112 [==============================] - 8s 72ms/step - loss: 0.3994 - accuracy: 0.8118
# Epoch 94/100
# 112/112 [==============================] - 8s 73ms/step - loss: 0.4043 - accuracy: 0.8191
# Epoch 95/100
# 112/112 [==============================] - ETA: 0s - loss: 0.3864 - accuracy: 0.8317INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU239.best/assets
# 112/112 [==============================] - 29s 261ms/step - loss: 0.3864 - accuracy: 0.8317
# Epoch 96/100
# 112/112 [==============================] - 8s 74ms/step - loss: 0.3839 - accuracy: 0.8295
# Epoch 97/100
# 112/112 [==============================] - 8s 72ms/step - loss: 0.3877 - accuracy: 0.8266
# Epoch 98/100
# 112/112 [==============================] - 8s 72ms/step - loss: 0.3797 - accuracy: 0.8314
# Epoch 99/100
# 112/112 [==============================] - 8s 73ms/step - loss: 0.3898 - accuracy: 0.8295
# Epoch 100/100
# 112/112 [==============================] - 8s 73ms/step - loss: 0.3866 - accuracy: 0.8269
# Train 100 epochs, 1579 sec

# %%
print ("Evaluate on A")
just_evaluate(X_valid_A,y_valid_A) 
print ("Evaluate on B")
just_evaluate(X_valid_B,y_valid_B)  
print ("Evaluate on C")
just_evaluate(X_valid_C,y_valid_C)  
print ("Evaluate on D")
just_evaluate(X_valid_D,y_valid_D)  
print ("Evaluate on E")
just_evaluate(X_valid_E,y_valid_E)  
print ("Evaluate on F")
just_evaluate(X_valid_F,y_valid_F)  

print ("Done")
# Out:
# Evaluate on A
# accuracy: 72.31%
# Evaluate on B
# accuracy: 78.19%
# Evaluate on C
# accuracy: 82.49%
# Evaluate on D
# accuracy: 77.84%
# Evaluate on E
# accuracy: 69.71%
# Evaluate on F
# accuracy: 41.28%
# Done
