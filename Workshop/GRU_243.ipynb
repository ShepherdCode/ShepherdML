# %% [markdown]
# # GRU 243
# Test the RNA length effect.

# %%
NC_FILENAME='ncRNA.gc34.processed.fasta'
PC_FILENAME='pcRNA.gc34.processed.fasta'
DATAPATH=""
try:
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
    NC_FILENAME = DATAPATH+NC_FILENAME
    PC_FILENAME = DATAPATH+PC_FILENAME
except:
    IN_COLAB = False
    DATAPATH="" 

EPOCHS=100  # use 2 for debug, 200 for real
K=3
VOCABULARY_SIZE=4**K+1   # e.g. K=3 => 64 DNA K-mers + 'NNN'
EMBED_DIMEN=16
FILENAME='GRU243'
NEURONS=16
ACT="tanh"
DROP=0.5
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import StratifiedKFold
import tensorflow as tf
from tensorflow import keras
from keras.wrappers.scikit_learn import KerasRegressor
from keras.models import Sequential
from keras.layers import Bidirectional
from keras.layers import GRU
from keras.layers import Dense
from keras.layers import LayerNormalization
import time
dt='float32'
tf.keras.backend.set_floatx(dt)

# %% [markdown]
# ## Build model

# %%
def compile_model(model):
    adam_default_learn_rate = 0.001
    schedule = tf.keras.optimizers.schedules.ExponentialDecay(
        initial_learning_rate = adam_default_learn_rate*10,
        #decay_steps=100000, decay_rate=0.96, staircase=True)
        decay_steps=10000, decay_rate=0.99, staircase=True)
    # learn rate = initial_learning_rate * decay_rate ^ (step / decay_steps)
    alrd = tf.keras.optimizers.Adam(learning_rate=schedule)
    bc=tf.keras.losses.BinaryCrossentropy(from_logits=False)
    print("COMPILE...")
    #model.compile(loss=bc, optimizer=alrd, metrics=["accuracy"])
    model.compile(loss=bc, optimizer="adam", metrics=["accuracy"])
    print("...COMPILED")
    return model

def build_model():
    embed_layer  = keras.layers.Embedding(
        #VOCABULARY_SIZE, EMBED_DIMEN, input_length=1000, input_length=1000, mask_zero=True)
        #input_dim=[None,VOCABULARY_SIZE], output_dim=EMBED_DIMEN, mask_zero=True)
        input_dim=VOCABULARY_SIZE, output_dim=EMBED_DIMEN, mask_zero=True)
    #rnn1_layer = keras.layers.Bidirectional(
    rnn1_layer = keras.layers.GRU(NEURONS, return_sequences=False,  #   True, 
          input_shape=[1000,EMBED_DIMEN], activation=ACT, dropout=DROP)#)#bi
    #rnn2_layer = keras.layers.Bidirectional(
    rnn2_layer = keras.layers.GRU(NEURONS, return_sequences=False, 
        activation=ACT, dropout=DROP)#)#bi
    dense1_layer = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt)
    drop1_layer = keras.layers.Dropout(DROP)
    #dense2_layer = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt)
    #drop2_layer = keras.layers.Dropout(DROP)
    output_layer = keras.layers.Dense(1, activation="sigmoid", dtype=dt)
    mlp = keras.models.Sequential()
    mlp.add(embed_layer)
    mlp.add(rnn1_layer)
    #mlp.add(rnn2_layer)
    mlp.add(dense1_layer)
    mlp.add(drop1_layer)
    #mlp.add(dense2_layer)
    #mlp.add(drop2_layer)
    mlp.add(output_layer)
    mlpc = compile_model(mlp)
    return mlpc

# %% [markdown]
# ## Load and partition sequences

# %%
# Assume file was preprocessed to contain one line per seq.
# Prefer Pandas dataframe but df does not support append.
# For conversion to tensor, must avoid python lists.
def load_fasta(filename,label):
    DEFLINE='>'
    labels=[]
    seqs=[]
    lens=[]
    nums=[]
    num=0
    with open (filename,'r') as infile:
        for line in infile:
            if line[0]!=DEFLINE:
                seq=line.rstrip()
                num += 1   # first seqnum is 1
                seqlen=len(seq)
                nums.append(num)
                labels.append(label)
                seqs.append(seq)
                lens.append(seqlen)
    df1=pd.DataFrame(nums,columns=['seqnum'])
    df2=pd.DataFrame(labels,columns=['class'])
    df3=pd.DataFrame(seqs,columns=['sequence'])
    df4=pd.DataFrame(lens,columns=['seqlen'])
    df=pd.concat((df1,df2,df3,df4),axis=1)
    return df

def separate_X_and_y(data):
    y=   data[['class']].copy()
    X=   data.drop(columns=['class','seqnum','seqlen'])
    return (X,y)

# %% [markdown]
# ## Make K-mers

# %%
def make_kmer_table(K):
    npad='N'*K
    shorter_kmers=['']
    for i in range(K):
        longer_kmers=[]
        for mer in shorter_kmers:
            longer_kmers.append(mer+'A')
            longer_kmers.append(mer+'C')
            longer_kmers.append(mer+'G')
            longer_kmers.append(mer+'T')
        shorter_kmers = longer_kmers
    all_kmers = shorter_kmers
    kmer_dict = {}
    kmer_dict[npad]=0
    value=1
    for mer in all_kmers:
        kmer_dict[mer]=value
        value += 1
    return kmer_dict

KMER_TABLE=make_kmer_table(K)

def strings_to_vectors(data,uniform_len):
    all_seqs=[]
    for seq in data['sequence']:
        i=0
        seqlen=len(seq)
        kmers=[]
        while i < seqlen-K+1 -1:  # stop at minus one for spaced seed
            #kmer=seq[i:i+2]+seq[i+3:i+5]    # SPACED SEED 2/1/2 for K=4
            kmer=seq[i:i+K]  
            i += 1
            value=KMER_TABLE[kmer]
            kmers.append(value)
        pad_val=0
        while i < uniform_len:
            kmers.append(pad_val)
            i += 1
        all_seqs.append(kmers)
    pd2d=pd.DataFrame(all_seqs)
    return pd2d   # return 2D dataframe, uniform dimensions

# %%
def make_kmers(MAXLEN,train_set):
    (X_train_all,y_train_all)=separate_X_and_y(train_set)
    X_train_kmers=strings_to_vectors(X_train_all,MAXLEN)
    # From pandas dataframe to numpy to list to numpy
    num_seqs=len(X_train_kmers)
    tmp_seqs=[]
    for i in range(num_seqs):
        kmer_sequence=X_train_kmers.iloc[i]
        tmp_seqs.append(kmer_sequence)
    X_train_kmers=np.array(tmp_seqs)
    tmp_seqs=None
    labels=y_train_all.to_numpy()
    return (X_train_kmers,labels)

# %%
def make_frequencies(Xin):
    Xout=[]
    VOCABULARY_SIZE= 4**K + 1  # plus one for 'NNN'
    for seq in Xin:
        freqs =[0] * VOCABULARY_SIZE
        total = 0
        for kmerval in seq:
            freqs[kmerval] += 1
            total += 1
        for c in range(VOCABULARY_SIZE):
            freqs[c] = freqs[c]/total
        Xout.append(freqs)
    Xnum = np.asarray(Xout)
    return (Xnum)
def make_slice(data_set,min_len,max_len):
    slice = data_set.query('seqlen < '+str(max_len)+' & seqlen>= '+str(min_len))
    return slice

# %% [markdown]
# ## Cross validation

# %%
bestname=DATAPATH+FILENAME+".best"
def just_train(X,y): # give me training set
    model=build_model()
    print(model.summary())
    mycallbacks = [keras.callbacks.ModelCheckpoint(
        filepath=bestname, save_best_only=True, 
        monitor='accuracy', mode='max')]   
    print("FIT")
    start_time=time.time()
    history=model.fit(X_train, y_train, # batch_size=10, default=32 works nicely
            epochs=EPOCHS, verbose=1,  # verbose=1 for ascii art, verbose=0 for none
            callbacks=mycallbacks )  # no validation data
    end_time=time.time()
    elapsed_time=(end_time-start_time)                        
    print("Train %d epochs, %d sec"%(EPOCHS,elapsed_time))
    pd.DataFrame(history.history).plot(figsize=(8,5))
    plt.grid(True)
    plt.gca().set_ylim(0,1)
    plt.show()
def just_evaluate(X,y):  # give me validation set
    best_model=keras.models.load_model(bestname)
    scores = best_model.evaluate(X, y, verbose=0)
    print("%s: %.2f%%" % (best_model.metrics_names[1], scores[1]*100))

# %% [markdown]
# ## Train on RNA length-based slice

# %%
#      A    B    C     D     E     F
# 200, 500, 750, 1000, 1500, 3000, 30000 
print("Load data from files.")
nc_seq=load_fasta(NC_FILENAME,0)
pc_seq=load_fasta(PC_FILENAME,1)
together=pd.concat((nc_seq,pc_seq),axis=0)
train_set=together.sample(frac=1)   # shuffle
together=None
nc_seq=None
pc_seq=None
def get_x_and_y(train_set,minlen,maxlen):
  subset=make_slice(train_set,minlen,maxlen)
  (X_set,y_set)=make_kmers(maxlen,subset)
  print("Shape of X is "+str(X_set.shape))
  L=len(X_set)
  T=int(0.80*L+0.5)
  print("Total %d, Train portion %d"%(L,T))
  X_train=X_set[:T]
  y_train=y_set[:T]
  X_valid=X_set[T:]
  y_valid=y_set[T:]
  return (X_train,y_train,X_valid,y_valid)

MINLEN=1300
MAXLEN=1900
(X_train,y_train,X_valid,y_valid)=get_x_and_y(train_set,MINLEN,MAXLEN)
print("Loaded")
# Out:
# Load data from files.
# Shape of X is (4421, 1900)
# Total 4421, Train portion 3537
# Loaded

# %%
print ("Train on ",MINLEN,"-",MAXLEN)
just_train(X_train,y_train)
# Out:
# Train on  1300 - 1900
# COMPILE...
# ...COMPILED
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, None, 16)          1040
# _________________________________________________________________
# gru_6 (GRU)                  (None, 16)                1632
# _________________________________________________________________
# dense_6 (Dense)              (None, 16)                272
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 2,961
# Trainable params: 2,961
# Non-trainable params: 0
# _________________________________________________________________
# None
# FIT
# Epoch 1/100
# 111/111 [==============================] - ETA: 0s - loss: 0.6772 - accuracy: 0.5991INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 111/111 [==============================] - 15s 133ms/step - loss: 0.6772 - accuracy: 0.5991
# Epoch 2/100
# 111/111 [==============================] - ETA: 0s - loss: 0.6700 - accuracy: 0.6019INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 111/111 [==============================] - 15s 135ms/step - loss: 0.6700 - accuracy: 0.6019
# Epoch 3/100
# 111/111 [==============================] - ETA: 0s - loss: 0.6632 - accuracy: 0.6096INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 111/111 [==============================] - 17s 151ms/step - loss: 0.6632 - accuracy: 0.6096
# Epoch 4/100
# 111/111 [==============================] - ETA: 0s - loss: 0.6605 - accuracy: 0.6135INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 111/111 [==============================] - 15s 133ms/step - loss: 0.6605 - accuracy: 0.6135
# Epoch 5/100
# 111/111 [==============================] - 7s 63ms/step - loss: 0.6604 - accuracy: 0.6110
# Epoch 6/100
# 111/111 [==============================] - ETA: 0s - loss: 0.6597 - accuracy: 0.6178INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 111/111 [==============================] - 15s 132ms/step - loss: 0.6597 - accuracy: 0.6178
# Epoch 7/100
# 111/111 [==============================] - 7s 63ms/step - loss: 0.6582 - accuracy: 0.6172
# Epoch 8/100
# 111/111 [==============================] - 7s 63ms/step - loss: 0.6539 - accuracy: 0.6169
# Epoch 9/100
# 111/111 [==============================] - 7s 63ms/step - loss: 0.6536 - accuracy: 0.6175
# Epoch 10/100
# 111/111 [==============================] - 7s 63ms/step - loss: 0.6524 - accuracy: 0.6172
# Epoch 11/100
# 111/111 [==============================] - 7s 64ms/step - loss: 0.6526 - accuracy: 0.6146
# Epoch 12/100
# 111/111 [==============================] - ETA: 0s - loss: 0.6508 - accuracy: 0.6180INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 111/111 [==============================] - 15s 133ms/step - loss: 0.6508 - accuracy: 0.6180
# Epoch 13/100
# 111/111 [==============================] - 7s 65ms/step - loss: 0.6494 - accuracy: 0.6163
# Epoch 14/100
# 111/111 [==============================] - ETA: 0s - loss: 0.6500 - accuracy: 0.6192INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 111/111 [==============================] - 17s 153ms/step - loss: 0.6500 - accuracy: 0.6192
# Epoch 15/100
# 111/111 [==============================] - ETA: 0s - loss: 0.6390 - accuracy: 0.6330INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 111/111 [==============================] - 15s 133ms/step - loss: 0.6390 - accuracy: 0.6330
# Epoch 16/100
# 111/111 [==============================] - 7s 63ms/step - loss: 0.6471 - accuracy: 0.6180
# Epoch 17/100
# 111/111 [==============================] - 7s 64ms/step - loss: 0.6477 - accuracy: 0.6217
# Epoch 18/100
# 111/111 [==============================] - 7s 64ms/step - loss: 0.6448 - accuracy: 0.6223
# Epoch 19/100
# 111/111 [==============================] - 7s 64ms/step - loss: 0.6459 - accuracy: 0.6149
# Epoch 20/100
# 111/111 [==============================] - 7s 64ms/step - loss: 0.6426 - accuracy: 0.6296
# Epoch 21/100
# 111/111 [==============================] - 7s 64ms/step - loss: 0.6417 - accuracy: 0.6240
# Epoch 22/100
# 111/111 [==============================] - 7s 65ms/step - loss: 0.6408 - accuracy: 0.6299
# Epoch 23/100
# 111/111 [==============================] - 7s 65ms/step - loss: 0.6338 - accuracy: 0.6262
# Epoch 24/100
# 111/111 [==============================] - 7s 64ms/step - loss: 0.6417 - accuracy: 0.6268
# Epoch 25/100
# 111/111 [==============================] - 7s 64ms/step - loss: 0.6860 - accuracy: 0.5926
# Epoch 26/100
# 111/111 [==============================] - 7s 65ms/step - loss: 0.6643 - accuracy: 0.6039
# Epoch 27/100
# 111/111 [==============================] - 7s 65ms/step - loss: 0.6618 - accuracy: 0.6081
# Epoch 28/100
# 111/111 [==============================] - 7s 64ms/step - loss: 0.6592 - accuracy: 0.6064
# Epoch 29/100
# 111/111 [==============================] - 7s 65ms/step - loss: 0.6579 - accuracy: 0.6124
# Epoch 30/100
# 111/111 [==============================] - 7s 65ms/step - loss: 0.6582 - accuracy: 0.6093
# Epoch 31/100
# 111/111 [==============================] - 7s 66ms/step - loss: 0.6585 - accuracy: 0.6039
# Epoch 32/100
# 111/111 [==============================] - 7s 64ms/step - loss: 0.6585 - accuracy: 0.6059
# Epoch 33/100
# 111/111 [==============================] - 7s 65ms/step - loss: 0.6543 - accuracy: 0.6118
# Epoch 34/100
# 111/111 [==============================] - 7s 66ms/step - loss: 0.6552 - accuracy: 0.6129
# Epoch 35/100
# 111/111 [==============================] - 7s 66ms/step - loss: 0.6525 - accuracy: 0.6138
# Epoch 36/100
# 111/111 [==============================] - 7s 65ms/step - loss: 0.6530 - accuracy: 0.6237
# Epoch 37/100
# 111/111 [==============================] - 7s 64ms/step - loss: 0.6523 - accuracy: 0.6115
# Epoch 38/100
# 111/111 [==============================] - 7s 65ms/step - loss: 0.6507 - accuracy: 0.6163
# Epoch 39/100
# 111/111 [==============================] - 7s 65ms/step - loss: 0.6465 - accuracy: 0.6158
# Epoch 40/100
# 111/111 [==============================] - 7s 65ms/step - loss: 0.6430 - accuracy: 0.6211
# Epoch 41/100
# 111/111 [==============================] - 7s 65ms/step - loss: 0.6368 - accuracy: 0.6257
# Epoch 42/100
# 111/111 [==============================] - ETA: 0s - loss: 0.6317 - accuracy: 0.6347INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 111/111 [==============================] - 15s 133ms/step - loss: 0.6317 - accuracy: 0.6347
# Epoch 43/100
# 111/111 [==============================] - 7s 65ms/step - loss: 0.6604 - accuracy: 0.6019
# Epoch 44/100
# 111/111 [==============================] - 7s 66ms/step - loss: 0.6536 - accuracy: 0.6166
# Epoch 45/100
# 111/111 [==============================] - 7s 65ms/step - loss: 0.6541 - accuracy: 0.6161
# Epoch 46/100
# 111/111 [==============================] - 7s 65ms/step - loss: 0.6473 - accuracy: 0.6288
# Epoch 47/100
# 111/111 [==============================] - 7s 65ms/step - loss: 0.6467 - accuracy: 0.6291
# Epoch 48/100
# 111/111 [==============================] - 7s 65ms/step - loss: 0.6442 - accuracy: 0.6265
# Epoch 49/100
# 111/111 [==============================] - 7s 66ms/step - loss: 0.6441 - accuracy: 0.6141
# Epoch 50/100
# 111/111 [==============================] - 7s 65ms/step - loss: 0.6415 - accuracy: 0.6271
# Epoch 51/100
# 111/111 [==============================] - 7s 65ms/step - loss: 0.6399 - accuracy: 0.6291
# Epoch 52/100
# 111/111 [==============================] - ETA: 0s - loss: 0.6291 - accuracy: 0.6364INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 111/111 [==============================] - 15s 134ms/step - loss: 0.6291 - accuracy: 0.6364
# Epoch 53/100
# 111/111 [==============================] - ETA: 0s - loss: 0.6440 - accuracy: 0.6506INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 111/111 [==============================] - 15s 132ms/step - loss: 0.6440 - accuracy: 0.6506
# Epoch 54/100
# 111/111 [==============================] - 7s 66ms/step - loss: 0.6689 - accuracy: 0.5957
# Epoch 55/100
# 111/111 [==============================] - 7s 66ms/step - loss: 0.6640 - accuracy: 0.6025
# Epoch 56/100
# 111/111 [==============================] - 7s 65ms/step - loss: 0.6630 - accuracy: 0.6028
# Epoch 57/100
# 111/111 [==============================] - 7s 65ms/step - loss: 0.6607 - accuracy: 0.6008
# Epoch 58/100
# 111/111 [==============================] - 7s 65ms/step - loss: 0.6594 - accuracy: 0.5991
# Epoch 59/100
# 111/111 [==============================] - 7s 67ms/step - loss: 0.6598 - accuracy: 0.6036
# Epoch 60/100
# 111/111 [==============================] - 7s 66ms/step - loss: 0.6558 - accuracy: 0.6096
# Epoch 61/100
# 111/111 [==============================] - 7s 66ms/step - loss: 0.6563 - accuracy: 0.6124
# Epoch 62/100
# 111/111 [==============================] - 7s 67ms/step - loss: 0.6515 - accuracy: 0.6163
# Epoch 63/100
# 111/111 [==============================] - 7s 66ms/step - loss: 0.6512 - accuracy: 0.6118
# Epoch 64/100
# 111/111 [==============================] - 7s 66ms/step - loss: 0.6489 - accuracy: 0.6228
# Epoch 65/100
# 111/111 [==============================] - 7s 67ms/step - loss: 0.6492 - accuracy: 0.6141
# Epoch 66/100
# 111/111 [==============================] - 7s 67ms/step - loss: 0.6477 - accuracy: 0.6274
# Epoch 67/100
# 111/111 [==============================] - 7s 66ms/step - loss: 0.6492 - accuracy: 0.6214
# Epoch 68/100
# 111/111 [==============================] - 7s 66ms/step - loss: 0.6405 - accuracy: 0.6339
# Epoch 69/100
# 111/111 [==============================] - 7s 66ms/step - loss: 0.6401 - accuracy: 0.6231
# Epoch 70/100
# 111/111 [==============================] - 7s 66ms/step - loss: 0.6335 - accuracy: 0.6302
# Epoch 71/100
# 111/111 [==============================] - ETA: 0s - loss: 0.6165 - accuracy: 0.6531INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 111/111 [==============================] - 18s 159ms/step - loss: 0.6165 - accuracy: 0.6531
# Epoch 72/100
# 111/111 [==============================] - ETA: 0s - loss: 0.6042 - accuracy: 0.6723INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 111/111 [==============================] - 15s 138ms/step - loss: 0.6042 - accuracy: 0.6723
# Epoch 73/100
# 111/111 [==============================] - ETA: 0s - loss: 0.5960 - accuracy: 0.6797INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 111/111 [==============================] - 15s 136ms/step - loss: 0.5960 - accuracy: 0.6797
# Epoch 74/100
# 111/111 [==============================] - ETA: 0s - loss: 0.5637 - accuracy: 0.7096INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 111/111 [==============================] - 15s 135ms/step - loss: 0.5637 - accuracy: 0.7096
# Epoch 75/100
# 111/111 [==============================] - ETA: 0s - loss: 0.5518 - accuracy: 0.7277INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 111/111 [==============================] - 17s 157ms/step - loss: 0.5518 - accuracy: 0.7277
# Epoch 76/100
# 111/111 [==============================] - ETA: 0s - loss: 0.5249 - accuracy: 0.7515INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 111/111 [==============================] - 15s 136ms/step - loss: 0.5249 - accuracy: 0.7515
# Epoch 77/100
# 111/111 [==============================] - ETA: 0s - loss: 0.4926 - accuracy: 0.7693INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 111/111 [==============================] - 15s 133ms/step - loss: 0.4926 - accuracy: 0.7693
# Epoch 78/100
# 111/111 [==============================] - ETA: 0s - loss: 0.4876 - accuracy: 0.7750INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 111/111 [==============================] - 15s 132ms/step - loss: 0.4876 - accuracy: 0.7750
# Epoch 79/100
# 111/111 [==============================] - ETA: 0s - loss: 0.4672 - accuracy: 0.7897INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 111/111 [==============================] - 14s 130ms/step - loss: 0.4672 - accuracy: 0.7897
# Epoch 80/100
# 111/111 [==============================] - ETA: 0s - loss: 0.4657 - accuracy: 0.7953INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 111/111 [==============================] - 17s 154ms/step - loss: 0.4657 - accuracy: 0.7953
# Epoch 81/100
# 111/111 [==============================] - ETA: 0s - loss: 0.4347 - accuracy: 0.8126INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 111/111 [==============================] - 15s 132ms/step - loss: 0.4347 - accuracy: 0.8126
# Epoch 82/100
# 111/111 [==============================] - ETA: 0s - loss: 0.4208 - accuracy: 0.8162INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 111/111 [==============================] - 15s 131ms/step - loss: 0.4208 - accuracy: 0.8162
# Epoch 83/100
# 111/111 [==============================] - ETA: 0s - loss: 0.4268 - accuracy: 0.8188INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 111/111 [==============================] - 15s 131ms/step - loss: 0.4268 - accuracy: 0.8188
# Epoch 84/100
# 111/111 [==============================] - ETA: 0s - loss: 0.4122 - accuracy: 0.8278INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 111/111 [==============================] - 17s 151ms/step - loss: 0.4122 - accuracy: 0.8278
# Epoch 85/100
# 111/111 [==============================] - 7s 63ms/step - loss: 0.4132 - accuracy: 0.8267
# Epoch 86/100
# 111/111 [==============================] - 7s 64ms/step - loss: 0.4256 - accuracy: 0.8137
# Epoch 87/100
# 111/111 [==============================] - ETA: 0s - loss: 0.3988 - accuracy: 0.8335INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 111/111 [==============================] - 14s 131ms/step - loss: 0.3988 - accuracy: 0.8335
# Epoch 88/100
# 111/111 [==============================] - ETA: 0s - loss: 0.3855 - accuracy: 0.8374INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 111/111 [==============================] - 15s 131ms/step - loss: 0.3855 - accuracy: 0.8374
# Epoch 89/100
# 111/111 [==============================] - 7s 64ms/step - loss: 0.3988 - accuracy: 0.8312
# Epoch 90/100
# 111/111 [==============================] - 7s 63ms/step - loss: 0.3838 - accuracy: 0.8335
# Epoch 91/100
# 111/111 [==============================] - ETA: 0s - loss: 0.3747 - accuracy: 0.8482INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 111/111 [==============================] - 14s 130ms/step - loss: 0.3747 - accuracy: 0.8482
# Epoch 92/100
# 111/111 [==============================] - 7s 63ms/step - loss: 0.3756 - accuracy: 0.8456
# Epoch 93/100
# 111/111 [==============================] - 7s 64ms/step - loss: 0.4002 - accuracy: 0.8270
# Epoch 94/100
# 111/111 [==============================] - 7s 63ms/step - loss: 0.3829 - accuracy: 0.8349
# Epoch 95/100
# 111/111 [==============================] - 7s 63ms/step - loss: 0.3711 - accuracy: 0.8420
# Epoch 96/100
# 111/111 [==============================] - 7s 63ms/step - loss: 0.3708 - accuracy: 0.8482
# Epoch 97/100
# 111/111 [==============================] - 7s 66ms/step - loss: 0.3776 - accuracy: 0.8386
# Epoch 98/100
# 111/111 [==============================] - 7s 65ms/step - loss: 0.3659 - accuracy: 0.8473
# Epoch 99/100
# 111/111 [==============================] - ETA: 0s - loss: 0.3593 - accuracy: 0.8589INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 111/111 [==============================] - 14s 129ms/step - loss: 0.3593 - accuracy: 0.8589
# Epoch 100/100
# 111/111 [==============================] - 7s 63ms/step - loss: 0.3793 - accuracy: 0.8369
# Train 100 epochs, 961 sec

# %%
print ("Evaluate on A")
(X_train,y_train,X_valid_A,y_valid_A)=get_x_and_y(train_set,200,600)
just_evaluate(X_valid_A,y_valid_A) 
(X_valid_A,y_valid_A)=(None,None)
print ("Evaluate on B")
(X_train,y_train,X_valid_B,y_valid_B)=get_x_and_y(train_set,600,900)
just_evaluate(X_valid_B,y_valid_B)  
(X_valid_B,y_valid_B)=(None,None)
print ("Evaluate on C")
(X_train,y_train,X_valid_C,y_valid_C)=get_x_and_y(train_set,900,1300)
just_evaluate(X_valid_C,y_valid_C)  
(X_valid_C,y_valid_C)=(None,None)
print ("Evaluate on D")
(X_train,y_train,X_valid_D,y_valid_D)=get_x_and_y(train_set,1300,1900)
just_evaluate(X_valid_D,y_valid_D)  
(X_valid_D,y_valid_D)=(None,None)
print ("Evaluate on E")
(X_train,y_train,X_valid_E,y_valid_E)=get_x_and_y(train_set,1900,3000)
just_evaluate(X_valid_E,y_valid_E)  
(X_valid_E,y_valid_E)=(None,None)
print ("Evaluate on F")
(X_train,y_train,X_valid_F,y_valid_F)=get_x_and_y(train_set,3000,30000)
just_evaluate(X_valid_F,y_valid_F) 
(X_valid_F,y_valid_F)=(None,None) 

print ("Done")
# Out:
# Evaluate on A
# Shape of X is (8165, 600)
# Total 8165, Train portion 6532
# accuracy: 80.96%
# Evaluate on B
# Shape of X is (6442, 900)
# Total 6442, Train portion 5154
# accuracy: 74.61%
# Evaluate on C
# Shape of X is (4478, 1300)
# Total 4478, Train portion 3582
# accuracy: 76.00%
# Evaluate on D
# Shape of X is (4421, 1900)
# Total 4421, Train portion 3537
# accuracy: 82.24%
# Evaluate on E
# Shape of X is (4590, 3000)
# Total 4590, Train portion 3672
# accuracy: 87.25%
# Evaluate on F
# Shape of X is (3900, 30000)
# Total 3900, Train portion 3120
# accuracy: 90.26%
# Done
