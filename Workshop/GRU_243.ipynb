# %% [markdown]
# # GRU 243
# Test the RNA length effect.

# %%
NC_FILENAME='ncRNA.gc34.processed.fasta'
PC_FILENAME='pcRNA.gc34.processed.fasta'
DATAPATH=""
try:
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
    NC_FILENAME = DATAPATH+NC_FILENAME
    PC_FILENAME = DATAPATH+PC_FILENAME
except:
    IN_COLAB = False
    DATAPATH="" 

EPOCHS=100  # use 2 for debug, 200 for real
K=3
VOCABULARY_SIZE=4**K+1   # e.g. K=3 => 64 DNA K-mers + 'NNN'
EMBED_DIMEN=16
FILENAME='GRU243'
NEURONS=16
ACT="tanh"
DROP=0.5
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import StratifiedKFold
import tensorflow as tf
from tensorflow import keras
from keras.wrappers.scikit_learn import KerasRegressor
from keras.models import Sequential
from keras.layers import Bidirectional
from keras.layers import GRU
from keras.layers import Dense
from keras.layers import LayerNormalization
import time
dt='float32'
tf.keras.backend.set_floatx(dt)

# %% [markdown]
# ## Build model

# %%
def compile_model(model):
    adam_default_learn_rate = 0.001
    schedule = tf.keras.optimizers.schedules.ExponentialDecay(
        initial_learning_rate = adam_default_learn_rate*10,
        #decay_steps=100000, decay_rate=0.96, staircase=True)
        decay_steps=10000, decay_rate=0.99, staircase=True)
    # learn rate = initial_learning_rate * decay_rate ^ (step / decay_steps)
    alrd = tf.keras.optimizers.Adam(learning_rate=schedule)
    bc=tf.keras.losses.BinaryCrossentropy(from_logits=False)
    print("COMPILE...")
    #model.compile(loss=bc, optimizer=alrd, metrics=["accuracy"])
    model.compile(loss=bc, optimizer="adam", metrics=["accuracy"])
    print("...COMPILED")
    return model

def build_model():
    embed_layer  = keras.layers.Embedding(
        #VOCABULARY_SIZE, EMBED_DIMEN, input_length=1000, input_length=1000, mask_zero=True)
        #input_dim=[None,VOCABULARY_SIZE], output_dim=EMBED_DIMEN, mask_zero=True)
        input_dim=VOCABULARY_SIZE, output_dim=EMBED_DIMEN, mask_zero=True)
    #rnn1_layer = keras.layers.Bidirectional(
    rnn1_layer = keras.layers.GRU(NEURONS, return_sequences=False,  #   True, 
          input_shape=[1000,EMBED_DIMEN], activation=ACT, dropout=DROP)#)#bi
    #rnn2_layer = keras.layers.Bidirectional(
    rnn2_layer = keras.layers.GRU(NEURONS, return_sequences=False, 
        activation=ACT, dropout=DROP)#)#bi
    dense1_layer = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt)
    drop1_layer = keras.layers.Dropout(DROP)
    #dense2_layer = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt)
    #drop2_layer = keras.layers.Dropout(DROP)
    output_layer = keras.layers.Dense(1, activation="sigmoid", dtype=dt)
    mlp = keras.models.Sequential()
    mlp.add(embed_layer)
    mlp.add(rnn1_layer)
    #mlp.add(rnn2_layer)
    mlp.add(dense1_layer)
    mlp.add(drop1_layer)
    #mlp.add(dense2_layer)
    #mlp.add(drop2_layer)
    mlp.add(output_layer)
    mlpc = compile_model(mlp)
    return mlpc

# %% [markdown]
# ## Load and partition sequences

# %%
# Assume file was preprocessed to contain one line per seq.
# Prefer Pandas dataframe but df does not support append.
# For conversion to tensor, must avoid python lists.
def load_fasta(filename,label):
    DEFLINE='>'
    labels=[]
    seqs=[]
    lens=[]
    nums=[]
    num=0
    with open (filename,'r') as infile:
        for line in infile:
            if line[0]!=DEFLINE:
                seq=line.rstrip()
                num += 1   # first seqnum is 1
                seqlen=len(seq)
                nums.append(num)
                labels.append(label)
                seqs.append(seq)
                lens.append(seqlen)
    df1=pd.DataFrame(nums,columns=['seqnum'])
    df2=pd.DataFrame(labels,columns=['class'])
    df3=pd.DataFrame(seqs,columns=['sequence'])
    df4=pd.DataFrame(lens,columns=['seqlen'])
    df=pd.concat((df1,df2,df3,df4),axis=1)
    return df

def separate_X_and_y(data):
    y=   data[['class']].copy()
    X=   data.drop(columns=['class','seqnum','seqlen'])
    return (X,y)

# %% [markdown]
# ## Make K-mers

# %%
def make_kmer_table(K):
    npad='N'*K
    shorter_kmers=['']
    for i in range(K):
        longer_kmers=[]
        for mer in shorter_kmers:
            longer_kmers.append(mer+'A')
            longer_kmers.append(mer+'C')
            longer_kmers.append(mer+'G')
            longer_kmers.append(mer+'T')
        shorter_kmers = longer_kmers
    all_kmers = shorter_kmers
    kmer_dict = {}
    kmer_dict[npad]=0
    value=1
    for mer in all_kmers:
        kmer_dict[mer]=value
        value += 1
    return kmer_dict

KMER_TABLE=make_kmer_table(K)

def strings_to_vectors(data,uniform_len):
    all_seqs=[]
    for seq in data['sequence']:
        i=0
        seqlen=len(seq)
        kmers=[]
        while i < seqlen-K+1 -1:  # stop at minus one for spaced seed
            #kmer=seq[i:i+2]+seq[i+3:i+5]    # SPACED SEED 2/1/2 for K=4
            kmer=seq[i:i+K]  
            i += 1
            value=KMER_TABLE[kmer]
            kmers.append(value)
        pad_val=0
        while i < uniform_len:
            kmers.append(pad_val)
            i += 1
        all_seqs.append(kmers)
    pd2d=pd.DataFrame(all_seqs)
    return pd2d   # return 2D dataframe, uniform dimensions

# %%
def make_kmers(MAXLEN,train_set):
    (X_train_all,y_train_all)=separate_X_and_y(train_set)
    X_train_kmers=strings_to_vectors(X_train_all,MAXLEN)
    # From pandas dataframe to numpy to list to numpy
    num_seqs=len(X_train_kmers)
    tmp_seqs=[]
    for i in range(num_seqs):
        kmer_sequence=X_train_kmers.iloc[i]
        tmp_seqs.append(kmer_sequence)
    X_train_kmers=np.array(tmp_seqs)
    tmp_seqs=None
    labels=y_train_all.to_numpy()
    return (X_train_kmers,labels)

# %%
def make_frequencies(Xin):
    Xout=[]
    VOCABULARY_SIZE= 4**K + 1  # plus one for 'NNN'
    for seq in Xin:
        freqs =[0] * VOCABULARY_SIZE
        total = 0
        for kmerval in seq:
            freqs[kmerval] += 1
            total += 1
        for c in range(VOCABULARY_SIZE):
            freqs[c] = freqs[c]/total
        Xout.append(freqs)
    Xnum = np.asarray(Xout)
    return (Xnum)
def make_slice(data_set,min_len,max_len):
    slice = data_set.query('seqlen <= '+str(max_len)+' & seqlen>= '+str(min_len))
    return slice

# %% [markdown]
# ## Cross validation

# %%
bestname=DATAPATH+FILENAME+".best"
def just_train(X,y): # give me training set
    model=build_model()
    print(model.summary())
    mycallbacks = [keras.callbacks.ModelCheckpoint(
        filepath=bestname, save_best_only=True, 
        monitor='accuracy', mode='max')]   
    print("FIT")
    start_time=time.time()
    history=model.fit(X_train, y_train, # batch_size=10, default=32 works nicely
            epochs=EPOCHS, verbose=1,  # verbose=1 for ascii art, verbose=0 for none
            callbacks=mycallbacks )  # no validation data
    end_time=time.time()
    elapsed_time=(end_time-start_time)                        
    print("Train %d epochs, %d sec"%(EPOCHS,elapsed_time))
    pd.DataFrame(history.history).plot(figsize=(8,5))
    plt.grid(True)
    plt.gca().set_ylim(0,1)
    plt.show()
def just_evaluate(X,y):  # give me validation set
    best_model=keras.models.load_model(bestname)
    scores = best_model.evaluate(X, y, verbose=0)
    print("%s: %.2f%%" % (best_model.metrics_names[1], scores[1]*100))

# %% [markdown]
# ## Train on RNA length-based slice

# %%
#      A    B    C     D     E     F
# 200, 500, 750, 1000, 1500, 3000, 30000 
print("Load data from files.")
nc_seq=load_fasta(NC_FILENAME,0)
pc_seq=load_fasta(PC_FILENAME,1)
train_set=pd.concat((nc_seq,pc_seq),axis=0)
nc_seq=None
pc_seq=None
def get_x_and_y(train_set,minlen,maxlen):
  subset=make_slice(train_set,minlen,maxlen)
  (X_set,y_set)=make_kmers(maxlen,subset)
  print("Shape of X is "+str(X_set.shape))
  L=len(X_set)
  T=int(0.80*L+0.5)
  print("Total %d, Train portion %d"%(L,T))
  X_train=X_set[:T]
  y_train=y_set[:T]
  X_valid=X_set[T:]
  y_valid=y_set[T:]
  return (X_train,y_train,X_valid,y_valid)

MINLEN=1000
MAXLEN=1500
(X_train,y_train,X_valid,y_valid)=get_x_and_y(train_set,MINLEN,MAXLEN)
print("Loaded")
# Out:
# Load data from files.
# Shape of X is (4580, 1500)
# Total 4580, Train portion 3664
# Loaded

# %%
print ("Train on ",MINLEN,"-",MAXLEN)
just_train(X_train,y_train)
# Out:
# Train on  1000 - 1500
# COMPILE...
# ...COMPILED
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, None, 16)          1040
# _________________________________________________________________
# gru_2 (GRU)                  (None, 16)                1632
# _________________________________________________________________
# dense_2 (Dense)              (None, 16)                272
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 2,961
# Trainable params: 2,961
# Non-trainable params: 0
# _________________________________________________________________
# None
# FIT
# Epoch 1/100
# 115/115 [==============================] - ETA: 0s - loss: 0.6844 - accuracy: 0.5630INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 115/115 [==============================] - 13s 116ms/step - loss: 0.6844 - accuracy: 0.5630
# Epoch 2/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.6723 - accuracy: 0.5781INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 115/115 [==============================] - 14s 124ms/step - loss: 0.6721 - accuracy: 0.5781
# Epoch 3/100
# 115/115 [==============================] - ETA: 0s - loss: 0.6659 - accuracy: 0.6023INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 115/115 [==============================] - 13s 116ms/step - loss: 0.6659 - accuracy: 0.6023
# Epoch 4/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.6594 - accuracy: 0.6069INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 115/115 [==============================] - 14s 126ms/step - loss: 0.6603 - accuracy: 0.6064
# Epoch 5/100
# 115/115 [==============================] - ETA: 0s - loss: 0.6553 - accuracy: 0.6124INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 115/115 [==============================] - 14s 118ms/step - loss: 0.6553 - accuracy: 0.6124
# Epoch 6/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.6477 - accuracy: 0.6338INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 115/115 [==============================] - 14s 124ms/step - loss: 0.6475 - accuracy: 0.6340
# Epoch 7/100
# 115/115 [==============================] - 6s 51ms/step - loss: 0.6500 - accuracy: 0.6264
# Epoch 8/100
# 115/115 [==============================] - 6s 51ms/step - loss: 0.6417 - accuracy: 0.6324
# Epoch 9/100
# 115/115 [==============================] - ETA: 0s - loss: 0.6411 - accuracy: 0.6376INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 115/115 [==============================] - 13s 116ms/step - loss: 0.6411 - accuracy: 0.6376
# Epoch 10/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.6405 - accuracy: 0.6450INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 115/115 [==============================] - 15s 127ms/step - loss: 0.6415 - accuracy: 0.6441
# Epoch 11/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.6344 - accuracy: 0.6557INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 115/115 [==============================] - 13s 117ms/step - loss: 0.6347 - accuracy: 0.6558
# Epoch 12/100
# 115/115 [==============================] - 6s 50ms/step - loss: 0.6370 - accuracy: 0.6441
# Epoch 13/100
# 115/115 [==============================] - 6s 51ms/step - loss: 0.6360 - accuracy: 0.6381
# Epoch 14/100
# 115/115 [==============================] - 6s 50ms/step - loss: 0.6435 - accuracy: 0.6416
# Epoch 15/100
# 115/115 [==============================] - 6s 51ms/step - loss: 0.6359 - accuracy: 0.6507
# Epoch 16/100
# 115/115 [==============================] - 6s 51ms/step - loss: 0.6284 - accuracy: 0.6531
# Epoch 17/100
# 115/115 [==============================] - 6s 51ms/step - loss: 0.6315 - accuracy: 0.6545
# Epoch 18/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.6237 - accuracy: 0.6593INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 115/115 [==============================] - 15s 127ms/step - loss: 0.6231 - accuracy: 0.6605
# Epoch 19/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.6238 - accuracy: 0.6639INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 115/115 [==============================] - 14s 120ms/step - loss: 0.6233 - accuracy: 0.6643
# Epoch 20/100
# 115/115 [==============================] - 6s 53ms/step - loss: 0.6280 - accuracy: 0.6575
# Epoch 21/100
# 115/115 [==============================] - 6s 53ms/step - loss: 0.6250 - accuracy: 0.6558
# Epoch 22/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.6212 - accuracy: 0.6634INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 115/115 [==============================] - 15s 129ms/step - loss: 0.6202 - accuracy: 0.6646
# Epoch 23/100
# 115/115 [==============================] - 6s 51ms/step - loss: 0.6713 - accuracy: 0.5993
# Epoch 24/100
# 115/115 [==============================] - 6s 51ms/step - loss: 0.6666 - accuracy: 0.6048
# Epoch 25/100
# 115/115 [==============================] - 6s 51ms/step - loss: 0.6642 - accuracy: 0.6059
# Epoch 26/100
# 115/115 [==============================] - 6s 51ms/step - loss: 0.6595 - accuracy: 0.6116
# Epoch 27/100
# 115/115 [==============================] - 6s 51ms/step - loss: 0.6620 - accuracy: 0.6081
# Epoch 28/100
# 115/115 [==============================] - 6s 53ms/step - loss: 0.6563 - accuracy: 0.6067
# Epoch 29/100
# 115/115 [==============================] - 6s 52ms/step - loss: 0.6591 - accuracy: 0.6165
# Epoch 30/100
# 115/115 [==============================] - 6s 51ms/step - loss: 0.6571 - accuracy: 0.6212
# Epoch 31/100
# 115/115 [==============================] - 6s 52ms/step - loss: 0.6569 - accuracy: 0.6124
# Epoch 32/100
# 115/115 [==============================] - 6s 51ms/step - loss: 0.6549 - accuracy: 0.6206
# Epoch 33/100
# 115/115 [==============================] - 6s 54ms/step - loss: 0.6503 - accuracy: 0.6217
# Epoch 34/100
# 115/115 [==============================] - 6s 54ms/step - loss: 0.6534 - accuracy: 0.6215
# Epoch 35/100
# 115/115 [==============================] - 6s 51ms/step - loss: 0.6527 - accuracy: 0.6228
# Epoch 36/100
# 115/115 [==============================] - 6s 53ms/step - loss: 0.6463 - accuracy: 0.6329
# Epoch 37/100
# 115/115 [==============================] - 6s 52ms/step - loss: 0.6430 - accuracy: 0.6340
# Epoch 38/100
# 115/115 [==============================] - 6s 52ms/step - loss: 0.6440 - accuracy: 0.6302
# Epoch 39/100
# 115/115 [==============================] - 6s 53ms/step - loss: 0.6362 - accuracy: 0.6389
# Epoch 40/100
# 115/115 [==============================] - 6s 52ms/step - loss: 0.6372 - accuracy: 0.6438
# Epoch 41/100
# 115/115 [==============================] - 6s 52ms/step - loss: 0.6398 - accuracy: 0.6362
# Epoch 42/100
# 115/115 [==============================] - 6s 51ms/step - loss: 0.6325 - accuracy: 0.6485
# Epoch 43/100
# 115/115 [==============================] - 6s 51ms/step - loss: 0.6304 - accuracy: 0.6586
# Epoch 44/100
# 115/115 [==============================] - 6s 52ms/step - loss: 0.6229 - accuracy: 0.6635
# Epoch 45/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.6132 - accuracy: 0.6752INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 115/115 [==============================] - 14s 118ms/step - loss: 0.6131 - accuracy: 0.6755
# Epoch 46/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.5972 - accuracy: 0.6889INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 115/115 [==============================] - 15s 129ms/step - loss: 0.5966 - accuracy: 0.6891
# Epoch 47/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.5751 - accuracy: 0.7113INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 115/115 [==============================] - 14s 118ms/step - loss: 0.5749 - accuracy: 0.7115
# Epoch 48/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.5568 - accuracy: 0.7278INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 115/115 [==============================] - 14s 118ms/step - loss: 0.5570 - accuracy: 0.7276
# Epoch 49/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.5322 - accuracy: 0.7453INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 115/115 [==============================] - 15s 130ms/step - loss: 0.5319 - accuracy: 0.7456
# Epoch 50/100
# 115/115 [==============================] - ETA: 0s - loss: 0.5018 - accuracy: 0.7656INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 115/115 [==============================] - 14s 125ms/step - loss: 0.5018 - accuracy: 0.7656
# Epoch 51/100
# 115/115 [==============================] - ETA: 0s - loss: 0.5035 - accuracy: 0.7672INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 115/115 [==============================] - 14s 118ms/step - loss: 0.5035 - accuracy: 0.7672
# Epoch 52/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.4891 - accuracy: 0.7782INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 115/115 [==============================] - 15s 128ms/step - loss: 0.4890 - accuracy: 0.7781
# Epoch 53/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.4875 - accuracy: 0.7788INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 115/115 [==============================] - 14s 117ms/step - loss: 0.4883 - accuracy: 0.7784
# Epoch 54/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.4831 - accuracy: 0.7802INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 115/115 [==============================] - 15s 128ms/step - loss: 0.4831 - accuracy: 0.7803
# Epoch 55/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.4605 - accuracy: 0.7969INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 115/115 [==============================] - 14s 118ms/step - loss: 0.4617 - accuracy: 0.7964
# Epoch 56/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.4575 - accuracy: 0.8021INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 115/115 [==============================] - 15s 128ms/step - loss: 0.4570 - accuracy: 0.8027
# Epoch 57/100
# 115/115 [==============================] - 6s 52ms/step - loss: 0.4496 - accuracy: 0.8024
# Epoch 58/100
# 115/115 [==============================] - 6s 53ms/step - loss: 0.4424 - accuracy: 0.7999
# Epoch 59/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.4324 - accuracy: 0.8169INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 115/115 [==============================] - 14s 120ms/step - loss: 0.4323 - accuracy: 0.8169
# Epoch 60/100
# 115/115 [==============================] - 6s 53ms/step - loss: 0.4506 - accuracy: 0.8098
# Epoch 61/100
# 115/115 [==============================] - 6s 52ms/step - loss: 0.4348 - accuracy: 0.8117
# Epoch 62/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.4265 - accuracy: 0.8215INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 115/115 [==============================] - 15s 128ms/step - loss: 0.4263 - accuracy: 0.8212
# Epoch 63/100
# 115/115 [==============================] - 6s 52ms/step - loss: 0.4246 - accuracy: 0.8160
# Epoch 64/100
# 115/115 [==============================] - 6s 52ms/step - loss: 0.4268 - accuracy: 0.8204
# Epoch 65/100
# 115/115 [==============================] - 6s 54ms/step - loss: 0.4276 - accuracy: 0.8158
# Epoch 66/100
# 115/115 [==============================] - 6s 56ms/step - loss: 0.4185 - accuracy: 0.8207
# Epoch 67/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.4048 - accuracy: 0.8298INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 115/115 [==============================] - 14s 120ms/step - loss: 0.4052 - accuracy: 0.8291
# Epoch 68/100
# 115/115 [==============================] - 6s 53ms/step - loss: 0.4142 - accuracy: 0.8182
# Epoch 69/100
# 115/115 [==============================] - 6s 53ms/step - loss: 0.4127 - accuracy: 0.8275
# Epoch 70/100
# 115/115 [==============================] - 6s 53ms/step - loss: 0.4188 - accuracy: 0.8248
# Epoch 71/100
# 115/115 [==============================] - 6s 53ms/step - loss: 0.4199 - accuracy: 0.8218
# Epoch 72/100
# 115/115 [==============================] - 6s 52ms/step - loss: 0.4162 - accuracy: 0.8125
# Epoch 73/100
# 115/115 [==============================] - 6s 53ms/step - loss: 0.4063 - accuracy: 0.8291
# Epoch 74/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.4105 - accuracy: 0.8306INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 115/115 [==============================] - 15s 129ms/step - loss: 0.4105 - accuracy: 0.8300
# Epoch 75/100
# 115/115 [==============================] - 6s 53ms/step - loss: 0.4093 - accuracy: 0.8261
# Epoch 76/100
# 115/115 [==============================] - 6s 53ms/step - loss: 0.4173 - accuracy: 0.8182
# Epoch 77/100
# 115/115 [==============================] - ETA: 0s - loss: 0.4052 - accuracy: 0.8313INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 115/115 [==============================] - 14s 119ms/step - loss: 0.4052 - accuracy: 0.8313
# Epoch 78/100
# 115/115 [==============================] - 6s 54ms/step - loss: 0.4052 - accuracy: 0.8281
# Epoch 79/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3952 - accuracy: 0.8343INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 115/115 [==============================] - 14s 119ms/step - loss: 0.3952 - accuracy: 0.8343
# Epoch 80/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.3976 - accuracy: 0.8350INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 115/115 [==============================] - 15s 130ms/step - loss: 0.3971 - accuracy: 0.8352
# Epoch 81/100
# 115/115 [==============================] - 6s 53ms/step - loss: 0.4051 - accuracy: 0.8286
# Epoch 82/100
# 115/115 [==============================] - 6s 53ms/step - loss: 0.3937 - accuracy: 0.8330
# Epoch 83/100
# 115/115 [==============================] - 6s 53ms/step - loss: 0.4094 - accuracy: 0.8248
# Epoch 84/100
# 115/115 [==============================] - 6s 55ms/step - loss: 0.4010 - accuracy: 0.8319
# Epoch 85/100
# 115/115 [==============================] - 6s 53ms/step - loss: 0.3952 - accuracy: 0.8324
# Epoch 86/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.3880 - accuracy: 0.8372INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 115/115 [==============================] - 15s 127ms/step - loss: 0.3878 - accuracy: 0.8371
# Epoch 87/100
# 115/115 [==============================] - 6s 53ms/step - loss: 0.3988 - accuracy: 0.8300
# Epoch 88/100
# 115/115 [==============================] - 6s 54ms/step - loss: 0.3892 - accuracy: 0.8335
# Epoch 89/100
# 114/115 [============================>.] - ETA: 0s - loss: 0.3880 - accuracy: 0.8410INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 115/115 [==============================] - 14s 121ms/step - loss: 0.3876 - accuracy: 0.8412
# Epoch 90/100
# 115/115 [==============================] - 6s 53ms/step - loss: 0.3909 - accuracy: 0.8313
# Epoch 91/100
# 115/115 [==============================] - ETA: 0s - loss: 0.3841 - accuracy: 0.8472INFO:tensorflow:Assets written to: /content/drive/My Drive/data/GRU243.best/assets
# 115/115 [==============================] - 15s 130ms/step - loss: 0.3841 - accuracy: 0.8472
# Epoch 92/100
# 115/115 [==============================] - 6s 54ms/step - loss: 0.3964 - accuracy: 0.8352
# Epoch 93/100
# 115/115 [==============================] - 6s 53ms/step - loss: 0.3872 - accuracy: 0.8352
# Epoch 94/100
# 115/115 [==============================] - 6s 53ms/step - loss: 0.4050 - accuracy: 0.8248
# Epoch 95/100
# 115/115 [==============================] - 6s 54ms/step - loss: 0.3898 - accuracy: 0.8354
# Epoch 96/100
# 115/115 [==============================] - 6s 55ms/step - loss: 0.3847 - accuracy: 0.8324
# Epoch 97/100
# 115/115 [==============================] - 6s 54ms/step - loss: 0.3829 - accuracy: 0.8362
# Epoch 98/100
# 115/115 [==============================] - 6s 54ms/step - loss: 0.3859 - accuracy: 0.8409
# Epoch 99/100
# 115/115 [==============================] - 6s 53ms/step - loss: 0.3827 - accuracy: 0.8390
# Epoch 100/100
# 115/115 [==============================] - 6s 54ms/step - loss: 0.3795 - accuracy: 0.8458
# Train 100 epochs, 888 sec

# %%
print ("Evaluate on A")
(X_train,y_train,X_valid_A,y_valid_A)=get_x_and_y(train_set,200,700)
just_evaluate(X_valid_A,y_valid_A) 
(X_valid_A,y_valid_A)=(None,None)
print ("Evaluate on B")
(X_train,y_train,X_valid_B,y_valid_B)=get_x_and_y(train_set,700,900)
just_evaluate(X_valid_B,y_valid_B)  
(X_valid_B,y_valid_B)=(None,None)
print ("Evaluate on C")
(X_train,y_train,X_valid_C,y_valid_C)=get_x_and_y(train_set,900,1200)
just_evaluate(X_valid_C,y_valid_C)  
(X_valid_C,y_valid_C)=(None,None)
print ("Evaluate on D")
(X_train,y_train,X_valid_D,y_valid_D)=get_x_and_y(train_set,1200,1700)
just_evaluate(X_valid_D,y_valid_D)  
(X_valid_D,y_valid_D)=(None,None)
print ("Evaluate on E")
(X_train,y_train,X_valid_E,y_valid_E)=get_x_and_y(train_set,1700,2500)
just_evaluate(X_valid_E,y_valid_E)  
(X_valid_E,y_valid_E)=(None,None)
print ("Evaluate on F")
(X_train,y_train,X_valid_F,y_valid_F)=get_x_and_y(train_set,2500,30000)
just_evaluate(X_valid_F,y_valid_F) 
(X_valid_F,y_valid_F)=(None,None) 

print ("Done")
# Out:
# Evaluate on A
# Shape of X is (10501, 700)
# Total 10501, Train portion 8401
# accuracy: 70.57%
# Evaluate on B
# Shape of X is (4148, 900)
# Total 4148, Train portion 3318
# accuracy: 81.81%
# Evaluate on C
# Shape of X is (3636, 1200)
# Total 3636, Train portion 2909
# accuracy: 85.28%
# Evaluate on D
# Shape of X is (3942, 1700)
# Total 3942, Train portion 3154
# accuracy: 87.31%
# Evaluate on E
# Shape of X is (4395, 2500)
# Total 4395, Train portion 3516
# accuracy: 89.87%
# Evaluate on F
# Shape of X is (5438, 30000)
# Total 5438, Train portion 4350
# accuracy: 90.26%
# Done
