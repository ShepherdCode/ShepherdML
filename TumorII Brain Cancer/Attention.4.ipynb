# %% [markdown]
# # Attention HalfRoll
# Class = 4.
#
# How well can RF recapitulate CNN attention
# given only CP nucleus stats?
# Train a RF on the average attention "temperature" per
# nucleus bounding box as selected by CP.

# %%
import datetime
import numpy as np
import pandas as pd
from RandomForestUtil import RF_Util
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

# %%
ATTFILEPATH='/home/jrm/Adjeroh/Naved/CP_80K/attention_nucleus/' # Alien
ATTFILENAME='class4_avg_temp.csv'
NUCFILEPATH='/home/jrm/Adjeroh/Naved/CP_80K/Output4/'
NUCFILENAME='Process100_Nucleus.csv'

# %% [markdown]
# ## Load labels
# The labels are the temperatures of the CNN attention heatmap,
# specifically an average across the bounding box of each nucleus.

# %%
att_df=pd.read_csv(ATTFILEPATH+ATTFILENAME)
cols={'ImageNumber':'PatchNumber',' ObjectNumber':'ObjectNumber',' AvgTemp':'AvgTemp'}
att_df.rename(columns=cols,inplace=True)
att_df.sort_values(by=['PatchNumber','ObjectNumber'],axis=0,inplace=True)
att_df.reset_index(drop=True,inplace=True)

# %%
# Later, try the RandomForestRegressor. For now use bins and classification.
bins = [0, 0.3, 0.45, 0.6, 0.75, 1.0]
labels = ['to30%', 'to45%', 'to60%', 'to75%', 'to100%']
att_df['bin'] = pd.cut(att_df['AvgTemp'], bins=bins, labels=labels)
att_df
# Out:
#        PatchNumber  ObjectNumber   AvgTemp    bin
# 0                1             1  0.024352  to30%
# 1                1             2  0.167493  to30%
# 2                1             3  0.301966  to45%
# 3                1             4  0.568698  to60%
# 4                1             5  0.341957  to45%
# ...            ...           ...       ...    ...
# 46520         3196             6  0.542161  to60%
# 46521         3196             7  0.419783  to45%
# 46522         3196             8  0.519468  to60%
# 46523         3196             9  0.564878  to60%
# 46524         3197             1  0.678582  to75%
#
# [46525 rows x 4 columns]

# %%
ytrain = att_df['bin'] 
ytrain.value_counts()
# Out:
# to30%     10295
# to100%    10230
# to60%      9689
# to45%      8818
# to75%      7493
# Name: bin, dtype: int64

# %% [markdown]
# ## Load features
# These are features of nuclei as determined by our "Process100" pipeline for CellProfiler.
# These are the nuclei used to set the bounding boxes for the temperature lables.
# Other than that, the features and temperatures were each derived independently.

# %%
nuc_df=pd.read_csv(NUCFILEPATH+NUCFILENAME)
cols={'ImageNumber':'PatchNumber'}
nuc_df.rename(columns=cols,inplace=True)
nuc_df.sort_values(by=['PatchNumber','ObjectNumber'],axis=0,inplace=True)
nuc_df.reset_index(drop=True,inplace=True)

# %%
Xtrain = nuc_df.drop(columns=['PatchNumber','ObjectNumber'])
Xtrain
# Out:
#        AreaShape_Area  AreaShape_BoundingBoxArea  \
# 0                 196                        294
# 1                 469                        609
# 2                 223                        304
# 3                 508                        798
# 4                 521                        768
# ...               ...                        ...
# 46520             491                        684
# 46521             298                        364
# 46522             235                        345
# 46523             269                        414
# 46524             452                        570
#
#        AreaShape_BoundingBoxMaximum_X  AreaShape_BoundingBoxMaximum_Y  \
# 0                                  80                              26
# 1                                 126                              37
# 2                                 193                              41
# 3                                  21                              61
# 4                                 143                              74
# ...                               ...                             ...
# 46520                             234                             216
# 46521                             149                             208
# 46522                             210                             219
# 46523                             214                             233
# 46524                             263                             103
#
#        AreaShape_BoundingBoxMinimum_X  AreaShape_BoundingBoxMinimum_Y  \
# 0                                  59                              12
# 1                                  97                              16
# 2                                 174                              25
# 3                                   0                              23
# 4                                 111                              50
# ...                               ...                             ...
# 46520                             216                             178
# 46521                             136                             180
# 46522                             195                             196
# 46523                             196                             210
# 46524                             244                              73
#
#        AreaShape_Center_X  AreaShape_Center_Y  AreaShape_CentralMoment_0_0  \
# 0               68.193878           18.607143                        196.0
# 1              111.159915           25.989339                        469.0
# 2              182.551570           32.852018                        223.0
# 3                7.982283           43.293307                        508.0
# 4              126.280230           60.255278                        521.0
# ...                   ...                 ...                          ...
# 46520          224.256619          197.356415                        491.0
# 46521          142.043624          193.359060                        298.0
# 46522          200.523404          206.736170                        235.0
# 46523          205.635688          222.234201                        269.0
# 46524          252.573009           87.595133                        452.0
#
#        AreaShape_CentralMoment_0_1  ...  \
# 0                    -5.329071e-15  ...
# 1                    -9.166001e-13  ...
# 2                     4.796163e-14  ...
# 3                     2.131628e-14  ...
# 4                    -1.652012e-13  ...
# ...                            ...  ...
# 46520                 7.105427e-14  ...
# 46521                -2.842171e-14  ...
# 46522                -6.039613e-14  ...
# 46523                -2.113865e-13  ...
# 46524                -2.433609e-13  ...
#
#        Texture_Variance_Hematoxylin_4_02_256  \
# 0                                 602.743285
# 1                                 539.175397
# 2                                 888.080613
# 3                                1241.667208
# 4                                 951.986476
# ...                                      ...
# 46520                            1422.754541
# 46521                            1695.628540
# 46522                            1399.381486
# 46523                            1255.160768
# 46524                            1687.989581
#
#        Texture_Variance_Hematoxylin_4_03_256  \
# 0                                 642.679273
# 1                                 565.853063
# 2                                 808.414113
# 3                                1159.372486
# 4                                 964.896780
# ...                                      ...
# 46520                            1428.622175
# 46521                            1787.881929
# 46522                            1530.439781
# 46523                            1348.841787
# 46524                            1722.659264
#
#        Texture_Variance_Hematoxylin_5_00_256  \
# 0                                 642.319285
# 1                                 548.903754
# 2                                 845.188775
# 3                                1238.719919
# 4                                 907.957406
# ...                                      ...
# 46520                            1361.131323
# 46521                            1789.764515
# 46522                            1401.851562
# 46523                            1194.540566
# 46524                            1776.284579
#
#        Texture_Variance_Hematoxylin_5_01_256  \
# 0                                 642.400310
# 1                                 562.875134
# 2                                 847.659739
# 3                                1169.194520
# 4                                 909.009379
# ...                                      ...
# 46520                            1573.083123
# 46521                            1910.202155
# 46522                            1347.494422
# 46523                            1004.038428
# 46524                            1870.997250
#
#        Texture_Variance_Hematoxylin_5_02_256  \
# 0                                 640.764599
# 1                                 556.688253
# 2                                 899.641109
# 3                                1257.374985
# 4                                 956.391792
# ...                                      ...
# 46520                            1431.157207
# 46521                            1681.800641
# 46522                            1361.041939
# 46523                            1251.985997
# 46524                            1663.660735
#
#        Texture_Variance_Hematoxylin_5_03_256  \
# 0                                 699.330009
# 1                                 597.419939
# 2                                 733.203961
# 3                                1114.919318
# 4                                 966.036051
# ...                                      ...
# 46520                            1464.698052
# 46521                            1907.651012
# 46522                            1664.847698
# 46523                            1453.395007
# 46524                            1759.756351
#
#        Texture_Variance_Hematoxylin_7_00_256  \
# 0                                 644.967400
# 1                                 567.698283
# 2                                 877.066057
# 3                                1175.562484
# 4                                 933.923255
# ...                                      ...
# 46520                            1423.252150
# 46521                            2040.167169
# 46522                            1485.990710
# 46523                            1280.273024
# 46524                            1925.989226
#
#        Texture_Variance_Hematoxylin_7_01_256  \
# 0                                 687.076735
# 1                                 508.662662
# 2                                 587.996061
# 3                                1175.745806
# 4                                 943.625640
# ...                                      ...
# 46520                            1665.083694
# 46521                            2072.963190
# 46522                            1525.224615
# 46523                             901.265840
# 46524                            2120.779164
#
#        Texture_Variance_Hematoxylin_7_02_256  \
# 0                                 834.618344
# 1                                 579.599297
# 2                                 814.744709
# 3                                1287.354528
# 4                                 974.996622
# ...                                      ...
# 46520                            1452.185763
# 46521                            1667.108287
# 46522                            1400.377914
# 46523                            1300.529218
# 46524                            1683.065477
#
#        Texture_Variance_Hematoxylin_7_03_256
# 0                                 850.561523
# 1                                 624.531535
# 2                                 819.948881
# 3                                1171.277847
# 4                                 928.684668
# ...                                      ...
# 46520                            1378.132307
# 46521                            2022.937578
# 46522                            1819.843827
# 46523                            1757.844843
# 46524                            1753.059649
#
# [46525 rows x 648 columns]

# %%
att_df=None
nuc_df=None
print('Count Nan before:',Xtrain.isna().sum().sum())
Xtrain.fillna(0,inplace=True)
print('Count Nan after:',Xtrain.isna().sum().sum())
# Out:
# Count Nan before: 139801
# Count Nan after: 0

# %% [markdown]
# ## Measure agreement (with a random forest classifier)
# Can the RF predict the temperature of each nucleus given only the CellProfiler features?

# %%
print(datetime.datetime.now())
print("Shuffle...")
Xtrain,ytrain=shuffle(Xtrain,ytrain)  #set random_state for reproducibility
# Out:
# 2022-06-09 12:24:00.751357
# Shuffle...

# %%
print(datetime.datetime.now())
print('Cross validation...')
rf1 = RF_Util()
rf1.set_train(Xtrain,ytrain)
cv_scores = rf1.cross_validation()
print(cv_scores)
print('Accuracy mean %.4f +/- %.4f' % (cv_scores.mean(),cv_scores.std()))
# Out:
# 2022-06-09 12:24:00.852199
# Cross validation...
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] END .................................................... total time= 1.1min
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  1.1min remaining:    0.0s
# [CV] END .................................................... total time= 1.1min
# [CV] END .................................................... total time= 1.1min
# [CV] END .................................................... total time= 1.0min
# [CV] END .................................................... total time= 1.1min
# [0.91155293 0.9130575  0.90725416 0.91112305 0.91133799]
# Accuracy mean 0.9109 +/- 0.0019
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  5.3min finished

# %% [markdown]
# ## Measure feature importance

# %%
print(datetime.datetime.now())
print('Re-train on full training set...')
rf1 = None
rf2 = RF_Util()
rf2.set_train(Xtrain,ytrain)
rf2.fit()
print(datetime.datetime.now())
print('...and rank the features by importance.')
top = rf2.important_features()
pd.set_option('display.max_rows', None)
top.loc[:200]
# Out:
# 2022-06-09 12:29:21.857263
# Re-train on full training set...
# 2022-06-09 12:30:43.491611
# ...and rank the features by importance.
#             0                                                  1
# 0    0.066514         Location_CenterMassIntensity_X_Hematoxylin
# 1    0.065837                                 AreaShape_Center_X
# 2    0.064648                                  Location_Center_X
# 3    0.061513                     AreaShape_BoundingBoxMaximum_X
# 4    0.052292                     AreaShape_BoundingBoxMinimum_X
# 5    0.048541                Location_MaxIntensity_X_Hematoxylin
# 6    0.042566         Location_CenterMassIntensity_Y_Hematoxylin
# 7    0.035003                                 AreaShape_Center_Y
# 8    0.033924                     AreaShape_BoundingBoxMinimum_Y
# 9    0.032761                                  Location_Center_Y
# 10   0.030493                     AreaShape_BoundingBoxMaximum_Y
# 11   0.030394                Location_MaxIntensity_Y_Hematoxylin
# 12   0.017640                 Neighbors_PercentTouching_Expanded
# 13   0.011388                               Number_Object_Number
# 14   0.005725        Neighbors_FirstClosestObjectNumber_Expanded
# 15   0.005107               Neighbors_NumberOfNeighbors_Expanded
# 16   0.004296       Neighbors_SecondClosestObjectNumber_Expanded
# 17   0.002504      Intensity_IntegratedIntensityEdge_Hematoxylin
# 18   0.001998        RadialDistribution_FracAtD_Hematoxylin_1of5
# 19   0.001940                     AreaShape_NormalizedMoment_1_2
# 20   0.001932           Neighbors_SecondClosestDistance_Expanded
# 21   0.001596                                   AreaShape_Extent
# 22   0.001532                     AreaShape_NormalizedMoment_2_1
# 23   0.001447                     AreaShape_NormalizedMoment_0_2
# 24   0.001444            Neighbors_FirstClosestDistance_Expanded
# 25   0.001433                     AreaShape_NormalizedMoment_2_2
# 26   0.001432           Neighbors_AngleBetweenNeighbors_Expanded
# 27   0.001430                          Granularity_1_Hematoxylin
# 28   0.001413        RadialDistribution_FracAtD_Hematoxylin_2of5
# 29   0.001400                               AreaShape_HuMoment_2
# 30   0.001392    RadialDistribution_ZernikePhase_Hematoxylin_4_2
# 31   0.001384                     AreaShape_NormalizedMoment_3_0
# 32   0.001342                     AreaShape_NormalizedMoment_3_2
# 33   0.001293                     AreaShape_NormalizedMoment_2_0
# 34   0.001249    RadialDistribution_ZernikePhase_Hematoxylin_2_2
# 35   0.001239                                 AreaShape_Solidity
# 36   0.001206                        AreaShape_CentralMoment_1_2
# 37   0.001128                        AreaShape_InertiaTensor_0_0
# 38   0.001080                        AreaShape_SpatialMoment_0_3
# 39   0.001079                     AreaShape_NormalizedMoment_2_3
# 40   0.001059        RadialDistribution_FracAtD_Hematoxylin_3of5
# 41   0.001058                     AreaShape_NormalizedMoment_0_3
# 42   0.001049                        AreaShape_CentralMoment_2_1
# 43   0.001043    RadialDistribution_ZernikePhase_Hematoxylin_1_1
# 44   0.001040        RadialDistribution_FracAtD_Hematoxylin_5of5
# 45   0.001022                        AreaShape_SpatialMoment_2_0
# 46   0.001019    RadialDistribution_ZernikePhase_Hematoxylin_6_4
# 47   0.000999                        AreaShape_SpatialMoment_0_2
# 48   0.000995    RadialDistribution_ZernikePhase_Hematoxylin_6_6
# 49   0.000992    RadialDistribution_ZernikePhase_Hematoxylin_9_5
# 50   0.000981    RadialDistribution_ZernikePhase_Hematoxylin_5_5
# 51   0.000980    RadialDistribution_ZernikePhase_Hematoxylin_8_6
# 52   0.000980  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 53   0.000979                              AreaShape_Zernike_3_1
# 54   0.000977                        AreaShape_CentralMoment_2_3
# 55   0.000976                              AreaShape_Compactness
# 56   0.000972    RadialDistribution_ZernikePhase_Hematoxylin_8_2
# 57   0.000968                              AreaShape_Zernike_6_0
# 58   0.000962    RadialDistribution_ZernikePhase_Hematoxylin_9_9
# 59   0.000961    RadialDistribution_ZernikePhase_Hematoxylin_8_4
# 60   0.000958  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 61   0.000958                              AreaShape_Zernike_7_7
# 62   0.000957                              AreaShape_Zernike_9_9
# 63   0.000957                        AreaShape_CentralMoment_0_3
# 64   0.000954                              AreaShape_Zernike_3_3
# 65   0.000954                          Granularity_2_Hematoxylin
# 66   0.000954    RadialDistribution_ZernikePhase_Hematoxylin_8_8
# 67   0.000949  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 68   0.000944    RadialDistribution_ZernikePhase_Hematoxylin_7_7
# 69   0.000944        RadialDistribution_FracAtD_Hematoxylin_4of5
# 70   0.000941    RadialDistribution_ZernikePhase_Hematoxylin_9_3
# 71   0.000941    RadialDistribution_ZernikePhase_Hematoxylin_3_1
# 72   0.000940    RadialDistribution_ZernikePhase_Hematoxylin_3_3
# 73   0.000939                               AreaShape_FormFactor
# 74   0.000938                              AreaShape_Zernike_8_2
# 75   0.000938                              AreaShape_Zernike_5_3
# 76   0.000936    RadialDistribution_ZernikePhase_Hematoxylin_7_1
# 77   0.000936                              AreaShape_Orientation
# 78   0.000936  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 79   0.000935    RadialDistribution_ZernikePhase_Hematoxylin_9_1
# 80   0.000934    RadialDistribution_ZernikePhase_Hematoxylin_5_1
# 81   0.000934                              AreaShape_Zernike_8_8
# 82   0.000933                              AreaShape_Zernike_1_1
# 83   0.000932    RadialDistribution_ZernikePhase_Hematoxylin_9_7
# 84   0.000931  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 85   0.000929    RadialDistribution_ZernikePhase_Hematoxylin_5_3
# 86   0.000926    RadialDistribution_ZernikePhase_Hematoxylin_6_2
# 87   0.000924                              AreaShape_Zernike_0_0
# 88   0.000922                              AreaShape_Zernike_8_4
# 89   0.000922                        AreaShape_SpatialMoment_1_0
# 90   0.000922  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 91   0.000918    RadialDistribution_ZernikePhase_Hematoxylin_4_4
# 92   0.000916                              AreaShape_Zernike_2_0
# 93   0.000914  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 94   0.000914                          Granularity_3_Hematoxylin
# 95   0.000913                              AreaShape_Zernike_8_6
# 96   0.000910    RadialDistribution_ZernikePhase_Hematoxylin_7_3
# 97   0.000906                              AreaShape_Zernike_5_5
# 98   0.000905  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 99   0.000903                 Texture_Correlation_Eosin_5_02_256
# 100  0.000900                              AreaShape_Zernike_9_7
# 101  0.000900  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 102  0.000900  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 103  0.000899  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 104  0.000899                              AreaShape_Zernike_8_0
# 105  0.000894  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 106  0.000894  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 107  0.000891  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 108  0.000891                              AreaShape_Zernike_9_1
# 109  0.000889                        AreaShape_InertiaTensor_1_1
# 110  0.000888  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 111  0.000887                              AreaShape_Zernike_5_1
# 112  0.000887    RadialDistribution_ZernikePhase_Hematoxylin_7_5
# 113  0.000886                 Texture_Correlation_Eosin_7_02_256
# 114  0.000886                              AreaShape_Zernike_9_5
# 115  0.000885  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 116  0.000884                              AreaShape_Zernike_6_4
# 117  0.000882                              AreaShape_Zernike_9_3
# 118  0.000882                 Texture_Correlation_Eosin_3_00_256
# 119  0.000880                              AreaShape_Zernike_7_5
# 120  0.000880  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 121  0.000879                              AreaShape_Zernike_4_0
# 122  0.000874                              AreaShape_Zernike_6_6
# 123  0.000873                              AreaShape_Zernike_7_3
# 124  0.000869  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 125  0.000869             Intensity_MassDisplacement_Hematoxylin
# 126  0.000866  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 127  0.000866  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 128  0.000861                              AreaShape_Zernike_4_4
# 129  0.000861                 Texture_Correlation_Eosin_4_01_256
# 130  0.000861                  Texture_SumAverage_Eosin_7_03_256
# 131  0.000856                 Texture_Correlation_Eosin_3_01_256
# 132  0.000854  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 133  0.000852                 Texture_Correlation_Eosin_7_00_256
# 134  0.000852                              AreaShape_Zernike_2_2
# 135  0.000852  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 136  0.000851  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 137  0.000849           Texture_Correlation_Hematoxylin_7_02_256
# 138  0.000848           Texture_Correlation_Hematoxylin_5_00_256
# 139  0.000847  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 140  0.000844           Texture_Correlation_Hematoxylin_5_02_256
# 141  0.000843                 Texture_Correlation_Eosin_7_01_256
# 142  0.000842                 Texture_Correlation_Eosin_4_03_256
# 143  0.000841           Texture_Correlation_Hematoxylin_7_01_256
# 144  0.000840                 Texture_Correlation_Eosin_3_02_256
# 145  0.000839                        AreaShape_SpatialMoment_1_3
# 146  0.000839  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 147  0.000838  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 148  0.000837       RadialDistribution_RadialCV_Hematoxylin_5of5
# 149  0.000829           Texture_Correlation_Hematoxylin_5_03_256
# 150  0.000827                 Texture_Correlation_Eosin_4_02_256
# 151  0.000826                              AreaShape_Zernike_6_2
# 152  0.000825                 Texture_Correlation_Eosin_5_00_256
# 153  0.000822                  Texture_SumAverage_Eosin_3_01_256
# 154  0.000820                 Texture_Correlation_Eosin_7_03_256
# 155  0.000818           Texture_Correlation_Hematoxylin_3_01_256
# 156  0.000816                  Texture_SumAverage_Eosin_4_00_256
# 157  0.000816  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 158  0.000812  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 159  0.000809                 Texture_Correlation_Eosin_3_03_256
# 160  0.000807       RadialDistribution_MeanFrac_Hematoxylin_2of5
# 161  0.000806                              AreaShape_Zernike_7_1
# 162  0.000805                              AreaShape_Zernike_4_2
# 163  0.000804                        AreaShape_SpatialMoment_0_1
# 164  0.000798                  Texture_SumAverage_Eosin_3_03_256
# 165  0.000798                 Texture_Correlation_Eosin_4_00_256
# 166  0.000797           Texture_Correlation_Hematoxylin_7_00_256
# 167  0.000795       RadialDistribution_RadialCV_Hematoxylin_4of5
# 168  0.000795           Texture_Correlation_Hematoxylin_5_01_256
# 169  0.000794       RadialDistribution_MeanFrac_Hematoxylin_5of5
# 170  0.000793                 Texture_Correlation_Eosin_5_01_256
# 171  0.000791  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 172  0.000790           Texture_Correlation_Hematoxylin_7_03_256
# 173  0.000790           Texture_Correlation_Hematoxylin_3_00_256
# 174  0.000789                  Texture_SumAverage_Eosin_7_02_256
# 175  0.000789                        AreaShape_SpatialMoment_2_1
# 176  0.000788           Texture_Correlation_Hematoxylin_3_02_256
# 177  0.000787           Texture_Correlation_Hematoxylin_4_01_256
# 178  0.000786       RadialDistribution_MeanFrac_Hematoxylin_1of5
# 179  0.000786       RadialDistribution_MeanFrac_Hematoxylin_3of5
# 180  0.000784                        AreaShape_CentralMoment_1_1
# 181  0.000783                 Texture_Correlation_Eosin_5_03_256
# 182  0.000780                               AreaShape_HuMoment_1
# 183  0.000778       RadialDistribution_RadialCV_Hematoxylin_1of5
# 184  0.000777             Intensity_MaxIntensityEdge_Hematoxylin
# 185  0.000777           Texture_Correlation_Hematoxylin_4_00_256
# 186  0.000777           Texture_Correlation_Hematoxylin_4_03_256
# 187  0.000776           Texture_Correlation_Hematoxylin_3_03_256
# 188  0.000773       RadialDistribution_MeanFrac_Hematoxylin_4of5
# 189  0.000772           Texture_Correlation_Hematoxylin_4_02_256
# 190  0.000769                  Texture_SumAverage_Eosin_4_02_256
# 191  0.000765                     AreaShape_NormalizedMoment_1_3
# 192  0.000762                     AreaShape_NormalizedMoment_3_1
# 193  0.000755                  Texture_SumAverage_Eosin_4_03_256
# 194  0.000754                        AreaShape_InertiaTensor_1_0
# 195  0.000754                               AreaShape_HuMoment_3
# 196  0.000751                     AreaShape_NormalizedMoment_3_3
# 197  0.000750                  Texture_SumAverage_Eosin_5_02_256
# 198  0.000749                  Texture_SumAverage_Eosin_4_01_256
# 199  0.000749                          Granularity_8_Hematoxylin
# 200  0.000747                             AreaShape_Eccentricity
