# %% [markdown]
# # Random Forest
# Try leave-one-out cross validation.

# %%
import datetime
print(datetime.datetime.now())
from platform import python_version
print('Python',python_version())
import numpy as np
import pandas as pd
import matplotlib as plt
import random
import sklearn   # pip install --upgrade scikit-learn
print('sklearn',sklearn.__version__)
# Out:
# 2022-07-19 18:07:30.583915
# Python 3.8.10
# sklearn 1.0.2

# %%
# Shuffle X,y in tandem -- can cause shape problems
from sklearn.utils import shuffle
# The model
from sklearn.ensemble import RandomForestClassifier

# This generates one split after shuffling. By default, not stratified.
# from sklearn.model_selection import train_test_split
# This does stratified K-fold cross-validation with no shuffling.
# from sklearn.model_selection import cross_val_score

#from sklearn.model_selection import RepeatedStratifiedKFold
#from sklearn.metrics import confusion_matrix
#from sklearn.feature_selection import RFE
#import joblib # used to dump/load sklearn models
#from CellProfiler_Util import CP_Util
#from RandomForestUtil import RF_Util

# %% [markdown]
# ## Prepare train and valid sets

# %%
def list_shuffle(X):   # could use skilearn shuffle instead
    L = len(X)
    for i in range(L):
        r = random.randrange(0,L)
        if i!=r:
            temp = X[i]
            X[i] = X[r]
            X[r] = temp
    return X

# %%
# Prepare to divy up patches stratified by patient.
DF_Ypos = ['B7_','B15','D1_','D5_','E7_','E9_','F9_','G3_','H13','I1_','I5_','I13']
DF_Yneg = ['A3_','A5_','B13','C1_','C11','D3_','E5_','F3_','F7_','F11','F15','G15','H1_','H3_','H7_','H15']
ALL_PATIENTS = DF_Ypos + DF_Yneg
PATIENT_TO_LABEL = {}
for patient in DF_Ypos:
    PATIENT_TO_LABEL[patient]=np.int8(1)
for patient in DF_Yneg:
    PATIENT_TO_LABEL[patient]=np.int8(0)
print('All patients',ALL_PATIENTS)
print('Count Ypos:Yneg',len(DF_Ypos),len(DF_Yneg))
# Out:
# All patients ['B7_', 'B15', 'D1_', 'D5_', 'E7_', 'E9_', 'F9_', 'G3_', 'H13', 'I1_', 'I5_', 'I13', 'A3_', 'A5_', 'B13', 'C1_', 'C11', 'D3_', 'E5_', 'F3_', 'F7_', 'F11', 'F15', 'G15', 'H1_', 'H3_', 'H7_', 'H15']
# Count Ypos:Yneg 12 16

# %%
BASE_PATH='/home/jrm/Martinez/CellProfilerRuns/CP_20220705/'
FILENAME='Filtered_Image.csv'
def load_patient(p):
    filepath=BASE_PATH+p+'/'+FILENAME
    df = pd.read_csv(filepath)
    return df

# %%
def load_patients(fold):
    train_patients = list(ALL_PATIENTS)  # this will shrink
    valid_patients = []   # this will grow
    for patient in Ypos_valid_patients[fold]:
        train_patients.remove(patient)
        valid_patients.append(patient)
    for patient in Yneg_valid_patients[fold]:
        train_patients.remove(patient)
        valid_patients.append(patient)
    return train_patients,valid_patients

# %%
# Load csv rows for one fold given list of train names (strings) and one valid name.
def load_fold(train_patients,valid_patient):
    X_train=None
    y_train=None
    X_valid=None
    y_valid=None
    z_valid=None
    for patient in train_patients:
        df = load_patient(patient)
        label = PATIENT_TO_LABEL[patient]
        if X_train is None:
            X_train = df
            y_train = np.full(shape=len(df),fill_value=label,dtype=np.int8)
        else:
            X_train = pd.concat( (X_train,df) )
            more = np.full(shape=len(df),fill_value=label,dtype=np.int8)
            y_train = np.concatenate( (y_train, more) )
    patient = valid_patient
    df = load_patient(patient)
    label = PATIENT_TO_LABEL[patient]
    X_valid = df
    y_valid = np.full(shape=len(df),fill_value=label,dtype=np.int8)
    z_valid = [patient]*len(df)  # retain patient ID for evaluation
    return X_train,y_train,X_valid,y_valid,z_valid

# %% [markdown]
# ## Random Forest

# %%
# Later, weight each patch label by the confidence i.e. score
# This is specialized for leave-one-out: num patients = 1 
def aggregate_accuracy(y_pred,z_valid):
    L = len(y_pred)
    if L != len(z_valid):
        raise Exception('Lengths of y and z do not match')
    correct = 0
    incorrect = 0
    for i in range(L):
        patient = z_valid[i]
        label = PATIENT_TO_LABEL[patient]
        pred = y_pred[i]
        if pred == label:
            correct += 1
        else:
            incorrect += 1
    numerator = correct
    denominator = correct + incorrect
    accuracy = 100.0 * numerator/denominator 
    return accuracy

# %%
patch_accuracies = []
patient_accuracies = []
NUM_FOLDS = len(ALL_PATIENTS)
for fold in range(NUM_FOLDS):
    train_patients = list(ALL_PATIENTS)
    valid_patient = train_patients[fold]
    train_patients.remove(valid_patient)
    if len(train_patients)!=len(ALL_PATIENTS)-1:
        raise Exception('Train test split not as expected!')

    print()
    print(datetime.datetime.now(),'Fold',fold,'Validate patient',valid_patient)
    X_train,y_train,X_valid,y_valid,z_valid = load_fold(train_patients,valid_patient)
    
    #print('Fold',fold,'patients train',train_patients,'patients valid',valid_patient)
    print('Fold:',fold,'patches train',X_train.shape,'patches valid',X_valid.shape)
    # CNN models are sensitive to train set order but RF models are not. 
    X_train,y_train = shuffle(X_train,y_train)
    rfc = RandomForestClassifier(min_samples_leaf=4)
    rfc.fit(X_train,y_train)  # slow
    
    y_pred = rfc.predict(X_train)
    matches = np.count_nonzero(y_train==y_pred)
    accuracy = 100.0 * matches / len(y_pred)
    print('Fold',fold,'Patch-level Training Accuracy:',accuracy)
    
    y_pred = rfc.predict(X_valid)
    matches = np.count_nonzero(y_valid==y_pred)
    accuracy = 100.0 * matches / len(y_pred)
    print('Fold',fold,'Patch-level Validation Accuracy:',accuracy)
    patch_accuracies.append(accuracy)
    
    accuracy = aggregate_accuracy(y_pred,z_valid)
    patient_accuracies.append(accuracy)
    print('Fold',fold,'Patient-level Validation Accuracy:',accuracy)
# Out:
# 2022-07-19 18:07:31.035807 Fold 0 Validate patient B7_
# Fold: 0 patches train (6675, 5305) patches valid (278, 5305)
# Fold 0 Patch-level Training Accuracy: 98.96629213483146
# Fold 0 Patch-level Validation Accuracy: 17.26618705035971
# Fold 0 Patient-level Validation Accuracy: 17.26618705035971
#
# 2022-07-19 18:07:58.907809 Fold 1 Validate patient B15
# Fold: 1 patches train (6688, 5305) patches valid (265, 5305)
# Fold 1 Patch-level Training Accuracy: 99.11782296650718
# Fold 1 Patch-level Validation Accuracy: 36.9811320754717
# Fold 1 Patient-level Validation Accuracy: 36.9811320754717
#
# 2022-07-19 18:08:28.633857 Fold 2 Validate patient D1_
# Fold: 2 patches train (6667, 5305) patches valid (286, 5305)
# Fold 2 Patch-level Training Accuracy: 99.35503224838759
# Fold 2 Patch-level Validation Accuracy: 48.6013986013986
# Fold 2 Patient-level Validation Accuracy: 48.6013986013986
#
# 2022-07-19 18:08:59.190746 Fold 3 Validate patient D5_
# Fold: 3 patches train (6701, 5305) patches valid (252, 5305)
# Fold 3 Patch-level Training Accuracy: 99.19415012684674
# Fold 3 Patch-level Validation Accuracy: 41.26984126984127
# Fold 3 Patient-level Validation Accuracy: 41.26984126984127
#
# 2022-07-19 18:09:32.408225 Fold 4 Validate patient E7_
# Fold: 4 patches train (6750, 5305) patches valid (203, 5305)
# Fold 4 Patch-level Training Accuracy: 99.24444444444444
# Fold 4 Patch-level Validation Accuracy: 66.00985221674877
# Fold 4 Patient-level Validation Accuracy: 66.00985221674877
#
# 2022-07-19 18:10:02.257690 Fold 5 Validate patient E9_
# Fold: 5 patches train (6660, 5305) patches valid (293, 5305)
# Fold 5 Patch-level Training Accuracy: 99.50450450450451
# Fold 5 Patch-level Validation Accuracy: 97.61092150170649
# Fold 5 Patient-level Validation Accuracy: 97.61092150170649
#
# 2022-07-19 18:10:29.884263 Fold 6 Validate patient F9_
# Fold: 6 patches train (6644, 5305) patches valid (309, 5305)
# Fold 6 Patch-level Training Accuracy: 99.2173389524383
# Fold 6 Patch-level Validation Accuracy: 22.006472491909385
# Fold 6 Patient-level Validation Accuracy: 22.006472491909385
#
# 2022-07-19 18:10:57.413340 Fold 7 Validate patient G3_
# Fold: 7 patches train (6801, 5305) patches valid (152, 5305)
# Fold 7 Patch-level Training Accuracy: 99.41185119835319
# Fold 7 Patch-level Validation Accuracy: 49.3421052631579
# Fold 7 Patient-level Validation Accuracy: 49.3421052631579
#
# 2022-07-19 18:11:24.744305 Fold 8 Validate patient H13
# Fold: 8 patches train (6744, 5305) patches valid (209, 5305)
# Fold 8 Patch-level Training Accuracy: 99.28825622775801
# Fold 8 Patch-level Validation Accuracy: 45.45454545454545
# Fold 8 Patient-level Validation Accuracy: 45.45454545454545
#
# 2022-07-19 18:11:52.460917 Fold 9 Validate patient I1_
# Fold: 9 patches train (6700, 5305) patches valid (253, 5305)
# Fold 9 Patch-level Training Accuracy: 99.32835820895522
# Fold 9 Patch-level Validation Accuracy: 41.89723320158103
# Fold 9 Patient-level Validation Accuracy: 41.89723320158103
#
# 2022-07-19 18:12:19.148732 Fold 10 Validate patient I5_
# Fold: 10 patches train (6684, 5305) patches valid (269, 5305)
# Fold 10 Patch-level Training Accuracy: 99.43147815679234
# Fold 10 Patch-level Validation Accuracy: 64.31226765799256
# Fold 10 Patient-level Validation Accuracy: 64.31226765799256
#
# 2022-07-19 18:12:45.970709 Fold 11 Validate patient I13
# Fold: 11 patches train (6703, 5305) patches valid (250, 5305)
# Fold 11 Patch-level Training Accuracy: 99.20930926450843
# Fold 11 Patch-level Validation Accuracy: 27.6
# Fold 11 Patient-level Validation Accuracy: 27.6
#
# 2022-07-19 18:13:12.946563 Fold 12 Validate patient A3_
# Fold: 12 patches train (6737, 5305) patches valid (216, 5305)
# Fold 12 Patch-level Training Accuracy: 99.24298649250409
# Fold 12 Patch-level Validation Accuracy: 50.925925925925924
# Fold 12 Patient-level Validation Accuracy: 50.925925925925924
#
# 2022-07-19 18:13:39.783762 Fold 13 Validate patient A5_
# Fold: 13 patches train (6750, 5305) patches valid (203, 5305)
# Fold 13 Patch-level Training Accuracy: 99.39259259259259
# Fold 13 Patch-level Validation Accuracy: 87.6847290640394
# Fold 13 Patient-level Validation Accuracy: 87.6847290640394
#
# 2022-07-19 18:14:06.968127 Fold 14 Validate patient B13
# Fold: 14 patches train (6698, 5305) patches valid (255, 5305)
# Fold 14 Patch-level Training Accuracy: 99.47745595700209
# Fold 14 Patch-level Validation Accuracy: 95.29411764705883
# Fold 14 Patient-level Validation Accuracy: 95.29411764705883
#
# 2022-07-19 18:14:33.782773 Fold 15 Validate patient C1_
# Fold: 15 patches train (6724, 5305) patches valid (229, 5305)
# Fold 15 Patch-level Training Accuracy: 99.39024390243902
# Fold 15 Patch-level Validation Accuracy: 56.33187772925764
# Fold 15 Patient-level Validation Accuracy: 56.33187772925764
#
# 2022-07-19 18:15:01.019924 Fold 16 Validate patient C11
# Fold: 16 patches train (6660, 5305) patches valid (293, 5305)
# Fold 16 Patch-level Training Accuracy: 99.54954954954955
# Fold 16 Patch-level Validation Accuracy: 92.4914675767918
# Fold 16 Patient-level Validation Accuracy: 92.4914675767918
#
# 2022-07-19 18:15:27.628884 Fold 17 Validate patient D3_
# Fold: 17 patches train (6743, 5305) patches valid (210, 5305)
# Fold 17 Patch-level Training Accuracy: 99.42162242325375
# Fold 17 Patch-level Validation Accuracy: 35.23809523809524
# Fold 17 Patient-level Validation Accuracy: 35.23809523809524
#
# 2022-07-19 18:15:54.998034 Fold 18 Validate patient E5_
# Fold: 18 patches train (6683, 5305) patches valid (270, 5305)
# Fold 18 Patch-level Training Accuracy: 99.37153972766721
# Fold 18 Patch-level Validation Accuracy: 37.407407407407405
# Fold 18 Patient-level Validation Accuracy: 37.407407407407405
#
# 2022-07-19 18:16:21.005988 Fold 19 Validate patient F3_
# Fold: 19 patches train (6703, 5305) patches valid (250, 5305)
# Fold 19 Patch-level Training Accuracy: 99.49276443383559
# Fold 19 Patch-level Validation Accuracy: 77.2
# Fold 19 Patient-level Validation Accuracy: 77.2
#
# 2022-07-19 18:16:49.145935 Fold 20 Validate patient F7_
# Fold: 20 patches train (6713, 5305) patches valid (240, 5305)
# Fold 20 Patch-level Training Accuracy: 99.27007299270073
# Fold 20 Patch-level Validation Accuracy: 32.916666666666664
# Fold 20 Patient-level Validation Accuracy: 32.916666666666664
#
# 2022-07-19 18:17:19.145650 Fold 21 Validate patient F11
# Fold: 21 patches train (6711, 5305) patches valid (242, 5305)
# Fold 21 Patch-level Training Accuracy: 99.4188645507376
# Fold 21 Patch-level Validation Accuracy: 86.77685950413223
# Fold 21 Patient-level Validation Accuracy: 86.77685950413223
#
# 2022-07-19 18:17:48.671586 Fold 22 Validate patient F15
# Fold: 22 patches train (6669, 5305) patches valid (284, 5305)
# Fold 22 Patch-level Training Accuracy: 99.52016794122058
# Fold 22 Patch-level Validation Accuracy: 91.90140845070422
# Fold 22 Patient-level Validation Accuracy: 91.90140845070422
#
# 2022-07-19 18:18:16.712458 Fold 23 Validate patient G15
# Fold: 23 patches train (6705, 5305) patches valid (248, 5305)
# Fold 23 Patch-level Training Accuracy: 99.2841163310962
# Fold 23 Patch-level Validation Accuracy: 63.70967741935484
# Fold 23 Patient-level Validation Accuracy: 63.70967741935484
#
# 2022-07-19 18:18:44.261682 Fold 24 Validate patient H1_
# Fold: 24 patches train (6676, 5305) patches valid (277, 5305)
# Fold 24 Patch-level Training Accuracy: 99.46075494307969
# Fold 24 Patch-level Validation Accuracy: 98.91696750902527
# Fold 24 Patient-level Validation Accuracy: 98.91696750902527
#
# 2022-07-19 18:19:11.109860 Fold 25 Validate patient H3_
# Fold: 25 patches train (6692, 5305) patches valid (261, 5305)
# Fold 25 Patch-level Training Accuracy: 99.35744172145846
# Fold 25 Patch-level Validation Accuracy: 92.33716475095785
# Fold 25 Patient-level Validation Accuracy: 92.33716475095785
#
# 2022-07-19 18:19:37.729864 Fold 26 Validate patient H7_
# Fold: 26 patches train (6731, 5305) patches valid (222, 5305)
# Fold 26 Patch-level Training Accuracy: 99.46516119447334
# Fold 26 Patch-level Validation Accuracy: 91.89189189189189
# Fold 26 Patient-level Validation Accuracy: 91.89189189189189
#
# 2022-07-19 18:20:04.214335 Fold 27 Validate patient H15
# Fold: 27 patches train (6719, 5305) patches valid (234, 5305)
# Fold 27 Patch-level Training Accuracy: 99.38979014734335
# Fold 27 Patch-level Validation Accuracy: 66.66666666666667
# Fold 27 Patient-level Validation Accuracy: 66.66666666666667

# %%
print(datetime.datetime.now())
print('Cross validation patch-level accuracy:',patch_accuracies)
print('mean:',np.mean(patch_accuracies),'std:',np.std(patch_accuracies))
print('Cross validation patient-level accuracy:',patient_accuracies)
print('mean:',np.mean(patient_accuracies),'std:',np.std(patient_accuracies))
# Out:
# 2022-07-19 18:20:31.366558
# Cross validation patch-level accuracy: [17.26618705035971, 36.9811320754717, 48.6013986013986, 41.26984126984127, 66.00985221674877, 97.61092150170649, 22.006472491909385, 49.3421052631579, 45.45454545454545, 41.89723320158103, 64.31226765799256, 27.6, 50.925925925925924, 87.6847290640394, 95.29411764705883, 56.33187772925764, 92.4914675767918, 35.23809523809524, 37.407407407407405, 77.2, 32.916666666666664, 86.77685950413223, 91.90140845070422, 63.70967741935484, 98.91696750902527, 92.33716475095785, 91.89189189189189, 66.66666666666667]
# mean: 61.28724572259602 std: 25.41975235700361
# Cross validation patient-level accuracy: [17.26618705035971, 36.9811320754717, 48.6013986013986, 41.26984126984127, 66.00985221674877, 97.61092150170649, 22.006472491909385, 49.3421052631579, 45.45454545454545, 41.89723320158103, 64.31226765799256, 27.6, 50.925925925925924, 87.6847290640394, 95.29411764705883, 56.33187772925764, 92.4914675767918, 35.23809523809524, 37.407407407407405, 77.2, 32.916666666666664, 86.77685950413223, 91.90140845070422, 63.70967741935484, 98.91696750902527, 92.33716475095785, 91.89189189189189, 66.66666666666667]
# mean: 61.28724572259602 std: 25.41975235700361
