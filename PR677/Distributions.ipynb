# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
mu, sigma = 0, 1 
s = np.random.normal(mu, sigma, 1000)
count, bins, ignored = plt.hist(s, 30, density=True)
print("bins=\n",bins)
print("counts=\n",count)
plt.show()
# Out:
# bins=
#  [-3.51628608 -3.27899008 -3.04169409 -2.80439809 -2.56710209 -2.3298061
#  -2.0925101  -1.85521411 -1.61791811 -1.38062212 -1.14332612 -0.90603012
#  -0.66873413 -0.43143813 -0.19414214  0.04315386  0.28044986  0.51774585
#   0.75504185  0.99233784  1.22963384  1.46692984  1.70422583  1.94152183
#   2.17881782  2.41611382  2.65340982  2.89070581  3.12800181  3.3652978
#   3.6025938 ]
# counts=
#  [0.00842829 0.00421415 0.         0.02107073 0.03371317 0.03371317
#  0.04214146 0.09271121 0.11799609 0.18120828 0.24442047 0.2739195
#  0.3202751  0.36241657 0.41298632 0.37084486 0.35398827 0.3202751
#  0.26970535 0.2739195  0.15592341 0.11378195 0.06742634 0.0547839
#  0.03371317 0.01264244 0.02528488 0.00842829 0.         0.00421415]

# %%
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
               np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
         linewidth=2, color='r')
plt.show()

# %%
plt.hist(s, 30, density=True)
var = sigma**2
plt.plot(bins, 1/(np.sqrt(2 * np.pi * var)) *
               np.exp( (-1/2) * (bins - mu)**2 / var ),
         linewidth=2, color='r')
plt.show()
