# %% [markdown]
# Maximum likelihood estimation

# %%
from os import listdir
import numpy as np
import pandas as pd
from scipy.stats import norm

# %%
pathR='data/ChunkedData_R/'
pathN='data/ChunkedData_NR/'
filesR = listdir(pathR)
filesN = listdir(pathN)
filesR[0]
# Out:
# 'Daily_2060_S3.csv'

# %%
# Read one CSV file. Drop the date column.
def file_mean (filepath):
    mydata = pd.read_csv(filepath)
    # Drop the date column.
    mydata = mydata.drop('Date',axis=1) 
    # Transpose column of mean values into a row.
    mymean = mydata.mean(axis=0).to_frame().T
    return mymean

# %%
# Read directory of CSV files. Retain only one row per file = column averages.
def mean_per_file (directory):
    files = listdir(directory)
    means = pd.DataFrame()
    for fp in files:
        dfp = directory+fp
        m = file_mean(dfp)
        # Let Pandas number the rows sequentially.
        means = means.append(m,ignore_index=True)
    return means

# %%
meansR = mean_per_file(pathR)
meansN = mean_per_file(pathN)
meansAll = pd.concat((meansR,meansN),ignore_index=True)

# %%
def make_question_features(X):
    c = X.columns[:13] # Excel columns B-N
    z = X[c]
    return np.asarray(z)
def make_physiol_features(X):
    c = X.columns[249:] # Excel columns IQ-IZ
    z = X[c]
    return np.asarray(z)
X_questionFeatures_R = make_question_features(meansR)
X_questionFeatures_N = make_question_features(meansN)
X_physiolFeatures_R = make_physiol_features(meansR)
X_physiolFeatures_N = make_physiol_features(meansN)

# %%
# Mean vector should have 13 features
np.mean(X_questionFeatures_R,axis=0)
# Out:
# array([2.77162962, 2.70476552, 3.68423888, 3.42797521, 2.39332778,
#        4.36899756, 3.6862858 , 3.51347216, 2.73680122, 2.42942592,
#        3.47397681, 2.99122293, 2.72413645])

# %%
# Confirm the mean for the first feature
s = 0
num = len(X_questionFeatures_R)
for vec in X_questionFeatures_R:
    v = vec[0]
    s = s + v
print ("mean=",s/num)
# Out:
# mean= 2.771629620151788

# %%
# Get four mean vectors
mean_Q_R = np.mean(X_questionFeatures_R,axis=0)
mean_Q_N = np.mean(X_questionFeatures_N,axis=0)
mean_P_R = np.mean(X_physiolFeatures_R,axis=0)
mean_P_N = np.mean(X_physiolFeatures_N,axis=0)
print("Features=BN, Class=R")
print(mean_Q_R)
print("Features=BN, Class=N")
print(mean_Q_N)
print("Features=IQIZ, Class=R")
print(mean_P_R)
print("Features=IQIZ, Class=N")
print(mean_P_N)
# Out:
# Features=BN, Class=R
# [2.77162962 2.70476552 3.68423888 3.42797521 2.39332778 4.36899756
#  3.6862858  3.51347216 2.73680122 2.42942592 3.47397681 2.99122293
#  2.72413645]
# Features=BN, Class=N
# [2.98212268 2.88884591 4.23550324 3.53718177 2.1989232  4.30800458
#  4.27954876 4.20733162 3.08629637 2.49876146 4.21626721 3.31846817
#  3.56183687]
# Features=IQIZ, Class=R
# [ 79.32724741 168.02242085  12.35867154   0.78748283   0.6629929
#   30.62998668 449.66925538  20.4576429    0.91754963   0.61243098]
# Features=IQIZ, Class=N
# [ 76.61158267 159.97559128  11.96003637   0.68312697   0.56079015
#   30.68924129 401.67052684  18.86156023   0.78119817   1.11272882]

# %%
# Get four covariance matrices
# Get four mean vectors
cov_Q_R = np.cov(X_questionFeatures_R,rowvar=False)
cov_Q_N = np.cov(X_questionFeatures_N,rowvar=False)
cov_P_R = np.cov(X_physiolFeatures_R,rowvar=False)
cov_P_N = np.cov(X_physiolFeatures_N,rowvar=False)
print("Features=BN, Class=R")
print(cov_Q_R)
print("Features=BN, Class=N")
print(cov_Q_N)
print("Features=IQIZ, Class=R")
print(cov_P_R)
print("Features=IQIZ, Class=N")
print(cov_P_N)
# Out:
# Features=BN, Class=R
# [[ 1.79355001 -0.98040806 -1.26485279  0.13415504  0.83840107 -0.21111466
#   -1.12799672 -1.32056846 -0.79506226 -0.1642217  -1.52590787  0.23307538
#    0.86425508]
#  [-0.98040806  1.24438612  1.12579471 -0.4226461  -0.66674278  0.06464912
#    1.0041908   1.15076669  0.10971841 -0.4987404   0.44255833 -0.43092002
#   -0.21135111]
#  [-1.26485279  1.12579471  1.4550986  -0.36456781 -0.9125852   0.19354764
#    1.42248298  1.51454896  0.7523408   0.15892811  1.17408764 -0.54382239
#   -0.62314824]
#  [ 0.13415504 -0.4226461  -0.36456781  1.23959089  0.4785619   0.44330704
#   -0.2108463  -0.23043295  0.20986097  0.22338362  0.70024025  1.20345417
#    0.46990031]
#  [ 0.83840107 -0.66674278 -0.9125852   0.4785619   0.79873281  0.10859196
#   -0.85721632 -0.90691378 -0.5850454  -0.28303296 -0.77855001  0.65667014
#    0.7353295 ]
#  [-0.21111466  0.06464912  0.19354764  0.44330704  0.10859196  0.49307767
#    0.30349457  0.30135852  0.21972785  0.0815126   0.50192056  0.52816827
#    0.34035503]
#  [-1.12799672  1.0041908   1.42248298 -0.2108463  -0.85721632  0.30349457
#    1.49241642  1.49138009  0.80305811  0.26885004  1.27526895 -0.38120245
#   -0.45221788]
#  [-1.32056846  1.15076669  1.51454896 -0.23043295 -0.90691378  0.30135852
#    1.49138009  1.61909049  0.86984056  0.23449818  1.34503882 -0.42195197
#   -0.59657385]
#  [-0.79506226  0.10971841  0.7523408   0.20986097 -0.5850454   0.21972785
#    0.80305811  0.86984056  1.31674811  1.11066749  1.57335557 -0.15041359
#   -0.95751024]
#  [-0.1642217  -0.4987404   0.15892811  0.22338362 -0.28303296  0.0815126
#    0.26885004  0.23449818  1.11066749  1.32771775  1.10015991 -0.0689792
#   -0.78835524]
#  [-1.52590787  0.44255833  1.17408764  0.70024025 -0.77855001  0.50192056
#    1.27526895  1.34503882  1.57335557  1.10015991  2.52681503  0.37975785
#   -0.93800596]
#  [ 0.23307538 -0.43092002 -0.54382239  1.20345417  0.65667014  0.52816827
#   -0.38120245 -0.42195197 -0.15041359 -0.0689792   0.37975785  1.46083395
#    0.83857721]
#  [ 0.86425508 -0.21135111 -0.62314824  0.46990031  0.7353295   0.34035503
#   -0.45221788 -0.59657385 -0.95751024 -0.78835524 -0.93800596  0.83857721
#    1.45008225]]
# Features=BN, Class=N
# [[ 1.67907871  1.27317982 -0.26448816  1.21692934  0.6421792  -0.23600975
#   -0.21687628 -0.19910694  1.60693679  1.43085458 -0.16122686  1.32045007
#    1.21962923]
#  [ 1.27317982  1.42905854 -0.38451115  1.09929521  0.83738226 -0.32080514
#   -0.3241071  -0.36968473  1.28677394  1.01532736 -0.43433974  1.19552994
#    1.0953722 ]
#  [-0.26448816 -0.38451115  0.56127229 -0.17301991  0.07283409  0.3702963
#    0.49688696  0.63769682  0.15038993 -0.1128397   0.69910783 -0.07277925
#   -0.13409925]
#  [ 1.21692934  1.09929521 -0.17301991  1.1971728   0.64816679 -0.13890227
#   -0.10180388 -0.09687282  1.32889794  1.0813301  -0.05254028  1.22662846
#    1.19191202]
#  [ 0.6421792   0.83738226  0.07283409  0.64816679  1.50270306 -0.1448981
#   -0.09375238  0.0297897   1.03503093  0.27313233 -0.04161845  0.69316204
#    0.61443622]
#  [-0.23600975 -0.32080514  0.3702963  -0.13890227 -0.1448981   0.36684454
#    0.43893203  0.48082277 -0.01073625 -0.16354459  0.49596205 -0.05288987
#   -0.10210044]
#  [-0.21687628 -0.3241071   0.49688696 -0.10180388 -0.09375238  0.43893203
#    0.57631737  0.64833234  0.14928725 -0.05376701  0.66774049  0.03743796
#   -0.04097889]
#  [-0.19910694 -0.36968473  0.63769682 -0.09687282  0.0297897   0.48082277
#    0.64833234  0.79913104  0.28911219  0.03809969  0.83997532  0.06820228
#   -0.03963863]
#  [ 1.60693679  1.28677394  0.15038993  1.32889794  1.03503093 -0.01073625
#    0.14928725  0.28911219  2.17667657  1.65407169  0.40487868  1.54424354
#    1.34406797]
#  [ 1.43085458  1.01532736 -0.1128397   1.0813301   0.27313233 -0.16354459
#   -0.05376701  0.03809969  1.65407169  1.9777316   0.10720237  1.25608402
#    1.07738203]
#  [-0.16122686 -0.43433974  0.69910783 -0.05254028 -0.04161845  0.49596205
#    0.66774049  0.83997532  0.40487868  0.10720237  1.02246569  0.05808343
#   -0.00535765]
#  [ 1.32045007  1.19552994 -0.07277925  1.22662846  0.69316204 -0.05288987
#    0.03743796  0.06820228  1.54424354  1.25608402  0.05808343  1.45422875
#    1.25872625]
#  [ 1.21962923  1.0953722  -0.13409925  1.19191202  0.61443622 -0.10210044
#   -0.04097889 -0.03963863  1.34406797  1.07738203 -0.00535765  1.25872625
#    1.22154024]]
# Features=IQIZ, Class=R
# [[ 1.42063049e+01 -5.28385008e+01 -1.67439154e+00 -5.35088015e-01
#   -9.07549895e-01  8.99247979e+00 -8.60362100e+01 -1.41784579e+00
#   -5.06772533e-01 -4.08484614e-01]
#  [-5.28385008e+01  3.75510003e+03  1.39667495e+02  1.07082773e+01
#    2.25345392e+01  1.26274884e+02  5.32279154e+03  1.19734180e+02
#   -5.02462794e+00 -2.00832656e+01]
#  [-1.67439154e+00  1.39667495e+02  5.24098375e+00  4.05533291e-01
#    8.31142792e-01  5.16148990e+00  1.98381165e+02  4.52994047e+00
#   -2.07450031e-01 -8.01897921e-01]
#  [-5.35088015e-01  1.07082773e+01  4.05533291e-01  7.44715032e-02
#    1.52621293e-01  9.97278042e-02  1.74108780e+01  4.07649202e-01
#    9.91044720e-03 -3.25608751e-02]
#  [-9.07549895e-01  2.25345392e+01  8.31142792e-01  1.52621293e-01
#    4.48230083e-01  2.39469232e-01  3.41783365e+01  7.59712397e-01
#    2.50615118e-02 -5.77056291e-02]
#  [ 8.99247979e+00  1.26274884e+02  5.16148990e+00  9.97278042e-02
#    2.39469232e-01  2.19355019e+01  2.90935294e+02  7.35575196e+00
#   -1.13214697e+00 -2.59521821e+00]
#  [-8.60362100e+01  5.32279154e+03  1.98381165e+02  1.74108780e+01
#    3.41783365e+01  2.90935294e+02  1.10257929e+04  2.56781390e+02
#   -1.46929924e+01 -5.24897190e+01]
#  [-1.41784579e+00  1.19734180e+02  4.52994047e+00  4.07649202e-01
#    7.59712397e-01  7.35575196e+00  2.56781390e+02  6.16918974e+00
#   -3.80943567e-01 -1.39048855e+00]
#  [-5.06772533e-01 -5.02462794e+00 -2.07450031e-01  9.91044720e-03
#    2.50615118e-02 -1.13214697e+00 -1.46929924e+01 -3.80943567e-01
#    7.21717596e-02  1.83206174e-01]
#  [-4.08484614e-01 -2.00832656e+01 -8.01897921e-01 -3.25608751e-02
#   -5.77056291e-02 -2.59521821e+00 -5.24897190e+01 -1.39048855e+00
#    1.83206174e-01  6.80366793e-01]]
# Features=IQIZ, Class=N
# [[ 2.96118362e+01 -1.12513442e+02 -3.52217879e+00 -8.27138159e-01
#   -1.00462868e+00  1.94978341e+01  1.79303077e+01 -5.99883669e-01
#   -6.65293566e-01  1.26737601e+00]
#  [-1.12513442e+02  6.57746708e+03  2.38151397e+02 -2.82853007e+00
#   -1.28070363e+01  1.80700480e+02  1.08938635e+04  3.03558402e+02
#   -9.10719803e+00 -8.84188676e+01]
#  [-3.52217879e+00  2.38151397e+02  8.76528585e+00 -1.62261423e-01
#   -6.45159683e-01  7.62179261e+00  4.19302698e+02  1.17263168e+01
#   -3.55223199e-01 -3.35720869e+00]
#  [-8.27138159e-01 -2.82853007e+00 -1.62261423e-01  8.07155592e-02
#    1.61399398e-01 -1.39536732e+00 -2.74254398e+01 -7.57847311e-01
#    7.47938228e-02  2.25252948e-01]
#  [-1.00462868e+00 -1.28070363e+01 -6.45159683e-01  1.61399398e-01
#    8.07060305e-01  1.18815157e-02 -4.59498013e+01 -1.19814645e+00
#   -5.23790598e-02  1.39327066e-01]
#  [ 1.94978341e+01  1.80700480e+02  7.62179261e+00 -1.39536732e+00
#    1.18815157e-02  7.23099645e+01  1.15512183e+03  3.11956857e+01
#   -4.15895846e+00 -1.14675639e+01]
#  [ 1.79303077e+01  1.08938635e+04  4.19302698e+02 -2.74254398e+01
#   -4.59498013e+01  1.15512183e+03  3.34329692e+04  9.22784056e+02
#   -6.81526671e+01 -3.19732264e+02]
#  [-5.99883669e-01  3.03558402e+02  1.17263168e+01 -7.57847311e-01
#   -1.19814645e+00  3.11956857e+01  9.22784056e+02  2.58282085e+01
#   -1.82322058e+00 -8.99604837e+00]
#  [-6.65293566e-01 -9.10719803e+00 -3.55223199e-01  7.47938228e-02
#   -5.23790598e-02 -4.15895846e+00 -6.81526671e+01 -1.82322058e+00
#    2.83803540e-01  7.81404575e-01]
#  [ 1.26737601e+00 -8.84188676e+01 -3.35720869e+00  2.25252948e-01
#    1.39327066e-01 -1.14675639e+01 -3.19732264e+02 -8.99604837e+00
#    7.81404575e-01  3.70472458e+00]]

# %%
print(mean_Q_R.shape)
print(cov_Q_R.shape)
print(X_questionFeatures_R.shape)
print(X_questionFeatures_R.shape[0])
norm.pdf(X_questionFeatures_R[0],mean_Q_R,cov_Q_R)
D_Q_R = norm(mean_Q_R,cov_Q_R)
print(D_Q_R.pdf(X_questionFeatures_R.shape[0]))
# Out:
# (13,)
# (13, 13)
# (14, 13)
# 14
# [[6.86411527e-010             nan             nan 0.00000000e+000
#   1.15054789e-042             nan             nan             nan
#               nan             nan             nan 0.00000000e+000
#   5.02373099e-038]
#  [            nan 4.12059224e-019 2.07623603e-019             nan
#               nan 0.00000000e+000 4.93114649e-024 3.22071810e-019
#   0.00000000e+000             nan 1.30118695e-123             nan
#               nan]
#  [            nan 4.90508124e-023 3.34439353e-012             nan
#               nan 0.00000000e+000 1.07766505e-012 1.02474945e-011
#   1.13743118e-049 0.00000000e+000 1.19600684e-018             nan
#               nan]
#  [0.00000000e+000             nan             nan 5.16225813e-017
#   1.55164705e-128 2.90175308e-103             nan             nan
#   0.00000000e+000 0.00000000e+000 4.88359741e-050 2.23722405e-019
#   7.77625679e-126]
#  [5.36476402e-040             nan             nan 8.87498895e-107
#   7.00840893e-047 0.00000000e+000             nan             nan
#               nan             nan             nan 5.67971252e-062
#   4.71360128e-052]
#  [            nan 0.00000000e+000 0.00000000e+000 2.85618203e-124
#   0.00000000e+000 1.15592810e-083 2.21145672e-251 1.53239258e-263
#   0.00000000e+000 0.00000000e+000 2.50126718e-096 3.46640348e-095
#   5.40770405e-239]
#  [            nan 1.33566709e-028 1.06647880e-012             nan
#               nan 2.79007679e-219 1.13869174e-011 4.91311990e-012
#   9.56803358e-044 0.00000000e+000 5.02944730e-016             nan
#               nan]
#  [            nan 4.16399209e-022 2.22279019e-011             nan
#               nan 2.17645393e-222 1.10227568e-011 1.91662996e-010
#   1.79196468e-037 0.00000000e+000 1.49055712e-014             nan
#               nan]
#  [            nan 0.00000000e+000 7.93156890e-042 0.00000000e+000
#               nan 0.00000000e+000 7.56922806e-037 1.26289075e-032
#   3.92004725e-017 9.74487192e-025 4.84075076e-011             nan
#               nan]
#  [            nan             nan 0.00000000e+000 0.00000000e+000
#               nan 0.00000000e+000 4.00637832e-320 0.00000000e+000
#   1.67589935e-023 9.69596754e-018 4.80304026e-021             nan
#               nan]
#  [            nan 3.19645093e-142 5.86207744e-018 1.81522730e-050
#               nan 8.88471879e-081 1.96011099e-015 1.87482233e-014
#   1.88758051e-012 3.47206707e-025 2.69226805e-005 3.46619551e-183
#               nan]
#  [0.00000000e+000             nan             nan 5.79283361e-018
#   8.81498037e-069 4.73764812e-073             nan             nan
#               nan             nan 1.56029916e-167 1.27170767e-013
#   2.60484293e-040]
#  [1.02741039e-037             nan             nan 1.03118664e-110
#   4.29900886e-055 1.56912988e-174             nan             nan
#               nan             nan             nan 1.79348560e-038
#   2.03891102e-014]]

# %%
def pdf_multivariate_gauss(x, mu, cov):
    part1 = 1 / ( ((2* np.pi)**(len(mu)/2)) * (np.linalg.det(cov)**(1/2)) )
    part2 = (-1/2) * ((x-mu).T.dot(np.linalg.inv(cov))).dot((x-mu))
    return float(part1 * np.exp(part2))
print(pdf_multivariate_gauss(X_questionFeatures_R.shape[0],mean_Q_R,cov_Q_R))
# Out:
# nan
# <ipython-input-21-7ef4bd02579a>:2: RuntimeWarning: invalid value encountered in double_scalars
#   part1 = 1 / ( ((2* np.pi)**(len(mu)/2)) * (np.linalg.det(cov)**(1/2)) )
# <ipython-input-21-7ef4bd02579a>:4: RuntimeWarning: overflow encountered in exp
#   return float(part1 * np.exp(part2))
