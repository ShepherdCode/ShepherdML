# %% [markdown]
# # MLP
#
# Compare MLP to LSTM on same data.
# Compare to LSTM notebook 113.
# K=3.
# Normalized K-mer counts.
# Two-layer MLP.

# %% [markdown]
# ## Environment setup

# %%
from datetime import datetime
print(datetime.now())
from platform import python_version
print('Python',python_version())
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt 
import sklearn   # pip install --upgrade scikit-learn
print('sklearn',sklearn.__version__)
# Out:
# 2022-11-21 15:30:45.138602
# Python 3.7.15
# sklearn 1.0.2

# %%
import tensorflow as tf
dt='float32'
tf.keras.backend.set_floatx('float32')
tf.random.set_seed(42) 

from tensorflow import keras
from sklearn.model_selection import KFold
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.losses import BinaryCrossentropy

K=3
EPOCHS=100
FOLDS=5  
BREAK = False   # break after first fold
MAXLEN=4000   # this is problematic as some genes will be excluded entirely or partially
MINLEN=1000

# %%
try:
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATA_DIR=PATH+'My Drive/data/Localization/TrainTest/'  # must end in "/"
except:
    IN_COLAB = False
    DATA_DIR = '/Users/jasonmiller/WVU/Localization/TrainTest/'    # Mac
    DATA_DIR = 'D:/Adjeroh/Localization/TrainTest/'   # Windows
print(DATA_DIR)
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /content/drive/My Drive/data/Localization/TrainTest/

# %%
GENES_FILE =    'CNRCI_coding_train_genes.csv'
RCI_FILE =      'CNRCI_coding_train_RCI.gc42.csv'
SEQUENCE_FILE = 'CNRCI_coding_train_transcripts.gc42.csv'
COUNTS_FILE=    'CNRCI_coding_train_counts.K3.gc42.csv'   # K=3

# %%
def get_ordered_list():
    ordered_list = \
    ['A549',\
      'H1.hESC',\
      'HeLa.S3',\
      'HepG2',\
      'HT1080',\
      'HUVEC',\
      'MCF.7',\
      'NCI.H460',\
      'NHEK',\
      'SK.MEL.5',\
      'SK.N.DZ',\
      'SK.N.SH',\
      'GM12878',\
      'K562',\
      'IMR.90']
    return ordered_list
CELL_LINE_NUMBER=1
all_cell_lines = get_ordered_list()
cell_line_name = all_cell_lines[CELL_LINE_NUMBER]
print('Cell line for today:',CELL_LINE_NUMBER,'=',cell_line_name)
# Out:
# Cell line for today: 1 = H1.hESC

# %% [markdown]
# ## Data Load

# %%
print(datetime.now())
# labels
filepath = DATA_DIR+RCI_FILE
gene_to_rci = {}
with open (filepath,'r') as handle:
    header = None
    for row in handle:
        if header is None:
            header = row
        else:
            line = row.strip()
            fields = line.split(',')
            gene_id = fields[0]
            rci_val = fields[CELL_LINE_NUMBER+1]
            # Could implement Gudenas style threshold here
            if rci_val != "nan":
                gene_to_rci[gene_id] = float(rci_val)
print('Num RCI:', len(gene_to_rci.keys()))
print(list(gene_to_rci.items())[:3])
all_genes = list(gene_to_rci.keys())
# Out:
# 2022-11-21 15:30:46.495308
# Num RCI: 13000
# [('ENSG00000000003', 1.85734), ('ENSG00000000005', 5.88264), ('ENSG00000000419', 2.58954)]

# %%
# kmer counts
print(datetime.now())
filepath = DATA_DIR+COUNTS_FILE
labels=[]
allids=[]
counts=[]
with open (filepath,'r') as handle:
    header = None
    for row in handle:
        if header is None:
            header = row
        else:
            line    = row.strip()
            fields  = line.split(',')
            gene_id = fields.pop(0)
            tran_id = fields.pop(0)
            numbers = [int(x) for x in fields]
            seq_len = sum(numbers)+K-1
            if seq_len>=MINLEN and seq_len<=MAXLEN and gene_id in gene_to_rci.keys():
                rci_val = gene_to_rci[gene_id]
                allids.append( (gene_id,tran_id) )
                labels.append(rci_val)
                counts.append(numbers)
print(datetime.now())
print('Normalize')
rows = len(counts)
cols = len(counts[0])
for row in range(rows):
    total = sum(counts[row])
    for col in range(cols):
        counts[row][col] /= total
print(datetime.now())
print('Num IDs:',len(allids))
#print('Examples:',[allids[x] for x in [10, 20, 30, 40]] )
print('Num labels:',len(labels))
#print('Examples:',[labels[x] for x in [10, 20, 30, 40]] )
print('Num counts:',len(counts))
#print('Example:',counts[3])
# Out:
# 2022-11-21 15:30:46.760580
# 2022-11-21 15:30:48.082920
# Normalize
# 2022-11-21 15:30:48.472611
# Num IDs: 31220
# Num labels: 31220
# Num counts: 31220

# %%
def get_gene_subset(all_genes,sub_index):
    sub_genes = set()
    for index in sub_index:
        one_gene = all_genes[index]
        sub_genes.add(one_gene)
    return sub_genes
def get_X_y(gene_set,allids,allX,allY,threshold):
    cnt = len(allids)
    subsetX=[]
    subsetY=[]
    if cnt != len(allX) or cnt!= len(allY):
        raise Exception('Lengths differ')
    for i in range(cnt):
        gene_id,tran_id = allids[i]
        if gene_id in gene_set:
            oneX = allX[i]
            oneY = allY[i]
            if oneY < threshold:
                Yvalue = int(0)
            else:
                Yvalue = int(1)
            subsetX.append(oneX)
            subsetY.append(Yvalue)
    return subsetX,subsetY

# %% [markdown]
# ## Model design

# %%
def build_model():
    ALPHABET=4**K  # NUMBER OF DISTINCT KMERS POSSIBLE
    mlp    = Sequential()
    layer1 = Dense(64, activation='sigmoid',dtype=dt,input_dim=ALPHABET)
    layer2 = Dense(8, activation='sigmoid')
    output = Dense(1, activation='sigmoid')
    mlp.add(layer1)
    mlp.add(layer2)
    mlp.add(output)
      
    bc=BinaryCrossentropy(from_logits=False)
    print("COMPILE...")
    mlp.compile(loss=bc, optimizer="Adam",metrics=["accuracy"])
    print("...COMPILED")
    return mlp

# %%
print(datetime.now())
model=build_model()
print(model.summary())  # Print this only once
# Out:
# 2022-11-21 15:30:48.522745
# COMPILE...
# ...COMPILED
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_27 (Dense)            (None, 64)                4160
#
#  dense_28 (Dense)            (None, 8)                 520
#
#  dense_29 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 4,689
# Trainable params: 4,689
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## Train and validate with all K-mer counts

# %%
SCALING = False
def do_cross_validation(eps):
    cv_scores = []
    fold=0
    print(datetime.now())
    print('splitting')
    # KFold shuffles once before making the partitions
    splitter = KFold(n_splits=FOLDS,shuffle=True,random_state=42)
    for train_index,valid_index in splitter.split(all_genes):
        fold += 1
        print('Fold',fold)
        train_genes = get_gene_subset(all_genes,train_index)
        valid_genes = get_gene_subset(all_genes,valid_index)
        X_train,y_train = get_X_y(train_genes,allids,counts,labels,0)
        X_valid,y_valid = get_X_y(valid_genes,allids,counts,labels,0)

        if SCALING:
            print('scaling')
            print(datetime.now())
            scaler = StandardScaler()
            scaler.fit(X_train)
            X_train = scaler.transform(X_train)
            X_valid = scaler.transform(X_valid)

        print('Train sizes',len(X_train),len(y_train))
        print('Valid sizes',len(X_valid),len(y_valid))
        print('Train set ones/size',
              np.count_nonzero(y_train),'/',len(y_train))
        print('Valid set ones/size',
              np.count_nonzero(y_valid),'/',len(y_valid))

        print("BUILD MODEL")
        model=build_model()

        print("FIT")
        print(datetime.now())
        history=model.fit(X_train, y_train, # batch_size=10, default=32 works nicely
                epochs=EPOCHS, verbose=1,  # verbose=1 for ascii art, verbose=0 for none
                validation_data=(X_valid,y_valid) )

        pd.DataFrame(history.history).plot(figsize=(8,5))
        plt.grid(True)
        plt.gca().set_ylim(0,1)
        plt.show()

        print("Compute valiation accuracy")
        print(datetime.now())
        scores = model.evaluate(X_valid, y_valid, verbose=0)
        print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
        print(datetime.now())
        cv_scores.append(scores[1] * 100)
    return cv_scores

# %%
print(datetime.now())
cv_scores = do_cross_validation(EPOCHS)    
print("Cross validation acc mean %.2f%% (+/- %.2f%%)" % (np.mean(cv_scores), np.std(cv_scores)))
print(datetime.now())
# Out:
# 2022-11-21 15:30:48.660805
# 2022-11-21 15:30:48.662237
# splitting
# Fold 1
# Train sizes 24903 24903
# Valid sizes 6317 6317
# Train set ones/size 12187 / 24903
# Valid set ones/size 3025 / 6317
# BUILD MODEL
# COMPILE...
# ...COMPILED
# FIT
# 2022-11-21 15:30:48.759488
# Epoch 1/100
# 779/779 [==============================] - 4s 5ms/step - loss: 0.6810 - accuracy: 0.5889 - val_loss: 0.6581 - val_accuracy: 0.6864
# Epoch 2/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.6189 - accuracy: 0.6935 - val_loss: 0.5985 - val_accuracy: 0.6910
# Epoch 3/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5917 - accuracy: 0.6983 - val_loss: 0.5906 - val_accuracy: 0.6945
# Epoch 4/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5884 - accuracy: 0.6997 - val_loss: 0.5879 - val_accuracy: 0.6965
# Epoch 5/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5865 - accuracy: 0.7016 - val_loss: 0.5859 - val_accuracy: 0.6959
# Epoch 6/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5848 - accuracy: 0.7036 - val_loss: 0.5840 - val_accuracy: 0.6978
# Epoch 7/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5832 - accuracy: 0.7053 - val_loss: 0.5823 - val_accuracy: 0.6987
# Epoch 8/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5817 - accuracy: 0.7069 - val_loss: 0.5808 - val_accuracy: 0.6995
# Epoch 9/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5803 - accuracy: 0.7077 - val_loss: 0.5792 - val_accuracy: 0.7003
# Epoch 10/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5789 - accuracy: 0.7081 - val_loss: 0.5778 - val_accuracy: 0.7008
# Epoch 11/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5777 - accuracy: 0.7097 - val_loss: 0.5765 - val_accuracy: 0.7021
# Epoch 12/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5765 - accuracy: 0.7110 - val_loss: 0.5753 - val_accuracy: 0.7027
# Epoch 13/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5754 - accuracy: 0.7116 - val_loss: 0.5741 - val_accuracy: 0.7038
# Epoch 14/100
# 779/779 [==============================] - 3s 4ms/step - loss: 0.5744 - accuracy: 0.7124 - val_loss: 0.5731 - val_accuracy: 0.7037
# Epoch 15/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5734 - accuracy: 0.7125 - val_loss: 0.5722 - val_accuracy: 0.7037
# Epoch 16/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5726 - accuracy: 0.7127 - val_loss: 0.5713 - val_accuracy: 0.7051
# Epoch 17/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5719 - accuracy: 0.7130 - val_loss: 0.5706 - val_accuracy: 0.7049
# Epoch 18/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5712 - accuracy: 0.7137 - val_loss: 0.5699 - val_accuracy: 0.7068
# Epoch 19/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5706 - accuracy: 0.7144 - val_loss: 0.5693 - val_accuracy: 0.7062
# Epoch 20/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5701 - accuracy: 0.7148 - val_loss: 0.5688 - val_accuracy: 0.7076
# Epoch 21/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5696 - accuracy: 0.7156 - val_loss: 0.5684 - val_accuracy: 0.7078
# Epoch 22/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5692 - accuracy: 0.7160 - val_loss: 0.5679 - val_accuracy: 0.7084
# Epoch 23/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5688 - accuracy: 0.7161 - val_loss: 0.5676 - val_accuracy: 0.7100
# Epoch 24/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5684 - accuracy: 0.7162 - val_loss: 0.5672 - val_accuracy: 0.7108
# Epoch 25/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5681 - accuracy: 0.7161 - val_loss: 0.5669 - val_accuracy: 0.7098
# Epoch 26/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5677 - accuracy: 0.7163 - val_loss: 0.5666 - val_accuracy: 0.7100
# Epoch 27/100
# 779/779 [==============================] - 3s 4ms/step - loss: 0.5674 - accuracy: 0.7165 - val_loss: 0.5664 - val_accuracy: 0.7098
# Epoch 28/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5672 - accuracy: 0.7170 - val_loss: 0.5661 - val_accuracy: 0.7098
# Epoch 29/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5669 - accuracy: 0.7171 - val_loss: 0.5659 - val_accuracy: 0.7097
# Epoch 30/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5667 - accuracy: 0.7173 - val_loss: 0.5656 - val_accuracy: 0.7105
# Epoch 31/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5664 - accuracy: 0.7174 - val_loss: 0.5654 - val_accuracy: 0.7106
# Epoch 32/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5662 - accuracy: 0.7176 - val_loss: 0.5652 - val_accuracy: 0.7105
# Epoch 33/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5660 - accuracy: 0.7177 - val_loss: 0.5650 - val_accuracy: 0.7101
# Epoch 34/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5658 - accuracy: 0.7178 - val_loss: 0.5648 - val_accuracy: 0.7101
# Epoch 35/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5656 - accuracy: 0.7177 - val_loss: 0.5646 - val_accuracy: 0.7106
# Epoch 36/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5654 - accuracy: 0.7175 - val_loss: 0.5645 - val_accuracy: 0.7116
# Epoch 37/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5652 - accuracy: 0.7178 - val_loss: 0.5643 - val_accuracy: 0.7124
# Epoch 38/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5650 - accuracy: 0.7181 - val_loss: 0.5641 - val_accuracy: 0.7130
# Epoch 39/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5648 - accuracy: 0.7179 - val_loss: 0.5640 - val_accuracy: 0.7124
# Epoch 40/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5647 - accuracy: 0.7176 - val_loss: 0.5638 - val_accuracy: 0.7132
# Epoch 41/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5645 - accuracy: 0.7179 - val_loss: 0.5636 - val_accuracy: 0.7133
# Epoch 42/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5643 - accuracy: 0.7177 - val_loss: 0.5635 - val_accuracy: 0.7136
# Epoch 43/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5642 - accuracy: 0.7179 - val_loss: 0.5634 - val_accuracy: 0.7147
# Epoch 44/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5640 - accuracy: 0.7184 - val_loss: 0.5632 - val_accuracy: 0.7154
# Epoch 45/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5639 - accuracy: 0.7183 - val_loss: 0.5631 - val_accuracy: 0.7157
# Epoch 46/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5637 - accuracy: 0.7184 - val_loss: 0.5630 - val_accuracy: 0.7154
# Epoch 47/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5636 - accuracy: 0.7191 - val_loss: 0.5628 - val_accuracy: 0.7157
# Epoch 48/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5635 - accuracy: 0.7196 - val_loss: 0.5627 - val_accuracy: 0.7154
# Epoch 49/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5633 - accuracy: 0.7197 - val_loss: 0.5626 - val_accuracy: 0.7158
# Epoch 50/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5632 - accuracy: 0.7197 - val_loss: 0.5625 - val_accuracy: 0.7157
# Epoch 51/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5631 - accuracy: 0.7196 - val_loss: 0.5624 - val_accuracy: 0.7158
# Epoch 52/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5630 - accuracy: 0.7196 - val_loss: 0.5622 - val_accuracy: 0.7162
# Epoch 53/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5628 - accuracy: 0.7196 - val_loss: 0.5621 - val_accuracy: 0.7157
# Epoch 54/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5627 - accuracy: 0.7197 - val_loss: 0.5620 - val_accuracy: 0.7155
# Epoch 55/100
# 779/779 [==============================] - 3s 4ms/step - loss: 0.5626 - accuracy: 0.7198 - val_loss: 0.5619 - val_accuracy: 0.7158
# Epoch 56/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5625 - accuracy: 0.7199 - val_loss: 0.5618 - val_accuracy: 0.7163
# Epoch 57/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5624 - accuracy: 0.7198 - val_loss: 0.5618 - val_accuracy: 0.7163
# Epoch 58/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5623 - accuracy: 0.7200 - val_loss: 0.5617 - val_accuracy: 0.7160
# Epoch 59/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5622 - accuracy: 0.7202 - val_loss: 0.5616 - val_accuracy: 0.7163
# Epoch 60/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5621 - accuracy: 0.7201 - val_loss: 0.5615 - val_accuracy: 0.7168
# Epoch 61/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5620 - accuracy: 0.7202 - val_loss: 0.5614 - val_accuracy: 0.7174
# Epoch 62/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5619 - accuracy: 0.7203 - val_loss: 0.5613 - val_accuracy: 0.7174
# Epoch 63/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5618 - accuracy: 0.7202 - val_loss: 0.5613 - val_accuracy: 0.7173
# Epoch 64/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5617 - accuracy: 0.7202 - val_loss: 0.5612 - val_accuracy: 0.7177
# Epoch 65/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5617 - accuracy: 0.7206 - val_loss: 0.5611 - val_accuracy: 0.7181
# Epoch 66/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5616 - accuracy: 0.7205 - val_loss: 0.5611 - val_accuracy: 0.7176
# Epoch 67/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5615 - accuracy: 0.7205 - val_loss: 0.5610 - val_accuracy: 0.7184
# Epoch 68/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5614 - accuracy: 0.7205 - val_loss: 0.5609 - val_accuracy: 0.7182
# Epoch 69/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5614 - accuracy: 0.7206 - val_loss: 0.5609 - val_accuracy: 0.7185
# Epoch 70/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5613 - accuracy: 0.7206 - val_loss: 0.5608 - val_accuracy: 0.7184
# Epoch 71/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5612 - accuracy: 0.7208 - val_loss: 0.5608 - val_accuracy: 0.7182
# Epoch 72/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5611 - accuracy: 0.7207 - val_loss: 0.5607 - val_accuracy: 0.7187
# Epoch 73/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5611 - accuracy: 0.7204 - val_loss: 0.5607 - val_accuracy: 0.7187
# Epoch 74/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5610 - accuracy: 0.7206 - val_loss: 0.5607 - val_accuracy: 0.7184
# Epoch 75/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5610 - accuracy: 0.7204 - val_loss: 0.5606 - val_accuracy: 0.7184
# Epoch 76/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5609 - accuracy: 0.7204 - val_loss: 0.5606 - val_accuracy: 0.7184
# Epoch 77/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5608 - accuracy: 0.7203 - val_loss: 0.5605 - val_accuracy: 0.7184
# Epoch 78/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5608 - accuracy: 0.7204 - val_loss: 0.5605 - val_accuracy: 0.7182
# Epoch 79/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5607 - accuracy: 0.7204 - val_loss: 0.5605 - val_accuracy: 0.7187
# Epoch 80/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5607 - accuracy: 0.7204 - val_loss: 0.5604 - val_accuracy: 0.7190
# Epoch 81/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5606 - accuracy: 0.7207 - val_loss: 0.5604 - val_accuracy: 0.7190
# Epoch 82/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5606 - accuracy: 0.7207 - val_loss: 0.5604 - val_accuracy: 0.7192
# Epoch 83/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5605 - accuracy: 0.7208 - val_loss: 0.5603 - val_accuracy: 0.7193
# Epoch 84/100
# 779/779 [==============================] - 3s 4ms/step - loss: 0.5605 - accuracy: 0.7208 - val_loss: 0.5603 - val_accuracy: 0.7193
# Epoch 85/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5605 - accuracy: 0.7210 - val_loss: 0.5603 - val_accuracy: 0.7192
# Epoch 86/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5604 - accuracy: 0.7209 - val_loss: 0.5603 - val_accuracy: 0.7189
# Epoch 87/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5604 - accuracy: 0.7208 - val_loss: 0.5603 - val_accuracy: 0.7190
# Epoch 88/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5603 - accuracy: 0.7208 - val_loss: 0.5602 - val_accuracy: 0.7192
# Epoch 89/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5603 - accuracy: 0.7210 - val_loss: 0.5602 - val_accuracy: 0.7193
# Epoch 90/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5603 - accuracy: 0.7210 - val_loss: 0.5602 - val_accuracy: 0.7192
# Epoch 91/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5602 - accuracy: 0.7210 - val_loss: 0.5602 - val_accuracy: 0.7190
# Epoch 92/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5602 - accuracy: 0.7210 - val_loss: 0.5602 - val_accuracy: 0.7190
# Epoch 93/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5602 - accuracy: 0.7209 - val_loss: 0.5602 - val_accuracy: 0.7192
# Epoch 94/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5601 - accuracy: 0.7208 - val_loss: 0.5601 - val_accuracy: 0.7190
# Epoch 95/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5601 - accuracy: 0.7208 - val_loss: 0.5601 - val_accuracy: 0.7192
# Epoch 96/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5601 - accuracy: 0.7209 - val_loss: 0.5601 - val_accuracy: 0.7189
# Epoch 97/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5600 - accuracy: 0.7210 - val_loss: 0.5601 - val_accuracy: 0.7190
# Epoch 98/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5600 - accuracy: 0.7210 - val_loss: 0.5601 - val_accuracy: 0.7185
# Epoch 99/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5600 - accuracy: 0.7212 - val_loss: 0.5601 - val_accuracy: 0.7189
# Epoch 100/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5599 - accuracy: 0.7211 - val_loss: 0.5601 - val_accuracy: 0.7189
# Compute valiation accuracy
# 2022-11-21 15:34:57.963821
# accuracy: 71.89%
# 2022-11-21 15:35:00.289788
# Fold 2
# Train sizes 24921 24921
# Valid sizes 6299 6299
# Train set ones/size 12133 / 24921
# Valid set ones/size 3079 / 6299
# BUILD MODEL
# COMPILE...
# ...COMPILED
# FIT
# 2022-11-21 15:35:00.370551
# Epoch 1/100
# 779/779 [==============================] - 4s 5ms/step - loss: 0.6847 - accuracy: 0.5904 - val_loss: 0.6686 - val_accuracy: 0.6199
# Epoch 2/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.6302 - accuracy: 0.6863 - val_loss: 0.6055 - val_accuracy: 0.6852
# Epoch 3/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5919 - accuracy: 0.6958 - val_loss: 0.5954 - val_accuracy: 0.6946
# Epoch 4/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5871 - accuracy: 0.6981 - val_loss: 0.5934 - val_accuracy: 0.6947
# Epoch 5/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5850 - accuracy: 0.6999 - val_loss: 0.5919 - val_accuracy: 0.6963
# Epoch 6/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5831 - accuracy: 0.7014 - val_loss: 0.5905 - val_accuracy: 0.6969
# Epoch 7/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5813 - accuracy: 0.7029 - val_loss: 0.5892 - val_accuracy: 0.6977
# Epoch 8/100
# 779/779 [==============================] - 4s 5ms/step - loss: 0.5796 - accuracy: 0.7044 - val_loss: 0.5881 - val_accuracy: 0.6995
# Epoch 9/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5779 - accuracy: 0.7063 - val_loss: 0.5870 - val_accuracy: 0.7000
# Epoch 10/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5763 - accuracy: 0.7084 - val_loss: 0.5859 - val_accuracy: 0.6996
# Epoch 11/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5748 - accuracy: 0.7089 - val_loss: 0.5850 - val_accuracy: 0.7004
# Epoch 12/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5733 - accuracy: 0.7095 - val_loss: 0.5841 - val_accuracy: 0.7014
# Epoch 13/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5720 - accuracy: 0.7110 - val_loss: 0.5834 - val_accuracy: 0.7017
# Epoch 14/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5708 - accuracy: 0.7114 - val_loss: 0.5827 - val_accuracy: 0.7015
# Epoch 15/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5697 - accuracy: 0.7117 - val_loss: 0.5822 - val_accuracy: 0.7027
# Epoch 16/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5687 - accuracy: 0.7125 - val_loss: 0.5817 - val_accuracy: 0.7028
# Epoch 17/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5678 - accuracy: 0.7134 - val_loss: 0.5814 - val_accuracy: 0.7041
# Epoch 18/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5671 - accuracy: 0.7142 - val_loss: 0.5811 - val_accuracy: 0.7044
# Epoch 19/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5664 - accuracy: 0.7146 - val_loss: 0.5808 - val_accuracy: 0.7036
# Epoch 20/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5658 - accuracy: 0.7145 - val_loss: 0.5807 - val_accuracy: 0.7055
# Epoch 21/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5653 - accuracy: 0.7145 - val_loss: 0.5805 - val_accuracy: 0.7069
# Epoch 22/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5649 - accuracy: 0.7147 - val_loss: 0.5804 - val_accuracy: 0.7080
# Epoch 23/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5644 - accuracy: 0.7154 - val_loss: 0.5803 - val_accuracy: 0.7079
# Epoch 24/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5641 - accuracy: 0.7162 - val_loss: 0.5802 - val_accuracy: 0.7076
# Epoch 25/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5637 - accuracy: 0.7166 - val_loss: 0.5802 - val_accuracy: 0.7077
# Epoch 26/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5634 - accuracy: 0.7173 - val_loss: 0.5801 - val_accuracy: 0.7082
# Epoch 27/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5631 - accuracy: 0.7177 - val_loss: 0.5801 - val_accuracy: 0.7080
# Epoch 28/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5628 - accuracy: 0.7183 - val_loss: 0.5800 - val_accuracy: 0.7087
# Epoch 29/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5625 - accuracy: 0.7188 - val_loss: 0.5800 - val_accuracy: 0.7092
# Epoch 30/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5622 - accuracy: 0.7188 - val_loss: 0.5800 - val_accuracy: 0.7090
# Epoch 31/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5620 - accuracy: 0.7194 - val_loss: 0.5800 - val_accuracy: 0.7095
# Epoch 32/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5617 - accuracy: 0.7192 - val_loss: 0.5799 - val_accuracy: 0.7098
# Epoch 33/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5615 - accuracy: 0.7194 - val_loss: 0.5799 - val_accuracy: 0.7100
# Epoch 34/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5613 - accuracy: 0.7193 - val_loss: 0.5799 - val_accuracy: 0.7101
# Epoch 35/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5611 - accuracy: 0.7195 - val_loss: 0.5799 - val_accuracy: 0.7093
# Epoch 36/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5609 - accuracy: 0.7197 - val_loss: 0.5799 - val_accuracy: 0.7096
# Epoch 37/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5607 - accuracy: 0.7198 - val_loss: 0.5799 - val_accuracy: 0.7096
# Epoch 38/100
# 779/779 [==============================] - 3s 4ms/step - loss: 0.5605 - accuracy: 0.7204 - val_loss: 0.5799 - val_accuracy: 0.7106
# Epoch 39/100
# 779/779 [==============================] - 3s 4ms/step - loss: 0.5603 - accuracy: 0.7203 - val_loss: 0.5799 - val_accuracy: 0.7103
# Epoch 40/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5601 - accuracy: 0.7204 - val_loss: 0.5799 - val_accuracy: 0.7098
# Epoch 41/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5599 - accuracy: 0.7205 - val_loss: 0.5799 - val_accuracy: 0.7101
# Epoch 42/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5597 - accuracy: 0.7210 - val_loss: 0.5799 - val_accuracy: 0.7107
# Epoch 43/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5596 - accuracy: 0.7210 - val_loss: 0.5800 - val_accuracy: 0.7107
# Epoch 44/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5594 - accuracy: 0.7212 - val_loss: 0.5800 - val_accuracy: 0.7107
# Epoch 45/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5593 - accuracy: 0.7214 - val_loss: 0.5800 - val_accuracy: 0.7104
# Epoch 46/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5591 - accuracy: 0.7219 - val_loss: 0.5800 - val_accuracy: 0.7104
# Epoch 47/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5590 - accuracy: 0.7216 - val_loss: 0.5800 - val_accuracy: 0.7107
# Epoch 48/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5588 - accuracy: 0.7218 - val_loss: 0.5800 - val_accuracy: 0.7109
# Epoch 49/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5587 - accuracy: 0.7219 - val_loss: 0.5800 - val_accuracy: 0.7111
# Epoch 50/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5586 - accuracy: 0.7222 - val_loss: 0.5801 - val_accuracy: 0.7109
# Epoch 51/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5584 - accuracy: 0.7222 - val_loss: 0.5801 - val_accuracy: 0.7111
# Epoch 52/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5583 - accuracy: 0.7224 - val_loss: 0.5801 - val_accuracy: 0.7111
# Epoch 53/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5582 - accuracy: 0.7226 - val_loss: 0.5801 - val_accuracy: 0.7109
# Epoch 54/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5581 - accuracy: 0.7230 - val_loss: 0.5802 - val_accuracy: 0.7106
# Epoch 55/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5580 - accuracy: 0.7228 - val_loss: 0.5802 - val_accuracy: 0.7101
# Epoch 56/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5579 - accuracy: 0.7230 - val_loss: 0.5802 - val_accuracy: 0.7101
# Epoch 57/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5578 - accuracy: 0.7230 - val_loss: 0.5802 - val_accuracy: 0.7100
# Epoch 58/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5577 - accuracy: 0.7229 - val_loss: 0.5803 - val_accuracy: 0.7098
# Epoch 59/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5576 - accuracy: 0.7232 - val_loss: 0.5803 - val_accuracy: 0.7098
# Epoch 60/100
# 779/779 [==============================] - 3s 3ms/step - loss: 0.5575 - accuracy: 0.7231 - val_loss: 0.5803 - val_accuracy: 0.7098
# Epoch 61/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5574 - accuracy: 0.7232 - val_loss: 0.5803 - val_accuracy: 0.7098
# Epoch 62/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5573 - accuracy: 0.7232 - val_loss: 0.5804 - val_accuracy: 0.7096
# Epoch 63/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5572 - accuracy: 0.7232 - val_loss: 0.5804 - val_accuracy: 0.7096
# Epoch 64/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5571 - accuracy: 0.7232 - val_loss: 0.5804 - val_accuracy: 0.7092
# Epoch 65/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5570 - accuracy: 0.7233 - val_loss: 0.5804 - val_accuracy: 0.7093
# Epoch 66/100
# 779/779 [==============================] - 3s 4ms/step - loss: 0.5570 - accuracy: 0.7235 - val_loss: 0.5805 - val_accuracy: 0.7093
# Epoch 67/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5569 - accuracy: 0.7234 - val_loss: 0.5805 - val_accuracy: 0.7090
# Epoch 68/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5568 - accuracy: 0.7234 - val_loss: 0.5805 - val_accuracy: 0.7092
# Epoch 69/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5567 - accuracy: 0.7236 - val_loss: 0.5805 - val_accuracy: 0.7087
# Epoch 70/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5567 - accuracy: 0.7237 - val_loss: 0.5806 - val_accuracy: 0.7084
# Epoch 71/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5566 - accuracy: 0.7235 - val_loss: 0.5806 - val_accuracy: 0.7084
# Epoch 72/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5566 - accuracy: 0.7237 - val_loss: 0.5806 - val_accuracy: 0.7087
# Epoch 73/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5565 - accuracy: 0.7238 - val_loss: 0.5806 - val_accuracy: 0.7088
# Epoch 74/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5564 - accuracy: 0.7238 - val_loss: 0.5807 - val_accuracy: 0.7095
# Epoch 75/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5564 - accuracy: 0.7237 - val_loss: 0.5807 - val_accuracy: 0.7090
# Epoch 76/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5563 - accuracy: 0.7238 - val_loss: 0.5807 - val_accuracy: 0.7088
# Epoch 77/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5563 - accuracy: 0.7239 - val_loss: 0.5807 - val_accuracy: 0.7088
# Epoch 78/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5562 - accuracy: 0.7238 - val_loss: 0.5808 - val_accuracy: 0.7092
# Epoch 79/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5562 - accuracy: 0.7239 - val_loss: 0.5808 - val_accuracy: 0.7092
# Epoch 80/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5561 - accuracy: 0.7240 - val_loss: 0.5808 - val_accuracy: 0.7087
# Epoch 81/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5561 - accuracy: 0.7241 - val_loss: 0.5808 - val_accuracy: 0.7082
# Epoch 82/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5560 - accuracy: 0.7242 - val_loss: 0.5809 - val_accuracy: 0.7080
# Epoch 83/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5560 - accuracy: 0.7243 - val_loss: 0.5809 - val_accuracy: 0.7080
# Epoch 84/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5560 - accuracy: 0.7242 - val_loss: 0.5809 - val_accuracy: 0.7079
# Epoch 85/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5559 - accuracy: 0.7243 - val_loss: 0.5809 - val_accuracy: 0.7080
# Epoch 86/100
# 779/779 [==============================] - 3s 3ms/step - loss: 0.5559 - accuracy: 0.7244 - val_loss: 0.5809 - val_accuracy: 0.7084
# Epoch 87/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5559 - accuracy: 0.7246 - val_loss: 0.5809 - val_accuracy: 0.7085
# Epoch 88/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5558 - accuracy: 0.7246 - val_loss: 0.5810 - val_accuracy: 0.7087
# Epoch 89/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5558 - accuracy: 0.7244 - val_loss: 0.5810 - val_accuracy: 0.7085
# Epoch 90/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5558 - accuracy: 0.7246 - val_loss: 0.5810 - val_accuracy: 0.7087
# Epoch 91/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5557 - accuracy: 0.7246 - val_loss: 0.5810 - val_accuracy: 0.7090
# Epoch 92/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5557 - accuracy: 0.7246 - val_loss: 0.5810 - val_accuracy: 0.7087
# Epoch 93/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5557 - accuracy: 0.7244 - val_loss: 0.5810 - val_accuracy: 0.7085
# Epoch 94/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5557 - accuracy: 0.7244 - val_loss: 0.5811 - val_accuracy: 0.7085
# Epoch 95/100
# 779/779 [==============================] - 3s 3ms/step - loss: 0.5556 - accuracy: 0.7244 - val_loss: 0.5811 - val_accuracy: 0.7085
# Epoch 96/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5556 - accuracy: 0.7244 - val_loss: 0.5811 - val_accuracy: 0.7085
# Epoch 97/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5556 - accuracy: 0.7241 - val_loss: 0.5811 - val_accuracy: 0.7087
# Epoch 98/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5556 - accuracy: 0.7242 - val_loss: 0.5811 - val_accuracy: 0.7087
# Epoch 99/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5555 - accuracy: 0.7242 - val_loss: 0.5811 - val_accuracy: 0.7087
# Epoch 100/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5555 - accuracy: 0.7241 - val_loss: 0.5811 - val_accuracy: 0.7090
# Compute valiation accuracy
# 2022-11-21 15:39:16.091467
# accuracy: 70.90%
# 2022-11-21 15:39:18.326687
# Fold 3
# Train sizes 24914 24914
# Valid sizes 6306 6306
# Train set ones/size 12233 / 24914
# Valid set ones/size 2979 / 6306
# BUILD MODEL
# COMPILE...
# ...COMPILED
# FIT
# 2022-11-21 15:39:18.408661
# Epoch 1/100
# 779/779 [==============================] - 5s 5ms/step - loss: 0.6786 - accuracy: 0.5904 - val_loss: 0.6484 - val_accuracy: 0.6966
# Epoch 2/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.6142 - accuracy: 0.6925 - val_loss: 0.5950 - val_accuracy: 0.6998
# Epoch 3/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5898 - accuracy: 0.6958 - val_loss: 0.5907 - val_accuracy: 0.7023
# Epoch 4/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5865 - accuracy: 0.6971 - val_loss: 0.5889 - val_accuracy: 0.7058
# Epoch 5/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5843 - accuracy: 0.6998 - val_loss: 0.5873 - val_accuracy: 0.7088
# Epoch 6/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5824 - accuracy: 0.7012 - val_loss: 0.5858 - val_accuracy: 0.7092
# Epoch 7/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5806 - accuracy: 0.7025 - val_loss: 0.5845 - val_accuracy: 0.7119
# Epoch 8/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5788 - accuracy: 0.7043 - val_loss: 0.5832 - val_accuracy: 0.7136
# Epoch 9/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5772 - accuracy: 0.7065 - val_loss: 0.5820 - val_accuracy: 0.7144
# Epoch 10/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5757 - accuracy: 0.7077 - val_loss: 0.5810 - val_accuracy: 0.7147
# Epoch 11/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5742 - accuracy: 0.7084 - val_loss: 0.5800 - val_accuracy: 0.7139
# Epoch 12/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5729 - accuracy: 0.7090 - val_loss: 0.5792 - val_accuracy: 0.7136
# Epoch 13/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5717 - accuracy: 0.7096 - val_loss: 0.5784 - val_accuracy: 0.7134
# Epoch 14/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5706 - accuracy: 0.7107 - val_loss: 0.5778 - val_accuracy: 0.7138
# Epoch 15/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5696 - accuracy: 0.7116 - val_loss: 0.5772 - val_accuracy: 0.7147
# Epoch 16/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5688 - accuracy: 0.7122 - val_loss: 0.5768 - val_accuracy: 0.7157
# Epoch 17/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5680 - accuracy: 0.7127 - val_loss: 0.5764 - val_accuracy: 0.7158
# Epoch 18/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5673 - accuracy: 0.7134 - val_loss: 0.5761 - val_accuracy: 0.7161
# Epoch 19/100
# 779/779 [==============================] - 3s 4ms/step - loss: 0.5668 - accuracy: 0.7136 - val_loss: 0.5758 - val_accuracy: 0.7160
# Epoch 20/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5662 - accuracy: 0.7142 - val_loss: 0.5756 - val_accuracy: 0.7158
# Epoch 21/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5657 - accuracy: 0.7142 - val_loss: 0.5754 - val_accuracy: 0.7158
# Epoch 22/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5653 - accuracy: 0.7149 - val_loss: 0.5752 - val_accuracy: 0.7160
# Epoch 23/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5649 - accuracy: 0.7152 - val_loss: 0.5750 - val_accuracy: 0.7157
# Epoch 24/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5645 - accuracy: 0.7159 - val_loss: 0.5749 - val_accuracy: 0.7152
# Epoch 25/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5642 - accuracy: 0.7165 - val_loss: 0.5748 - val_accuracy: 0.7147
# Epoch 26/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5639 - accuracy: 0.7167 - val_loss: 0.5746 - val_accuracy: 0.7150
# Epoch 27/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5636 - accuracy: 0.7174 - val_loss: 0.5745 - val_accuracy: 0.7147
# Epoch 28/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5633 - accuracy: 0.7178 - val_loss: 0.5744 - val_accuracy: 0.7152
# Epoch 29/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5630 - accuracy: 0.7181 - val_loss: 0.5743 - val_accuracy: 0.7146
# Epoch 30/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5627 - accuracy: 0.7186 - val_loss: 0.5742 - val_accuracy: 0.7134
# Epoch 31/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5625 - accuracy: 0.7188 - val_loss: 0.5741 - val_accuracy: 0.7131
# Epoch 32/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5622 - accuracy: 0.7192 - val_loss: 0.5740 - val_accuracy: 0.7127
# Epoch 33/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5620 - accuracy: 0.7190 - val_loss: 0.5739 - val_accuracy: 0.7117
# Epoch 34/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5618 - accuracy: 0.7192 - val_loss: 0.5738 - val_accuracy: 0.7120
# Epoch 35/100
# 779/779 [==============================] - 2s 2ms/step - loss: 0.5616 - accuracy: 0.7193 - val_loss: 0.5737 - val_accuracy: 0.7117
# Epoch 36/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5614 - accuracy: 0.7196 - val_loss: 0.5736 - val_accuracy: 0.7119
# Epoch 37/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5612 - accuracy: 0.7198 - val_loss: 0.5735 - val_accuracy: 0.7122
# Epoch 38/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5610 - accuracy: 0.7198 - val_loss: 0.5734 - val_accuracy: 0.7127
# Epoch 39/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5608 - accuracy: 0.7195 - val_loss: 0.5733 - val_accuracy: 0.7122
# Epoch 40/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5606 - accuracy: 0.7197 - val_loss: 0.5732 - val_accuracy: 0.7123
# Epoch 41/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5604 - accuracy: 0.7199 - val_loss: 0.5731 - val_accuracy: 0.7122
# Epoch 42/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5603 - accuracy: 0.7201 - val_loss: 0.5731 - val_accuracy: 0.7119
# Epoch 43/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5601 - accuracy: 0.7201 - val_loss: 0.5730 - val_accuracy: 0.7119
# Epoch 44/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5600 - accuracy: 0.7199 - val_loss: 0.5729 - val_accuracy: 0.7117
# Epoch 45/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5598 - accuracy: 0.7203 - val_loss: 0.5728 - val_accuracy: 0.7115
# Epoch 46/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5596 - accuracy: 0.7205 - val_loss: 0.5728 - val_accuracy: 0.7114
# Epoch 47/100
# 779/779 [==============================] - 3s 4ms/step - loss: 0.5595 - accuracy: 0.7207 - val_loss: 0.5727 - val_accuracy: 0.7120
# Epoch 48/100
# 779/779 [==============================] - 3s 4ms/step - loss: 0.5594 - accuracy: 0.7212 - val_loss: 0.5726 - val_accuracy: 0.7123
# Epoch 49/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5592 - accuracy: 0.7215 - val_loss: 0.5726 - val_accuracy: 0.7123
# Epoch 50/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5591 - accuracy: 0.7218 - val_loss: 0.5725 - val_accuracy: 0.7122
# Epoch 51/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5590 - accuracy: 0.7222 - val_loss: 0.5724 - val_accuracy: 0.7119
# Epoch 52/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5588 - accuracy: 0.7223 - val_loss: 0.5724 - val_accuracy: 0.7112
# Epoch 53/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5587 - accuracy: 0.7218 - val_loss: 0.5723 - val_accuracy: 0.7101
# Epoch 54/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5586 - accuracy: 0.7220 - val_loss: 0.5723 - val_accuracy: 0.7104
# Epoch 55/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5585 - accuracy: 0.7218 - val_loss: 0.5723 - val_accuracy: 0.7108
# Epoch 56/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5584 - accuracy: 0.7219 - val_loss: 0.5722 - val_accuracy: 0.7108
# Epoch 57/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5583 - accuracy: 0.7220 - val_loss: 0.5722 - val_accuracy: 0.7108
# Epoch 58/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5582 - accuracy: 0.7222 - val_loss: 0.5721 - val_accuracy: 0.7109
# Epoch 59/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5581 - accuracy: 0.7221 - val_loss: 0.5721 - val_accuracy: 0.7114
# Epoch 60/100
# 779/779 [==============================] - 3s 3ms/step - loss: 0.5580 - accuracy: 0.7222 - val_loss: 0.5721 - val_accuracy: 0.7112
# Epoch 61/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5579 - accuracy: 0.7225 - val_loss: 0.5720 - val_accuracy: 0.7114
# Epoch 62/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5578 - accuracy: 0.7226 - val_loss: 0.5720 - val_accuracy: 0.7119
# Epoch 63/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5577 - accuracy: 0.7226 - val_loss: 0.5720 - val_accuracy: 0.7123
# Epoch 64/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5577 - accuracy: 0.7227 - val_loss: 0.5719 - val_accuracy: 0.7122
# Epoch 65/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5576 - accuracy: 0.7225 - val_loss: 0.5719 - val_accuracy: 0.7127
# Epoch 66/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5575 - accuracy: 0.7226 - val_loss: 0.5719 - val_accuracy: 0.7128
# Epoch 67/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5574 - accuracy: 0.7226 - val_loss: 0.5719 - val_accuracy: 0.7128
# Epoch 68/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5574 - accuracy: 0.7229 - val_loss: 0.5718 - val_accuracy: 0.7127
# Epoch 69/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5573 - accuracy: 0.7229 - val_loss: 0.5718 - val_accuracy: 0.7128
# Epoch 70/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5572 - accuracy: 0.7228 - val_loss: 0.5718 - val_accuracy: 0.7128
# Epoch 71/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5572 - accuracy: 0.7230 - val_loss: 0.5718 - val_accuracy: 0.7127
# Epoch 72/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5571 - accuracy: 0.7230 - val_loss: 0.5717 - val_accuracy: 0.7128
# Epoch 73/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5571 - accuracy: 0.7229 - val_loss: 0.5717 - val_accuracy: 0.7128
# Epoch 74/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5570 - accuracy: 0.7229 - val_loss: 0.5717 - val_accuracy: 0.7136
# Epoch 75/100
# 779/779 [==============================] - 3s 4ms/step - loss: 0.5570 - accuracy: 0.7230 - val_loss: 0.5717 - val_accuracy: 0.7142
# Epoch 76/100
# 779/779 [==============================] - 3s 4ms/step - loss: 0.5569 - accuracy: 0.7231 - val_loss: 0.5717 - val_accuracy: 0.7142
# Epoch 77/100
# 779/779 [==============================] - 3s 4ms/step - loss: 0.5569 - accuracy: 0.7230 - val_loss: 0.5717 - val_accuracy: 0.7139
# Epoch 78/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5568 - accuracy: 0.7231 - val_loss: 0.5716 - val_accuracy: 0.7141
# Epoch 79/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5568 - accuracy: 0.7232 - val_loss: 0.5716 - val_accuracy: 0.7146
# Epoch 80/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5567 - accuracy: 0.7230 - val_loss: 0.5716 - val_accuracy: 0.7146
# Epoch 81/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5567 - accuracy: 0.7229 - val_loss: 0.5716 - val_accuracy: 0.7147
# Epoch 82/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5566 - accuracy: 0.7231 - val_loss: 0.5716 - val_accuracy: 0.7146
# Epoch 83/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5566 - accuracy: 0.7232 - val_loss: 0.5716 - val_accuracy: 0.7149
# Epoch 84/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5566 - accuracy: 0.7233 - val_loss: 0.5716 - val_accuracy: 0.7150
# Epoch 85/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5565 - accuracy: 0.7232 - val_loss: 0.5716 - val_accuracy: 0.7150
# Epoch 86/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5565 - accuracy: 0.7230 - val_loss: 0.5716 - val_accuracy: 0.7154
# Epoch 87/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5565 - accuracy: 0.7232 - val_loss: 0.5715 - val_accuracy: 0.7161
# Epoch 88/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5564 - accuracy: 0.7234 - val_loss: 0.5715 - val_accuracy: 0.7161
# Epoch 89/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5564 - accuracy: 0.7234 - val_loss: 0.5715 - val_accuracy: 0.7163
# Epoch 90/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5564 - accuracy: 0.7235 - val_loss: 0.5715 - val_accuracy: 0.7163
# Epoch 91/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5563 - accuracy: 0.7239 - val_loss: 0.5715 - val_accuracy: 0.7165
# Epoch 92/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5563 - accuracy: 0.7239 - val_loss: 0.5715 - val_accuracy: 0.7166
# Epoch 93/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5563 - accuracy: 0.7236 - val_loss: 0.5715 - val_accuracy: 0.7169
# Epoch 94/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5563 - accuracy: 0.7236 - val_loss: 0.5715 - val_accuracy: 0.7169
# Epoch 95/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5562 - accuracy: 0.7236 - val_loss: 0.5715 - val_accuracy: 0.7173
# Epoch 96/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5562 - accuracy: 0.7235 - val_loss: 0.5715 - val_accuracy: 0.7173
# Epoch 97/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5562 - accuracy: 0.7233 - val_loss: 0.5715 - val_accuracy: 0.7173
# Epoch 98/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5562 - accuracy: 0.7232 - val_loss: 0.5715 - val_accuracy: 0.7173
# Epoch 99/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5561 - accuracy: 0.7231 - val_loss: 0.5715 - val_accuracy: 0.7171
# Epoch 100/100
# 779/779 [==============================] - 2s 3ms/step - loss: 0.5561 - accuracy: 0.7232 - val_loss: 0.5715 - val_accuracy: 0.7169
# Compute valiation accuracy
# 2022-11-21 15:43:41.384426
# accuracy: 71.69%
# 2022-11-21 15:43:44.064496
# Fold 4
# Train sizes 24986 24986
# Valid sizes 6234 6234
# Train set ones/size 12223 / 24986
# Valid set ones/size 2989 / 6234
# BUILD MODEL
# COMPILE...
# ...COMPILED
# FIT
# 2022-11-21 15:43:44.161982
# Epoch 1/100
# 781/781 [==============================] - 5s 6ms/step - loss: 0.6834 - accuracy: 0.5907 - val_loss: 0.6613 - val_accuracy: 0.6471
# Epoch 2/100
# 781/781 [==============================] - 2s 3ms/step - loss: 0.6236 - accuracy: 0.6894 - val_loss: 0.5946 - val_accuracy: 0.7004
# Epoch 3/100
# 781/781 [==============================] - 2s 3ms/step - loss: 0.5919 - accuracy: 0.6948 - val_loss: 0.5888 - val_accuracy: 0.7008
# Epoch 4/100
# 781/781 [==============================] - 2s 3ms/step - loss: 0.5887 - accuracy: 0.6965 - val_loss: 0.5868 - val_accuracy: 0.7007
# Epoch 5/100
# 781/781 [==============================] - 2s 3ms/step - loss: 0.5869 - accuracy: 0.6980 - val_loss: 0.5851 - val_accuracy: 0.7010
# Epoch 6/100
# 781/781 [==============================] - 2s 3ms/step - loss: 0.5853 - accuracy: 0.6996 - val_loss: 0.5834 - val_accuracy: 0.7032
# Epoch 7/100
# 781/781 [==============================] - 2s 3ms/step - loss: 0.5838 - accuracy: 0.7014 - val_loss: 0.5818 - val_accuracy: 0.7039
# Epoch 8/100
# 781/781 [==============================] - 2s 3ms/step - loss: 0.5823 - accuracy: 0.7028 - val_loss: 0.5803 - val_accuracy: 0.7044
# Epoch 9/100
# 781/781 [==============================] - 2s 3ms/step - loss: 0.5809 - accuracy: 0.7038 - val_loss: 0.5788 - val_accuracy: 0.7044
# Epoch 10/100
# 781/781 [==============================] - 2s 3ms/step - loss: 0.5796 - accuracy: 0.7044 - val_loss: 0.5773 - val_accuracy: 0.7060
# Epoch 11/100
# 781/781 [==============================] - 2s 3ms/step - loss: 0.5783 - accuracy: 0.7054 - val_loss: 0.5759 - val_accuracy: 0.7066
# Epoch 12/100
# 781/781 [==============================] - 2s 3ms/step - loss: 0.5771 - accuracy: 0.7070 - val_loss: 0.5746 - val_accuracy: 0.7076
# Epoch 13/100
# 781/781 [==============================] - 2s 3ms/step - loss: 0.5760 - accuracy: 0.7084 - val_loss: 0.5732 - val_accuracy: 0.7069
# Epoch 14/100
# 781/781 [==============================] - 2s 3ms/step - loss: 0.5750 - accuracy: 0.7098 - val_loss: 0.5720 - val_accuracy: 0.7063
# Epoch 15/100
# 781/781 [==============================] - 2s 3ms/step - loss: 0.5740 - accuracy: 0.7107 - val_loss: 0.5709 - val_accuracy: 0.7064
# Epoch 16/100
# 781/781 [==============================] - 2s 3ms/step - loss: 0.5732 - accuracy: 0.7118 - val_loss: 0.5698 - val_accuracy: 0.7081
# Epoch 17/100
# 781/781 [==============================] - 2s 3ms/step - loss: 0.5724 - accuracy: 0.7125 - val_loss: 0.5688 - val_accuracy: 0.7082
# Epoch 18/100
# 781/781 [==============================] - 2s 3ms/step - loss: 0.5717 - accuracy: 0.7135 - val_loss: 0.5679 - val_accuracy: 0.7082
# Epoch 19/100
# 781/781 [==============================] - 2s 3ms/step - loss: 0.5711 - accuracy: 0.7139 - val_loss: 0.5672 - val_accuracy: 0.7082
# Epoch 20/100
# 781/781 [==============================] - 2s 3ms/step - loss: 0.5705 - accuracy: 0.7140 - val_loss: 0.5664 - val_accuracy: 0.7076
# Epoch 21/100
# 781/781 [==============================] - 2s 3ms/step - loss: 0.5700 - accuracy: 0.7143 - val_loss: 0.5658 - val_accuracy: 0.7071
# Epoch 22/100
# 781/781 [==============================] - 2s 3ms/step - loss: 0.5696 - accuracy: 0.7148 - val_loss: 0.5652 - val_accuracy: 0.7084
# Epoch 23/100
# 781/781 [==============================] - 2s 3ms/step - loss: 0.5692 - accuracy: 0.7152 - val_loss: 0.5647 - val_accuracy: 0.7089
# Epoch 24/100
# 781/781 [==============================] - 2s 3ms/step - loss: 0.5688 - accuracy: 0.7162 - val_loss: 0.5642 - val_accuracy: 0.7093
# Epoch 25/100
# 781/781 [==============================] - 2s 3ms/step - loss: 0.5685 - accuracy: 0.7162 - val_loss: 0.5638 - val_accuracy: 0.7097
# Epoch 26/100
# ...
# Epoch 93/100
# 781/781 [==============================] - 2s 2ms/step - loss: 0.5609 - accuracy: 0.7238 - val_loss: 0.5571 - val_accuracy: 0.7133
# Epoch 94/100
# 781/781 [==============================] - 2s 3ms/step - loss: 0.5609 - accuracy: 0.7239 - val_loss: 0.5571 - val_accuracy: 0.7130
# Epoch 95/100
# 781/781 [==============================] - 2s 3ms/step - loss: 0.5609 - accuracy: 0.7239 - val_loss: 0.5571 - val_accuracy: 0.7129
# Epoch 96/100
# 781/781 [==============================] - 2s 3ms/step - loss: 0.5608 - accuracy: 0.7239 - val_loss: 0.5571 - val_accuracy: 0.7133
# Epoch 97/100
# 781/781 [==============================] - 2s 3ms/step - loss: 0.5608 - accuracy: 0.7239 - val_loss: 0.5571 - val_accuracy: 0.7129
# Epoch 98/100
# 781/781 [==============================] - 2s 3ms/step - loss: 0.5608 - accuracy: 0.7237 - val_loss: 0.5571 - val_accuracy: 0.7127
# Epoch 99/100
# 781/781 [==============================] - 2s 3ms/step - loss: 0.5608 - accuracy: 0.7239 - val_loss: 0.5571 - val_accuracy: 0.7125
# Epoch 100/100
# 781/781 [==============================] - 2s 3ms/step - loss: 0.5607 - accuracy: 0.7240 - val_loss: 0.5571 - val_accuracy: 0.7127
# Compute valiation accuracy
# 2022-11-21 15:48:15.094668
# accuracy: 71.27%
# 2022-11-21 15:48:17.342308
# Fold 5
# Train sizes 25156 25156
# Valid sizes 6064 6064
# Train set ones/size 12072 / 25156
# Valid set ones/size 3140 / 6064
# BUILD MODEL
# COMPILE...
# ...COMPILED
# FIT
# 2022-11-21 15:48:17.425908
# Epoch 1/100
# 787/787 [==============================] - 5s 6ms/step - loss: 0.6834 - accuracy: 0.5470 - val_loss: 0.6700 - val_accuracy: 0.5821
# Epoch 2/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.6319 - accuracy: 0.6831 - val_loss: 0.6045 - val_accuracy: 0.6933
# Epoch 3/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5961 - accuracy: 0.6958 - val_loss: 0.5904 - val_accuracy: 0.6981
# Epoch 4/100
# 787/787 [==============================] - 3s 4ms/step - loss: 0.5905 - accuracy: 0.6979 - val_loss: 0.5866 - val_accuracy: 0.6981
# Epoch 5/100
# 787/787 [==============================] - 3s 4ms/step - loss: 0.5881 - accuracy: 0.7002 - val_loss: 0.5844 - val_accuracy: 0.6994
# Epoch 6/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5863 - accuracy: 0.7017 - val_loss: 0.5825 - val_accuracy: 0.6997
# Epoch 7/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5847 - accuracy: 0.7031 - val_loss: 0.5808 - val_accuracy: 0.7017
# Epoch 8/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5832 - accuracy: 0.7046 - val_loss: 0.5792 - val_accuracy: 0.7010
# Epoch 9/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5818 - accuracy: 0.7058 - val_loss: 0.5776 - val_accuracy: 0.7018
# Epoch 10/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5804 - accuracy: 0.7073 - val_loss: 0.5761 - val_accuracy: 0.7022
# Epoch 11/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5792 - accuracy: 0.7076 - val_loss: 0.5747 - val_accuracy: 0.7040
# Epoch 12/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5779 - accuracy: 0.7088 - val_loss: 0.5734 - val_accuracy: 0.7045
# Epoch 13/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5767 - accuracy: 0.7100 - val_loss: 0.5722 - val_accuracy: 0.7042
# Epoch 14/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5756 - accuracy: 0.7115 - val_loss: 0.5710 - val_accuracy: 0.7043
# Epoch 15/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5746 - accuracy: 0.7120 - val_loss: 0.5700 - val_accuracy: 0.7048
# Epoch 16/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5736 - accuracy: 0.7125 - val_loss: 0.5690 - val_accuracy: 0.7060
# Epoch 17/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5727 - accuracy: 0.7131 - val_loss: 0.5682 - val_accuracy: 0.7060
# Epoch 18/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5719 - accuracy: 0.7139 - val_loss: 0.5674 - val_accuracy: 0.7076
# Epoch 19/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5712 - accuracy: 0.7150 - val_loss: 0.5668 - val_accuracy: 0.7076
# Epoch 20/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5706 - accuracy: 0.7152 - val_loss: 0.5662 - val_accuracy: 0.7099
# Epoch 21/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5700 - accuracy: 0.7154 - val_loss: 0.5657 - val_accuracy: 0.7114
# Epoch 22/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5694 - accuracy: 0.7155 - val_loss: 0.5652 - val_accuracy: 0.7129
# Epoch 23/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5690 - accuracy: 0.7160 - val_loss: 0.5648 - val_accuracy: 0.7136
# Epoch 24/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5685 - accuracy: 0.7159 - val_loss: 0.5644 - val_accuracy: 0.7144
# Epoch 25/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5681 - accuracy: 0.7161 - val_loss: 0.5641 - val_accuracy: 0.7145
# Epoch 26/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5677 - accuracy: 0.7164 - val_loss: 0.5638 - val_accuracy: 0.7154
# Epoch 27/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5674 - accuracy: 0.7166 - val_loss: 0.5635 - val_accuracy: 0.7152
# Epoch 28/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5671 - accuracy: 0.7172 - val_loss: 0.5633 - val_accuracy: 0.7157
# Epoch 29/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5667 - accuracy: 0.7175 - val_loss: 0.5630 - val_accuracy: 0.7157
# Epoch 30/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5664 - accuracy: 0.7176 - val_loss: 0.5628 - val_accuracy: 0.7155
# Epoch 31/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5662 - accuracy: 0.7177 - val_loss: 0.5626 - val_accuracy: 0.7157
# Epoch 32/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5659 - accuracy: 0.7181 - val_loss: 0.5624 - val_accuracy: 0.7165
# Epoch 33/100
# 787/787 [==============================] - 3s 4ms/step - loss: 0.5656 - accuracy: 0.7179 - val_loss: 0.5623 - val_accuracy: 0.7167
# Epoch 34/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5654 - accuracy: 0.7176 - val_loss: 0.5621 - val_accuracy: 0.7170
# Epoch 35/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5652 - accuracy: 0.7182 - val_loss: 0.5619 - val_accuracy: 0.7173
# Epoch 36/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5649 - accuracy: 0.7187 - val_loss: 0.5618 - val_accuracy: 0.7173
# Epoch 37/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5647 - accuracy: 0.7191 - val_loss: 0.5616 - val_accuracy: 0.7173
# Epoch 38/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5645 - accuracy: 0.7191 - val_loss: 0.5615 - val_accuracy: 0.7172
# Epoch 39/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5643 - accuracy: 0.7193 - val_loss: 0.5614 - val_accuracy: 0.7175
# Epoch 40/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5641 - accuracy: 0.7197 - val_loss: 0.5613 - val_accuracy: 0.7178
# Epoch 41/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5639 - accuracy: 0.7202 - val_loss: 0.5612 - val_accuracy: 0.7183
# Epoch 42/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5637 - accuracy: 0.7204 - val_loss: 0.5611 - val_accuracy: 0.7188
# Epoch 43/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5635 - accuracy: 0.7205 - val_loss: 0.5610 - val_accuracy: 0.7182
# Epoch 44/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5634 - accuracy: 0.7205 - val_loss: 0.5609 - val_accuracy: 0.7177
# Epoch 45/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5632 - accuracy: 0.7202 - val_loss: 0.5608 - val_accuracy: 0.7175
# Epoch 46/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5630 - accuracy: 0.7204 - val_loss: 0.5607 - val_accuracy: 0.7178
# Epoch 47/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5629 - accuracy: 0.7204 - val_loss: 0.5606 - val_accuracy: 0.7183
# Epoch 48/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5627 - accuracy: 0.7207 - val_loss: 0.5605 - val_accuracy: 0.7185
# Epoch 49/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5626 - accuracy: 0.7206 - val_loss: 0.5605 - val_accuracy: 0.7177
# Epoch 50/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5624 - accuracy: 0.7209 - val_loss: 0.5604 - val_accuracy: 0.7177
# Epoch 51/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5623 - accuracy: 0.7210 - val_loss: 0.5603 - val_accuracy: 0.7178
# Epoch 52/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5621 - accuracy: 0.7213 - val_loss: 0.5603 - val_accuracy: 0.7178
# Epoch 53/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5620 - accuracy: 0.7212 - val_loss: 0.5602 - val_accuracy: 0.7180
# Epoch 54/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5619 - accuracy: 0.7213 - val_loss: 0.5602 - val_accuracy: 0.7180
# Epoch 55/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5618 - accuracy: 0.7213 - val_loss: 0.5601 - val_accuracy: 0.7183
# Epoch 56/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5616 - accuracy: 0.7214 - val_loss: 0.5601 - val_accuracy: 0.7190
# Epoch 57/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5615 - accuracy: 0.7217 - val_loss: 0.5601 - val_accuracy: 0.7187
# Epoch 58/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5614 - accuracy: 0.7219 - val_loss: 0.5600 - val_accuracy: 0.7188
# Epoch 59/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5613 - accuracy: 0.7216 - val_loss: 0.5600 - val_accuracy: 0.7190
# Epoch 60/100
# 787/787 [==============================] - 3s 3ms/step - loss: 0.5612 - accuracy: 0.7215 - val_loss: 0.5600 - val_accuracy: 0.7193
# Epoch 61/100
# 787/787 [==============================] - 4s 5ms/step - loss: 0.5611 - accuracy: 0.7215 - val_loss: 0.5599 - val_accuracy: 0.7193
# Epoch 62/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5610 - accuracy: 0.7217 - val_loss: 0.5599 - val_accuracy: 0.7190
# Epoch 63/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5609 - accuracy: 0.7217 - val_loss: 0.5599 - val_accuracy: 0.7190
# Epoch 64/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5608 - accuracy: 0.7218 - val_loss: 0.5599 - val_accuracy: 0.7193
# Epoch 65/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5607 - accuracy: 0.7219 - val_loss: 0.5598 - val_accuracy: 0.7197
# Epoch 66/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5606 - accuracy: 0.7221 - val_loss: 0.5598 - val_accuracy: 0.7205
# Epoch 67/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5605 - accuracy: 0.7222 - val_loss: 0.5598 - val_accuracy: 0.7203
# Epoch 68/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5604 - accuracy: 0.7223 - val_loss: 0.5598 - val_accuracy: 0.7205
# Epoch 69/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5604 - accuracy: 0.7223 - val_loss: 0.5598 - val_accuracy: 0.7202
# Epoch 70/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5603 - accuracy: 0.7223 - val_loss: 0.5598 - val_accuracy: 0.7200
# Epoch 71/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5602 - accuracy: 0.7224 - val_loss: 0.5598 - val_accuracy: 0.7202
# Epoch 72/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5601 - accuracy: 0.7227 - val_loss: 0.5598 - val_accuracy: 0.7210
# Epoch 73/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5601 - accuracy: 0.7227 - val_loss: 0.5598 - val_accuracy: 0.7213
# Epoch 74/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5600 - accuracy: 0.7226 - val_loss: 0.5598 - val_accuracy: 0.7213
# Epoch 75/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5599 - accuracy: 0.7225 - val_loss: 0.5598 - val_accuracy: 0.7211
# Epoch 76/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5599 - accuracy: 0.7225 - val_loss: 0.5598 - val_accuracy: 0.7211
# Epoch 77/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5598 - accuracy: 0.7226 - val_loss: 0.5598 - val_accuracy: 0.7218
# Epoch 78/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5597 - accuracy: 0.7223 - val_loss: 0.5598 - val_accuracy: 0.7220
# Epoch 79/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5597 - accuracy: 0.7221 - val_loss: 0.5598 - val_accuracy: 0.7220
# Epoch 80/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5596 - accuracy: 0.7220 - val_loss: 0.5598 - val_accuracy: 0.7218
# Epoch 81/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5596 - accuracy: 0.7222 - val_loss: 0.5598 - val_accuracy: 0.7220
# Epoch 82/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5595 - accuracy: 0.7223 - val_loss: 0.5598 - val_accuracy: 0.7220
# Epoch 83/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5595 - accuracy: 0.7224 - val_loss: 0.5598 - val_accuracy: 0.7220
# Epoch 84/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5594 - accuracy: 0.7223 - val_loss: 0.5598 - val_accuracy: 0.7220
# Epoch 85/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5594 - accuracy: 0.7224 - val_loss: 0.5598 - val_accuracy: 0.7223
# Epoch 86/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5593 - accuracy: 0.7224 - val_loss: 0.5599 - val_accuracy: 0.7225
# Epoch 87/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5593 - accuracy: 0.7225 - val_loss: 0.5599 - val_accuracy: 0.7220
# Epoch 88/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5592 - accuracy: 0.7223 - val_loss: 0.5599 - val_accuracy: 0.7218
# Epoch 89/100
# 787/787 [==============================] - 3s 3ms/step - loss: 0.5592 - accuracy: 0.7225 - val_loss: 0.5599 - val_accuracy: 0.7218
# Epoch 90/100
# 787/787 [==============================] - 4s 5ms/step - loss: 0.5592 - accuracy: 0.7225 - val_loss: 0.5599 - val_accuracy: 0.7216
# Epoch 91/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5591 - accuracy: 0.7224 - val_loss: 0.5599 - val_accuracy: 0.7218
# Epoch 92/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5591 - accuracy: 0.7223 - val_loss: 0.5599 - val_accuracy: 0.7220
# Epoch 93/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5591 - accuracy: 0.7224 - val_loss: 0.5599 - val_accuracy: 0.7220
# Epoch 94/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5590 - accuracy: 0.7228 - val_loss: 0.5600 - val_accuracy: 0.7218
# Epoch 95/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5590 - accuracy: 0.7227 - val_loss: 0.5600 - val_accuracy: 0.7215
# Epoch 96/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5590 - accuracy: 0.7227 - val_loss: 0.5600 - val_accuracy: 0.7215
# Epoch 97/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5589 - accuracy: 0.7226 - val_loss: 0.5600 - val_accuracy: 0.7213
# Epoch 98/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5589 - accuracy: 0.7227 - val_loss: 0.5600 - val_accuracy: 0.7213
# Epoch 99/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5589 - accuracy: 0.7228 - val_loss: 0.5600 - val_accuracy: 0.7215
# Epoch 100/100
# 787/787 [==============================] - 2s 3ms/step - loss: 0.5588 - accuracy: 0.7228 - val_loss: 0.5601 - val_accuracy: 0.7213
# Compute valiation accuracy
# 2022-11-21 15:52:42.825798
# accuracy: 72.13%
# 2022-11-21 15:52:45.063739
# Cross validation acc mean 71.58% (+/- 0.44%)
# 2022-11-21 15:52:45.066542
