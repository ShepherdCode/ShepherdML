# %% [markdown]
# # CNN + MaxPool
# Unfortunately, CNN_184 did not print any information about the RCI threshold which is implicit in the GMM. Here, skip the taining but do print approximate thresholds.

# %%
from datetime import datetime
print(datetime.now())
from platform import python_version
print('Python',python_version())
import numpy as np
import pandas as pd
import scipy.stats as ss
import pickle
import time # sleep function
from os.path import isfile
from matplotlib import pyplot as plt 
import sklearn   # pip install --upgrade scikit-learn
print('sklearn',sklearn.__version__)
# Out:
# 2023-02-14 11:17:37.820636
# Python 3.10.0
# sklearn 1.1.2

# %% [markdown]
# We prevously used sklearn.model_selection.ShuffleSplit
# Now we avoid it due to this note in the
# [documentation](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.ShuffleSplit.html):
# Note: contrary to other cross-validation strategies, random splits do not guarantee that all folds will be different, although this is still very likely for sizeable datasets.

# %%
import tensorflow as tf
dt='float32'
tf.keras.backend.set_floatx('float32')
tf.random.set_seed(42) 

from tensorflow import keras
from sklearn.mixture import GaussianMixture
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc

from keras.models import Sequential
from keras.layers import Masking
from keras.layers import Embedding
from keras.layers import Conv1D
from keras.layers import GlobalAveragePooling1D
from keras.layers import GlobalMaxPooling1D
from keras.layers import AveragePooling1D
from keras.layers import MaxPooling1D
from keras.layers import Bidirectional
from keras.layers import LSTM
from keras.layers import TimeDistributed
from keras.layers import Flatten
from keras.layers import Dense
from keras.layers import Dropout
from keras.losses import BinaryCrossentropy

K=4
CFILTERS=64
FILTERSIZE=16
RCELLS=32
DCELLS=16
EPOCHS=3
FOLDS=10      
EMBED_DIMEN = 4 # arbitrary hyperparameter
MINLEN=200
MAXLEN=5000   
PRETTY_PICTURES = True
RCI_THRESHOLD_MECHANISM = 'RCI_GMM' # 'ZERO' 'THE_MEAN'
BREAK = False   # break after first fold
CACHING = False   # have not worked out how to cache multiple cell lines
NUM_LINES = 15   # 15 to analyze all of them
# Out:
# 2023-02-14 11:17:41.599433: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
try:
    from google.colab import drive
    IN_COLAB = True
    print('Running on CoLab')
    PATH='/content/drive/'
    drive.mount(PATH)
    DATA_DIR=PATH+'My Drive/data/Localization/TrainTest/'  # must end in "/"
except:
    IN_COLAB = False
    DATA_DIR = 'D:/Adjeroh/Localization/TrainTest/'   # Windows
    DATA_DIR = '/Users/jasonmiller/WVU/Localization/TrainTest/'    # Mac
print(DATA_DIR)
# Out:
# /Users/jasonmiller/WVU/Localization/TrainTest/

# %%
RCI_FILE =      'CNRCI_noncoding_train_RCI.gc42.csv'
SEQUENCE_FILE = 'CNRCI_noncoding_train_transcripts.gc42.csv'
CACHE_SEQUENCE = 'cache.seq.pickle'
CACHE_IDS = 'cache.id.pickle'
if CACHING:
    cache_seq = DATA_DIR+CACHE_SEQUENCE 
    cache_ids = DATA_DIR+CACHE_IDS 
    if isfile(cache_seq) and isfile(cache_ids):
        print('WARNING: this run will read sequence from cache.')
    else:
        print('INFO: this run will write sequence to cache.')

# %%
def get_ordered_list():
    ordered_list = \
    ['A549','H1.hESC','HeLa.S3','HepG2','HT1080',\
      'HUVEC','MCF.7','NCI.H460','NHEK','SK.MEL.5',\
      'SK.N.DZ','SK.N.SH','GM12878','K562','IMR.90']
    return ordered_list
all_cell_lines = get_ordered_list()

EXCLUSIONS = [1,7]   # use these though they are clearly different

# %% [markdown]
# ## Data Load

# %%
class DataLoader():
    def __init__(self):
        self.cache=dict() 
        self.vals = {'A':0, 'C':1, 'G':2, 'T':3}
        
    def load_gene_rci_values(self,filepath,cell_line):
        '''
        Load from RCI csv file.
        Return dict with keys=gene:str and values=RCI:float.
        '''
        gene_to_rci = {}
        overall_sum = 0
        with open (filepath,'r') as handle:
            header = None
            for row in handle:
                if header is None:
                    header = row # skip file's header line
                else:
                    line = row.strip()
                    fields = line.split(',')
                    gene_id = fields.pop(0)
                    rci_str = fields[cell_line]
                    if rci_str != "nan":
                        rci_val = float(rci_str)
                        gene_to_rci[gene_id] = rci_val
        print('Number of RCI values loaded',len(gene_to_rci.keys()))
        return gene_to_rci

    def seq_to_kmer_values(self,rna,K):
        vec=[] # seq converted to list of K-mers 
        N_indicator = 0 # indicator value
        length = len(rna)
        for i in range(length-K+1):
            kmer = rna[i:i+K]
            if 'N' in kmer:
                value = N_indicator
            elif kmer in self.cache.keys():
                value = self.cache[kmer]
            else:
                value = 0
                for j in range(K):
                    value *= 4   
                    nextnuc = kmer[j] 
                    nucval = self.vals[nextnuc]
                    value += nucval
                value += 1   # NNN => 0, AAA => 1
                self.cache[kmer] = value
            vec.append(value)
        return vec

    def load_sequence(self,filepath):
        allids=[]
        allseq=[]
        cache_seq = DATA_DIR+CACHE_SEQUENCE 
        cache_ids = DATA_DIR+CACHE_IDS 
        if CACHING and isfile(cache_seq) and isfile(cache_ids):
            # Warning: the cache may represent the wrong K.
            with open(cache_seq,'rb') as fin:
                allseq = pickle.load(fin)
            with open(cache_ids,'rb') as fin:
                allids = pickle.load(fin)
            return allids,allseq           
        NREPEAT = str('N'*MAXLEN)
        with open (filepath,'r') as handle:
            header = None
            for row in handle:
                if header is None:
                    header = row
                else:
                    line    = row.strip()
                    fields  = line.split(',')
                    tran_id = fields[0]  # with version number
                    gene_id = fields[1]        # without version number
                    seq_len = int(fields[3])
                    seq_txt = fields[4]
                    if seq_len>=MINLEN and seq_len<=MAXLEN and gene_id in gene_to_rci.keys():
                        allids.append( (gene_id,tran_id) )
                        if seq_len<MAXLEN:
                            seq_txt = seq_txt + NREPEAT
                            seq_txt = seq_txt[:MAXLEN]
                        hot_vec = self.seq_to_kmer_values(seq_txt,K)
                        allseq.append(hot_vec)
        if CACHING:
            with open(cache_seq,'wb') as fout:
                pickle.dump(allseq,fout)
            with open(cache_ids,'wb') as fout:
                pickle.dump(allids,fout)
        return allids,allseq

# %% [markdown]
# ## Model

# %%
def build_model():
    ALPHABET=4**K+1  # NUMBER OF DISTINCT KMERS POSSIBLE, add one if N gets mask value
    ADJUST_LENGTH = MAXLEN-K+1  # fixed length sequences
    cnn = Sequential()
    embed_layer = Embedding(ALPHABET,EMBED_DIMEN,input_length=ADJUST_LENGTH,mask_zero=True)   
    cnn1_layer = Conv1D(CFILTERS, FILTERSIZE)
    pool_layer = MaxPooling1D(pool_size=FILTERSIZE, strides=FILTERSIZE//2)
    #pool_layer = GlobalAveragePooling1D()
    flat_layer = Flatten()
    dens_layer = Dense(DCELLS)
    drop_layer = Dropout(0.5)
    output_layer = Dense(1,activation='sigmoid',dtype=dt)

    cnn.add(embed_layer)
    cnn.add(cnn1_layer)
    cnn.add(pool_layer)
    cnn.add(flat_layer)
    cnn.add(dens_layer)
    cnn.add(drop_layer)
    cnn.add(output_layer)

    bc=BinaryCrossentropy(from_logits=False)
    cnn.compile(loss=bc, optimizer="Adam",metrics=["accuracy"])
    return cnn

# %%
print(datetime.now())
model=build_model()
print(model.summary())  # Print this only once
model=None
# Out:
# 2023-02-14 11:17:51.543314
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# 2023-02-14 11:17:51.552994: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
#  embedding (Embedding)       (None, 4997, 4)           1028
#
#  conv1d (Conv1D)             (None, 4982, 64)          4160
#
#  max_pooling1d (MaxPooling1D  (None, 621, 64)          0
#  )
#
#  flatten (Flatten)           (None, 39744)             0
#
#  dense (Dense)               (None, 16)                635920
#
#  dropout (Dropout)           (None, 16)                0
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 641,125
# Trainable params: 641,125
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## Training

# %%
import gc
class CrossValidator():
    def __init__(self,epochs,folds,quick_test=False,score_threshold=0.5):
        self.epochs = epochs
        self.folds = folds
        self.quick_test = quick_test
        self.score_threshold = score_threshold
        self.mechanism = 'ZERO'
        self.discriminator = None
        
    def set_sequences(self, allids, allseq):
        # It is critical to keep IDs and sequences in same order!
        self.all_ids = allids  # pairs of (gene_id,tran_id)
        self.all_seqs = allseq  # may be vectors of K-mers
        genes = []
        for i in range(len(allids)):
            (one_gene,one_tran) = allids[i]
            genes.append(one_gene)
        self.all_genes = genes
            
    def set_rci_map(self, gene_to_rci):
        # The map is for fast lookup, not gene order!
        self.rci_map = gene_to_rci # map gene_id to RCI value
    
    def get_gene_subset(self, sub_index):
        sub_genes = set()
        for index in sub_index:
            one_gene = self.all_genes[index]
            sub_genes.add(one_gene)
        return sub_genes   # this is a set: unordered with fast lookup
    
    def _get_X_y(self, gene_index):
        cnt = len(self.all_ids)
        subsetX=[]
        subsetY=[]
        next_index = 0
        for i in range(cnt):
            if next_index==len(gene_index):
                break
            if i==gene_index[next_index]:
                gene_id,tran_id = self.all_ids[i]
                oneX = self.all_seqs[i]
                oneY = self.rci_map[gene_id]
                subsetX.append(oneX)
                subsetY.append(oneY)
                next_index += 1
        subsetX = np.array(subsetX)
        subsetY = np.array(subsetY).reshape((-1,1))
        return subsetX,subsetY
    
    def set_threshold_mechanism(self, mechanism):
        if mechanism not in ['RCI_GMM','THE_MEAN','ZERO']:
            raise Exception('Unrecognized mechansm:',mechanism)
        self.mechanism = mechanism
    
    def _apply_threshold(self, array_of_rci):
        '''Takes list of float, returns list of labels [0,1].'''
        if self.mechanism == 'RCI_GMM':
            labels = self.discriminator.predict(array_of_rci)
        else:
            IS_CYTO = lambda rci: 1 if rci>rci_threshold else 0
            labels = np.array(list(map(IS_CYTO, array_of_rci)))
        return labels
    
    def _prepare_threshold(self, rci_values):
        if self.mechanism == 'RCI_GMM':
            self.discriminator = GaussianMixture(n_components=2, verbose=0, 
                covariance_type='spherical', n_init=100) 
            self.discriminator.fit(rci_values)
        elif RCI_THRESHOLD_MECHANISM == 'THE_MEAN':
            self.discriminator = np.mean(rci_values)
        else:
            self.discriminator = 0
    
    def _explain_threshold(self):
        if self.mechanism == 'RCI_GMM':
            gmm=self.discriminator
            print('Discriminator is GMM')
            print('Means',gmm.means_)
            print('Variances',gmm.covariances_)
            print('Priors',gmm.weights_)
            num_tests = 20
            for numer in range(num_tests):
                # test values -5 to +5
                test_rci = -5 + 10.0 * numer/num_tests
                value = np.array([test_rci]).reshape((-1,1))
                test_label = gmm.predict(value)
                print('rci=',test_rci,'label=',test_label)
        else:
            print('Discriminator',self.mechanism,self.discriminator)
        
    def do_cross_validation(self):
        cv_accuracy=[]
        cv_precision=[]
        cv_recall=[]
        cv_f1=[]
        cv_auprc=[]
        cv_auroc=[]
        fold=0
        print(datetime.now())
        print('splitting')
        # KFold shuffles once before making the partitions
        splitter = KFold(n_splits=self.folds,shuffle=True,random_state=42)
        splits = splitter.split(self.all_genes)
        splitter = None
        for train_index,valid_index in splits:
            fold += 1
            print('Fold',fold)
            X_train,y_rci = self._get_X_y(train_index)
            self._prepare_threshold(y_rci)  # use train subset only!
            self._explain_threshold()
            y_train = self._apply_threshold(y_rci)
            X_valid,y_rci = self._get_X_y(valid_index)
            y_valid = self._apply_threshold(y_rci) 
            y_rci = None

            if False:

                #print('Training example')
                #print(X_train[0])
                #print("BUILD MODEL")
                model=build_model()
                print("FIT")
                print(datetime.now())
                history=model.fit(X_train, y_train, # batch_size=10, default=32 works nicely
                  epochs=self.epochs, verbose=0,  # verbose=1 for ascii art, verbose=0 for none
                  validation_data=(X_valid,y_valid) )
                print("PREDICT")
                print(datetime.now())
                yhat_pred=model.predict(X_valid, verbose=0)             
                yhat_classes=np.where(yhat_pred > self.score_threshold, 1, 0)

                # accuracy: (tp + tn) / (p + n)
                accuracy = accuracy_score(y_valid, yhat_classes)*100.
                # precision tp / (tp + fp)
                precision = precision_score(y_valid, yhat_classes)*100.
                # recall: tp / (tp + fn)
                recall = recall_score(y_valid, yhat_classes)*100.
                # f1: 2 tp / (2 tp + fp + fn)
                f1 = f1_score(y_valid, yhat_classes)*100.
                # PRC
                prc_Y, prc_X, prc_bins = precision_recall_curve(y_valid, yhat_pred)
                auprc = auc(prc_X,prc_Y)*100.
                auroc = roc_auc_score(y_valid, yhat_pred)*100.

                if PRETTY_PICTURES:
                    pd.DataFrame(history.history).plot(figsize=(8,5))
                    plt.grid(True)
                    plt.gca().set_ylim(0,1)
                    plt.show()

                    print('Train set ones/size',
                          np.count_nonzero(y_train),'/',len(y_train))
                    print("Compute valiation accuracy")
                    print('Valid sizes',X_valid.shape,y_valid.shape)
                    print('Valid set ones/size',
                          np.count_nonzero(y_valid),'/',len(y_valid))
                    print('Range of scores:',np.min(yhat_pred),'to',np.max(yhat_pred))
                    print('Score threshold',self.score_threshold)
                    print('Prediction set ones/size',
                          np.count_nonzero(yhat_classes),'/',len(yhat_classes))
                
                    count_ones= len(y_valid[y_valid==1])
                    count_zeros= len(y_valid[y_valid==0])
                    guess = max(count_ones,count_zeros) / len(y_valid)
                    plt.plot(prc_X, prc_Y, marker='.')
                    plt.plot([0, 1], [guess,guess], linestyle='--')
                    plt.xlabel('Recall')
                    plt.ylabel('Precision')
                    plt.show()
                    # ROC
                    fpr, tpr, roc_bins = roc_curve(y_valid, yhat_pred)
                    plt.plot(fpr, tpr, marker='.')
                    plt.xlabel('False Positive Rate')
                    plt.ylabel('True Positive Rate')
                    plt.show()
                
                print('Accuracy: %.2f%% Precision: %.2f%% Recall: %.2f%%' % (accuracy,precision,recall)) 
                print('F1: %.2f%% AUPRC: %.2f%% AUROC: %.2f%%' % (f1,auprc,auroc)) 
                cv_accuracy.append(accuracy)
                cv_precision.append(precision)
                cv_recall.append(recall)
                cv_f1.append(f1)
                cv_auprc.append(auprc)
                cv_auroc.append(auroc)
            
            print(datetime.now())
            if self.quick_test:   
                print('Break -- this was for code testing only')
                break

            # There is a memory leak within the fit() command!
            # Each successive call to fit() consumes more memory.
            model = None
            history = None
            prc_Y = None
            prc_X = None
            prc_bins = None
            yhat_classes = None
            X_train = None
            y_train = None
            X_valid = None
            y_valid = None
            tf.keras.backend.clear_session()
            gc.collect()
            time.sleep(1)  # hope gc kicks in
        print()
        return cv_accuracy, cv_precision, cv_recall, cv_f1, cv_auprc, cv_auroc

# %%
for CELL_LINE in range(NUM_LINES):
    print(datetime.now())
    print('Start cell Line',CELL_LINE,all_cell_lines[CELL_LINE])
    loader = DataLoader()
    filepath = DATA_DIR+RCI_FILE
    gene_to_rci = loader.load_gene_rci_values(filepath,CELL_LINE)
    print('Num RCI:', len(gene_to_rci.keys()))
    print('Load sequence...')
    filepath = DATA_DIR+SEQUENCE_FILE
    allids,allseq = loader.load_sequence(filepath)
    loader = None  # drop K-mer cache to save RAM

    print("Cross validation...")
    cvdo = CrossValidator(EPOCHS,FOLDS,BREAK)
    cvdo.set_sequences(allids,allseq)
    cvdo.set_rci_map(gene_to_rci)
    cvdo.set_threshold_mechanism(RCI_THRESHOLD_MECHANISM)
    cv_accuracy, cv_precision, cv_recall, cv_f1, cv_auprc, cv_auroc = cvdo.do_cross_validation()   
    cvdo = None
    print("Completed cross validation %d folds %d epochs" % (FOLDS,EPOCHS)) 
    print(" accuracy mean %.2f%% +/- %.2f" % (np.mean(cv_accuracy), np.std(cv_accuracy,ddof=1)))
    print(" precision mean %.2f%% +/- %.2f" % (np.mean(cv_precision), np.std(cv_precision,ddof=1)))
    print(" recall mean %.2f%% +/- %.2f" % (np.mean(cv_recall), np.std(cv_recall,ddof=1)))
    print(" F1 mean %.2f%% +/- %.2f" % (np.mean(cv_f1), np.std(cv_f1,ddof=1)))
    print(" AUPRC mean %.2f%% +/- %.2f" % (np.mean(cv_auprc), np.std(cv_auprc,ddof=1)))
    print(" AUROC mean %.2f%% +/- %.2f" % (np.mean(cv_auroc), np.std(cv_auroc,ddof=1)))
    print('Finished cell Line',CELL_LINE,all_cell_lines[CELL_LINE])
    print()
print(datetime.now())
# Out:
# 2023-02-14 11:17:51.990320
# Start cell Line 0 A549
# Number of RCI values loaded 1447
# Num RCI: 1447
# Load sequence...
# Cross validation...
# 2023-02-14 11:18:10.499425
# splitting
# Fold 1
# Discriminator is GMM
# Means [[-0.96783255]
#  [ 0.58810143]]
# Variances [1.89368705 0.87635584]
# Priors [0.42465818 0.57534182]
# rci= -5.0 label= [0]
# rci= -4.5 label= [0]
# rci= -4.0 label= [0]
# rci= -3.5 label= [0]
# rci= -3.0 label= [0]
# rci= -2.5 label= [0]
# rci= -2.0 label= [0]
# rci= -1.5 label= [0]
# rci= -1.0 label= [0]
# rci= -0.5 label= [1]
# rci= 0.0 label= [1]
# rci= 0.5 label= [1]
# rci= 1.0 label= [1]
# rci= 1.5 label= [1]
# rci= 2.0 label= [1]
# rci= 2.5 label= [1]
# rci= 3.0 label= [1]
# rci= 3.5 label= [1]
# rci= 4.0 label= [1]
# rci= 4.5 label= [0]
# 2023-02-14 11:18:19.143367
# Fold 2
# Discriminator is GMM
# Means [[ 0.57633945]
#  [-0.97655092]]
# Variances [0.88489623 1.89856066]
# Priors [0.57160942 0.42839058]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [1]
# rci= -0.5 label= [0]
# rci= 0.0 label= [0]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [1]
# 2023-02-14 11:18:27.414796
# Fold 3
# Discriminator is GMM
# Means [[ 0.56894947]
#  [-0.94437585]]
# Variances [0.87123385 1.95010908]
# Priors [0.57077302 0.42922698]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [1]
# rci= -0.5 label= [0]
# rci= 0.0 label= [0]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [1]
# 2023-02-14 11:18:36.485814
# Fold 4
# Discriminator is GMM
# Means [[ 0.56809425]
#  [-0.94702423]]
# Variances [0.89685098 1.97641118]
# Priors [0.57777174 0.42222826]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [1]
# rci= -0.5 label= [0]
# rci= 0.0 label= [0]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [1]
# 2023-02-14 11:18:45.297367
# Fold 5
# Discriminator is GMM
# Means [[ 0.55872178]
#  [-0.9373971 ]]
# Variances [0.88676987 1.98053463]
# Priors [0.57368615 0.42631385]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [1]
# rci= -0.5 label= [0]
# rci= 0.0 label= [0]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [1]
# 2023-02-14 11:18:56.613137
# Fold 6
# Discriminator is GMM
# Means [[ 0.58618355]
#  [-0.99125416]]
# Variances [0.88180148 1.90554887]
# Priors [0.57552289 0.42447711]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [1]
# rci= -0.5 label= [0]
# rci= 0.0 label= [0]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [1]
# 2023-02-14 11:19:06.119979
# Fold 7
# Discriminator is GMM
# Means [[ 0.59783961]
#  [-0.96105196]]
# Variances [0.88851043 1.84837778]
# Priors [0.57016285 0.42983715]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [1]
# rci= -0.5 label= [0]
# rci= 0.0 label= [0]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [0]
# 2023-02-14 11:19:17.238248
# Fold 8
# Discriminator is GMM
# Means [[ 0.56704421]
#  [-0.94196339]]
# Variances [0.9025308  1.96771895]
# Priors [0.5748989 0.4251011]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [1]
# rci= -0.5 label= [0]
# rci= 0.0 label= [0]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [1]
# 2023-02-14 11:19:27.029770
# Fold 9
# Discriminator is GMM
# Means [[-0.93368277]
#  [ 0.55510488]]
# Variances [1.9573652  0.87575272]
# Priors [0.4274285 0.5725715]
# rci= -5.0 label= [0]
# rci= -4.5 label= [0]
# rci= -4.0 label= [0]
# rci= -3.5 label= [0]
# rci= -3.0 label= [0]
# rci= -2.5 label= [0]
# rci= -2.0 label= [0]
# rci= -1.5 label= [0]
# rci= -1.0 label= [0]
# rci= -0.5 label= [1]
# rci= 0.0 label= [1]
# rci= 0.5 label= [1]
# rci= 1.0 label= [1]
# rci= 1.5 label= [1]
# rci= 2.0 label= [1]
# rci= 2.5 label= [1]
# rci= 3.0 label= [1]
# rci= 3.5 label= [1]
# rci= 4.0 label= [1]
# rci= 4.5 label= [0]
# 2023-02-14 11:19:36.535397
# Fold 10
# Discriminator is GMM
# Means [[ 0.56844724]
#  [-0.94155523]]
# Variances [0.88136011 1.95845933]
# Priors [0.57154056 0.42845944]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [1]
# rci= -0.5 label= [0]
# rci= 0.0 label= [0]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [1]
# 2023-02-14 11:19:46.696635
#
# Completed cross validation 10 folds 3 epochs
#  accuracy mean nan% +/- nan
#  precision mean nan% +/- nan
#  recall mean nan% +/- nan
#  F1 mean nan% +/- nan
#  AUPRC mean nan% +/- nan
#  AUROC mean nan% +/- nan
# Finished cell Line 0 A549
#
# 2023-02-14 11:19:48.151781
# Start cell Line 1 H1.hESC
# Number of RCI values loaded 3327
# Num RCI: 3327
# Load sequence...
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/_methods.py:265: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/_methods.py:223: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean, casting='unsafe',
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Cross validation...
# 2023-02-14 11:20:22.505991
# splitting
# Fold 1
# Discriminator is GMM
# Means [[ 0.42572199]
#  [-0.94339151]]
# Variances [1.38963576 1.3773158 ]
# Priors [0.48012172 0.51987828]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [1]
# rci= -0.5 label= [1]
# rci= 0.0 label= [0]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [0]
# 2023-02-14 11:20:35.662572
# Fold 2
# Discriminator is GMM
# Means [[-0.92580338]
#  [ 0.43922577]]
# Variances [1.3712376  1.40518122]
# Priors [0.52453727 0.47546273]
# rci= -5.0 label= [0]
# rci= -4.5 label= [0]
# rci= -4.0 label= [0]
# rci= -3.5 label= [0]
# rci= -3.0 label= [0]
# rci= -2.5 label= [0]
# rci= -2.0 label= [0]
# rci= -1.5 label= [0]
# rci= -1.0 label= [0]
# rci= -0.5 label= [0]
# rci= 0.0 label= [1]
# rci= 0.5 label= [1]
# rci= 1.0 label= [1]
# rci= 1.5 label= [1]
# rci= 2.0 label= [1]
# rci= 2.5 label= [1]
# rci= 3.0 label= [1]
# rci= 3.5 label= [1]
# rci= 4.0 label= [1]
# rci= 4.5 label= [1]
# 2023-02-14 11:20:49.858040
# Fold 3
# Discriminator is GMM
# Means [[-0.9279393 ]
#  [ 0.43323677]]
# Variances [1.3880729  1.41768182]
# Priors [0.52739569 0.47260431]
# rci= -5.0 label= [0]
# rci= -4.5 label= [0]
# rci= -4.0 label= [0]
# rci= -3.5 label= [0]
# rci= -3.0 label= [0]
# rci= -2.5 label= [0]
# rci= -2.0 label= [0]
# rci= -1.5 label= [0]
# rci= -1.0 label= [0]
# rci= -0.5 label= [0]
# rci= 0.0 label= [1]
# rci= 0.5 label= [1]
# rci= 1.0 label= [1]
# rci= 1.5 label= [1]
# rci= 2.0 label= [1]
# rci= 2.5 label= [1]
# rci= 3.0 label= [1]
# rci= 3.5 label= [1]
# rci= 4.0 label= [1]
# rci= 4.5 label= [1]
# 2023-02-14 11:21:03.426362
# Fold 4
# Discriminator is GMM
# Means [[-0.92555838]
#  [ 0.43029091]]
# Variances [1.37748709 1.41774285]
# Priors [0.52689996 0.47310004]
# rci= -5.0 label= [0]
# rci= -4.5 label= [0]
# rci= -4.0 label= [0]
# rci= -3.5 label= [0]
# rci= -3.0 label= [0]
# rci= -2.5 label= [0]
# rci= -2.0 label= [0]
# rci= -1.5 label= [0]
# rci= -1.0 label= [0]
# rci= -0.5 label= [0]
# rci= 0.0 label= [1]
# rci= 0.5 label= [1]
# rci= 1.0 label= [1]
# rci= 1.5 label= [1]
# rci= 2.0 label= [1]
# rci= 2.5 label= [1]
# rci= 3.0 label= [1]
# rci= 3.5 label= [1]
# rci= 4.0 label= [1]
# rci= 4.5 label= [1]
# 2023-02-14 11:21:17.340562
# Fold 5
# Discriminator is GMM
# Means [[ 0.42259762]
#  [-0.93708225]]
# Variances [1.40089672 1.3698043 ]
# Priors [0.47678129 0.52321871]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [1]
# rci= -0.5 label= [1]
# rci= 0.0 label= [0]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [0]
# 2023-02-14 11:21:31.425712
# Fold 6
# Discriminator is GMM
# Means [[ 0.43687381]
#  [-0.92959667]]
# Variances [1.43653616 1.38707939]
# Priors [0.47109826 0.52890174]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [1]
# rci= -0.5 label= [1]
# rci= 0.0 label= [0]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [0]
# 2023-02-14 11:21:48.019912
# Fold 7
# Discriminator is GMM
# Means [[ 0.42217569]
#  [-0.93258316]]
# Variances [1.41114226 1.38265548]
# Priors [0.47908016 0.52091984]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [1]
# rci= -0.5 label= [1]
# rci= 0.0 label= [0]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [0]
# 2023-02-14 11:22:02.449214
# Fold 8
# Discriminator is GMM
# Means [[ 0.40500762]
#  [-0.95962508]]
# Variances [1.40489839 1.38854096]
# Priors [0.49822593 0.50177407]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [1]
# rci= -0.5 label= [1]
# rci= 0.0 label= [0]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [0]
# 2023-02-14 11:22:17.992209
# Fold 9
# Discriminator is GMM
# Means [[-0.93962202]
#  [ 0.43109155]]
# Variances [1.37738967 1.39938075]
# Priors [0.51897002 0.48102998]
# rci= -5.0 label= [0]
# rci= -4.5 label= [0]
# rci= -4.0 label= [0]
# rci= -3.5 label= [0]
# rci= -3.0 label= [0]
# rci= -2.5 label= [0]
# rci= -2.0 label= [0]
# rci= -1.5 label= [0]
# rci= -1.0 label= [0]
# rci= -0.5 label= [0]
# rci= 0.0 label= [1]
# rci= 0.5 label= [1]
# rci= 1.0 label= [1]
# rci= 1.5 label= [1]
# rci= 2.0 label= [1]
# rci= 2.5 label= [1]
# rci= 3.0 label= [1]
# rci= 3.5 label= [1]
# rci= 4.0 label= [1]
# rci= 4.5 label= [1]
# 2023-02-14 11:22:34.702590
# Fold 10
# Discriminator is GMM
# Means [[-0.94123257]
#  [ 0.42623114]]
# Variances [1.37632519 1.40308477]
# Priors [0.51961398 0.48038602]
# rci= -5.0 label= [0]
# rci= -4.5 label= [0]
# rci= -4.0 label= [0]
# rci= -3.5 label= [0]
# rci= -3.0 label= [0]
# rci= -2.5 label= [0]
# rci= -2.0 label= [0]
# rci= -1.5 label= [0]
# rci= -1.0 label= [0]
# rci= -0.5 label= [0]
# rci= 0.0 label= [1]
# rci= 0.5 label= [1]
# rci= 1.0 label= [1]
# rci= 1.5 label= [1]
# rci= 2.0 label= [1]
# rci= 2.5 label= [1]
# rci= 3.0 label= [1]
# rci= 3.5 label= [1]
# rci= 4.0 label= [1]
# rci= 4.5 label= [1]
# 2023-02-14 11:22:49.263607
#
# Completed cross validation 10 folds 3 epochs
#  accuracy mean nan% +/- nan
#  precision mean nan% +/- nan
#  recall mean nan% +/- nan
#  F1 mean nan% +/- nan
#  AUPRC mean nan% +/- nan
#  AUROC mean nan% +/- nan
# Finished cell Line 1 H1.hESC
#
# 2023-02-14 11:22:50.912793
# Start cell Line 2 HeLa.S3
# Number of RCI values loaded 919
# Num RCI: 919
# Load sequence...
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/_methods.py:265: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/_methods.py:223: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean, casting='unsafe',
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Cross validation...
# 2023-02-14 11:23:02.264127
# splitting
# Fold 1
# Discriminator is GMM
# Means [[ 0.2132687 ]
#  [-2.21564105]]
# Variances [1.28402137 1.52326069]
# Priors [0.38375288 0.61624712]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [1]
# rci= -0.5 label= [0]
# rci= 0.0 label= [0]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [0]
# 2023-02-14 11:23:07.183055
# Fold 2
# Discriminator is GMM
# Means [[-2.2029888 ]
#  [ 0.24244014]]
# Variances [1.53044047 1.26302496]
# Priors [0.62274329 0.37725671]
# rci= -5.0 label= [0]
# rci= -4.5 label= [0]
# rci= -4.0 label= [0]
# rci= -3.5 label= [0]
# rci= -3.0 label= [0]
# rci= -2.5 label= [0]
# rci= -2.0 label= [0]
# rci= -1.5 label= [0]
# rci= -1.0 label= [0]
# rci= -0.5 label= [1]
# rci= 0.0 label= [1]
# rci= 0.5 label= [1]
# rci= 1.0 label= [1]
# rci= 1.5 label= [1]
# rci= 2.0 label= [1]
# rci= 2.5 label= [1]
# rci= 3.0 label= [1]
# rci= 3.5 label= [1]
# rci= 4.0 label= [1]
# rci= 4.5 label= [1]
# 2023-02-14 11:23:13.116890
# Fold 3
# Discriminator is GMM
# Means [[-2.2001023 ]
#  [ 0.24395063]]
# Variances [1.55764596 1.28556721]
# Priors [0.62256023 0.37743977]
# rci= -5.0 label= [0]
# rci= -4.5 label= [0]
# rci= -4.0 label= [0]
# rci= -3.5 label= [0]
# rci= -3.0 label= [0]
# rci= -2.5 label= [0]
# rci= -2.0 label= [0]
# rci= -1.5 label= [0]
# rci= -1.0 label= [0]
# rci= -0.5 label= [1]
# rci= 0.0 label= [1]
# rci= 0.5 label= [1]
# rci= 1.0 label= [1]
# rci= 1.5 label= [1]
# rci= 2.0 label= [1]
# rci= 2.5 label= [1]
# rci= 3.0 label= [1]
# rci= 3.5 label= [1]
# rci= 4.0 label= [1]
# rci= 4.5 label= [1]
# 2023-02-14 11:23:19.131613
# Fold 4
# Discriminator is GMM
# Means [[ 0.2332894 ]
#  [-2.21441409]]
# Variances [1.26460434 1.53699144]
# Priors [0.38339219 0.61660781]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [1]
# rci= -0.5 label= [0]
# rci= 0.0 label= [0]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [0]
# 2023-02-14 11:23:25.260400
# Fold 5
# Discriminator is GMM
# Means [[-2.2180173 ]
#  [ 0.23619174]]
# Variances [1.53414046 1.2713961 ]
# Priors [0.62103766 0.37896234]
# rci= -5.0 label= [0]
# rci= -4.5 label= [0]
# rci= -4.0 label= [0]
# rci= -3.5 label= [0]
# rci= -3.0 label= [0]
# rci= -2.5 label= [0]
# rci= -2.0 label= [0]
# rci= -1.5 label= [0]
# rci= -1.0 label= [0]
# rci= -0.5 label= [1]
# rci= 0.0 label= [1]
# rci= 0.5 label= [1]
# rci= 1.0 label= [1]
# rci= 1.5 label= [1]
# rci= 2.0 label= [1]
# rci= 2.5 label= [1]
# rci= 3.0 label= [1]
# rci= 3.5 label= [1]
# rci= 4.0 label= [1]
# rci= 4.5 label= [1]
# 2023-02-14 11:23:31.137769
# Fold 6
# Discriminator is GMM
# Means [[-2.20088755]
#  [ 0.23034059]]
# Variances [1.5268434  1.28430256]
# Priors [0.62354453 0.37645547]
# rci= -5.0 label= [0]
# rci= -4.5 label= [0]
# rci= -4.0 label= [0]
# rci= -3.5 label= [0]
# rci= -3.0 label= [0]
# rci= -2.5 label= [0]
# rci= -2.0 label= [0]
# rci= -1.5 label= [0]
# rci= -1.0 label= [0]
# rci= -0.5 label= [1]
# rci= 0.0 label= [1]
# rci= 0.5 label= [1]
# rci= 1.0 label= [1]
# rci= 1.5 label= [1]
# rci= 2.0 label= [1]
# rci= 2.5 label= [1]
# rci= 3.0 label= [1]
# rci= 3.5 label= [1]
# rci= 4.0 label= [1]
# rci= 4.5 label= [1]
# 2023-02-14 11:23:37.398677
# Fold 7
# Discriminator is GMM
# Means [[ 0.21283414]
#  [-2.23113701]]
# Variances [1.270875   1.55600021]
# Priors [0.38067587 0.61932413]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [1]
# rci= -0.5 label= [0]
# rci= 0.0 label= [0]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [0]
# 2023-02-14 11:23:45.828991
# Fold 8
# Discriminator is GMM
# Means [[-2.20823844]
#  [ 0.24804925]]
# Variances [1.5277877  1.25341829]
# Priors [0.62160882 0.37839118]
# rci= -5.0 label= [0]
# rci= -4.5 label= [0]
# rci= -4.0 label= [0]
# rci= -3.5 label= [0]
# rci= -3.0 label= [0]
# rci= -2.5 label= [0]
# rci= -2.0 label= [0]
# rci= -1.5 label= [0]
# rci= -1.0 label= [0]
# rci= -0.5 label= [1]
# rci= 0.0 label= [1]
# rci= 0.5 label= [1]
# rci= 1.0 label= [1]
# rci= 1.5 label= [1]
# rci= 2.0 label= [1]
# rci= 2.5 label= [1]
# rci= 3.0 label= [1]
# rci= 3.5 label= [1]
# rci= 4.0 label= [1]
# rci= 4.5 label= [1]
# 2023-02-14 11:23:52.421426
# Fold 9
# Discriminator is GMM
# Means [[ 0.25036686]
#  [-2.20489624]]
# Variances [1.29039132 1.53959939]
# Priors [0.36982874 0.63017126]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [1]
# rci= -0.5 label= [0]
# rci= 0.0 label= [0]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [0]
# 2023-02-14 11:23:58.855853
# Fold 10
# Discriminator is GMM
# Means [[-2.22825034]
#  [ 0.18317642]]
# Variances [1.55049175 1.32523818]
# Priors [0.61121067 0.38878933]
# rci= -5.0 label= [0]
# rci= -4.5 label= [0]
# rci= -4.0 label= [0]
# rci= -3.5 label= [0]
# rci= -3.0 label= [0]
# rci= -2.5 label= [0]
# rci= -2.0 label= [0]
# rci= -1.5 label= [0]
# rci= -1.0 label= [0]
# rci= -0.5 label= [1]
# rci= 0.0 label= [1]
# rci= 0.5 label= [1]
# rci= 1.0 label= [1]
# rci= 1.5 label= [1]
# rci= 2.0 label= [1]
# rci= 2.5 label= [1]
# rci= 3.0 label= [1]
# rci= 3.5 label= [1]
# rci= 4.0 label= [1]
# rci= 4.5 label= [1]
# 2023-02-14 11:24:05.103901
#
# Completed cross validation 10 folds 3 epochs
#  accuracy mean nan% +/- nan
#  precision mean nan% +/- nan
#  recall mean nan% +/- nan
#  F1 mean nan% +/- nan
#  AUPRC mean nan% +/- nan
#  AUROC mean nan% +/- nan
# Finished cell Line 2 HeLa.S3
#
# 2023-02-14 11:24:06.419375
# Start cell Line 3 HepG2
# Number of RCI values loaded 1362
# Num RCI: 1362
# Load sequence...
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/_methods.py:265: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/_methods.py:223: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean, casting='unsafe',
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Cross validation...
# 2023-02-14 11:24:23.195133
# splitting
# Fold 1
# Discriminator is GMM
# Means [[-1.90046395]
#  [ 0.20477243]]
# Variances [2.24575716 1.56416781]
# Priors [0.61215829 0.38784171]
# rci= -5.0 label= [0]
# rci= -4.5 label= [0]
# rci= -4.0 label= [0]
# rci= -3.5 label= [0]
# rci= -3.0 label= [0]
# rci= -2.5 label= [0]
# rci= -2.0 label= [0]
# rci= -1.5 label= [0]
# rci= -1.0 label= [0]
# rci= -0.5 label= [1]
# rci= 0.0 label= [1]
# rci= 0.5 label= [1]
# rci= 1.0 label= [1]
# rci= 1.5 label= [1]
# rci= 2.0 label= [1]
# rci= 2.5 label= [1]
# rci= 3.0 label= [1]
# rci= 3.5 label= [1]
# rci= 4.0 label= [1]
# rci= 4.5 label= [1]
# 2023-02-14 11:24:30.240699
# Fold 2
# Discriminator is GMM
# Means [[ 0.19681601]
#  [-1.89451033]]
# Variances [1.56630979 2.22008805]
# Priors [0.38939818 0.61060182]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [1]
# rci= -0.5 label= [0]
# rci= 0.0 label= [0]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [0]
# 2023-02-14 11:24:38.787118
# Fold 3
# Discriminator is GMM
# Means [[ 0.18342731]
#  [-1.88781659]]
# Variances [1.59499021 2.28294434]
# Priors [0.39217125 0.60782875]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [1]
# rci= -0.5 label= [0]
# rci= 0.0 label= [0]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [0]
# 2023-02-14 11:24:47.431752
# Fold 4
# Discriminator is GMM
# Means [[ 0.1984139]
#  [-1.9002295]]
# Variances [1.54821036 2.21197723]
# Priors [0.39090914 0.60909086]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [1]
# rci= -0.5 label= [0]
# rci= 0.0 label= [0]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [0]
# 2023-02-14 11:24:56.154949
# Fold 5
# Discriminator is GMM
# Means [[ 0.23041842]
#  [-1.92365229]]
# Variances [1.54103244 2.13283526]
# Priors [0.39079467 0.60920533]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [1]
# rci= -0.5 label= [0]
# rci= 0.0 label= [0]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [0]
# 2023-02-14 11:25:05.276422
# Fold 6
# Discriminator is GMM
# Means [[ 0.21047932]
#  [-1.89281925]]
# Variances [1.57417104 2.20008263]
# Priors [0.38601511 0.61398489]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [1]
# rci= -0.5 label= [1]
# rci= 0.0 label= [0]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [0]
# 2023-02-14 11:25:18.458048
# Fold 7
# Discriminator is GMM
# Means [[ 0.18387581]
#  [-1.89826337]]
# Variances [1.57501549 2.28449468]
# Priors [0.39169994 0.60830006]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [1]
# rci= -0.5 label= [0]
# rci= 0.0 label= [0]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [0]
# 2023-02-14 11:25:26.385267
# Fold 8
# Discriminator is GMM
# Means [[ 0.15928625]
#  [-1.8945465 ]]
# Variances [1.58063269 2.27430301]
# Priors [0.39256731 0.60743269]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [1]
# rci= -0.5 label= [0]
# rci= 0.0 label= [0]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [0]
# 2023-02-14 11:25:34.287650
# Fold 9
# Discriminator is GMM
# Means [[ 0.18682789]
#  [-1.89096166]]
# Variances [1.58995876 2.26548925]
# Priors [0.38921986 0.61078014]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [1]
# rci= -0.5 label= [0]
# rci= 0.0 label= [0]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [0]
# 2023-02-14 11:25:42.263756
# Fold 10
# Discriminator is GMM
# Means [[-1.8926451 ]
#  [ 0.18452281]]
# Variances [2.24296745 1.60161847]
# Priors [0.61016267 0.38983733]
# rci= -5.0 label= [0]
# rci= -4.5 label= [0]
# rci= -4.0 label= [0]
# rci= -3.5 label= [0]
# rci= -3.0 label= [0]
# rci= -2.5 label= [0]
# rci= -2.0 label= [0]
# rci= -1.5 label= [0]
# rci= -1.0 label= [0]
# rci= -0.5 label= [1]
# rci= 0.0 label= [1]
# rci= 0.5 label= [1]
# rci= 1.0 label= [1]
# rci= 1.5 label= [1]
# rci= 2.0 label= [1]
# rci= 2.5 label= [1]
# rci= 3.0 label= [1]
# rci= 3.5 label= [1]
# rci= 4.0 label= [1]
# rci= 4.5 label= [1]
# 2023-02-14 11:25:50.210734
#
# Completed cross validation 10 folds 3 epochs
#  accuracy mean nan% +/- nan
#  precision mean nan% +/- nan
#  recall mean nan% +/- nan
#  F1 mean nan% +/- nan
#  AUPRC mean nan% +/- nan
#  AUROC mean nan% +/- nan
# Finished cell Line 3 HepG2
#
# 2023-02-14 11:25:51.598808
# Start cell Line 4 HT1080
# Number of RCI values loaded 936
# Num RCI: 936
# Load sequence...
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/_methods.py:265: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/_methods.py:223: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean, casting='unsafe',
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Cross validation...
# 2023-02-14 11:26:04.710505
# splitting
# Fold 1
# Discriminator is GMM
# Means [[ 0.92470668]
#  [-1.01057157]]
# Variances [0.88818885 1.98139541]
# Priors [0.37557475 0.62442525]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [1]
# rci= -0.5 label= [1]
# rci= 0.0 label= [1]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [0]
# 2023-02-14 11:26:10.340381
# Fold 2
# Discriminator is GMM
# Means [[ 0.94165078]
#  [-1.00821109]]
# Variances [0.88871252 1.97720333]
# Priors [0.37587088 0.62412912]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [1]
# rci= -0.5 label= [1]
# rci= 0.0 label= [1]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [0]
# 2023-02-14 11:26:17.359364
# Fold 3
# Discriminator is GMM
# Means [[-1.0376163 ]
#  [ 0.98243082]]
# Variances [1.89621649 0.84870621]
# Priors [0.6244428 0.3755572]
# rci= -5.0 label= [0]
# rci= -4.5 label= [0]
# rci= -4.0 label= [0]
# rci= -3.5 label= [0]
# rci= -3.0 label= [0]
# rci= -2.5 label= [0]
# rci= -2.0 label= [0]
# rci= -1.5 label= [0]
# rci= -1.0 label= [0]
# rci= -0.5 label= [0]
# rci= 0.0 label= [0]
# rci= 0.5 label= [1]
# rci= 1.0 label= [1]
# rci= 1.5 label= [1]
# rci= 2.0 label= [1]
# rci= 2.5 label= [1]
# rci= 3.0 label= [1]
# rci= 3.5 label= [1]
# rci= 4.0 label= [1]
# rci= 4.5 label= [1]
# 2023-02-14 11:26:25.624724
# Fold 4
# Discriminator is GMM
# Means [[-1.02632517]
#  [ 0.95509904]]
# Variances [1.92585631 0.87260194]
# Priors [0.6278025 0.3721975]
# rci= -5.0 label= [0]
# rci= -4.5 label= [0]
# rci= -4.0 label= [0]
# rci= -3.5 label= [0]
# rci= -3.0 label= [0]
# rci= -2.5 label= [0]
# rci= -2.0 label= [0]
# rci= -1.5 label= [0]
# rci= -1.0 label= [0]
# rci= -0.5 label= [0]
# rci= 0.0 label= [0]
# rci= 0.5 label= [1]
# rci= 1.0 label= [1]
# rci= 1.5 label= [1]
# rci= 2.0 label= [1]
# rci= 2.5 label= [1]
# rci= 3.0 label= [1]
# rci= 3.5 label= [1]
# rci= 4.0 label= [1]
# rci= 4.5 label= [1]
# 2023-02-14 11:26:33.245196
# Fold 5
# Discriminator is GMM
# Means [[ 0.95728706]
#  [-1.01915069]]
# Variances [0.85289443 1.93853796]
# Priors [0.3723154 0.6276846]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [1]
# rci= -0.5 label= [1]
# rci= 0.0 label= [1]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [0]
# 2023-02-14 11:26:41.804501
# Fold 6
# Discriminator is GMM
# Means [[-1.02492134]
#  [ 0.96903531]]
# Variances [1.95934933 0.86925618]
# Priors [0.62722892 0.37277108]
# rci= -5.0 label= [0]
# rci= -4.5 label= [0]
# rci= -4.0 label= [0]
# rci= -3.5 label= [0]
# rci= -3.0 label= [0]
# rci= -2.5 label= [0]
# rci= -2.0 label= [0]
# rci= -1.5 label= [0]
# rci= -1.0 label= [0]
# rci= -0.5 label= [0]
# rci= 0.0 label= [0]
# rci= 0.5 label= [1]
# rci= 1.0 label= [1]
# rci= 1.5 label= [1]
# rci= 2.0 label= [1]
# rci= 2.5 label= [1]
# rci= 3.0 label= [1]
# rci= 3.5 label= [1]
# rci= 4.0 label= [1]
# rci= 4.5 label= [1]
# 2023-02-14 11:26:49.674007
# Fold 7
# Discriminator is GMM
# Means [[ 0.95354343]
#  [-1.02295262]]
# Variances [0.86054544 1.93362301]
# Priors [0.37152843 0.62847157]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [1]
# rci= -0.5 label= [1]
# rci= 0.0 label= [1]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [0]
# 2023-02-14 11:26:58.397819
# Fold 8
# Discriminator is GMM
# Means [[-1.02804833]
#  [ 0.96175339]]
# Variances [1.9658337  0.83925367]
# Priors [0.62409177 0.37590823]
# rci= -5.0 label= [0]
# rci= -4.5 label= [0]
# rci= -4.0 label= [0]
# rci= -3.5 label= [0]
# rci= -3.0 label= [0]
# rci= -2.5 label= [0]
# rci= -2.0 label= [0]
# rci= -1.5 label= [0]
# rci= -1.0 label= [0]
# rci= -0.5 label= [0]
# rci= 0.0 label= [0]
# rci= 0.5 label= [1]
# rci= 1.0 label= [1]
# rci= 1.5 label= [1]
# rci= 2.0 label= [1]
# rci= 2.5 label= [1]
# rci= 3.0 label= [1]
# rci= 3.5 label= [1]
# rci= 4.0 label= [1]
# rci= 4.5 label= [1]
# 2023-02-14 11:27:06.241049
# Fold 9
# Discriminator is GMM
# Means [[ 0.94457501]
#  [-1.03282932]]
# Variances [0.8678581  1.98723895]
# Priors [0.37724745 0.62275255]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [1]
# rci= -0.5 label= [1]
# rci= 0.0 label= [1]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [0]
# 2023-02-14 11:27:13.618883
# Fold 10
# Discriminator is GMM
# Means [[-1.03042648]
#  [ 0.96457306]]
# Variances [1.94560191 0.85432349]
# Priors [0.62671445 0.37328555]
# rci= -5.0 label= [0]
# rci= -4.5 label= [0]
# rci= -4.0 label= [0]
# rci= -3.5 label= [0]
# rci= -3.0 label= [0]
# rci= -2.5 label= [0]
# rci= -2.0 label= [0]
# rci= -1.5 label= [0]
# rci= -1.0 label= [0]
# rci= -0.5 label= [0]
# rci= 0.0 label= [0]
# rci= 0.5 label= [1]
# rci= 1.0 label= [1]
# rci= 1.5 label= [1]
# rci= 2.0 label= [1]
# rci= 2.5 label= [1]
# rci= 3.0 label= [1]
# rci= 3.5 label= [1]
# rci= 4.0 label= [1]
# rci= 4.5 label= [1]
# 2023-02-14 11:27:23.282376
#
# Completed cross validation 10 folds 3 epochs
#  accuracy mean nan% +/- nan
#  precision mean nan% +/- nan
#  recall mean nan% +/- nan
#  F1 mean nan% +/- nan
#  AUPRC mean nan% +/- nan
#  AUROC mean nan% +/- nan
# Finished cell Line 4 HT1080
#
# 2023-02-14 11:27:24.655373
# Start cell Line 5 HUVEC
# Number of RCI values loaded 1488
# Num RCI: 1488
# Load sequence...
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/_methods.py:265: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/_methods.py:223: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean, casting='unsafe',
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Cross validation...
# 2023-02-14 11:27:45.563456
# splitting
# Fold 1
# Discriminator is GMM
# Means [[-0.00258608]
#  [-2.01488856]]
# Variances [1.7495863  2.12845584]
# Priors [0.52428465 0.47571535]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [0]
# rci= -0.5 label= [0]
# rci= 0.0 label= [0]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [0]
# 2023-02-14 11:27:53.445965
# Fold 2
# Discriminator is GMM
# Means [[-2.01805051]
#  [-0.00808216]]
# Variances [2.12858246 1.76120407]
# Priors [0.47540116 0.52459884]
# rci= -5.0 label= [0]
# rci= -4.5 label= [0]
# rci= -4.0 label= [0]
# rci= -3.5 label= [0]
# rci= -3.0 label= [0]
# rci= -2.5 label= [0]
# rci= -2.0 label= [0]
# rci= -1.5 label= [0]
# rci= -1.0 label= [1]
# rci= -0.5 label= [1]
# rci= 0.0 label= [1]
# rci= 0.5 label= [1]
# rci= 1.0 label= [1]
# rci= 1.5 label= [1]
# rci= 2.0 label= [1]
# rci= 2.5 label= [1]
# rci= 3.0 label= [1]
# rci= 3.5 label= [1]
# rci= 4.0 label= [1]
# rci= 4.5 label= [1]
# 2023-02-14 11:28:02.745041
# Fold 3
# Discriminator is GMM
# Means [[-2.00681174]
#  [-0.0216709 ]]
# Variances [2.12050072 1.75575581]
# Priors [0.47236093 0.52763907]
# rci= -5.0 label= [0]
# rci= -4.5 label= [0]
# rci= -4.0 label= [0]
# rci= -3.5 label= [0]
# rci= -3.0 label= [0]
# rci= -2.5 label= [0]
# rci= -2.0 label= [0]
# rci= -1.5 label= [0]
# rci= -1.0 label= [1]
# rci= -0.5 label= [1]
# rci= 0.0 label= [1]
# rci= 0.5 label= [1]
# rci= 1.0 label= [1]
# rci= 1.5 label= [1]
# rci= 2.0 label= [1]
# rci= 2.5 label= [1]
# rci= 3.0 label= [1]
# rci= 3.5 label= [1]
# rci= 4.0 label= [1]
# rci= 4.5 label= [1]
# 2023-02-14 11:28:10.984534
# Fold 4
# Discriminator is GMM
# Means [[-2.01237094]
#  [-0.01629527]]
# Variances [2.14594735 1.72794652]
# Priors [0.46734509 0.53265491]
# rci= -5.0 label= [0]
# rci= -4.5 label= [0]
# rci= -4.0 label= [0]
# rci= -3.5 label= [0]
# rci= -3.0 label= [0]
# rci= -2.5 label= [0]
# rci= -2.0 label= [0]
# rci= -1.5 label= [0]
# rci= -1.0 label= [1]
# rci= -0.5 label= [1]
# rci= 0.0 label= [1]
# rci= 0.5 label= [1]
# rci= 1.0 label= [1]
# rci= 1.5 label= [1]
# rci= 2.0 label= [1]
# rci= 2.5 label= [1]
# rci= 3.0 label= [1]
# rci= 3.5 label= [1]
# rci= 4.0 label= [1]
# rci= 4.5 label= [1]
# 2023-02-14 11:28:20.287591
# Fold 5
# Discriminator is GMM
# Means [[-0.00739639]
#  [-2.02027079]]
# Variances [1.75359505 2.10049886]
# Priors [0.52287652 0.47712348]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [0]
# rci= -0.5 label= [0]
# rci= 0.0 label= [0]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [0]
# 2023-02-14 11:28:28.695517
# Fold 6
# Discriminator is GMM
# Means [[-0.01931424]
#  [-2.02661881]]
# Variances [1.71982197 2.15184808]
# Priors [0.52965989 0.47034011]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [0]
# rci= -0.5 label= [0]
# rci= 0.0 label= [0]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [0]
# 2023-02-14 11:28:39.573046
# Fold 7
# Discriminator is GMM
# Means [[-2.00645053e+00]
#  [ 7.34503588e-04]]
# Variances [2.04364991 1.71786298]
# Priors [0.47033563 0.52966437]
# rci= -5.0 label= [0]
# rci= -4.5 label= [0]
# rci= -4.0 label= [0]
# rci= -3.5 label= [0]
# rci= -3.0 label= [0]
# rci= -2.5 label= [0]
# rci= -2.0 label= [0]
# rci= -1.5 label= [0]
# rci= -1.0 label= [1]
# rci= -0.5 label= [1]
# rci= 0.0 label= [1]
# rci= 0.5 label= [1]
# rci= 1.0 label= [1]
# rci= 1.5 label= [1]
# rci= 2.0 label= [1]
# rci= 2.5 label= [1]
# rci= 3.0 label= [1]
# rci= 3.5 label= [1]
# rci= 4.0 label= [1]
# rci= 4.5 label= [1]
# 2023-02-14 11:28:50.170175
# Fold 8
# Discriminator is GMM
# Means [[-2.00960068e+00]
#  [ 9.00751362e-05]]
# Variances [2.08319096 1.73726102]
# Priors [0.47351452 0.52648548]
# rci= -5.0 label= [0]
# rci= -4.5 label= [0]
# rci= -4.0 label= [0]
# rci= -3.5 label= [0]
# rci= -3.0 label= [0]
# rci= -2.5 label= [0]
# rci= -2.0 label= [0]
# rci= -1.5 label= [0]
# rci= -1.0 label= [1]
# rci= -0.5 label= [1]
# rci= 0.0 label= [1]
# rci= 0.5 label= [1]
# rci= 1.0 label= [1]
# rci= 1.5 label= [1]
# rci= 2.0 label= [1]
# rci= 2.5 label= [1]
# rci= 3.0 label= [1]
# rci= 3.5 label= [1]
# rci= 4.0 label= [1]
# rci= 4.5 label= [1]
# 2023-02-14 11:28:59.501589
# Fold 9
# Discriminator is GMM
# Means [[ 0.00404697]
#  [-2.02607619]]
# Variances [1.72262935 2.07483847]
# Priors [0.52502558 0.47497442]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [0]
# rci= -0.5 label= [0]
# rci= 0.0 label= [0]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [0]
# 2023-02-14 11:29:08.397162
# Fold 10
# Discriminator is GMM
# Means [[-2.02932329]
#  [-0.00299865]]
# Variances [2.09813806 1.72423738]
# Priors [0.47115341 0.52884659]
# rci= -5.0 label= [0]
# rci= -4.5 label= [0]
# rci= -4.0 label= [0]
# rci= -3.5 label= [0]
# rci= -3.0 label= [0]
# rci= -2.5 label= [0]
# rci= -2.0 label= [0]
# rci= -1.5 label= [0]
# rci= -1.0 label= [1]
# rci= -0.5 label= [1]
# rci= 0.0 label= [1]
# rci= 0.5 label= [1]
# rci= 1.0 label= [1]
# rci= 1.5 label= [1]
# rci= 2.0 label= [1]
# rci= 2.5 label= [1]
# rci= 3.0 label= [1]
# rci= 3.5 label= [1]
# rci= 4.0 label= [1]
# rci= 4.5 label= [1]
# 2023-02-14 11:29:19.227836
#
# Completed cross validation 10 folds 3 epochs
#  accuracy mean nan% +/- nan
#  precision mean nan% +/- nan
#  recall mean nan% +/- nan
#  F1 mean nan% +/- nan
#  AUPRC mean nan% +/- nan
#  AUROC mean nan% +/- nan
# Finished cell Line 5 HUVEC
#
# 2023-02-14 11:29:20.743604
# Start cell Line 6 MCF.7
# Number of RCI values loaded 2156
# Num RCI: 2156
# Load sequence...
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/_methods.py:265: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/_methods.py:223: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean, casting='unsafe',
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Cross validation...
# 2023-02-14 11:29:45.434813
# splitting
# Fold 1
# Discriminator is GMM
# Means [[-2.13183903]
#  [-0.06532588]]
# Variances [3.44737818 2.12804729]
# Priors [0.51761078 0.48238922]
# rci= -5.0 label= [0]
# rci= -4.5 label= [0]
# rci= -4.0 label= [0]
# rci= -3.5 label= [0]
# rci= -3.0 label= [0]
# rci= -2.5 label= [0]
# rci= -2.0 label= [0]
# rci= -1.5 label= [0]
# rci= -1.0 label= [1]
# rci= -0.5 label= [1]
# rci= 0.0 label= [1]
# rci= 0.5 label= [1]
# rci= 1.0 label= [1]
# rci= 1.5 label= [1]
# rci= 2.0 label= [1]
# rci= 2.5 label= [1]
# rci= 3.0 label= [1]
# rci= 3.5 label= [1]
# rci= 4.0 label= [1]
# rci= 4.5 label= [1]
# 2023-02-14 11:29:58.410046
# Fold 2
# Discriminator is GMM
# Means [[-0.09646221]
#  [-2.12381251]]
# Variances [2.11197667 3.48737721]
# Priors [0.49024428 0.50975572]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [0]
# rci= -0.5 label= [0]
# rci= 0.0 label= [0]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [0]
# 2023-02-14 11:30:11.205202
# Fold 3
# Discriminator is GMM
# Means [[-0.05838407]
#  [-2.13247202]]
# Variances [2.0881166  3.37897661]
# Priors [0.48868525 0.51131475]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [0]
# rci= -0.5 label= [0]
# rci= 0.0 label= [0]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [0]
# 2023-02-14 11:30:22.633116
# Fold 4
# Discriminator is GMM
# Means [[-2.1310797 ]
#  [-0.06405098]]
# Variances [3.39153752 2.10842833]
# Priors [0.51240402 0.48759598]
# rci= -5.0 label= [0]
# rci= -4.5 label= [0]
# rci= -4.0 label= [0]
# rci= -3.5 label= [0]
# rci= -3.0 label= [0]
# rci= -2.5 label= [0]
# rci= -2.0 label= [0]
# rci= -1.5 label= [0]
# rci= -1.0 label= [1]
# rci= -0.5 label= [1]
# rci= 0.0 label= [1]
# rci= 0.5 label= [1]
# rci= 1.0 label= [1]
# rci= 1.5 label= [1]
# rci= 2.0 label= [1]
# rci= 2.5 label= [1]
# rci= 3.0 label= [1]
# rci= 3.5 label= [1]
# rci= 4.0 label= [1]
# rci= 4.5 label= [1]
# 2023-02-14 11:30:37.141844
# Fold 5
# Discriminator is GMM
# Means [[-2.12703986]
#  [-0.09207305]]
# Variances [3.468672   2.12312551]
# Priors [0.50433378 0.49566622]
# rci= -5.0 label= [0]
# rci= -4.5 label= [0]
# rci= -4.0 label= [0]
# rci= -3.5 label= [0]
# rci= -3.0 label= [0]
# rci= -2.5 label= [0]
# rci= -2.0 label= [0]
# rci= -1.5 label= [0]
# rci= -1.0 label= [1]
# rci= -0.5 label= [1]
# rci= 0.0 label= [1]
# rci= 0.5 label= [1]
# rci= 1.0 label= [1]
# rci= 1.5 label= [1]
# rci= 2.0 label= [1]
# rci= 2.5 label= [1]
# rci= 3.0 label= [1]
# rci= 3.5 label= [1]
# rci= 4.0 label= [1]
# rci= 4.5 label= [1]
# 2023-02-14 11:30:48.762845
# Fold 6
# Discriminator is GMM
# Means [[-2.12787257]
#  [-0.06433799]]
# Variances [3.40159355 2.09905411]
# Priors [0.50979659 0.49020341]
# rci= -5.0 label= [0]
# rci= -4.5 label= [0]
# rci= -4.0 label= [0]
# rci= -3.5 label= [0]
# rci= -3.0 label= [0]
# rci= -2.5 label= [0]
# rci= -2.0 label= [0]
# rci= -1.5 label= [0]
# rci= -1.0 label= [1]
# rci= -0.5 label= [1]
# rci= 0.0 label= [1]
# rci= 0.5 label= [1]
# rci= 1.0 label= [1]
# rci= 1.5 label= [1]
# rci= 2.0 label= [1]
# rci= 2.5 label= [1]
# rci= 3.0 label= [1]
# rci= 3.5 label= [1]
# rci= 4.0 label= [1]
# rci= 4.5 label= [1]
# 2023-02-14 11:30:59.366588
# Fold 7
# Discriminator is GMM
# Means [[-0.06540538]
#  [-2.14064344]]
# Variances [2.10825555 3.46475136]
# Priors [0.48839775 0.51160225]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [0]
# rci= -0.5 label= [0]
# rci= 0.0 label= [0]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [0]
# 2023-02-14 11:31:13.187174
# Fold 8
# Discriminator is GMM
# Means [[-0.07998428]
#  [-2.12207335]]
# Variances [2.14193094 3.49438856]
# Priors [0.48858551 0.51141449]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [0]
# rci= -0.5 label= [0]
# rci= 0.0 label= [0]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [0]
# 2023-02-14 11:31:24.528947
# Fold 9
# Discriminator is GMM
# Means [[-2.12441485]
#  [-0.05355742]]
# Variances [3.37862845 2.09463023]
# Priors [0.51543009 0.48456991]
# rci= -5.0 label= [0]
# rci= -4.5 label= [0]
# rci= -4.0 label= [0]
# rci= -3.5 label= [0]
# rci= -3.0 label= [0]
# rci= -2.5 label= [0]
# rci= -2.0 label= [0]
# rci= -1.5 label= [0]
# rci= -1.0 label= [1]
# rci= -0.5 label= [1]
# rci= 0.0 label= [1]
# rci= 0.5 label= [1]
# rci= 1.0 label= [1]
# rci= 1.5 label= [1]
# rci= 2.0 label= [1]
# rci= 2.5 label= [1]
# rci= 3.0 label= [1]
# ...
# rci= -4.5 label= [0]
# rci= -4.0 label= [0]
# rci= -3.5 label= [0]
# rci= -3.0 label= [0]
# rci= -2.5 label= [0]
# rci= -2.0 label= [0]
# rci= -1.5 label= [0]
# rci= -1.0 label= [0]
# rci= -0.5 label= [1]
# rci= 0.0 label= [1]
# rci= 0.5 label= [1]
# rci= 1.0 label= [1]
# rci= 1.5 label= [1]
# rci= 2.0 label= [1]
# rci= 2.5 label= [1]
# rci= 3.0 label= [1]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [0]
# 2023-02-14 11:40:59.197453
#
# Completed cross validation 10 folds 3 epochs
#  accuracy mean nan% +/- nan
#  precision mean nan% +/- nan
#  recall mean nan% +/- nan
#  F1 mean nan% +/- nan
#  AUPRC mean nan% +/- nan
#  AUROC mean nan% +/- nan
# Finished cell Line 12 GM12878
#
# 2023-02-14 11:41:00.619578
# Start cell Line 13 K562
# Number of RCI values loaded 958
# Num RCI: 958
# Load sequence...
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/_methods.py:265: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/_methods.py:223: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean, casting='unsafe',
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Cross validation...
# 2023-02-14 11:41:11.173740
# splitting
# Fold 1
# Discriminator is GMM
# Means [[ 0.02270007]
#  [-1.870572  ]]
# Variances [0.96117527 1.43805354]
# Priors [0.6334342 0.3665658]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [0]
# rci= -0.5 label= [0]
# rci= 0.0 label= [0]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [0]
# 2023-02-14 11:41:15.548754
# Fold 2
# Discriminator is GMM
# Means [[ 0.01892517]
#  [-1.87346617]]
# Variances [0.95098259 1.39925796]
# Priors [0.63395017 0.36604983]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [0]
# rci= -0.5 label= [0]
# rci= 0.0 label= [0]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [0]
# 2023-02-14 11:41:21.301395
# Fold 3
# Discriminator is GMM
# Means [[-1.86983584e+00]
#  [-7.91788785e-04]]
# Variances [1.47017722 0.95934147]
# Priors [0.36258751 0.63741249]
# rci= -5.0 label= [0]
# rci= -4.5 label= [0]
# rci= -4.0 label= [0]
# rci= -3.5 label= [0]
# rci= -3.0 label= [0]
# rci= -2.5 label= [0]
# rci= -2.0 label= [0]
# rci= -1.5 label= [0]
# rci= -1.0 label= [1]
# rci= -0.5 label= [1]
# rci= 0.0 label= [1]
# rci= 0.5 label= [1]
# rci= 1.0 label= [1]
# rci= 1.5 label= [1]
# rci= 2.0 label= [1]
# rci= 2.5 label= [1]
# rci= 3.0 label= [1]
# rci= 3.5 label= [1]
# rci= 4.0 label= [1]
# rci= 4.5 label= [1]
# 2023-02-14 11:41:26.980720
# Fold 4
# Discriminator is GMM
# Means [[ 0.0180862 ]
#  [-1.88846942]]
# Variances [0.95004075 1.42097589]
# Priors [0.62985983 0.37014017]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [0]
# rci= -0.5 label= [0]
# rci= 0.0 label= [0]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [0]
# 2023-02-14 11:41:32.665676
# Fold 5
# Discriminator is GMM
# Means [[-1.86965524]
#  [ 0.0208972 ]]
# Variances [1.42054283 0.95594656]
# Priors [0.36528321 0.63471679]
# rci= -5.0 label= [0]
# rci= -4.5 label= [0]
# rci= -4.0 label= [0]
# rci= -3.5 label= [0]
# rci= -3.0 label= [0]
# rci= -2.5 label= [0]
# rci= -2.0 label= [0]
# rci= -1.5 label= [0]
# rci= -1.0 label= [1]
# rci= -0.5 label= [1]
# rci= 0.0 label= [1]
# rci= 0.5 label= [1]
# rci= 1.0 label= [1]
# rci= 1.5 label= [1]
# rci= 2.0 label= [1]
# rci= 2.5 label= [1]
# rci= 3.0 label= [1]
# rci= 3.5 label= [1]
# rci= 4.0 label= [1]
# rci= 4.5 label= [1]
# 2023-02-14 11:41:38.350154
# Fold 6
# Discriminator is GMM
# Means [[-1.86808175]
#  [ 0.01533203]]
# Variances [1.41459089 0.95569803]
# Priors [0.36674664 0.63325336]
# rci= -5.0 label= [0]
# rci= -4.5 label= [0]
# rci= -4.0 label= [0]
# rci= -3.5 label= [0]
# rci= -3.0 label= [0]
# rci= -2.5 label= [0]
# rci= -2.0 label= [0]
# rci= -1.5 label= [0]
# rci= -1.0 label= [1]
# rci= -0.5 label= [1]
# rci= 0.0 label= [1]
# rci= 0.5 label= [1]
# rci= 1.0 label= [1]
# rci= 1.5 label= [1]
# rci= 2.0 label= [1]
# rci= 2.5 label= [1]
# rci= 3.0 label= [1]
# rci= 3.5 label= [1]
# rci= 4.0 label= [1]
# rci= 4.5 label= [1]
# 2023-02-14 11:41:44.026161
# Fold 7
# Discriminator is GMM
# Means [[ 0.01799052]
#  [-1.88851024]]
# Variances [0.93525143 1.36958272]
# Priors [0.63519173 0.36480827]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [0]
# rci= -0.5 label= [0]
# rci= 0.0 label= [0]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [0]
# 2023-02-14 11:41:49.722203
# Fold 8
# Discriminator is GMM
# Means [[ 0.01064354]
#  [-1.87536986]]
# Variances [0.95542845 1.42223811]
# Priors [0.63336259 0.36663741]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [0]
# rci= -0.5 label= [0]
# rci= 0.0 label= [0]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [0]
# 2023-02-14 11:41:55.412512
# Fold 9
# Discriminator is GMM
# Means [[-1.88534827]
#  [ 0.01017887]]
# Variances [1.40242573 0.95011502]
# Priors [0.36243801 0.63756199]
# rci= -5.0 label= [0]
# rci= -4.5 label= [0]
# rci= -4.0 label= [0]
# rci= -3.5 label= [0]
# rci= -3.0 label= [0]
# rci= -2.5 label= [0]
# rci= -2.0 label= [0]
# rci= -1.5 label= [0]
# rci= -1.0 label= [1]
# rci= -0.5 label= [1]
# rci= 0.0 label= [1]
# rci= 0.5 label= [1]
# rci= 1.0 label= [1]
# rci= 1.5 label= [1]
# rci= 2.0 label= [1]
# rci= 2.5 label= [1]
# rci= 3.0 label= [1]
# rci= 3.5 label= [1]
# rci= 4.0 label= [1]
# rci= 4.5 label= [1]
# 2023-02-14 11:42:01.100162
# Fold 10
# Discriminator is GMM
# Means [[-1.89986221]
#  [ 0.01443363]]
# Variances [1.43709206 0.95986923]
# Priors [0.36575872 0.63424128]
# rci= -5.0 label= [0]
# rci= -4.5 label= [0]
# rci= -4.0 label= [0]
# rci= -3.5 label= [0]
# rci= -3.0 label= [0]
# rci= -2.5 label= [0]
# rci= -2.0 label= [0]
# rci= -1.5 label= [0]
# rci= -1.0 label= [1]
# rci= -0.5 label= [1]
# rci= 0.0 label= [1]
# rci= 0.5 label= [1]
# rci= 1.0 label= [1]
# rci= 1.5 label= [1]
# rci= 2.0 label= [1]
# rci= 2.5 label= [1]
# rci= 3.0 label= [1]
# rci= 3.5 label= [1]
# rci= 4.0 label= [1]
# rci= 4.5 label= [1]
# 2023-02-14 11:42:06.824836
#
# Completed cross validation 10 folds 3 epochs
#  accuracy mean nan% +/- nan
#  precision mean nan% +/- nan
#  recall mean nan% +/- nan
#  F1 mean nan% +/- nan
#  AUPRC mean nan% +/- nan
#  AUROC mean nan% +/- nan
# Finished cell Line 13 K562
#
# 2023-02-14 11:42:08.153169
# Start cell Line 14 IMR.90
# Number of RCI values loaded 390
# Num RCI: 390
# Load sequence...
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/_methods.py:265: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/_methods.py:223: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean, casting='unsafe',
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Cross validation...
# 2023-02-14 11:42:12.392101
# splitting
# Fold 1
# Discriminator is GMM
# Means [[ 0.05361554]
#  [-2.73075759]]
# Variances [1.98448726 4.91467572]
# Priors [0.6955601 0.3044399]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [0]
# rci= -1.5 label= [0]
# rci= -1.0 label= [0]
# rci= -0.5 label= [0]
# rci= 0.0 label= [0]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [0]
# 2023-02-14 11:42:14.711051
# Fold 2
# Discriminator is GMM
# Means [[ 0.02748846]
#  [-2.72807335]]
# Variances [2.02027366 4.99479983]
# Priors [0.70228865 0.29771135]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [0]
# rci= -1.5 label= [0]
# rci= -1.0 label= [0]
# rci= -0.5 label= [0]
# rci= 0.0 label= [0]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [0]
# 2023-02-14 11:42:18.201224
# Fold 3
# Discriminator is GMM
# Means [[ 0.04816166]
#  [-2.6796779 ]]
# Variances [1.99053068 4.86717388]
# Priors [0.68874922 0.31125078]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [0]
# rci= -1.5 label= [0]
# rci= -1.0 label= [0]
# rci= -0.5 label= [0]
# rci= 0.0 label= [0]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [0]
# 2023-02-14 11:42:21.663180
# Fold 4
# Discriminator is GMM
# Means [[-2.66902789]
#  [ 0.03178569]]
# Variances [4.91285697 2.01529773]
# Priors [0.31016253 0.68983747]
# rci= -5.0 label= [0]
# rci= -4.5 label= [0]
# rci= -4.0 label= [0]
# rci= -3.5 label= [0]
# rci= -3.0 label= [0]
# rci= -2.5 label= [0]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [1]
# rci= -0.5 label= [1]
# rci= 0.0 label= [1]
# rci= 0.5 label= [1]
# rci= 1.0 label= [1]
# rci= 1.5 label= [1]
# rci= 2.0 label= [1]
# rci= 2.5 label= [1]
# rci= 3.0 label= [1]
# rci= 3.5 label= [1]
# rci= 4.0 label= [1]
# rci= 4.5 label= [1]
# 2023-02-14 11:42:25.149087
# Fold 5
# Discriminator is GMM
# Means [[ 0.04317101]
#  [-2.65122845]]
# Variances [2.01396856 4.91573303]
# Priors [0.69216346 0.30783654]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [0]
# rci= -1.5 label= [0]
# rci= -1.0 label= [0]
# rci= -0.5 label= [0]
# rci= 0.0 label= [0]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [0]
# 2023-02-14 11:42:28.662109
# Fold 6
# Discriminator is GMM
# Means [[-2.73244826]
#  [ 0.05847411]]
# Variances [4.82595779 2.00615047]
# Priors [0.3084507 0.6915493]
# rci= -5.0 label= [0]
# rci= -4.5 label= [0]
# rci= -4.0 label= [0]
# rci= -3.5 label= [0]
# rci= -3.0 label= [0]
# rci= -2.5 label= [0]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [1]
# rci= -0.5 label= [1]
# rci= 0.0 label= [1]
# rci= 0.5 label= [1]
# rci= 1.0 label= [1]
# rci= 1.5 label= [1]
# rci= 2.0 label= [1]
# rci= 2.5 label= [1]
# rci= 3.0 label= [1]
# rci= 3.5 label= [1]
# rci= 4.0 label= [1]
# rci= 4.5 label= [1]
# 2023-02-14 11:42:32.178681
# Fold 7
# Discriminator is GMM
# Means [[-2.68928023]
#  [ 0.04326213]]
# Variances [4.88904452 2.0111666 ]
# Priors [0.311154 0.688846]
# rci= -5.0 label= [0]
# rci= -4.5 label= [0]
# rci= -4.0 label= [0]
# rci= -3.5 label= [0]
# rci= -3.0 label= [0]
# rci= -2.5 label= [0]
# rci= -2.0 label= [1]
# rci= -1.5 label= [1]
# rci= -1.0 label= [1]
# rci= -0.5 label= [1]
# rci= 0.0 label= [1]
# rci= 0.5 label= [1]
# rci= 1.0 label= [1]
# rci= 1.5 label= [1]
# rci= 2.0 label= [1]
# rci= 2.5 label= [1]
# rci= 3.0 label= [1]
# rci= 3.5 label= [1]
# rci= 4.0 label= [1]
# rci= 4.5 label= [1]
# 2023-02-14 11:42:36.166582
# Fold 8
# Discriminator is GMM
# Means [[ 0.05037432]
#  [-2.71267818]]
# Variances [2.01996968 4.86973245]
# Priors [0.69190299 0.30809701]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [0]
# rci= -1.5 label= [0]
# rci= -1.0 label= [0]
# rci= -0.5 label= [0]
# rci= 0.0 label= [0]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [0]
# 2023-02-14 11:42:40.234790
# Fold 9
# Discriminator is GMM
# Means [[ 0.03031371]
#  [-2.70651607]]
# Variances [2.02679564 4.89641578]
# Priors [0.68480322 0.31519678]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [0]
# rci= -1.5 label= [0]
# rci= -1.0 label= [0]
# rci= -0.5 label= [0]
# rci= 0.0 label= [0]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [0]
# 2023-02-14 11:42:43.840027
# Fold 10
# Discriminator is GMM
# Means [[ 0.0219855 ]
#  [-2.74612379]]
# Variances [2.01361685 4.98495262]
# Priors [0.70172166 0.29827834]
# rci= -5.0 label= [1]
# rci= -4.5 label= [1]
# rci= -4.0 label= [1]
# rci= -3.5 label= [1]
# rci= -3.0 label= [1]
# rci= -2.5 label= [1]
# rci= -2.0 label= [0]
# rci= -1.5 label= [0]
# rci= -1.0 label= [0]
# rci= -0.5 label= [0]
# rci= 0.0 label= [0]
# rci= 0.5 label= [0]
# rci= 1.0 label= [0]
# rci= 1.5 label= [0]
# rci= 2.0 label= [0]
# rci= 2.5 label= [0]
# rci= 3.0 label= [0]
# rci= 3.5 label= [0]
# rci= 4.0 label= [0]
# rci= 4.5 label= [0]
# 2023-02-14 11:42:47.563036
#
# Completed cross validation 10 folds 3 epochs
#  accuracy mean nan% +/- nan
#  precision mean nan% +/- nan
#  recall mean nan% +/- nan
#  F1 mean nan% +/- nan
#  AUPRC mean nan% +/- nan
#  AUROC mean nan% +/- nan
# Finished cell Line 14 IMR.90
#
# 2023-02-14 11:42:48.765229
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/_methods.py:265: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/_methods.py:223: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean, casting='unsafe',
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/_methods.py:257: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
