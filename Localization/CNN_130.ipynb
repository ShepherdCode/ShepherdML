# %% [markdown]
# # CNN + GlobalAvgPool
# Based on CNN 107 which got 75% acc on H1 coding len 2000-4000.
# Model: Embed mask, Conv1D, GlobalAvgPool.
#
# H1 coding len 3000-4000.
# Cross validation 5 folds 50 epochs, accuracy mean , F1 mean
#
# Same as CNN 118 but switch cell line 1 to 5.
# Same as CNN 129 but switch 5 epochs to 50.
# Some models do well -- 72% acc and still climbing.

# %%
from datetime import datetime
print(datetime.now())
from platform import python_version
print('Python',python_version())
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt 
import sklearn   # pip install --upgrade scikit-learn
print('sklearn',sklearn.__version__)
# Out:
# 2022-12-29 16:18:55.294195
# Python 3.8.16
# sklearn 1.0.2

# %% [markdown]
# We prevously used sklearn.model_selection.ShuffleSplit
# Now we avoid it due to this note in the
# [documentation](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.ShuffleSplit.html):
# Note: contrary to other cross-validation strategies, random splits do not guarantee that all folds will be different, although this is still very likely for sizeable datasets.

# %%
import tensorflow as tf
dt='float32'
tf.keras.backend.set_floatx('float32')
tf.random.set_seed(42) 

from tensorflow import keras
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

from keras.models import Sequential
from keras.layers import Masking
from keras.layers import Embedding
from keras.layers import Conv1D
from keras.layers import MaxPooling1D
from keras.layers import GlobalAveragePooling1D
from keras.layers import GlobalMaxPooling1D
from keras.layers import Flatten
from keras.layers import Attention
from keras.layers import Bidirectional
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Dropout
from keras.losses import BinaryCrossentropy

K=4
RCI_THRESHOLD=0.0
CFILTERS=64
FILTERSIZE=8
RCELLS=16
DCELLS=8
EPOCHS=50
FOLDS=5      
EMBED_DIMEN = 4 # arbitrary hyperparameter
BREAK = False   # break after first fold
MINLEN=3000
MAXLEN=4000

# %%
try:
    from google.colab import drive
    IN_COLAB = True
    print('Running on CoLab')
    PATH='/content/drive/'
    drive.mount(PATH)
    DATA_DIR=PATH+'My Drive/data/Localization/TrainTest/'  # must end in "/"
except:
    IN_COLAB = False
    DATA_DIR = 'D:/Adjeroh/Localization/TrainTest/'   # Windows
    DATA_DIR = '/Users/jasonmiller/WVU/Localization/TrainTest/'    # Mac
print(DATA_DIR)
# Out:
# Running on CoLab
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /content/drive/My Drive/data/Localization/TrainTest/

# %%
GENES_FILE =    'CNRCI_coding_train_genes.csv'
RCI_FILE =      'CNRCI_coding_train_RCI.gc42.csv'
SEQUENCE_FILE = 'CNRCI_coding_train_transcripts.gc42.csv'
COUNTS_FILE=    'CNRCI_coding_train_counts.K4.gc42.csv'

# %%
def get_ordered_list():
    ordered_list = \
    ['A549',\
      'H1.hESC',\
      'HeLa.S3',\
      'HepG2',\
      'HT1080',\
      'HUVEC',\
      'MCF.7',\
      'NCI.H460',\
      'NHEK',\
      'SK.MEL.5',\
      'SK.N.DZ',\
      'SK.N.SH',\
      'GM12878',\
      'K562',\
      'IMR.90']
    return ordered_list
CELL_LINE_NUMBER=5
all_cell_lines = get_ordered_list()
cell_line_name = all_cell_lines[CELL_LINE_NUMBER]
print('Cell line for today:',CELL_LINE_NUMBER,'=',cell_line_name)
# Out:
# Cell line for today: 5 = HUVEC

# %% [markdown]
# ## Data Load

# %%
class DataLoader():
    def __init__(self):
        self.cache=dict() 
        self.vals = {'A':0, 'C':1, 'G':2, 'T':3}
        
    def load_gene_rci_values(self,filepath,cell_line):
        '''
        Load from RCI csv file.
        Return dict with keys=gene:str and values=RCI:float.
        '''
        gene_to_rci = {}
        with open (filepath,'r') as handle:
            header = None
            for row in handle:
                if header is None:
                    header = row # skip file's header line
                else:
                    line = row.strip()
                    fields = line.split(',')
                    gene_id = fields[0]
                    rci_val = fields[cell_line+1]
                    if rci_val != "nan":
                        # Convert string nan to float(nan)
                        gene_to_rci[gene_id] = float(rci_val)
        return gene_to_rci
    
    def seq_to_kmer_values(self,rna,K):
        # The cache may represent more than one K. Probably not a problem.
        N_indicator = 0 # indicator value
        vec=[] # seq converted to list of K-mers 
        length = len(rna)
        for i in range(length-K+1):
            kmer = rna[i:i+K]
            if 'N' in kmer:
                value = N_indicator
            elif kmer in self.cache.keys():
                value = self.cache[kmer]
            else:
                value = 0
                for j in range(K):
                    value *= 4   
                    nextnuc = kmer[j] 
                    nucval = self.vals[nextnuc]
                    value += nucval
                value += 1   # NNN => 0, AAA => 1
                self.cache[kmer] = value
            vec.append(value)
        return vec

    def rci_to_label(self,rci):
        CYTO_LABEL = 1
        NUCLEAR_LABEL = 0
        # cnrci = log (cyto-to-nuclear ratio)
        # rci > 0 implies cytoplasmic
        if rci > RCI_THRESHOLD:
            return CYTO_LABEL
        return NUCLEAR_LABEL

    def load_sequence(self,filepath):
        labels=[]
        allids=[]
        allseq=[]
        NREPEAT = str('N'*MAXLEN)
        with open (filepath,'r') as handle:
            header = None
            for row in handle:
                if header is None:
                    header = row
                else:
                    line    = row.strip()
                    fields  = line.split(',')
                    tran_id = fields[0]  # with version number
                    gene_id = fields[1]        # without version number
                    seq_len = int(fields[3])
                    seq_txt = fields[4]
                    if seq_len>=MINLEN and seq_len<=MAXLEN and gene_id in gene_to_rci.keys():
                        allids.append( (gene_id,tran_id) )
                        rci_val = gene_to_rci[gene_id]
                        rci_label = self.rci_to_label(rci_val)
                        labels.append(rci_label)
                        if seq_len<MAXLEN:
                            seq_txt = seq_txt + NREPEAT
                            seq_txt = seq_txt[:MAXLEN]
                        hot_vec = self.seq_to_kmer_values(seq_txt,K)
                        allseq.append(hot_vec)
        return labels,allids,allseq
    
loader = DataLoader()
# test it
print(loader.seq_to_kmer_values('AAAA',3))
print(loader.seq_to_kmer_values('CATT',3))
print(loader.seq_to_kmer_values('TTGA',3))
print(loader.seq_to_kmer_values('TTTN',3))
# test it
print(loader.rci_to_label(-0.9))
print(loader.rci_to_label(1.1))
# Out:
# [1, 1]
# [20, 16]
# [63, 57]
# [64, 0]
# 0
# 1

# %%
print(datetime.now())
print("Load RCI values...")
loader = DataLoader()
filepath = DATA_DIR+RCI_FILE
gene_to_rci = loader.load_gene_rci_values(filepath,CELL_LINE_NUMBER)
print('Num RCI:', len(gene_to_rci.keys()))
print('Example RCI:', list(gene_to_rci.items())[:3])
print("Load genes...")
all_genes = list(gene_to_rci.keys())
print(datetime.now())
print('Load sequence...')
filepath = DATA_DIR+SEQUENCE_FILE
labels,allids,allseq = loader.load_sequence(filepath)
print(datetime.now())
print('Num IDs:',len(allids))
print('Example IDs:',[allids[x] for x in [10, 20, 30, 40]] )
print('Count',np.count_nonzero(labels),'ones out of',len(labels),'labels.')
print('Example labels:',[labels[x] for x in [10, 20, 30, 40]] )
print('Num counts:',len(allseq))
print('Example sequence:',allseq[3])
loader = None  # drop K-mer cache to save RAM
# Out:
# 2022-12-29 16:18:58.775072
# Load RCI values...
# Num RCI: 10257
# Example RCI: [('ENSG00000000003', 1.28494), ('ENSG00000000419', 1.27546), ('ENSG00000000457', -0.853779)]
# Load genes...
# 2022-12-29 16:18:58.801480
# Load sequence...
# 2022-12-29 16:19:08.395251
# Num IDs: 5722
# Example IDs: [('ENSG00000008130', 'ENST00000341991.7'), ('ENSG00000069424', 'ENST00000669250.1'), ('ENSG00000171680', 'ENST00000673471.2'), ('ENSG00000173614', 'ENST00000377205.6')]
# Count 2044 ones out of 5722 labels.
# Example labels: [0, 0, 0, 1]
# Num counts: 5722
# Example sequence: [150, 88, 96, 126, 247, 219, 107, 172, 174, 182, 214, 85, 82, 69, 19, 76, 48, 192, 254, 246, 213, 83, 74, 38, 151, 90, 102, 151, 90, 104, 158, 120, 222, 118, 216, 94, 117, 211, 76, 47, 186, 230, 150, 87, 91, 108, 175, 187, 234, 166, 150, 85, 83, 75, 41, 163, 139, 43, 170, 166, 152, 95, 123, 235, 169, 163, 138, 38, 150, 87, 89, 97, 131, 10, 38, 151, 92, 110, 182, 214, 86, 87, 89, 99, 140, 46, 183, 218, 104, 158, 118, 216, 93, 115, 203, 44, 174, 181, 210, 72, 31, 123, 234, 167, 154, 103, 153, 100, 143, 58, 231, 155, 107, 170, 166, 151, 92, 110, 182, 216, 94, 120, 222, 119, 219, 106, 168, 159, 121, 228, 143, 59, 235, 172, 176, 191, 251, 233, 161, 131, 10, 38, 150, 85, 83, 74, 39, 153, 99, 139, 42, 168, 157, 115, 201, 35, 139, 42, 166, 149, 83, 76, 46, 182, 214, 85, 81, 65, 3, 12, 48, 192, 254, 246, 213, 83, 75, 42, 165, 148, 78, 53, 211, 75, 43, 170, 168, 159, 122, 229, 147, 74, 38, 150, 85, 83, 75, 41, 163, 138, 38, 152, 94, 117, 209, 67, 11, 42, 167, 155, 106, 166, 150, 87, 91, 106, 167, 155, 107, 170, 167, 153, 98, 136, 31, 123, 233, 162, 135, 27, 106, 166, 151, 91, 105, 162, 133, 19, 75, 44, 174, 182, 214, 87, 89, 99, 138, 37, 147, 74, 38, 150, 86, 87, 90, 102, 150, 85, 81, 66, 5, 20, 79, 59, 233, 162, 134, 22, 85, 83, 73, 34, 134, 22, 86, 86, 85, 83, 75, 42, 167, 155, 107, 170, 167, 156
41, 164, 143, 59, 233, 163, 139, 43, 171, 169, 161, 131, 11, 43, 169, 161, 129, 2, 6, 23, 91, 107, 170, 166, 151, 92, 111, 188, 239, 187, 236, 175, 187, 233, 162, 133, 20, 78, 54, 215, 92, 111, 187, 234, 168, 159, 123, 235, 169, 164, 143, 60, 239, 187, 233, 163, 137, 34, 133, 19, 75, 42, 166, 151, 91, 105, 163, 140, 47, 188, 239, 187, 234, 166, 149, 83, 74, 39, 156, 111, 185 ...

# %% [markdown]
# ## Model

# %%
def build_model():
    ALPHABET=4**K+1  # NUMBER OF DISTINCT KMERS POSSIBLE, add one if N gets mask value
    ADJUST_LENGTH = MAXLEN-K+1  # fixed length sequences
    rnn = Sequential()
    embed_layer = Embedding(ALPHABET,EMBED_DIMEN,input_length=ADJUST_LENGTH,mask_zero=True)   
    cnn1_layer = Conv1D(CFILTERS, FILTERSIZE)
    #rnn1_layer = Bidirectional( LSTM(RCELLS, return_sequences=False) )
    #pool_layer = MaxPooling1D(pool_size=3)
    pool_layer = GlobalAveragePooling1D()
    #pool_layer = GlobalMaxPooling1D()
    flat_layer = Flatten()
    den1_layer = Dense(DCELLS)
    drop_layer = Dropout(0.5)
    output_layer = Dense(1,activation='sigmoid',dtype=dt)

    rnn.add(embed_layer)
    rnn.add(cnn1_layer)
    rnn.add(pool_layer)
    #rnn.add(flat_layer)
    #rnn.add(den1_layer)
    #rnn.add(drop_layer)
    rnn.add(output_layer)

    bc=BinaryCrossentropy(from_logits=False)
    print("COMPILE")
    rnn.compile(loss=bc, optimizer="Adam",metrics=["accuracy"])
    return rnn

# %%
print(datetime.now())
model=build_model()
print(model.summary())  # Print this only once
# Out:
# 2022-12-29 16:19:08.428644
# COMPILE
# Model: "sequential_106"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_106 (Embedding)   (None, 3997, 4)           1028
#
#  conv1d_106 (Conv1D)         (None, 3990, 64)          2112
#
#  global_average_pooling1d_93  (None, 64)               0
#   (GlobalAveragePooling1D)
#
#  dense_211 (Dense)           (None, 1)                 65
#
# =================================================================
# Total params: 3,205
# Trainable params: 3,205
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## Training

# %%
class CrossValidator():
    def __init__(self,epochs,folds,quick_test=False,pred_threshold=0.5):
        self.epochs = epochs
        self.folds = folds
        self.quick_test = quick_test
        self.threshold = pred_threshold # e.g. score>0.5 => class 1
    
    def get_gene_subset(self,all_genes,sub_index):
        sub_genes = set()
        for index in sub_index:
            one_gene = all_genes[index]
            sub_genes.add(one_gene)
        return sub_genes
    
    def get_X_y(self,gene_set,allids,allX,allY):
        cnt = len(allids)
        subsetX=[]
        subsetY=[]
        if cnt != len(allX) or cnt!= len(allY):
            raise Exception('Lengths differ')
        for i in range(cnt):
            gene_id,tran_id = allids[i]
            if gene_id in gene_set:
                oneX = allX[i]
                oneY = allY[i]
                subsetX.append(oneX)
                subsetY.append(oneY)
        subsetX = np.array(subsetX)
        subsetY = np.array(subsetY).reshape((-1,1))
        return subsetX,subsetY
    
    def do_cross_validation(self):
        cv_accuracy=[]
        cv_precision=[]
        cv_recall=[]
        cv_f1=[]
        fold=0
        print(datetime.now())
        print('splitting')
        # KFold shuffles once before making the partitions
        splitter = KFold(n_splits=self.folds,shuffle=True,random_state=42)
        for train_index,valid_index in splitter.split(all_genes):
            fold += 1
            print('Fold',fold)
            train_genes = self.get_gene_subset(all_genes,train_index)
            valid_genes = self.get_gene_subset(all_genes,valid_index)
            X_train,y_train = self.get_X_y(train_genes,allids,allseq,labels)
            X_valid,y_valid = self.get_X_y(valid_genes,allids,allseq,labels)

            print('Training example')
            print(X_train[0])

            print('Train sizes',X_train.shape,y_train.shape)
            print('Valid sizes',X_valid.shape,y_valid.shape)
            print('Train set ones/size',
                  np.count_nonzero(y_train),'/',len(y_train))
            print('Valid set ones/size',
                  np.count_nonzero(y_valid),'/',len(y_valid))

            print("BUILD MODEL")
            model=build_model()

            print("FIT")
            print(datetime.now())
            history=model.fit(X_train, y_train, # batch_size=10, default=32 works nicely
                    epochs=self.epochs, verbose=1,  # verbose=1 for ascii art, verbose=0 for none
                    validation_data=(X_valid,y_valid) )

            pd.DataFrame(history.history).plot(figsize=(8,5))
            plt.grid(True)
            plt.gca().set_ylim(0,1)
            plt.show()

            print("Compute valiation accuracy")
            print(datetime.now())
            yhat_pred=model.predict(X_valid, verbose=0) 
            print('Range of scores:',np.min(yhat_pred),'to',np.max(yhat_pred))
            yhat_classes=np.where(yhat_pred > self.threshold, 1, 0)
            print('Predicted zeros and ones',np.count_nonzero(yhat_classes==0),np.count_nonzero(yhat_classes==1))
            # accuracy: (tp + tn) / (p + n)
            accuracy = accuracy_score(y_valid, yhat_classes)*100.
            # precision tp / (tp + fp)
            precision = precision_score(y_valid, yhat_classes)*100.
            # recall: tp / (tp + fn)
            recall = recall_score(y_valid, yhat_classes)*100.
            # f1: 2 tp / (2 tp + fp + fn)
            f1 = f1_score(y_valid, yhat_classes)*100.
            print('Accuracy: %.2f%% Precision: %.2f%% Recall: %.2f%% F1: %.2f%%' % (accuracy,precision,recall,f1)) 
            print(datetime.now())
            cv_accuracy.append(accuracy)
            cv_precision.append(precision)
            cv_recall.append(recall)
            cv_f1.append(f1)
            if self.quick_test:   
                print('Break -- this was for code testing only')
                break
        print()
        return cv_accuracy, cv_precision, cv_recall, cv_f1

# %%
print(datetime.now())
cvdo = CrossValidator(EPOCHS,FOLDS,BREAK)
cv_accuracy, cv_precision, cv_recall, cv_f1 = cvdo.do_cross_validation()   
print("Cross validation %d folds %d epochs" % (FOLDS,EPOCHS)) 
print(" accuracy mean %.2f%% +/- %.2f" % (np.mean(cv_accuracy), np.std(cv_accuracy)))
print(" precision mean %.2f%% +/- %.2f" % (np.mean(cv_precision), np.std(cv_precision)))
print(" recall mean %.2f%% +/- %.2f" % (np.mean(cv_recall), np.std(cv_recall)))
print(" F1 mean %.2f%% +/- %.2f" % (np.mean(cv_f1), np.std(cv_f1)))
print(datetime.now())
# Out:
# 2022-12-29 16:19:08.560178
# 2022-12-29 16:19:08.560335
# splitting
# Fold 1
# Training example
# [158 117 210 ...   0   0   0]
# Train sizes (4618, 3997) (4618, 1)
# Valid sizes (1104, 3997) (1104, 1)
# Train set ones/size 1660 / 4618
# Valid set ones/size 384 / 1104
# BUILD MODEL
# COMPILE
# FIT
# 2022-12-29 16:19:10.072089
# Epoch 1/50
# 145/145 [==============================] - 2s 9ms/step - loss: 0.6553 - accuracy: 0.6390 - val_loss: 0.6375 - val_accuracy: 0.6522
# Epoch 2/50
# 145/145 [==============================] - 1s 7ms/step - loss: 0.6376 - accuracy: 0.6423 - val_loss: 0.6251 - val_accuracy: 0.6549
# Epoch 3/50
# 145/145 [==============================] - 1s 7ms/step - loss: 0.6237 - accuracy: 0.6585 - val_loss: 0.6122 - val_accuracy: 0.6703
# Epoch 4/50
# 145/145 [==============================] - 1s 7ms/step - loss: 0.6081 - accuracy: 0.6752 - val_loss: 0.6129 - val_accuracy: 0.6757
# Epoch 5/50
# 145/145 [==============================] - 1s 7ms/step - loss: 0.6018 - accuracy: 0.6871 - val_loss: 0.6000 - val_accuracy: 0.6784
# Epoch 6/50
# 145/145 [==============================] - 1s 7ms/step - loss: 0.5961 - accuracy: 0.6903 - val_loss: 0.5990 - val_accuracy: 0.6902
# Epoch 7/50
# 145/145 [==============================] - 1s 7ms/step - loss: 0.5925 - accuracy: 0.6897 - val_loss: 0.5980 - val_accuracy: 0.6757
# Epoch 8/50
# 145/145 [==============================] - 1s 7ms/step - loss: 0.5881 - accuracy: 0.6960 - val_loss: 0.6031 - val_accuracy: 0.6784
# Epoch 9/50
# 145/145 [==============================] - 1s 7ms/step - loss: 0.5873 - accuracy: 0.6968 - val_loss: 0.6033 - val_accuracy: 0.6803
# Epoch 10/50
# 145/145 [==============================] - 1s 7ms/step - loss: 0.5793 - accuracy: 0.6992 - val_loss: 0.5966 - val_accuracy: 0.6812
# Epoch 11/50
# 145/145 [==============================] - 1s 7ms/step - loss: 0.5773 - accuracy: 0.6977 - val_loss: 0.5935 - val_accuracy: 0.6993
# Epoch 12/50
# 145/145 [==============================] - 1s 7ms/step - loss: 0.5742 - accuracy: 0.7053 - val_loss: 0.6009 - val_accuracy: 0.6821
# Epoch 13/50
# 145/145 [==============================] - 1s 7ms/step - loss: 0.5689 - accuracy: 0.7068 - val_loss: 0.5931 - val_accuracy: 0.7111
# Epoch 14/50
# 145/145 [==============================] - 1s 7ms/step - loss: 0.5651 - accuracy: 0.7074 - val_loss: 0.6353 - val_accuracy: 0.6594
# Epoch 15/50
# 145/145 [==============================] - 1s 7ms/step - loss: 0.5659 - accuracy: 0.7027 - val_loss: 0.6011 - val_accuracy: 0.6857
# Epoch 16/50
# 145/145 [==============================] - 1s 7ms/step - loss: 0.5653 - accuracy: 0.7079 - val_loss: 0.5891 - val_accuracy: 0.7129
# Epoch 17/50
# 145/145 [==============================] - 1s 7ms/step - loss: 0.5599 - accuracy: 0.7124 - val_loss: 0.5911 - val_accuracy: 0.7192
# Epoch 18/50
# 145/145 [==============================] - 1s 7ms/step - loss: 0.5547 - accuracy: 0.7144 - val_loss: 0.5924 - val_accuracy: 0.7201
# Epoch 19/50
# 145/145 [==============================] - 1s 7ms/step - loss: 0.5516 - accuracy: 0.7204 - val_loss: 0.5923 - val_accuracy: 0.7129
# Epoch 20/50
# 145/145 [==============================] - 1s 7ms/step - loss: 0.5538 - accuracy: 0.7122 - val_loss: 0.6010 - val_accuracy: 0.7083
# Epoch 21/50
# 145/145 [==============================] - 1s 7ms/step - loss: 0.5487 - accuracy: 0.7213 - val_loss: 0.5910 - val_accuracy: 0.7246
# Epoch 22/50
# 145/145 [==============================] - 1s 7ms/step - loss: 0.5463 - accuracy: 0.7198 - val_loss: 0.5987 - val_accuracy: 0.7056
# Epoch 23/50
# 145/145 [==============================] - 1s 7ms/step - loss: 0.5463 - accuracy: 0.7196 - val_loss: 0.5961 - val_accuracy: 0.7310
# Epoch 24/50
# 145/145 [==============================] - 1s 7ms/step - loss: 0.5461 - accuracy: 0.7207 - val_loss: 0.6042 - val_accuracy: 0.6938
# Epoch 25/50
# 145/145 [==============================] - 1s 7ms/step - loss: 0.5418 - accuracy: 0.7237 - val_loss: 0.6028 - val_accuracy: 0.7165
# Epoch 26/50
# 145/145 [==============================] - 1s 7ms/step - loss: 0.5424 - accuracy: 0.7265 - val_loss: 0.6018 - val_accuracy: 0.6993
# Epoch 27/50
# 145/145 [==============================] - 1s 7ms/step - loss: 0.5409 - accuracy: 0.7254 - val_loss: 0.5947 - val_accuracy: 0.7165
# Epoch 28/50
# 145/145 [==============================] - 1s 7ms/step - loss: 0.5388 - accuracy: 0.7337 - val_loss: 0.6275 - val_accuracy: 0.6612
# Epoch 29/50
# 145/145 [==============================] - 1s 7ms/step - loss: 0.5390 - accuracy: 0.7282 - val_loss: 0.5987 - val_accuracy: 0.7274
# Epoch 30/50
# 145/145 [==============================] - 1s 7ms/step - loss: 0.5419 - accuracy: 0.7235 - val_loss: 0.6010 - val_accuracy: 0.7038
# Epoch 31/50
# 145/145 [==============================] - 1s 9ms/step - loss: 0.5390 - accuracy: 0.7250 - val_loss: 0.6564 - val_accuracy: 0.6123
# Epoch 32/50
# 145/145 [==============================] - 1s 10ms/step - loss: 0.5398 - accuracy: 0.7259 - val_loss: 0.6090 - val_accuracy: 0.6975
# Epoch 33/50
# 145/145 [==============================] - 1s 8ms/step - loss: 0.5362 - accuracy: 0.7269 - val_loss: 0.6227 - val_accuracy: 0.6739
# Epoch 34/50
# 145/145 [==============================] - 1s 7ms/step - loss: 0.5358 - accuracy: 0.7302 - val_loss: 0.6422 - val_accuracy: 0.6476
# Epoch 35/50
# 145/145 [==============================] - 1s 7ms/step - loss: 0.5376 - accuracy: 0.7267 - val_loss: 0.6004 - val_accuracy: 0.7120
# Epoch 36/50
# 145/145 [==============================] - 1s 7ms/step - loss: 0.5354 - accuracy: 0.7291 - val_loss: 0.6018 - val_accuracy: 0.7174
# Epoch 37/50
# 145/145 [==============================] - 1s 8ms/step - loss: 0.5375 - accuracy: 0.7304 - val_loss: 0.5990 - val_accuracy: 0.7210
# Epoch 38/50
# 145/145 [==============================] - 1s 7ms/step - loss: 0.5358 - accuracy: 0.7302 - val_loss: 0.6025 - val_accuracy: 0.7228
# Epoch 39/50
# 145/145 [==============================] - 1s 7ms/step - loss: 0.5388 - accuracy: 0.7291 - val_loss: 0.5987 - val_accuracy: 0.7201
# Epoch 40/50
# 145/145 [==============================] - 1s 7ms/step - loss: 0.5344 - accuracy: 0.7298 - val_loss: 0.6034 - val_accuracy: 0.7219
# Epoch 41/50
# 145/145 [==============================] - 1s 7ms/step - loss: 0.5386 - accuracy: 0.7298 - val_loss: 0.6149 - val_accuracy: 0.6857
# Epoch 42/50
# 145/145 [==============================] - 1s 7ms/step - loss: 0.5354 - accuracy: 0.7289 - val_loss: 0.6179 - val_accuracy: 0.7120
# Epoch 43/50
# 145/145 [==============================] - 1s 7ms/step - loss: 0.5336 - accuracy: 0.7319 - val_loss: 0.6131 - val_accuracy: 0.6875
# Epoch 44/50
# 145/145 [==============================] - 1s 7ms/step - loss: 0.5347 - accuracy: 0.7298 - val_loss: 0.6180 - val_accuracy: 0.6757
# Epoch 45/50
# 145/145 [==============================] - 1s 7ms/step - loss: 0.5359 - accuracy: 0.7324 - val_loss: 0.6059 - val_accuracy: 0.7092
# Epoch 46/50
# 145/145 [==============================] - 1s 7ms/step - loss: 0.5338 - accuracy: 0.7324 - val_loss: 0.6169 - val_accuracy: 0.6775
# Epoch 47/50
# 145/145 [==============================] - 1s 7ms/step - loss: 0.5341 - accuracy: 0.7328 - val_loss: 0.6234 - val_accuracy: 0.6694
# Epoch 48/50
# 145/145 [==============================] - 1s 7ms/step - loss: 0.5374 - accuracy: 0.7324 - val_loss: 0.6093 - val_accuracy: 0.7192
# Epoch 49/50
# 145/145 [==============================] - 1s 7ms/step - loss: 0.5339 - accuracy: 0.7350 - val_loss: 0.6032 - val_accuracy: 0.7201
# Epoch 50/50
# 145/145 [==============================] - 1s 7ms/step - loss: 0.5309 - accuracy: 0.7365 - val_loss: 0.6475 - val_accuracy: 0.6540
# Compute valiation accuracy
# 2022-12-29 16:20:32.816021
# Range of scores: 0.011530704 to 0.9790133
# Predicted zeros and ones 628 476
# Accuracy: 65.40% Precision: 50.21% Recall: 62.24% F1: 55.58%
# 2022-12-29 16:20:33.026709
# Fold 2
# Training example
# [ 62 246 215 ...   0   0   0]
# Train sizes (4593, 3997) (4593, 1)
# Valid sizes (1129, 3997) (1129, 1)
# Train set ones/size 1665 / 4593
# Valid set ones/size 379 / 1129
# BUILD MODEL
# COMPILE
# FIT
# 2022-12-29 16:20:34.381275
# Epoch 1/50
# 144/144 [==============================] - 2s 9ms/step - loss: 0.6588 - accuracy: 0.6373 - val_loss: 0.6385 - val_accuracy: 0.6643
# Epoch 2/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0
50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.5267 - accuracy: 0.7318 - val_loss: 0.6603 - val_accuracy: 0.6315
# Compute valiation accuracy
# 2022-12-29 16:21:57.089608
# Range of scores: 0.017415922 to 0.9515078
# Predicted zeros and ones 786 343
# Accuracy: 63.15% Precision: 44.61% Recall: 40.37% F1: 42.38%
# 2022-12-29 16:21:57.340776
# Fold 3
# Training example
# [ 62 246 215 ...   0   0   0]
# Train sizes (4521, 3997) (4521, 1)
# Valid sizes (1201, 3997) (1201, 1)
# Train set ones/size 1565 / 4521
# Valid set ones/size 479 / 1201
# BUILD MODEL
# COMPILE
# FIT
# 2022-12-29 16:21:58.707689
# Epoch 1/50
# 142/142 [==============================] - 2s 9ms/step - loss: 0.6455 - accuracy: 0.6538 - val_loss: 0.6680 - val_accuracy: 0.6012
# Epoch 2/50
# 142/142 [==============================] - 1s 8ms/step - loss: 0.6296 - accuracy: 0.6536 - val_loss: 0.6490 - val_accuracy: 0.6178
# Epoch 3/50
# 142/142 [==============================] - 1s 7ms/step - loss: 0.6145 - accuracy: 0.6709 - val_loss: 0.6465 - val_accuracy: 0.6436
# Epoch 4/50
# 142/142 [==============================] - 1s 7ms/step - loss: 0.5984 - accuracy: 0.6844 - val_loss: 0.6628 - val_accuracy: 0.6545
# Epoch 5/50
# 142/142 [==============================] - 1s 7ms/step - loss: 0.5886 - accuracy: 0.6934 - val_loss: 0.6402 - val_accuracy: 0.6636
# Epoch 6/50
# 142/142 [==============================] - 1s 7ms/step - loss: 0.5824 - accuracy: 0.6972 - val_loss: 0.6628 - val_accuracy: 0.6545
# Epoch 7/50
# 142/142 [==============================] - 1s 7ms/step - loss: 0.5803 - accuracy: 0.6994 - val_loss: 0.6526 - val_accuracy: 0.6570
# Epoch 8/50
# 142/142 [==============================] - 1s 7ms/step - loss: 0.5766 - accuracy: 0.7016 - val_loss: 0.6355 - val_accuracy: 0.6619
# Epoch 9/50
# 142/142 [==============================] - 1s 7ms/step - loss: 0.5719 - accuracy: 0.7067 - val_loss: 0.6383 - val_accuracy: 0.6728
# Epoch 10/50
# 142/142 [==============================] - 1s 8ms/step - loss: 0.5682 - accuracy: 0.7005 - val_loss: 0.6340 - val_accuracy: 0.6728
# Epoch 11/50
# 142/142 [==============================] - 1s 7ms/step - loss: 0.5640 - accuracy: 0.7098 - val_loss: 0.6551 - val_accuracy: 0.6628
# Epoch 12/50
# 142/142 [==============================] - 1s 7ms/step - loss: 0.5606 - accuracy: 0.7125 - val_loss: 0.6468 - val_accuracy: 0.6686
# Epoch 13/50
# 142/142 [==============================] - 1s 7ms/step - loss: 0.5588 - accuracy: 0.7160 - val_loss: 0.6404 - val_accuracy: 0.6728
# Epoch 14/50
# 142/142 [==============================] - 1s 7ms/step - loss: 0.5556 - accuracy: 0.7136 - val_loss: 0.6320 - val_accuracy: 0.6728
# Epoch 15/50
# 142/142 [==============================] - 1s 7ms/step - loss: 0.5513 - accuracy: 0.7140 - val_loss: 0.6332 - val_accuracy: 0.6636
# Epoch 16/50
# 142/142 [==============================] - 1s 8ms/step - loss: 0.5466 - accuracy: 0.7204 - val_loss: 0.6335 - val_accuracy: 0.6595
# Epoch 17/50
# 142/142 [==============================] - 1s 7ms/step - loss: 0.5456 - accuracy: 0.7217 - val_loss: 0.6372 - val_accuracy: 0.6570
# Epoch 18/50
# 142/142 [==============================] - 1s 7ms/step - loss: 0.5455 - accuracy: 0.7164 - val_loss: 0.6607 - val_accuracy: 0.6703
# Epoch 19/50
# 142/142 [==============================] - 1s 7ms/step - loss: 0.5392 - accuracy: 0.7273 - val_loss: 0.6394 - val_accuracy: 0.6520
# Epoch 20/50
# 142/142 [==============================] - 1s 7ms/step - loss: 0.5376 - accuracy: 0.7315 - val_loss: 0.6434 - val_accuracy: 0.6644
# Epoch 21/50
# 142/142 [==============================] - 1s 7ms/step - loss: 0.5321 - accuracy: 0.7337 - val_loss: 0.6551 - val_accuracy: 0.6345
# Epoch 22/50
# 142/142 [==============================] - 1s 7ms/step - loss: 0.5359 - accuracy: 0.7308 - val_loss: 0.6910 - val_accuracy: 0.6686
# Epoch 23/50
# 142/142 [==============================] - 1s 7ms/step - loss: 0.5337 - accuracy: 0.7284 - val_loss: 0.6523 - val_accuracy: 0.6586
# Epoch 24/50
# 142/142 [==============================] - 1s 7ms/step - loss: 0.5308 - accuracy: 0.7355 - val_loss: 0.6539 - val_accuracy: 0.6678
# Epoch 25/50
# 142/142 [==============================] - 1s 7ms/step - loss: 0.
# 142/142 [==============================] - 1s 7ms/step - loss: 0.5173 - accuracy: 0.7485 - val_loss: 0.6662 - val_accuracy: 0.6353
# Compute valiation accuracy
# 2022-12-29 16:22:52.589895
# Range of scores: 0.016917173 to 0.97000533
# Predicted zeros and ones 760 441
# Accuracy: 63.53% Precision: 54.65% Recall: 50.31% F1: 52.39%
# 2022-12-29 16:22:52.863377
# Fold 4
# Training example
# [ 62 246 215 ...   0   0   0]
# Train sizes (4603, 3997) (4603, 1)
# Valid sizes (1119, 3997) (1119, 1)
# Train set ones/size 1678 / 4603
# Valid set ones/size 366 / 1119
# BUILD MODEL
# COMPILE
# FIT
# 2022-12-29 16:22:54.276346
# Epoch 1/50
# 144/144 [==============================] - 2s 9ms/step - loss: 0.6599 - accuracy: 0.6333 - val_loss: 0.6245 - val_accuracy: 0.6729
# Epoch 2/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.6435 - accuracy: 0.6365 - val_loss: 0.6069 - val_accuracy: 0.6729
# Epoch 3/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.6320 - accuracy: 0.6494 - val_loss: 0.5941 - val_accuracy: 0.6899
# Epoch 4/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.6216 - accuracy: 0.6613 - val_loss: 0.5732 - val_accuracy: 0.7113
# Epoch 5/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.6101 - accuracy: 0.6796 - val_loss: 0.5758 - val_accuracy: 0.7006
# Epoch 6/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.6080 - accuracy: 0.6726 - val_loss: 0.5585 - val_accuracy: 0.7265
# Epoch 7/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.6034 - accuracy: 0.6789 - val_loss: 0.5627 - val_accuracy: 0.7176
# Epoch 8/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.6007 - accuracy: 0.6861 - val_loss: 0.5573 - val_accuracy: 0.7274
# Epoch 9/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.5977 - accuracy: 0.6854 - val_loss: 0.5689 - val_accuracy: 0.6997
# Epoch 10/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.5938 - accuracy: 0.6906 - val_loss: 0.5464 - val_accuracy: 0.7310
# Epoch 11/50
# 144/144 [==============================] - 1s 8ms/step - loss: 0.5886 - accuracy: 0.6922 - val_loss: 0.5540 - val_accuracy: 0.7158
# Epoch 12/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.5866 - accuracy: 0.6943 - val_loss: 0.5506 - val_accuracy: 0.7230
# Epoch 13/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.5813 - accuracy: 0.7011 - val_loss: 0.5434 - val_accuracy: 0.7248
# Epoch 14/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.5774 - accuracy: 0.6995 - val_loss: 0.5415 - val_accuracy: 0.7310
# Epoch 15/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.5747 - accuracy: 0.7019 - val_loss: 0.5639 - val_accuracy: 0.7033
# Epoch 16/50
# 144/144 [==============================] - 1s 8ms/step - loss: 0.5698 - accuracy: 0.7074 - val_loss: 0.5398 - val_accuracy: 0.7328
# Epoch 17/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.5712 - accuracy: 0.7039 - val_loss: 0.5652 - val_accuracy: 0.7069
# Epoch 18/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.5655 - accuracy: 0.7161 - val_loss: 0.5829 - val_accuracy: 0.6863
# Epoch 19/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.5637 - accuracy: 0.7145 - val_loss: 0.5371 - val_accuracy: 0.7373
# Epoch 20/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.5613 - accuracy: 0.7124 - val_loss: 0.5517 - val_accuracy: 0.7248
# Epoch 21/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.5590 - accuracy: 0.7165 - val_loss: 0.5508 - val_accuracy: 0.7265
# Epoch 22/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.5606 - accuracy: 0.7148 - val_loss: 0.5365 - val_accuracy: 0.7328
# Epoch 23/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.5560 - accuracy: 0.7176 - val_loss: 0.5379 - val_accuracy: 0.7248
# Epoch 24/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.5584 - accuracy: 0.7197 - val_loss: 0.5380 - val_accuracy: 0.7319
# Epoch 25/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.5520 - accuracy: 0.7202 - val_loss: 0.5455 - val_accuracy: 0.7337
# Epoch 26/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.5536 - accuracy: 0.7134 - val_loss: 0.5399 - val_accuracy: 0.7230
# Epoch 27/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.5507 - accuracy: 0.7189 - val_loss: 0.5439 - val_accuracy: 0.7328
# Epoch 28/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.5520 - accuracy: 0.7197 - val_loss: 0.5445 - val_accuracy: 0.7310
# Epoch 29/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.5506 - accuracy: 0.7200 - val_loss: 0.5405 - val_accuracy: 0.7248
# Epoch 30/50
# 144/144 [==============================] - 1s 8ms/step - loss: 0.5557 - accuracy: 0.7108 - val_loss: 0.5693 - val_accuracy: 0.7140
# Epoch 31/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.5488 - accuracy: 0.7234 - val_loss: 0.5511 - val_accuracy: 0.7283
# Epoch 32/50
# 144/144 [==============================] - 1s 8ms/step - loss: 0.5493 - accuracy: 0.7234 - val_loss: 0.5433 - val_accuracy: 0.7265
# Epoch 33/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.5501 - accuracy: 0.7202 - val_loss: 0.5574 - val_accuracy: 0.7265
# Epoch 34/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.5505 - accuracy: 0.7176 - val_loss: 0.5487 - val_accuracy: 0.7230
# Epoch 35/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.5471 - accuracy: 0.7252 - val_loss: 0.5933 - val_accuracy: 0.7096
# Epoch 36/50
# 144/144 [==============================] - 1s 8ms/step - loss: 0.5514 - accuracy: 0.7250 - val_loss: 0.5429 - val_accuracy: 0.7283
# Epoch 37/50
# 144/144 [==============================] - 1s 8ms/step - loss: 0.5442 - accuracy: 0.7245 - val_loss: 0.5467 - val_accuracy: 0.7265
# Epoch 38/50
# 144/144 [==============================] - 1s 8ms/step - loss: 0.5466 - accuracy: 0.7300 - val_loss: 0.5441 - val_accuracy: 0.7283
# Epoch 39/50
# 144/144 [==============================] - 1s 8ms/step - loss: 0.5459 - accuracy: 0.7263 - val_loss: 0.5474 - val_accuracy: 0.7256
# Epoch 40/50
# 144/144 [==============================] - 1s 8ms/step - loss: 0.5465 - accuracy: 0.7239 - val_loss: 0.5584 - val_accuracy: 0.7221
# Epoch 41/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.5474 - accuracy: 0.7260 - val_loss: 0.5530 - val_accuracy: 0.7265
# Epoch 42/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.5470 - accuracy: 0.7267 - val_loss: 0.5610 - val_accuracy: 0.7292
# Epoch 43/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.5488 - accuracy: 0.7219 - val_loss: 0.5507 - val_accuracy: 0.7212
# Epoch 44/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.5532 - accuracy: 0.7224 - val_loss: 0.5492 - val_accuracy: 0.7265
# Epoch 45/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.5425 - accuracy: 0.7302 - val_loss: 0.5517 - val_accuracy: 0.7203
# Epoch 46/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.5472 - accuracy: 0.7224 - val_loss: 0.5505 - val_accuracy: 0.7221
# Epoch 47/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.5425 - accuracy: 0.7269 - val_loss: 0.5510 - val_accuracy: 0.7230
# Epoch 48/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.5459 - accuracy: 0.7271 - val_loss: 0.5487 - val_accuracy: 0.7310
# Epoch 49/50
# 144/144 [==============================] - 1s 8ms/step - loss: 0.5424 - accuracy: 0.7245 - val_loss: 0.5482 - val_accuracy: 0.7274
# Epoch 50/50
# 144/144 [==============================] - 1s 7ms/step - loss: 0.5453 - accuracy: 0.7269 - val_loss: 0.5520 - val_accuracy: 0.7230
# Compute valiation accuracy
# 2022-12-29 16:24:17.107579
# Range of scores: 0.014872198 to 0.9107779
# Predicted zeros and ones 815 304
# Accuracy: 72.30% Precision: 59.21% Recall: 49.18% F1: 53.73%
# 2022-12-29 16:24:17.501238
# Fold 5
# Training example
# [ 62 246 215 ...   0   0   0]
# Train sizes (4553, 3997) (4553, 1)
# Valid sizes (1169, 3997) (1169, 1)
# Train set ones/size 1608 / 4553
# Valid set ones/size 436 / 1169
# BUILD MODEL
# COMPILE
# FIT
# 2022-12-29 16:24:20.137450
# Epoch 1/50
# 143/143 [==============================] - 2s 9ms/step - loss: 0.6517 - accuracy: 0.6422 - val_loss: 0.6525 - val_accuracy: 0.6270
# Epoch 2/50
# 143/143 [==============================] - 1s 7ms/step - loss: 0.6361 - accuracy: 0.6477 - val_loss: 0.6351 - val_accuracy: 0.6253
# Epoch 3/50
# 143/143 [==============================] - 1s 7ms/step - loss: 0.6207 - accuracy: 0.6655 - val_loss: 0.6191 - val_accuracy: 0.6638
# Epoch 4/50
# 143/143 [==============================] - 1s 7ms/step - loss: 0.6072 - accuracy: 0.6780 - val_loss: 0.6142 - val_accuracy: 0.6672
# Epoch 5/50
# 143/143 [==============================] - 1s 7ms/step - loss: 0.5953 - accuracy: 0.6839 - val_loss: 0.6099 - val_accuracy: 0.6886
# Epoch 6/50
# 143/143 [==============================] - 1s 7ms/step - loss: 0.5911 - accuracy: 0.6932 - val_loss: 0.6100 - val_accuracy: 0.6749
# Epoch 7/50
# 143/143 [==============================] - 1s 8ms/step - loss: 0.5849 - accuracy: 0.7017 - val_loss: 0.6083 - val_accuracy: 0.6826
# Epoch 8/50
# 143/143 [==============================] - 1s 7ms/step - loss: 0.5817 - accuracy: 0.7015 - val_loss: 0.6090 - val_accuracy: 0.6741
# Epoch 9/50
# 143/143 [==============================] - 1s 7ms/step - loss: 0.5769 - accuracy: 0.7061 - val_loss: 0.6125 - val_accuracy: 0.6664
# Epoch 10/50
# 143/143 [==============================] - 1s 8ms/step - loss: 0.5767 - accuracy: 0.7055 - val_loss: 0.6145 - val_accuracy: 0.6595
# Epoch 11/50
# 143/143 [==============================] - 1s 9ms/step - loss: 0.5695 - accuracy: 0.7092 - val_loss: 0.6104 - val_accuracy: 0.6578
# Epoch 12/50
# 143/143 [==============================] - 2s 10ms/step - loss: 0.5658 - accuracy: 0.7107 - val_loss: 0.6197 - val_accuracy: 0.6587
# Epoch 13/50
# 143/143 [==============================] - 2s 11ms/step - loss: 0.5558 - accuracy: 0.7204 - val_loss: 0.6181 - val_accuracy: 0.6570
# Epoch 14/50
# 143/143 [==============================] - 1s 9ms/step - loss: 0.5525 - accuracy: 0.7224 - val_loss: 0.6268 - val_accuracy: 0.6493
# Epoch 15/50
# 143/143 [==============================] - 1s 9ms/step - loss: 0.5494 - accuracy: 0.7296 - val_loss: 0.6296 - val_accuracy: 0.6467
# Epoch 16/50
# 143/143 [==============================] - 1s 8ms/step - loss: 0.5223 - accuracy: 0.7371 - val_loss: 0.6683 - val_accuracy: 0.6245
# Epoch 36/50
# 143/143 [==============================] - 1s 8ms/step - loss: 0.5274 - accuracy: 0.7301 - val_loss: 0.6663 - val_accuracy: 0.6339
# Epoch 37/50
# 143/143 [==============================] - 1s 7ms/step - loss: 0.5213 - accuracy: 0.7362 - val_loss: 0.6981 - val_accuracy: 0.6287
# Epoch 38/50
# 143/143 [==============================] - 1s 7ms/step - loss: 0.5227 - accuracy: 0.7307 - val_loss: 0.6620 - val_accuracy: 0.6382
# Epoch 39/50
# 143/143 [==============================] - 1s 7ms/step - loss: 0.5221 - accuracy: 0.7318 - val_loss: 0.6633 - val_accuracy: 0.6373
# Epoch 40/50
# 143/143 [==============================] - 1s 7ms/step - loss: 0.5208 - accuracy: 0.7327 - val_loss: 0.6621 - val_accuracy: 0.6382
# Epoch 41/50
# 143/143 [==============================] - 1s 7ms/step - loss: 0.5214 - accuracy: 0.7323 - val_loss: 0.6698 - val_accuracy: 0.6347
# Epoch 42/50
# 143/143 [==============================] - 1s 7ms/step - loss: 0.5201 - accuracy: 0.7408 - val_loss: 0.6847 - val_accuracy: 0.6176
# Epoch 43/50
# 143/143 [==============================] - 1s 7ms/step - loss: 0.5241 - accuracy: 0.7305 - val_loss: 0.6593 - val_accuracy: 0.6364
# Epoch 44/50
# 143/143 [==============================] - 1s 7ms/step - loss: 0.5178 - accuracy: 0.7373 - val_loss: 0.6664 - val_accuracy: 0.6373
# Epoch 45/50
# 143/143 [==============================] - 1s 7ms/step - loss: 0.5180 - accuracy: 0.7356 - val_loss: 0.6747 - val_accuracy: 0.6330
# Epoch 46/50
# 143/143 [==============================] - 1s 7ms/step - loss: 0.5229 - accuracy: 0.7296 - val_loss: 0.6705 - val_accuracy: 0.6262
# Epoch 47/50
# 143/143 [==============================] - 1s 7ms/step - loss: 0.5170 - accuracy: 0.7386 - val_loss: 0.6723 - val_accuracy: 0.6364
# Epoch 48/50
# 143/143 [==============================] - 1s 7ms/step - loss: 0.5220 - accuracy: 0.7351 - val_loss: 0.6863 - val_accuracy: 0.6168
# Epoch 49/50
# 143/143 [==============================] - 1s 8ms/step - loss: 0.5239 - accuracy: 0.7351 - val_loss: 0.6721 - val_accuracy: 0.6322
# Epoch 50/50
# 143/143 [==============================] - 1s 7ms/step - loss: 0.5176 - accuracy: 0.7353 - val_loss: 0.6712 - val_accuracy: 0.6279
# Compute valiation accuracy
# 2022-12-29 16:25:19.081867
# Range of scores: 0.008890536 to 0.9339974
# Predicted zeros and ones 886 283
# Accuracy: 62.79% Precision: 50.18% Recall: 32.57% F1: 39.50%
# 2022-12-29 16:25:19.348171
#
# Cross validation 5 folds 50 epochs
#  accuracy mean 65.43% +/- 3.55
#  precision mean 51.77% +/- 4.90
#  recall mean 46.93% +/- 10.00
#  F1 mean 48.72% +/- 6.49
# 2022-12-29 16:25:19.351206
