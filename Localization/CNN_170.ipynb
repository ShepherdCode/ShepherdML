# %% [markdown]
# # CNN + GlobalAvgPool
# Run this model on all lncRNA cell lines using some theshold. This notebook tests RCI GMM(2).
#
# * zero
# * RCI threshold set by GMM(2).
# * Antilog threshold set by GMM(2).
#
# Slight disconnect: transcripts are filtered by length, but RCI threshold is computed with the RCI from all genes.
#
# Ran on CoLab Pro. RAM 5.6/12.7 GB. GPU 1.9/15.0 GB.

# %%
from datetime import datetime
print(datetime.now())
from platform import python_version
print('Python',python_version())
import numpy as np
import pandas as pd
import pickle
import time # sleep function
from os.path import isfile
from matplotlib import pyplot as plt 
import sklearn   # pip install --upgrade scikit-learn
print('sklearn',sklearn.__version__)
# Out:
# 2023-02-05 21:24:33.177095
# Python 3.8.10
# sklearn 1.0.2

# %% [markdown]
# We prevously used sklearn.model_selection.ShuffleSplit
# Now we avoid it due to this note in the
# [documentation](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.ShuffleSplit.html):
# Note: contrary to other cross-validation strategies, random splits do not guarantee that all folds will be different, although this is still very likely for sizeable datasets.

# %%
import tensorflow as tf
dt='float32'
tf.keras.backend.set_floatx('float32')
tf.random.set_seed(42) 

from tensorflow import keras
from sklearn.mixture import GaussianMixture
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc

from keras.models import Sequential
from keras.layers import Masking
from keras.layers import Embedding
from keras.layers import Conv1D
from keras.layers import GlobalAveragePooling1D
from keras.layers import GlobalMaxPooling1D
from keras.layers import AveragePooling1D
from keras.layers import MaxPooling1D
from keras.layers import Bidirectional
from keras.layers import LSTM
from keras.layers import TimeDistributed
from keras.layers import Flatten
from keras.layers import Dense
from keras.layers import Dropout
from keras.losses import BinaryCrossentropy

K=4
CFILTERS=64
FILTERSIZE=16
RCELLS=32
DCELLS=16
EPOCHS=3
FOLDS=5      
EMBED_DIMEN = 4 # arbitrary hyperparameter
BREAK = False   # break after first fold
MINLEN=200
MAXLEN=5000   
PRETTY_PICTURES = False
RCI_THRESHOLD_MECHANISM = 'ZERO'
CACHING = False   # have not worked out how to cache multiple cell lines

# %%
try:
    from google.colab import drive
    IN_COLAB = True
    print('Running on CoLab')
    PATH='/content/drive/'
    drive.mount(PATH)
    DATA_DIR=PATH+'My Drive/data/Localization/TrainTest/'  # must end in "/"
except:
    IN_COLAB = False
    DATA_DIR = 'D:/Adjeroh/Localization/TrainTest/'   # Windows
    DATA_DIR = '/Users/jasonmiller/WVU/Localization/TrainTest/'    # Mac
print(DATA_DIR)
# Out:
# Running on CoLab
# Mounted at /content/drive/
# /content/drive/My Drive/data/Localization/TrainTest/

# %%
RCI_FILE =      'CNRCI_noncoding_train_RCI.gc42.csv'
SEQUENCE_FILE = 'CNRCI_noncoding_train_transcripts.gc42.csv'
CACHE_SEQUENCE = 'cache.seq.pickle'
CACHE_IDS = 'cache.id.pickle'
if CACHING:
    cache_seq = DATA_DIR+CACHE_SEQUENCE 
    cache_ids = DATA_DIR+CACHE_IDS 
    if isfile(cache_seq) and isfile(cache_ids):
        print('WARNING: this run will read sequence from cache.')
    else:
        print('INFO: this run will write sequence to cache.')

# %%
def get_ordered_list():
    ordered_list = \
    ['A549','H1.hESC','HeLa.S3','HepG2','HT1080',\
      'HUVEC','MCF.7','NCI.H460','NHEK','SK.MEL.5',\
      'SK.N.DZ','SK.N.SH','GM12878','K562','IMR.90']
    return ordered_list
all_cell_lines = get_ordered_list()

EXCLUSIONS = [1,7]   # use these though they are clearly different

# %% [markdown]
# ## Data Load

# %%
class DataLoader():
    def __init__(self):
        self.cache=dict() 
        self.vals = {'A':0, 'C':1, 'G':2, 'T':3}
        
    def load_gene_rci_values(self,filepath,cell_line):
        '''
        Load from RCI csv file.
        Return dict with keys=gene:str and values=RCI:float.
        '''
        gene_to_rci = {}
        overall_sum = 0
        with open (filepath,'r') as handle:
            header = None
            for row in handle:
                if header is None:
                    header = row # skip file's header line
                else:
                    line = row.strip()
                    fields = line.split(',')
                    gene_id = fields.pop(0)
                    rci_str = fields[cell_line]
                    if rci_str != "nan":
                        rci_val = float(rci_str)
                        gene_to_rci[gene_id] = rci_val
        print('Number of RCI values loaded',len(gene_to_rci.keys()))
        return gene_to_rci

    def seq_to_kmer_values(self,rna,K):
        vec=[] # seq converted to list of K-mers 
        N_indicator = 0 # indicator value
        length = len(rna)
        for i in range(length-K+1):
            kmer = rna[i:i+K]
            if 'N' in kmer:
                value = N_indicator
            elif kmer in self.cache.keys():
                value = self.cache[kmer]
            else:
                value = 0
                for j in range(K):
                    value *= 4   
                    nextnuc = kmer[j] 
                    nucval = self.vals[nextnuc]
                    value += nucval
                value += 1   # NNN => 0, AAA => 1
                self.cache[kmer] = value
            vec.append(value)
        return vec

    def load_sequence(self,filepath):
        allids=[]
        allseq=[]
        cache_seq = DATA_DIR+CACHE_SEQUENCE 
        cache_ids = DATA_DIR+CACHE_IDS 
        if CACHING and isfile(cache_seq) and isfile(cache_ids):
            # Warning: the cache may represent the wrong K.
            with open(cache_seq,'rb') as fin:
                allseq = pickle.load(fin)
            with open(cache_ids,'rb') as fin:
                allids = pickle.load(fin)
            return allids,allseq           
        NREPEAT = str('N'*MAXLEN)
        with open (filepath,'r') as handle:
            header = None
            for row in handle:
                if header is None:
                    header = row
                else:
                    line    = row.strip()
                    fields  = line.split(',')
                    tran_id = fields[0]  # with version number
                    gene_id = fields[1]        # without version number
                    seq_len = int(fields[3])
                    seq_txt = fields[4]
                    if seq_len>=MINLEN and seq_len<=MAXLEN and gene_id in gene_to_rci.keys():
                        allids.append( (gene_id,tran_id) )
                        if seq_len<MAXLEN:
                            seq_txt = seq_txt + NREPEAT
                            seq_txt = seq_txt[:MAXLEN]
                        hot_vec = self.seq_to_kmer_values(seq_txt,K)
                        allseq.append(hot_vec)
        if CACHING:
            with open(cache_seq,'wb') as fout:
                pickle.dump(allseq,fout)
            with open(cache_ids,'wb') as fout:
                pickle.dump(allids,fout)
        return allids,allseq

# %% [markdown]
# ## Model

# %%
def build_model():
    ALPHABET=4**K+1  # NUMBER OF DISTINCT KMERS POSSIBLE, add one if N gets mask value
    ADJUST_LENGTH = MAXLEN-K+1  # fixed length sequences
    cnn = Sequential()
    embed_layer = Embedding(ALPHABET,EMBED_DIMEN,input_length=ADJUST_LENGTH,mask_zero=True)   
    cnn1_layer = Conv1D(CFILTERS, FILTERSIZE)
    pool_layer = MaxPooling1D(pool_size=FILTERSIZE, strides=FILTERSIZE//2)
    #pool_layer = GlobalAveragePooling1D()
    flat_layer = Flatten()
    dens_layer = Dense(DCELLS)
    drop_layer = Dropout(0.5)
    output_layer = Dense(1,activation='sigmoid',dtype=dt)

    cnn.add(embed_layer)
    cnn.add(cnn1_layer)
    cnn.add(pool_layer)
    cnn.add(flat_layer)
    cnn.add(dens_layer)
    cnn.add(drop_layer)
    cnn.add(output_layer)

    bc=BinaryCrossentropy(from_logits=False)
    cnn.compile(loss=bc, optimizer="Adam",metrics=["accuracy"])
    return cnn

# %%
print(datetime.now())
model=build_model()
print(model.summary())  # Print this only once
model=None
# Out:
# 2023-02-05 21:25:05.227282
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 4997, 4)           1028
#
#  conv1d (Conv1D)             (None, 4982, 64)          4160
#
#  max_pooling1d (MaxPooling1D  (None, 621, 64)          0
#  )
#
#  flatten (Flatten)           (None, 39744)             0
#
#  dense (Dense)               (None, 16)                635920
#
#  dropout (Dropout)           (None, 16)                0
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 641,125
# Trainable params: 641,125
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## Training

# %%
import gc
class CrossValidator():
    def __init__(self,epochs,folds,quick_test=False,score_threshold=0.5):
        self.epochs = epochs
        self.folds = folds
        self.quick_test = quick_test
        self.score_threshold = score_threshold
        
    def set_sequences(self, allids, allseq):
        # It is critical to keep IDs and sequences in same order!
        self.all_ids = allids  # pairs of (gene_id,tran_id)
        self.all_seqs = allseq  # may be vectors of K-mers
        self.all_genes = [g for (g,t) in allids]
        
    def set_rci_map(self, gene_to_rci):
        # The map is for fast lookup, not gene order!
        self.rci_map = gene_to_rci # map gene_id to RCI value
    
    def get_gene_subset(self, sub_index):
        sub_genes = set()
        for index in sub_index:
            one_gene = self.all_genes[index]
            sub_genes.add(one_gene)
        return sub_genes
    
    def get_X_y(self, gene_set):
        cnt = len(self.all_ids)
        subsetX=[]
        subsetY=[]
        for i in range(cnt):
            gene_id,tran_id = self.all_ids[i]
            if gene_id in gene_set:
                oneX = self.all_seqs[i]
                oneY = self.rci_map[gene_id]
                subsetX.append(oneX)
                subsetY.append(oneY)
        subsetX = np.array(subsetX)
        subsetY = np.array(subsetY).reshape((-1,1))
        return subsetX,subsetY
    
    def rcis_to_labels(self, array_of_rci, rci_threshold):
        IS_CYTO = lambda rci: 1 if rci>rci_threshold else 0
        return np.array(list(map(IS_CYTO, array_of_rci)))
    
    def choose_rci_threshold(self, rci_values):
        discrim = 0
        if RCI_THRESHOLD_MECHANISM == 'RCI_GMM':
            gmm2 = GaussianMixture(n_components=2, verbose=0, 
                covariance_type='spherical', n_init=10) # best of 10
            gmm2.fit(rci_values)
            # Optimal discriminator = weighted average of means of the 2 gaussians
            discrim = gmm2.weights_[0]*gmm2.means_[0]+gmm2.weights_[1]*gmm2.means_[1]
            print('Model params (mean %.2f, wgt %.2f) (mean %.2f, wgt %.2f)' %
                (gmm2.means_[0], gmm2.weights_[0], gmm2.means_[1], gmm2.weights_[1]))
        return discrim
        
    def do_cross_validation(self):
        cv_accuracy=[]
        cv_precision=[]
        cv_recall=[]
        cv_f1=[]
        cv_auprc=[]
        cv_auroc=[]
        fold=0
        print(datetime.now())
        print('splitting')
        # KFold shuffles once before making the partitions
        splitter = KFold(n_splits=self.folds,shuffle=True,random_state=42)
        splits = splitter.split(self.all_genes)
        splitter = None
        for train_index,valid_index in splits:
            fold += 1
            print('Fold',fold)
            train_genes = self.get_gene_subset(train_index)
            X_train,y_train = self.get_X_y(train_genes)
            train_based_rci_threshold = self.choose_rci_threshold(y_train)
            y_train = self.rcis_to_labels(y_train,train_based_rci_threshold)
            valid_genes = self.get_gene_subset(valid_index)
            X_valid,y_valid = self.get_X_y(valid_genes)
            y_valid = self.rcis_to_labels(y_valid,train_based_rci_threshold) # yes, train_based
            print('RCI threshold derived from training set:',train_based_rci_threshold)

            #print('Training example')
            #print(X_train[0])
            #print("BUILD MODEL")
            model=build_model()
            print("FIT")
            print(datetime.now())
            history=model.fit(X_train, y_train, # batch_size=10, default=32 works nicely
              epochs=self.epochs, verbose=0,  # verbose=1 for ascii art, verbose=0 for none
              validation_data=(X_valid,y_valid) )
            print("PREDICT")
            print(datetime.now())
            yhat_pred=model.predict(X_valid, verbose=0)             
            yhat_classes=np.where(yhat_pred > self.score_threshold, 1, 0)

            # accuracy: (tp + tn) / (p + n)
            accuracy = accuracy_score(y_valid, yhat_classes)*100.
            # precision tp / (tp + fp)
            precision = precision_score(y_valid, yhat_classes)*100.
            # recall: tp / (tp + fn)
            recall = recall_score(y_valid, yhat_classes)*100.
            # f1: 2 tp / (2 tp + fp + fn)
            f1 = f1_score(y_valid, yhat_classes)*100.
            # PRC
            prc_Y, prc_X, prc_bins = precision_recall_curve(y_valid, yhat_pred)
            auprc = auc(prc_X,prc_Y)*100.
            auroc = roc_auc_score(y_valid, yhat_pred)*100.

            if PRETTY_PICTURES:
                pd.DataFrame(history.history).plot(figsize=(8,5))
                plt.grid(True)
                plt.gca().set_ylim(0,1)
                plt.show()

                print('Train set ones/size',
                      np.count_nonzero(y_train),'/',len(y_train))
                print("Compute valiation accuracy")
                print('Valid sizes',X_valid.shape,y_valid.shape)
                print('Valid set ones/size',
                      np.count_nonzero(y_valid),'/',len(y_valid))
                print('Range of scores:',np.min(yhat_pred),'to',np.max(yhat_pred))
                print('Score threshold',self.score_threshold)
                print('Prediction set ones/size',
                      np.count_nonzero(yhat_classes),'/',len(yhat_classes))
            
                count_ones= len(y_valid[y_valid==1])
                count_zeros= len(y_valid[y_valid==0])
                guess = max(count_ones,count_zeros) / len(y_valid)
                plt.plot(prc_X, prc_Y, marker='.')
                plt.plot([0, 1], [guess,guess], linestyle='--')
                plt.xlabel('Recall')
                plt.ylabel('Precision')
                plt.show()
                # ROC
                fpr, tpr, roc_bins = roc_curve(y_valid, yhat_pred)
                plt.plot(fpr, tpr, marker='.')
                plt.xlabel('False Positive Rate')
                plt.ylabel('True Positive Rate')
                plt.show()
            
            print('Accuracy: %.2f%% Precision: %.2f%% Recall: %.2f%%' % (accuracy,precision,recall)) 
            print('F1: %.2f%% AUPRC: %.2f%% AUROC: %.2f%%' % (f1,auprc,auroc)) 
            cv_accuracy.append(accuracy)
            cv_precision.append(precision)
            cv_recall.append(recall)
            cv_f1.append(f1)
            cv_auprc.append(auprc)
            cv_auroc.append(auroc)
            
            print(datetime.now())
            if self.quick_test:   
                print('Break -- this was for code testing only')
                break

            # There is a memory leak within the fit() command!
            # Each successive call to fit() consumes more memory.
            model = None
            history = None
            prc_Y = None
            prc_X = None
            prc_bins = None
            yhat_classes = None
            X_train = None
            y_train = None
            train_genes = None
            X_valid = None
            y_valid = None
            valid_genes = None
            tf.keras.backend.clear_session()
            gc.collect()
            time.sleep(1)  # hope gc kicks in
        print()
        return cv_accuracy, cv_precision, cv_recall, cv_f1, cv_auprc, cv_auroc

# %%
for CELL_LINE in range(15):
    print(datetime.now())
    print('Start cell Line',CELL_LINE,all_cell_lines[CELL_LINE])
    loader = DataLoader()
    filepath = DATA_DIR+RCI_FILE
    gene_to_rci = loader.load_gene_rci_values(filepath,CELL_LINE)
    print('Num RCI:', len(gene_to_rci.keys()))
    print('Load sequence...')
    filepath = DATA_DIR+SEQUENCE_FILE
    allids,allseq = loader.load_sequence(filepath)
    loader = None  # drop K-mer cache to save RAM

    print("Cross validation...")
    cvdo = CrossValidator(EPOCHS,FOLDS,BREAK)
    cvdo.set_sequences(allids,allseq)
    cvdo.set_rci_map(gene_to_rci)
    cv_accuracy, cv_precision, cv_recall, cv_f1, cv_auprc, cv_auroc = cvdo.do_cross_validation()   
    cvdo = None
    print("Completed cross validation %d folds %d epochs" % (FOLDS,EPOCHS)) 
    print(" accuracy mean %.2f%% +/- %.2f" % (np.mean(cv_accuracy), np.std(cv_accuracy)))
    print(" precision mean %.2f%% +/- %.2f" % (np.mean(cv_precision), np.std(cv_precision)))
    print(" recall mean %.2f%% +/- %.2f" % (np.mean(cv_recall), np.std(cv_recall)))
    print(" F1 mean %.2f%% +/- %.2f" % (np.mean(cv_f1), np.std(cv_f1)))
    print(" AUPRC mean %.2f%% +/- %.2f" % (np.mean(cv_auprc), np.std(cv_auprc)))
    print(" AUROC mean %.2f%% +/- %.2f" % (np.mean(cv_auroc), np.std(cv_auroc)))
    print('Finished cell Line',CELL_LINE,all_cell_lines[CELL_LINE])
    print()
print(datetime.now())
# Out:
# 2023-02-05 21:25:08.646763
# Start cell Line 0 A549
# Number of RCI values loaded 1447
# Num RCI: 1447
# Load sequence...
# Cross validation...
# 2023-02-05 21:25:33.762692
# splitting
# Fold 1
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:25:37.802448
# PREDICT
# 2023-02-05 21:25:59.084002
# Accuracy: 83.85% Precision: 83.92% Recall: 86.59%
# F1: 85.23% AUPRC: 92.16% AUROC: 91.62%
# 2023-02-05 21:26:00.311915
# Fold 2
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:26:05.601257
# PREDICT
# 2023-02-05 21:26:17.981803
# Accuracy: 85.74% Precision: 85.97% Recall: 87.36%
# F1: 86.66% AUPRC: 94.18% AUROC: 93.64%
# 2023-02-05 21:26:19.593991
# Fold 3
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:26:26.398395
# PREDICT
# 2023-02-05 21:26:38.195335
# Accuracy: 86.09% Precision: 85.99% Recall: 88.45%
# F1: 87.20% AUPRC: 94.75% AUROC: 93.92%
# 2023-02-05 21:26:39.677420
# Fold 4
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:26:44.998329
# PREDICT
# 2023-02-05 21:27:06.379158
# Accuracy: 85.54% Precision: 82.93% Recall: 91.41%
# F1: 86.96% AUPRC: 93.80% AUROC: 93.37%
# 2023-02-05 21:27:07.568385
# Fold 5
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:27:13.137563
# PREDICT
# 2023-02-05 21:27:25.667753
# Accuracy: 85.06% Precision: 81.51% Recall: 92.87%
# F1: 86.82% AUPRC: 92.93% AUROC: 92.70%
# 2023-02-05 21:27:26.990908
#
# Completed cross validation 5 folds 3 epochs
#  accuracy mean 85.26% +/- 0.78
#  precision mean 84.06% +/- 1.74
#  recall mean 89.34% +/- 2.41
#  F1 mean 86.58% +/- 0.70
#  AUPRC mean 93.57% +/- 0.92
#  AUROC mean 93.05% +/- 0.82
# Finished cell Line 0 A549
#
# 2023-02-05 21:27:28.537572
# Start cell Line 1 H1.hESC
# Number of RCI values loaded 3327
# Num RCI: 3327
# Load sequence...
# Cross validation...
# 2023-02-05 21:27:53.709315
# splitting
# Fold 1
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:28:02.670203
# PREDICT
# 2023-02-05 21:28:25.452985
# Accuracy: 85.00% Precision: 80.31% Recall: 77.75%
# F1: 79.01% AUPRC: 87.93% AUROC: 91.82%
# 2023-02-05 21:28:27.466780
# Fold 2
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:28:37.377350
# PREDICT
# 2023-02-05 21:29:19.299539
# Accuracy: 80.11% Precision: 91.32% Recall: 51.41%
# F1: 65.79% AUPRC: 86.47% AUROC: 90.68%
# 2023-02-05 21:29:22.159812
# Fold 3
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:29:32.417303
# PREDICT
# 2023-02-05 21:30:14.211910
# Accuracy: 72.24% Precision: 96.28% Recall: 26.91%
# F1: 42.06% AUPRC: 86.15% AUROC: 90.41%
# 2023-02-05 21:30:16.537505
# Fold 4
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:30:28.104845
# PREDICT
# 2023-02-05 21:30:49.969425
# Accuracy: 84.05% Precision: 78.00% Recall: 78.86%
# F1: 78.43% AUPRC: 87.32% AUROC: 91.30%
# 2023-02-05 21:30:52.837682
# Fold 5
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:31:02.934282
# PREDICT
# 2023-02-05 21:31:44.755155
# Accuracy: 80.76% Precision: 88.28% Recall: 54.85%
# F1: 67.66% AUPRC: 85.26% AUROC: 90.06%
# 2023-02-05 21:31:46.575744
#
# Completed cross validation 5 folds 3 epochs
#  accuracy mean 80.43% +/- 4.50
#  precision mean 86.84% +/- 6.81
#  recall mean 57.96% +/- 19.21
#  F1 mean 66.59% +/- 13.40
#  AUPRC mean 86.63% +/- 0.93
#  AUROC mean 90.85% +/- 0.63
# Finished cell Line 1 H1.hESC
#
# 2023-02-05 21:31:48.096043
# Start cell Line 2 HeLa.S3
# Number of RCI values loaded 919
# Num RCI: 919
# Load sequence...
# Cross validation...
# 2023-02-05 21:31:58.020985
# splitting
# Fold 1
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:32:00.943810
# PREDICT
# 2023-02-05 21:32:09.873280
# Accuracy: 84.79% Precision: 98.91% Recall: 37.47%
# F1: 54.35% AUPRC: 89.13% AUROC: 94.42%
# 2023-02-05 21:32:10.781637
# Fold 2
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:32:14.696874
# PREDICT
# 2023-02-05 21:32:25.590445
# Accuracy: 90.24% Precision: 94.89% Recall: 61.09%
# F1: 74.33% AUPRC: 88.93% AUROC: 94.68%
# 2023-02-05 21:32:26.382897
# Fold 3
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:32:30.354992
# PREDICT
# 2023-02-05 21:32:39.092382
# Accuracy: 92.25% Precision: 90.65% Recall: 75.19%
# F1: 82.20% AUPRC: 90.67% AUROC: 95.03%
# 2023-02-05 21:32:39.830015
# Fold 4
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:32:43.782861
# PREDICT
# 2023-02-05 21:32:54.748787
# Accuracy: 89.89% Precision: 95.99% Recall: 59.47%
# F1: 73.44% AUPRC: 90.00% AUROC: 95.00%
# 2023-02-05 21:32:55.543611
# Fold 5
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:33:01.082525
# PREDICT
# 2023-02-05 21:33:11.993330
# Accuracy: 88.69% Precision: 93.63% Recall: 57.92%
# F1: 71.57% AUPRC: 86.81% AUROC: 92.65%
# 2023-02-05 21:33:13.491104
#
# Completed cross validation 5 folds 3 epochs
#  accuracy mean 89.18% +/- 2.47
#  precision mean 94.81% +/- 2.72
#  recall mean 58.23% +/- 12.07
#  F1 mean 71.18% +/- 9.16
#  AUPRC mean 89.11% +/- 1.31
#  AUROC mean 94.36% +/- 0.88
# Finished cell Line 2 HeLa.S3
#
# 2023-02-05 21:33:14.812147
# Start cell Line 3 HepG2
# Number of RCI values loaded 1362
# Num RCI: 1362
# Load sequence...
# Cross validation...
# 2023-02-05 21:33:27.978089
# splitting
# Fold 1
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:33:31.803804
# PREDICT
# 2023-02-05 21:33:43.197212
# Accuracy: 87.38% Precision: 81.48% Recall: 71.96%
# F1: 76.42% AUPRC: 85.91% AUROC: 91.65%
# 2023-02-05 21:33:44.690286
# Fold 2
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:33:49.786672
# PREDICT
# 2023-02-05 21:34:01.312853
# Accuracy: 85.81% Precision: 95.34% Recall: 51.94%
# F1: 67.25% AUPRC: 87.42% AUROC: 92.54%
# 2023-02-05 21:34:02.316573
# Fold 3
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:34:09.138158
# PREDICT
# 2023-02-05 21:34:30.326226
# Accuracy: 86.23% Precision: 72.54% Recall: 83.49%
# F1: 77.63% AUPRC: 88.58% AUROC: 93.31%
# 2023-02-05 21:34:31.822577
# Fold 4
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:34:37.127042
# PREDICT
# 2023-02-05 21:34:58.289610
# Accuracy: 88.87% Precision: 92.69% Recall: 65.60%
# F1: 76.82% AUPRC: 91.16% AUROC: 95.37%
# 2023-02-05 21:34:59.504346
# Fold 5
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:35:04.605041
# PREDICT
# 2023-02-05 21:35:25.770575
# Accuracy: 88.69% Precision: 93.97% Recall: 64.97%
# F1: 76.82% AUPRC: 90.64% AUROC: 94.55%
# 2023-02-05 21:35:26.806236
#
# Completed cross validation 5 folds 3 epochs
#  accuracy mean 87.40% +/- 1.24
#  precision mean 87.20% +/- 8.83
#  recall mean 67.59% +/- 10.27
#  F1 mean 74.99% +/- 3.89
#  AUPRC mean 88.74% +/- 1.96
#  AUROC mean 93.48% +/- 1.34
# Finished cell Line 3 HepG2
#
# 2023-02-05 21:35:28.155524
# Start cell Line 4 HT1080
# Number of RCI values loaded 936
# Num RCI: 936
# Load sequence...
# Cross validation...
# 2023-02-05 21:35:39.839329
# splitting
# Fold 1
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:35:43.116448
# PREDICT
# 2023-02-05 21:35:54.189997
# Accuracy: 86.18% Precision: 90.16% Recall: 76.44%
# F1: 82.74% AUPRC: 93.13% AUROC: 94.10%
# 2023-02-05 21:35:55.208835
# Fold 2
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:35:59.737128
# PREDICT
# 2023-02-05 21:36:10.734295
# Accuracy: 82.97% Precision: 95.16% Recall: 64.71%
# F1: 77.03% AUPRC: 94.07% AUROC: 94.93%
# 2023-02-05 21:36:12.190360
# Fold 3
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:36:18.342656
# PREDICT
# 2023-02-05 21:36:28.086176
# Accuracy: 87.86% Precision: 84.46% Recall: 87.79%
# F1: 86.09% AUPRC: 93.89% AUROC: 94.92%
# 2023-02-05 21:36:29.585999
# Fold 4
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:36:34.261317
# PREDICT
# 2023-02-05 21:36:44.528394
# Accuracy: 86.16% Precision: 81.04% Recall: 89.41%
# F1: 85.02% AUPRC: 93.05% AUROC: 94.09%
# 2023-02-05 21:36:45.990583
# Fold 5
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:36:50.566308
# PREDICT
# 2023-02-05 21:37:01.494309
# Accuracy: 87.04% Precision: 87.60% Recall: 81.57%
# F1: 84.48% AUPRC: 93.04% AUROC: 94.25%
# 2023-02-05 21:37:02.382031
#
# Completed cross validation 5 folds 3 epochs
#  accuracy mean 86.04% +/- 1.66
#  precision mean 87.69% +/- 4.83
#  recall mean 79.98% +/- 8.92
#  F1 mean 83.07% +/- 3.21
#  AUPRC mean 93.44% +/- 0.45
#  AUROC mean 94.46% +/- 0.39
# Finished cell Line 4 HT1080
#
# 2023-02-05 21:37:03.713634
# Start cell Line 5 HUVEC
# Number of RCI values loaded 1488
# Num RCI: 1488
# Load sequence...
# Cross validation...
# 2023-02-05 21:37:18.802058
# splitting
# Fold 1
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:37:24.723914
# PREDICT
# 2023-02-05 21:37:36.773122
# Accuracy: 89.35% Precision: 90.19% Recall: 71.08%
# F1: 79.50% AUPRC: 90.07% AUROC: 94.46%
# 2023-02-05 21:37:38.118258
# Fold 2
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:37:43.794076
# PREDICT
# 2023-02-05 21:37:56.683865
# Accuracy: 86.47% Precision: 96.66% Recall: 54.61%
# F1: 69.79% AUPRC: 89.63% AUROC: 94.00%
# 2023-02-05 21:37:57.806082
# Fold 3
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:38:05.127307
# PREDICT
# 2023-02-05 21:38:26.238365
# Accuracy: 88.67% Precision: 88.91% Recall: 69.93%
# F1: 78.29% AUPRC: 89.11% AUROC: 93.59%
# 2023-02-05 21:38:27.457438
# Fold 4
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:38:34.136429
# PREDICT
# 2023-02-05 21:38:55.354166
# Accuracy: 88.96% Precision: 83.10% Recall: 76.51%
# F1: 79.67% AUPRC: 88.44% AUROC: 93.48%
# 2023-02-05 21:38:56.536629
# Fold 5
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:39:03.250798
# PREDICT
# 2023-02-05 21:39:16.021207
# Accuracy: 89.02% Precision: 84.11% Recall: 76.24%
# F1: 79.98% AUPRC: 89.27% AUROC: 94.15%
# 2023-02-05 21:39:17.522766
#
# Completed cross validation 5 folds 3 epochs
#  accuracy mean 88.49% +/- 1.04
#  precision mean 88.59% +/- 4.86
#  recall mean 69.67% +/- 7.99
#  F1 mean 77.45% +/- 3.87
#  AUPRC mean 89.30% +/- 0.54
#  AUROC mean 93.93% +/- 0.36
# Finished cell Line 5 HUVEC
#
# 2023-02-05 21:39:18.905628
# Start cell Line 6 MCF.7
# Number of RCI values loaded 2156
# Num RCI: 2156
# Load sequence...
# Cross validation...
# 2023-02-05 21:39:36.307981
# splitting
# Fold 1
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:39:43.085431
# PREDICT
# 2023-02-05 21:40:04.412032
# Accuracy: 84.75% Precision: 91.71% Recall: 54.05%
# F1: 68.01% AUPRC: 86.54% AUROC: 92.33%
# 2023-02-05 21:40:06.045414
# Fold 2
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:40:12.698586
# PREDICT
# 2023-02-05 21:40:27.535583
# Accuracy: 87.90% Precision: 87.33% Recall: 68.67%
# F1: 76.88% AUPRC: 88.11% AUROC: 93.01%
# 2023-02-05 21:40:28.834621
# Fold 3
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:40:36.893466
# PREDICT
# 2023-02-05 21:40:58.130266
# Accuracy: 85.02% Precision: 69.28% Recall: 88.58%
# F1: 77.75% AUPRC: 89.72% AUROC: 94.28%
# 2023-02-05 21:41:00.979388
# Fold 4
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:41:07.523280
# PREDICT
# 2023-02-05 21:41:28.763120
# Accuracy: 87.15% Precision: 77.56% Recall: 78.29%
# F1: 77.92% AUPRC: 86.97% AUROC: 92.57%
# 2023-02-05 21:41:30.287281
# Fold 5
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:41:38.738688
# PREDICT
# 2023-02-05 21:41:59.996445
# Accuracy: 76.63% Precision: 55.69% Recall: 91.91%
# F1: 69.36% AUPRC: 86.07% AUROC: 92.10%
# 2023-02-05 21:42:01.357738
#
# Completed cross validation 5 folds 3 epochs
#  accuracy mean 84.29% +/- 4.01
#  precision mean 76.31% +/- 12.92
#  recall mean 76.30% +/- 13.80
#  F1 mean 73.99% +/- 4.36
#  AUPRC mean 87.48% +/- 1.31
#  AUROC mean 92.86% +/- 0.77
# Finished cell Line 6 MCF.7
#
# 2023-02-05 21:42:02.795527
# Start cell Line 7 NCI.H460
# Number of RCI values loaded 610
# Num RCI: 610
# Load sequence...
# Cross validation...
# 2023-02-05 21:42:11.621813
# splitting
# Fold 1
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:42:14.199556
# PREDICT
# 2023-02-05 21:42:25.124333
# Accuracy: 88.48% Precision: 99.29% Recall: 43.80%
# F1: 60.78% AUPRC: 91.16% AUROC: 96.23%
# 2023-02-05 21:42:25.880107
# Fold 2
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:42:29.919433
# PREDICT
# 2023-02-05 21:42:37.607693
# Accuracy: 91.90% Precision: 77.16% Recall: 86.70%
# F1: 81.65% AUPRC: 91.72% AUROC: 96.43%
# 2023-02-05 21:42:38.411376
# Fold 3
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:42:42.162938
# PREDICT
# 2023-02-05 21:42:53.219829
# Accuracy: 93.10% Precision: 84.49% Recall: 80.59%
# F1: 82.49% AUPRC: 89.98% AUROC: 95.27%
# 2023-02-05 21:42:53.986888
# Fold 4
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:42:59.244369
# PREDICT
# 2023-02-05 21:43:06.422255
# Accuracy: 92.66% Precision: 93.37% Recall: 69.25%
# F1: 79.52% AUPRC: 89.93% AUROC: 95.78%
# 2023-02-05 21:43:07.221520
# Fold 5
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:43:12.160805
# PREDICT
# 2023-02-05 21:43:19.494866
# Accuracy: 88.03% Precision: 99.50% Recall: 41.68%
# F1: 58.75% AUPRC: 90.19% AUROC: 95.87%
# 2023-02-05 21:43:20.182406
#
# Completed cross validation 5 folds 3 epochs
#  accuracy mean 90.83% +/- 2.15
#  precision mean 90.76% +/- 8.72
#  recall mean 64.40% +/- 18.57
#  F1 mean 72.64% +/- 10.57
#  AUPRC mean 90.60% +/- 0.72
#  AUROC mean 95.92% +/- 0.40
# Finished cell Line 7 NCI.H460
#
# 2023-02-05 21:43:21.472582
# Start cell Line 8 NHEK
# Number of RCI values loaded 1080
# Num RCI: 1080
# Load sequence...
# Cross validation...
# 2023-02-05 21:43:34.451407
# splitting
# Fold 1
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:43:39.670406
# PREDICT
# 2023-02-05 21:44:00.997316
# Accuracy: 85.50% Precision: 91.90% Recall: 67.44%
# F1: 77.79% AUPRC: 91.42% AUROC: 93.97%
# 2023-02-05 21:44:02.473947
# Fold 2
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:44:08.364298
# PREDICT
# 2023-02-05 21:44:19.657627
# Accuracy: 84.22% Precision: 84.32% Recall: 72.45%
# F1: 77.93% AUPRC: 88.81% AUROC: 91.69%
# 2023-02-05 21:44:21.191471
# Fold 3
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:44:26.330837
# PREDICT
# 2023-02-05 21:44:38.038488
# Accuracy: 82.39% Precision: 86.91% Recall: 63.68%
# F1: 73.50% AUPRC: 87.83% AUROC: 91.40%
# 2023-02-05 21:44:39.512029
# Fold 4
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:44:46.119991
# PREDICT
# 2023-02-05 21:45:07.273408
# Accuracy: 84.07% Precision: 75.90% Recall: 87.16%
# F1: 81.14% AUPRC: 90.75% AUROC: 92.98%
# 2023-02-05 21:45:08.754615
# Fold 5
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:45:14.171452
# PREDICT
# 2023-02-05 21:45:25.418186
# Accuracy: 79.77% Precision: 92.10% Recall: 51.59%
# F1: 66.13% AUPRC: 89.09% AUROC: 92.60%
# 2023-02-05 21:45:26.409492
#
# Completed cross validation 5 folds 3 epochs
#  accuracy mean 83.19% +/- 1.97
#  precision mean 86.23% +/- 5.96
#  recall mean 68.46% +/- 11.61
#  F1 mean 75.30% +/- 5.19
#  AUPRC mean 89.58% +/- 1.32
#  AUROC mean 92.53% +/- 0.92
# Finished cell Line 8 NHEK
#
# 2023-02-05 21:45:27.762020
# Start cell Line 9 SK.MEL.5
# Number of RCI values loaded 534
# Num RCI: 534
# Load sequence...
# Cross validation...
# 2023-02-05 21:45:35.463444
# splitting
# Fold 1
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:45:39.066055
# PREDICT
# 2023-02-05 21:45:50.000971
# Accuracy: 93.33% Precision: 88.36% Recall: 78.25%
# F1: 83.00% AUPRC: 90.30% AUROC: 95.08%
# 2023-02-05 21:45:50.752614
# Fold 2
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:45:54.419027
# PREDICT
# 2023-02-05 21:46:05.301512
# Accuracy: 87.77% Precision: 99.52% Recall: 42.67%
# F1: 59.73% AUPRC: 92.94% AUROC: 96.96%
# 2023-02-05 21:46:06.093585
# Fold 3
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:46:09.845194
# PREDICT
# 2023-02-05 21:46:20.738999
# Accuracy: 94.15% Precision: 94.57% Recall: 76.51%
# F1: 84.58% AUPRC: 93.58% AUROC: 97.19%
# 2023-02-05 21:46:21.533761
# Fold 4
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:46:25.287584
# PREDICT
# 2023-02-05 21:46:36.246331
# Accuracy: 92.78% Precision: 85.73% Recall: 78.89%
# F1: 82.17% AUPRC: 90.06% AUROC: 95.13%
# 2023-02-05 21:46:37.017982
# Fold 5
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:46:42.000231
# PREDICT
# 2023-02-05 21:46:53.101396
# Accuracy: 90.07% Precision: 98.59% Recall: 52.24%
# F1: 68.29% AUPRC: 90.94% AUROC: 96.03%
# 2023-02-05 21:46:54.569887
#
# Completed cross validation 5 folds 3 epochs
#  accuracy mean 91.62% +/- 2.36
#  precision mean 93.36% +/- 5.48
#  recall mean 65.71% +/- 15.23
#  F1 mean 75.55% +/- 9.84
#  AUPRC mean 91.56% +/- 1.43
#  AUROC mean 96.08% +/- 0.89
# Finished cell Line 9 SK.MEL.5
#
# 2023-02-05 21:46:55.943670
# Start cell Line 10 SK.N.DZ
# Number of RCI values loaded 603
# Num RCI: 603
# Load sequence...
# Cross validation...
# 2023-02-05 21:47:03.710178
# splitting
# Fold 1
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:47:08.438856
# PREDICT
# 2023-02-05 21:47:19.832262
# Accuracy: 87.62% Precision: 93.87% Recall: 68.24%
# F1: 79.03% AUPRC: 92.73% AUROC: 95.15%
# 2023-02-05 21:47:20.659205
# Fold 2
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:47:25.490412
# PREDICT
# 2023-02-05 21:47:36.389780
# Accuracy: 90.16% Precision: 84.10% Recall: 86.52%
# F1: 85.29% AUPRC: 93.91% AUROC: 96.03%
# 2023-02-05 21:47:37.194595
# Fold 3
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:47:41.242035
# PREDICT
# 2023-02-05 21:47:50.164533
# Accuracy: 91.15% Precision: 91.04% Recall: 81.56%
# F1: 86.04% AUPRC: 94.28% AUROC: 96.23%
# 2023-02-05 21:47:50.980225
# Fold 4
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:47:54.996767
# PREDICT
# 2023-02-05 21:48:05.941447
# Accuracy: 85.70% Precision: 93.68% Recall: 62.75%
# F1: 75.16% AUPRC: 90.71% AUROC: 93.78%
# 2023-02-05 21:48:06.772782
# Fold 5
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:48:10.744696
# PREDICT
# 2023-02-05 21:48:20.655087
# Accuracy: 87.42% Precision: 79.93% Recall: 82.50%
# F1: 81.20% AUPRC: 90.70% AUROC: 93.88%
# 2023-02-05 21:48:21.460066
#
# Completed cross validation 5 folds 3 epochs
#  accuracy mean 88.41% +/- 1.98
#  precision mean 88.52% +/- 5.57
#  recall mean 76.32% +/- 9.16
#  F1 mean 81.34% +/- 4.03
#  AUPRC mean 92.47% +/- 1.53
#  AUROC mean 95.01% +/- 1.03
# Finished cell Line 10 SK.N.DZ
#
# 2023-02-05 21:48:22.761670
# Start cell Line 11 SK.N.SH
# Number of RCI values loaded 1647
# Num RCI: 1647
# Load sequence...
# Cross validation...
# 2023-02-05 21:48:38.753366
# splitting
# Fold 1
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:48:45.052093
# PREDICT
# 2023-02-05 21:49:06.314906
# Accuracy: 87.12% Precision: 86.49% Recall: 68.82%
# F1: 76.65% AUPRC: 87.59% AUROC: 92.77%
# 2023-02-05 21:49:07.834507
# Fold 2
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:49:14.093985
# PREDICT
# 2023-02-05 21:49:27.539683
# Accuracy: 84.00% Precision: 96.91% Recall: 48.73%
# F1: 64.85% AUPRC: 89.61% AUROC: 93.92%
# 2023-02-05 21:49:29.044821
# Fold 3
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:49:36.680763
# PREDICT
# 2023-02-05 21:49:57.895045
# Accuracy: 87.50% Precision: 83.15% Recall: 73.48%
# F1: 78.01% AUPRC: 88.16% AUROC: 93.49%
# 2023-02-05 21:49:59.168270
# Fold 4
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:50:06.350823
# PREDICT
# 2023-02-05 21:50:19.920825
# Accuracy: 82.35% Precision: 95.93% Recall: 43.63%
# F1: 59.98% AUPRC: 87.26% AUROC: 92.48%
# 2023-02-05 21:50:21.436927
# Fold 5
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:50:28.185950
# PREDICT
# 2023-02-05 21:50:49.678468
# Accuracy: 86.06% Precision: 90.07% Recall: 61.58%
# F1: 73.15% AUPRC: 88.60% AUROC: 93.45%
# 2023-02-05 21:50:51.188471
#
# Completed cross validation 5 folds 3 epochs
#  accuracy mean 85.40% +/- 1.95
#  precision mean 90.51% +/- 5.31
#  recall mean 59.25% +/- 11.44
#  F1 mean 70.53% +/- 6.98
#  AUPRC mean 88.24% +/- 0.83
#  AUROC mean 93.22% +/- 0.52
# Finished cell Line 11 SK.N.SH
#
# 2023-02-05 21:50:52.595200
# Start cell Line 12 GM12878
# Number of RCI values loaded 1698
# Num RCI: 1698
# Load sequence...
# Cross validation...
# 2023-02-05 21:51:09.300571
# splitting
# Fold 1
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:51:14.277667
# PREDICT
# 2023-02-05 21:51:35.520187
# Accuracy: 86.61% Precision: 89.71% Recall: 67.02%
# F1: 76.72% AUPRC: 89.98% AUROC: 93.49%
# 2023-02-05 21:51:37.064175
# Fold 2
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:51:42.823423
# PREDICT
# 2023-02-05 21:52:04.029182
# Accuracy: 85.62% Precision: 94.85% Recall: 59.93%
# F1: 73.45% AUPRC: 89.95% AUROC: 93.22%
# 2023-02-05 21:52:05.533044
# Fold 3
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:52:11.257100
# PREDICT
# 2023-02-05 21:52:24.571144
# Accuracy: 88.10% Precision: 88.63% Recall: 72.83%
# F1: 79.96% AUPRC: 90.97% AUROC: 94.27%
# 2023-02-05 21:52:26.065859
# Fold 4
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:52:31.934557
# PREDICT
# 2023-02-05 21:52:45.121189
# Accuracy: 85.60% Precision: 93.22% Recall: 59.65%
# F1: 72.74% AUPRC: 88.24% AUROC: 92.07%
# 2023-02-05 21:52:46.256219
# Fold 5
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:52:52.014375
# PREDICT
# 2023-02-05 21:53:04.342599
# Accuracy: 87.26% Precision: 81.19% Recall: 79.31%
# F1: 80.24% AUPRC: 89.95% AUROC: 93.61%
# 2023-02-05 21:53:05.503326
#
# Completed cross validation 5 folds 3 epochs
#  accuracy mean 86.64% +/- 0.96
#  precision mean 89.52% +/- 4.74
#  recall mean 67.75% +/- 7.57
#  F1 mean 76.62% +/- 3.14
#  AUPRC mean 89.82% +/- 0.88
#  AUROC mean 93.33% +/- 0.72
# Finished cell Line 12 GM12878
#
# 2023-02-05 21:53:06.898956
# Start cell Line 13 K562
# Number of RCI values loaded 958
# Num RCI: 958
# Load sequence...
# Cross validation...
# 2023-02-05 21:53:16.767968
# splitting
# Fold 1
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:53:20.077529
# PREDICT
# 2023-02-05 21:53:31.294952
# Accuracy: 86.19% Precision: 94.08% Recall: 58.24%
# F1: 71.95% AUPRC: 88.63% AUROC: 93.03%
# 2023-02-05 21:53:32.752037
# Fold 2
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:53:37.600986
# PREDICT
# 2023-02-05 21:53:46.729541
# Accuracy: 84.48% Precision: 70.52% Recall: 85.41%
# F1: 77.25% AUPRC: 87.68% AUROC: 92.81%
# 2023-02-05 21:53:48.232486
# Fold 3
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:53:52.389770
# PREDICT
# 2023-02-05 21:54:02.652321
# Accuracy: 85.56% Precision: 91.83% Recall: 58.87%
# F1: 71.74% AUPRC: 87.42% AUROC: 92.35%
# 2023-02-05 21:54:03.427894
# Fold 4
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:54:07.589942
# PREDICT
# 2023-02-05 21:54:18.492883
# Accuracy: 84.33% Precision: 95.90% Recall: 51.09%
# F1: 66.67% AUPRC: 88.79% AUROC: 93.28%
# 2023-02-05 21:54:19.275685
# Fold 5
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:54:23.463868
# PREDICT
# 2023-02-05 21:54:34.387077
# Accuracy: 82.42% Precision: 97.02% Recall: 44.82%
# F1: 61.31% AUPRC: 90.63% AUROC: 94.65%
# 2023-02-05 21:54:35.835574
#
# Completed cross validation 5 folds 3 epochs
#  accuracy mean 84.60% +/- 1.29
#  precision mean 89.87% +/- 9.83
#  recall mean 59.69% +/- 13.85
#  F1 mean 69.78% +/- 5.40
#  AUPRC mean 88.63% +/- 1.13
#  AUROC mean 93.22% +/- 0.78
# Finished cell Line 13 K562
#
# 2023-02-05 21:54:37.145619
# Start cell Line 14 IMR.90
# Number of RCI values loaded 390
# Num RCI: 390
# Load sequence...
# Cross validation...
# 2023-02-05 21:54:42.577921
# splitting
# Fold 1
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:54:43.839502
# PREDICT
# 2023-02-05 21:54:47.802458
# Accuracy: 82.78% Precision: 75.76% Recall: 75.24%
# F1: 75.50% AUPRC: 84.21% AUROC: 90.29%
# 2023-02-05 21:54:48.232692
# Fold 2
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:54:50.665734
# PREDICT
# 2023-02-05 21:54:56.385537
# Accuracy: 68.06% Precision: 94.25% Recall: 10.96%
# F1: 19.64% AUPRC: 70.61% AUROC: 81.73%
# 2023-02-05 21:54:56.821502
# Fold 3
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:54:59.198430
# PREDICT
# 2023-02-05 21:55:03.055611
# Accuracy: 83.03% Precision: 84.92% Recall: 65.15%
# F1: 73.73% AUPRC: 85.77% AUROC: 90.80%
# 2023-02-05 21:55:03.481349
# Fold 4
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:55:06.796482
# PREDICT
# 2023-02-05 21:55:10.935801
# Accuracy: 84.27% Precision: 84.54% Recall: 68.44%
# F1: 75.64% AUPRC: 86.13% AUROC: 92.14%
# 2023-02-05 21:55:11.357739
# Fold 5
# RCI threshold derived from training set: 0
# FIT
# 2023-02-05 21:55:13.709658
# PREDICT
# 2023-02-05 21:55:19.440369
# Accuracy: 84.84% Precision: 81.18% Recall: 76.35%
# F1: 78.69% AUPRC: 87.22% AUROC: 91.94%
# 2023-02-05 21:55:20.215792
#
# Completed cross validation 5 folds 3 epochs
#  accuracy mean 80.60% +/- 6.31
#  precision mean 84.13% +/- 6.03
#  recall mean 59.23% +/- 24.49
#  F1 mean 64.64% +/- 22.56
#  AUPRC mean 82.79% +/- 6.17
#  AUROC mean 89.38% +/- 3.89
# Finished cell Line 14 IMR.90
#
# 2023-02-05 21:55:21.439542
