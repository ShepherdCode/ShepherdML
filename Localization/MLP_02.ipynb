# %% [markdown]
# # MLP

# %%
from datetime import datetime
print(datetime.now())
from platform import python_version
print('Python',python_version())
from csv import reader
import numpy as np
import pandas as pd
import matplotlib as plt
import math
import random
import sklearn   # pip install --upgrade scikit-learn
print('sklearn',sklearn.__version__)
# Out:
# 2022-10-06 08:21:04.279560
# Python 3.10.0
# sklearn 1.1.2

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import StratifiedKFold
import tensorflow as tf
from tensorflow import keras
from keras.wrappers.scikit_learn import KerasRegressor
from keras.models import Sequential
from keras.layers import Bidirectional
from keras.layers import Dense
from keras.layers import LayerNormalization

dt='float32'
tf.keras.backend.set_floatx(dt)

EPOCHS=200
SPLITS=3
EMBED_DIMEN=16

# %%
ATLAS_DIR = '/Users/jasonmiller/WVU/Localization/LncAtlas/'
RCI_FILE = 'CNRCI_coding_train_genes.csv'
GENCODE_DIR = '/Users/jasonmiller/WVU/Localization/GenCode/'
SEQUENCE_FILE = 'Homo_sapiens.GRCh38.cds.csv'

# %%
from cell_lines import Cell_Lines
all_cell_lines = Cell_Lines.get_ordered_list()
cell_line_number = 0
cell_line_name = all_cell_lines[cell_line_number]
print('Cell line for today:',cell_line_number,cell_line_name)
# Out:
# Cell line for today: 0 A549

# %% [markdown]
# ## Load labels and sequences

# %%
def load_labels(atlas_file,cells):
    gene_labels = {}
    with open(atlas_file,'r') as atlas:
        header = None
        genes_considered = 0
        positives = 0
        csv = reader(atlas)
        for row in csv:
            if header is None:
                header = row
            else:
                gene = row[0]
                genes_considered += 1
                rci = float(row[1+cells])
                if not math.isnan(rci):
                    # GENERATE BINARY LABELS
                    label = 0   # RCI<0
                    if rci>=0:  # THRESHOLD
                        label = 1   #RCI>=0
                        positives += 1
                    gene_labels[gene]=label
    print('Genes:',genes_considered)
    print('Gene labels:',len(gene_labels))
    print('Positive labels:',positives)
    return gene_labels
    
print(datetime.now())
atlas_path = ATLAS_DIR+RCI_FILE
gene_label = load_labels(atlas_path,cell_line_number)
# Out:
# 2022-10-06 08:21:15.930613
# Genes: 14216
# Gene labels: 10392
# Positive labels: 5412

# %%
def load_sequences(gencode_file,gene_label):
    gid_tid = []
    labels = []
    tseqs = []
    with open(gencode_file,'r') as gencode:
        header = None
        csv = reader(gencode)
        for row in csv:
            if header is None:
                header = row
            else:
                tran_id = row[0]
                gene_id = row[1]
                tseq = row[4]
                if gene_id in gene_label:
                    label = gene_label[gene_id]
                    gid_tid.append ((gene_id,tran_id))
                    labels.append(label)
                    tseqs.append(tseq)
    return gid_tid,labels,tseqs

# %%
print(datetime.now())
gencode_path = GENCODE_DIR+SEQUENCE_FILE
ordered_gid_tid,ordered_labels,ordered_seqs = \
    load_sequences(gencode_path,gene_label)
# Out:
# 2022-10-06 08:21:16.043212

# %% [markdown]
# ## Make K-mers

# %%
K=4
MAX_COUNT = 2**8-1
VOCABULARY_SIZE = 4**K
def seq_to_kmer_counts(seq):
    counts = np.zeros(VOCABULARY_SIZE,np.int8)
    letter_values={'A':0, 'C':1, 'G':2, 'T':3}
    for p in range(len(seq)-K+1):
        valid = True
        kmer_seq=seq[p:p+K]
        kmer_hash=0
        for d in range(K):
            letter = kmer_seq[d]
            if letter in letter_values:
                additional = letter_values[letter]
                kmer_hash = kmer_hash * 4  # left shift
                kmer_hash = kmer_hash + additional
            else:
                valid = False
        #print(p, kmer_seq, kmer_hash, valid)
        if valid and counts[kmer_hash]<MAX_COUNT:
            counts[kmer_hash] += 1
    return counts

# %%
print(datetime.now())
ordered_kmer_counts = []
tock = 1000
tick = 0
for seq in ordered_seqs:
    tick += 1
    if tick >= tock:
        tick = 1
        print('.',end='')
    counts = seq_to_kmer_counts(seq)
    ordered_kmer_counts.append(counts)
print(datetime.now())
# Out:
# 2022-10-06 08:21:17.447695
# .....................................................2022-10-06 08:27:44.405652

# %% [markdown]
# ## Build model

# %%
def build_model():
    act="sigmoid"
    #embed_layer  = keras.layers.Embedding(
    #    VOCABULARY_SIZE,EMBED_DIMEN,input_length=maxlen);
    dense1_layer = keras.layers.Dense(64, activation=act,dtype=dt,
                                      input_dim=VOCABULARY_SIZE)
    dense2_layer = keras.layers.Dense(64, activation=act,dtype=dt)
    dense3_layer = keras.layers.Dense(64, activation=act,dtype=dt)
    output_layer = keras.layers.Dense(1,  activation="softmax",dtype=dt)

    mlp = keras.models.Sequential()
    #mlp.add(embed_layer)
    mlp.add(dense1_layer)
    mlp.add(dense2_layer)
    mlp.add(dense3_layer)
    mlp.add(output_layer)
    
    # Logit=True ranges from + to - infinity.
    # Logit=False i.e. probabilities range from 0 to 1.
    # If your output layer has a 'softmax' activation, from_logits should be False. If your output layer doesn't have a 'softmax' activation, from_logits should be True. 
    bc=tf.keras.losses.BinaryCrossentropy(from_logits=False)
    print("COMPILE...")
    mlp.compile(loss=bc, optimizer="Adam",metrics=["accuracy"])
    print("...COMPILED")
    return mlp

# %% [markdown]
# ## Cross validation

# %%
from random import Random
def train_valid_split(iteration, partitions):
    num_transcripts = len(ordered_gid_tid)
    gene_set = set()
    for (gid,tid) in ordered_gid_tid:
        gene_set.add(gid)
    num_genes = len(gene_set)
    print('Num genes:',num_genes,'Num transcripts:',num_transcripts)
    low = int(0)
    high = int(num_genes * 0.20)    # later, calculate from iteration
    gene_list = list(gene_set)
    generator = Random()
    generator.seed(42)
    generator.shuffle(gene_list)  # in-place
    valid_genes = set(gene_list[low:high])
    train_genes = set(gene_list[high:])    # not needed?
    X_train = []   # would be more efficient with fixed-size numpy array
    X_valid = []
    y_train = []
    y_valid = []
    for i in range(num_transcripts):
        (gid,tid) = ordered_gid_tid[i]     
        if gid in valid_genes:
            X_valid.append(ordered_kmer_counts[i])   
            y_valid.append(ordered_labels[i])
        else:
            X_train.append(ordered_kmer_counts[i])   
            y_train.append(ordered_labels[i])
    X_train = np.asarray(X_train)
    y_train = np.asarray(y_train)
    X_valid = np.asarray(X_valid)
    y_valid = np.asarray(y_valid)
    return X_train,y_train,X_valid,y_valid

# %%
def do_cross_validation(X,y,eps):
    cv_scores = []
    fold=0
    splitter = ShuffleSplit(n_splits=SPLITS, test_size=0.2, random_state=37863)
    PARTITIONS=5
    PARTITIONS=1   # for testing
    for i in range(PARTITIONS):
        X_train,y_train,X_valid,y_valid = train_valid_split(i,PARTITIONS)

        print("BUILD MODEL")
        model=build_model()

        print("FIT")
        # this is complaining about string to float
        history=model.fit(X_train, y_train, # batch_size=10, default=32 works nicely
                epochs=eps, verbose=1,  # verbose=1 for ascii art, verbose=0 for none
                validation_data=(X_valid,y_valid) )
                        
        fold += 1
        print("Fold %d, %d epochs"%(fold,eps))

        pd.DataFrame(history.history).plot(figsize=(8,5))
        plt.grid(True)
        plt.gca().set_ylim(0,1)
        plt.show()

        scores = model.evaluate(X_valid, y_valid, verbose=0)
        print("%s: %.2f%%" % (rnn2.metrics_names[1], scores[1]*100))
        # What are the other metrics_names?
        # Try this from Geron page 505:
        # np.mean(keras.losses.mean_squared_error(y_valid,y_pred))
        cv_scores.append(scores[1] * 100)
    print()
    print("Validation core mean %.2f%% (+/- %.2f%%)" % (np.mean(cv_scores), np.std(cv_scores)))

# %% [markdown]
# ## Train

# %%
print(datetime.now())
model=build_model()
print ("Summarize the model")
print(model.summary())  # Print this only once

print ("Sequence to Kmer")
y = ordered_labels
X = ordered_kmer_counts

print ("Cross valiation")
do_cross_validation(X,y,EPOCHS)
print(datetime.now())
# Out:
# 2022-10-06 08:27:44.533291
# COMPILE...
# ...COMPILED
# Summarize the model
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                16448
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 24,833
# Trainable params: 24,833
# Non-trainable params: 0
# 2022-10-06 08:27:44.545699: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# _________________________________________________________________
# None
# Sequence to Kmer
# Cross valiation
# Num genes: 10268 Num transcripts: 53450
# BUILD MODEL
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/200
# 1319/1319 [==============================] - 4s 2ms/step - loss: 0.5979 - accuracy: 0.5042 - val_loss: 0.5930 - val_accuracy: 0.5054
# Epoch 2/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.5811 - accuracy: 0.5042 - val_loss: 0.5884 - val_accuracy: 0.5054
# Epoch 3/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.5732 - accuracy: 0.5042 - val_loss: 0.6013 - val_accuracy: 0.5054
# Epoch 4/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.5700 - accuracy: 0.5042 - val_loss: 0.5866 - val_accuracy: 0.5054
# Epoch 5/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.5582 - accuracy: 0.5042 - val_loss: 0.5893 - val_accuracy: 0.5054
# Epoch 6/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.5440 - accuracy: 0.5042 - val_loss: 0.5931 - val_accuracy: 0.5054
# Epoch 7/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.5326 - accuracy: 0.5042 - val_loss: 0.6099 - val_accuracy: 0.5054
# Epoch 8/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.5356 - accuracy: 0.5042 - val_loss: 0.6007 - val_accuracy: 0.5054
# Epoch 9/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.5175 - accuracy: 0.5042 - val_loss: 0.6211 - val_accuracy: 0.5054
# Epoch 10/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.5026 - accuracy: 0.5042 - val_loss: 0.6301 - val_accuracy: 0.5054
# Epoch 11/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.4900 - accuracy: 0.5042 - val_loss: 0.6552 - val_accuracy: 0.5054
# Epoch 12/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.4799 - accuracy: 0.5042 - val_loss: 0.6568 - val_accuracy: 0.5054
# Epoch 13/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.4675 - accuracy: 0.5042 - val_loss: 0.6583 - val_accuracy: 0.5054
# Epoch 14/200
# 1319/1319 [==============================] - 3s 3ms/step - loss: 0.4661 - accuracy: 0.5042 - val_loss: 0.6687 - val_accuracy: 0.5054
# Epoch 15/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.4532 - accuracy: 0.5042 - val_loss: 0.6754 - val_accuracy: 0.5054
# Epoch 16/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.4383 - accuracy: 0.5042 - val_loss: 0.6887 - val_accuracy: 0.5054
# Epoch 17/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.4286 - accuracy: 0.5042 - val_loss: 0.7188 - val_accuracy: 0.5054
# Epoch 18/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.4190 - accuracy: 0.5042 - val_loss: 0.7146 - val_accuracy: 0.5054
# Epoch 19/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.4077 - accuracy: 0.5042 - val_loss: 0.7149 - val_accuracy: 0.5054
# Epoch 20/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.3994 - accuracy: 0.5042 - val_loss: 0.7521 - val_accuracy: 0.5054
# Epoch 21/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.3901 - accuracy: 0.5042 - val_loss: 0.8265 - val_accuracy: 0.5054
# Epoch 22/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.3811 - accuracy: 0.5042 - val_loss: 0.7742 - val_accuracy: 0.5054
# Epoch 23/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.3751 - accuracy: 0.5042 - val_loss: 0.8195 - val_accuracy: 0.5054
# Epoch 24/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.3708 - accuracy: 0.5042 - val_loss: 0.8148 - val_accuracy: 0.5054
# Epoch 25/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.3606 - accuracy: 0.5042 - val_loss: 0.8131 - val_accuracy: 0.5054
# Epoch 26/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.3566 - accuracy: 0.5042 - val_loss: 0.8374 - val_accuracy: 0.5054
# Epoch 27/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.3483 - accuracy: 0.5042 - val_loss: 0.8445 - val_accuracy: 0.5054
# Epoch 28/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.3431 - accuracy: 0.5042 - val_loss: 0.8652 - val_accuracy: 0.5054
# Epoch 29/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.3389 - accuracy: 0.5042 - val_loss: 0.8889 - val_accuracy: 0.5054
# Epoch 30/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.3299 - accuracy: 0.5042 - val_loss: 0.9293 - val_accuracy: 0.5054
# Epoch 31/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.3243 - accuracy: 0.5042 - val_loss: 0.9319 - val_accuracy: 0.5054
# Epoch 32/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.3182 - accuracy: 0.5042 - val_loss: 0.9438 - val_accuracy: 0.5054
# Epoch 33/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.3155 - accuracy: 0.5042 - val_loss: 0.9372 - val_accuracy: 0.5054
# Epoch 34/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.3101 - accuracy: 0.5042 - val_loss: 0.9584 - val_accuracy: 0.5054
# Epoch 35/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.3042 - accuracy: 0.5042 - val_loss: 0.9270 - val_accuracy: 0.5054
# Epoch 36/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.2991 - accuracy: 0.5042 - val_loss: 0.9576 - val_accuracy: 0.5054
# Epoch 37/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.2935 - accuracy: 0.5042 - val_loss: 0.9665 - val_accuracy: 0.5054
# Epoch 38/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.2904 - accuracy: 0.5042 - val_loss: 1.0457 - val_accuracy: 0.5054
# Epoch 39/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.2872 - accuracy: 0.5042 - val_loss: 1.0279 - val_accuracy: 0.5054
# Epoch 40/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.2835 - accuracy: 0.5042 - val_loss: 1.0059 - val_accuracy: 0.5054
# Epoch 41/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.2816 - accuracy: 0.5042 - val_loss: 1.0479 - val_accuracy: 0.5054
# Epoch 42/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.2761 - accuracy: 0.5042 - val_loss: 1.0879 - val_accuracy: 0.5054
# Epoch 43/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.2734 - accuracy: 0.5042 - val_loss: 1.0829 - val_accuracy: 0.5054
# Epoch 44/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.2679 - accuracy: 0.5042 - val_loss: 1.1073 - val_accuracy: 0.5054
# Epoch 45/200
# 1319/1319 [==============================] - 3s 3ms/step - loss: 0.2653 - accuracy: 0.5042 - val_loss: 1.1053 - val_accuracy: 0.5054
# Epoch 46/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.2627 - accuracy: 0.5042 - val_loss: 1.1363 - val_accuracy: 0.5054
# Epoch 47/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.2569 - accuracy: 0.5042 - val_loss: 1.1261 - val_accuracy: 0.5054
# Epoch 48/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.2572 - accuracy: 0.5042 - val_loss: 1.1823 - val_accuracy: 0.5054
# Epoch 49/200
# 1319/1319 [==============================] - 3s 3ms/step - loss: 0.2534 - accuracy: 0.5042 - val_loss: 1.1888 - val_accuracy: 0.5054
# Epoch 50/200
# 1319/1319 [==============================] - 3s 3ms/step - loss: 0.2533 - accuracy: 0.5042 - val_loss: 1.1875 - val_accuracy: 0.5054
# Epoch 51/200
# 1319/1319 [==============================] - 3s 3ms/step - loss: 0.2486 - accuracy: 0.5042 - val_loss: 1.1605 - val_accuracy: 0.5054
# Epoch 52/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.2468 - accuracy: 0.5042 - val_loss: 1.1589 - val_accuracy: 0.5054
# Epoch 53/200
# 1319/1319 [==============================] - 3s 3ms/step - loss: 0.2439 - accuracy: 0.5042 - val_loss: 1.1274 - val_accuracy: 0.5054
# Epoch 54/200
# 1319/1319 [==============================] - 3s 3ms/step - loss: 0.2396 - accuracy: 0.5042 - val_loss: 1.1724 - val_accuracy: 0.5054
# Epoch 55/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.2444 - accuracy: 0.5042 - val_loss: 1.1754 - val_accuracy: 0.5054
# Epoch 56/200
# 1319/1319 [==============================] - 3s 3ms/step - loss: 0.2351 - accuracy: 0.5042 - val_loss: 1.2005 - val_accuracy: 0.5054
# Epoch 57/200
# 1319/1319 [==============================] - 3s 3ms/step - loss: 0.2412 - accuracy: 0.5042 - val_loss: 1.1476 - val_accuracy: 0.5054
# Epoch 58/200
# 1319/1319 [==============================] - 3s 3ms/step - loss: 0.2443 - accuracy: 0.5042 - val_loss: 1.1324 - val_accuracy: 0.5054
# Epoch 59/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.2464 - accuracy: 0.5042 - val_loss: 1.1913 - val_accuracy: 0.5054
# Epoch 60/200
# 1319/1319 [==============================] - 4s 3ms/step - loss: 0.2326 - accuracy: 0.5042 - val_loss: 1.2228 - val_accuracy: 0.5054
# Epoch 61/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.2341 - accuracy: 0.5042 - val_loss: 1.1845 - val_accuracy: 0.5054
# Epoch 62/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.2271 - accuracy: 0.5042 - val_loss: 1.2268 - val_accuracy: 0.5054
# Epoch 63/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.2222 - accuracy: 0.5042 - val_loss: 1.2887 - val_accuracy: 0.5054
# Epoch 64/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.2198 - accuracy: 0.5042 - val_loss: 1.3195 - val_accuracy: 0.5054
# Epoch 65/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.2196 - accuracy: 0.5042 - val_loss: 1.2876 - val_accuracy: 0.5054
# Epoch 66/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.2160 - accuracy: 0.5042 - val_loss: 1.2853 - val_accuracy: 0.5054
# Epoch 67/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.2158 - accuracy: 0.5042 - val_loss: 1.2751 - val_accuracy: 0.5054
# Epoch 68/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.2136 - accuracy: 0.5042 - val_loss: 1.3211 - val_accuracy: 0.5054
# Epoch 69/200
# 1319/1319 [==============================] - 3s 3ms/step - loss: 0.2205 - accuracy: 0.5042 - val_loss: 1.2540 - val_accuracy: 0.5054
# Epoch 70/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.2137 - accuracy: 0.5042 - val_loss: 1.2527 - val_accuracy: 0.5054
# Epoch 71/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.2209 - accuracy: 0.5042 - val_loss: 1.2636 - val_accuracy: 0.5054
# Epoch 72/200
# 1319/1319 [==============================] - 3s 3ms/step - loss: 0.2105 - accuracy: 0.5042 - val_loss: 1.2780 - val_accuracy: 0.5054
# Epoch 73/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.2158 - accuracy: 0.5042 - val_loss: 1.2864 - val_accuracy: 0.5054
# Epoch 74/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.2107 - accuracy: 0.5042 - val_loss: 1.2677 - val_accuracy: 0.5054
# Epoch 75/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.2079 - accuracy: 0.5042 - val_loss: 1.3095 - val_accuracy: 0.5054
# Epoch 76/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.2084 - accuracy: 0.5042 - val_loss: 1.2380 - val_accuracy: 0.5054
# Epoch 77/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.2104 - accuracy: 0.5042 - val_loss: 1.2800 - val_accuracy: 0.5054
# Epoch 78/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.2100 - accuracy: 0.5042 - val_loss: 1.3196 - val_accuracy: 0.5054
# Epoch 79/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.2066 - accuracy: 0.5042 - val_loss: 1.2778 - val_accuracy: 0.5054
# Epoch 80/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.2021 - accuracy: 0.5042 - val_loss: 1.3484 - val_accuracy: 0.5054
# Epoch 81/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.2036 - accuracy: 0.5042 - val_loss: 1.3212 - val_accuracy: 0.5054
# Epoch 82/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.2062 - accuracy: 0.5042 - val_loss: 1.3110 - val_accuracy: 0.5054
# Epoch 83/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.2028 - accuracy: 0.5042 - val_loss: 1.2896 - val_accuracy: 0.5054
# Epoch 84/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.2037 - accuracy: 0.5042 - val_loss: 1.3114 - val_accuracy: 0.5054
# Epoch 85/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.2023 - accuracy: 0.5042 - val_loss: 1.2503 - val_accuracy: 0.5054
# Epoch 86/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.2013 - accuracy: 0.5042 - val_loss: 1.2887 - val_accuracy: 0.5054
# Epoch 87/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1936 - accuracy: 0.5042 - val_loss: 1.3603 - val_accuracy: 0.5054
# Epoch 88/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1981 - accuracy: 0.5042 - val_loss: 1.2694 - val_accuracy: 0.5054
# Epoch 89/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1927 - accuracy: 0.5042 - val_loss: 1.3360 - val_accuracy: 0.5054
# Epoch 90/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1930 - accuracy: 0.5042 - val_loss: 1.4169 - val_accuracy: 0.5054
# Epoch 91/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1922 - accuracy: 0.5042 - val_loss: 1.3267 - val_accuracy: 0.5054
# Epoch 92/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1974 - accuracy: 0.5042 - val_loss: 1.3514 - val_accuracy: 0.5054
# Epoch 93/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1857 - accuracy: 0.5042 - val_loss: 1.3960 - val_accuracy: 0.5054
# Epoch 94/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1898 - accuracy: 0.5042 - val_loss: 1.4065 - val_accuracy: 0.5054
# Epoch 95/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1820 - accuracy: 0.5042 - val_loss: 1.3858 - val_accuracy: 0.5054
# Epoch 96/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1874 - accuracy: 0.5042 - val_loss: 1.3386 - val_accuracy: 0.5054
# Epoch 97/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1893 - accuracy: 0.5042 - val_loss: 1.3546 - val_accuracy: 0.5054
# Epoch 98/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1886 - accuracy: 0.5042 - val_loss: 1.3085 - val_accuracy: 0.5054
# Epoch 99/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1909 - accuracy: 0.5042 - val_loss: 1.3403 - val_accuracy: 0.5054
# Epoch 100/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1833 - accuracy: 0.5042 - val_loss: 1.4092 - val_accuracy: 0.5054
# Epoch 101/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1798 - accuracy: 0.5042 - val_loss: 1.4217 - val_accuracy: 0.5054
# Epoch 102/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1773 - accuracy: 0.5042 - val_loss: 1.4235 - val_accuracy: 0.5054
# Epoch 103/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1827 - accuracy: 0.5042 - val_loss: 1.4015 - val_accuracy: 0.5054
# Epoch 104/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1837 - accuracy: 0.5042 - val_loss: 1.3606 - val_accuracy: 0.5054
# Epoch 105/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1884 - accuracy: 0.5042 - val_loss: 1.4357 - val_accuracy: 0.5054
# Epoch 106/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1787 - accuracy: 0.5042 - val_loss: 1.3801 - val_accuracy: 0.5054
# Epoch 107/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1785 - accuracy: 0.5042 - val_loss: 1.4148 - val_accuracy: 0.5054
# Epoch 108/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1793 - accuracy: 0.5042 - val_loss: 1.3687 - val_accuracy: 0.5054
# Epoch 109/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1785 - accuracy: 0.5042 - val_loss: 1.3113 - val_accuracy: 0.5054
# Epoch 110/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1750 - accuracy: 0.5042 - val_loss: 1.4098 - val_accuracy: 0.5054
# Epoch 111/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1761 - accuracy: 0.5042 - val_loss: 1.3930 - val_accuracy: 0.5054
# Epoch 112/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1749 - accuracy: 0.5042 - val_loss: 1.4125 - val_accuracy: 0.5054
# Epoch 113/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1741 - accuracy: 0.5042 - val_loss: 1.3827 - val_accuracy: 0.5054
# Epoch 114/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1670 - accuracy: 0.5042 - val_loss: 1.4350 - val_accuracy: 0.5054
# Epoch 115/200
# 1319/1319 [==============================] - 3s 3ms/step - loss: 0.1747 - accuracy: 0.5042 - val_loss: 1.4944 - val_accuracy: 0.5054
# Epoch 116/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1785 - accuracy: 0.5042 - val_loss: 1.3480 - val_accuracy: 0.5054
# Epoch 117/200
# 1319/1319 [==============================] - 3s 3ms/step - loss: 0.1657 - accuracy: 0.5042 - val_loss: 1.4699 - val_accuracy: 0.5054
# Epoch 118/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1655 - accuracy: 0.5042 - val_loss: 1.5177 - val_accuracy: 0.5054
# Epoch 119/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1698 - accuracy: 0.5042 - val_loss: 1.3845 - val_accuracy: 0.5054
# Epoch 120/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1714 - accuracy: 0.5042 - val_loss: 1.4566 - val_accuracy: 0.5054
# Epoch 121/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1710 - accuracy: 0.5042 - val_loss: 1.4280 - val_accuracy: 0.5054
# Epoch 122/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1736 - accuracy: 0.5042 - val_loss: 1.3729 - val_accuracy: 0.5054
# Epoch 123/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1631 - accuracy: 0.5042 - val_loss: 1.4365 - val_accuracy: 0.5054
# Epoch 124/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1666 - accuracy: 0.5042 - val_loss: 1.3699 - val_accuracy: 0.5054
# Epoch 125/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1610 - accuracy: 0.5042 - val_loss: 1.4366 - val_accuracy: 0.5054
# Epoch 126/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1657 - accuracy: 0.5042 - val_loss: 1.4270 - val_accuracy: 0.5054
# Epoch 127/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1656 - accuracy: 0.5042 - val_loss: 1.4343 - val_accuracy: 0.5054
# Epoch 128/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1611 - accuracy: 0.5042 - val_loss: 1.4688 - val_accuracy: 0.5054
# Epoch 129/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1674 - accuracy: 0.5042 - val_loss: 1.4418 - val_accuracy: 0.5054
# Epoch 130/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1596 - accuracy: 0.5042 - val_loss: 1.4526 - val_accuracy: 0.5054
# Epoch 131/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1709 - accuracy: 0.5042 - val_loss: 1.4559 - val_accuracy: 0.5054
# Epoch 132/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1604 - accuracy: 0.5042 - val_loss: 1.4980 - val_accuracy: 0.5054
# Epoch 133/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1625 - accuracy: 0.5042 - val_loss: 1.4851 - val_accuracy: 0.5054
# Epoch 134/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1641 - accuracy: 0.5042 - val_loss: 1.3896 - val_accuracy: 0.5054
# Epoch 135/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1648 - accuracy: 0.5042 - val_loss: 1.5015 - val_accuracy: 0.5054
# Epoch 136/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1620 - accuracy: 0.5042 - val_loss: 1.4557 - val_accuracy: 0.5054
# Epoch 137/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1576 - accuracy: 0.5042 - val_loss: 1.5024 - val_accuracy: 0.5054
# Epoch 138/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1578 - accuracy: 0.5042 - val_loss: 1.5311 - val_accuracy: 0.5054
# Epoch 139/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1626 - accuracy: 0.5042 - val_loss: 1.4551 - val_accuracy: 0.5054
# Epoch 140/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1586 - accuracy: 0.5042 - val_loss: 1.5177 - val_accuracy: 0.5054
# Epoch 141/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1663 - accuracy: 0.5042 - val_loss: 1.4837 - val_accuracy: 0.5054
# Epoch 142/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1685 - accuracy: 0.5042 - val_loss: 1.4419 - val_accuracy: 0.5054
# Epoch 143/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1622 - accuracy: 0.5042 - val_loss: 1.4909 - val_accuracy: 0.5054
# Epoch 144/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1598 - accuracy: 0.5042 - val_loss: 1.4880 - val_accuracy: 0.5054
# Epoch 145/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1592 - accuracy: 0.5042 - val_loss: 1.5358 - val_accuracy: 0.5054
# Epoch 146/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1610 - accuracy: 0.5042 - val_loss: 1.3542 - val_accuracy: 0.5054
# Epoch 147/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1538 - accuracy: 0.5042 - val_loss: 1.5326 - val_accuracy: 0.5054
# Epoch 148/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1538 - accuracy: 0.5042 - val_loss: 1.5014 - val_accuracy: 0.5054
# Epoch 149/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1491 - accuracy: 0.5042 - val_loss: 1.5023 - val_accuracy: 0.5054
# Epoch 150/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1526 - accuracy: 0.5042 - val_loss: 1.4880 - val_accuracy: 0.5054
# Epoch 151/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1516 - accuracy: 0.5042 - val_loss: 1.6046 - val_accuracy: 0.5054
# Epoch 152/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1495 - accuracy: 0.5042 - val_loss: 1.5531 - val_accuracy: 0.5054
# Epoch 153/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1491 - accuracy: 0.5042 - val_loss: 1.5286 - val_accuracy: 0.5054
# Epoch 154/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1517 - accuracy: 0.5042 - val_loss: 1.5171 - val_accuracy: 0.5054
# Epoch 155/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1617 - accuracy: 0.5042 - val_loss: 1.4340 - val_accuracy: 0.5054
# Epoch 156/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1567 - accuracy: 0.5042 - val_loss: 1.5219 - val_accuracy: 0.5054
# Epoch 157/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1495 - accuracy: 0.5042 - val_loss: 1.6282 - val_accuracy: 0.5054
# Epoch 158/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1536 - accuracy: 0.5042 - val_loss: 1.5810 - val_accuracy: 0.5054
# Epoch 159/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1438 - accuracy: 0.5042 - val_loss: 1.6320 - val_accuracy: 0.5054
# Epoch 160/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1516 - accuracy: 0.5042 - val_loss: 1.5270 - val_accuracy: 0.5054
# Epoch 161/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1630 - accuracy: 0.5042 - val_loss: 1.4178 - val_accuracy: 0.5054
# Epoch 162/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1485 - accuracy: 0.5042 - val_loss: 1.5545 - val_accuracy: 0.5054
# Epoch 163/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1539 - accuracy: 0.5042 - val_loss: 1.4951 - val_accuracy: 0.5054
# Epoch 164/200
# 1319/1319 [==============================] - 3s 3ms/step - loss: 0.1469 - accuracy: 0.5042 - val_loss: 1.4485 - val_accuracy: 0.5054
# Epoch 165/200
# 1319/1319 [==============================] - 4s 3ms/step - loss: 0.1557 - accuracy: 0.5042 - val_loss: 1.4536 - val_accuracy: 0.5054
# Epoch 166/200
# 1319/1319 [==============================] - 4s 3ms/step - loss: 0.1481 - accuracy: 0.5042 - val_loss: 1.4867 - val_accuracy: 0.5054
# Epoch 167/200
# 1319/1319 [==============================] - 3s 3ms/step - loss: 0.1429 - accuracy: 0.5042 - val_loss: 1.5076 - val_accuracy: 0.5054
# Epoch 168/200
# 1319/1319 [==============================] - 3s 3ms/step - loss: 0.1568 - accuracy: 0.5042 - val_loss: 1.3790 - val_accuracy: 0.5054
# Epoch 169/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1487 - accuracy: 0.5042 - val_loss: 1.5904 - val_accuracy: 0.5054
# Epoch 170/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1487 - accuracy: 0.5042 - val_loss: 1.5980 - val_accuracy: 0.5054
# Epoch 171/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1456 - accuracy: 0.5042 - val_loss: 1.5585 - val_accuracy: 0.5054
# Epoch 172/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1503 - accuracy: 0.5042 - val_loss: 1.5636 - val_accuracy: 0.5054
# Epoch 173/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1457 - accuracy: 0.5042 - val_loss: 1.5908 - val_accuracy: 0.5054
# Epoch 174/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1449 - accuracy: 0.5042 - val_loss: 1.5618 - val_accuracy: 0.5054
# Epoch 175/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1451 - accuracy: 0.5042 - val_loss: 1.5963 - val_accuracy: 0.5054
# Epoch 176/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1406 - accuracy: 0.5042 - val_loss: 1.6260 - val_accuracy: 0.5054
# Epoch 177/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1392 - accuracy: 0.5042 - val_loss: 1.6191 - val_accuracy: 0.5054
# Epoch 178/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1479 - accuracy: 0.5042 - val_loss: 1.5173 - val_accuracy: 0.5054
# Epoch 179/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1420 - accuracy: 0.5042 - val_loss: 1.6105 - val_accuracy: 0.5054
# Epoch 180/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1400 - accuracy: 0.5042 - val_loss: 1.5423 - val_accuracy: 0.5054
# Epoch 181/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1434 - accuracy: 0.5042 - val_loss: 1.6428 - val_accuracy: 0.5054
# Epoch 182/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1490 - accuracy: 0.5042 - val_loss: 1.5971 - val_accuracy: 0.5054
# Epoch 183/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1454 - accuracy: 0.5042 - val_loss: 1.4628 - val_accuracy: 0.5054
# Epoch 184/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1420 - accuracy: 0.5042 - val_loss: 1.6017 - val_accuracy: 0.5054
# Epoch 185/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1378 - accuracy: 0.5042 - val_loss: 1.5995 - val_accuracy: 0.5054
# Epoch 186/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1402 - accuracy: 0.5042 - val_loss: 1.6483 - val_accuracy: 0.5054
# Epoch 187/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1458 - accuracy: 0.5042 - val_loss: 1.5715 - val_accuracy: 0.5054
# Epoch 188/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1395 - accuracy: 0.5042 - val_loss: 1.5970 - val_accuracy: 0.5054
# Epoch 189/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1399 - accuracy: 0.5042 - val_loss: 1.6049 - val_accuracy: 0.5054
# Epoch 190/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1331 - accuracy: 0.5042 - val_loss: 1.7159 - val_accuracy: 0.5054
# Epoch 191/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1450 - accuracy: 0.5042 - val_loss: 1.5053 - val_accuracy: 0.5054
# Epoch 192/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1410 - accuracy: 0.5042 - val_loss: 1.6434 - val_accuracy: 0.5054
# Epoch 193/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1396 - accuracy: 0.5042 - val_loss: 1.5764 - val_accuracy: 0.5054
# Epoch 194/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1389 - accuracy: 0.5042 - val_loss: 1.6237 - val_accuracy: 0.5054
# Epoch 195/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1381 - accuracy: 0.5042 - val_loss: 1.5208 - val_accuracy: 0.5054
# Epoch 196/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1388 - accuracy: 0.5042 - val_loss: 1.4989 - val_accuracy: 0.5054
# Epoch 197/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1413 - accuracy: 0.5042 - val_loss: 1.5518 - val_accuracy: 0.5054
# Epoch 198/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1452 - accuracy: 0.5042 - val_loss: 1.5924 - val_accuracy: 0.5054
# Epoch 199/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1370 - accuracy: 0.5042 - val_loss: 1.5242 - val_accuracy: 0.5054
# Epoch 200/200
# 1319/1319 [==============================] - 3s 2ms/step - loss: 0.1348 - accuracy: 0.5042 - val_loss: 1.6181 - val_accuracy: 0.5054
# Fold 1, 200 epochs
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [13], in <cell line: 11>()
#       8 X = ordered_kmer_counts
#      10 print ("Cross valiation")
# ---> 11 do_cross_validation(X,y,EPOCHS)
#      12 print(datetime.now())
#
# Input In [12], in do_cross_validation(X, y, eps)
#      20 print("Fold %d, %d epochs"%(fold,eps))
#      22 pd.DataFrame(history.history).plot(figsize=(8,5))
# ---> 23 plt.grid(True)
#      24 plt.gca().set_ylim(0,1)
#      25 plt.show()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/_api/__init__.py:222, in caching_module_getattr.<locals>.__getattr__(name)
#     220 if name in props:
#     221     return props[name].__get__(instance)
# --> 222 raise AttributeError(
#     223     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'grid'

# %% [markdown]
# # to do
# Do train/valid split with respect to genes.
