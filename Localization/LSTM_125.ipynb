# %% [markdown]
# # LSTM
# Same as LSTM_124 but do a full run.

# %%
from datetime import datetime
print(datetime.now())
from platform import python_version
print('Python',python_version())
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt 
import sklearn   # pip install --upgrade scikit-learn
print('sklearn',sklearn.__version__)
# Out:
# 2022-12-13 13:35:49.647950
# Python 3.8.16
# sklearn 1.0.2

# %% [markdown]
# We prevously used sklearn.model_selection.ShuffleSplit
# Now we avoid it due to this note in the
# [documentation](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.ShuffleSplit.html):
# Note: contrary to other cross-validation strategies, random splits do not guarantee that all folds will be different, although this is still very likely for sizeable datasets.

# %%
import tensorflow as tf
dt='float32'
tf.keras.backend.set_floatx('float32')
tf.random.set_seed(42) 

from tensorflow import keras
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

from keras.models import Sequential
from keras.layers import Masking
from keras.layers import Embedding
from keras.layers import Bidirectional
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Dropout
from keras.losses import BinaryCrossentropy

K=4
RCELLS=16
EPOCHS=50
FOLDS=5      
EMBED_DIMEN = 4 # arbitrary hyperparameter
BREAK = False   # break after first fold
MINLEN=1000
MAXLEN=2000

# %%
try:
    from google.colab import drive
    IN_COLAB = True
    print('Running on CoLab')
    PATH='/content/drive/'
    drive.mount(PATH)
    DATA_DIR=PATH+'My Drive/data/Localization/TrainTest/'  # must end in "/"
except:
    IN_COLAB = False
    DATA_DIR = 'D:/Adjeroh/Localization/TrainTest/'   # Windows
    DATA_DIR = '/Users/jasonmiller/WVU/Localization/TrainTest/'    # Mac
print(DATA_DIR)
# Out:
# Running on CoLab
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /content/drive/My Drive/data/Localization/TrainTest/

# %%
GENES_FILE =    'CNRCI_coding_train_genes.csv'
RCI_FILE =      'CNRCI_coding_train_RCI.gc42.csv'
SEQUENCE_FILE = 'CNRCI_coding_train_transcripts.gc42.csv'
COUNTS_FILE=    'CNRCI_coding_train_counts.K4.gc42.csv'

# %%
def get_ordered_list():
    ordered_list = \
    ['A549',\
      'H1.hESC',\
      'HeLa.S3',\
      'HepG2',\
      'HT1080',\
      'HUVEC',\
      'MCF.7',\
      'NCI.H460',\
      'NHEK',\
      'SK.MEL.5',\
      'SK.N.DZ',\
      'SK.N.SH',\
      'GM12878',\
      'K562',\
      'IMR.90']
    return ordered_list
CELL_LINE_NUMBER=1
all_cell_lines = get_ordered_list()
cell_line_name = all_cell_lines[CELL_LINE_NUMBER]
print('Cell line for today:',CELL_LINE_NUMBER,'=',cell_line_name)
# Out:
# Cell line for today: 1 = H1.hESC

# %% [markdown]
# ## Data Load

# %%
print(datetime.now())
# labels
filepath = DATA_DIR+RCI_FILE
gene_to_rci = {}
with open (filepath,'r') as handle:
    header = None
    for row in handle:
        if header is None:
            header = row
        else:
            line = row.strip()
            fields = line.split(',')
            gene_id = fields[0]
            rci_val = fields[CELL_LINE_NUMBER+1]
            # Could implement Gudenas style threshold here
            if rci_val != "nan":
                gene_to_rci[gene_id] = float(rci_val)
print('Num RCI:', len(gene_to_rci.keys()))
print(list(gene_to_rci.items())[:3])
all_genes = list(gene_to_rci.keys())
# Out:
# 2022-12-13 13:35:53.098326
# Num RCI: 13000
# [('ENSG00000000003', 1.85734), ('ENSG00000000005', 5.88264), ('ENSG00000000419', 2.58954)]

# %%
KMER_VALUES=dict()   # drop this after to save RAM
def seq_to_kmer_values(rna,K):
    VALS = {'A':0, 'C':1, 'G':2, 'T':3}
    length = len(rna)
    vec=[]
    for i in range(length-K+1):
        kmer = rna[i:i+K]
        if 'N' in kmer:
            value = 0
        elif kmer in KMER_VALUES.keys():
            value = KMER_VALUES[kmer]
        else:
            value = 0
            for j in range(K):
                value *= 4   
                nextnuc = kmer[j] 
                nucval = VALS[nextnuc]
                value += nucval
            value += 1   # NNN => 0, AAA => 1
            KMER_VALUES[kmer] = value
        vec.append(value)
    return vec
print(seq_to_kmer_values('AAAA',3))
print(seq_to_kmer_values('CATT',3))
print(seq_to_kmer_values('TTGA',3))
print(seq_to_kmer_values('TTTN',3))
# Out:
# [1, 1]
# [20, 16]
# [63, 57]
# [64, 0]

# %%
print(datetime.now())
print('Load sequence')
filepath = DATA_DIR+SEQUENCE_FILE
labels=[]
allids=[]
allseq=[]
NREPEAT = str('N'*MAXLEN)
with open (filepath,'r') as handle:
    header = None
    for row in handle:
        if header is None:
            header = row
        else:
            line    = row.strip()
            fields  = line.split(',')
            tran_id = fields[0]  # with version number
            gene_id = fields[1]        # without version number
            seq_len = int(fields[3])
            seq_txt = fields[4]
            if seq_len>=MINLEN and seq_len<=MAXLEN and gene_id in gene_to_rci.keys():
                rci_val = gene_to_rci[gene_id]
                allids.append( (gene_id,tran_id) )
                labels.append(rci_val)
                if seq_len<MAXLEN:
                    seq_txt = seq_txt + NREPEAT
                    seq_txt = seq_txt[:MAXLEN]
                hot_vec = seq_to_kmer_values(seq_txt,K)
                allseq.append(hot_vec)
print(datetime.now())
KMER_VALUES=dict()   # drop this after to save RAM

print('Num IDs:',len(allids))
#print('Examples:',[allids[x] for x in [10, 20, 30, 40]] )
print('Num labels:',len(labels))
#print('Examples:',[labels[x] for x in [10, 20, 30, 40]] )
print('Num counts:',len(allseq))
#print('Example:',allseq[3])
# Out:
# 2022-12-13 13:36:43.976688
# Load sequence
# 2022-12-13 13:36:53.096861
# Num IDs: 13143
# Num labels: 13143
# Num counts: 13143

# %%
def get_gene_subset(all_genes,sub_index):
    sub_genes = set()
    for index in sub_index:
        one_gene = all_genes[index]
        sub_genes.add(one_gene)
    return sub_genes
def get_X_y(gene_set,allids,allX,allY,threshold):
    cnt = len(allids)
    subsetX=[]
    subsetY=[]
    if cnt != len(allX) or cnt!= len(allY):
        raise Exception('Lengths differ')
    for i in range(cnt):
        gene_id,tran_id = allids[i]
        if gene_id in gene_set:
            oneX = allX[i]
            oneY = allY[i]
            if oneY < threshold:
                Yvalue = int(0)
            else:
                Yvalue = int(1)
            subsetX.append(oneX)
            subsetY.append(Yvalue)
    subsetX = np.array(subsetX)
    subsetY = np.array(subsetY).reshape((-1,1))
    return subsetX,subsetY

# %%
def build_model():
    ALPHABET=4**K+1  # NUMBER OF DISTINCT KMERS POSSIBLE, add one if N gets mask value
    ADJUST_LENGTH = MAXLEN-K+1  # fixed length sequences
    rnn = Sequential()
    # To do: try with and without masking layer
    # To do: try the embedding layer with mask, instead of masking layer
    #mask_layer = Masking(mask_value=0, input_shape=(ADJUST_LENGTH, K))
    #mask_layer = Masking(mask_value=0, input_shape=(ADJUST_LENGTH, 1))
    # This layer automatically converts inputs to one-hot using alphabet size.
    embed_layer = Embedding(ALPHABET,EMBED_DIMEN,input_length=ADJUST_LENGTH,mask_zero=True)   
    # rnn1_layer = LSTM(16, return_sequences=True, input_shape=[MAXLEN,DIMEN]) 
    rnn1_layer = LSTM(RCELLS, return_sequences=False) # True)
    # rnn1_layer = Bidirectional( LSTM(32, return_sequences=True) )
    # rnn1_layer = LSTM(16, return_sequences=True) 
    # rnn2_layer = LSTM(16, return_sequences=True)
    # Dense can handle sequence input. Is it the best thing to do?
    #dense1_layer = Dense(16,activation='sigmoid',dtype=dt)
    #dropout1_layer = Dropout(0.25)
    output_layer = Dense(1,activation='sigmoid',dtype=dt)

    #rnn.add(mask_layer)
    rnn.add(embed_layer)
    rnn.add(rnn1_layer)
    #rnn.add(rnn2_layer)
    #rnn.add(dense1_layer)
    #rnn.add(dropout1_layer)
    #rnn.add(dense2_layer)
    rnn.add(output_layer)

    bc=BinaryCrossentropy(from_logits=False)
    print("COMPILE")
    rnn.compile(loss=bc, optimizer="Adam",metrics=["accuracy"])
    return rnn

# %%
print(datetime.now())
model=build_model()
print(model.summary())  # Print this only once
# Out:
# 2022-12-13 13:36:53.138927
# COMPILE
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_6 (Embedding)     (None, 1997, 4)           1028
#
#  lstm_6 (LSTM)               (None, 16)                1344
#
#  dense_6 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 2,389
# Trainable params: 2,389
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
def do_cross_validation(eps):
    cv_accuracy=[]
    cv_precision=[]
    cv_recall=[]
    cv_f1=[]
    fold=0
    print(datetime.now())
    print('splitting')
    # KFold shuffles once before making the partitions
    splitter = KFold(n_splits=FOLDS,shuffle=True,random_state=42)
    for train_index,valid_index in splitter.split(all_genes):
        fold += 1
        print('Fold',fold)
        train_genes = get_gene_subset(all_genes,train_index)
        valid_genes = get_gene_subset(all_genes,valid_index)
        X_train,y_train = get_X_y(train_genes,allids,allseq,labels,0)
        X_valid,y_valid = get_X_y(valid_genes,allids,allseq,labels,0)

        print('Training example')
        print(X_train[0])
        
        print('Train sizes',X_train.shape,y_train.shape)
        print('Valid sizes',X_valid.shape,y_valid.shape)
        print('Train set ones/size',
              np.count_nonzero(y_train),'/',len(y_train))
        print('Valid set ones/size',
              np.count_nonzero(y_valid),'/',len(y_valid))

        print("BUILD MODEL")
        model=build_model()

        print("FIT")
        print(datetime.now())
        history=model.fit(X_train, y_train, # batch_size=10, default=32 works nicely
                epochs=EPOCHS, verbose=1,  # verbose=1 for ascii art, verbose=0 for none
                validation_data=(X_valid,y_valid) )

        pd.DataFrame(history.history).plot(figsize=(8,5))
        plt.grid(True)
        plt.gca().set_ylim(0,1)
        plt.show()

        print("Compute valiation accuracy")
        print(datetime.now())
        yhat_pred=model.predict(X_valid, verbose=0) 
        print('Range of scores:',np.min(yhat_pred),'to',np.max(yhat_pred))
        THRESHOLD=0.5
        yhat_classes=np.where(yhat_pred > THRESHOLD, 1, 0)
        print('Predicted zeros and ones',np.count_nonzero(yhat_classes==0),np.count_nonzero(yhat_classes==1))
        # accuracy: (tp + tn) / (p + n)
        accuracy = accuracy_score(y_valid, yhat_classes)*100.
        # precision tp / (tp + fp)
        precision = precision_score(y_valid, yhat_classes)*100.
        # recall: tp / (tp + fn)
        recall = recall_score(y_valid, yhat_classes)*100.
        # f1: 2 tp / (2 tp + fp + fn)
        f1 = f1_score(y_valid, yhat_classes)*100.
        print('Accuracy: %.2f%% Precision: %.2f%% Recall: %.2f%% F1: %.2f%%' % (accuracy,precision,recall,f1)) 
        print(datetime.now())
        cv_accuracy.append(accuracy)
        cv_precision.append(precision)
        cv_recall.append(recall)
        cv_f1.append(f1)
        
        if BREAK:
            break
        
    print()
    return cv_accuracy, cv_precision, cv_recall, cv_f1

print(datetime.now())
# Out:
# 2022-12-13 13:36:54.022186

# %%
print(datetime.now())
cv_accuracy, cv_precision, cv_recall, cv_f1 = do_cross_validation(EPOCHS)   
print("Cross validation %d folds %d epochs" % (FOLDS,EPOCHS)) 
print(" accuracy mean %.2f%% +/- %.2f" % (np.mean(cv_accuracy), np.std(cv_accuracy)))
print(" precision mean %.2f%% +/- %.2f" % (np.mean(cv_precision), np.std(cv_precision)))
print(" recall mean %.2f%% +/- %.2f" % (np.mean(cv_recall), np.std(cv_recall)))
print(" F1 mean %.2f%% +/- %.2f" % (np.mean(cv_f1), np.std(cv_f1)))

print(datetime.now())
# Out:
# 2022-12-13 13:36:54.031330
# 2022-12-13 13:36:54.031928
# splitting
# Fold 1
# Training example
# [ 60 238 182 ...   0   0   0]
# Train sizes (10521, 1997) (10521, 1)
# Valid sizes (2622, 1997) (2622, 1)
# Train set ones/size 5687 / 10521
# Valid set ones/size 1362 / 2622
# BUILD MODEL
# COMPILE
# FIT
# 2022-12-13 13:36:56.348050
# Epoch 1/50
# 329/329 [==============================] - 24s 63ms/step - loss: 0.6692 - accuracy: 0.5846 - val_loss: 0.6651 - val_accuracy: 0.6251
# Epoch 2/50
# 329/329 [==============================] - 19s 59ms/step - loss: 0.6396 - accuracy: 0.6545 - val_loss: 0.6699 - val_accuracy: 0.6293
# Epoch 3/50
# 329/329 [==============================] - 19s 59ms/step - loss: 0.6386 - accuracy: 0.6471 - val_loss: 0.6675 - val_accuracy: 0.5980
# Epoch 4/50
# 329/329 [==============================] - 19s 59ms/step - loss: 0.6325 - accuracy: 0.6493 - val_loss: 0.6568 - val_accuracy: 0.6140
# Epoch 5/50
# 329/329 [==============================] - 19s 59ms/step - loss: 0.6343 - accuracy: 0.6493 - val_loss: 0.6732 - val_accuracy: 0.5778
# Epoch 6/50
# 329/329 [==============================] - 19s 59ms/step - loss: 0.6393 - accuracy: 0.6409 - val_loss: 0.6680 - val_accuracy: 0.6045
# Epoch 7/50
# 329/329 [==============================] - 19s 58ms/step - loss: 0.6225 - accuracy: 0.6594 - val_loss: 0.6528 - val_accuracy: 0.6358
# Epoch 8/50
# 329/329 [==============================] - 20s 59ms/step - loss: 0.6169 - accuracy: 0.6664 - val_loss: 0.6606 - val_accuracy: 0.6159
# 329/329 [==============================] - 20s 60ms/step - loss: 0.6093 - accuracy: 0.6730 - val_loss: 0.6983 - val_accuracy: 0.5275
# Epoch 48/50
# 329/329 [==============================] - 20s 60ms/step - loss: 0.6627 - accuracy: 0.6052 - val_loss: 0.7011 - val_accuracy: 0.5591
# Epoch 49/50
# 329/329 [==============================] - 20s 61ms/step - loss: 0.6441 - accuracy: 0.6334 - val_loss: 0.6695 - val_accuracy: 0.5938
# Epoch 50/50
# 329/329 [==============================] - 20s 60ms/step - loss: 0.6229 - accuracy: 0.6621 - val_loss: 0.7406 - val_accuracy: 0.5416
# Compute valiation accuracy
# 2022-12-13 13:53:30.926956
# Range of scores: 0.21545833 to 0.83382565
# Predicted zeros and ones 186 2436
# Accuracy: 54.16% Precision: 53.28% Recall: 95.30% F1: 68.35%
# 2022-12-13 13:53:34.193871
# Fold 2
# Training example
# [ 60 238 182 ...   0   0   0]
# Train sizes (10474, 1997) (10474, 1)
# Valid sizes (2669, 1997) (2669, 1)
# Train set ones/size 5545 / 10474
# Valid set ones/size 1504 / 2669
# BUILD MODEL
# COMPILE
# FIT
# 2022-12-13 13:53:36.891839
# Epoch 1/50
# 328/328 [==============================] - 25s 66ms/step - loss: 0.6882 - accuracy: 0.5469 - val_loss: 0.6781 - val_accuracy: 0.5639
# Epoch 2/50
# 328/328 [==============================] - 20s 61ms/step - loss: 0.6775 - accuracy: 0.5771 - val_loss: 0.6599 - val_accuracy: 0.6193
# Epoch 3/50
# 328/328 [==============================] - 20s 60ms/step - loss: 0.6547 - accuracy: 0.6140 - val_loss: 0.6401 - val_accuracy: 0.6332
# Epoch 4/50
# 328/328 [==============================] - 20s 60ms/step - loss: 0.6796 - accuracy: 0.5790 - val_loss: 0.7007 - val_accuracy: 0.4646
# Epoch 5/50
# 328/328 [==============================] - 20s 60ms/step - loss: 0.6587 - accuracy: 0.6103 - val_loss: 0.6413 - val_accuracy: 0.6332
# Epoch 6/50
# 328/328 [==============================] - 20s 60ms/step - loss: 0.6583 - accuracy: 0.6212 - val_loss: 0.6458 - val_accuracy: 0.6366
# Epoch 7/50
# 328/328 [==============================] - 20s 61ms/step - loss: 0.6580 - accuracy: 0.6155 - val_loss: 0.6548 - val_accuracy: 0.6186
# Epoch 8/50
# 328/328 [==============================] - 20s 62ms/step - loss: 0.6373 - accuracy: 0.6492 - val_loss: 0.6380 - val_accuracy: 0.6418
# Epoch 9/50
# 328/328 [==============================] - 20s 60ms/step - loss: 0.6347 - accuracy: 0.6541 - val_loss: 0.6363 - val_accuracy: 0.6549
# Epoch 10/50
# 328/328 [==============================] - 20s 60ms/step - loss: 0.6468 - accuracy: 0.6341 - val_loss: 0.6560 - val_accuracy: 0.6205
# Epoch 11/50
# 328/328 [==============================] - 20s 60ms/step - loss: 0.6544 - accuracy: 0.6206 - val_loss: 0.6506 - val_accuracy: 0.6250
# Epoch 12/50
# 328/328 [==============================] - 20s 60ms/step - loss: 0.6465 - accuracy: 0.6311 - val_loss: 0.6518 - val_accuracy: 0.6324
# Epoch 13/50
# 328/328 [==============================] - 20s 60ms/step - loss: 0.6404 - accuracy: 0.6418 - val_loss: 0.6464 - val_accuracy: 0.6381
# Epoch 14/50
# 328/328 [==============================] - 20s 62ms/step - loss: 0.6355 - accuracy: 0.6503 - val_loss: 0.6435 - val_accuracy: 0.6343
# Epoch 15/50
# 328/328 [==============================] - 20s 62ms/step - loss: 0.6333 - accuracy: 0.6514 - val_loss: 0.6549 - val_accuracy: 0.6145
# Epoch 16/50
# 328/328 [==============================] - 20s 60ms/step - loss: 0.6329 - accuracy: 0.6495 - val_loss: 0.6429 - val_accuracy: 0.6384
# Epoch 17/50
# 328/328 [==============================] - 20s 60ms/step - loss: 0.
50
# 328/328 [==============================] - 20s 60ms/step - loss: 0.6578 - accuracy: 0.6213 - val_loss: 0.6602 - val_accuracy: 0.6220
# Epoch 45/50
# 328/328 [==============================] - 21s 63ms/step - loss: 0.6551 - accuracy: 0.6178 - val_loss: 0.6748 - val_accuracy: 0.5807
# Epoch 46/50
# 328/328 [==============================] - 20s 60ms/step - loss: 0.6540 - accuracy: 0.6177 - val_loss: 0.6646 - val_accuracy: 0.5916
# Epoch 47/50
# 328/328 [==============================] - 20s 60ms/step - loss: 0.6417 - accuracy: 0.6364 - val_loss: 0.6513 - val_accuracy: 0.6081
# Epoch 48/50
# 328/328 [==============================] - 20s 61ms/step - loss: 0.6311 - accuracy: 0.6485 - val_loss: 0.6473 - val_accuracy: 0.6118
# Epoch 49/50
# 328/328 [==============================] - 20s 60ms/step - loss: 0.6312 - accuracy: 0.6551 - val_loss: 0.6531 - val_accuracy: 0.6145
# Epoch 50/50
# 328/328 [==============================] - 20s 61ms/step - loss: 0.6271 - accuracy: 0.6602 - val_loss: 0.6451 - val_accuracy: 0.6411
# Compute valiation accuracy
# 2022-12-13 14:10:16.354530
# Range of scores: 0.12927622 to 0.8659952
# Predicted zeros and ones 983 1686
# Accuracy: 64.11% Precision: 66.19% Recall: 74.20% F1: 69.97%
# 2022-12-13 14:10:19.932056
# Fold 3
# Training example
# [ 60 238 182 ...   0   0   0]
# Train sizes (10563, 1997) (10563, 1)
# Valid sizes (2580, 1997) (2580, 1)
# Train set ones/size 5740 / 10563
# Valid set ones/size 1309 / 2580
# BUILD MODEL
# COMPILE
# FIT
# 2022-12-13 14:10:22.211998
# Epoch 1/50
# 331/331 [==============================] - 25s 64ms/step - loss: 0.6664 - accuracy: 0.5913 - val_loss: 0.6561 - val_accuracy: 0.6473
# Epoch 2/50
# 331/331 [==============================] - 20s 59ms/step - loss: 0.6477 - accuracy: 0.6327 - val_loss: 0.6980 - val_accuracy: 0.4880
# Epoch 3/50
# 331/331 [==============================] - 20s 60ms/step - loss: 0.6661 - accuracy: 0.5948 - val_loss: 0.6480 - val_accuracy: 0.6453
# Epoch 4/50
# 331/331 [==============================] - 20s 61ms/step - loss: 0.6399 - accuracy: 0.6371 - val_loss: 0.6634 - val_accuracy: 0.6252
# Epoch 5/50
# 331/331 [==============================] - 21s 62ms/step - loss: 0.6698 - accuracy: 0.5947 - val_loss: 0.6726 - val_accuracy: 0.5922
# Epoch 6/50
# 331/331 [==============================] - 21s 62ms/step - loss: 0.6555 - accuracy: 0.6225 - val_loss: 0.6628 - val_accuracy: 0.6190
# Epoch 7/50
# 331/331 [==============================] - 20s 60ms/step - loss: 0.6523 - accuracy: 0.6240 - val_loss: 0.6770 - val_accuracy: 0.5605
# Epoch 8/50
# 331/331 [==============================] - 21s 64ms/step - loss: 0.6614 - accuracy: 0.6069 - val_loss: 0.6789 - val_accuracy: 0.5876
# Epoch 9/50
# 331/331 [==============================] - 20s 60ms/step - loss: 0.6576 - accuracy: 0.6131 - val_loss: 0.6662 - val_accuracy: 0.5984
# Epoch 10/50
# 331/331 [==============================] - 20s 61ms/step - loss: 0.6563 - accuracy: 0.6247 - val_loss: 0.6741 - val_accuracy: 0.5957
# Epoch 11/50
# 331/331 [==============================] - 20s 60ms/step - loss: 0.6472 - accuracy: 0.6310 - val_loss: 0.6710 - val_accuracy: 0.6147
# Epoch 12/50
# 331/331 [==============================] - 20s 61ms/step - loss: 0.6543 - accuracy: 0.6199 - val_loss: 0.6878 - val_accuracy: 0.5702
# 2022-12-13 14:27:12.105655
# Range of scores: 0.035391238 to 0.79601884
# Predicted zeros and ones 912 1668
# Accuracy: 60.04% Precision: 58.33% Recall: 74.33% F1: 65.37%
# 2022-12-13 14:27:15.713815
# Fold 4
# Training example
# [ 60 238 182 ...   0   0   0]
# Train sizes (10478, 1997) (10478, 1)
# Valid sizes (2665, 1997) (2665, 1)
# Train set ones/size 5659 / 10478
# Valid set ones/size 1390 / 2665
# BUILD MODEL
# COMPILE
# FIT
# 2022-12-13 14:27:18.011861
# Epoch 1/50
# 328/328 [==============================] - 25s 64ms/step - loss: 0.6650 - accuracy: 0.5921 - val_loss: 0.6473 - val_accuracy: 0.6368
# Epoch 2/50
# 328/328 [==============================] - 20s 61ms/step - loss: 0.6416 - accuracy: 0.6468 - val_loss: 0.6502 - val_accuracy: 0.6435
# Epoch 3/50
# 328/328 [==============================] - 20s 60ms/step - loss: 0.6329 - accuracy: 0.6548 - val_loss: 0.6518 - val_accuracy: 0.6188
# Epoch 4/50
# 328/328 [==============================] - 20s 60ms/step - loss: 0.6309 - accuracy: 0.6568 - val_loss: 0.6521 - val_accuracy: 0.6334
# Epoch 5/50
# 328/328 [==============================] - 20s 61ms/step - loss: 0.6616 - accuracy: 0.6050 - val_loss: 0.6482 - val_accuracy: 0.6345
# Epoch 6/50
# 328/328 [==============================] - 20s 60ms/step - loss: 0.6622 - accuracy: 0.6054 - val_loss: 0.6871 - val_accuracy: 0.5362
# Epoch 7/50
# 328/328 [==============================] - 20s 60ms/step - loss: 0.6657 - accuracy: 0.5988 - val_loss: 0.6729 - val_accuracy: 0.6255
# Epoch 8/50
# 328/328 [==============================] - 20s 61ms/step - loss: 0.6396 - accuracy: 0.6491 - val_loss: 0.7033 - val_accuracy: 0.4916
# Epoch 9/50
# 328/328 [==============================] - 20s 60ms/step - loss: 0.6358 - accuracy: 0.6457 - val_loss: 0.6398 - val_accuracy: 0.6364
# Epoch 10/50
# 328/328 [==============================] - 20s 61ms/step - loss: 0.6256 - accuracy: 0.6579 - val_loss: 0.6399 - val_accuracy: 0.6255
# Epoch 11/50
# 328/328 [==============================] - 20s 61ms/step - loss: 0.6231 - accuracy: 0.6667 - val_loss: 0.6448 - val_accuracy: 0.6492
# Epoch 12/50
# 328/328 [==============================] - 20s 61ms/step - loss: 0.6223 - accuracy: 0.6745 - val_loss: 0.6512 - val_accuracy: 0.6300
# Epoch 13/50
# 328/328 [==============================] - 20s 61ms/step - loss: 0.6194 - accuracy: 0.6744 - val_loss: 0.6442 - val_accuracy: 0.6420
# Epoch 14/50
# 328/328 [==============================] - 20s 61ms/step - loss: 0.6233 - accuracy: 0.6689 - val_loss: 0.6521 - val_accuracy: 0.6356
# Epoch 15/50
# 328/328 [==============================] - 21s 65ms/step - loss: 0.6274 - accuracy: 0.6633 - val_loss: 0.6452 - val_accuracy: 0.6443
# Epoch 16/50
# 328/328 [==============================] - 20s 61ms/step - loss: 0.6379 - accuracy: 0.6508 - val_loss: 0.6786 - val_accuracy: 0.5771
# Epoch 17/50
# 328/328 [==============================] - 20s 61ms/step - loss: 0.6353 - accuracy: 0.6459 - val_loss: 0.6554 - val_accuracy: 0.6210
# Epoch 18/50
# 328/328 [==============================] - 20s 61ms/step - loss: 0.6347 - accuracy: 0.6472 - val_loss: 0.6562 - val_accuracy: 0.6300
# Epoch 19/50
# 328/328 [==============================] - 20s 61ms/step - loss: 0.6573 - accuracy: 0.6130 - val_loss: 0.6589 - val_accuracy: 0.6240
# Epoch 20/50
# 328/328 [==============================] - 20s 61ms/step - loss: 0.6547 - accuracy: 0.6197 - val_loss: 0.6839 - val_accuracy: 0.5752
# Epoch 21/50
# 328/328 [==============================] - 20s 60ms/step - loss: 0.6558 - accuracy: 0.6155 - val_loss: 0.6795 - val_accuracy: 0.5940
# Epoch 22/50
# 328/328 [==============================] - 20s 61ms/step - loss: 0.6362 - accuracy: 0.6480 - val_loss: 0.6648 - val_accuracy: 0.6225
# Epoch 23/50
# 328/328 [==============================] - 20s 61ms/step - loss: 0.6318 - accuracy: 0.6594 - val_loss: 0.6686 - val_accuracy: 0.6131
# Epoch 24/50
# 328/328 [==============================] - 20s 61ms/step - loss: 0.6425 - accuracy: 0.6325 - val_loss: 0.6598 - val_accuracy: 0.6143
# Epoch 25/50
# 328/328 [==============================] - 20s 61ms/step - loss: 0.6321 - accuracy: 0.6433 - val_loss: 0.6577 - val_accuracy: 0.6188
# Epoch 26/50
# 328/328 [==============================] - 20s 61ms/step - loss: 0.6348 - accuracy: 0.6526 - val_loss: 0.6543 - val_accuracy: 0.6210
# Epoch 27/50
# 328/328 [==============================] - 20s 61ms/step - loss: 0.6236 - accuracy: 0.6599 - val_loss: 0.6537 - val_accuracy: 0.6477
# Epoch 28/50
# 328/328 [==============================] - 20s 61ms/step - loss: 0.6334 - accuracy: 0.6500 - val_loss: 0.6352 - val_accuracy: 0.6544
# Epoch 29/50
# 328/328 [==============================] - 20s 60ms/step - loss: 0.6173 - accuracy: 0.6694 - val_loss: 0.6450 - val_accuracy: 0.6255
# Epoch 30/50
# 328/328 [==============================] - 20s 61ms/step - loss: 0.6216 - accuracy: 0.6621 - val_loss: 0.6386 - val_accuracy: 0.6428
# Epoch 31/50
# 328/328 [==============================] - 21s 65ms/step - loss: 0.6218 - accuracy: 0.6678 - val_loss: 0.6494 - val_accuracy: 0.6420
# Epoch 32/50
# 328/328 [==============================] - 20s 61ms/step - loss: 0.6170 - accuracy: 0.6760 - val_loss: 0.6427 - val_accuracy: 0.6555
# Epoch 33/50
# 328/328 [==============================] - 20s 61ms/step - loss: 0.6169 - accuracy: 0.6725 - val_loss: 0.6438 - val_accuracy: 0.6465
# Epoch 34/50
# 328/328 [==============================] - 20s 61ms/step - loss: 0.6117 - accuracy: 0.6813 - val_loss: 0.6340 - val_accuracy: 0.6687
# Epoch 35/50
# 328/328 [==============================] - 20s 62ms/step - loss: 0.6053 - accuracy: 0.6860 - val_loss: 0.6423 - val_accuracy: 0.6503
# Epoch 36/50
# 328/328 [==============================] - 20s 62ms/step - loss: 0.5984 - accuracy: 0.6921 - val_loss: 0.6388 - val_accuracy: 0.6540
# Epoch 37/50
# 328/328 [==============================] - 21s 64ms/step - loss: 0.5956 - accuracy: 0.6908 - val_loss: 0.6223 - val_accuracy: 0.6630
# Epoch 38/50
# 328/328 [==============================] - 20s 62ms/step - loss: 0.5922 - accuracy: 0.6970 - val_loss: 0.6207 - val_accuracy: 0.6630
# Epoch 39/50
# 328/328 [==============================] - 20s 62ms/step - loss: 0.5915 - accuracy: 0.6963 - val_loss: 0.6141 - val_accuracy: 0.6694
# Epoch 40/50
# 328/328 [==============================] - 20s 61ms/step - loss: 0.6145 - accuracy: 0.6719 - val_loss: 0.7552 - val_accuracy: 0.5400
# Epoch 41/50
# 328/328 [==============================] - 20s 61ms/step - loss: 0.6648 - accuracy: 0.6076 - val_loss: 0.6951 - val_accuracy: 0.5561
# Epoch 42/50
# 328/328 [==============================] - 20s 61ms/step - loss: 0.6466 - accuracy: 0.6332 - val_loss: 0.6886 - val_accuracy: 0.5887
# Epoch 43/50
# 328/328 [==============================] - 20s 61ms/step - loss: 0.6379 - accuracy: 0.6457 - val_loss: 0.6720 - val_accuracy: 0.6049
# Epoch 44/50
# 328/328 [==============================] - 20s 61ms/step - loss: 0.6304 - accuracy: 0.6531 - val_loss: 0.6707 - val_accuracy: 0.5970
# Epoch 45/50
# 328/328 [==============================] - 20s 61ms/step - loss: 0.6477 - accuracy: 0.6287 - val_loss: 0.6946 - val_accuracy: 0.5482
# Epoch 46/50
# 328/328 [==============================] - 21s 65ms/step - loss: 0.6606 - accuracy: 0.6043 - val_loss: 0.6782 - val_accuracy: 0.5846
# Epoch 47/50
# 328/328 [==============================] - 20s 62ms/step - loss: 0.6474 - accuracy: 0.6257 - val_loss: 0.6855 - val_accuracy: 0.5685
# Epoch 48/50
# 328/328 [==============================] - 20s 61ms/step - loss: 0.6455 - accuracy: 0.6318 - val_loss: 0.6834 - val_accuracy: 0.5902
# Epoch 49/50
# 328/328 [==============================] - 20s 61ms/step - loss: 0.6536 - accuracy: 0.6154 - val_loss: 0.6877 - val_accuracy: 0.5636
# Epoch 50/50
# 328/328 [==============================] - 20s 61ms/step - loss: 0.6498 - accuracy: 0.6232 - val_loss: 0.6845 - val_accuracy: 0.5726
# Compute valiation accuracy
# 2022-12-13 14:44:07.212773
# Range of scores: 0.10707541 to 0.78791374
# Predicted zeros and ones 1042 1623
# Accuracy: 57.26% Precision: 57.73% Recall: 67.41% F1: 62.20%
# 2022-12-13 14:44:10.795579
# Fold 5
# Training example
# [169 161 129 ...   0   0   0]
# Train sizes (10536, 1997) (10536, 1)
# Valid sizes (2607, 1997) (2607, 1)
# Train set ones/size 5565 / 10536
# Valid set ones/size 1484 / 2607
# BUILD MODEL
# COMPILE
# FIT
# 2022-12-13 14:44:13.237354
# Epoch 1/50
# 330/330 [==============================] - 26s 65ms/step - loss: 0.6758 - accuracy: 0.5836 - val_loss: 0.6228 - val_accuracy: 0.6640
# Epoch 2/50
# 330/330 [==============================] - 20s 61ms/step - loss: 0.6479 - accuracy: 0.6318 - val_loss: 0.7349 - val_accuracy: 0.4802
# Epoch 3/50
# 330/330 [==============================] - 20s 61ms/step - loss: 0.6547 - accuracy: 0.6237 - val_loss: 0.6218 - val_accuracy: 0.6816
# Epoch 4/50
# 330/330 [==============================] - 20s 62ms/step - loss: 0.6598 - accuracy: 0.6085 - val_loss: 0.6947 - val_accuracy: 0.4749
# Epoch 5/50
# 330/330 [==============================] - 20s 62ms/step - loss: 0.6570 - accuracy: 0.6156 - val_loss: 0.6420 - val_accuracy: 0.6452
# Epoch 6/50
# 330/330 [==============================] - 21s 62ms/step - loss: 0.6540 - accuracy: 0.6248 - val_loss: 0.6226 - val_accuracy: 0.6724
# Epoch 7/50
# 330/330 [==============================] - 20s 62ms/step - loss: 0.6447 - accuracy: 0.6424 - val_loss: 0.6336 - val_accuracy: 0.6709
# Epoch 8/50
# 330/330 [==============================] - 20s 62ms/step - loss: 0.6390 - accuracy: 0.6433 - val_loss: 0.6231 - val_accuracy: 0.6647
# Epoch 9/50
# 330/330 [==============================] - 21s 62ms/step - loss: 0.6395 - accuracy: 0.6436 - val_loss: 0.6225 - val_accuracy: 0.6809
# Epoch 10/50
# 330/330 [==============================] - 20s 62ms/step - loss: 0.6441 - accuracy: 0.6300 - val_loss: 0.6723 - val_accuracy: 0.5643
# Epoch 11/50
# 330/330 [==============================] - 21s 64ms/step - loss: 0.6347 - accuracy: 0.6503 - val_loss: 0.6247 - val_accuracy: 0.6671
# Epoch 12/50
# 330/330 [==============================] - 22s 65ms/step - loss: 0.6315 - accuracy: 0.6532 - val_loss: 0.6172 - val_accuracy: 0.6897
# Epoch 13/50
# 330/330 [==============================] - 20s 61ms/step - loss: 0.6336 - accuracy: 0.6483 - val_loss: 0.6155 - val_accuracy: 0.6816
# Epoch 14/50
# 330/330 [==============================] - 20s 61ms/step - loss: 0.6407 - accuracy: 0.6379 - val_loss: 0.6546 - val_accuracy: 0.6256
# Epoch 15/50
# 330/330 [==============================] - 20s 61ms/step - loss: 0.6434 - accuracy: 0.6403 - val_loss: 0.6139 - val_accuracy: 0.6920
# Epoch 16/50
# 330/330 [==============================] - 20s 61ms/step - loss: 0.6338 - accuracy: 0.6486 - val_loss: 0.6185 - val_accuracy: 0.6763
# Epoch 17/50
# 330/330 [==============================] - 20s 61ms/step - loss: 0.6307 - accuracy: 0.6521 - val_loss: 0.6395 - val_accuracy: 0.6410
# Epoch 18/50
# 330/330 [==============================] - 20s 61ms/step - loss: 0.6459 - accuracy: 0.6288 - val_loss: 0.6342 - val_accuracy: 0.6694
# Epoch 19/50
# 330/330 [==============================] - 20s 61ms/step - loss: 0.6526 - accuracy: 0.6218 - val_loss: 0.6697 - val_accuracy: 0.6130
# Epoch 20/50
# 330/330 [==============================] - 20s 62ms/step - loss: 0.6533 - accuracy: 0.6234 - val_loss: 0.6255 - val_accuracy: 0.6763
# Epoch 21/50
# 330/330 [==============================] - 20s 61ms/step - loss: 0.6372 - accuracy: 0.6488 - val_loss: 0.6287 - val_accuracy: 0.6690
# Epoch 22/50
# 330/330 [==============================] - 20s 61ms/step - loss: 0.6349 - accuracy: 0.6477 - val_loss: 0.6238 - val_accuracy: 0.6924
# Epoch 23/50
# 330/330 [==============================] - 20s 61ms/step - loss: 0.6737 - accuracy: 0.5751 - val_loss: 0.6913 - val_accuracy: 0.5152
# Epoch 24/50
# 330/330 [==============================] - 20s 62ms/step - loss: 0.6712 - accuracy: 0.5925 - val_loss: 0.6759 - val_accuracy: 0.5838
# Epoch 25/50
# 330/330 [==============================] - 20s 62ms/step - loss: 0.6633 - accuracy: 0.6062 - val_loss: 0.6681 - val_accuracy: 0.6003
# Epoch 26/50
# 330/330 [==============================] - 20s 61ms/step - loss: 0.6576 - accuracy: 0.6141 - val_loss: 0.6605 - val_accuracy: 0.6087
# Epoch 27/50
# 330/330 [==============================] - 21s 65ms/step - loss: 0.6500 - accuracy: 0.6275 - val_loss: 0.6259 - val_accuracy: 0.6651
# Epoch 28/50
# 330/330 [==============================] - 20s 62ms/step - loss: 0.6351 - accuracy: 0.6395 - val_loss: 0.6468 - val_accuracy: 0.6226
# Epoch 29/50
# 330/330 [==============================] - 20s 61ms/step - loss: 0.6522 - accuracy: 0.6192 - val_loss: 0.6498 - val_accuracy: 0.6260
# Epoch 30/50
# 330/330 [==============================] - 20s 61ms/step - loss: 0.6373 - accuracy: 0.6439 - val_loss: 0.7388 - val_accuracy: 0.5182
# Epoch 31/50
# 330/330 [==============================] - 20s 62ms/step - loss: 0.6653 - accuracy: 0.6021 - val_loss: 0.6570 - val_accuracy: 0.6145
# Epoch 32/50
# 330/330 [==============================] - 20s 62ms/step - loss: 0.6307 - accuracy: 0.6503 - val_loss: 0.6193 - val_accuracy: 0.6671
# Epoch 33/50
# 330/330 [==============================] - 20s 62ms/step - loss: 0.6292 - accuracy: 0.6541 - val_loss: 0.6247 - val_accuracy: 0.6774
# Epoch 34/50
# 330/330 [==============================] - 20s 61ms/step - loss: 0.6278 - accuracy: 0.6538 - val_loss: 0.6246 - val_accuracy: 0.6763
# Epoch 35/50
# 330/330 [==============================] - 20s 61ms/step - loss: 0.6236 - accuracy: 0.6586 - val_loss: 0.6492 - val_accuracy: 0.6563
# Epoch 36/50
# 330/330 [==============================] - 20s 62ms/step - loss: 0.6342 - accuracy: 0.6465 - val_loss: 0.6353 - val_accuracy: 0.6663
# Epoch 37/50
# 330/330 [==============================] - 20s 62ms/step - loss: 0.6335 - accuracy: 0.6437 - val_loss: 0.6296 - val_accuracy: 0.6697
# Epoch 38/50
# 330/330 [==============================] - 20s 61ms/step - loss: 0.6408 - accuracy: 0.6296 - val_loss: 0.6404 - val_accuracy: 0.6371
# Epoch 39/50
# 330/330 [==============================] - 20s 61ms/step - loss: 0.6251 - accuracy: 0.6558 - val_loss: 0.6118 - val_accuracy: 0.6835
# Epoch 40/50
# 330/330 [==============================] - 20s 62ms/step - loss: 0.6419 - accuracy: 0.6372 - val_loss: 0.6620 - val_accuracy: 0.6118
# Epoch 41/50
# 330/330 [==============================] - 20s 61ms/step - loss: 0.6370 - accuracy: 0.6377 - val_loss: 0.6208 - val_accuracy: 0.6682
# Epoch 42/50
# 330/330 [==============================] - 20s 62ms/step - loss: 0.6238 - accuracy: 0.6521 - val_loss: 0.6250 - val_accuracy: 0.6582
# Epoch 43/50
# 330/330 [==============================] - 20s 61ms/step - loss: 0.6474 - accuracy: 0.6228 - val_loss: 0.6747 - val_accuracy: 0.5796
# Epoch 44/50
# 330/330 [==============================] - 21s 65ms/step - loss: 0.6501 - accuracy: 0.6240 - val_loss: 0.6551 - val_accuracy: 0.6157
# Epoch 45/50
# 330/330 [==============================] - 20s 61ms/step - loss: 0.6331 - accuracy: 0.6455 - val_loss: 0.6293 - val_accuracy: 0.6429
# Epoch 46/50
# 330/330 [==============================] - 20s 61ms/step - loss: 0.6687 - accuracy: 0.5896 - val_loss: 0.6784 - val_accuracy: 0.5781
# Epoch 47/50
# 330/330 [==============================] - 20s 62ms/step - loss: 0.6613 - accuracy: 0.6083 - val_loss: 0.6752 - val_accuracy: 0.5907
# Epoch 48/50
# 330/330 [==============================] - 20s 62ms/step - loss: 0.6578 - accuracy: 0.6102 - val_loss: 0.6736 - val_accuracy: 0.5953
# Epoch 49/50
# 330/330 [==============================] - 20s 62ms/step - loss: 0.6549 - accuracy: 0.6149 - val_loss: 0.6727 - val_accuracy: 0.5980
# Epoch 50/50
# 330/330 [==============================] - 20s 62ms/step - loss: 0.6494 - accuracy: 0.6218 - val_loss: 0.6587 - val_accuracy: 0.6180
# Compute valiation accuracy
# 2022-12-13 15:01:18.664553
# Range of scores: 0.22141308 to 0.8570904
# Predicted zeros and ones 1063 1544
# Accuracy: 61.80% Precision: 65.80% Recall: 68.46% F1: 67.11%
# 2022-12-13 15:01:22.267359
#
# Cross validation 5 folds 50 epochs
#  accuracy mean 59.47% +/- 3.47
#  precision mean 60.27% +/- 4.99
#  recall mean 75.94% +/- 10.09
#  F1 mean 66.60% +/- 2.67
# 2022-12-13 15:01:22.269372
