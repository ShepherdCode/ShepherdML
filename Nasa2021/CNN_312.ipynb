# %% [markdown]
# # CNN 312
# Rather than partition train/validation sets, use different sets.
# Cut train set down to random LIMIT number of transcripts.
# Use all of the validation set.
# Use fit(shuffle) on the train set.
#
# TO DO:
# Save five best models to same directory to make it easy to delete.

# %%
TRAIN_NC_FILENAME='ncRNA.gc36.all.fasta'
TRAIN_PC_FILENAME='pcRNA.gc36.all.fasta'
VALID_NC_FILENAME='ncRNA.gc36.long.fasta'
VALID_PC_FILENAME='pcRNA.gc36.long.fasta'
#NC_FILENAME='ncRNA.tiny50.fasta'
#PC_FILENAME='pcRNA.tiny50.fasta'
#NC_FILENAME='ncRNA.gc34.processed.fasta'
#PC_FILENAME='pcRNA.gc34.processed.fasta'

MODEL_FILE='JUNK2'  # change this if you want to keep models
DATAPATH=''

try:
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
except:
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"
TRAIN_NC_FILENAME = DATAPATH+TRAIN_NC_FILENAME
TRAIN_PC_FILENAME = DATAPATH+TRAIN_PC_FILENAME
VALID_NC_FILENAME = DATAPATH+VALID_NC_FILENAME
VALID_PC_FILENAME = DATAPATH+VALID_PC_FILENAME
MODEL_FILE=DATAPATH+MODEL_FILE

EPOCHS=200
SPLITS=5
K=1
VOCABULARY_SIZE=4**K+1   # e.g. K=3 => 64 DNA K-mers + 'NNN'
EMBED_DIMEN=2
FILTERS=32
KERNEL=3
NEURONS=32
DROP=0.25
ACT="tanh"
MINLEN=201
MAXLEN=2000
LIMIT=5588    # This is the size of our smallest set (protein coding short)
# Out:
# Mounted at /content/drive/

# %%
# Load our own tools
# TO DO: don't go to GitHub if the file is already local.
GITHUB = True
if GITHUB:
    #!pip install requests  # Uncomment this if necessary. Seems to be pre-installed.
    import requests
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/ShepherdML/master/Strings/tools_fasta.py')
    with open('tools_fasta.py', 'w') as f:
        f.write(r.text)
    # TO DO: delete the file after import
import tools_fasta as tools
tools.yahoo()  # If this prints "Yahoo!" the the import was successful.

TOOLS_CHANGED = False   # set to True to re-run with a new version of tools
if TOOLS_CHANGED:
  from importlib import reload 
  tools=reload(tools)
  print(dir(tools))   # run this to see EVERYTHING in the tools module
# Out:
# Yahoo!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import StratifiedKFold
import tensorflow as tf
from tensorflow import keras
import time
dt='float32'
tf.keras.backend.set_floatx(dt)

# %% [markdown]
# Build model

# %%
def compile_model(model):
    ## learn rate = initial_learning_rate * decay_rate ^ (step / decay_steps)
    #adam_default_learn_rate = 0.001
    #schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    #    initial_learning_rate = adam_default_learn_rate*10,
    #    decay_steps=10000, decay_rate=0.99, staircase=True)
    #alrd = tf.keras.optimizers.Adam(learning_rate=schedule)
    #model.compile(loss=bc, optimizer=alrd, metrics=["accuracy"])

    print("COMPILE...")
    bc=tf.keras.losses.BinaryCrossentropy(from_logits=False)
    model.compile(loss=bc, optimizer="adam", metrics=["accuracy"])
    print("...COMPILED")
    return model

def build_model():
    SHAPE=(MAXLEN,5)  # MAXLEN bases = time steps, 5 features = one hots
    clayer1 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same",
                                 input_shape=SHAPE)
    clayer2 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer3 = keras.layers.MaxPooling1D(2)
    clayer4 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer5 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer6 = keras.layers.MaxPooling1D(2)
    clayer7 = keras.layers.Flatten()

    dlayer1 = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt, input_shape=[1000])
    dlayer2 = keras.layers.Dropout(DROP)
    dlayer3 = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt)
    dlayer4 = keras.layers.Dropout(DROP)
    output_layer = keras.layers.Dense(1, activation="sigmoid", dtype=dt)

    cnn = keras.models.Sequential()
    cnn.add(clayer1)
    cnn.add(clayer2)
    cnn.add(clayer3)
    cnn.add(clayer4)
    cnn.add(clayer5)
    cnn.add(clayer6)
    cnn.add(clayer7)
    cnn.add(dlayer1)
    cnn.add(dlayer2)
    cnn.add(dlayer3)
    cnn.add(dlayer4)
    cnn.add(output_layer)
    mlpc = compile_model(cnn)
    return mlpc

# %% [markdown]
# Cross validation

# %%
def do_cross_validation(X_train,y_train,given_model,X_valid,y_valid):
    cv_scores = []
    fold=0
    # When not using ShuffleSplit, make sure to randomize train data.
    #splitter = ShuffleSplit(n_splits=SPLITS, test_size=0.1, random_state=37863)
    #for train_index,valid_index in splitter.split(X):
    while fold < SPLITS:
        fold += 1
        # Avoid continually improving the same model.
        model = compile_model(keras.models.clone_model(given_model))
        bestname=MODEL_FILE+".cv."+str(fold)+".best"
        es = keras.callbacks.EarlyStopping(monitor='val_loss',  
            patience=10, verbose=1)
        mc = keras.callbacks.ModelCheckpoint(
            filepath=bestname, save_best_only=True, 
            monitor='val_accuracy', mode='max')  
        mycallbacks = [es,mc]  
        print("FIT")
        start_time=time.time()
        history=model.fit(X_train, y_train, # batch_size=10, default=32 works nicely
                epochs=EPOCHS, verbose=1,  # verbose=1 for ascii art, verbose=0 for none
                callbacks=mycallbacks, shuffle=True,
                validation_data=(X_valid,y_valid) )
        end_time=time.time()
        elapsed_time=(end_time-start_time)                        
        print("Fold %d, %d epochs, %d sec"%(fold,EPOCHS,elapsed_time))
        pd.DataFrame(history.history).plot(figsize=(8,5))
        plt.grid(True)
        plt.gca().set_ylim(0,1)
        plt.show()
        best_model=keras.models.load_model(bestname)
        scores = best_model.evaluate(X_valid, y_valid, verbose=0)
        print("%s: %.2f%%" % (best_model.metrics_names[1], scores[1]*100))
        cv_scores.append(scores[1] * 100)  

    print()
    print("%d-way Cross Validation max %.2f%%, mean %.2f%% (+/- %.2f%%)" % 
          (fold, np.amax(cv_scores), np.mean(cv_scores), np.std(cv_scores)))

# %% [markdown]
# ## Train on RNA lengths 200-1Kb

# %%
print ("Compile the model")
model=build_model()
print ("Summarize the model")
print(model.summary())  # Print this only once
#model.save(MODEL_FILE+'.model')
# Out:
# Compile the model
# COMPILE...
# ...COMPILED
# Summarize the model
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 2000, 32)          512
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 2000, 32)          3104
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 1000, 32)          0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 1000, 32)          3104
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 1000, 32)          3104
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 500, 32)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 16000)             0
# _________________________________________________________________
# dense (Dense)                (None, 32)                512032
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 522,945
# Trainable params: 522,945
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
def load_data(nc_filename,pc_filename,limit=None):
  nc_seq=tools.load_fasta(nc_filename,0)
  pc_seq=tools.load_fasta(pc_filename,1)
  if limit is not None:
    # Choose a random subset of size = limit.
    # Side effect: randomizes the data order.
    nfrac=1.0*limit/len(nc_seq)
    pfrac=1.0*limit/len(pc_seq)
    if nfrac<1.0:
      nc_seq=nc_seq.sample(frac=nfrac)
    if pfrac<1.0:
      pc_seq=pc_seq.sample(frac=pfrac)
  train_set=pd.concat((nc_seq,pc_seq),axis=0)
  # May not need to slice by length if input files already sliced
  subset=tools.make_slice(train_set,MINLEN,MAXLEN)
  # randset=subset.sample(frac=1) # unneccessary with fit(shuffle)
  (X1,y1)=tools.separate_X_and_y(subset)
  # X1 is pandas df of ("list" of one sequence)
  X2=X1.to_numpy()  # numpy ndarray of ("list" of one sequence)
  X3=[elem[0] for elem in X2]  # numpy dnarray of str
  X4=tools.uniform_length(X3,MAXLEN)
  X5= [tools.one_hot(x) for x in X4]
  X6=np.asarray(X5)
  y6=y1.to_numpy()
  return X6,y6

print("Load train data from files.")
X_train,y_train = load_data(TRAIN_NC_FILENAME,TRAIN_PC_FILENAME,LIMIT)
print("X_train",X_train.shape)
print("Load valid data from files.")
X_valid,y_valid = load_data(VALID_NC_FILENAME,VALID_PC_FILENAME)
print("X_valid",X_valid.shape)
# Out:
# Load train data from files.
# X_train (11176, 2000, 5)
# Load valid data from files.
# X_valid (18224, 2000, 5)

# %%
print ("Cross valiation")
do_cross_validation(X_train,y_train,model,X_valid,y_valid)  
print ("Done")
# Out:
# Cross valiation
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/200
# 350/350 [==============================] - 9s 13ms/step - loss: 0.6875 - accuracy: 0.6061 - val_loss: 0.7552 - val_accuracy: 0.6030
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.1.best/assets
# Epoch 2/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.6072 - accuracy: 0.6827 - val_loss: 0.6366 - val_accuracy: 0.6321
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.1.best/assets
# Epoch 3/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.6255 - accuracy: 0.6518 - val_loss: 0.7384 - val_accuracy: 0.5920
# Epoch 4/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5934 - accuracy: 0.6916 - val_loss: 0.5623 - val_accuracy: 0.7249
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.1.best/assets
# Epoch 5/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0
200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5875 - accuracy: 0.6932 - val_loss: 0.5384 - val_accuracy: 0.7526
# Epoch 6/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5803 - accuracy: 0.7087 - val_loss: 0.5398 - val_accuracy: 0.7401
# Epoch 7/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5709 - accuracy: 0.7080 - val_loss: 0.5885 - val_accuracy: 0.7160
# Epoch 8/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5779 - accuracy: 0.7116 - val_loss: 0.5522 - val_accuracy: 0.7287
# Epoch 9/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5807 - accuracy: 0.7054 - val_loss: 0.5325 - val_accuracy: 0.7400
# Epoch 10/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5626 - accuracy: 0.7196 - val_loss: 0.6043 - val_accuracy: 0.7009
# Epoch 11/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5569 - accuracy: 0.7327 - val_loss: 0.5793 - val_accuracy: 0.7175
# Epoch 12/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5361 - accuracy: 0.7405 - val_loss: 0.5553 - val_accuracy: 0.7334
# Epoch 00012: early stopping
# Fold 4, 200 epochs, 52 sec
# accuracy: 75.77%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/200
# 350/350 [==============================] - 5s 13ms/step - loss: 0.7039 - accuracy: 0.5766 - val_loss: 0.5843 - val_accuracy: 0.7312
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.5.best/assets
# Epoch 2/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.6283 - accuracy: 0.6631 - val_loss: 0.6894 - val_accuracy: 0.5014
# Epoch 3/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.6602 - accuracy: 0.6157 - val_loss: 0.5910 - val_accuracy: 0.6902
# Epoch 4/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.6238 - accuracy: 0.6637 - val_loss: 0.6545 - val_accuracy: 0.6327
# Epoch 5/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.6214 - accuracy: 0.6642 - val_loss: 0.6140 - val_accuracy: 0.6979
# Epoch 6/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.6115 - accuracy: 0.6740 - val_loss: 0.6157 - val_accuracy: 0.6612
# Epoch 7/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.6027 - accuracy: 0.6864 - val_loss: 0.6262 - val_accuracy: 0.6923
# Epoch 8/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.6115 - accuracy: 0.6756 - val_loss: 0.6302 - val_accuracy: 0.6304
# Epoch 9/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.6051 - accuracy: 0.6758 - val_loss: 0.5725 - val_accuracy: 0.7467
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.5.best/assets
# Epoch 10/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.6195 - accuracy: 0.6564 - val_loss: 0.5848 - val_accuracy: 0.6612
# Epoch 11/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5873 - accuracy: 0.6905 - val_loss: 0.6523 - val_accuracy: 0.6367
# Epoch 12/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5884 - accuracy: 0.6798 - val_loss: 0.6025 - val_accuracy: 0.7373
# Epoch 13/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5875 - accuracy: 0.7006 - val_loss: 0.5725 - val_accuracy: 0.7243
# Epoch 14/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5959 - accuracy: 0.6888 - val_loss: 0.6942 - val_accuracy: 0.5730
# Epoch 15/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5818 - accuracy: 0.7024 - val_loss: 0.5916 - val_accuracy: 0.6875
# Epoch 16/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5900 - accuracy: 0.6945 - val_loss: 0.5641 - val_accuracy: 0.7081
# Epoch 17/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5827 - accuracy: 0.6981 - val_loss: 0.5821 - val_accuracy: 0.7154
# Epoch 18/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5868 - accuracy: 0.6922 - val_loss: 0.5755 - val_accuracy: 0.7006
# Epoch 19/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5805 - accuracy: 0.7011 - val_loss: 0.5549 - val_accuracy: 0.7185
# Epoch 20/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5799 - accuracy: 0.7040 - val_loss: 0.5863 - val_accuracy: 0.7173
# Epoch 21/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5884 - accuracy: 0.6923 - val_loss: 0.5652 - val_accuracy: 0.7291
# Epoch 22/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.5916 - accuracy: 0.6969 - val_loss: 0.5307 - val_accuracy: 0.7655
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.5.best/assets
# Epoch 23/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.5951 - accuracy: 0.6845 - val_loss: 0.6030 - val_accuracy: 0.6639
# Epoch 24/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5909 - accuracy: 0.6891 - val_loss: 0.5575 - val_accuracy: 0.7589
# Epoch 25/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5879 - accuracy: 0.6866 - val_loss: 0.5376 - val_accuracy: 0.7225
# Epoch 26/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5824 - accuracy: 0.6966 - val_loss: 0.5322 - val_accuracy: 0.7582
# Epoch 27/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.5809 - accuracy: 0.6930 - val_loss: 0.5293 - val_accuracy: 0.7664
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.5.best/assets
# Epoch 28/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5921 - accuracy: 0.6851 - val_loss: 0.5578 - val_accuracy: 0.7133
# Epoch 29/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5733 - accuracy: 0.7160 - val_loss: 0.5860 - val_accuracy: 0.6899
# Epoch 30/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5874 - accuracy: 0.6941 - val_loss: 0.5794 - val_accuracy: 0.7014
# Epoch 31/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5586 - accuracy: 0.7161 - val_loss: 0.5637 - val_accuracy: 0.7272
# Epoch 32/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5666 - accuracy: 0.7116 - val_loss: 0.5899 - val_accuracy: 0.6967
# Epoch 33/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.6086 - accuracy: 0.6758 - val_loss: 0.5497 - val_accuracy: 0.7322
# Epoch 34/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5921 - accuracy: 0.6876 - val_loss: 0.5171 - val_accuracy: 0.7597
# Epoch 35/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5838 - accuracy: 0.7009 - val_loss: 0.5326 - val_accuracy: 0.7559
# Epoch 36/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5821 - accuracy: 0.7039 - val_loss: 0.5794 - val_accuracy: 0.7114
# Epoch 37/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5723 - accuracy: 0.7099 - val_loss: 0.6277 - val_accuracy: 0.6774
# Epoch 38/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5653 - accuracy: 0.7122 - val_loss: 0.5207 - val_accuracy: 0.7693
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.5.best/assets
# Epoch 39/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5934 - accuracy: 0.6907 - val_loss: 0.5711 - val_accuracy: 0.7373
# Epoch 40/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5947 - accuracy: 0.6886 - val_loss: 0.5603 - val_accuracy: 0.7387
# Epoch 41/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.5914 - accuracy: 0.6951 - val_loss: 0.6110 - val_accuracy: 0.6647
# Epoch 42/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.6071 - accuracy: 0.6784 - val_loss: 0.5996 - val_accuracy: 0.7127
# Epoch 43/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.6126 - accuracy: 0.6682 - val_loss: 0.5763 - val_accuracy: 0.7253
# Epoch 44/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5994 - accuracy: 0.6875 - val_loss: 0.5698 - val_accuracy: 0.7255
# Epoch 00044: early stopping
# Fold 5, 200 epochs, 184 sec
# accuracy: 76.93%
#
# 5-way Cross Validation max 86.36%, mean 82.33% (+/- 4.90%)
# Done
