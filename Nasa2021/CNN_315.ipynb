# %% [markdown]
# # CNN 315
# Rather than partition train/validation sets, use different sets.
# Cut train set down to random LIMIT number of transcripts.
# Use all of the validation set.
# Use fit(shuffle) on the train set.
#
# TO DO:
# Save five best models to same directory to make it easy to delete.

# %%
TRAIN_NC_FILENAME='ncRNA.gc36.short.fasta'
TRAIN_PC_FILENAME='pcRNA.gc36.short.fasta'
VALID_NC_FILENAME='ncRNA.gc36.long.fasta'
VALID_PC_FILENAME='pcRNA.gc36.long.fasta'
#NC_FILENAME='ncRNA.tiny50.fasta'
#PC_FILENAME='pcRNA.tiny50.fasta'
#NC_FILENAME='ncRNA.gc34.processed.fasta'
#PC_FILENAME='pcRNA.gc34.processed.fasta'

MODEL_FILE='JUNK1'  # change this if you want to keep models
DATAPATH=''

try:
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
except:
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"
TRAIN_NC_FILENAME = DATAPATH+TRAIN_NC_FILENAME
TRAIN_PC_FILENAME = DATAPATH+TRAIN_PC_FILENAME
VALID_NC_FILENAME = DATAPATH+VALID_NC_FILENAME
VALID_PC_FILENAME = DATAPATH+VALID_PC_FILENAME
MODEL_FILE=DATAPATH+MODEL_FILE

EPOCHS=200
SPLITS=5
K=1
VOCABULARY_SIZE=4**K+1   # e.g. K=3 => 64 DNA K-mers + 'NNN'
EMBED_DIMEN=2
FILTERS=32
KERNEL=3
NEURONS=32
DROP=0.25
ACT="tanh"
MINLEN=201
MAXLEN=2000
LIMIT=5588    # This is the size of our smallest set (protein coding short)
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# Load our own tools
# TO DO: don't go to GitHub if the file is already local.
GITHUB = True
if GITHUB:
    #!pip install requests  # Uncomment this if necessary. Seems to be pre-installed.
    import requests
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/ShepherdML/master/Strings/tools_fasta.py')
    with open('tools_fasta.py', 'w') as f:
        f.write(r.text)
    # TO DO: delete the file after import
import tools_fasta as tools
tools.yahoo()  # If this prints "Yahoo!" the the import was successful.

TOOLS_CHANGED = False   # set to True to re-run with a new version of tools
if TOOLS_CHANGED:
  from importlib import reload 
  tools=reload(tools)
  print(dir(tools))   # run this to see EVERYTHING in the tools module
# Out:
# Yahoo!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import StratifiedKFold
import tensorflow as tf
from tensorflow import keras
import time
dt='float32'
tf.keras.backend.set_floatx(dt)

# %% [markdown]
# Build model

# %%
def compile_model(model):
    ## learn rate = initial_learning_rate * decay_rate ^ (step / decay_steps)
    #adam_default_learn_rate = 0.001
    #schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    #    initial_learning_rate = adam_default_learn_rate*10,
    #    decay_steps=10000, decay_rate=0.99, staircase=True)
    #alrd = tf.keras.optimizers.Adam(learning_rate=schedule)
    #model.compile(loss=bc, optimizer=alrd, metrics=["accuracy"])

    print("COMPILE...")
    bc=tf.keras.losses.BinaryCrossentropy(from_logits=False)
    model.compile(loss=bc, optimizer="adam", metrics=["accuracy"])
    print("...COMPILED")
    return model

def build_model():
    SHAPE=(MAXLEN,5)  # MAXLEN bases = time steps, 5 features = one hots
    clayer1 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same",
                                 input_shape=SHAPE)
    clayer2 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer3 = keras.layers.MaxPooling1D(2)
    clayer4 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer5 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer6 = keras.layers.MaxPooling1D(2)
    clayer7 = keras.layers.Flatten()

    dlayer1 = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt, input_shape=[1000])
    dlayer2 = keras.layers.Dropout(DROP)
    dlayer3 = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt)
    dlayer4 = keras.layers.Dropout(DROP)
    output_layer = keras.layers.Dense(1, activation="sigmoid", dtype=dt)

    cnn = keras.models.Sequential()
    cnn.add(clayer1)
    cnn.add(clayer2)
    cnn.add(clayer3)
    cnn.add(clayer4)
    cnn.add(clayer5)
    cnn.add(clayer6)
    cnn.add(clayer7)
    cnn.add(dlayer1)
    cnn.add(dlayer2)
    cnn.add(dlayer3)
    cnn.add(dlayer4)
    cnn.add(output_layer)
    mlpc = compile_model(cnn)
    return mlpc

# %% [markdown]
# Cross validation

# %%
def do_cross_validation(X_train,y_train,given_model,X_valid,y_valid):
    cv_scores = []
    fold=0
    # When not using ShuffleSplit, make sure to randomize train data.
    #splitter = ShuffleSplit(n_splits=SPLITS, test_size=0.1, random_state=37863)
    #for train_index,valid_index in splitter.split(X):
    while fold < SPLITS:
        fold += 1
        # Avoid continually improving the same model.
        model = compile_model(keras.models.clone_model(given_model))
        bestname=MODEL_FILE+".cv."+str(fold)+".best"
        es = keras.callbacks.EarlyStopping(monitor='val_loss',  
            patience=10, verbose=1)
        mc = keras.callbacks.ModelCheckpoint(
            filepath=bestname, save_best_only=True, 
            monitor='val_accuracy', mode='max')  
        mycallbacks = [es,mc]  
        print("FIT")
        start_time=time.time()
        history=model.fit(X_train, y_train, # batch_size=10, default=32 works nicely
                epochs=EPOCHS, verbose=1,  # verbose=1 for ascii art, verbose=0 for none
                callbacks=mycallbacks, shuffle=True,
                validation_data=(X_valid,y_valid) )
        end_time=time.time()
        elapsed_time=(end_time-start_time)                        
        print("Fold %d, %d epochs, %d sec"%(fold,EPOCHS,elapsed_time))
        pd.DataFrame(history.history).plot(figsize=(8,5))
        plt.grid(True)
        plt.gca().set_ylim(0,1)
        plt.show()
        best_model=keras.models.load_model(bestname)
        scores = best_model.evaluate(X_valid, y_valid, verbose=0)
        print("%s: %.2f%%" % (best_model.metrics_names[1], scores[1]*100))
        cv_scores.append(scores[1] * 100)  

    print()
    print("%d-way Cross Validation max %.2f%%, mean %.2f%% (+/- %.2f%%)" % 
          (fold, np.amax(cv_scores), np.mean(cv_scores), np.std(cv_scores)))

# %% [markdown]
# ## Train on RNA lengths 200-1Kb

# %%
print ("Compile the model")
model=build_model()
print ("Summarize the model")
print(model.summary())  # Print this only once
#model.save(MODEL_FILE+'.model')
# Out:
# Compile the model
# COMPILE...
# ...COMPILED
# Summarize the model
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_8 (Conv1D)            (None, 2000, 32)          512
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 2000, 32)          3104
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 1000, 32)          0
# _________________________________________________________________
# conv1d_10 (Conv1D)           (None, 1000, 32)          3104
# _________________________________________________________________
# conv1d_11 (Conv1D)           (None, 1000, 32)          3104
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 500, 32)           0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 16000)             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                512032
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 522,945
# Trainable params: 522,945
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
def load_data(nc_filename,pc_filename,limit=None):
  nc_seq=tools.load_fasta(nc_filename,0)
  pc_seq=tools.load_fasta(pc_filename,1)
  if limit is not None:
    # Choose a random subset of size = limit.
    # Side effect: randomizes the data order.
    nfrac=1.0*limit/len(nc_seq)
    pfrac=1.0*limit/len(pc_seq)
    if nfrac<1.0:
      nc_seq=nc_seq.sample(frac=nfrac)
    if pfrac<1.0:
      pc_seq=pc_seq.sample(frac=pfrac)
  train_set=pd.concat((nc_seq,pc_seq),axis=0)
  # May not need to slice by length if input files already sliced
  subset=tools.make_slice(train_set,MINLEN,MAXLEN)
  # randset=subset.sample(frac=1) # unneccessary with fit(shuffle)
  (X1,y1)=tools.separate_X_and_y(subset)
  # X1 is pandas df of ("list" of one sequence)
  X2=X1.to_numpy()  # numpy ndarray of ("list" of one sequence)
  X3=[elem[0] for elem in X2]  # numpy dnarray of str
  X4=tools.uniform_length(X3,MAXLEN)
  X5= [tools.one_hot(x) for x in X4]
  X6=np.asarray(X5)
  y6=y1.to_numpy()
  return X6,y6

print("Load train data from files.")
X_train,y_train = load_data(TRAIN_NC_FILENAME,TRAIN_PC_FILENAME,LIMIT)
print("X_train",X_train.shape)
print("Load valid data from files.")
X_valid,y_valid = load_data(VALID_NC_FILENAME,VALID_PC_FILENAME)
print("X_valid",X_valid.shape)
# Out:
# Load train data from files.
# X_train (11176, 2000, 5)
# Load valid data from files.
# X_valid (18224, 2000, 5)

# %%
print ("Cross valiation")
do_cross_validation(X_train,y_train,model,X_valid,y_valid)  
print ("Done")
# Out:
# Cross valiation
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/200
# 350/350 [==============================] - 5s 11ms/step - loss: 0.6823 - accuracy: 0.6145 - val_loss: 0.5504 - val_accuracy: 0.7444
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.1.best/assets
# Epoch 2/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.6493 - accuracy: 0.6231 - val_loss: 0.5312 - val_accuracy: 0.7519
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.1.best/assets
# Epoch 3/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.6430 - accuracy: 0.6331 - val_loss: 0.6341 - val_accuracy: 0.6068
# Epoch 4/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.6246 - accuracy: 0.6629 - val_loss: 0.6374 - val_accuracy: 0.6566
# Epoch 5/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.6276 - accuracy: 0.6599 - val_loss: 0.5832 - val_accuracy: 0.7214
# Epoch 6/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.6020 - accuracy: 0.6806 - val_loss: 0.5566 - val_accuracy: 0.7053
# Epoch 7/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.6146 - accuracy: 0.6684 - val_loss: 0.5442 - val_accuracy: 0.7288
# Epoch 8/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.5981 - accuracy: 0.6875 - val_loss: 0.5392 - val_accuracy: 0.7243
# Epoch 9/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5709 - accuracy: 0.7139 - val_loss: 0.5629 - val_accuracy: 0.7196
# Epoch 10/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5443 - accuracy: 0.7225 - val_loss: 0.6231 - val_accuracy: 0.6524
# Epoch 11/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.5148 - accuracy: 0.7515 - val_loss: 0.4146 - val_accuracy: 0.8162
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.1.best/assets
# Epoch 12/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.4802 - accuracy: 0.7676 - val_loss: 0.3735 - val_accuracy: 0.8438
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.1.best/assets
# Epoch 13/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.4422 - accuracy: 0.7999 - val_loss: 0.4415 - val_accuracy: 0.7906
# Epoch 14/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.3984 - accuracy: 0.8232 - val_loss: 0.4776 - val_accuracy: 0.7793
# Epoch 15/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.3930 - accuracy: 0.8287 - val_loss: 0.4645 - val_accuracy: 0.7894
# Epoch 16/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.3238 - accuracy: 0.8662 - val_loss: 0.4839 - val_accuracy: 0.7927
# Epoch 17/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.2870 - accuracy: 0.8826 - val_loss: 0.4287 - val_accuracy: 0.8248
# Epoch 18/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.2427 - accuracy: 0.9031 - val_loss: 0.4742 - val_accuracy: 0.8141
# Epoch 19/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.2360 - accuracy: 0.9048 - val_loss: 0.3510 - val_accuracy: 0.8662
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.1.best/assets
# Epoch 20/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.2217 - accuracy: 0.9114 - val_loss: 0.4425 - val_accuracy: 0.8414
# Epoch 21/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.1706 - accuracy: 0.9371 - val_loss: 0.3830 - val_accuracy: 0.8655
# Epoch 22/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.1638 - accuracy: 0.9391 - val_loss: 0.4858 - val_accuracy: 0.8411
# Epoch 23/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.1365 - accuracy: 0.9500 - val_loss: 0.5154 - val_accuracy: 0.8329
# Epoch 24/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.1336 - accuracy: 0.9495 - val_loss: 0.4545 - val_accuracy: 0.8594
# Epoch 25/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.1203 - accuracy: 0.9536 - val_loss: 0.6431 - val_accuracy: 0.8129
# Epoch 26/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.1085 - accuracy: 0.9606 - val_loss: 0.4596 - val_accuracy: 0.8646
# Epoch 27/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.1010 - accuracy: 0.9638 - val_loss: 0.4261 - val_accuracy: 0.8728
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.1.best/assets
# Epoch 28/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.1133 - accuracy: 0.9569 - val_loss: 0.5465 - val_accuracy: 0.8486
# Epoch 29/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.0974 - accuracy: 0.9638 - val_loss: 0.5383 - val_accuracy: 0.8531
# Epoch 00029: early stopping
# Fold 1, 200 epochs, 110 sec
# accuracy: 87.28%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/200
# 350/350 [==============================] - 5s 11ms/step - loss: 0.7408 - accuracy: 0.5220 - val_loss: 0.6740 - val_accuracy: 0.6626
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.2.best/assets
# Epoch 2/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.6969 - accuracy: 0.5565 - val_loss: 0.6667 - val_accuracy: 0.6591
# Epoch 3/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.6757 - accuracy: 0.5827 - val_loss: 0.6117 - val_accuracy: 0.7610
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.2.best/assets
# Epoch 4/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.6701 - accuracy: 0.5830 - val_loss: 0.6389 - val_accuracy: 0.7435
# Epoch 5/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.6651 - accuracy: 0.6082 - val_loss: 0.6522 - val_accuracy: 0.7615
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.2.best/assets
# Epoch 6/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.6549 - accuracy: 0.6044 - val_loss: 0.5829 - val_accuracy: 0.7559
# Epoch 7/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.6557 - accuracy: 0.6073 - val_loss: 0.6243 - val_accuracy: 0.6731
# Epoch 8/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.6386 - accuracy: 0.6434 - val_loss: 0.6085 - val_accuracy: 0.6290
# Epoch 9/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.6598 - accuracy: 0.6031 - val_loss: 0.6435 - val_accuracy: 0.6270
# Epoch 10/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.6477 - accuracy: 0.6285 - val_loss: 0.6415 - val_accuracy: 0.7067
# Epoch 11/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.6556 - accuracy: 0.6171 - val_loss: 0.6742 - val_accuracy: 0.6200
# Epoch 12/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.6351 - accuracy: 0.6389 - val_loss: 0.6151 - val_accuracy: 0.6771
# Epoch 13/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.6395 - accuracy: 0.6335 - val_loss: 0.6683 - val_accuracy: 0.6591
# Epoch 14/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.6410 - accuracy: 0.6391 - val_loss: 0.6032 - val_accuracy: 0.7553
# Epoch 15/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.6331 - accuracy: 0.6455 - val_loss: 0.6150 - val_accuracy: 0.6943
# Epoch 16/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.6406 - accuracy: 0.6454 - val_loss: 0.6881 - val_accuracy: 0.6435
# Epoch 00016: early stopping
# Fold 2, 200 epochs, 61 sec
# accuracy: 76.15%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/200
# 350/350 [==============================] - 5s 10ms/step - loss: 0.7361 - accuracy: 0.5263 - val_loss: 0.6796 - val_accuracy: 0.6931
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.3.best/assets
# Epoch 2/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.7182 - accuracy: 0.5094 - val_loss: 0.6879 - val_accuracy: 0.6931
# Epoch 3/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.7055 - accuracy: 0.5018 - val_loss: 0.7330 - val_accuracy: 0.3069
# Epoch 4/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.7012 - accuracy: 0.5057 - val_loss: 0.7005 - val_accuracy: 0.3069
# Epoch 5/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.7002 - accuracy: 0.4941 - val_loss: 0.6765 - val_accuracy: 0.6931
# Epoch 6/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.6954 - accuracy: 0.5044 - val_loss: 0.6958 - val_accuracy: 0.3069
# Epoch 7/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.6967 - accuracy: 0.4954 - val_loss: 0.6859 - val_accuracy: 0.6931
# Epoch 8/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.6944 - accuracy: 0.5098 - val_loss: 0.7000 - val_accuracy: 0.3069
# Epoch 9/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.6950 - accuracy: 0.4947 - val_loss: 0.6959 - val_accuracy: 0.3069
# Epoch 10/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.6957 - accuracy: 0.4863 - val_loss: 0.6912 - val_accuracy: 0.6931
# Epoch 11/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.6941 - accuracy: 0.4990 - val_loss: 0.7116 - val_accuracy: 0.3069
# Epoch 12/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.6941 - accuracy: 0.5017 - val_loss: 0.6923 - val_accuracy: 0.6931
# Epoch 13/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.6937 - accuracy: 0.5096 - val_loss: 0.6861 - val_accuracy: 0.6931
# Epoch 14/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.6939 - accuracy: 0.4880 - val_loss: 0.6822 - val_accuracy: 0.6931
# Epoch 15/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.6939 - accuracy: 0.4916 - val_loss: 0.7009 - val_accuracy: 0.3069
# Epoch 00015: early stopping
# Fold 3, 200 epochs, 54 sec
# accuracy: 69.31%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.6969 - accuracy: 0.5994 - val_loss: 0.6982 - val_accuracy: 0.5949
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.4.best/assets
# Epoch 2/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.6490 - accuracy: 0.6260 - val_loss: 0.6883 - val_accuracy: 0.6031
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.4.best/assets
# Epoch 3/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.6135 - accuracy: 0.6670 - val_loss: 0.6529 - val_accuracy: 0.6535
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.4.best/assets
# Epoch 4/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.6191 - accuracy: 0.6591 - val_loss: 0.6415 - val_accuracy: 0.6498
# Epoch 5/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.6235 - accuracy: 0.6677 - val_loss: 0.6125 - val_accuracy: 0.6198
# Epoch 6/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.6181 - accuracy: 0.6578 - val_loss: 0.6515 - val_accuracy: 0.6165
# Epoch 7/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5904 - accuracy: 0.6933 - val_loss: 0.6773 - val_accuracy: 0.5509
# Epoch 8/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5802 - accuracy: 0.7019 - val_loss: 0.4405 - val_accuracy: 0.8049
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.4.best/assets
# Epoch 9/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5772 - accuracy: 0.7013 - val_loss: 0.4648 - val_accuracy: 0.7864
# Epoch 10/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.5465 - accuracy: 0.7275 - val_loss: 0.5227 - val_accuracy: 0.7840
# Epoch 11/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.5119 - accuracy: 0.7556 - val_loss: 0.4458 - val_accuracy: 0.8019
# Epoch 12/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.4488 - accuracy: 0.7944 - val_loss: 0.3604 - val_accuracy: 0.8535
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.4.best/assets
# Epoch 13/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.4161 - accuracy: 0.8152 - val_loss: 0.3398 - val_accuracy: 0.8599
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.4.best/assets
# Epoch 14/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.3843 - accuracy: 0.8315 - val_loss: 0.3654 - val_accuracy: 0.8441
# Epoch 15/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.3442 - accuracy: 0.8522 - val_loss: 0.4409 - val_accuracy: 0.8083
# Epoch 16/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.3103 - accuracy: 0.8731 - val_loss: 0.3293 - val_accuracy: 0.8683
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.4.best/assets
# Epoch 17/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.2924 - accuracy: 0.8809 - val_loss: 0.4076 - val_accuracy: 0.8309
# Epoch 18/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.2594 - accuracy: 0.8947 - val_loss: 0.4341 - val_accuracy: 0.8289
# Epoch 19/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.2312 - accuracy: 0.9103 - val_loss: 0.3698 - val_accuracy: 0.8605
# Epoch 20/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.1920 - accuracy: 0.9284 - val_loss: 0.4041 - val_accuracy: 0.8578
# Epoch 21/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.1926 - accuracy: 0.9266 - val_loss: 0.4290 - val_accuracy: 0.8491
# Epoch 22/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.1531 - accuracy: 0.9435 - val_loss: 0.4733 - val_accuracy: 0.8410
# Epoch 23/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.1470 - accuracy: 0.9464 - val_loss: 0.4473 - val_accuracy: 0.8548
# Epoch 24/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.1409 - accuracy: 0.9508 - val_loss: 0.5895 - val_accuracy: 0.8235
# Epoch 25/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.1258 - accuracy: 0.9541 - val_loss: 0.4508 - val_accuracy: 0.8675
# Epoch 26/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.1078 - accuracy: 0.9609 - val_loss: 0.7133 - val_accuracy: 0.7934
# Epoch 00026: early stopping
# Fold 4, 200 epochs, 101 sec
# accuracy: 86.83%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/200
# 350/350 [==============================] - 5s 11ms/step - loss: 0.6987 - accuracy: 0.5875 - val_loss: 0.6368 - val_accuracy: 0.6727
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.5.best/assets
# Epoch 2/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.6564 - accuracy: 0.6244 - val_loss: 0.6435 - val_accuracy: 0.6831
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.5.best/assets
# Epoch 3/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.6662 - accuracy: 0.6110 - val_loss: 0.6658 - val_accuracy: 0.6209
# Epoch 4/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.6297 - accuracy: 0.6602 - val_loss: 0.6366 - val_accuracy: 0.6262
# Epoch 5/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.6224 - accuracy: 0.6651 - val_loss: 0.6191 - val_accuracy: 0.6127
# Epoch 6/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.6059 - accuracy: 0.6684 - val_loss: 0.5020 - val_accuracy: 0.7576
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.5.best/assets
# Epoch 7/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5997 - accuracy: 0.6824 - val_loss: 0.4793 - val_accuracy: 0.7805
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.5.best/assets
# Epoch 8/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.5764 - accuracy: 0.6948 - val_loss: 0.5069 - val_accuracy: 0.7835
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.5.best/assets
# Epoch 9/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.5295 - accuracy: 0.7423 - val_loss: 0.4620 - val_accuracy: 0.7898
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.5.best/assets
# Epoch 10/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.5054 - accuracy: 0.7578 - val_loss: 0.5956 - val_accuracy: 0.7079
# Epoch 11/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.4888 - accuracy: 0.7643 - val_loss: 0.4401 - val_accuracy: 0.8084
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.5.best/assets
# Epoch 12/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.4398 - accuracy: 0.8036 - val_loss: 0.3832 - val_accuracy: 0.8379
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.5.best/assets
# Epoch 13/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.4126 - accuracy: 0.8182 - val_loss: 0.3601 - val_accuracy: 0.8466
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.5.best/assets
# Epoch 14/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.3712 - accuracy: 0.8382 - val_loss: 0.5800 - val_accuracy: 0.7353
# Epoch 15/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.3691 - accuracy: 0.8449 - val_loss: 0.3504 - val_accuracy: 0.8563
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.5.best/assets
# Epoch 16/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.3147 - accuracy: 0.8684 - val_loss: 0.4203 - val_accuracy: 0.8245
# Epoch 17/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.2900 - accuracy: 0.8799 - val_loss: 0.3886 - val_accuracy: 0.8414
# Epoch 18/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.2538 - accuracy: 0.9009 - val_loss: 0.3366 - val_accuracy: 0.8673
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.5.best/assets
# Epoch 19/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.2218 - accuracy: 0.9169 - val_loss: 0.3473 - val_accuracy: 0.8700
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.5.best/assets
# Epoch 20/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.2070 - accuracy: 0.9204 - val_loss: 0.3882 - val_accuracy: 0.8624
# Epoch 21/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.1751 - accuracy: 0.9370 - val_loss: 0.7228 - val_accuracy: 0.7531
# Epoch 22/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.1754 - accuracy: 0.9329 - val_loss: 0.3939 - val_accuracy: 0.8669
# Epoch 23/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.1591 - accuracy: 0.9414 - val_loss: 0.6083 - val_accuracy: 0.8003
# Epoch 24/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.1406 - accuracy: 0.9454 - val_loss: 0.3955 - val_accuracy: 0.8730
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.5.best/assets
# Epoch 25/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.1217 - accuracy: 0.9592 - val_loss: 0.3947 - val_accuracy: 0.8739
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.5.best/assets
# Epoch 26/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.1188 - accuracy: 0.9594 - val_loss: 0.5432 - val_accuracy: 0.8374
# Epoch 27/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.1238 - accuracy: 0.9550 - val_loss: 0.6115 - val_accuracy: 0.8240
# Epoch 28/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.1161 - accuracy: 0.9599 - val_loss: 0.5680 - val_accuracy: 0.8401
# Epoch 00028: early stopping
# Fold 5, 200 epochs, 117 sec
# accuracy: 87.39%
#
# 5-way Cross Validation max 87.39%, mean 81.39% (+/- 7.40%)
# Done
