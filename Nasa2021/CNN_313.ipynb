# %% [markdown]
# # CNN 313
# Rather than partition train/validation sets, use different sets.
# Cut train set down to random LIMIT number of transcripts.
# Use all of the validation set.
# Use fit(shuffle) on the train set.
#
# TO DO:
# Save five best models to same directory to make it easy to delete.

# %%
TRAIN_NC_FILENAME='ncRNA.gc36.median.fasta'
TRAIN_PC_FILENAME='pcRNA.gc36.median.fasta'
VALID_NC_FILENAME='ncRNA.gc36.all.fasta'
VALID_PC_FILENAME='pcRNA.gc36.all.fasta'
#NC_FILENAME='ncRNA.tiny50.fasta'
#PC_FILENAME='pcRNA.tiny50.fasta'
#NC_FILENAME='ncRNA.gc34.processed.fasta'
#PC_FILENAME='pcRNA.gc34.processed.fasta'

MODEL_FILE='JUNK1'  # change this if you want to keep models
DATAPATH=''

try:
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
except:
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"
TRAIN_NC_FILENAME = DATAPATH+TRAIN_NC_FILENAME
TRAIN_PC_FILENAME = DATAPATH+TRAIN_PC_FILENAME
VALID_NC_FILENAME = DATAPATH+VALID_NC_FILENAME
VALID_PC_FILENAME = DATAPATH+VALID_PC_FILENAME
MODEL_FILE=DATAPATH+MODEL_FILE

EPOCHS=200
SPLITS=5
K=1
VOCABULARY_SIZE=4**K+1   # e.g. K=3 => 64 DNA K-mers + 'NNN'
EMBED_DIMEN=2
FILTERS=32
KERNEL=3
NEURONS=32
DROP=0.25
ACT="tanh"
MINLEN=201
MAXLEN=2000
LIMIT=5588    # This is the size of our smallest set (protein coding short)
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# Load our own tools
# TO DO: don't go to GitHub if the file is already local.
GITHUB = True
if GITHUB:
    #!pip install requests  # Uncomment this if necessary. Seems to be pre-installed.
    import requests
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/ShepherdML/master/Strings/tools_fasta.py')
    with open('tools_fasta.py', 'w') as f:
        f.write(r.text)
    # TO DO: delete the file after import
import tools_fasta as tools
tools.yahoo()  # If this prints "Yahoo!" the the import was successful.

TOOLS_CHANGED = False   # set to True to re-run with a new version of tools
if TOOLS_CHANGED:
  from importlib import reload 
  tools=reload(tools)
  print(dir(tools))   # run this to see EVERYTHING in the tools module
# Out:
# Yahoo!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import StratifiedKFold
import tensorflow as tf
from tensorflow import keras
import time
dt='float32'
tf.keras.backend.set_floatx(dt)

# %% [markdown]
# Build model

# %%
def compile_model(model):
    ## learn rate = initial_learning_rate * decay_rate ^ (step / decay_steps)
    #adam_default_learn_rate = 0.001
    #schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    #    initial_learning_rate = adam_default_learn_rate*10,
    #    decay_steps=10000, decay_rate=0.99, staircase=True)
    #alrd = tf.keras.optimizers.Adam(learning_rate=schedule)
    #model.compile(loss=bc, optimizer=alrd, metrics=["accuracy"])

    print("COMPILE...")
    bc=tf.keras.losses.BinaryCrossentropy(from_logits=False)
    model.compile(loss=bc, optimizer="adam", metrics=["accuracy"])
    print("...COMPILED")
    return model

def build_model():
    SHAPE=(MAXLEN,5)  # MAXLEN bases = time steps, 5 features = one hots
    clayer1 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same",
                                 input_shape=SHAPE)
    clayer2 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer3 = keras.layers.MaxPooling1D(2)
    clayer4 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer5 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer6 = keras.layers.MaxPooling1D(2)
    clayer7 = keras.layers.Flatten()

    dlayer1 = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt, input_shape=[1000])
    dlayer2 = keras.layers.Dropout(DROP)
    dlayer3 = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt)
    dlayer4 = keras.layers.Dropout(DROP)
    output_layer = keras.layers.Dense(1, activation="sigmoid", dtype=dt)

    cnn = keras.models.Sequential()
    cnn.add(clayer1)
    cnn.add(clayer2)
    cnn.add(clayer3)
    cnn.add(clayer4)
    cnn.add(clayer5)
    cnn.add(clayer6)
    cnn.add(clayer7)
    cnn.add(dlayer1)
    cnn.add(dlayer2)
    cnn.add(dlayer3)
    cnn.add(dlayer4)
    cnn.add(output_layer)
    mlpc = compile_model(cnn)
    return mlpc

# %% [markdown]
# Cross validation

# %%
def do_cross_validation(X_train,y_train,given_model,X_valid,y_valid):
    cv_scores = []
    fold=0
    # When not using ShuffleSplit, make sure to randomize train data.
    #splitter = ShuffleSplit(n_splits=SPLITS, test_size=0.1, random_state=37863)
    #for train_index,valid_index in splitter.split(X):
    while fold < SPLITS:
        fold += 1
        # Avoid continually improving the same model.
        model = compile_model(keras.models.clone_model(given_model))
        bestname=MODEL_FILE+".cv."+str(fold)+".best"
        es = keras.callbacks.EarlyStopping(monitor='val_loss',  
            patience=10, verbose=1)
        mc = keras.callbacks.ModelCheckpoint(
            filepath=bestname, save_best_only=True, 
            monitor='val_accuracy', mode='max')  
        mycallbacks = [es,mc]  
        print("FIT")
        start_time=time.time()
        history=model.fit(X_train, y_train, # batch_size=10, default=32 works nicely
                epochs=EPOCHS, verbose=1,  # verbose=1 for ascii art, verbose=0 for none
                callbacks=mycallbacks, shuffle=True,
                validation_data=(X_valid,y_valid) )
        end_time=time.time()
        elapsed_time=(end_time-start_time)                        
        print("Fold %d, %d epochs, %d sec"%(fold,EPOCHS,elapsed_time))
        pd.DataFrame(history.history).plot(figsize=(8,5))
        plt.grid(True)
        plt.gca().set_ylim(0,1)
        plt.show()
        best_model=keras.models.load_model(bestname)
        scores = best_model.evaluate(X_valid, y_valid, verbose=0)
        print("%s: %.2f%%" % (best_model.metrics_names[1], scores[1]*100))
        cv_scores.append(scores[1] * 100)  

    print()
    print("%d-way Cross Validation max %.2f%%, mean %.2f%% (+/- %.2f%%)" % 
          (fold, np.amax(cv_scores), np.mean(cv_scores), np.std(cv_scores)))

# %% [markdown]
# ## Train on RNA lengths 200-1Kb

# %%
print ("Compile the model")
model=build_model()
print ("Summarize the model")
print(model.summary())  # Print this only once
#model.save(MODEL_FILE+'.model')
# Out:
# Compile the model
# COMPILE...
# ...COMPILED
# Summarize the model
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_24 (Conv1D)           (None, 2000, 32)          512
# _________________________________________________________________
# conv1d_25 (Conv1D)           (None, 2000, 32)          3104
# _________________________________________________________________
# max_pooling1d_12 (MaxPooling (None, 1000, 32)          0
# _________________________________________________________________
# conv1d_26 (Conv1D)           (None, 1000, 32)          3104
# _________________________________________________________________
# conv1d_27 (Conv1D)           (None, 1000, 32)          3104
# _________________________________________________________________
# max_pooling1d_13 (MaxPooling (None, 500, 32)           0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 16000)             0
# _________________________________________________________________
# dense_18 (Dense)             (None, 32)                512032
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_19 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_20 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 522,945
# Trainable params: 522,945
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
def load_data(nc_filename,pc_filename,limit=None):
  nc_seq=tools.load_fasta(nc_filename,0)
  pc_seq=tools.load_fasta(pc_filename,1)
  if limit is not None:
    # Choose a random subset of size = limit.
    # Side effect: randomizes the data order.
    nfrac=1.0*limit/len(nc_seq)
    pfrac=1.0*limit/len(pc_seq)
    if nfrac<1.0:
      nc_seq=nc_seq.sample(frac=nfrac)
    if pfrac<1.0:
      pc_seq=pc_seq.sample(frac=pfrac)
  train_set=pd.concat((nc_seq,pc_seq),axis=0)
  # May not need to slice by length if input files already sliced
  subset=tools.make_slice(train_set,MINLEN,MAXLEN)
  # randset=subset.sample(frac=1) # unneccessary with fit(shuffle)
  (X1,y1)=tools.separate_X_and_y(subset)
  # X1 is pandas df of ("list" of one sequence)
  X2=X1.to_numpy()  # numpy ndarray of ("list" of one sequence)
  X3=[elem[0] for elem in X2]  # numpy dnarray of str
  X4=tools.uniform_length(X3,MAXLEN)
  X5= [tools.one_hot(x) for x in X4]
  X6=np.asarray(X5)
  y6=y1.to_numpy()
  return X6,y6

print("Load train data from files.")
X_train,y_train = load_data(TRAIN_NC_FILENAME,TRAIN_PC_FILENAME,LIMIT)
print("X_train",X_train.shape)
print("Load valid data from files.")
X_valid,y_valid = load_data(VALID_NC_FILENAME,VALID_PC_FILENAME)
print("X_valid",X_valid.shape)
# Out:
# Load train data from files.
# X_train (11176, 2000, 5)
# Load valid data from files.
# X_valid (40592, 2000, 5)

# %%
print ("Cross valiation")
do_cross_validation(X_train,y_train,model,X_valid,y_valid)  
print ("Done")
# Out:
# Cross valiation
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/200
# 350/350 [==============================] - 7s 17ms/step - loss: 0.6772 - accuracy: 0.6098 - val_loss: 0.6357 - val_accuracy: 0.6128
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.1.best/assets
# Epoch 2/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6491 - accuracy: 0.6284 - val_loss: 0.5953 - val_accuracy: 0.6964
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.1.best/assets
# Epoch 3/200
# 350/350 [==============================] - 6s 18ms/step - loss: 0.6147 - accuracy: 0.6705 - val_loss: 0.5948 - val_accuracy: 0.6904
# Epoch 4/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6017 - accuracy: 0.6818 - val_loss: 0.6248 - val_accuracy: 0.6447
# Epoch 5/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6277 - accuracy: 0.6479 - val_loss: 0.6891 - val_accuracy: 0.5158
# Epoch 6/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6964 - accuracy: 0.5221 - val_loss: 0.6342 - val_accuracy: 0.6957
# Epoch 7/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6559 - accuracy: 0.6259 - val_loss: 0.6256 - val_accuracy: 0.6071
# Epoch 8/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6359 - accuracy: 0.6406 - val_loss: 0.6253 - val_accuracy: 0.6503
# Epoch 9/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6250 - accuracy: 0.6592 - val_loss: 0.5994 - val_accuracy: 0.6773
# Epoch 10/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6366 - accuracy: 0.6416 - val_loss: 0.5983 - val_accuracy: 0.6617
# Epoch 11/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6250 - accuracy: 0.6604 - val_loss: 0.5842 - val_accuracy: 0.6814
# Epoch 12/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6094 - accuracy: 0.6700 - val_loss: 0.5915 - val_accuracy: 0.6965
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.1.best/assets
# Epoch 13/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6080 - accuracy: 0.6855 - val_loss: 0.6037 - val_accuracy: 0.6765
# Epoch 14/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6177 - accuracy: 0.6629 - val_loss: 0.6605 - val_accuracy: 0.5762
# Epoch 15/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6284 - accuracy: 0.6419 - val_loss: 0.5863 - val_accuracy: 0.7044
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.1.best/assets
# Epoch 16/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6130 - accuracy: 0.6757 - val_loss: 0.6168 - val_accuracy: 0.6831
# Epoch 17/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6038 - accuracy: 0.6833 - val_loss: 0.5847 - val_accuracy: 0.7031
# Epoch 18/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5866 - accuracy: 0.6919 - val_loss: 0.6225 - val_accuracy: 0.6472
# Epoch 19/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6155 - accuracy: 0.6658 - val_loss: 0.6214 - val_accuracy: 0.6747
# Epoch 20/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6165 - accuracy: 0.6642 - val_loss: 0.6084 - val_accuracy: 0.6789
# Epoch 21/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6129 - accuracy: 0.6611 - val_loss: 0.5870 - val_accuracy: 0.6878
# Epoch 00021: early stopping
# Fold 1, 200 epochs, 130 sec
# accuracy: 70.44%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/200
# 350/350 [==============================] - 7s 17ms/step - loss: 0.6922 - accuracy: 0.5993 - val_loss: 0.6115 - val_accuracy: 0.6398
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.2.best/assets
# Epoch 2/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6420 - accuracy: 0.6424 - val_loss: 0.6431 - val_accuracy: 0.6793
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.2.best/assets
# Epoch 3/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6529 - accuracy: 0.6229 - val_loss: 0.6913 - val_accuracy: 0.6296
# Epoch 4/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6271 - accuracy: 0.6668 - val_loss: 0.6525 - val_accuracy: 0.6375
# Epoch 5/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6286 - accuracy: 0.6558 - val_loss: 0.6046 - val_accuracy: 0.6848
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.2.best/assets
# Epoch 6/200
# 350/350 [==============================] - 6s 18ms/step - loss: 0.6153 - accuracy: 0.6643 - val_loss: 0.6251 - val_accuracy: 0.6575
# Epoch 7/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6285 - accuracy: 0.6519 - val_loss: 0.6528 - val_accuracy: 0.6305
# Epoch 8/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6102 - accuracy: 0.6774 - val_loss: 0.6114 - val_accuracy: 0.6783
# Epoch 9/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5984 - accuracy: 0.6832 - val_loss: 0.6449 - val_accuracy: 0.6156
# Epoch 10/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6054 - accuracy: 0.6697 - val_loss: 0.5891 - val_accuracy: 0.7053
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.2.best/assets
# Epoch 11/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6121 - accuracy: 0.6693 - val_loss: 0.6646 - val_accuracy: 0.6372
# Epoch 12/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6092 - accuracy: 0.6811 - val_loss: 0.6258 - val_accuracy: 0.6769
# Epoch 13/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6065 - accuracy: 0.6708 - val_loss: 0.6113 - val_accuracy: 0.6653
# Epoch 14/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6095 - accuracy: 0.6795 - val_loss: 0.6070 - val_accuracy: 0.6632
# Epoch 15/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6108 - accuracy: 0.6652 - val_loss: 0.6173 - val_accuracy: 0.6632
# Epoch 16/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6087 - accuracy: 0.6754 - val_loss: 0.5974 - val_accuracy: 0.6719
# Epoch 17/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5946 - accuracy: 0.6865 - val_loss: 0.6130 - val_accuracy: 0.6477
# Epoch 18/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6082 - accuracy: 0.6730 - val_loss: 0.5959 - val_accuracy: 0.6712
# Epoch 19/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6024 - accuracy: 0.6794 - val_loss: 0.5948 - val_accuracy: 0.6828
# Epoch 20/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6039 - accuracy: 0.6831 - val_loss: 0.5798 - val_accuracy: 0.7011
# Epoch 21/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6063 - accuracy: 0.6796 - val_loss: 0.6449 - val_accuracy: 0.6526
# Epoch 22/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6061 - accuracy: 0.6801 - val_loss: 0.5902 - val_accuracy: 0.6980
# Epoch 23/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6168 - accuracy: 0.6619 - val_loss: 0.5657 - val_accuracy: 0.7239
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.2.best/assets
# Epoch 24/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5993 - accuracy: 0.6947 - val_loss: 0.5855 - val_accuracy: 0.7038
# Epoch 25/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5956 - accuracy: 0.6896 - val_loss: 0.6552 - val_accuracy: 0.6136
# Epoch 26/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6035 - accuracy: 0.6765 - val_loss: 0.6154 - val_accuracy: 0.6716
# Epoch 27/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5979 - accuracy: 0.6864 - val_loss: 0.5934 - val_accuracy: 0.6797
# Epoch 28/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6010 - accuracy: 0.6873 - val_loss: 0.6161 - val_accuracy: 0.6556
# Epoch 29/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5939 - accuracy: 0.6880 - val_loss: 0.5782 - val_accuracy: 0.6896
# Epoch 30/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5717 - accuracy: 0.7012 - val_loss: 0.5901 - val_accuracy: 0.7005
# Epoch 31/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5865 - accuracy: 0.6799 - val_loss: 0.5768 - val_accuracy: 0.7049
# Epoch 32/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5877 - accuracy: 0.6909 - val_loss: 0.5754 - val_accuracy: 0.6903
# Epoch 33/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5872 - accuracy: 0.6864 - val_loss: 0.5782 - val_accuracy: 0.7107
# Epoch 00033: early stopping
# Fold 2, 200 epochs, 202 sec
# accuracy: 72.39%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/200
# 350/350 [==============================] - 7s 17ms/step - loss: 0.6850 - accuracy: 0.5900 - val_loss: 0.5873 - val_accuracy: 0.7046
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.3.best/assets
# Epoch 2/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6223 - accuracy: 0.6653 - val_loss: 0.6618 - val_accuracy: 0.5508
# Epoch 3/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6504 - accuracy: 0.6243 - val_loss: 0.6213 - val_accuracy: 0.6722
# Epoch 4/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6209 - accuracy: 0.6580 - val_loss: 0.6087 - val_accuracy: 0.6727
# Epoch 5/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6143 - accuracy: 0.6689 - val_loss: 0.5855 - val_accuracy: 0.7119
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.3.best/assets
# Epoch 6/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6069 - accuracy: 0.6776 - val_loss: 0.5871 - val_accuracy: 0.6987
# Epoch 7/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6090 - accuracy: 0.6741 - val_loss: 0.6237 - val_accuracy: 0.6517
# Epoch 8/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6113 - accuracy: 0.6850 - val_loss: 0.6358 - val_accuracy: 0.6031
# Epoch 9/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6035 - accuracy: 0.6801 - val_loss: 0.6037 - val_accuracy: 0.6699
# Epoch 10/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6145 - accuracy: 0.6648 - val_loss: 0.6049 - val_accuracy: 0.6646
# Epoch 11/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6062 - accuracy: 0.6798 - val_loss: 0.6539 - val_accuracy: 0.6468
# Epoch 12/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6059 - accuracy: 0.6802 - val_loss: 0.6162 - val_accuracy: 0.6605
# Epoch 13/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6021 - accuracy: 0.6844 - val_loss: 0.5948 - val_accuracy: 0.6976
# Epoch 14/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5996 - accuracy: 0.6751 - val_loss: 0.5750 - val_accuracy: 0.7089
# Epoch 15/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5956 - accuracy: 0.6775 - val_loss: 0.6007 - val_accuracy: 0.6746
# Epoch 16/200
# 350/350 [==============================] - 6s 18ms/step - loss: 0.5943 - accuracy: 0.6892 - val_loss: 0.6012 - val_accuracy: 0.6934
# Epoch 17/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6117 - accuracy: 0.6770 - val_loss: 0.6140 - val_accuracy: 0.6909
# Epoch 18/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6154 - accuracy: 0.6541 - val_loss: 0.6131 - val_accuracy: 0.6637
# Epoch 19/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5994 - accuracy: 0.6875 - val_loss: 0.5897 - val_accuracy: 0.6957
# Epoch 20/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5903 - accuracy: 0.6945 - val_loss: 0.5949 - val_accuracy: 0.6864
# Epoch 21/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6023 - accuracy: 0.6751 - val_loss: 0.6017 - val_accuracy: 0.7005
# Epoch 22/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6161 - accuracy: 0.6601 - val_loss: 0.6162 - val_accuracy: 0.6595
# Epoch 23/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6085 - accuracy: 0.6744 - val_loss: 0.6455 - val_accuracy: 0.6303
# Epoch 24/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5989 - accuracy: 0.6838 - val_loss: 0.6133 - val_accuracy: 0.6580
# Epoch 00024: early stopping
# Fold 3, 200 epochs, 146 sec
# accuracy: 71.19%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/200
# 350/350 [==============================] - 7s 18ms/step - loss: 0.6919 - accuracy: 0.6005 - val_loss: 0.6107 - val_accuracy: 0.6495
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.4.best/assets
# Epoch 2/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6441 - accuracy: 0.6502 - val_loss: 0.6234 - val_accuracy: 0.6627
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.4.best/assets
# Epoch 3/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6226 - accuracy: 0.6661 - val_loss: 0.6842 - val_accuracy: 0.6077
# Epoch 4/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6275 - accuracy: 0.6572 - val_loss: 0.6247 - val_accuracy: 0.6617
# Epoch 5/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6190 - accuracy: 0.6669 - val_loss: 0.6367 - val_accuracy: 0.5928
# Epoch 6/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6148 - accuracy: 0.6705 - val_loss: 0.5854 - val_accuracy: 0.6964
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.4.best/assets
# Epoch 7/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6324 - accuracy: 0.6396 - val_loss: 0.5922 - val_accuracy: 0.6940
# Epoch 8/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6001 - accuracy: 0.6841 - val_loss: 0.6801 - val_accuracy: 0.5759
# Epoch 9/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6194 - accuracy: 0.6512 - val_loss: 0.5940 - val_accuracy: 0.6740
# Epoch 10/200
# 350/350 [==============================] - 6s 18ms/step - loss: 0.6104 - accuracy: 0.6744 - val_loss: 0.5818 - val_accuracy: 0.7022
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.4.best/assets
# Epoch 11/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6086 - accuracy: 0.6726 - val_loss: 0.6113 - val_accuracy: 0.6366
# Epoch 12/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6007 - accuracy: 0.6798 - val_loss: 0.5945 - val_accuracy: 0.6709
# Epoch 13/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6065 - accuracy: 0.6755 - val_loss: 0.6079 - val_accuracy: 0.6731
# Epoch 14/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5947 - accuracy: 0.6867 - val_loss: 0.6315 - val_accuracy: 0.6685
# Epoch 15/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5933 - accuracy: 0.6837 - val_loss: 0.5673 - val_accuracy: 0.7083
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.4.best/assets
# Epoch 16/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5883 - accuracy: 0.6911 - val_loss: 0.5913 - val_accuracy: 0.6398
# Epoch 17/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5928 - accuracy: 0.6892 - val_loss: 0.6714 - val_accuracy: 0.6252
# Epoch 18/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5958 - accuracy: 0.6810 - val_loss: 0.5926 - val_accuracy: 0.6938
# Epoch 19/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5947 - accuracy: 0.6865 - val_loss: 0.5764 - val_accuracy: 0.7105
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.4.best/assets
# Epoch 20/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5956 - accuracy: 0.6909 - val_loss: 0.5827 - val_accuracy: 0.7125
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.4.best/assets
# Epoch 21/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5947 - accuracy: 0.6958 - val_loss: 0.6284 - val_accuracy: 0.6606
# Epoch 22/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6060 - accuracy: 0.6789 - val_loss: 0.6198 - val_accuracy: 0.6652
# Epoch 23/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5961 - accuracy: 0.6717 - val_loss: 0.5656 - val_accuracy: 0.7132
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.4.best/assets
# Epoch 24/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6026 - accuracy: 0.6729 - val_loss: 0.5774 - val_accuracy: 0.6925
# Epoch 25/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5846 - accuracy: 0.6955 - val_loss: 0.5688 - val_accuracy: 0.7120
# Epoch 26/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5782 - accuracy: 0.6828 - val_loss: 0.6007 - val_accuracy: 0.6554
# Epoch 27/200
# 350/350 [==============================] - 6s 18ms/step - loss: 0.5836 - accuracy: 0.6922 - val_loss: 0.5822 - val_accuracy: 0.6729
# Epoch 28/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5745 - accuracy: 0.7043 - val_loss: 0.5782 - val_accuracy: 0.7015
# Epoch 29/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5818 - accuracy: 0.6962 - val_loss: 0.5847 - val_accuracy: 0.6792
# Epoch 30/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5862 - accuracy: 0.6884 - val_loss: 0.5809 - val_accuracy: 0.6609
# Epoch 31/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5893 - accuracy: 0.6871 - val_loss: 0.5665 - val_accuracy: 0.7043
# Epoch 32/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5844 - accuracy: 0.6953 - val_loss: 0.5749 - val_accuracy: 0.7037
# Epoch 33/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5857 - accuracy: 0.6921 - val_loss: 0.5941 - val_accuracy: 0.6833
# Epoch 00033: early stopping
# Fold 4, 200 epochs, 206 sec
# accuracy: 71.32%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/200
# 350/350 [==============================] - 7s 17ms/step - loss: 0.6907 - accuracy: 0.6068 - val_loss: 0.5895 - val_accuracy: 0.6841
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.5.best/assets
# Epoch 2/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6268 - accuracy: 0.6579 - val_loss: 0.5740 - val_accuracy: 0.7155
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.5.best/assets
# Epoch 3/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6019 - accuracy: 0.6841 - val_loss: 0.6110 - val_accuracy: 0.6658
# Epoch 4/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6081 - accuracy: 0.6700 - val_loss: 0.5700 - val_accuracy: 0.7141
# Epoch 5/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5962 - accuracy: 0.6874 - val_loss: 0.5592 - val_accuracy: 0.7102
# Epoch 6/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5953 - accuracy: 0.6865 - val_loss: 0.5886 - val_accuracy: 0.6731
# Epoch 7/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5938 - accuracy: 0.6838 - val_loss: 0.5914 - val_accuracy: 0.7049
# Epoch 8/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5898 - accuracy: 0.6858 - val_loss: 0.5905 - val_accuracy: 0.6945
# Epoch 9/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5882 - accuracy: 0.6932 - val_loss: 0.6228 - val_accuracy: 0.6603
# Epoch 10/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5819 - accuracy: 0.7023 - val_loss: 0.5460 - val_accuracy: 0.7277
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.5.best/assets
# Epoch 11/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5678 - accuracy: 0.7004 - val_loss: 0.5719 - val_accuracy: 0.7190
# Epoch 12/200
# 350/350 [==============================] - 6s 18ms/step - loss: 0.5676 - accuracy: 0.7085 - val_loss: 0.5411 - val_accuracy: 0.7330
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.5.best/assets
# Epoch 13/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5606 - accuracy: 0.7207 - val_loss: 0.5287 - val_accuracy: 0.7450
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.5.best/assets
# Epoch 14/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5515 - accuracy: 0.7245 - val_loss: 0.5490 - val_accuracy: 0.7165
# Epoch 15/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5544 - accuracy: 0.7247 - val_loss: 0.5214 - val_accuracy: 0.7461
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.5.best/assets
# Epoch 16/200
# 350/350 [==============================] - 6s 18ms/step - loss: 0.5140 - accuracy: 0.7511 - val_loss: 0.5028 - val_accuracy: 0.7555
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.5.best/assets
# Epoch 17/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5033 - accuracy: 0.7483 - val_loss: 0.5576 - val_accuracy: 0.7005
# Epoch 18/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.4844 - accuracy: 0.7688 - val_loss: 0.4780 - val_accuracy: 0.7832
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.5.best/assets
# Epoch 19/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.4675 - accuracy: 0.7804 - val_loss: 0.4394 - val_accuracy: 0.8029
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.5.best/assets
# Epoch 20/200
# 350/350 [==============================] - 6s 18ms/step - loss: 0.4444 - accuracy: 0.7983 - val_loss: 0.4416 - val_accuracy: 0.8007
# Epoch 21/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.4197 - accuracy: 0.8126 - val_loss: 0.4184 - val_accuracy: 0.8154
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.5.best/assets
# Epoch 22/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.4082 - accuracy: 0.8199 - val_loss: 0.4004 - val_accuracy: 0.8236
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.5.best/assets
# Epoch 23/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.3728 - accuracy: 0.8368 - val_loss: 0.4148 - val_accuracy: 0.8171
# Epoch 24/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.3513 - accuracy: 0.8466 - val_loss: 0.4924 - val_accuracy: 0.7731
# Epoch 25/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.3427 - accuracy: 0.8514 - val_loss: 0.4139 - val_accuracy: 0.8244
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.5.best/assets
# Epoch 26/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.3206 - accuracy: 0.8622 - val_loss: 0.4547 - val_accuracy: 0.8025
# Epoch 27/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.3231 - accuracy: 0.8566 - val_loss: 0.4558 - val_accuracy: 0.8031
# Epoch 28/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.2906 - accuracy: 0.8806 - val_loss: 0.4312 - val_accuracy: 0.8185
# Epoch 29/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.2834 - accuracy: 0.8861 - val_loss: 0.4175 - val_accuracy: 0.8231
# Epoch 30/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.2785 - accuracy: 0.8873 - val_loss: 0.3970 - val_accuracy: 0.8404
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.5.best/assets
# Epoch 31/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.2616 - accuracy: 0.8927 - val_loss: 0.4273 - val_accuracy: 0.8344
# Epoch 32/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.2589 - accuracy: 0.8943 - val_loss: 0.4252 - val_accuracy: 0.8350
# Epoch 33/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.2419 - accuracy: 0.9020 - val_loss: 0.4729 - val_accuracy: 0.8247
# Epoch 34/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.2095 - accuracy: 0.9190 - val_loss: 0.4636 - val_accuracy: 0.8215
# Epoch 35/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.2063 - accuracy: 0.9180 - val_loss: 0.4393 - val_accuracy: 0.8335
# Epoch 36/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.1863 - accuracy: 0.9309 - val_loss: 0.5429 - val_accuracy: 0.8105
# Epoch 37/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.1953 - accuracy: 0.9197 - val_loss: 0.4924 - val_accuracy: 0.8159
# Epoch 38/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.1715 - accuracy: 0.9349 - val_loss: 0.4796 - val_accuracy: 0.8337
# Epoch 39/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.1529 - accuracy: 0.9435 - val_loss: 0.6247 - val_accuracy: 0.7946
# Epoch 40/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.1616 - accuracy: 0.9398 - val_loss: 0.4472 - val_accuracy: 0.8483
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.5.best/assets
# Epoch 00040: early stopping
# Fold 5, 200 epochs, 254 sec
# accuracy: 84.83%
#
# 5-way Cross Validation max 84.83%, mean 74.03% (+/- 5.43%)
# Done
