# %% [markdown]
# <a href="https://colab.research.google.com/github/ShepherdCode/ShepherdML/blob/master/Nasa2021/CNN_523JL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CNN 523JL
#
# 1. Four layers of CNNS and MaxPooling
# 2. Drop out at 0.2
# 3. Variable filters and dense neurons
# 4. 6K coding and 6K noncoding

# %%
#NC_FILENAME='ncRNA.tiny50.fasta'
#PC_FILENAME='pcRNA.tiny50.fasta'
#NC_FILENAME='ncRNA.gc34.processed.fasta'
#PC_FILENAME='pcRNA.gc34.processed.fasta'
#NC_FILENAME='ncRNA.gc36.balance.fasta'
#PC_FILENAME='pcRNA.gc36.balance.fasta'
NC_FILENAME='coding_6K.fasta'
PC_FILENAME='noncod_6K.fasta'

MODEL_FILE='JLSIM6K' 
DATAPATH=''

try:
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
except:
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"
NC_FILENAME = DATAPATH+NC_FILENAME
PC_FILENAME = DATAPATH+PC_FILENAME
MODEL_FILE=DATAPATH+MODEL_FILE

EPOCHS=50
SPLITS=5
K=1
VOCABULARY_SIZE=4**K+1   # e.g. K=3 => 64 DNA K-mers + 'NNN'
EMBED_DIMEN=2
FILTERS=32
KERNEL=3
NEURONS=24
DROP=0.2
MINLEN=200
MAXLEN=2000
DENSE_LEN = 1000
ACT="tanh"
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# Load our own tools
# TO DO: don't go to GitHub if the file is already local.
GITHUB = True
if GITHUB:
    #!pip install requests  # Uncomment this if necessary. Seems to be pre-installed.
    import requests
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/ShepherdML/master/Strings/tools_fasta.py')
    with open('tools_fasta.py', 'w') as f:
        f.write(r.text)
    # TO DO: delete the file after import
import tools_fasta as tools
tools.yahoo()  # If this prints "Yahoo!" the the import was successful.

TOOLS_CHANGED = False   # set to True to re-run with a new version of tools
if TOOLS_CHANGED:
  from importlib import reload 
  tools=reload(tools)
  print(dir(tools))   # run this to see EVERYTHING in the tools module
# Out:
# Yahoo!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import StratifiedKFold
import tensorflow as tf
from tensorflow import keras
import time
dt='float32'
tf.keras.backend.set_floatx(dt)

# %% [markdown]
# Build model

# %%
def compile_model(model):
    ## learn rate = initial_learning_rate * decay_rate ^ (step / decay_steps)
    #adam_default_learn_rate = 0.001
    #schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    #    initial_learning_rate = adam_default_learn_rate*10,
    #    decay_steps=10000, decay_rate=0.99, staircase=True)
    #alrd = tf.keras.optimizers.Adam(learning_rate=schedule)
    #model.compile(loss=bc, optimizer=alrd, metrics=["accuracy"])

    print("COMPILE...")
    bc=tf.keras.losses.BinaryCrossentropy(from_logits=False)
    model.compile(loss=bc, optimizer="adam", metrics=["accuracy"])
    print("...COMPILED")
    return model

def build_model():
    SHAPE=(MAXLEN,5)  # 2000 time steps, 5 features
    clayer1 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same",
                                 input_shape=SHAPE)
    clayer2 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer3 = keras.layers.MaxPooling1D(2)
    clayer4 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer5 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer6 = keras.layers.MaxPooling1D(2)
    clayer7 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer8 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer9 = keras.layers.MaxPooling1D(2)
    clayer10 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer11 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer12 = keras.layers.MaxPooling1D(2)

    clayer13 = keras.layers.Flatten()

    dlayer1 = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt, input_shape=[DENSE_LEN])
    dlayer2 = keras.layers.Dropout(DROP)
    dlayer3 = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt)
    dlayer4 = keras.layers.Dropout(DROP)
    output_layer = keras.layers.Dense(1, activation="sigmoid", dtype=dt)

    cnn = keras.models.Sequential()
    cnn.add(clayer1)
    cnn.add(clayer2)
    cnn.add(clayer3)
    cnn.add(clayer4)
    cnn.add(clayer5)
    cnn.add(clayer6)
    cnn.add(clayer7)
    cnn.add(clayer8)
    cnn.add(clayer9)
    cnn.add(clayer10)
    cnn.add(clayer11)
    cnn.add(clayer12)
    cnn.add(clayer13)
    cnn.add(dlayer1)
    cnn.add(dlayer2)
    cnn.add(dlayer3)
    cnn.add(dlayer4)
    cnn.add(output_layer)
    mlpc = compile_model(cnn)
    return mlpc

# %% [markdown]
# Cross validation

# %%
def do_cross_validation(X,y,given_model):
    cv_scores = []
    fold=0
    splitter = ShuffleSplit(n_splits=SPLITS, test_size=0.1, random_state=37863)
    for train_index,valid_index in splitter.split(X):
        fold += 1
        X_train=X[train_index] # use iloc[] for dataframe
        y_train=y[train_index]
        X_valid=X[valid_index]
        y_valid=y[valid_index]        
        # Avoid continually improving the same model.
        model = compile_model(keras.models.clone_model(given_model))
        bestname=MODEL_FILE+".cv."+str(fold)+".best"
        mycallbacks = [keras.callbacks.ModelCheckpoint(
            filepath=bestname, save_best_only=True, 
            monitor='val_accuracy', mode='max')]   
        print("FIT")
        start_time=time.time()
        history=model.fit(X_train, y_train, # batch_size=10, default=32 works nicely
                epochs=EPOCHS, verbose=1,  # verbose=1 for ascii art, verbose=0 for none
                callbacks=mycallbacks,
                validation_data=(X_valid,y_valid) )
        end_time=time.time()
        elapsed_time=(end_time-start_time)                        
        print("Fold %d, %d epochs, %d sec"%(fold,EPOCHS,elapsed_time))
        pd.DataFrame(history.history).plot(figsize=(8,5))
        plt.grid(True)
        plt.gca().set_ylim(0,1)
        plt.show()
        best_model=keras.models.load_model(bestname)
        scores = best_model.evaluate(X_valid, y_valid, verbose=0)
        print("%s: %.2f%%" % (best_model.metrics_names[1], scores[1]*100))
        cv_scores.append(scores[1] * 100)  
    print()
    print("%d-way Cross Validation mean %.2f%% (+/- %.2f%%)" % (fold, np.mean(cv_scores), np.std(cv_scores)))

# %% [markdown]
# ## Train on RNA lengths 200-1Kb

# %%
print ("Compile the model")
model=build_model()
print ("Summarize the model")
print(model.summary())  # Print this only once
#model.save(MODEL_FILE+'.model')
# Out:
# Compile the model
# COMPILE...
# ...COMPILED
# Summarize the model
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 2000, 32)          512
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 2000, 32)          3104
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 1000, 32)          0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 1000, 32)          3104
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 1000, 32)          3104
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 500, 32)           0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 500, 32)           3104
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 500, 32)           3104
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 250, 32)           0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 250, 32)           3104
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 250, 32)           3104
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 125, 32)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 4000)              0
# _________________________________________________________________
# dense (Dense)                (None, 24)                96024
# _________________________________________________________________
# dropout (Dropout)            (None, 24)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 24)                600
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 24)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 25
# =================================================================
# Total params: 118,889
# Trainable params: 118,889
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#MINLEN=200
#MAXLEN=2000
print("Load data from files.")
nc_seq=tools.load_fasta(NC_FILENAME,0)
pc_seq=tools.load_fasta(PC_FILENAME,1)
train_set=pd.concat((nc_seq,pc_seq),axis=0)
nc_seq=None
pc_seq=None
print("Ready: train_set")
#train_set
subset=tools.make_slice(train_set,MINLEN,MAXLEN)# One array to two: X and y
(X1,y_train)=tools.separate_X_and_y(subset)
# X1 is pandas df of ("list" of one sequence)
X2=X1.to_numpy()  # numpy ndarray of ("list" of one sequence)
X3=[elem[0] for elem in X2]  # numpy dnarray of str
X4=tools.uniform_length(X3,MAXLEN)
X5= [tools.one_hot(x) for x in X4]
X_train=np.asarray(X5)
y_train=y_train.to_numpy()

subset=None
X1=None
X2=None
X3=None
X4=None
X5=None
# Out:
# Load data from files.
# Ready: train_set

# %%
print ("Cross validation")
do_cross_validation(X_train,y_train,model)  
print ("Done")
# Out:
# Cross validation
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/50
# 338/338 [==============================] - 6s 9ms/step - loss: 0.7435 - accuracy: 0.4981 - val_loss: 0.6938 - val_accuracy: 0.5167
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JLSIM6K.cv.1.best/assets
# Epoch 2/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.7120 - accuracy: 0.5135 - val_loss: 0.6927 - val_accuracy: 0.5167
# Epoch 3/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.7069 - accuracy: 0.4964 - val_loss: 0.6942 - val_accuracy: 0.4833
# Epoch 4/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.6996 - accuracy: 0.5112 - val_loss: 0.6927 - val_accuracy: 0.5167
# Epoch 5/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.7018 - accuracy: 0.4931 - val_loss: 0.7004 - val_accuracy: 0.4833
# Epoch 6/50
# 338/338 [==============================] - 3s 8ms/step - loss: 0.7003 - accuracy: 0.5015 - val_loss: 0.6952 - val_accuracy: 0.4833
# Epoch 7/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.6992 - accuracy: 0.4930 - val_loss: 0.6969 - val_accuracy: 0.4833
# Epoch 8/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.6972 - accuracy: 0.4953 - val_loss: 0.6926 - val_accuracy: 0.5167
# Epoch 9/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.6959 - accuracy: 0.5066 - val_loss: 0.6965 - val_accuracy: 0.4833
# Epoch 10/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.6957 - accuracy: 0.4937 - val_loss: 0.6929 - val_accuracy: 0.5167
# Epoch 11/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.6943 - accuracy: 0.5026 - val_loss: 0.6932 - val_accuracy: 0.4833
# Epoch 12/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.6947 - accuracy: 0.4931 - val_loss: 0.6927 - val_accuracy: 0.5167
# Epoch 13/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.6939 - accuracy: 0.5058 - val_loss: 0.6933 - val_accuracy: 0.4833
# Epoch 14/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.6939 - accuracy: 0.5005 - val_loss: 0.6936 - val_accuracy: 0.4833
# Epoch 15/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.6943 - accuracy: 0.4817 - val_loss: 0.6951 - val_accuracy: 0.4833
# Epoch 16/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.6940 - accuracy: 0.5010 - val_loss: 0.6947 - val_accuracy: 0.4833
# Epoch 17/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.6932 - accuracy: 0.5040 - val_loss: 0.6936 - val_accuracy: 0.4833
# Epoch 18/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.

# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/50
# 338/338 [==============================] - 4s 8ms/step - loss: 0.7156 - accuracy: 0.5277 - val_loss: 0.6541 - val_accuracy: 0.5983
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JLSIM6K.cv.4.best/assets
# Epoch 2/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.6148 - accuracy: 0.6609 - val_loss: 0.5688 - val_accuracy: 0.7075
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JLSIM6K.cv.4.best/assets
# Epoch 3/50
# 338/338 [==============================] - 3s 8ms/step - loss: 0.5272 - accuracy: 0.7421 - val_loss: 0.5275 - val_accuracy: 0.7417
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JLSIM6K.cv.4.best/assets
# Epoch 4/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.4374 - accuracy: 0.8033 - val_loss: 0.4471 - val_accuracy: 0.8050
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JLSIM6K.cv.4.best/assets
# Epoch 5/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.3494 - accuracy: 0.8501 - val_loss: 0.3923 - val_accuracy: 0.8258
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JLSIM6K.cv.4.best/assets
# Epoch 6/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.2294 - accuracy: 0.9095 - val_loss: 0.1843 - val_accuracy: 0.9225
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JLSIM6K.cv.4.best/assets
# Epoch 7/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.1148 - accuracy: 0.9594 - val_loss: 0.1288 - val_accuracy: 0.9542
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JLSIM6K.cv.4.best/assets
# Epoch 8/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.0916 - accuracy: 0.9704 - val_loss: 0.0966 - val_accuracy: 0.9692
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JLSIM6K.cv.4.best/assets
# Epoch 9/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.0697 - accuracy: 0.9768 - val_loss: 0.0703 - val_accuracy: 0.9758
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JLSIM6K.cv.4.best/assets
# Epoch 10/50
# 338/338 [==============================] - 3s 8ms/step - loss: 0.0420 - accuracy: 0.9874 - val_loss: 0.1121 - val_accuracy: 0.9675
# Epoch 11/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.0398 - accuracy: 0.9874 - val_loss: 0.0582 - val_accuracy: 0.9808
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JLSIM6K.cv.4.best/assets
# Epoch 12/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.0436 - accuracy: 0.9879 - val_loss: 0.0746 - val_accuracy: 0.9767
# Epoch 13/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.0411 - accuracy: 0.9857 - val_loss: 0.1370 - val_accuracy: 0.9450
# Epoch 14/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.0587 - accuracy: 0.9800 - val_loss: 0.0773 - val_accuracy: 0.9775
# Epoch 15/50
# 338/338 [==============================] - 3s 7ms/step - loss: 0.0409 - accuracy: 0.9871 - val_loss: 0.0560 - val_accuracy: 0.9817
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JLSIM6K.cv.4.best/assets
# Epoch 16/50
# 338/338 [==============================] - 3s 8ms/step - loss: 0.0287 - accuracy: 0.9911 - val_loss: 0.0576 - val_accuracy: 0.9850
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JLSIM6K.cv.4.best/assets
# Epoch 17/50
# 338/338 [==============================] - 3s 8ms/step - loss: 0.0162 - accuracy: 0.9950 - val_loss: 0.0675 - val_accuracy: 0.9850
# Epoch 18/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.0512 - accuracy: 0.9835 - val_loss: 0.0769 - val_accuracy: 0.9800
# Epoch 19/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.0471 - accuracy: 0.9872 - val_loss: 0.0818 - val_accuracy: 0.9783
# Epoch 20/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.0249 - accuracy: 0.9920 - val_loss: 0.0570 - val_accuracy: 0.9883
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JLSIM6K.cv.4.best/assets
# Epoch 21/50
# 338/338 [==============================] - 3s 7ms/step - loss: 0.0134 - accuracy: 0.9968 - val_loss: 0.0647 - val_accuracy: 0.9842
# Epoch 22/50
# 338/338 [==============================] - 3s 8ms/step - loss: 0.0209 - accuracy: 0.9931 - val_loss: 0.0691 - val_accuracy: 0.9817
# Epoch 23/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.0304 - accuracy: 0.9897 - val_loss: 0.0697 - val_accuracy: 0.9850
# Epoch 24/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JLSIM6K.cv.5.best/assets
# Epoch 2/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.6390 - accuracy: 0.6436 - val_loss: 0.5765 - val_accuracy: 0.7017
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JLSIM6K.cv.5.best/assets
# Epoch 3/50
# 338/338 [==============================] - 3s 8ms/step - loss: 0.5744 - accuracy: 0.7001 - val_loss: 0.5203 - val_accuracy: 0.7492
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JLSIM6K.cv.5.best/assets
# Epoch 4/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.4498 - accuracy: 0.7937 - val_loss: 0.4821 - val_accuracy: 0.7775
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JLSIM6K.cv.5.best/assets
# Epoch 5/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.3245 - accuracy: 0.8655 - val_loss: 0.2421 - val_accuracy: 0.9050
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JLSIM6K.cv.5.best/assets
# Epoch 6/50
# 338/338 [==============================] - 3s 7ms/step - loss: 0.1826 - accuracy: 0.9317 - val_loss: 0.1803 - val_accuracy: 0.9250
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JLSIM6K.cv.5.best/assets
# Epoch 7/50
# 338/338 [==============================] - 3s 8ms/step - loss: 0.0984 - accuracy: 0.9666 - val_loss: 0.0822 - val_accuracy: 0.9717
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JLSIM6K.cv.5.best/assets
# Epoch 8/50
# 338/338 [==============================] - 3s 8ms/step - loss: 0.0807 - accuracy: 0.9733 - val_loss: 0.0693 - val_accuracy: 0.9742
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JLSIM6K.cv.5.best/assets
# Epoch 9/50
# 338/338 [==============================] - 3s 8ms/step - loss: 0.0581 - accuracy: 0.9804 - val_loss: 0.0647 - val_accuracy: 0.9792
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JLSIM6K.cv.5.best/assets
# Epoch 10/50
# 338/338 [==============================] - 3s 7ms/step - loss: 0.0475 - accuracy: 0.9869 - val_loss: 0.0475 - val_accuracy: 0.9825
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JLSIM6K.cv.5.best/assets
# Epoch 11/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.0446 - accuracy: 0.9859 - val_loss: 0.0473 - val_accuracy: 0.9850
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JLSIM6K.cv.5.best/assets
# Epoch 12/50
# 338/338 [==============================] - 3s 8ms/step - loss: 0.0375 - accuracy: 0.9889 - val_loss: 0.0464 - val_accuracy: 0.9833
# Epoch 13/50
# 338/338 [==============================] - 3s 8ms/step - loss: 0.0490 - accuracy: 0.9828 - val_loss: 0.0363 - val_accuracy: 0.9883
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JLSIM6K.cv.5.best/assets
# Epoch 14/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.0632 - accuracy: 0.9808 - val_loss: 0.0176 - val_accuracy: 0.9950
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JLSIM6K.cv.5.best/assets
# Epoch 15/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.0309 - accuracy: 0.9907 - val_loss: 0.0598 - val_accuracy: 0.9825
# Epoch 16/50
# 338/338 [==============================] - 3s 7ms/step - loss: 0.0368 - accuracy: 0.9873 - val_loss: 0.0435 - val_accuracy: 0.9892
# Epoch 17/50
# 338/338 [==============================] - 3s 8ms/step - loss: 0.0236 - accuracy: 0.9929 - val_loss: 0.0326 - val_accuracy: 0.9908
# Epoch 18/50
# 338/338 [==============================] - 3s 8ms/step - loss: 0.0241 - accuracy: 0.9920 - val_loss: 0.0392 - val_accuracy: 0.9867
# Epoch 19/50
# 338/338 [==============================] - 3s 8ms/step - loss: 0.0331 - accuracy: 0.9896 - val_loss: 0.0372 - val_accuracy: 0.9908
# Epoch 20/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.0256 - accuracy: 0.9906 - val_loss: 0.0230 - val_accuracy: 0.9917
# Epoch 21/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.0212 - accuracy: 0.9937 - val_loss: 0.1136 - val_accuracy: 0.9733
# Epoch 22/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.0251 - accuracy: 0.9922 - val_loss: 0.0591 - val_accuracy: 0.9867
# Epoch 23/50
# 338/338 [==============================] - 3s 8ms/step - loss: 0.0371 - accuracy: 0.9885 - val_loss: 0.0595 - val_accuracy: 0.9842
# Epoch 24/50
# 338/338 [==============================] - 3s 8ms/step - loss: 0.0521 - accuracy: 0.9831 - val_loss: 0.0293 - val_accuracy: 0.9925
# Epoch 25/50
# 338/338 [==============================] - 3s 8ms/step - loss: 0.0190 - accuracy: 0.9939 - val_loss: 0.0372 - val_accuracy: 0.9867
# Epoch 26/50
# 338/338 [==============================] - 3s 8ms/step - loss: 0.0195 - accuracy: 0.9935 - val_loss: 0.0287 - val_accuracy: 0.9925
# Epoch 27/50
# 338/338 [==============================] - 3s 8ms/step - loss: 0.0129 - accuracy: 0.9970 - val_loss: 0.0397 - val_accuracy: 0.9883
# Epoch 28/50
# 338/338 [==============================] - 3s 8ms/step - loss: 0.0248 - accuracy: 0.9922 - val_loss: 0.0263 - val_accuracy: 0.9933
# Epoch 29/50
# 338/338 [==============================] - 3s 8ms/step - loss: 0.0156 - accuracy: 0.9949 - val_loss: 0.0367 - val_accuracy: 0.9908
# Epoch 30/50
# 338/338 [==============================] - 3s 8ms/step - loss: 0.0537 - accuracy: 0.9812 - val_loss: 0.0345 - val_accuracy: 0.9900
# Epoch 31/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.0307 - accuracy: 0.9912 - val_loss: 0.0349 - val_accuracy: 0.9917
# Epoch 32/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.0157 - accuracy: 0.9953 - val_loss: 0.0272 - val_accuracy: 0.9925
# Epoch 33/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.0499 - accuracy: 0.9837 - val_loss: 0.0218 - val_accuracy: 0.9917
# Epoch 34/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.0236 - accuracy: 0.9934 - val_loss: 0.0324 - val_accuracy: 0.9908
# Epoch 35/50
# 338/338 [==============================] - 3s 7ms/step - loss: 0.0151 - accuracy: 0.9956 - val_loss: 0.0533 - val_accuracy: 0.9892
# Epoch 36/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.0188 - accuracy: 0.9946 - val_loss: 0.0554 - val_accuracy: 0.9858
# Epoch 37/50
# 338/338 [==============================] - 3s 8ms/step - loss: 0.0275 - accuracy: 0.9913 - val_loss: 0.0394 - val_accuracy: 0.9892
# Epoch 38/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.0243 - accuracy: 0.9932 - val_loss: 0.0377 - val_accuracy: 0.9933
# Epoch 39/50
# 338/338 [==============================] - 3s 8ms/step - loss: 0.0151 - accuracy: 0.9962 - val_loss: 0.0407 - val_accuracy: 0.9908
# Epoch 40/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.0205 - accuracy: 0.9936 - val_loss: 0.1017 - val_accuracy: 0.9733
# Epoch 41/50
# 338/338 [==============================] - 3s 8ms/step - loss: 0.0604 - accuracy: 0.9789 - val_loss: 0.0513 - val_accuracy: 0.9850
# Epoch 42/50
# 338/338 [==============================] - 3s 8ms/step - loss: 0.0409 - accuracy: 0.9883 - val_loss: 0.0268 - val_accuracy: 0.9900
# Epoch 43/50
# 338/338 [==============================] - 3s 7ms/step - loss: 0.0424 - accuracy: 0.9859 - val_loss: 0.0220 - val_accuracy: 0.9925
# Epoch 44/50
# 338/338 [==============================] - 3s 8ms/step - loss: 0.0201 - accuracy: 0.9950 - val_loss: 0.0157 - val_accuracy: 0.9950
# Epoch 45/50
# 338/338 [==============================] - 3s 8ms/step - loss: 0.0144 - accuracy: 0.9952 - val_loss: 0.0384 - val_accuracy: 0.9908
# Epoch 46/50
# 338/338 [==============================] - 3s 8ms/step - loss: 0.0150 - accuracy: 0.9947 - val_loss: 0.0316 - val_accuracy: 0.9900
# Epoch 47/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.0092 - accuracy: 0.9978 - val_loss: 0.0296 - val_accuracy: 0.9925
# Epoch 48/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.0308 - accuracy: 0.9905 - val_loss: 0.0285 - val_accuracy: 0.9925
# Epoch 49/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.0457 - accuracy: 0.9841 - val_loss: 0.0322 - val_accuracy: 0.9925
# Epoch 50/50
# 338/338 [==============================] - 2s 7ms/step - loss: 0.0305 - accuracy: 0.9897 - val_loss: 0.0198 - val_accuracy: 0.9950
# Fold 5, 50 epochs, 156 sec
# accuracy: 99.50%
#
# 5-way Cross Validation mean 70.27% (+/- 23.81%)
# Done
