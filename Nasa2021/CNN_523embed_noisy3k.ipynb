# %% [markdown]
# <a href="https://colab.research.google.com/github/ShepherdCode/ShepherdML/blob/master/Nasa2021/CNN_523embed_noisy3k.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://colab.research.google.com/github/ShepherdCode/ShepherdML/blob/master/Nasa2021/CNN_523.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CNN 523 3k noisy
#
# 1. Four layers of CNNS and MaxPooling
# 2. Drop out at 0.2
# 3. Variable filters and dense neurons
# 4. 10% Noise, datasets of 3k coding and noncoding from 3k to 192k

# %%
#NC_FILENAME='ncRNA.tiny50.fasta'
#PC_FILENAME='pcRNA.tiny50.fasta'
#NC_FILENAME='ncRNA.gc34.processed.fasta'
#PC_FILENAME='pcRNA.gc34.processed.fasta'
NC_FILENAME='noisy_noncod_3000_10.fasta'  # CHANGE THIS TO 1000, 2000, 4000, etc.
PC_FILENAME='noisy_coding_3000_10.fasta'
NC_VAL_FILE='noncod_validation.fasta'  # 'noncod_validation.fasta'  # CHANGE THIS TO THE UNIFORM VALIDATION FILE
PC_VAL_FILE='coding_validation.fasta'  # 'coding_validation.fasta'

MODEL_FILE='JUNK1'   # CHANGE THIS IF YOU WANT TO SAVE THE MODEL!
DATAPATH=''

try:
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
except:
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"
NC_FILENAME = DATAPATH+NC_FILENAME
PC_FILENAME = DATAPATH+PC_FILENAME
NC_VAL_FILE = DATAPATH+NC_VAL_FILE
PC_VAL_FILE = DATAPATH+PC_VAL_FILE
MODEL_FILE=DATAPATH+MODEL_FILE

EPOCHS=20  # DECIDE ON SOME AMOUNT AND STICK WITH IT
SPLITS=5
K=1
VOCABULARY_SIZE=4**K+1   # e.g. K=3 => 64 DNA K-mers + 'NNN'
EMBED_DIMEN=2
FILTERS=32
KERNEL=3
NEURONS=24
DROP=0.2
MINLEN=200
MAXLEN=1000    # THIS HAS TO MATCH THE SIMULATION DATA
DENSE_LEN = 1000
ACT="tanh"
# Out:
# Mounted at /content/drive/

# %%
# Load our own tools
# TO DO: don't go to GitHub if the file is already local.
GITHUB = True
if GITHUB:
    #!pip install requests  # Uncomment this if necessary. Seems to be pre-installed.
    import requests
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/ShepherdML/master/Strings/tools_fasta.py')
    with open('tools_fasta.py', 'w') as f:
        f.write(r.text)
    # TO DO: delete the file after import
import tools_fasta as tools
tools.yahoo()  # If this prints "Yahoo!" the the import was successful.

TOOLS_CHANGED = False   # set to True to re-run with a new version of tools
if TOOLS_CHANGED:
  from importlib import reload 
  tools=reload(tools)
  print(dir(tools))   # run this to see EVERYTHING in the tools module
# Out:
# Yahoo!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import StratifiedKFold
import tensorflow as tf
from tensorflow import keras
import time
dt='float32'
tf.keras.backend.set_floatx(dt)

# %% [markdown]
# Build model

# %%
def compile_model(model):
    print("COMPILE...")
    bc=tf.keras.losses.BinaryCrossentropy(from_logits=False)
    model.compile(loss=bc, optimizer="adam", metrics=["accuracy"])
    print("...COMPILED")
    return model

def build_model():
    #SHAPE=(MAXLEN,5)  
    SHAPE=(MAXLEN,4)  
    # 4 input letters, 4 output dimensions, 1000 letters/RNA
    elayer  = keras.layers.Embedding(4,4,input_length=1000) 

    clayer1 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same",
                                 input_shape=SHAPE)
    clayer2 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer3 = keras.layers.MaxPooling1D(2)
    clayer4 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer5 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer6 = keras.layers.MaxPooling1D(2)
    clayer7 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer8 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer9 = keras.layers.MaxPooling1D(2)
    clayer10 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer11 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer12 = keras.layers.MaxPooling1D(2)

    clayer13 = keras.layers.Flatten()

    dlayer1 = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt, input_shape=[DENSE_LEN])
    dlayer2 = keras.layers.Dropout(DROP)
    dlayer3 = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt)
    dlayer4 = keras.layers.Dropout(DROP)
    output_layer = keras.layers.Dense(1, activation="sigmoid", dtype=dt)

    cnn = keras.models.Sequential()
    cnn.add(elayer)
    cnn.add(clayer1)
    cnn.add(clayer2)
    cnn.add(clayer3)
    cnn.add(clayer4)
    cnn.add(clayer5)
    cnn.add(clayer6)
    cnn.add(clayer7)
    cnn.add(clayer8)
    cnn.add(clayer9)
    cnn.add(clayer10)
    cnn.add(clayer11)
    cnn.add(clayer12)
    cnn.add(clayer13)
    cnn.add(dlayer1)
    cnn.add(dlayer2)
    cnn.add(dlayer3)
    cnn.add(dlayer4)
    cnn.add(output_layer)
    mlpc = compile_model(cnn)
    return mlpc

# %% [markdown]
# Cross validation

# %%
def do_cross_validation(X,y,given_model,X_VALID,Y_VALID):
    cv_scores = []
    fold=0
    splitter = ShuffleSplit(n_splits=SPLITS, test_size=0.1, random_state=37863)
    for train_index,valid_index in splitter.split(X):
        fold += 1
        X_train=X[train_index] # use iloc[] for dataframe
        y_train=y[train_index]
        X_valid=X[valid_index]
        y_valid=y[valid_index]        
        # Avoid continually improving the same model.
        model = compile_model(keras.models.clone_model(given_model))
        bestname=MODEL_FILE+".cv."+str(fold)+".best"
        mycallbacks = [keras.callbacks.ModelCheckpoint(
            filepath=bestname, save_best_only=True, 
            monitor='val_accuracy', mode='max')]   
        print("FIT")
        start_time=time.time()
        history=model.fit(X_train, y_train, 
                epochs=EPOCHS, verbose=1, callbacks=mycallbacks,
                validation_data=(X_valid,y_valid))
        # THE VALIDATION ABOVE IS JUST FOR SHOW
        end_time=time.time()
        elapsed_time=(end_time-start_time)                        
        print("Fold %d, %d epochs, %d sec"%(fold,EPOCHS,elapsed_time))
        pd.DataFrame(history.history).plot(figsize=(8,5))
        plt.grid(True)
        plt.gca().set_ylim(0,1)
        plt.show()
        best_model=keras.models.load_model(bestname)
        # THE VALIDATION BELOW IS FOR KEEPS
        scores = best_model.evaluate(X_VALID, Y_VALID, verbose=0)
        print("%s: %.2f%%" % (best_model.metrics_names[1], scores[1]*100))
        cv_scores.append(scores[1] * 100)  
    print()
    print("%d-way Cross Validation mean %.2f%% (+/- %.2f%%)" % (fold, np.mean(cv_scores), np.std(cv_scores)))

# %% [markdown]
# ## Train on RNA lengths 200-1Kb

# %%
print ("Compile the model")
model=build_model()
print ("Summarize the model")
print(model.summary())  # Print this only once
#model.save(MODEL_FILE+'.model')
# Out:
# Compile the model
# COMPILE...
# ...COMPILED
# Summarize the model
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 1000, 4)           16
# _________________________________________________________________
# conv1d (Conv1D)              (None, 1000, 32)          416
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 1000, 32)          3104
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 500, 32)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 500, 32)           3104
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 500, 32)           3104
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 250, 32)           0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 250, 32)           3104
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 250, 32)           3104
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 125, 32)           0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 125, 32)           3104
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 125, 32)           3104
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 62, 32)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 1984)              0
# _________________________________________________________________
# dense (Dense)                (None, 24)                47640
# _________________________________________________________________
# dropout (Dropout)            (None, 24)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 24)                600
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 24)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 25
# =================================================================
# Total params: 70,425
# Trainable params: 70,425
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
def load_data_from_files(nc_filename,pc_filename):
  FREEMEM=True   # use False for debugging, True for production
  print("Load data from files.")
  nc_seq=tools.load_fasta(nc_filename,0)
  pc_seq=tools.load_fasta(pc_filename,1)
  train_set=pd.concat((nc_seq,pc_seq),axis=0)
  print("Ready: train_set")
  subset=tools.make_slice(train_set,MINLEN,MAXLEN)# One array to two: X and y
  if FREEMEM:
      nc_seq=None
      pc_seq=None
      train_set=None
  (X1,y_train)=tools.separate_X_and_y(subset)
  # X1 is pandas df of ("list" of one sequence)
  X2=X1.to_numpy()  # numpy ndarray of ("list" of one sequence)
  X3=[elem[0] for elem in X2]  # numpy ndarray of ACGT-str
  # X3? It might be faster to use int-array than char-array. Come back to this.
  X4=X3  # no-op
  print("X4",type(X4))
  #print(X4[0])
  if FREEMEM:
      X1=None
      X2=None
      X3=None
  X5=[]
  dna_to_int = {'A':0,'C':1,'G':2,'T':3}
  for x in X4:
      a=[]
      for c in x:
          i = dna_to_int[c]
          a.append(i)
      X5.append(a)
  X5=np.asarray(X5)
  print("X5",type(X5))
  print(X5.shape)
  if FREEMEM:
      X4=None
  X_train=X5
  if FREEMEM:
      X5=None
  print("X_train",type(X_train))
  y_train=y_train.to_numpy()
  print(X_train.shape)
  print(X_train[0].shape)
  print(X_train[0])
  return X_train,y_train

# %%
print("Loading training data...")
X_train,y_train = load_data_from_files(NC_FILENAME,PC_FILENAME)
# Out:
# Loading training data...
# Load data from files.
# Ready: train_set
# X4 <class 'list'>
# X5 <class 'numpy.ndarray'>
# (6000, 1000)
# X_train <class 'numpy.ndarray'>
# (6000, 1000)
# (1000,)
# [3 1 1 0 2 3 2 2 3 2 1 1 1 0 2 1 2 2 0 0 0 1 0 3 3 3 3 3 1 0 2 2 3 3 2 3 2
#  2 1 3 2 3 2 3 0 2 2 1 0 0 0 1 2 2 0 2 1 2 0 3 2 0 1 3 3 2 2 0 2 2 3 3 3 3
#  3 0 3 3 1 3 2 3 1 2 3 1 3 0 1 1 3 1 3 0 2 1 2 3 3 0 3 2 0 0 2 2 3 2 3 1 2
#  3 1 2 2 2 1 1 1 1 2 3 3 1 3 1 1 2 1 3 1 3 1 2 0 2 1 3 2 3 3 3 2 1 1 2 3 3
#  1 2 2 1 1 0 2 0 1 3 0 1 2 2 1 2 0 0 3 0 0 2 1 3 2 3 3 0 1 1 0 3 2 3 0 1 3
#  0 1 0 3 1 3 0 2 0 1 0 3 0 0 2 1 0 0 3 1 2 1 2 0 0 1 1 2 0 3 2 2 3 0 2 2 1
#  3 3 1 2 3 2 3 1 2 0 1 3 2 0 3 2 0 3 0 2 3 2 2 1 0 1 2 2 1 0 2 3 1 0 0 0 0
#  2 1 0 0 0 1 2 2 2 1 2 0 1 0 3 3 1 1 3 1 1 2 2 3 0 1 1 1 3 3 3 1 1 3 0 1 3
#  0 1 0 3 1 2 2 2 0 2 0 0 2 0 1 1 1 3 1 2 3 2 2 3 1 0 1 0 0 2 3 2 2 2 2 2 3
#  3 2 1 0 3 1 0 0 3 2 3 2 2 3 3 1 2 0 0 1 3 0 0 3 0 3 0 1 3 2 1 1 3 0 1 0 0
#  2 3 0 3 1 2 1 0 1 0 2 0 1 2 1 1 3 0 2 2 0 1 0 2 3 3 3 1 2 1 2 2 2 3 3 0 2
#  2 3 1 0 1 2 2 1 2 2 1 3 2 1 0 2 1 3 0 0 3 2 3 1 1 0 0 0 3 1 0 2 0 2 3 3 1
#  3 0 3 0 2 3 2 2 3 1 1 2 0 0 0 1 1 2 2 3 2 3 0 1 0 3 1 0 0 0 3 2 3 2 1 1 2
#  2 1 0 3 1 3 1 1 0 1 0 2 2 1 2 3 1 0 2 3 3 1 2 2 2 2 0 2 3 3 1 0 1 3 1 2 2
#  3 0 2 2 1 0 0 3 2 1 0 2 0 1 1 1 2 0 0 3 2 2 1 3 0 2 3 1 1 1 3 2 0 1 0 3 3
#  3 0 1 1 2 3 3 1 0 0 2 1 3 3 3 1 0 1 2 2 2 3 3 3 1 0 3 3 3 2 3 0 1 3 3 3 0
#  1 0 2 1 2 1 3 2 0 0 2 2 2 3 3 3 1 1 2 3 3 2 3 2 1 0 3 1 0 0 2 0 1 3 2 1 1
#  1 0 3 1 0 3 3 0 3 2 2 0 1 3 2 2 0 0 1 0 0 1 3 3 2 2 2 1 3 0 3 1 2 0 2 3 1
#  1 0 2 2 3 3 1 3 1 3 1 1 2 1 3 0 1 1 0 0 3 0 3 1 1 3 2 2 2 3 0 0 2 2 2 1 1
#  0 2 1 2 3 3 2 2 1 1 2 1 0 1 0 0 0 1 1 3 0 1 1 0 3 0 3 1 1 0 3 2 1 0 2 0 0
#  2 3 3 0 2 1 2 2 1 3 3 0 2 3 2 0 2 3 0 1 0 2 2 2 2 1 2 0 2 0 0 2 0 1 0 1 3
#  1 0 1 1 2 1 2 1 1 1 0 2 2 3 0 1 2 0 1 2 1 1 0 3 1 0 3 2 3 0 3 0 3 0 2 1 3
#  0 2 1 0 1 1 2 1 2 0 2 0 0 3 2 2 1 0 2 2 2 3 1 0 0 0 0 3 1 2 0 3 0 0 0 2 2
#  2 3 1 1 2 2 2 3 0 0 3 2 2 2 2 0 3 3 3 1 1 2 2 0 1 3 0 0 1 2 1 2 0 0 0 2 2
#  1 0 3 3 2 3 2 1 0 1 0 2 1 0 3 0 2 1 0 0 1 2 3 1 0 3 2 0 0 1 1 0 2 2 1 0 2
#  1 1 0 0 0 0 1 3 2 0 3 1 3 2 0 1 3 1 1 3 3 3 1 3 1 0 2 1 1 3 0 0 0 1 2 3 3
#  3 0 0 2 0 0 2 2 2 1 0 1 3 2 3 3 2 3 1 1 3 0 3 2 2 0 1 1 1 1 2 1 2 3 3 1 2
#  1]

# %%
print("Loading validation data...")
X_VALID,Y_VALID = load_data_from_files(NC_VAL_FILE,PC_VAL_FILE)
# Out:
# Loading validation data...
# Load data from files.
# Ready: train_set
# X4 <class 'list'>
# X5 <class 'numpy.ndarray'>
# (100000, 1000)
# X_train <class 'numpy.ndarray'>
# (100000, 1000)
# (1000,)
# [0 2 0 0 3 3 1 2 2 3 1 2 2 0 2 0 2 2 2 1 2 0 3 2 0 3 0 0 3 3 2 3 0 3 3 1 0
#  1 1 0 2 1 1 1 1 2 3 3 0 2 1 1 3 2 3 2 1 2 3 3 0 0 1 2 2 2 3 2 0 1 2 2 2 2
#  2 1 3 3 0 1 2 0 1 2 0 3 2 3 2 3 1 3 3 1 3 0 2 1 1 1 2 3 2 2 2 1 0 3 3 2 3
#  3 3 1 1 3 3 2 1 1 2 1 3 2 2 1 3 1 3 1 0 0 3 2 2 2 1 2 0 0 1 0 2 0 1 3 2 1
#  3 2 2 0 3 1 2 0 3 3 3 2 3 2 1 0 0 3 0 2 0 2 1 2 1 1 0 2 3 0 1 2 0 1 2 2 0
#  2 1 2 3 1 1 1 2 3 3 3 2 1 1 0 2 3 1 1 2 1 0 0 3 2 1 0 2 2 3 2 0 0 3 1 3 0
#  2 3 0 2 3 1 2 3 1 1 2 3 3 3 3 3 0 0 1 0 0 0 2 0 2 2 0 3 3 0 0 0 0 2 2 2 1
#  0 0 1 1 1 0 2 0 3 1 2 0 0 3 3 1 1 2 1 3 2 3 2 1 2 2 0 0 1 0 1 0 3 3 3 0 0
#  0 2 3 0 3 2 3 0 1 1 3 0 1 1 1 3 2 1 3 3 1 0 0 0 1 2 3 0 2 3 1 1 1 3 0 3 1
#  2 0 1 2 1 2 2 3 1 1 1 2 0 2 0 0 3 3 0 2 1 0 0 1 0 1 3 3 2 3 3 1 0 3 2 3 0
#  2 3 3 2 0 1 0 0 3 1 1 2 2 1 3 2 0 1 0 0 3 2 3 1 0 3 0 3 3 1 1 3 0 0 0 1 2
#  1 1 1 3 1 2 2 1 1 1 2 1 0 1 1 2 3 2 1 2 1 3 3 2 3 2 2 2 3 3 0 3 1 0 3 3 0
#  3 2 2 0 1 2 1 1 1 0 3 3 0 1 1 2 3 2 1 2 2 2 0 0 0 2 1 2 1 3 0 3 1 0 0 1 3
#  2 3 3 2 1 0 3 3 0 1 1 0 0 3 3 1 0 2 2 1 2 0 0 0 2 0 1 2 2 3 1 0 0 2 0 0 1
#  3 3 2 0 1 0 3 1 3 2 2 0 1 1 0 2 0 0 0 3 2 3 2 0 0 3 3 2 1 3 0 0 2 1 2 1 2
#  1 0 2 2 2 3 2 3 3 2 1 2 0 0 2 3 1 0 1 2 1 3 2 3 1 0 2 0 2 1 0 2 1 1 1 1 3
#  1 2 3 3 0 3 0 2 2 1 2 3 2 0 2 0 2 3 2 3 3 0 0 1 0 3 1 1 0 0 2 0 1 3 3 2 1
#  3 3 3 0 2 2 3 1 2 1 3 2 3 0 2 3 1 0 2 0 2 2 0 1 3 3 0 0 0 3 0 1 1 0 0 3 0
#  0 1 2 0 2 3 1 1 2 3 2 2 1 2 1 0 1 0 3 0 3 1 1 1 3 3 3 2 2 3 3 3 1 3 3 1 3
#  0 2 3 0 2 2 3 0 3 3 1 3 1 1 2 3 0 3 2 0 1 1 3 1 1 1 1 3 0 1 3 2 1 0 2 3 2
#  3 2 3 2 2 1 2 2 1 1 2 3 1 2 0 1 3 0 1 3 1 0 1 3 3 3 3 1 1 1 1 2 2 2 0 0 2
#  1 0 0 3 1 0 2 2 2 2 1 2 3 2 2 0 3 1 1 1 1 3 0 0 2 1 3 0 2 2 0 3 3 0 2 2 2
#  3 2 1 3 3 1 3 3 3 2 0 1 3 2 0 2 2 1 0 2 3 1 0 1 3 0 1 1 1 0 1 3 2 3 2 2 3
#  2 3 1 0 1 0 3 0 1 1 2 0 3 1 0 2 1 1 2 0 0 1 3 2 1 3 1 3 0 2 3 1 0 1 0 2 2
#  0 1 3 2 3 1 2 0 2 2 3 3 3 2 0 3 1 1 1 1 0 2 3 2 1 0 3 3 1 3 2 1 0 0 1 2 2
#  3 2 1 0 0 2 2 3 0 2 0 1 2 3 3 1 0 3 2 3 0 2 1 2 3 0 1 0 2 3 1 0 1 0 1 0 1
#  0 0 3 1 3 0 1 2 0 0 3 0 2 2 1 1 1 3 2 0 2 2 1 2 0 0 1 1 2 2 1 1 1 1 1 2 0
#  3]

# %%
print ("Cross validation")
do_cross_validation(X_train,y_train,model,X_VALID,Y_VALID)  
print ("Done")
# Out:
# Cross validation
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/20
# 169/169 [==============================] - 6s 10ms/step - loss: 0.6958 - accuracy: 0.5135 - val_loss: 0.6922 - val_accuracy: 0.5450
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.1.best/assets
# Epoch 2/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6944 - accuracy: 0.5209 - val_loss: 0.6721 - val_accuracy: 0.6083
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.1.best/assets
# Epoch 3/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6839 - accuracy: 0.5663 - val_loss: 0.6535 - val_accuracy: 0.6200
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.1.best/assets
# Epoch 4/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6512 - accuracy: 0.6125 - val_loss: 0.6415 - val_accuracy: 0.6483
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.1.best/assets
# Epoch 5/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6208 - accuracy: 0.6681 - val_loss: 0.6478 - val_accuracy: 0.6217
# Epoch 6/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.5651 - accuracy: 0.7185 - val_loss: 0.6732 - val_accuracy: 0.6233
# Epoch 7/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.5042 - accuracy: 0.7609 - val_loss: 0.7150 - val_accuracy: 0.6217
# Epoch 8/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.4614 - accuracy: 0.7958 - val_loss: 0.7561 - val_accuracy: 0.6050
# Epoch 9/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.3846 - accuracy: 0.8425 - val_loss: 0.8151 - val_accuracy: 0.6150
# Epoch 10/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.3291 - accuracy: 0.8636 - val_loss: 0.9421 - val_accuracy: 0.6033
# Epoch 11/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.2704 - accuracy: 0.8886 - val_loss: 1.0095 - val_accuracy: 0.6083
# Epoch 12/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.2121 - accuracy: 0.9196 - val_loss: 1.1611 - val_accuracy: 0.5817
# Epoch 13/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.1893 - accuracy: 0.9250 - val_loss: 1.2142 - val_accuracy: 0.5817
# Epoch 14/20
# 169/169 [==============================] - 1s 5ms/step - loss: 0.1605 - accuracy: 0.9383 - val_loss: 1.3505 - val_accuracy: 0.6050
# Epoch 15/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.1566 - accuracy: 0.9398 - val_loss: 1.3819 - val_accuracy: 0.6250
# Epoch 16/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.1145 - accuracy: 0.9587 - val_loss: 1.4849 - val_accuracy: 0.6150
# Epoch 17/20
# 169/169 [==============================] - 1s 5ms/step - loss: 0.1416 - accuracy: 0.9505 - val_loss: 1.5617 - val_accuracy: 0.5917
# Epoch 18/20
# 169/169 [==============================] - 1s 5ms/step - loss: 0.0954 - accuracy: 0.9631 - val_loss: 1.5868 - val_accuracy: 0.6067
# Epoch 19/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.0867 - accuracy: 0.9677 - val_loss: 1.6941 - val_accuracy: 0.6033
# Epoch 20/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.1140 - accuracy: 0.9536 - val_loss: 1.5402 - val_accuracy: 0.5983
# Fold 1, 20 epochs, 33 sec
# accuracy: 65.10%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/20
# 169/169 [==============================] - 2s 7ms/step - loss: 0.6972 - accuracy: 0.4840 - val_loss: 0.6842 - val_accuracy: 0.5800
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.2.best/assets
# Epoch 2/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6705 - accuracy: 0.5930 - val_loss: 0.6889 - val_accuracy: 0.5350
# Epoch 3/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6709 - accuracy: 0.5968 - val_loss: 0.6966 - val_accuracy: 0.5433
# Epoch 4/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6519 - accuracy: 0.6222 - val_loss: 0.6806 - val_accuracy: 0.5783
# Epoch 5/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6185 - accuracy: 0.6748 - val_loss: 0.6345 - val_accuracy: 0.6583
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.2.best/assets
# Epoch 6/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.5750 - accuracy: 0.7153 - val_loss: 0.6729 - val_accuracy: 0.6133
# Epoch 7/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.5071 - accuracy: 0.7682 - val_loss: 0.7807 - val_accuracy: 0.5800
# Epoch 8/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.4475 - accuracy: 0.7951 - val_loss: 0.8054 - val_accuracy: 0.6050
# Epoch 9/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.3881 - accuracy: 0.8360 - val_loss: 0.8427 - val_accuracy: 0.6067
# Epoch 10/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.3293 - accuracy: 0.8624 - val_loss: 0.9931 - val_accuracy: 0.5900
# Epoch 11/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.2751 - accuracy: 0.8926 - val_loss: 1.0409 - val_accuracy: 0.5917
# Epoch 12/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.2202 - accuracy: 0.9149 - val_loss: 1.1410 - val_accuracy: 0.5817
# Epoch 13/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.1964 - accuracy: 0.9258 - val_loss: 1.3800 - val_accuracy: 0.5550
# Epoch 14/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.1673 - accuracy: 0.9354 - val_loss: 1.4410 - val_accuracy: 0.5233
# Epoch 15/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.1463 - accuracy: 0.9478 - val_loss: 1.5907 - val_accuracy: 0.5500
# Epoch 16/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.1299 - accuracy: 0.9495 - val_loss: 1.5821 - val_accuracy: 0.5567
# Epoch 17/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.1052 - accuracy: 0.9613 - val_loss: 1.6567 - val_accuracy: 0.5417
# Epoch 18/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.0901 - accuracy: 0.9677 - val_loss: 1.6985 - val_accuracy: 0.5633
# Epoch 19/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.0773 - accuracy: 0.9713 - val_loss: 1.9705 - val_accuracy: 0.5300
# Epoch 20/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.1173 - accuracy: 0.9541 - val_loss: 1.7348 - val_accuracy: 0.5533
# Fold 2, 20 epochs, 25 sec
# accuracy: 61.56%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/20
# 169/169 [==============================] - 3s 7ms/step - loss: 0.6976 - accuracy: 0.4821 - val_loss: 0.7000 - val_accuracy: 0.4767
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.3.best/assets
# Epoch 2/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6982 - accuracy: 0.4847 - val_loss: 0.6947 - val_accuracy: 0.4767
# Epoch 3/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6951 - accuracy: 0.5026 - val_loss: 0.6929 - val_accuracy: 0.5233
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.3.best/assets
# Epoch 4/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6943 - accuracy: 0.5044 - val_loss: 0.6948 - val_accuracy: 0.4767
# Epoch 5/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6952 - accuracy: 0.4962 - val_loss: 0.6952 - val_accuracy: 0.4767
# Epoch 6/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6956 - accuracy: 0.4916 - val_loss: 0.6973 - val_accuracy: 0.4767
# Epoch 7/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6949 - accuracy: 0.5037 - val_loss: 0.6888 - val_accuracy: 0.5517
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.3.best/assets
# Epoch 8/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6924 - accuracy: 0.5249 - val_loss: 0.6892 - val_accuracy: 0.5350
# Epoch 9/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6927 - accuracy: 0.5234 - val_loss: 0.6989 - val_accuracy: 0.4917
# Epoch 10/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6782 - accuracy: 0.5718 - val_loss: 0.6953 - val_accuracy: 0.5183
# Epoch 11/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6593 - accuracy: 0.6101 - val_loss: 0.6958 - val_accuracy: 0.5417
# Epoch 12/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6223 - accuracy: 0.6578 - val_loss: 0.6939 - val_accuracy: 0.5950
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.3.best/assets
# Epoch 13/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.5570 - accuracy: 0.7245 - val_loss: 0.7367 - val_accuracy: 0.5400
# Epoch 14/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.4887 - accuracy: 0.7731 - val_loss: 0.7916 - val_accuracy: 0.5567
# Epoch 15/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.4283 - accuracy: 0.8122 - val_loss: 0.8663 - val_accuracy: 0.5267
# Epoch 16/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.3498 - accuracy: 0.8583 - val_loss: 0.9299 - val_accuracy: 0.5517
# Epoch 17/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.2992 - accuracy: 0.8862 - val_loss: 1.0521 - val_accuracy: 0.5617
# Epoch 18/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.2489 - accuracy: 0.9025 - val_loss: 1.1972 - val_accuracy: 0.5317
# Epoch 19/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.2039 - accuracy: 0.9262 - val_loss: 1.2736 - val_accuracy: 0.5567
# Epoch 20/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.1972 - accuracy: 0.9274 - val_loss: 1.4031 - val_accuracy: 0.5600
# Fold 3, 20 epochs, 33 sec
# accuracy: 55.24%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/20
# 169/169 [==============================] - 2s 7ms/step - loss: 0.6972 - accuracy: 0.5106 - val_loss: 0.6943 - val_accuracy: 0.4733
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.4.best/assets
# Epoch 2/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6947 - accuracy: 0.5078 - val_loss: 0.6930 - val_accuracy: 0.5583
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.4.best/assets
# Epoch 3/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6946 - accuracy: 0.5039 - val_loss: 0.6918 - val_accuracy: 0.5267
# Epoch 4/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6940 - accuracy: 0.5069 - val_loss: 0.6944 - val_accuracy: 0.4733
# Epoch 5/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6943 - accuracy: 0.5173 - val_loss: 0.6921 - val_accuracy: 0.5267
# Epoch 6/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6932 - accuracy: 0.5127 - val_loss: 0.6904 - val_accuracy: 0.5000
# Epoch 7/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6900 - accuracy: 0.5566 - val_loss: 0.6963 - val_accuracy: 0.5283
# Epoch 8/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6568 - accuracy: 0.6028 - val_loss: 0.6553 - val_accuracy: 0.6033
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.4.best/assets
# Epoch 9/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6183 - accuracy: 0.6738 - val_loss: 0.6618 - val_accuracy: 0.6100
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.4.best/assets
# Epoch 10/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.5669 - accuracy: 0.7179 - val_loss: 0.6824 - val_accuracy: 0.6017
# Epoch 11/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.5154 - accuracy: 0.7604 - val_loss: 0.6964 - val_accuracy: 0.6133
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.4.best/assets
# Epoch 12/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.4573 - accuracy: 0.7880 - val_loss: 0.7593 - val_accuracy: 0.5883
# Epoch 13/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.4123 - accuracy: 0.8228 - val_loss: 0.8389 - val_accuracy: 0.5833
# Epoch 14/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.3402 - accuracy: 0.8599 - val_loss: 0.8979 - val_accuracy: 0.5783
# Epoch 15/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.2966 - accuracy: 0.8817 - val_loss: 0.9861 - val_accuracy: 0.5733
# Epoch 16/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.2808 - accuracy: 0.8941 - val_loss: 1.0824 - val_accuracy: 0.5867
# Epoch 17/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.2044 - accuracy: 0.9300 - val_loss: 1.1789 - val_accuracy: 0.6000
# Epoch 18/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.1876 - accuracy: 0.9342 - val_loss: 1.2886 - val_accuracy: 0.5700
# Epoch 19/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.1612 - accuracy: 0.9387 - val_loss: 1.4246 - val_accuracy: 0.5750
# Epoch 20/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.1474 - accuracy: 0.9488 - val_loss: 1.4483 - val_accuracy: 0.5767
# Fold 4, 20 epochs, 31 sec
# accuracy: 61.93%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/20
# 169/169 [==============================] - 2s 7ms/step - loss: 0.6961 - accuracy: 0.5137 - val_loss: 0.6839 - val_accuracy: 0.5600
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.5.best/assets
# Epoch 2/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6772 - accuracy: 0.5826 - val_loss: 0.6669 - val_accuracy: 0.5950
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.5.best/assets
# Epoch 3/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6475 - accuracy: 0.6311 - val_loss: 0.6467 - val_accuracy: 0.6133
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.5.best/assets
# Epoch 4/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6274 - accuracy: 0.6670 - val_loss: 0.6447 - val_accuracy: 0.6200
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.5.best/assets
# Epoch 5/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.5910 - accuracy: 0.6853 - val_loss: 0.6515 - val_accuracy: 0.6233
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.5.best/assets
# Epoch 6/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.5387 - accuracy: 0.7413 - val_loss: 0.6529 - val_accuracy: 0.6600
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.5.best/assets
# Epoch 7/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.4917 - accuracy: 0.7668 - val_loss: 0.6905 - val_accuracy: 0.6100
# Epoch 8/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.4451 - accuracy: 0.8019 - val_loss: 0.7617 - val_accuracy: 0.6367
# Epoch 9/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.3459 - accuracy: 0.8550 - val_loss: 0.8625 - val_accuracy: 0.6250
# Epoch 10/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.3110 - accuracy: 0.8751 - val_loss: 0.8760 - val_accuracy: 0.6183
# Epoch 11/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.2445 - accuracy: 0.9103 - val_loss: 1.0463 - val_accuracy: 0.5967
# Epoch 12/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.2066 - accuracy: 0.9230 - val_loss: 1.0604 - val_accuracy: 0.6067
# Epoch 13/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.1874 - accuracy: 0.9315 - val_loss: 1.2779 - val_accuracy: 0.6067
# Epoch 14/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.1590 - accuracy: 0.9408 - val_loss: 1.3118 - val_accuracy: 0.6017
# Epoch 15/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.1131 - accuracy: 0.9581 - val_loss: 1.4719 - val_accuracy: 0.6017
# Epoch 16/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.1518 - accuracy: 0.9414 - val_loss: 1.4785 - val_accuracy: 0.5900
# Epoch 17/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.1248 - accuracy: 0.9564 - val_loss: 1.5284 - val_accuracy: 0.5983
# Epoch 18/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.0878 - accuracy: 0.9721 - val_loss: 1.7213 - val_accuracy: 0.5750
# Epoch 19/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.0855 - accuracy: 0.9701 - val_loss: 1.6742 - val_accuracy: 0.6100
# Epoch 20/20
# 169/169 [==============================] - 1s 6ms/step - loss: 0.1117 - accuracy: 0.9617 - val_loss: 1.6934 - val_accuracy: 0.5850
# Fold 5, 20 epochs, 33 sec
# accuracy: 63.80%
#
# 5-way Cross Validation mean 61.53% (+/- 3.40%)
# Done
