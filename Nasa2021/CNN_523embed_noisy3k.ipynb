# %% [markdown]
# <a href="https://colab.research.google.com/github/ShepherdCode/ShepherdML/blob/master/Nasa2021/CNN_523embed_noisy3k.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://colab.research.google.com/github/ShepherdCode/ShepherdML/blob/master/Nasa2021/CNN_523.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CNN 523 3k noisy
#
# 1. Four layers of CNNS and MaxPooling
# 2. Drop out at 0.2
# 3. Variable filters and dense neurons
# 4. 10% Noise, datasets of 3k coding and noncoding from 3k to 192k

# %%
#NC_FILENAME='ncRNA.tiny50.fasta'
#PC_FILENAME='pcRNA.tiny50.fasta'
#NC_FILENAME='ncRNA.gc34.processed.fasta'
#PC_FILENAME='pcRNA.gc34.processed.fasta'
NC_FILENAME='noisy_noncod_3000_10.fasta'  # CHANGE THIS TO 1000, 2000, 4000, etc.
PC_FILENAME='noisy_coding_3000_10.fasta'
NC_VAL_FILE='noncod_validation.fasta'  # 'noncod_validation.fasta'  # CHANGE THIS TO THE UNIFORM VALIDATION FILE
PC_VAL_FILE='coding_validation.fasta'  # 'coding_validation.fasta'

MODEL_FILE='JUNK1'   # CHANGE THIS IF YOU WANT TO SAVE THE MODEL!
DATAPATH=''

try:
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
except:
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"
NC_FILENAME = DATAPATH+NC_FILENAME
PC_FILENAME = DATAPATH+PC_FILENAME
NC_VAL_FILE = DATAPATH+NC_VAL_FILE
PC_VAL_FILE = DATAPATH+PC_VAL_FILE
MODEL_FILE=DATAPATH+MODEL_FILE

EPOCHS=20  # DECIDE ON SOME AMOUNT AND STICK WITH IT
SPLITS=5
K=1
VOCABULARY_SIZE=4**K+1   # e.g. K=3 => 64 DNA K-mers + 'NNN'
EMBED_DIMEN=2
FILTERS=32
KERNEL=3
NEURONS=24
DROP=0.2
MINLEN=200
MAXLEN=1000    # THIS HAS TO MATCH THE SIMULATION DATA
DENSE_LEN = 1000
ACT="tanh"
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# Load our own tools
# TO DO: don't go to GitHub if the file is already local.
GITHUB = True
if GITHUB:
    #!pip install requests  # Uncomment this if necessary. Seems to be pre-installed.
    import requests
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/ShepherdML/master/Strings/tools_fasta.py')
    with open('tools_fasta.py', 'w') as f:
        f.write(r.text)
    # TO DO: delete the file after import
import tools_fasta as tools
tools.yahoo()  # If this prints "Yahoo!" the the import was successful.

TOOLS_CHANGED = False   # set to True to re-run with a new version of tools
if TOOLS_CHANGED:
  from importlib import reload 
  tools=reload(tools)
  print(dir(tools))   # run this to see EVERYTHING in the tools module
# Out:
# Yahoo!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import StratifiedKFold
import tensorflow as tf
from tensorflow import keras
import time
dt='float32'
tf.keras.backend.set_floatx(dt)

# %% [markdown]
# Build model

# %%
def compile_model(model):
    print("COMPILE...")
    bc=tf.keras.losses.BinaryCrossentropy(from_logits=False)
    model.compile(loss=bc, optimizer="adam", metrics=["accuracy"])
    print("...COMPILED")
    return model

def build_model():
    #SHAPE=(MAXLEN,5)  
    SHAPE=(MAXLEN,4)  
    # 4 input letters, 4 output dimensions, 1000 letters/RNA
    elayer  = keras.layers.Embedding(4,4,input_length=1000) 

    clayer1 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same",
                                 input_shape=SHAPE)
    clayer2 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer3 = keras.layers.MaxPooling1D(2)
    clayer4 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer5 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer6 = keras.layers.MaxPooling1D(2)
    clayer7 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer8 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer9 = keras.layers.MaxPooling1D(2)
    clayer10 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer11 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer12 = keras.layers.MaxPooling1D(2)

    clayer13 = keras.layers.Flatten()

    dlayer1 = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt, input_shape=[DENSE_LEN])
    dlayer2 = keras.layers.Dropout(DROP)
    dlayer3 = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt)
    dlayer4 = keras.layers.Dropout(DROP)
    output_layer = keras.layers.Dense(1, activation="sigmoid", dtype=dt)

    cnn = keras.models.Sequential()
    cnn.add(elayer)
    cnn.add(clayer1)
    cnn.add(clayer2)
    cnn.add(clayer3)
    cnn.add(clayer4)
    cnn.add(clayer5)
    cnn.add(clayer6)
    cnn.add(clayer7)
    cnn.add(clayer8)
    cnn.add(clayer9)
    cnn.add(clayer10)
    cnn.add(clayer11)
    cnn.add(clayer12)
    cnn.add(clayer13)
    cnn.add(dlayer1)
    cnn.add(dlayer2)
    cnn.add(dlayer3)
    cnn.add(dlayer4)
    cnn.add(output_layer)
    mlpc = compile_model(cnn)
    return mlpc

# %% [markdown]
# Cross validation

# %%
def do_cross_validation(X,y,given_model,X_VALID,Y_VALID):
    cv_scores = []
    fold=0
    splitter = ShuffleSplit(n_splits=SPLITS, test_size=0.1, random_state=37863)
    for train_index,valid_index in splitter.split(X):
        fold += 1
        X_train=X[train_index] # use iloc[] for dataframe
        y_train=y[train_index]
        X_valid=X[valid_index]
        y_valid=y[valid_index]        
        # Avoid continually improving the same model.
        model = compile_model(keras.models.clone_model(given_model))
        bestname=MODEL_FILE+".cv."+str(fold)+".best"
        mycallbacks = [keras.callbacks.ModelCheckpoint(
            filepath=bestname, save_best_only=True, 
            monitor='val_accuracy', mode='max')]   
        print("FIT")
        start_time=time.time()
        history=model.fit(X_train, y_train, 
                epochs=EPOCHS, verbose=1, callbacks=mycallbacks,
                validation_data=(X_valid,y_valid))
        # THE VALIDATION ABOVE IS JUST FOR SHOW
        end_time=time.time()
        elapsed_time=(end_time-start_time)                        
        print("Fold %d, %d epochs, %d sec"%(fold,EPOCHS,elapsed_time))
        pd.DataFrame(history.history).plot(figsize=(8,5))
        plt.grid(True)
        plt.gca().set_ylim(0,1)
        plt.show()
        best_model=keras.models.load_model(bestname)
        # THE VALIDATION BELOW IS FOR KEEPS
        scores = best_model.evaluate(X_VALID, Y_VALID, verbose=0)
        print("%s: %.2f%%" % (best_model.metrics_names[1], scores[1]*100))
        cv_scores.append(scores[1] * 100)  
    print()
    print("%d-way Cross Validation mean %.2f%% (+/- %.2f%%)" % (fold, np.mean(cv_scores), np.std(cv_scores)))

# %% [markdown]
# ## Train on RNA lengths 200-1Kb

# %%
print ("Compile the model")
model=build_model()
print ("Summarize the model")
print(model.summary())  # Print this only once
#model.save(MODEL_FILE+'.model')
# Out:
# Compile the model
# COMPILE...
# ...COMPILED
# Summarize the model
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 1000, 4)           16
# _________________________________________________________________
# conv1d (Conv1D)              (None, 1000, 32)          416
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 1000, 32)          3104
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 500, 32)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 500, 32)           3104
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 500, 32)           3104
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 250, 32)           0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 250, 32)           3104
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 250, 32)           3104
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 125, 32)           0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 125, 32)           3104
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 125, 32)           3104
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 62, 32)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 1984)              0
# _________________________________________________________________
# dense (Dense)                (None, 24)                47640
# _________________________________________________________________
# dropout (Dropout)            (None, 24)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 24)                600
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 24)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 25
# =================================================================
# Total params: 70,425
# Trainable params: 70,425
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
def load_data_from_files(nc_filename,pc_filename):
  FREEMEM=True   # use False for debugging, True for production
  print("Load data from files.")
  nc_seq=tools.load_fasta(nc_filename,0)
  pc_seq=tools.load_fasta(pc_filename,1)
  train_set=pd.concat((nc_seq,pc_seq),axis=0)
  print("Ready: train_set")
  subset=tools.make_slice(train_set,MINLEN,MAXLEN)# One array to two: X and y
  if FREEMEM:
      nc_seq=None
      pc_seq=None
      train_set=None
  (X1,y_train)=tools.separate_X_and_y(subset)
  # X1 is pandas df of ("list" of one sequence)
  X2=X1.to_numpy()  # numpy ndarray of ("list" of one sequence)
  X3=[elem[0] for elem in X2]  # numpy ndarray of ACGT-str
  # X3? It might be faster to use int-array than char-array. Come back to this.
  X4=X3  # no-op
  print("X4",type(X4))
  #print(X4[0])
  if FREEMEM:
      X1=None
      X2=None
      X3=None
  X5=[]
  dna_to_int = {'A':0,'C':1,'G':2,'T':3}
  for x in X4:
      a=[]
      for c in x:
          i = dna_to_int[c]
          a.append(i)
      X5.append(a)
  X5=np.asarray(X5)
  print("X5",type(X5))
  print(X5.shape)
  if FREEMEM:
      X4=None
  X_train=X5
  if FREEMEM:
      X5=None
  print("X_train",type(X_train))
  y_train=y_train.to_numpy()
  print(X_train.shape)
  print(X_train[0].shape)
  print(X_train[0])
  return X_train,y_train

# %%
print("Loading training data...")
X_train,y_train = load_data_from_files(NC_FILENAME,PC_FILENAME)
# Out:
# Loading training data...
20
# 169/169 [==============================] - 1s 8ms/step - loss: 0.3019 - accuracy: 0.8820 - val_loss: 0.8524 - val_accuracy: 0.6200
# Epoch 12/20
# 169/169 [==============================] - 1s 8ms/step - loss: 0.2525 - accuracy: 0.9063 - val_loss: 0.9850 - val_accuracy: 0.6133
# Epoch 13/20
# 169/169 [==============================] - 1s 7ms/step - loss: 0.2207 - accuracy: 0.9206 - val_loss: 1.0465 - val_accuracy: 0.6333
# Epoch 14/20
# 169/169 [==============================] - 1s 8ms/step - loss: 0.1670 - accuracy: 0.9393 - val_loss: 1.1411 - val_accuracy: 0.6233
# Epoch 15/20
# 169/169 [==============================] - 1s 8ms/step - loss: 0.1541 - accuracy: 0.9443 - val_loss: 1.2911 - val_accuracy: 0.6050
# Epoch 16/20
# 169/169 [==============================] - 1s 8ms/step - loss: 0.1296 - accuracy: 0.9567 - val_loss: 1.3238 - val_accuracy: 0.5950
# Epoch 17/20
# 169/169 [==============================] - 1s 8ms/step - loss: 0.1081 - accuracy: 0.9669 - val_loss: 1.3899 - val_accuracy: 0.6000
# Epoch 18/20
# 169/169 [==============================] - 1s 8ms/step - loss: 0.1135 - accuracy: 0.9606 - val_loss: 1.4392 - val_accuracy: 0.6200
# Epoch 19/20
# 169/169 [==============================] - 1s 8ms/step - loss: 0.1033 - accuracy: 0.9589 - val_loss: 1.4925 - val_accuracy: 0.6200
# Epoch 20/20
# 169/169 [==============================] - 1s 7ms/step - loss: 0.0958 - accuracy: 0.9689 - val_loss: 1.5781 - val_accuracy: 0.6033
# Fold 3, 20 epochs, 40 sec
# accuracy: 66.93%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/20
# 169/169 [==============================] - 3s 9ms/step - loss: 0.6978 - accuracy: 0.4818 - val_loss: 0.6943 - val_accuracy: 0.4733
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.4.best/assets
# Epoch 2/20
# 169/169 [==============================] - 1s 8ms/step - loss: 0.6944 - accuracy: 0.5120 - val_loss: 0.6926 - val_accuracy: 0.5317
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.4.best/assets
# Epoch 3/20
# 169/169 [==============================] - 1s 8ms/step - loss: 0.6924 - accuracy: 0.5377 - val_loss: 0.6942 - val_accuracy: 0.4900
# Epoch 4/20
# 169/169 [==============================] - 1s 8ms/step - loss: 0.6975 - accuracy: 0.5436 - val_loss: 0.6980 - val_accuracy: 0.4733
# Epoch 5/20
# 169/169 [==============================] - 1s 8ms/step - loss: 0.6982 - accuracy: 0.5193 - val_loss: 0.6919 - val_accuracy: 0.5117
# Epoch 6/20
# 169/169 [==============================] - 1s 8ms/step - loss: 0.6612 - accuracy: 0.6053 - val_loss: 0.6790 - val_accuracy: 0.5733
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.4.best/assets
# Epoch 7/20
# 169/169 [==============================] - 1s 8ms/step - loss: 0.6496 - accuracy: 0.6211 - val_loss: 0.6966 - val_accuracy: 0.5700
# Epoch 8/20
# 169/169 [==============================] - 1s 8ms/step - loss: 0.5976 - accuracy: 0.6811 - val_loss: 0.7184 - val_accuracy: 0.5617
# Epoch 9/20
# 169/169 [==============================] - 1s 8ms/step - loss: 0.5319 - accuracy: 0.7425 - val_loss: 0.7516 - val_accuracy: 0.5667
# Epoch 10/20
# 169/169 [==============================] - 1s 8ms/step - loss: 0.4743 - accuracy: 0.7840 - val_loss: 0.7853 - val_accuracy: 0.5733
# Epoch 11/20
# 169/169 [==============================] - 1s 8ms/step - loss: 0.4093 - accuracy: 0.8205 - val_loss: 0.8770 - val_accuracy: 0.5633
# Epoch 12/20
# 169/169 [==============================] - 1s 8ms/step - loss: 0.3465 - accuracy: 0.8656 - val_loss: 0.9871 - val_accuracy: 0.5600
# Epoch 13/20
# 169/169 [==============================] - 1s 8ms/step - loss: 0.3050 - accuracy: 0.8756 - val_loss: 1.0714 - val_accuracy: 0.5900
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.4.best/assets
# Epoch 14/20
# 169/169 [==============================] - 1s 7ms/step - loss: 0.2711 - accuracy: 0.8903 - val_loss: 1.0846 - val_accuracy: 0.5800
# Epoch 15/20
# 169/169 [==============================] - 1s 8ms/step - loss: 0.1962 - accuracy: 0.9290 - val_loss: 1.2664 - val_accuracy: 0.5633
# Epoch 16/20
# 169/169 [==============================] - 1s 7ms/step - loss: 0.1741 - accuracy: 0.9427 - val_loss: 1.4059 - val_accuracy: 0.5750
# Epoch 17/20
# 169/169 [==============================] - 1s 8ms/step - loss: 0.1413 - accuracy: 0.9512 - val_loss: 1.5250 - val_accuracy: 0.5550
# Epoch 18/20
# 169/169 [==============================] - 1s 8ms/step - loss: 0.1290 - accuracy: 0.9530 - val_loss: 1.5610 - val_accuracy: 0.5583
# Epoch 19/20
# 169/169 [==============================] - 1s 7ms/step - loss: 0.1101 - accuracy: 0.9594 - val_loss: 1.6421 - val_accuracy: 0.5867
# Epoch 20/20
# 169/169 [==============================] - 1s 8ms/step - loss: 0.1140 - accuracy: 0.9575 - val_loss: 1.5661 - val_accuracy: 0.5917
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.4.best/assets
# Fold 4, 20 epochs, 40 sec
# accuracy: 59.43%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/20
# 169/169 [==============================] - 3s 10ms/step - loss: 0.6989 - accuracy: 0.5017 - val_loss: 0.6924 - val_accuracy: 0.5283
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.5.best/assets
# Epoch 2/20
# 169/169 [==============================] - 1s 8ms/step - loss: 0.6949 - accuracy: 0.5079 - val_loss: 0.6920 - val_accuracy: 0.5267
# Epoch 3/20
# 169/169 [==============================] - 1s 8ms/step - loss: 0.6943 - accuracy: 0.5095 - val_loss: 0.6951 - val_accuracy: 0.4733
# Epoch 4/20
# 169/169 [==============================] - 1s 8ms/step - loss: 0.6929 - accuracy: 0.5325 - val_loss: 0.6917 - val_accuracy: 0.5217
# Epoch 5/20
# 169/169 [==============================] - 1s 8ms/step - loss: 0.6877 - accuracy: 0.5514 - val_loss: 0.6742 - val_accuracy: 0.5933
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.5.best/assets
# Epoch 6/20
# 169/169 [==============================] - 1s 8ms/step - loss: 0.6520 - accuracy: 0.6276 - val_loss: 0.6710 - val_accuracy: 0.5867
# Epoch 7/20
# 169/169 [==============================] - 1s 8ms/step - loss: 0.5793 - accuracy: 0.7024 - val_loss: 0.6752 - val_accuracy: 0.5867
# Epoch 8/20
# 169/169 [==============================] - 1s 8ms/step - loss: 0.5200 - accuracy: 0.7546 - val_loss: 0.7418 - val_accuracy: 0.6133
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK1.cv.5.best/assets
# Epoch 9/20
# 169/169 [==============================] - 1s 8ms/step - loss: 0.4440 - accuracy: 0.8058 - val_loss: 0.8398 - val_accuracy: 0.5717
# Epoch 10/20
# 169/169 [==============================] - 1s 8ms/step - loss: 0.3644 - accuracy: 0.8484 - val_loss: 0.9106 - val_accuracy: 0.5750
# Epoch 11/20
# 169/169 [==============================] - 1s 8ms/step - loss: 0.2863 - accuracy: 0.8905 - val_loss: 1.0612 - val_accuracy: 0.5900
# Epoch 12/20
# 169/169 [==============================] - 1s 8ms/step - loss: 0.2476 - accuracy: 0.9031 - val_loss: 1.2198 - val_accuracy: 0.5667
# Epoch 13/20
# 169/169 [==============================] - 1s 8ms/step - loss: 0.1914 - accuracy: 0.9245 - val_loss: 1.3479 - val_accuracy: 0.5717
# Epoch 14/20
# 169/169 [==============================] - 1s 8ms/step - loss: 0.1579 - accuracy: 0.9409 - val_loss: 1.4959 - val_accuracy: 0.5850
# Epoch 15/20
# 169/169 [==============================] - 1s 8ms/step - loss: 0.1387 - accuracy: 0.9450 - val_loss: 1.5344 - val_accuracy: 0.5783
# Epoch 16/20
# 169/169 [==============================] - 1s 8ms/step - loss: 0.1367 - accuracy: 0.9449 - val_loss: 1.5896 - val_accuracy: 0.5833
# Epoch 17/20
# 169/169 [==============================] - 1s 8ms/step - loss: 0.1129 - accuracy: 0.9609 - val_loss: 1.7341 - val_accuracy: 0.5617
# Epoch 18/20
# 169/169 [==============================] - 1s 8ms/step - loss: 0.1229 - accuracy: 0.9562 - val_loss: 1.7219 - val_accuracy: 0.5800
# Epoch 19/20
# 169/169 [==============================] - 1s 8ms/step - loss: 0.0749 - accuracy: 0.9763 - val_loss: 1.8324 - val_accuracy: 0.5683
# Epoch 20/20
# 169/169 [==============================] - 2s 9ms/step - loss: 0.0686 - accuracy: 0.9770 - val_loss: 1.8889 - val_accuracy: 0.5600
# Fold 5, 20 epochs, 36 sec
# accuracy: 62.61%
#
# 5-way Cross Validation mean 62.83% (+/- 4.65%)
# Done
