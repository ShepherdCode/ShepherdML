# %% [markdown]
# # CNN 309
# Rather than partition train/validation sets, use different sets.
# Cut train set down to random LIMIT number of transcripts.
# Use all of the validation set.
# Use fit(shuffle) on the train set.
#
# TO DO:
# Save five best models to same directory to make it easy to delete.

# %%
TRAIN_NC_FILENAME='ncRNA.gc36.short.fasta'
TRAIN_PC_FILENAME='pcRNA.gc36.short.fasta'
VALID_NC_FILENAME='ncRNA.gc36.all.fasta'
VALID_PC_FILENAME='pcRNA.gc36.all.fasta'
#NC_FILENAME='ncRNA.tiny50.fasta'
#PC_FILENAME='pcRNA.tiny50.fasta'
#NC_FILENAME='ncRNA.gc34.processed.fasta'
#PC_FILENAME='pcRNA.gc34.processed.fasta'

MODEL_FILE='JUNK'  # change this if you want to keep models
DATAPATH=''

try:
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
except:
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"
TRAIN_NC_FILENAME = DATAPATH+TRAIN_NC_FILENAME
TRAIN_PC_FILENAME = DATAPATH+TRAIN_PC_FILENAME
VALID_NC_FILENAME = DATAPATH+VALID_NC_FILENAME
VALID_PC_FILENAME = DATAPATH+VALID_PC_FILENAME
MODEL_FILE=DATAPATH+MODEL_FILE

EPOCHS=200
SPLITS=5
K=1
VOCABULARY_SIZE=4**K+1   # e.g. K=3 => 64 DNA K-mers + 'NNN'
EMBED_DIMEN=2
FILTERS=32
KERNEL=3
NEURONS=32
DROP=0.25
ACT="tanh"
MINLEN=201
MAXLEN=2000
LIMIT=5588    # This is the size of our smallest set (protein coding short)
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# Load our own tools
# TO DO: don't go to GitHub if the file is already local.
GITHUB = True
if GITHUB:
    #!pip install requests  # Uncomment this if necessary. Seems to be pre-installed.
    import requests
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/ShepherdML/master/Strings/tools_fasta.py')
    with open('tools_fasta.py', 'w') as f:
        f.write(r.text)
    # TO DO: delete the file after import
import tools_fasta as tools
tools.yahoo()  # If this prints "Yahoo!" the the import was successful.

TOOLS_CHANGED = False   # set to True to re-run with a new version of tools
if TOOLS_CHANGED:
  from importlib import reload 
  tools=reload(tools)
  print(dir(tools))   # run this to see EVERYTHING in the tools module
# Out:
# Yahoo!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import StratifiedKFold
import tensorflow as tf
from tensorflow import keras
import time
dt='float32'
tf.keras.backend.set_floatx(dt)

# %% [markdown]
# Build model

# %%
def compile_model(model):
    ## learn rate = initial_learning_rate * decay_rate ^ (step / decay_steps)
    #adam_default_learn_rate = 0.001
    #schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    #    initial_learning_rate = adam_default_learn_rate*10,
    #    decay_steps=10000, decay_rate=0.99, staircase=True)
    #alrd = tf.keras.optimizers.Adam(learning_rate=schedule)
    #model.compile(loss=bc, optimizer=alrd, metrics=["accuracy"])

    print("COMPILE...")
    bc=tf.keras.losses.BinaryCrossentropy(from_logits=False)
    model.compile(loss=bc, optimizer="adam", metrics=["accuracy"])
    print("...COMPILED")
    return model

def build_model():
    SHAPE=(MAXLEN,5)  # MAXLEN bases = time steps, 5 features = one hots
    clayer1 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same",
                                 input_shape=SHAPE)
    clayer2 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer3 = keras.layers.MaxPooling1D(2)
    clayer4 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer5 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer6 = keras.layers.MaxPooling1D(2)
    clayer7 = keras.layers.Flatten()

    dlayer1 = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt, input_shape=[1000])
    dlayer2 = keras.layers.Dropout(DROP)
    dlayer3 = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt)
    dlayer4 = keras.layers.Dropout(DROP)
    output_layer = keras.layers.Dense(1, activation="sigmoid", dtype=dt)

    cnn = keras.models.Sequential()
    cnn.add(clayer1)
    cnn.add(clayer2)
    cnn.add(clayer3)
    cnn.add(clayer4)
    cnn.add(clayer5)
    cnn.add(clayer6)
    cnn.add(clayer7)
    cnn.add(dlayer1)
    cnn.add(dlayer2)
    cnn.add(dlayer3)
    cnn.add(dlayer4)
    cnn.add(output_layer)
    mlpc = compile_model(cnn)
    return mlpc

# %% [markdown]
# Cross validation

# %%
def do_cross_validation(X_train,y_train,given_model,X_valid,y_valid):
    cv_scores = []
    fold=0
    # When not using ShuffleSplit, make sure to randomize train data.
    #splitter = ShuffleSplit(n_splits=SPLITS, test_size=0.1, random_state=37863)
    #for train_index,valid_index in splitter.split(X):
    while fold < SPLITS:
        fold += 1
        # Avoid continually improving the same model.
        model = compile_model(keras.models.clone_model(given_model))
        bestname=MODEL_FILE+".cv."+str(fold)+".best"
        es = keras.callbacks.EarlyStopping(monitor='val_loss',  
            patience=10, verbose=1)
        mc = keras.callbacks.ModelCheckpoint(
            filepath=bestname, save_best_only=True, 
            monitor='val_accuracy', mode='max')  
        mycallbacks = [es,mc]  
        print("FIT")
        start_time=time.time()
        history=model.fit(X_train, y_train, # batch_size=10, default=32 works nicely
                epochs=EPOCHS, verbose=1,  # verbose=1 for ascii art, verbose=0 for none
                callbacks=mycallbacks, shuffle=True,
                validation_data=(X_valid,y_valid) )
        end_time=time.time()
        elapsed_time=(end_time-start_time)                        
        print("Fold %d, %d epochs, %d sec"%(fold,EPOCHS,elapsed_time))
        pd.DataFrame(history.history).plot(figsize=(8,5))
        plt.grid(True)
        plt.gca().set_ylim(0,1)
        plt.show()
        best_model=keras.models.load_model(bestname)
        scores = best_model.evaluate(X_valid, y_valid, verbose=0)
        print("%s: %.2f%%" % (best_model.metrics_names[1], scores[1]*100))
        cv_scores.append(scores[1] * 100)  

    print()
    print("%d-way Cross Validation max %.2f%%, mean %.2f%% (+/- %.2f%%)" % 
          (fold, np.amax(cv_scores), np.mean(cv_scores), np.std(cv_scores)))

# %% [markdown]
# ## Train on RNA lengths 200-1Kb

# %%
print ("Compile the model")
model=build_model()
print ("Summarize the model")
print(model.summary())  # Print this only once
#model.save(MODEL_FILE+'.model')
# Out:
# Compile the model
# COMPILE...
# ...COMPILED
# Summarize the model
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_16 (Conv1D)           (None, 2000, 32)          512
# _________________________________________________________________
# conv1d_17 (Conv1D)           (None, 2000, 32)          3104
# _________________________________________________________________
# max_pooling1d_8 (MaxPooling1 (None, 1000, 32)          0
# _________________________________________________________________
# conv1d_18 (Conv1D)           (None, 1000, 32)          3104
# _________________________________________________________________
# conv1d_19 (Conv1D)           (None, 1000, 32)          3104
# _________________________________________________________________
# max_pooling1d_9 (MaxPooling1 (None, 500, 32)           0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 16000)             0
# _________________________________________________________________
# dense_12 (Dense)             (None, 32)                512032
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 522,945
# Trainable params: 522,945
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
def load_data(nc_filename,pc_filename,limit=None):
  nc_seq=tools.load_fasta(nc_filename,0)
  pc_seq=tools.load_fasta(pc_filename,1)
  if limit is not None:
    # Choose a random subset of size = limit.
    # Side effect: randomizes the data order.
    nfrac=1.0*limit/len(nc_seq)
    pfrac=1.0*limit/len(pc_seq)
    if nfrac<1.0:
      nc_seq=nc_seq.sample(frac=nfrac)
    if pfrac<1.0:
      pc_seq=pc_seq.sample(frac=pfrac)
  train_set=pd.concat((nc_seq,pc_seq),axis=0)
  # May not need to slice by length if input files already sliced
  subset=tools.make_slice(train_set,MINLEN,MAXLEN)
  # randset=subset.sample(frac=1) # unneccessary with fit(shuffle)
  (X1,y1)=tools.separate_X_and_y(subset)
  # X1 is pandas df of ("list" of one sequence)
  X2=X1.to_numpy()  # numpy ndarray of ("list" of one sequence)
  X3=[elem[0] for elem in X2]  # numpy dnarray of str
  X4=tools.uniform_length(X3,MAXLEN)
  X5= [tools.one_hot(x) for x in X4]
  X6=np.asarray(X5)
  y6=y1.to_numpy()
  return X6,y6

print("Load train data from files.")
X_train,y_train = load_data(TRAIN_NC_FILENAME,TRAIN_PC_FILENAME,LIMIT)
print("X_train",X_train.shape)
print("Load valid data from files.")
X_valid,y_valid = load_data(VALID_NC_FILENAME,VALID_PC_FILENAME)
print("X_valid",X_valid.shape)
# Out:
# Load train data from files.
# X_train (11176, 2000, 5)
# Load valid data from files.
# X_valid (40592, 2000, 5)

# %%
print ("Cross valiation")
do_cross_validation(X_train,y_train,model,X_valid,y_valid)  
print ("Done")
# Out:
# Cross valiation
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/200
# 350/350 [==============================] - 7s 18ms/step - loss: 0.7307 - accuracy: 0.5312 - val_loss: 0.6192 - val_accuracy: 0.7046
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK.cv.1.best/assets
# Epoch 2/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6759 - accuracy: 0.5987 - val_loss: 0.5845 - val_accuracy: 0.7036
# Epoch 3/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6526 - accuracy: 0.6107 - val_loss: 0.5764 - val_accuracy: 0.7101
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK.cv.1.best/assets
# Epoch 4/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6516 - accuracy: 0.6152 - val_loss: 0.5978 - val_accuracy: 0.6557
# Epoch 5/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6532 - accuracy: 0.6200 - val_loss: 0.6444 - val_accuracy: 0.6056
# Epoch 6/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6541 - accuracy: 0.6174 - val_loss: 0.5847 - val_accuracy: 0.6934
# Epoch 7/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6369 - accuracy: 0.6410 - val_loss: 0.6208 - val_accuracy: 0.6303
# Epoch 8/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6482 - accuracy: 0.6221 - val_loss: 0.6269 - val_accuracy: 0.7165
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK.cv.1.best/assets
# Epoch 9/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6420 - accuracy: 0.6322 - val_loss: 0.5742 - val_accuracy: 0.7091
# Epoch 10/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6443 - accuracy: 0.6321 - val_loss: 0.6205 - val_accuracy: 0.6358
# Epoch 11/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6449 - accuracy: 0.6271 - val_loss: 0.5870 - val_accuracy: 0.6977
# Epoch 12/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6426 - accuracy: 0.6392 - val_loss: 0.6117 - val_accuracy: 0.6897
# Epoch 13/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6398 - accuracy: 0.6204 - val_loss: 0.6205 - val_accuracy: 0.6607
# Epoch 14/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6487 - accuracy: 0.6136 - val_loss: 0.6604 - val_accuracy: 0.5639
# Epoch 15/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6422 - accuracy: 0.6379 - val_loss: 0.5857 - val_accuracy: 0.7204
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK.cv.1.best/assets
# Epoch 16/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6406 - accuracy: 0.6424 - val_loss: 0.6099 - val_accuracy: 0.7140
# Epoch 17/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6414 - accuracy: 0.6344 - val_loss: 0.5820 - val_accuracy: 0.7144
# Epoch 18/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6272 - accuracy: 0.6412 - val_loss: 0.6043 - val_accuracy: 0.6941
# Epoch 19/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6289 - accuracy: 0.6407 - val_loss: 0.6415 - val_accuracy: 0.6495
# Epoch 00019: early stopping
# Fold 1, 200 epochs, 117 sec
# accuracy: 72.04%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/200
# 350/350 [==============================] - 7s 17ms/step - loss: 0.6858 - accuracy: 0.5972 - val_loss: 0.5977 - val_accuracy: 0.6843
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK.cv.2.best/assets
# Epoch 2/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6357 - accuracy: 0.6504 - val_loss: 0.5971 - val_accuracy: 0.6845
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK.cv.2.best/assets
# Epoch 3/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6201 - accuracy: 0.6593 - val_loss: 0.5730 - val_accuracy: 0.7283
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK.cv.2.best/assets
# Epoch 4/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6020 - accuracy: 0.6841 - val_loss: 0.5772 - val_accuracy: 0.6805
# Epoch 5/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5723 - accuracy: 0.7127 - val_loss: 0.5382 - val_accuracy: 0.7406
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK.cv.2.best/assets
# Epoch 6/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5452 - accuracy: 0.7371 - val_loss: 0.4714 - val_accuracy: 0.7837
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK.cv.2.best/assets
# Epoch 7/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.4847 - accuracy: 0.7777 - val_loss: 0.6131 - val_accuracy: 0.6857
# Epoch 8/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.4506 - accuracy: 0.7925 - val_loss: 0.4944 - val_accuracy: 0.7586
# Epoch 9/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.3923 - accuracy: 0.8309 - val_loss: 0.4480 - val_accuracy: 0.7999
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK.cv.2.best/assets
# Epoch 10/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.3786 - accuracy: 0.8392 - val_loss: 0.4227 - val_accuracy: 0.8107
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK.cv.2.best/assets
# Epoch 11/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.3170 - accuracy: 0.8675 - val_loss: 0.4444 - val_accuracy: 0.8102
# Epoch 12/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.2971 - accuracy: 0.8780 - val_loss: 0.4311 - val_accuracy: 0.8223
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK.cv.2.best/assets
# Epoch 13/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.2420 - accuracy: 0.9044 - val_loss: 0.4924 - val_accuracy: 0.8001
# Epoch 14/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.2156 - accuracy: 0.9209 - val_loss: 0.4951 - val_accuracy: 0.8166
# Epoch 15/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.2150 - accuracy: 0.9151 - val_loss: 0.4934 - val_accuracy: 0.8265
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK.cv.2.best/assets
# Epoch 16/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.1787 - accuracy: 0.9327 - val_loss: 0.6818 - val_accuracy: 0.7703
# Epoch 17/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.1600 - accuracy: 0.9393 - val_loss: 0.6831 - val_accuracy: 0.7805
# Epoch 18/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.1317 - accuracy: 0.9499 - val_loss: 0.5710 - val_accuracy: 0.8137
# Epoch 19/200
# 350/350 [==============================] - 6s 18ms/step - loss: 0.1168 - accuracy: 0.9585 - val_loss: 0.5623 - val_accuracy: 0.8205
# Epoch 20/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.1177 - accuracy: 0.9554 - val_loss: 0.6494 - val_accuracy: 0.8060
# Epoch 00020: early stopping
# Fold 2, 200 epochs, 129 sec
# accuracy: 82.65%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/200
# 350/350 [==============================] - 7s 17ms/step - loss: 0.6705 - accuracy: 0.6014 - val_loss: 0.5685 - val_accuracy: 0.7112
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK.cv.3.best/assets
# Epoch 2/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6488 - accuracy: 0.6353 - val_loss: 0.6246 - val_accuracy: 0.6559
# Epoch 3/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6365 - accuracy: 0.6488 - val_loss: 0.6226 - val_accuracy: 0.6407
# Epoch 4/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6183 - accuracy: 0.6642 - val_loss: 0.5441 - val_accuracy: 0.7280
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK.cv.3.best/assets
# Epoch 5/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5864 - accuracy: 0.7045 - val_loss: 0.5556 - val_accuracy: 0.7300
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK.cv.3.best/assets
# Epoch 6/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5610 - accuracy: 0.7181 - val_loss: 0.6463 - val_accuracy: 0.6380
# Epoch 7/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.5184 - accuracy: 0.7479 - val_loss: 0.4544 - val_accuracy: 0.7961
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK.cv.3.best/assets
# Epoch 8/200
# 350/350 [==============================] - 6s 18ms/step - loss: 0.4621 - accuracy: 0.7875 - val_loss: 0.5758 - val_accuracy: 0.7055
# Epoch 9/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.4261 - accuracy: 0.8078 - val_loss: 0.4253 - val_accuracy: 0.8103
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK.cv.3.best/assets
# Epoch 10/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.3737 - accuracy: 0.8363 - val_loss: 0.4114 - val_accuracy: 0.8188
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK.cv.3.best/assets
# Epoch 11/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.3271 - accuracy: 0.8625 - val_loss: 0.4078 - val_accuracy: 0.8265
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK.cv.3.best/assets
# Epoch 12/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.2785 - accuracy: 0.8874 - val_loss: 0.4358 - val_accuracy: 0.8168
# Epoch 13/200
# 350/350 [==============================] - 6s 18ms/step - loss: 0.2460 - accuracy: 0.9028 - val_loss: 0.5650 - val_accuracy: 0.7771
# Epoch 14/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.2049 - accuracy: 0.9225 - val_loss: 0.4277 - val_accuracy: 0.8284
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK.cv.3.best/assets
# Epoch 15/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.1932 - accuracy: 0.9222 - val_loss: 0.5207 - val_accuracy: 0.8040
# Epoch 16/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.1559 - accuracy: 0.9396 - val_loss: 0.4924 - val_accuracy: 0.8299
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK.cv.3.best/assets
# Epoch 17/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.1398 - accuracy: 0.9451 - val_loss: 0.5166 - val_accuracy: 0.8321
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK.cv.3.best/assets
# Epoch 18/200
# 350/350 [==============================] - 6s 18ms/step - loss: 0.1319 - accuracy: 0.9512 - val_loss: 0.5715 - val_accuracy: 0.8113
# Epoch 19/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.1297 - accuracy: 0.9468 - val_loss: 0.5668 - val_accuracy: 0.8200
# Epoch 20/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.1037 - accuracy: 0.9632 - val_loss: 0.6510 - val_accuracy: 0.8076
# Epoch 21/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.1205 - accuracy: 0.9552 - val_loss: 0.5639 - val_accuracy: 0.8252
# Epoch 00021: early stopping
# Fold 3, 200 epochs, 137 sec
# accuracy: 83.21%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/200
# 350/350 [==============================] - 7s 17ms/step - loss: 0.7230 - accuracy: 0.5367 - val_loss: 0.5684 - val_accuracy: 0.7170
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK.cv.4.best/assets
# Epoch 2/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6801 - accuracy: 0.5819 - val_loss: 0.6184 - val_accuracy: 0.6460
# Epoch 3/200
# 350/350 [==============================] - 6s 18ms/step - loss: 0.6711 - accuracy: 0.6028 - val_loss: 0.7105 - val_accuracy: 0.4490
# Epoch 4/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6935 - accuracy: 0.5358 - val_loss: 0.5997 - val_accuracy: 0.6938
# Epoch 5/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6672 - accuracy: 0.5849 - val_loss: 0.7026 - val_accuracy: 0.4380
# Epoch 6/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6868 - accuracy: 0.5454 - val_loss: 0.6415 - val_accuracy: 0.6589
# Epoch 7/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6638 - accuracy: 0.6119 - val_loss: 0.6049 - val_accuracy: 0.7109
# Epoch 8/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6470 - accuracy: 0.6380 - val_loss: 0.6952 - val_accuracy: 0.4438
# Epoch 9/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6956 - accuracy: 0.5115 - val_loss: 0.6658 - val_accuracy: 0.6512
# Epoch 10/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6743 - accuracy: 0.5872 - val_loss: 0.6948 - val_accuracy: 0.5347
# Epoch 11/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6711 - accuracy: 0.5882 - val_loss: 0.6197 - val_accuracy: 0.7027
# Epoch 00011: early stopping
# Fold 4, 200 epochs, 66 sec
# accuracy: 71.70%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/200
# 350/350 [==============================] - 7s 17ms/step - loss: 0.7761 - accuracy: 0.5423 - val_loss: 0.6288 - val_accuracy: 0.6973
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK.cv.5.best/assets
# Epoch 2/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6876 - accuracy: 0.5733 - val_loss: 0.6301 - val_accuracy: 0.6843
# Epoch 3/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6686 - accuracy: 0.5977 - val_loss: 0.6114 - val_accuracy: 0.6645
# Epoch 4/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6487 - accuracy: 0.6300 - val_loss: 0.6509 - val_accuracy: 0.6280
# Epoch 5/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6528 - accuracy: 0.6164 - val_loss: 0.6001 - val_accuracy: 0.7077
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK.cv.5.best/assets
# Epoch 6/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6469 - accuracy: 0.6365 - val_loss: 0.6366 - val_accuracy: 0.6846
# Epoch 7/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6510 - accuracy: 0.6271 - val_loss: 0.6211 - val_accuracy: 0.6827
# Epoch 8/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6463 - accuracy: 0.6412 - val_loss: 0.5771 - val_accuracy: 0.7183
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK.cv.5.best/assets
# Epoch 9/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6322 - accuracy: 0.6512 - val_loss: 0.6257 - val_accuracy: 0.6658
# Epoch 10/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6310 - accuracy: 0.6442 - val_loss: 0.5918 - val_accuracy: 0.7012
# Epoch 11/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6330 - accuracy: 0.6527 - val_loss: 0.6189 - val_accuracy: 0.6680
# Epoch 12/200
# 350/350 [==============================] - 6s 18ms/step - loss: 0.6455 - accuracy: 0.6408 - val_loss: 0.5933 - val_accuracy: 0.6799
# Epoch 13/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6307 - accuracy: 0.6529 - val_loss: 0.6083 - val_accuracy: 0.6872
# Epoch 14/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6417 - accuracy: 0.6324 - val_loss: 0.6263 - val_accuracy: 0.6498
# Epoch 15/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6375 - accuracy: 0.6381 - val_loss: 0.6248 - val_accuracy: 0.6622
# Epoch 16/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6425 - accuracy: 0.6219 - val_loss: 0.6454 - val_accuracy: 0.6398
# Epoch 17/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6495 - accuracy: 0.6284 - val_loss: 0.6536 - val_accuracy: 0.5886
# Epoch 18/200
# 350/350 [==============================] - 6s 17ms/step - loss: 0.6380 - accuracy: 0.6382 - val_loss: 0.5871 - val_accuracy: 0.7214
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK.cv.5.best/assets
# Epoch 00018: early stopping
# Fold 5, 200 epochs, 111 sec
# accuracy: 72.14%
#
# 5-way Cross Validation max 83.21%, mean 76.35% (+/- 5.38%)
# Done
