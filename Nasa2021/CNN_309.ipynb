# %% [markdown]
# # CNN 309
# Rather than partition train/validation sets, use different sets. Also use fit(shuffle) on the train set.
# Here train=all, valid=short.

# %%
TRAIN_NC_FILENAME='ncRNA.gc36.all.fasta'
TRAIN_PC_FILENAME='pcRNA.gc36.all.fasta'
VALID_NC_FILENAME='ncRNA.gc36.short.fasta'
VALID_PC_FILENAME='pcRNA.gc36.short.fasta'
#NC_FILENAME='ncRNA.tiny50.fasta'
#PC_FILENAME='pcRNA.tiny50.fasta'
#NC_FILENAME='ncRNA.gc34.processed.fasta'
#PC_FILENAME='pcRNA.gc34.processed.fasta'

MODEL_FILE='CNN308'  
DATAPATH=''

try:
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
except:
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"
TRAIN_NC_FILENAME = DATAPATH+TRAIN_NC_FILENAME
TRAIN_PC_FILENAME = DATAPATH+TRAIN_PC_FILENAME
VALID_NC_FILENAME = DATAPATH+VALID_NC_FILENAME
VALID_PC_FILENAME = DATAPATH+VALID_PC_FILENAME
MODEL_FILE=DATAPATH+MODEL_FILE

EPOCHS=200
SPLITS=5
K=1
VOCABULARY_SIZE=4**K+1   # e.g. K=3 => 64 DNA K-mers + 'NNN'
EMBED_DIMEN=2
FILTERS=32
KERNEL=3
NEURONS=32
DROP=0.25
ACT="tanh"
MINLEN=201
MAXLEN=2000
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# Load our own tools
# TO DO: don't go to GitHub if the file is already local.
GITHUB = True
if GITHUB:
    #!pip install requests  # Uncomment this if necessary. Seems to be pre-installed.
    import requests
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/ShepherdML/master/Strings/tools_fasta.py')
    with open('tools_fasta.py', 'w') as f:
        f.write(r.text)
    # TO DO: delete the file after import
import tools_fasta as tools
tools.yahoo()  # If this prints "Yahoo!" the the import was successful.

TOOLS_CHANGED = False   # set to True to re-run with a new version of tools
if TOOLS_CHANGED:
  from importlib import reload 
  tools=reload(tools)
  print(dir(tools))   # run this to see EVERYTHING in the tools module
# Out:
# Yahoo!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import StratifiedKFold
import tensorflow as tf
from tensorflow import keras
import time
dt='float32'
tf.keras.backend.set_floatx(dt)

# %% [markdown]
# Build model

# %%
def compile_model(model):
    ## learn rate = initial_learning_rate * decay_rate ^ (step / decay_steps)
    #adam_default_learn_rate = 0.001
    #schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    #    initial_learning_rate = adam_default_learn_rate*10,
    #    decay_steps=10000, decay_rate=0.99, staircase=True)
    #alrd = tf.keras.optimizers.Adam(learning_rate=schedule)
    #model.compile(loss=bc, optimizer=alrd, metrics=["accuracy"])

    print("COMPILE...")
    bc=tf.keras.losses.BinaryCrossentropy(from_logits=False)
    model.compile(loss=bc, optimizer="adam", metrics=["accuracy"])
    print("...COMPILED")
    return model

def build_model():
    SHAPE=(MAXLEN,5)  # MAXLEN bases = time steps, 5 features = one hots
    clayer1 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same",
                                 input_shape=SHAPE)
    clayer2 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer3 = keras.layers.MaxPooling1D(2)
    clayer4 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer5 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer6 = keras.layers.MaxPooling1D(2)
    clayer7 = keras.layers.Flatten()

    dlayer1 = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt, input_shape=[1000])
    dlayer2 = keras.layers.Dropout(DROP)
    dlayer3 = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt)
    dlayer4 = keras.layers.Dropout(DROP)
    output_layer = keras.layers.Dense(1, activation="sigmoid", dtype=dt)

    cnn = keras.models.Sequential()
    cnn.add(clayer1)
    cnn.add(clayer2)
    cnn.add(clayer3)
    cnn.add(clayer4)
    cnn.add(clayer5)
    cnn.add(clayer6)
    cnn.add(clayer7)
    cnn.add(dlayer1)
    cnn.add(dlayer2)
    cnn.add(dlayer3)
    cnn.add(dlayer4)
    cnn.add(output_layer)
    mlpc = compile_model(cnn)
    return mlpc

# %% [markdown]
# Cross validation

# %%
def do_cross_validation(X_train,y_train,given_model,X_valid,y_valid):
    cv_scores = []
    fold=0
    # When not using ShuffleSplit, make sure to randomize train data.
    #splitter = ShuffleSplit(n_splits=SPLITS, test_size=0.1, random_state=37863)
    #for train_index,valid_index in splitter.split(X):
    while fold < SPLITS:
        fold += 1
        # Avoid continually improving the same model.
        model = compile_model(keras.models.clone_model(given_model))
        bestname=MODEL_FILE+".cv."+str(fold)+".best"
        es = keras.callbacks.EarlyStopping(monitor='val_loss',  
            patience=10, verbose=1)
        mc = keras.callbacks.ModelCheckpoint(
            filepath=bestname, save_best_only=True, 
            monitor='val_accuracy', mode='max')  
        mycallbacks = [es,mc]  
        print("FIT")
        start_time=time.time()
        history=model.fit(X_train, y_train, # batch_size=10, default=32 works nicely
                epochs=EPOCHS, verbose=1,  # verbose=1 for ascii art, verbose=0 for none
                callbacks=mycallbacks, shuffle=True,
                validation_data=(X_valid,y_valid) )
        end_time=time.time()
        elapsed_time=(end_time-start_time)                        
        print("Fold %d, %d epochs, %d sec"%(fold,EPOCHS,elapsed_time))
        pd.DataFrame(history.history).plot(figsize=(8,5))
        plt.grid(True)
        plt.gca().set_ylim(0,1)
        plt.show()
        best_model=keras.models.load_model(bestname)
        scores = best_model.evaluate(X_valid, y_valid, verbose=0)
        print("%s: %.2f%%" % (best_model.metrics_names[1], scores[1]*100))
        cv_scores.append(scores[1] * 100)  

    print()
    print("%d-way Cross Validation max %.2f%%, mean %.2f%% (+/- %.2f%%)" % 
          (fold, np.amax(cv_scores), np.mean(cv_scores), np.std(cv_scores)))

# %% [markdown]
# ## Train on RNA lengths 200-1Kb

# %%
print ("Compile the model")
model=build_model()
print ("Summarize the model")
print(model.summary())  # Print this only once
#model.save(MODEL_FILE+'.model')
# Out:
# Compile the model
# COMPILE...
# ...COMPILED
# Summarize the model
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_56 (Conv1D)           (None, 2000, 32)          512
# _________________________________________________________________
# conv1d_57 (Conv1D)           (None, 2000, 32)          3104
# _________________________________________________________________
# max_pooling1d_28 (MaxPooling (None, 1000, 32)          0
# _________________________________________________________________
# conv1d_58 (Conv1D)           (None, 1000, 32)          3104
# _________________________________________________________________
# conv1d_59 (Conv1D)           (None, 1000, 32)          3104
# _________________________________________________________________
# max_pooling1d_29 (MaxPooling (None, 500, 32)           0
# _________________________________________________________________
# flatten_14 (Flatten)         (None, 16000)             0
# _________________________________________________________________
# dense_42 (Dense)             (None, 32)                512032
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_43 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_44 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 522,945
# Trainable params: 522,945
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
def load_data(nc_filename,pc_filename):
  nc_seq=tools.load_fasta(nc_filename,0)
  pc_seq=tools.load_fasta(pc_filename,1)
  train_set=pd.concat((nc_seq,pc_seq),axis=0)
  # May not need to slice by length if input files already sliced
  subset=tools.make_slice(train_set,MINLEN,MAXLEN)
  # randset=subset.sample(frac=1) # unneccessary with fit(shuffle)
  (X1,y1)=tools.separate_X_and_y(subset)
  # X1 is pandas df of ("list" of one sequence)
  X2=X1.to_numpy()  # numpy ndarray of ("list" of one sequence)
  X3=[elem[0] for elem in X2]  # numpy dnarray of str
  X4=tools.uniform_length(X3,MAXLEN)
  X5= [tools.one_hot(x) for x in X4]
  X6=np.asarray(X5)
  y6=y1.to_numpy()
  return X6,y6

print("Load train data from files.")
X_train,y_train = load_data(TRAIN_NC_FILENAME,TRAIN_PC_FILENAME)
print("Load valid data from files.")
X_valid,y_valid = load_data(VALID_NC_FILENAME,VALID_PC_FILENAME)
print("Data loaded from files.")
# Out:
# Load train data from files.
# Load valid data from files.
# Data loaded from files.

# %%
print ("Cross valiation")
do_cross_validation(X_train,y_train,model,X_valid,y_valid)  
print ("Done")
# Out:
# Cross valiation
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.6939 - accuracy: 0.5911 - val_loss: 0.6504 - val_accuracy: 0.6421
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.1.best/assets
# Epoch 2/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5825 - accuracy: 0.7053 - val_loss: 0.6356 - val_accuracy: 0.6455
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.1.best/assets
# Epoch 3/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5796 - accuracy: 0.7070 - val_loss: 0.6261 - val_accuracy: 0.6737
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.1.best/assets
# Epoch 4/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5743 - accuracy: 0.7098 - val_loss: 0.6746 - val_accuracy: 0.6539
# Epoch 5/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5687 - accuracy: 0.7183 - val_loss: 0.6174 - val_accuracy: 0.6710
# Epoch 6/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5432 - accuracy: 0.7278 - val_loss: 0.6260 - val_accuracy: 0.6827
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.1.best/assets
# Epoch 7/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5420 - accuracy: 0.7384 - val_loss: 0.5716 - val_accuracy: 0.7096
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.1.best/assets
# Epoch 8/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5233 - accuracy: 0.7455 - val_loss: 0.5799 - val_accuracy: 0.7158
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.1.best/assets
# Epoch 9/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.4929 - accuracy: 0.7683 - val_loss: 0.5475 - val_accuracy: 0.7290
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv
200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5621 - accuracy: 0.7147 - val_loss: 0.6365 - val_accuracy: 0.6580
# Epoch 5/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5338 - accuracy: 0.7351 - val_loss: 0.6296 - val_accuracy: 0.6756
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.3.best/assets
# Epoch 6/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5254 - accuracy: 0.7437 - val_loss: 0.5764 - val_accuracy: 0.7122
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.3.best/assets
# Epoch 7/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5068 - accuracy: 0.7512 - val_loss: 0.5422 - val_accuracy: 0.7334
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.3.best/assets
# Epoch 8/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.4539 - accuracy: 0.7916 - val_loss: 0.5024 - val_accuracy: 0.7634
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.3.best/assets
# Epoch 9/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.4213 - accuracy: 0.8134 - val_loss: 0.4983 - val_accuracy: 0.7619
# Epoch 10/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.3835 - accuracy: 0.8360 - val_loss: 0.4875 - val_accuracy: 0.7753
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.3.best/assets
# Epoch 11/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.3542 - accuracy: 0.8468 - val_loss: 0.5045 - val_accuracy: 0.7763
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.3.best/assets
# Epoch 12/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.3175 - accuracy: 0.8654 - val_loss: 0.5179 - val_accuracy: 0.7792
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.3.best/assets
# Epoch 13/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.2757 - accuracy: 0.8909 - val_loss: 0.5306 - val_accuracy: 0.7832
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.3.best/assets
# Epoch 14/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.2355 - accuracy: 0.9052 - val_loss: 0.5706 - val_accuracy: 0.7790
# Epoch 15/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.2046 - accuracy: 0.9210 - val_loss: 0.5630 - val_accuracy: 0.7964
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.3.best/assets
# Epoch 16/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.1959 - accuracy: 0.9290 - val_loss: 0.5545 - val_accuracy: 0.7989
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.3.best/assets
# Epoch 17/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.1648 - accuracy: 0.9417 - val_loss: 0.6018 - val_accuracy: 0.8039
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.3.best/assets
# Epoch 18/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.1526 - accuracy: 0.9468 - val_loss: 0.5901 - val_accuracy: 0.8121
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.3.best/assets
# Epoch 19/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.1349 - accuracy: 0.9496 - val_loss: 0.5923 - val_accuracy: 0.8121
# Epoch 20/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.1241 - accuracy: 0.9556 - val_loss: 0.6464 - val_accuracy: 0.8105
# Epoch 00020: early stopping
# Fold 3, 200 epochs, 79 sec
# accuracy: 81.21%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/200
# 350/350 [==============================] - 4s 9ms/step - loss: 0.7127 - accuracy: 0.5582 - val_loss: 0.6784 - val_accuracy: 0.6041
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.4.best/assets
# Epoch 2/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.6269 - accuracy: 0.6586 - val_loss: 0.6684 - val_accuracy: 0.6046
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.4.best/assets
# Epoch 3/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.6110 - accuracy: 0.6931 - val_loss: 0.6323 - val_accuracy: 0.6581
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.4.best/assets
# Epoch 4/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5981 - accuracy: 0.6963 - val_loss: 0.6487 - val_accuracy: 0.6513
# Epoch 5/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.6080 - accuracy: 0.6862 - val_loss: 0.6218 - val_accuracy: 0.6620
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.4.best/assets
# Epoch 6/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5858 - accuracy: 0.6944 - val_loss: 0.6411 - val_accuracy: 0.6658
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.4.best/assets
# Epoch 7/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5590 - accuracy: 0.7226 - val_loss: 0.6375 - val_accuracy: 0.6726
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.4.best/assets
# Epoch 8/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5540 - accuracy: 0.7203 - val_loss: 0.6313 - val_accuracy: 0.6617
# Epoch 9/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5494 - accuracy: 0.7273 - val_loss: 0.5990 - val_accuracy: 0.6805
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.4.best/assets
# Epoch 10/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5385 - accuracy: 0.7380 - val_loss: 0.5804 - val_accuracy: 0.7081
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.4.best/assets
# Epoch 11/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5293 - accuracy: 0.7410 - val_loss: 0.5971 - val_accuracy: 0.7035
# Epoch 12/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5073 - accuracy: 0.7619 - val_loss: 0.5749 - val_accuracy: 0.7063
# Epoch 13/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.4847 - accuracy: 0.7731 - val_loss: 0.5837 - val_accuracy: 0.6912
# Epoch 14/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.4655 - accuracy: 0.7833 - val_loss: 0.5332 - val_accuracy: 0.7483
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.4.best/assets
# Epoch 15/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.4425 - accuracy: 0.8011 - val_loss: 0.5306 - val_accuracy: 0.7507
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.4.best/assets
# Epoch 16/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.4235 - accuracy: 0.8091 - val_loss: 0.5607 - val_accuracy: 0.7409
# Epoch 17/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.4173 - accuracy: 0.8127 - val_loss: 0.4889 - val_accuracy: 0.7715
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.4.best/assets
# Epoch 18/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.4083 - accuracy: 0.8152 - val_loss: 0.4764 - val_accuracy: 0.7852
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.4.best/assets
# Epoch 19/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.3756 - accuracy: 0.8300 - val_loss: 0.6140 - val_accuracy: 0.7455
# Epoch 20/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.3489 - accuracy: 0.8484 - val_loss: 0.5844 - val_accuracy: 0.7403
# Epoch 21/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.3307 - accuracy: 0.8593 - val_loss: 0.4708 - val_accuracy: 0.7944
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.4.best/assets
# Epoch 22/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.3086 - accuracy: 0.8718 - val_loss: 0.4595 - val_accuracy: 0.8027
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.4.best/assets
# Epoch 23/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.3156 - accuracy: 0.8652 - val_loss: 0.4569 - val_accuracy: 0.8018
# Epoch 24/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.2560 - accuracy: 0.8934 - val_loss: 0.5063 - val_accuracy: 0.7925
# Epoch 25/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.2657 - accuracy: 0.8913 - val_loss: 0.4555 - val_accuracy: 0.8093
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.4.best/assets
# Epoch 26/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.2263 - accuracy: 0.9082 - val_loss: 0.4494 - val_accuracy: 0.8176
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.4.best/assets
# Epoch 27/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.2196 - accuracy: 0.9142 - val_loss: 0.4735 - val_accuracy: 0.8181
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.4.best/assets
# Epoch 28/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.2008 - accuracy: 0.9247 - val_loss: 0.4659 - val_accuracy: 0.8219
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.4.best/assets
# Epoch 29/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.1901 - accuracy: 0.9244 - val_loss: 0.4861 - val_accuracy: 0.8238
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.4.best/assets
# Epoch 30/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.1759 - accuracy: 0.9359 - val_loss: 0.5245 - val_accuracy: 0.8237
# Epoch 31/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.1664 - accuracy: 0.9389 - val_loss: 0.5084 - val_accuracy: 0.8250
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.4.best/assets
# Epoch 32/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.1430 - accuracy: 0.9483 - val_loss: 0.5543 - val_accuracy: 0.8227
# Epoch 33/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.1339 - accuracy: 0.9555 - val_loss: 0.6109 - val_accuracy: 0.8075
# Epoch 34/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.1392 - accuracy: 0.9500 - val_loss: 0.6102 - val_accuracy: 0.8129
# Epoch 35/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.1259 - accuracy: 0.9535 - val_loss: 0.5390 - val_accuracy: 0.8155
# Epoch 36/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.1275 - accuracy: 0.9549 - val_loss: 0.5322 - val_accuracy: 0.8332
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.4.best/assets
# Epoch 00036: early stopping
# Fold 4, 200 epochs, 135 sec
# accuracy: 83.32%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/200
# 350/350 [==============================] - 4s 9ms/step - loss: 0.6844 - accuracy: 0.6062 - val_loss: 0.7010 - val_accuracy: 0.6282
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.5.best/assets
# Epoch 2/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.6060 - accuracy: 0.6787 - val_loss: 0.6070 - val_accuracy: 0.6791
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.5.best/assets
# Epoch 3/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5788 - accuracy: 0.7104 - val_loss: 0.6165 - val_accuracy: 0.6835
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.5.best/assets
# Epoch 4/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5656 - accuracy: 0.7138 - val_loss: 0.6411 - val_accuracy: 0.6676
# Epoch 5/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5515 - accuracy: 0.7296 - val_loss: 0.6077 - val_accuracy: 0.6739
# Epoch 6/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5442 - accuracy: 0.7339 - val_loss: 0.6177 - val_accuracy: 0.6826
# Epoch 7/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5218 - accuracy: 0.7486 - val_loss: 0.6479 - val_accuracy: 0.6456
# Epoch 8/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5323 - accuracy: 0.7406 - val_loss: 0.5825 - val_accuracy: 0.6998
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.5.best/assets
# Epoch 9/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5001 - accuracy: 0.7621 - val_loss: 0.5490 - val_accuracy: 0.7215
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.5.best/assets
# Epoch 10/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.4857 - accuracy: 0.7757 - val_loss: 0.6232 - val_accuracy: 0.6945
# Epoch 11/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.4670 - accuracy: 0.7840 - val_loss: 0.6056 - val_accuracy: 0.7038
# Epoch 12/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.4481 - accuracy: 0.7942 - val_loss: 0.5214 - val_accuracy: 0.7555
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.5.best/assets
# Epoch 13/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.4155 - accuracy: 0.8194 - val_loss: 0.4869 - val_accuracy: 0.7686
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.5.best/assets
# Epoch 14/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.3718 - accuracy: 0.8412 - val_loss: 0.4765 - val_accuracy: 0.7902
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.5.best/assets
# Epoch 15/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.3582 - accuracy: 0.8470 - val_loss: 0.4969 - val_accuracy: 0.7837
# Epoch 16/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.3223 - accuracy: 0.8657 - val_loss: 0.4761 - val_accuracy: 0.7958
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.5.best/assets
# Epoch 17/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.2839 - accuracy: 0.8855 - val_loss: 0.5751 - val_accuracy: 0.7713
# Epoch 18/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.2446 - accuracy: 0.9034 - val_loss: 0.5895 - val_accuracy: 0.7762
# Epoch 19/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.2218 - accuracy: 0.9120 - val_loss: 0.4887 - val_accuracy: 0.8084
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.5.best/assets
# Epoch 20/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.2049 - accuracy: 0.9232 - val_loss: 0.5400 - val_accuracy: 0.8127
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.5.best/assets
# Epoch 21/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.1713 - accuracy: 0.9365 - val_loss: 0.5809 - val_accuracy: 0.7933
# Epoch 22/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.1604 - accuracy: 0.9397 - val_loss: 0.5981 - val_accuracy: 0.8056
# Epoch 23/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.1479 - accuracy: 0.9487 - val_loss: 0.5664 - val_accuracy: 0.8165
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.5.best/assets
# Epoch 24/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.1263 - accuracy: 0.9536 - val_loss: 0.6015 - val_accuracy: 0.8093
# Epoch 25/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.1340 - accuracy: 0.9516 - val_loss: 0.6261 - val_accuracy: 0.8183
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.5.best/assets
# Epoch 26/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.1411 - accuracy: 0.9505 - val_loss: 0.6025 - val_accuracy: 0.8166
# Epoch 00026: early stopping
# Fold 5, 200 epochs, 95 sec
# accuracy: 81.83%
#
# 5-way Cross Validation max 83.32%, mean 82.17% (+/- 0.69%)
# Done
