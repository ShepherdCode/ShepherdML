# %% [markdown]
# <a href="https://colab.research.google.com/github/ShepherdCode/ShepherdML/blob/master/Nasa2021/CNN_523embed_noisy3k_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CNN 523 Noisy 3k
#
# 1. Four layers of CNNS and MaxPooling
# 2. Drop out at 0.2
# 3. Variable filters and dense neurons
# 4. Adjusted Learning rate to 0.0005

# %%
#NC_FILENAME='ncRNA.tiny50.fasta'
#PC_FILENAME='pcRNA.tiny50.fasta'
#NC_FILENAME='ncRNA.gc34.processed.fasta'
#PC_FILENAME='pcRNA.gc34.processed.fasta'
NC_FILENAME='noisy_noncod_3000_10.fasta'  # CHANGE THIS TO 1000, 2000, 4000, etc.
PC_FILENAME='noisy_coding_3000_10.fasta'
NC_VAL_FILE='noncod_validation.fasta'  # 'noncod_validation.fasta'  # CHANGE THIS TO THE UNIFORM VALIDATION FILE
PC_VAL_FILE='coding_validation.fasta'  # 'coding_validation.fasta'

MODEL_FILE='Test_Non_noisy_3K'   # CHANGE THIS IF YOU WANT TO SAVE THE MODEL!
DATAPATH=''

try:
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
except:
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"
NC_FILENAME = DATAPATH+NC_FILENAME
PC_FILENAME = DATAPATH+PC_FILENAME
NC_VAL_FILE = DATAPATH+NC_VAL_FILE
PC_VAL_FILE = DATAPATH+PC_VAL_FILE
MODEL_FILE=DATAPATH+MODEL_FILE

EPOCHS=10  # DECIDE ON SOME AMOUNT AND STICK WITH IT
SPLITS=5
K=1
VOCABULARY_SIZE=4**K+1   # e.g. K=3 => 64 DNA K-mers + 'NNN'
EMBED_DIMEN=2
FILTERS=32
KERNEL=3
NEURONS=24
DROP=0.2
MINLEN=200
MAXLEN=1000    # THIS HAS TO MATCH THE SIMULATION DATA
DENSE_LEN = 1000
ACT="tanh"
LN_RATE = 0.0005
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# Load our own tools
# TO DO: don't go to GitHub if the file is already local.
GITHUB = True
if GITHUB:
    #!pip install requests  # Uncomment this if necessary. Seems to be pre-installed.
    import requests
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/ShepherdML/master/Strings/tools_fasta.py')
    with open('tools_fasta.py', 'w') as f:
        f.write(r.text)
    # TO DO: delete the file after import
import tools_fasta as tools
tools.yahoo()  # If this prints "Yahoo!" the the import was successful.

TOOLS_CHANGED = False   # set to True to re-run with a new version of tools
if TOOLS_CHANGED:
  from importlib import reload 
  tools=reload(tools)
  print(dir(tools))   # run this to see EVERYTHING in the tools module
# Out:
# Yahoo!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import StratifiedKFold
import tensorflow as tf
from tensorflow import keras
import time
dt='float32'
tf.keras.backend.set_floatx(dt)

# %% [markdown]
# Build model

# %%
def compile_model(model):
    print("COMPILE...")
    ## learn rate = initial_learning_rate * decay_rate ^ (step / decay_steps)
    #adam_default_learn_rate = 0.001
    #schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    #    initial_learning_rate = adam_default_learn_rate*10,
    #    decay_steps=10000, decay_rate=0.99, staircase=True)
    #alrd = tf.keras.optimizers.Adam(learning_rate=schedule)
    
    ln_rate = tf.keras.optimizers.Adam(learning_rate = LN_RATE)
    bc=tf.keras.losses.BinaryCrossentropy(from_logits=False)
    model.compile(loss=bc, optimizer=ln_rate, metrics=["accuracy"])
    print("...COMPILED")
    return model

def build_model():
    #SHAPE=(MAXLEN,5)  
    SHAPE=(MAXLEN,4)  
    # 4 input letters, 4 output dimensions, 1000 letters/RNA
    elayer  = keras.layers.Embedding(4,4,input_length=1000) 

    clayer1 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same",
                                 input_shape=SHAPE)
    clayer2 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer3 = keras.layers.MaxPooling1D(2)
    clayer4 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer5 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer6 = keras.layers.MaxPooling1D(2)
    clayer7 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer8 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer9 = keras.layers.MaxPooling1D(2)
    clayer10 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer11 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer12 = keras.layers.MaxPooling1D(2)

    clayer13 = keras.layers.Flatten()

    dlayer1 = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt, input_shape=[DENSE_LEN])
    dlayer2 = keras.layers.Dropout(DROP)
    dlayer3 = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt)
    dlayer4 = keras.layers.Dropout(DROP)
    output_layer = keras.layers.Dense(1, activation="sigmoid", dtype=dt)

    cnn = keras.models.Sequential()
    cnn.add(elayer)
    cnn.add(clayer1)
    cnn.add(clayer2)
    cnn.add(clayer3)
    cnn.add(clayer4)
    cnn.add(clayer5)
    cnn.add(clayer6)
    cnn.add(clayer7)
    cnn.add(clayer8)
    cnn.add(clayer9)
    cnn.add(clayer10)
    cnn.add(clayer11)
    cnn.add(clayer12)
    cnn.add(clayer13)
    cnn.add(dlayer1)
    cnn.add(dlayer2)
    cnn.add(dlayer3)
    cnn.add(dlayer4)
    cnn.add(output_layer)
    mlpc = compile_model(cnn)
    return mlpc

# %% [markdown]
# Cross validation

# %%
def do_cross_validation(X,y,given_model,X_VALID,Y_VALID):
    cv_scores = []
    fold=0
    splitter = ShuffleSplit(n_splits=SPLITS, test_size=0.1, random_state=37863)
    for train_index,valid_index in splitter.split(X):
        fold += 1
        X_train=X[train_index] # use iloc[] for dataframe
        y_train=y[train_index]
        X_valid=X[valid_index]
        y_valid=y[valid_index]        
        # Avoid continually improving the same model.
        model = compile_model(keras.models.clone_model(given_model))
        bestname=MODEL_FILE+".cv."+str(fold)+".best"
        mycallbacks = [keras.callbacks.ModelCheckpoint(
            filepath=bestname, save_best_only=True, 
            monitor='val_accuracy', mode='max')]   
        print("FIT")
        start_time=time.time()
        history=model.fit(X_train, y_train, 
                epochs=EPOCHS, verbose=1, callbacks=mycallbacks,
                validation_data=(X_valid,y_valid))
        # THE VALIDATION ABOVE IS JUST FOR SHOW
        end_time=time.time()
        elapsed_time=(end_time-start_time)                        
        print("Fold %d, %d epochs, %d sec"%(fold,EPOCHS,elapsed_time))
        pd.DataFrame(history.history).plot(figsize=(8,5))
        plt.grid(True)
        plt.gca().set_ylim(0,1)
        plt.show()
        best_model=keras.models.load_model(bestname)
        # THE VALIDATION BELOW IS FOR KEEPS
        scores = best_model.evaluate(X_VALID, Y_VALID, verbose=0)
        print("%s: %.2f%%" % (best_model.metrics_names[1], scores[1]*100))
        cv_scores.append(scores[1] * 100)  
    print()
    print("%d-way Cross Validation mean %.2f%% (+/- %.2f%%)" % (fold, np.mean(cv_scores), np.std(cv_scores)))

# %% [markdown]
# ## Train on RNA lengths 200-1Kb

# %%
print ("Compile the model")
model=build_model()
print ("Summarize the model")
print(model.summary())  # Print this only once
#model.save(MODEL_FILE+'.model')
# Out:
# Compile the model
# COMPILE...
# ...COMPILED
# Summarize the model
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 1000, 4)           16
# _________________________________________________________________
# conv1d (Conv1D)              (None, 1000, 32)          416
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 1000, 32)          3104
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 500, 32)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 500, 32)           3104
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 500, 32)           3104
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 250, 32)           0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 250, 32)           3104
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 250, 32)           3104
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 125, 32)           0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 125, 32)           3104
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 125, 32)           3104
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 62, 32)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 1984)              0
# _________________________________________________________________
# dense (Dense)                (None, 24)                47640
# _________________________________________________________________
# dropout (Dropout)            (None, 24)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 24)                600
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 24)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 25
# =================================================================
# Total params: 70,425
# Trainable params: 70,425
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
def load_data_from_files(nc_filename,pc_filename):
  FREEMEM=True   # use False for debugging, True for production
  print("Load data from files.")
  nc_seq=tools.load_fasta(nc_filename,0)
  pc_seq=tools.load_fasta(pc_filename,1)
  train_set=pd.concat((nc_seq,pc_seq),axis=0)
  print("Ready: train_set")
  subset=tools.make_slice(train_set,MINLEN,MAXLEN)# One array to two: X and y
  if FREEMEM:
      nc_seq=None
      pc_seq=None
      train_set=None
  (X1,y_train)=tools.separate_X_and_y(subset)
  # X1 is pandas df of ("list" of one sequence)
  X2=X1.to_numpy()  # numpy ndarray of ("list" of one sequence)
  X3=[elem[0] for elem in X2]  # numpy ndarray of ACGT-str
  # X3? It might be faster to use int-array than char-array. Come back to this.
  X4=X3  # no-op
  print("X4",type(X4))
  #print(X4[0])
  if FREEMEM:
      X1=None
      X2=None
      X3=None
  X5=[]
  dna_to_int = {'A':0,'C':1,'G':2,'T':3}
  for x in X4:
      a=[]
      for c in x:
          i = dna_to_int[c]
          a.append(i)
      X5.append(a)
  X5=np.asarray(X5)
  print("X5",type(X5))
  print(X5.shape)
  if FREEMEM:
      X4=None
  X_train=X5
  if FREEMEM:
      X5=None
  print("X_train",type(X_train))
  y_train=y_train.to_numpy()
  print(X_train.shape)
  print(X_train[0].shape)
  print(X_train[0])
  return X_train,y_train

# %%
print("Loading training data...")
X_train,y_train = load_data_from_files(NC_FILENAME,PC_FILENAME)
# Out:
# Loading training data...
# Load data from files.
# Ready: train_set
# X4 <class 'list'>
# X5 <class 'numpy.ndarray'>
# (6000, 1000)
# X_train <class 'numpy.ndarray'>
# (6000, 1000)
# (1000,)
# [3 1 1 0 2 3 2 2 3 2 1 1 1 0 2 1 2 2 0 0 0 1 0 3 3 3 3 3 1 0 2 2 3 3 2 3 2
#  2 1 3 2 3 2 3 0 2 2 1 0 0 0 1 2 2 0 2 1 2 0 3 2 0 1 3 3 2 2 0 2 2 3 3 3 3
#  3 0 3 3 1 3 2 3 1 2 3 1 3 0 1 1 3 1 3 0 2 1 2 3 3 0 3 2 0 0 2 2 3 2 3 1 2
#  3 1 2 2 2 1 1 1 1 2 3 3 1 3 1 1 2 1 3 1 3 1 2 0 2 1 3 2 3 3 3 2 1 1 2 3 3
#  1 2 2 1 1 0 2 0 1 3 0 1 2 2 1 2 0 0 3 0 0 2 1 3 2 3 3 0 1 1 0 3 2 3 0 1 3
#  0 1 0 3 1 3 0 2 0 1 0 3 0 0 2 1 0 0 3 1 2 1 2 0 0 1 1 2 0 3 2 2 3 0 2 2 1
#  3 3 1 2 3 2 3 1 2 0 1 3 2 0 3 2 0 3 0 2 3 2 2 1 0 1 2 2 1 0 2 3 1 0 0 0 0
#  2 1 0 0 0 1 2 2 2 1 2 0 1 0 3 3 1 1 3 1 1 2 2 3 0 1 1 1 3 3 3 1 1 3 0 1 3
#  0 1 0 3 1 2 2 2 0 2 0 0 2 0 1 1 1 3 1 2 3 2 2 3 1 0 1 0 0 2 3 2 2 2 2 2 3
#  3 2 1 0 3 1 0 0 3 2 3 2 2 3 3 1 2 0 0 1 3 0 0 3 0 3 0 1 3 2 1 1 3 0 1 0 0
#  2 3 0 3 1 2 1 0 1 0 2 0 1 2 1 1 3 0 2 2 0 1 0 2 3 3 3 1 2 1 2 2 2 3 3 0 2
#  2 3 1 0 1 2 2 1 2 2 1 3 2 1 0 2 1 3 0 0 3 2 3 1 1 0 0 0 3 1 0 2 0 2 3 3 1
#  3 0 3 0 2 3 2 2 3 1 1 2 0 0 0 1 1 2 2 3 2 3 0 1 0 3 1 0 0 0 3 2 3 2 1 1 2
#  2 1 0 3 1 3 1 1 0 1 0 2 2 1 2 3 1 0 2 3 3 1 2 2 2 2 0 2 3 3 1 0 1 3 1 2 2
#  2 3 1 0 1 0 3 0 1 1 2 0 3 1 0 2 1 1 2 0 0 1 3 2 1 3 1 3 0 2 3 1 0 1 0 2 2
#  0 1 3 2 3 1 2 0 2 2 3 3 3 2 0 3 1 1 1 1 0 2 3 2 1 0 3 3 1 3 2 1 0 0 1 2 2
#  3 2 1 0 0 2 2 3 0 2 0 1 2 3 3 1 0 3 2 3 0 2 1 2 3 0 1 0 2 3 1 0 1 0 1 0 1
#  0 0 3 1 3 0 1 2 0 0 3 0 2 2 1 1 1 3 2 0 2 2 1 2 0 0 1 1 2 2 1 1 1 1 1 2 0
#  3]

# %%
print ("Cross validation")
do_cross_validation(X_train,y_train,model,X_VALID,Y_VALID)  
print ("Done")
# Out:
# Cross validation
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/10
# 169/169 [==============================] - 4s 9ms/step - loss: 0.6946 - accuracy: 0.4995 - val_loss: 0.6928 - val_accuracy: 0.5483
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_3K.cv.1.best/assets
# Epoch 2/10
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6938 - accuracy: 0.5013 - val_loss: 0.6920 - val_accuracy: 0.5200
# Epoch 3/10
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6917 - accuracy: 0.5111 - val_loss: 0.6859 - val_accuracy: 0.5367
# Epoch 4/10
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6734 - accuracy: 0.5797 - val_loss: 0.6629 - val_accuracy: 0.6000
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_3K.cv.1.best/assets
# Epoch 5/10
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6438 - accuracy: 0.6264 - val_loss: 0.6401 - val_accuracy: 0.6283
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_3K.cv.1.best/assets
# Epoch 6/10
# 169/169 [==============================] - 1s 6ms/step - loss: 0.5726 - accuracy: 0.7089 - val_loss: 0.6410 - val_accuracy: 0.6467
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_3K.cv.1.best/assets
# Epoch 7/10
# 169/169 [==============================] - 1s 6ms/step - loss: 0.5207 - accuracy: 0.7557 - val_loss: 0.6813 - val_accuracy: 0.6383
# Epoch 8/10
# 169/169 [==============================] - 1s 6ms/step - loss: 0.4699 - accuracy: 0.7878 - val_loss: 0.7299 - val_accuracy: 0.6267
# Epoch 9/10
# 169/169 [==============================] - 1s 6ms/step - loss: 0.4207 - accuracy: 0.8201 - val_loss: 0.7764 - val_accuracy: 0.6100
# Epoch 10/10
# 169/169 [==============================] - 1s 6ms/step - loss: 0.3484 - accuracy: 0.8493 - val_loss: 0.8622 - val_accuracy: 0.6033
# Fold 1, 10 epochs, 21 sec
# accuracy: 65.40%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/10
# 169/169 [==============================] - 2s 7ms/step - loss: 0.6946 - accuracy: 0.4919 - val_loss: 0.6912 - val_accuracy: 0.5450
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_3K.cv.2.best/assets
# Epoch 2/10
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6925 - accuracy: 0.5143 - val_loss: 0.6864 - val_accuracy: 0.5300
# Epoch 3/10
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6679 - accuracy: 0.6051 - val_loss: 0.6764 - val_accuracy: 0.5600
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_3K.cv.2.best/assets
# Epoch 4/10
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6390 - accuracy: 0.6291 - val_loss: 0.6854 - val_accuracy: 0.5467
# Epoch 5/10
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6026 - accuracy: 0.6749 - val_loss: 0.7298 - val_accuracy: 0.5400
# Epoch 6/10
# 169/169 [==============================] - 1s 6ms/step - loss: 0.5253 - accuracy: 0.7404 - val_loss: 0.7884 - val_accuracy: 0.5200
# Epoch 7/10
# 169/169 [==============================] - 1s 6ms/step - loss: 0.4542 - accuracy: 0.8079 - val_loss: 0.9246 - val_accuracy: 0.5467
# Epoch 8/10
# 169/169 [==============================] - 1s 6ms/step - loss: 0.3540 - accuracy: 0.8583 - val_loss: 1.0399 - val_accuracy: 0.5217
# Epoch 9/10
# 169/169 [==============================] - 1s 6ms/step - loss: 0.2878 - accuracy: 0.8895 - val_loss: 1.2841 - val_accuracy: 0.5250
# Epoch 10/10
# 169/169 [==============================] - 1s 6ms/step - loss: 0.2052 - accuracy: 0.9237 - val_loss: 1.4390 - val_accuracy: 0.5550
# Fold 2, 10 epochs, 15 sec
# accuracy: 58.95%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/10
# 169/169 [==============================] - 3s 8ms/step - loss: 0.6937 - accuracy: 0.5097 - val_loss: 0.6912 - val_accuracy: 0.5283
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_3K.cv.3.best/assets
# Epoch 2/10
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6888 - accuracy: 0.5342 - val_loss: 0.6418 - val_accuracy: 0.6150
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_3K.cv.3.best/assets
# Epoch 3/10
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6536 - accuracy: 0.6164 - val_loss: 0.6245 - val_accuracy: 0.6333
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_3K.cv.3.best/assets
# Epoch 4/10
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6087 - accuracy: 0.6621 - val_loss: 0.6073 - val_accuracy: 0.6750
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_3K.cv.3.best/assets
# Epoch 5/10
# 169/169 [==============================] - 1s 6ms/step - loss: 0.5954 - accuracy: 0.6913 - val_loss: 0.7293 - val_accuracy: 0.5900
# Epoch 6/10
# 169/169 [==============================] - 1s 6ms/step - loss: 0.5230 - accuracy: 0.7417 - val_loss: 0.6655 - val_accuracy: 0.6400
# Epoch 7/10
# 169/169 [==============================] - 1s 6ms/step - loss: 0.4602 - accuracy: 0.7929 - val_loss: 0.7316 - val_accuracy: 0.6250
# Epoch 8/10
# 169/169 [==============================] - 1s 6ms/step - loss: 0.3856 - accuracy: 0.8393 - val_loss: 0.8359 - val_accuracy: 0.5933
# Epoch 9/10
# 169/169 [==============================] - 1s 6ms/step - loss: 0.3128 - accuracy: 0.8778 - val_loss: 1.0483 - val_accuracy: 0.5900
# Epoch 10/10
# 169/169 [==============================] - 1s 6ms/step - loss: 0.2612 - accuracy: 0.8949 - val_loss: 1.1610 - val_accuracy: 0.6050
# Fold 3, 10 epochs, 20 sec
# accuracy: 67.91%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/10
# 169/169 [==============================] - 2s 8ms/step - loss: 0.6944 - accuracy: 0.5088 - val_loss: 0.6916 - val_accuracy: 0.5267
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_3K.cv.4.best/assets
# Epoch 2/10
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6926 - accuracy: 0.5104 - val_loss: 0.6799 - val_accuracy: 0.5950
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_3K.cv.4.best/assets
# Epoch 3/10
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6735 - accuracy: 0.5748 - val_loss: 0.6732 - val_accuracy: 0.6067
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_3K.cv.4.best/assets
# Epoch 4/10
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6458 - accuracy: 0.6259 - val_loss: 0.6476 - val_accuracy: 0.6317
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_3K.cv.4.best/assets
# Epoch 5/10
# 169/169 [==============================] - 1s 6ms/step - loss: 0.5995 - accuracy: 0.6781 - val_loss: 0.6475 - val_accuracy: 0.6417
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_3K.cv.4.best/assets
# Epoch 6/10
# 169/169 [==============================] - 1s 6ms/step - loss: 0.5338 - accuracy: 0.7416 - val_loss: 0.6948 - val_accuracy: 0.6183
# Epoch 7/10
# 169/169 [==============================] - 1s 6ms/step - loss: 0.4733 - accuracy: 0.7752 - val_loss: 0.7843 - val_accuracy: 0.6083
# Epoch 8/10
# 169/169 [==============================] - 1s 6ms/step - loss: 0.4164 - accuracy: 0.8169 - val_loss: 0.8644 - val_accuracy: 0.5833
# Epoch 9/10
# 169/169 [==============================] - 1s 6ms/step - loss: 0.3256 - accuracy: 0.8616 - val_loss: 1.0123 - val_accuracy: 0.5933
# Epoch 10/10
# 169/169 [==============================] - 1s 6ms/step - loss: 0.2521 - accuracy: 0.9026 - val_loss: 1.1990 - val_accuracy: 0.5783
# Fold 4, 10 epochs, 22 sec
# accuracy: 65.18%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/10
# 169/169 [==============================] - 2s 8ms/step - loss: 0.6947 - accuracy: 0.5085 - val_loss: 0.6916 - val_accuracy: 0.5267
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_3K.cv.5.best/assets
# Epoch 2/10
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6946 - accuracy: 0.5101 - val_loss: 0.6760 - val_accuracy: 0.5733
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_3K.cv.5.best/assets
# Epoch 3/10
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6702 - accuracy: 0.5988 - val_loss: 0.6662 - val_accuracy: 0.6133
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_3K.cv.5.best/assets
# Epoch 4/10
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6489 - accuracy: 0.6313 - val_loss: 0.6491 - val_accuracy: 0.5967
# Epoch 5/10
# 169/169 [==============================] - 1s 6ms/step - loss: 0.6152 - accuracy: 0.6599 - val_loss: 0.6413 - val_accuracy: 0.6117
# Epoch 6/10
# 169/169 [==============================] - 1s 6ms/step - loss: 0.5774 - accuracy: 0.7001 - val_loss: 0.6483 - val_accuracy: 0.6333
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_3K.cv.5.best/assets
# Epoch 7/10
# 169/169 [==============================] - 1s 6ms/step - loss: 0.5281 - accuracy: 0.7462 - val_loss: 0.6681 - val_accuracy: 0.6433
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_3K.cv.5.best/assets
# Epoch 8/10
# 169/169 [==============================] - 1s 6ms/step - loss: 0.4524 - accuracy: 0.7942 - val_loss: 0.7334 - val_accuracy: 0.6367
# Epoch 9/10
# 169/169 [==============================] - 1s 6ms/step - loss: 0.3769 - accuracy: 0.8444 - val_loss: 0.8197 - val_accuracy: 0.6033
# Epoch 10/10
# 169/169 [==============================] - 1s 6ms/step - loss: 0.3023 - accuracy: 0.8858 - val_loss: 0.8816 - val_accuracy: 0.6417
# Fold 5, 10 epochs, 22 sec
# accuracy: 63.96%
#
# 5-way Cross Validation mean 64.28% (+/- 2.96%)
# Done
