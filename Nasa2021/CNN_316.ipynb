# %% [markdown]
# # CNN 316
# Rather than partition train/validation sets, use different sets.
# Cut train set down to random LIMIT number of transcripts.
# Use all of the validation set.
# Use fit(shuffle) on the train set.
#
# TO DO:
# Save five best models to same directory to make it easy to delete.

# %%
TRAIN_NC_FILENAME='ncRNA.gc36.long.fasta'
TRAIN_PC_FILENAME='pcRNA.gc36.long.fasta'
VALID_NC_FILENAME='ncRNA.gc36.short.fasta'
VALID_PC_FILENAME='pcRNA.gc36.short.fasta'
#NC_FILENAME='ncRNA.tiny50.fasta'
#PC_FILENAME='pcRNA.tiny50.fasta'
#NC_FILENAME='ncRNA.gc34.processed.fasta'
#PC_FILENAME='pcRNA.gc34.processed.fasta'

MODEL_FILE='JUNK2'  # change this if you want to keep models
DATAPATH=''

try:
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
except:
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"
TRAIN_NC_FILENAME = DATAPATH+TRAIN_NC_FILENAME
TRAIN_PC_FILENAME = DATAPATH+TRAIN_PC_FILENAME
VALID_NC_FILENAME = DATAPATH+VALID_NC_FILENAME
VALID_PC_FILENAME = DATAPATH+VALID_PC_FILENAME
MODEL_FILE=DATAPATH+MODEL_FILE

EPOCHS=200
SPLITS=5
K=1
VOCABULARY_SIZE=4**K+1   # e.g. K=3 => 64 DNA K-mers + 'NNN'
EMBED_DIMEN=2
FILTERS=32
KERNEL=3
NEURONS=32
DROP=0.25
ACT="tanh"
MINLEN=201
MAXLEN=2000
LIMIT=5588    # This is the size of our smallest set (protein coding short)
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# Load our own tools
# TO DO: don't go to GitHub if the file is already local.
GITHUB = True
if GITHUB:
    #!pip install requests  # Uncomment this if necessary. Seems to be pre-installed.
    import requests
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/ShepherdML/master/Strings/tools_fasta.py')
    with open('tools_fasta.py', 'w') as f:
        f.write(r.text)
    # TO DO: delete the file after import
import tools_fasta as tools
tools.yahoo()  # If this prints "Yahoo!" the the import was successful.

TOOLS_CHANGED = False   # set to True to re-run with a new version of tools
if TOOLS_CHANGED:
  from importlib import reload 
  tools=reload(tools)
  print(dir(tools))   # run this to see EVERYTHING in the tools module
# Out:
# Yahoo!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import StratifiedKFold
import tensorflow as tf
from tensorflow import keras
import time
dt='float32'
tf.keras.backend.set_floatx(dt)

# %% [markdown]
# Build model

# %%
def compile_model(model):
    ## learn rate = initial_learning_rate * decay_rate ^ (step / decay_steps)
    #adam_default_learn_rate = 0.001
    #schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    #    initial_learning_rate = adam_default_learn_rate*10,
    #    decay_steps=10000, decay_rate=0.99, staircase=True)
    #alrd = tf.keras.optimizers.Adam(learning_rate=schedule)
    #model.compile(loss=bc, optimizer=alrd, metrics=["accuracy"])

    print("COMPILE...")
    bc=tf.keras.losses.BinaryCrossentropy(from_logits=False)
    model.compile(loss=bc, optimizer="adam", metrics=["accuracy"])
    print("...COMPILED")
    return model

def build_model():
    SHAPE=(MAXLEN,5)  # MAXLEN bases = time steps, 5 features = one hots
    clayer1 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same",
                                 input_shape=SHAPE)
    clayer2 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer3 = keras.layers.MaxPooling1D(2)
    clayer4 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer5 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer6 = keras.layers.MaxPooling1D(2)
    clayer7 = keras.layers.Flatten()

    dlayer1 = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt, input_shape=[1000])
    dlayer2 = keras.layers.Dropout(DROP)
    dlayer3 = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt)
    dlayer4 = keras.layers.Dropout(DROP)
    output_layer = keras.layers.Dense(1, activation="sigmoid", dtype=dt)

    cnn = keras.models.Sequential()
    cnn.add(clayer1)
    cnn.add(clayer2)
    cnn.add(clayer3)
    cnn.add(clayer4)
    cnn.add(clayer5)
    cnn.add(clayer6)
    cnn.add(clayer7)
    cnn.add(dlayer1)
    cnn.add(dlayer2)
    cnn.add(dlayer3)
    cnn.add(dlayer4)
    cnn.add(output_layer)
    mlpc = compile_model(cnn)
    return mlpc

# %% [markdown]
# Cross validation

# %%
def do_cross_validation(X_train,y_train,given_model,X_valid,y_valid):
    cv_scores = []
    fold=0
    # When not using ShuffleSplit, make sure to randomize train data.
    #splitter = ShuffleSplit(n_splits=SPLITS, test_size=0.1, random_state=37863)
    #for train_index,valid_index in splitter.split(X):
    while fold < SPLITS:
        fold += 1
        # Avoid continually improving the same model.
        model = compile_model(keras.models.clone_model(given_model))
        bestname=MODEL_FILE+".cv."+str(fold)+".best"
        es = keras.callbacks.EarlyStopping(monitor='val_loss',  
            patience=10, verbose=1)
        mc = keras.callbacks.ModelCheckpoint(
            filepath=bestname, save_best_only=True, 
            monitor='val_accuracy', mode='max')  
        mycallbacks = [es,mc]  
        print("FIT")
        start_time=time.time()
        history=model.fit(X_train, y_train, # batch_size=10, default=32 works nicely
                epochs=EPOCHS, verbose=1,  # verbose=1 for ascii art, verbose=0 for none
                callbacks=mycallbacks, shuffle=True,
                validation_data=(X_valid,y_valid) )
        end_time=time.time()
        elapsed_time=(end_time-start_time)                        
        print("Fold %d, %d epochs, %d sec"%(fold,EPOCHS,elapsed_time))
        pd.DataFrame(history.history).plot(figsize=(8,5))
        plt.grid(True)
        plt.gca().set_ylim(0,1)
        plt.show()
        best_model=keras.models.load_model(bestname)
        scores = best_model.evaluate(X_valid, y_valid, verbose=0)
        print("%s: %.2f%%" % (best_model.metrics_names[1], scores[1]*100))
        cv_scores.append(scores[1] * 100)  

    print()
    print("%d-way Cross Validation max %.2f%%, mean %.2f%% (+/- %.2f%%)" % 
          (fold, np.amax(cv_scores), np.mean(cv_scores), np.std(cv_scores)))

# %% [markdown]
# ## Train on RNA lengths 200-1Kb

# %%
print ("Compile the model")
model=build_model()
print ("Summarize the model")
print(model.summary())  # Print this only once
#model.save(MODEL_FILE+'.model')
# Out:
# Compile the model
# COMPILE...
# ...COMPILED
# Summarize the model
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_12 (Conv1D)           (None, 2000, 32)          512
# _________________________________________________________________
# conv1d_13 (Conv1D)           (None, 2000, 32)          3104
# _________________________________________________________________
# max_pooling1d_6 (MaxPooling1 (None, 1000, 32)          0
# _________________________________________________________________
# conv1d_14 (Conv1D)           (None, 1000, 32)          3104
# _________________________________________________________________
# conv1d_15 (Conv1D)           (None, 1000, 32)          3104
# _________________________________________________________________
# max_pooling1d_7 (MaxPooling1 (None, 500, 32)           0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 16000)             0
# _________________________________________________________________
# dense_9 (Dense)              (None, 32)                512032
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 522,945
# Trainable params: 522,945
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
def load_data(nc_filename,pc_filename,limit=None):
  nc_seq=tools.load_fasta(nc_filename,0)
  pc_seq=tools.load_fasta(pc_filename,1)
  if limit is not None:
    # Choose a random subset of size = limit.
    # Side effect: randomizes the data order.
    nfrac=1.0*limit/len(nc_seq)
    pfrac=1.0*limit/len(pc_seq)
    if nfrac<1.0:
      nc_seq=nc_seq.sample(frac=nfrac)
    if pfrac<1.0:
      pc_seq=pc_seq.sample(frac=pfrac)
  train_set=pd.concat((nc_seq,pc_seq),axis=0)
  # May not need to slice by length if input files already sliced
  subset=tools.make_slice(train_set,MINLEN,MAXLEN)
  # randset=subset.sample(frac=1) # unneccessary with fit(shuffle)
  (X1,y1)=tools.separate_X_and_y(subset)
  # X1 is pandas df of ("list" of one sequence)
  X2=X1.to_numpy()  # numpy ndarray of ("list" of one sequence)
  X3=[elem[0] for elem in X2]  # numpy dnarray of str
  X4=tools.uniform_length(X3,MAXLEN)
  X5= [tools.one_hot(x) for x in X4]
  X6=np.asarray(X5)
  y6=y1.to_numpy()
  return X6,y6

print("Load train data from files.")
X_train,y_train = load_data(TRAIN_NC_FILENAME,TRAIN_PC_FILENAME,LIMIT)
print("X_train",X_train.shape)
print("Load valid data from files.")
X_valid,y_valid = load_data(VALID_NC_FILENAME,VALID_PC_FILENAME)
print("X_valid",X_valid.shape)
# Out:
# Load train data from files.
# X_train (11176, 2000, 5)
# Load valid data from files.
# X_valid (18216, 2000, 5)

# %%
print ("Cross valiation")
do_cross_validation(X_train,y_train,model,X_valid,y_valid)  
print ("Done")
# Out:
# Cross valiation
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/200
# 350/350 [==============================] - 5s 11ms/step - loss: 0.6749 - accuracy: 0.6447 - val_loss: 0.6500 - val_accuracy: 0.6471
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.1.best/assets
# Epoch 2/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.6213 - accuracy: 0.6731 - val_loss: 0.6225 - val_accuracy: 0.6863
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.1.best/assets
# Epoch 3/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.6191 - accuracy: 0.6785 - val_loss: 0.6034 - val_accuracy: 0.6980
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.1.best/assets
# Epoch 4/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5829 - accuracy: 0.7056 - val_loss: 0.6114 - val_accuracy: 0.6944
# Epoch 5/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.5949 - accuracy: 0.6903 - val_loss: 0.6281 - val_accuracy: 0.6768
# Epoch 6/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.5804 - accuracy: 0.7053 - val_loss: 0.6056 - val_accuracy: 0.6960
# Epoch 7/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5764 - accuracy: 0.6951 - val_loss: 0.5829 - val_accuracy: 0.7116
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.1.best/assets
# Epoch 8/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5899 - accuracy: 0.6996 - val_loss: 0.5866 - val_accuracy: 0.7027
# Epoch 9/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5902 - accuracy: 0.6968 - val_loss: 0.6180 - val_accuracy: 0.6804
# Epoch 10/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.6229 - accuracy: 0.6634 - val_loss: 0.6838 - val_accuracy: 0.4761
# Epoch 11/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.6550 - accuracy: 0.6127 - val_loss: 0.6109 - val_accuracy: 0.6875
# Epoch 12/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.6301 - accuracy: 0.6545 - val_loss: 0.6002 - val_accuracy: 0.6968
# Epoch 13/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.5735 - accuracy: 0.7116 - val_loss: 0.5915 - val_accuracy: 0.6907
# Epoch 14/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5769 - accuracy: 0.7062 - val_loss: 0.6021 - val_accuracy: 0.6953
# Epoch 15/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5780 - accuracy: 0.7084 - val_loss: 0.6033 - val_accuracy: 0.6929
# Epoch 16/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5689 - accuracy: 0.7144 - val_loss: 0.6351 - val_accuracy: 0.6320
# Epoch 17/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5613 - accuracy: 0.7167 - val_loss: 0.5843 - val_accuracy: 0.7036
# Epoch 00017: early stopping
# Fold 1, 200 epochs, 73 sec
# accuracy: 71.16%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/200
# 350/350 [==============================] - 5s 11ms/step - loss: 0.6417 - accuracy: 0.6563 - val_loss: 0.5686 - val_accuracy: 0.7070
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.2.best/assets
# Epoch 2/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5943 - accuracy: 0.6907 - val_loss: 0.6251 - val_accuracy: 0.6722
# Epoch 3/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5599 - accuracy: 0.7153 - val_loss: 0.5755 - val_accuracy: 0.7140
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.2.best/assets
# Epoch 4/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5689 - accuracy: 0.7052 - val_loss: 0.6033 - val_accuracy: 0.6836
# Epoch 5/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5653 - accuracy: 0.7098 - val_loss: 0.5669 - val_accuracy: 0.7145
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.2.best/assets
# Epoch 6/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5721 - accuracy: 0.7017 - val_loss: 0.5766 - val_accuracy: 0.7162
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.2.best/assets
# Epoch 7/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5625 - accuracy: 0.7166 - val_loss: 0.6028 - val_accuracy: 0.7001
# Epoch 8/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5649 - accuracy: 0.7169 - val_loss: 0.6565 - val_accuracy: 0.6445
# Epoch 9/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5846 - accuracy: 0.7036 - val_loss: 0.5834 - val_accuracy: 0.7033
# Epoch 10/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5619 - accuracy: 0.7235 - val_loss: 0.5925 - val_accuracy: 0.7088
# Epoch 11/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5576 - accuracy: 0.7308 - val_loss: 0.5876 - val_accuracy: 0.6960
# Epoch 12/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5449 - accuracy: 0.7338 - val_loss: 0.5823 - val_accuracy: 0.6961
# Epoch 13/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5436 - accuracy: 0.7294 - val_loss: 0.5752 - val_accuracy: 0.7083
# Epoch 14/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5471 - accuracy: 0.7295 - val_loss: 0.5844 - val_accuracy: 0.7056
# Epoch 15/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5808 - accuracy: 0.7009 - val_loss: 0.6185 - val_accuracy: 0.6668
# Epoch 00015: early stopping
# Fold 2, 200 epochs, 64 sec
# accuracy: 71.62%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/200
# 350/350 [==============================] - 5s 12ms/step - loss: 0.6368 - accuracy: 0.6611 - val_loss: 0.5723 - val_accuracy: 0.7207
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.3.best/assets
# Epoch 2/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5839 - accuracy: 0.7034 - val_loss: 0.5811 - val_accuracy: 0.6915
# Epoch 3/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5794 - accuracy: 0.6986 - val_loss: 0.5862 - val_accuracy: 0.7052
# Epoch 4/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5643 - accuracy: 0.7184 - val_loss: 0.6009 - val_accuracy: 0.7004
# Epoch 5/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.5810 - accuracy: 0.6987 - val_loss: 0.6752 - val_accuracy: 0.6266
# Epoch 6/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5590 - accuracy: 0.7089 - val_loss: 0.7239 - val_accuracy: 0.5791
# Epoch 7/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5713 - accuracy: 0.7006 - val_loss: 0.5737 - val_accuracy: 0.7090
# Epoch 8/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.5563 - accuracy: 0.7189 - val_loss: 0.5616 - val_accuracy: 0.7105
# Epoch 9/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5446 - accuracy: 0.7240 - val_loss: 0.5781 - val_accuracy: 0.7082
# Epoch 10/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.5384 - accuracy: 0.7337 - val_loss: 0.5818 - val_accuracy: 0.7033
# Epoch 11/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.5393 - accuracy: 0.7272 - val_loss: 0.5593 - val_accuracy: 0.7139
# Epoch 12/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.5195 - accuracy: 0.7360 - val_loss: 0.5219 - val_accuracy: 0.7451
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.3.best/assets
# Epoch 13/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.5104 - accuracy: 0.7534 - val_loss: 0.5316 - val_accuracy: 0.7367
# Epoch 14/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.5189 - accuracy: 0.7432 - val_loss: 0.5245 - val_accuracy: 0.7541
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.3.best/assets
# Epoch 15/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.5096 - accuracy: 0.7495 - val_loss: 0.5055 - val_accuracy: 0.7600
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.3.best/assets
# Epoch 16/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.4857 - accuracy: 0.7713 - val_loss: 0.5437 - val_accuracy: 0.7245
# Epoch 17/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.4902 - accuracy: 0.7616 - val_loss: 0.5053 - val_accuracy: 0.7590
# Epoch 18/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.4435 - accuracy: 0.7934 - val_loss: 0.4505 - val_accuracy: 0.7989
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.3.best/assets
# Epoch 19/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.4119 - accuracy: 0.8099 - val_loss: 0.4388 - val_accuracy: 0.8045
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.3.best/assets
# Epoch 20/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.3919 - accuracy: 0.8232 - val_loss: 0.4465 - val_accuracy: 0.7995
# Epoch 21/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.3767 - accuracy: 0.8311 - val_loss: 0.4279 - val_accuracy: 0.8116
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.3.best/assets
# Epoch 22/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.3446 - accuracy: 0.8457 - val_loss: 0.4109 - val_accuracy: 0.8365
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.3.best/assets
# Epoch 23/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.3341 - accuracy: 0.8574 - val_loss: 0.4270 - val_accuracy: 0.8146
# Epoch 24/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.2997 - accuracy: 0.8719 - val_loss: 0.4353 - val_accuracy: 0.8241
# Epoch 25/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.2865 - accuracy: 0.8773 - val_loss: 0.4074 - val_accuracy: 0.8388
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.3.best/assets
# Epoch 26/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.2699 - accuracy: 0.8888 - val_loss: 0.3876 - val_accuracy: 0.8477
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.3.best/assets
# Epoch 27/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.2404 - accuracy: 0.9046 - val_loss: 0.4042 - val_accuracy: 0.8538
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.3.best/assets
# Epoch 28/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.2227 - accuracy: 0.9111 - val_loss: 0.4874 - val_accuracy: 0.7950
# Epoch 29/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.2278 - accuracy: 0.9077 - val_loss: 0.4447 - val_accuracy: 0.8295
# Epoch 30/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.2254 - accuracy: 0.9074 - val_loss: 0.4469 - val_accuracy: 0.8485
# Epoch 31/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.1874 - accuracy: 0.9250 - val_loss: 0.4822 - val_accuracy: 0.8245
# Epoch 32/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.1854 - accuracy: 0.9293 - val_loss: 0.4472 - val_accuracy: 0.8492
# Epoch 33/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.1694 - accuracy: 0.9349 - val_loss: 0.4589 - val_accuracy: 0.8439
# Epoch 34/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.1616 - accuracy: 0.9402 - val_loss: 0.4760 - val_accuracy: 0.8522
# Epoch 35/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.1372 - accuracy: 0.9493 - val_loss: 0.4749 - val_accuracy: 0.8605
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.3.best/assets
# Epoch 36/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.1417 - accuracy: 0.9485 - val_loss: 0.4898 - val_accuracy: 0.8490
# Epoch 00036: early stopping
# Fold 3, 200 epochs, 162 sec
# accuracy: 86.05%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/200
# 350/350 [==============================] - 5s 12ms/step - loss: 0.6392 - accuracy: 0.6663 - val_loss: 0.6401 - val_accuracy: 0.6729
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.4.best/assets
# Epoch 2/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5990 - accuracy: 0.6840 - val_loss: 0.5831 - val_accuracy: 0.6911
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.4.best/assets
# Epoch 3/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.5849 - accuracy: 0.6995 - val_loss: 0.5995 - val_accuracy: 0.6797
# Epoch 4/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.5625 - accuracy: 0.7169 - val_loss: 0.5744 - val_accuracy: 0.7172
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.4.best/assets
# Epoch 5/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.5792 - accuracy: 0.6997 - val_loss: 0.5903 - val_accuracy: 0.6814
# Epoch 6/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.5774 - accuracy: 0.7040 - val_loss: 0.5800 - val_accuracy: 0.7012
# Epoch 7/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.5771 - accuracy: 0.7013 - val_loss: 0.6148 - val_accuracy: 0.6810
# Epoch 8/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.5702 - accuracy: 0.7140 - val_loss: 0.5843 - val_accuracy: 0.6950
# Epoch 9/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.5710 - accuracy: 0.7022 - val_loss: 0.5806 - val_accuracy: 0.6904
# Epoch 10/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5673 - accuracy: 0.7112 - val_loss: 0.5786 - val_accuracy: 0.7114
# Epoch 11/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.5826 - accuracy: 0.7028 - val_loss: 0.6020 - val_accuracy: 0.6826
# Epoch 12/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.5774 - accuracy: 0.7008 - val_loss: 0.6067 - val_accuracy: 0.6734
# Epoch 13/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.5665 - accuracy: 0.7093 - val_loss: 0.6247 - val_accuracy: 0.6612
# Epoch 14/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.5673 - accuracy: 0.7133 - val_loss: 0.6165 - val_accuracy: 0.6688
# Epoch 00014: early stopping
# Fold 4, 200 epochs, 62 sec
# accuracy: 71.72%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/200
# 350/350 [==============================] - 5s 12ms/step - loss: 0.6547 - accuracy: 0.6489 - val_loss: 0.6508 - val_accuracy: 0.6539
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.5.best/assets
# Epoch 2/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.6086 - accuracy: 0.6918 - val_loss: 0.6564 - val_accuracy: 0.6556
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.5.best/assets
# Epoch 3/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.6091 - accuracy: 0.6927 - val_loss: 0.6083 - val_accuracy: 0.6868
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.5.best/assets
# Epoch 4/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.6041 - accuracy: 0.6929 - val_loss: 0.6165 - val_accuracy: 0.6847
# Epoch 5/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5904 - accuracy: 0.7011 - val_loss: 0.6132 - val_accuracy: 0.6970
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.5.best/assets
# Epoch 6/200
# 350/350 [==============================] - 4s 13ms/step - loss: 0.5745 - accuracy: 0.7152 - val_loss: 0.6247 - val_accuracy: 0.6639
# Epoch 7/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.5770 - accuracy: 0.7154 - val_loss: 0.6186 - val_accuracy: 0.6686
# Epoch 8/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5748 - accuracy: 0.7114 - val_loss: 0.6212 - val_accuracy: 0.6623
# Epoch 9/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.5735 - accuracy: 0.7116 - val_loss: 0.5767 - val_accuracy: 0.7120
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.5.best/assets
# Epoch 10/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.5731 - accuracy: 0.7054 - val_loss: 0.6123 - val_accuracy: 0.6728
# Epoch 11/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5785 - accuracy: 0.7025 - val_loss: 0.6294 - val_accuracy: 0.6612
# Epoch 12/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.5743 - accuracy: 0.7232 - val_loss: 0.6024 - val_accuracy: 0.6841
# Epoch 13/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.5757 - accuracy: 0.7068 - val_loss: 0.5912 - val_accuracy: 0.7105
# Epoch 14/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.5755 - accuracy: 0.7144 - val_loss: 0.6011 - val_accuracy: 0.6931
# Epoch 15/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.5694 - accuracy: 0.7200 - val_loss: 0.5775 - val_accuracy: 0.7065
# Epoch 16/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.5666 - accuracy: 0.7119 - val_loss: 0.5785 - val_accuracy: 0.7093
# Epoch 17/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.5739 - accuracy: 0.7127 - val_loss: 0.6084 - val_accuracy: 0.6873
# Epoch 18/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.5605 - accuracy: 0.7283 - val_loss: 0.5728 - val_accuracy: 0.6981
# Epoch 19/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.5965 - accuracy: 0.6921 - val_loss: 0.6196 - val_accuracy: 0.6737
# Epoch 20/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.5649 - accuracy: 0.7169 - val_loss: 0.5888 - val_accuracy: 0.6916
# Epoch 21/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.5695 - accuracy: 0.7091 - val_loss: 0.5858 - val_accuracy: 0.6969
# Epoch 22/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.5596 - accuracy: 0.7212 - val_loss: 0.5871 - val_accuracy: 0.6998
# Epoch 23/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.5728 - accuracy: 0.7097 - val_loss: 0.6057 - val_accuracy: 0.6888
# Epoch 24/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.5576 - accuracy: 0.7267 - val_loss: 0.6062 - val_accuracy: 0.6927
# Epoch 25/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5635 - accuracy: 0.7195 - val_loss: 0.6251 - val_accuracy: 0.6566
# Epoch 26/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.5639 - accuracy: 0.7105 - val_loss: 0.6040 - val_accuracy: 0.6907
# Epoch 27/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.5600 - accuracy: 0.7173 - val_loss: 0.5936 - val_accuracy: 0.6794
# Epoch 28/200
# 350/350 [==============================] - 4s 12ms/step - loss: 0.5570 - accuracy: 0.7195 - val_loss: 0.5751 - val_accuracy: 0.7083
# Epoch 00028: early stopping
# Fold 5, 200 epochs, 121 sec
# accuracy: 71.20%
#
# 5-way Cross Validation max 86.05%, mean 74.35% (+/- 5.85%)
# Done
