# %% [markdown]
# <a href="https://colab.research.google.com/github/ShepherdCode/ShepherdML/blob/master/Nasa2021/CNN_520.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CNN 520
#
# 1. Three layers of CNNS and MaxPooling
# 2. Drop out at 0.2
# 3. Variable filters and dense neurons

# %%
#NC_FILENAME='ncRNA.tiny50.fasta'
#PC_FILENAME='pcRNA.tiny50.fasta'
#NC_FILENAME='ncRNA.gc34.processed.fasta'
#PC_FILENAME='pcRNA.gc34.processed.fasta'
NC_FILENAME='ncRNA.gc36.balance.fasta'
PC_FILENAME='pcRNA.gc36.balance.fasta'

MODEL_FILE='CNN520' 
DATAPATH=''

try:
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
except:
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"
NC_FILENAME = DATAPATH+NC_FILENAME
PC_FILENAME = DATAPATH+PC_FILENAME
MODEL_FILE=DATAPATH+MODEL_FILE

EPOCHS=50
SPLITS=5
K=1
VOCABULARY_SIZE=4**K+1   # e.g. K=3 => 64 DNA K-mers + 'NNN'
EMBED_DIMEN=2
FILTERS=32
KERNEL=3
NEURONS=24
DROP=0.2
MINLEN=200
MAXLEN=2000
DENSE_LEN = 1000
ACT="tanh"
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# Load our own tools
# TO DO: don't go to GitHub if the file is already local.
GITHUB = True
if GITHUB:
    #!pip install requests  # Uncomment this if necessary. Seems to be pre-installed.
    import requests
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/ShepherdML/master/Strings/tools_fasta.py')
    with open('tools_fasta.py', 'w') as f:
        f.write(r.text)
    # TO DO: delete the file after import
import tools_fasta as tools
tools.yahoo()  # If this prints "Yahoo!" the the import was successful.

TOOLS_CHANGED = False   # set to True to re-run with a new version of tools
if TOOLS_CHANGED:
  from importlib import reload 
  tools=reload(tools)
  print(dir(tools))   # run this to see EVERYTHING in the tools module
# Out:
# Yahoo!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import StratifiedKFold
import tensorflow as tf
from tensorflow import keras
import time
dt='float32'
tf.keras.backend.set_floatx(dt)

# %% [markdown]
# Build model

# %%
def compile_model(model):
    ## learn rate = initial_learning_rate * decay_rate ^ (step / decay_steps)
    #adam_default_learn_rate = 0.001
    #schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    #    initial_learning_rate = adam_default_learn_rate*10,
    #    decay_steps=10000, decay_rate=0.99, staircase=True)
    #alrd = tf.keras.optimizers.Adam(learning_rate=schedule)
    #model.compile(loss=bc, optimizer=alrd, metrics=["accuracy"])

    print("COMPILE...")
    bc=tf.keras.losses.BinaryCrossentropy(from_logits=False)
    model.compile(loss=bc, optimizer="adam", metrics=["accuracy"])
    print("...COMPILED")
    return model

def build_model():
    SHAPE=(MAXLEN,5)  # 2000 time steps, 5 features
    clayer1 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same",
                                 input_shape=SHAPE)
    clayer2 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer3 = keras.layers.MaxPooling1D(2)
    clayer4 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer5 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer6 = keras.layers.MaxPooling1D(2)
    clayer8 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer9 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer10 = keras.layers.MaxPooling1D(2)

    clayer7 = keras.layers.Flatten()

    dlayer1 = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt, input_shape=[DENSE_LEN])
    dlayer2 = keras.layers.Dropout(DROP)
    dlayer3 = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt)
    dlayer4 = keras.layers.Dropout(DROP)
    output_layer = keras.layers.Dense(1, activation="sigmoid", dtype=dt)

    cnn = keras.models.Sequential()
    cnn.add(clayer1)
    cnn.add(clayer2)
    cnn.add(clayer3)
    cnn.add(clayer4)
    cnn.add(clayer5)
    cnn.add(clayer6)
    cnn.add(clayer8)
    cnn.add(clayer9)
    cnn.add(clayer10)
    cnn.add(clayer7)
    cnn.add(dlayer1)
    cnn.add(dlayer2)
    cnn.add(dlayer3)
    cnn.add(dlayer4)
    cnn.add(output_layer)
    mlpc = compile_model(cnn)
    return mlpc

# %% [markdown]
# Cross validation

# %%
def do_cross_validation(X,y,given_model):
    cv_scores = []
    fold=0
    splitter = ShuffleSplit(n_splits=SPLITS, test_size=0.1, random_state=37863)
    for train_index,valid_index in splitter.split(X):
        fold += 1
        X_train=X[train_index] # use iloc[] for dataframe
        y_train=y[train_index]
        X_valid=X[valid_index]
        y_valid=y[valid_index]        
        # Avoid continually improving the same model.
        model = compile_model(keras.models.clone_model(given_model))
        bestname=MODEL_FILE+".cv."+str(fold)+".best"
        mycallbacks = [keras.callbacks.ModelCheckpoint(
            filepath=bestname, save_best_only=True, 
            monitor='val_accuracy', mode='max')]   
        print("FIT")
        start_time=time.time()
        history=model.fit(X_train, y_train, # batch_size=10, default=32 works nicely
                epochs=EPOCHS, verbose=1,  # verbose=1 for ascii art, verbose=0 for none
                callbacks=mycallbacks,
                validation_data=(X_valid,y_valid) )
        end_time=time.time()
        elapsed_time=(end_time-start_time)                        
        print("Fold %d, %d epochs, %d sec"%(fold,EPOCHS,elapsed_time))
        pd.DataFrame(history.history).plot(figsize=(8,5))
        plt.grid(True)
        plt.gca().set_ylim(0,1)
        plt.show()
        best_model=keras.models.load_model(bestname)
        scores = best_model.evaluate(X_valid, y_valid, verbose=0)
        print("%s: %.2f%%" % (best_model.metrics_names[1], scores[1]*100))
        cv_scores.append(scores[1] * 100)  
    print()
    print("%d-way Cross Validation mean %.2f%% (+/- %.2f%%)" % (fold, np.mean(cv_scores), np.std(cv_scores)))

# %% [markdown]
# ## Train on RNA lengths 200-1Kb

# %%
print ("Compile the model")
model=build_model()
print ("Summarize the model")
print(model.summary())  # Print this only once
#model.save(MODEL_FILE+'.model')
# Out:
# Compile the model
# COMPILE...
# ...COMPILED
# Summarize the model
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_6 (Conv1D)            (None, 2000, 32)          512
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 2000, 32)          3104
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 1000, 32)          0
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 1000, 32)          3104
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 1000, 32)          3104
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 500, 32)           0
# _________________________________________________________________
# conv1d_10 (Conv1D)           (None, 500, 32)           3104
# _________________________________________________________________
# conv1d_11 (Conv1D)           (None, 500, 32)           3104
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 250, 32)           0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8000)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 24)                192024
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 24)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 24)                600
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 24)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 25
# =================================================================
# Total params: 208,681
# Trainable params: 208,681
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#MINLEN=200
#MAXLEN=2000
print("Load data from files.")
nc_seq=tools.load_fasta(NC_FILENAME,0)
pc_seq=tools.load_fasta(PC_FILENAME,1)
train_set=pd.concat((nc_seq,pc_seq),axis=0)
nc_seq=None
pc_seq=None
print("Ready: train_set")
#train_set
subset=tools.make_slice(train_set,MINLEN,MAXLEN)# One array to two: X and y
(X1,y_train)=tools.separate_X_and_y(subset)
# X1 is pandas df of ("list" of one sequence)
X2=X1.to_numpy()  # numpy ndarray of ("list" of one sequence)
X3=[elem[0] for elem in X2]  # numpy dnarray of str
X4=tools.uniform_length(X3,MAXLEN)
X5= [tools.one_hot(x) for x in X4]
X_train=np.asarray(X5)
y_train=y_train.to_numpy()

subset=None
X1=None
X2=None
X3=None
X4=None
X5=None
# Out:
# Load data from files.
# Ready: train_set

# %%
print ("Cross validation")
do_cross_validation(X_train,y_train,model)  
print ("Done")
# Out:
# Cross validation
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/50
# 1000/1000 [==============================] - 7s 6ms/step - loss: 0.6606 - accuracy: 0.6295 - val_loss: 0.5847 - val_accuracy: 0.7067
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN520.cv.1.best/assets
# Epoch 2/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6085 - accuracy: 0.6790 - val_loss: 0.6079 - val_accuracy: 0.6732
# Epoch 3/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5906 - accuracy: 0.6965 - val_loss: 0.5649 - val_accuracy: 0.7166
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN520.cv.1.best/assets
# Epoch 4/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5842 - accuracy: 0.7008 - val_loss: 0.5726 - val_accuracy: 0.7039
# Epoch 5/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5805 - accuracy: 0.7098 - val_loss: 0.5552 - val_accuracy: 0.7174
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN520.cv.1.best/assets
# Epoch 6/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5700 - accuracy: 0.7181 - val_loss: 0.5527 - val_accuracy: 0.7233
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN520.cv.1.best/assets
# Epoch 7/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5700 - accuracy: 0.7157 - val_loss: 0.5615 - val_accuracy: 0.7143
# Epoch 8/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5584 - accuracy: 0.7181 - val_loss: 0.5418 - val_accuracy: 0.7374
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN520.cv.1.best/assets
# Epoch 9/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5595 - accuracy: 0.7174 - val_loss: 0.5404 - val_accuracy: 0.7326
# Epoch 10/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5603 - accuracy: 0.7183 - val_loss: 0.5483 - val_accuracy: 0.7222
# Epoch 11/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5596 - accuracy: 0.7238 - val_loss: 0.5870 - val_accuracy: 0.7031
# Epoch 12/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5870 - accuracy: 0.6950 - val_loss: 0.5546 - val_accuracy: 0.7214
# Epoch 13/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5530 - accuracy: 0.7330 - val_loss: 0.5270 - val_accuracy: 0.7540
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN520.cv.1.best/assets
# Epoch 14/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5532 - accuracy: 0.7252 - val_loss: 0.5424 - val_accuracy: 0.7312
# Epoch 15/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5659 - accuracy: 0.7168 - val_loss: 0.6076 - val_accuracy: 0.6741
# Epoch 16/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5837 - accuracy: 0.7049 - val_loss: 0.5768 - val_accuracy: 0.7095
# Epoch 17/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5698 - accuracy: 0.7168 - val_loss: 0.5483 - val_accuracy: 0.7149
# Epoch 18/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5590 - accuracy: 0.7177 - val_loss: 0.5230 - val_accuracy: 0.7442
# Epoch 19/50
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.5405 - accuracy: 0.7363 - val_loss: 0.5249 - val_accuracy: 0.7458
# Epoch 20/50
# 1000/1000 [==============================] - 5s 5ms/step - loss: 0.5402 - accuracy: 0.7343 - val_loss: 0.5504 - val_accuracy: 0.7413
# Epoch 21/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.
50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.4581 - accuracy: 0.7889 - val_loss: 0.4211 - val_accuracy: 0.8156
# Epoch 45/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.4353 - accuracy: 0.8049 - val_loss: 0.4207 - val_accuracy: 0.8126
# Epoch 46/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.4273 - accuracy: 0.8095 - val_loss: 0.4061 - val_accuracy: 0.8227
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN520.cv.4.best/assets
# Epoch 47/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.4207 - accuracy: 0.8111 - val_loss: 0.4418 - val_accuracy: 0.7937
# Epoch 48/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.4284 - accuracy: 0.8157 - val_loss: 0.4584 - val_accuracy: 0.8027
# Epoch 49/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.4087 - accuracy: 0.8238 - val_loss: 0.4213 - val_accuracy: 0.8156
# Epoch 50/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.4229 - accuracy: 0.8158 - val_loss: 0.4100 - val_accuracy: 0.8134
# Fold 4, 50 epochs, 311 sec
# accuracy: 82.27%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/50
# 1000/1000 [==============================] - 7s 6ms/step - loss: 0.6369 - accuracy: 0.6455 - val_loss: 0.6550 - val_accuracy: 0.6231
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN520.cv.5.best/assets
# Epoch 2/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6062 - accuracy: 0.6824 - val_loss: 0.5940 - val_accuracy: 0.6825
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN520.cv.5.best/assets
# Epoch 3/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5952 - accuracy: 0.6941 - val_loss: 0.5889 - val_accuracy: 0.7079
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN520.cv.5.best/assets
# Epoch 4/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5944 - accuracy: 0.6905 - val_loss: 0.5637 - val_accuracy: 0.7225
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN520.cv.5.best/assets
# Epoch 5/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5808 - accuracy: 0.7017 - val_loss: 0.6498 - val_accuracy: 0.6316
# Epoch 6/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5727 - accuracy: 0.7136 - val_loss: 0.5568 - val_accuracy: 0.7081
# Epoch 7/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5638 - accuracy: 0.7185 - val_loss: 0.5394 - val_accuracy: 0.7166
# Epoch 8/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5621 - accuracy: 0.7140 - val_loss: 0.5143 - val_accuracy: 0.7526
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN520.cv.5.best/assets
# Epoch 9/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5496 - accuracy: 0.7269 - val_loss: 0.5282 - val_accuracy: 0.7416
# Epoch 10/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5456 - accuracy: 0.7340 - val_loss: 0.5172 - val_accuracy: 0.7385
# Epoch 11/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5397 - accuracy: 0.7393 - val_loss: 0.5249 - val_accuracy: 0.7475
# Epoch 12/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5283 - accuracy: 0.7425 - val_loss: 0.5200 - val_accuracy: 0.7534
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN520.cv.5.best/assets
# Epoch 13/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5390 - accuracy: 0.7349 - val_loss: 0.5070 - val_accuracy: 0.7577
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN520.cv.5.best/assets
# Epoch 14/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5340 - accuracy: 0.7405 - val_loss: 0.5588 - val_accuracy: 0.7264
# Epoch 15/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5345 - accuracy: 0.7409 - val_loss: 0.5034 - val_accuracy: 0.7684
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN520.cv.5.best/assets
# Epoch 16/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5280 - accuracy: 0.7448 - val_loss: 0.4966 - val_accuracy: 0.7684
# Epoch 17/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5212 - accuracy: 0.7475 - val_loss: 0.4880 - val_accuracy: 0.7602
# Epoch 18/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5188 - accuracy: 0.7496 - val_loss: 0.4754 - val_accuracy: 0.7898
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN520.cv.5.best/assets
# Epoch 19/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5140 - accuracy: 0.7583 - val_loss: 0.5348 - val_accuracy: 0.7228
# Epoch 20/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5146 - accuracy: 0.7511 - val_loss: 0.5496 - val_accuracy: 0.7323
# Epoch 21/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5789 - accuracy: 0.7066 - val_loss: 0.5552 - val_accuracy: 0.7267
# Epoch 22/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5721 - accuracy: 0.7150 - val_loss: 0.5256 - val_accuracy: 0.7509
# Epoch 23/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5778 - accuracy: 0.7036 - val_loss: 0.5380 - val_accuracy: 0.7416
# Epoch 24/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5583 - accuracy: 0.7250 - val_loss: 0.5555 - val_accuracy: 0.7267
# Epoch 25/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5549 - accuracy: 0.7280 - val_loss: 0.5215 - val_accuracy: 0.7335
# Epoch 26/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5431 - accuracy: 0.7331 - val_loss: 0.5338 - val_accuracy: 0.7171
# Epoch 27/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5368 - accuracy: 0.7418 - val_loss: 0.5202 - val_accuracy: 0.7436
# Epoch 28/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5339 - accuracy: 0.7396 - val_loss: 0.4968 - val_accuracy: 0.7661
# Epoch 29/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5282 - accuracy: 0.7429 - val_loss: 0.5106 - val_accuracy: 0.7534
# Epoch 30/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5113 - accuracy: 0.7609 - val_loss: 0.4858 - val_accuracy: 0.7760
# Epoch 31/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5214 - accuracy: 0.7513 - val_loss: 0.5028 - val_accuracy: 0.7675
# Epoch 32/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5104 - accuracy: 0.7571 - val_loss: 0.4767 - val_accuracy: 0.7858
# Epoch 33/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.4933 - accuracy: 0.7729 - val_loss: 0.4868 - val_accuracy: 0.7678
# Epoch 34/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.4995 - accuracy: 0.7711 - val_loss: 0.4853 - val_accuracy: 0.7698
# Epoch 35/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.4970 - accuracy: 0.7602 - val_loss: 0.4641 - val_accuracy: 0.7822
# Epoch 36/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.4984 - accuracy: 0.7636 - val_loss: 0.5453 - val_accuracy: 0.7408
# Epoch 37/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5161 - accuracy: 0.7545 - val_loss: 0.5799 - val_accuracy: 0.6870
# Epoch 38/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5068 - accuracy: 0.7627 - val_loss: 0.4775 - val_accuracy: 0.7698
# Epoch 39/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.4811 - accuracy: 0.7794 - val_loss: 0.4581 - val_accuracy: 0.8005
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN520.cv.5.best/assets
# Epoch 40/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.4857 - accuracy: 0.7745 - val_loss: 0.5861 - val_accuracy: 0.7180
# Epoch 41/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.4977 - accuracy: 0.7687 - val_loss: 0.5414 - val_accuracy: 0.7360
# Epoch 42/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.4823 - accuracy: 0.7793 - val_loss: 0.4553 - val_accuracy: 0.7926
# Epoch 43/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.4755 - accuracy: 0.7796 - val_loss: 0.5090 - val_accuracy: 0.7754
# Epoch 44/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.4805 - accuracy: 0.7786 - val_loss: 0.4576 - val_accuracy: 0.7889
# Epoch 45/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.4767 - accuracy: 0.7752 - val_loss: 0.4544 - val_accuracy: 0.7875
# Epoch 46/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.4767 - accuracy: 0.7809 - val_loss: 0.4441 - val_accuracy: 0.8013
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN520.cv.5.best/assets
# Epoch 47/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.4610 - accuracy: 0.7956 - val_loss: 0.4288 - val_accuracy: 0.8123
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN520.cv.5.best/assets
# Epoch 48/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.4659 - accuracy: 0.7854 - val_loss: 0.4217 - val_accuracy: 0.8086
# Epoch 49/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.4486 - accuracy: 0.7948 - val_loss: 0.4091 - val_accuracy: 0.8221
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN520.cv.5.best/assets
# Epoch 50/50
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.4293 - accuracy: 0.8115 - val_loss: 0.5031 - val_accuracy: 0.7416
# Fold 5, 50 epochs, 314 sec
# accuracy: 82.21%
#
# 5-way Cross Validation mean 82.54% (+/- 1.43%)
# Done
