# %% [markdown]
# # CNN 307
# Start with CNN 306 which overfits most of the time. Reduce #params.

# %%
NC_FILENAME='ncRNA.gc36.median.fasta'
PC_FILENAME='pcRNA.gc36.median.fasta'
#NC_FILENAME='ncRNA.tiny50.fasta'
#PC_FILENAME='pcRNA.tiny50.fasta'
#NC_FILENAME='ncRNA.gc34.processed.fasta'
#PC_FILENAME='pcRNA.gc34.processed.fasta'

MODEL_FILE='CNN307'  
DATAPATH=''

try:
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
except:
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"
NC_FILENAME = DATAPATH+NC_FILENAME
PC_FILENAME = DATAPATH+PC_FILENAME
MODEL_FILE=DATAPATH+MODEL_FILE

EPOCHS=200
SPLITS=5
K=1
VOCABULARY_SIZE=4**K+1   # e.g. K=3 => 64 DNA K-mers + 'NNN'
EMBED_DIMEN=2
FILTERS=32
KERNEL=3
NEURONS=32
DROP=0.25
ACT="tanh"
MINLEN=201
MAXLEN=2000
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# Load our own tools
# TO DO: don't go to GitHub if the file is already local.
GITHUB = True
if GITHUB:
    #!pip install requests  # Uncomment this if necessary. Seems to be pre-installed.
    import requests
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/ShepherdML/master/Strings/tools_fasta.py')
    with open('tools_fasta.py', 'w') as f:
        f.write(r.text)
    # TO DO: delete the file after import
import tools_fasta as tools
tools.yahoo()  # If this prints "Yahoo!" the the import was successful.

TOOLS_CHANGED = False   # set to True to re-run with a new version of tools
if TOOLS_CHANGED:
  from importlib import reload 
  tools=reload(tools)
  print(dir(tools))   # run this to see EVERYTHING in the tools module
# Out:
# Yahoo!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import StratifiedKFold
import tensorflow as tf
from tensorflow import keras
import time
dt='float32'
tf.keras.backend.set_floatx(dt)

# %% [markdown]
# Build model

# %%
def compile_model(model):
    ## learn rate = initial_learning_rate * decay_rate ^ (step / decay_steps)
    #adam_default_learn_rate = 0.001
    #schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    #    initial_learning_rate = adam_default_learn_rate*10,
    #    decay_steps=10000, decay_rate=0.99, staircase=True)
    #alrd = tf.keras.optimizers.Adam(learning_rate=schedule)
    #model.compile(loss=bc, optimizer=alrd, metrics=["accuracy"])

    print("COMPILE...")
    bc=tf.keras.losses.BinaryCrossentropy(from_logits=False)
    model.compile(loss=bc, optimizer="adam", metrics=["accuracy"])
    print("...COMPILED")
    return model

def build_model():
    SHAPE=(MAXLEN,5)  # MAXLEN bases = time steps, 5 features = one hots
    clayer1 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same",
                                 input_shape=SHAPE)
    clayer2 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer3 = keras.layers.MaxPooling1D(2)
    clayer4 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer5 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer6 = keras.layers.MaxPooling1D(2)
    clayer7 = keras.layers.Flatten()

    dlayer1 = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt, input_shape=[1000])
    dlayer2 = keras.layers.Dropout(DROP)
    dlayer3 = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt)
    dlayer4 = keras.layers.Dropout(DROP)
    output_layer = keras.layers.Dense(1, activation="sigmoid", dtype=dt)

    cnn = keras.models.Sequential()
    cnn.add(clayer1)
    cnn.add(clayer2)
    cnn.add(clayer3)
    cnn.add(clayer4)
    cnn.add(clayer5)
    cnn.add(clayer6)
    cnn.add(clayer7)
    cnn.add(dlayer1)
    cnn.add(dlayer2)
    cnn.add(dlayer3)
    cnn.add(dlayer4)
    cnn.add(output_layer)
    mlpc = compile_model(cnn)
    return mlpc

# %% [markdown]
# Cross validation

# %%
def do_cross_validation(X,y,given_model):
    cv_scores = []
    fold=0
    splitter = ShuffleSplit(n_splits=SPLITS, test_size=0.1, random_state=37863)
    for train_index,valid_index in splitter.split(X):
        fold += 1
        X_train=X[train_index] # use iloc[] for dataframe
        y_train=y[train_index]
        X_valid=X[valid_index]
        y_valid=y[valid_index]        
        # Avoid continually improving the same model.
        model = compile_model(keras.models.clone_model(given_model))
        bestname=MODEL_FILE+".cv."+str(fold)+".best"
        es = keras.callbacks.EarlyStopping(monitor='loss',  
            patience=5, verbose=1)
        mc = keras.callbacks.ModelCheckpoint(
            filepath=bestname, save_best_only=True, 
            monitor='val_accuracy', mode='max')  
        mycallbacks = [es,mc]  
        print("FIT")
        start_time=time.time()
        history=model.fit(X_train, y_train, # batch_size=10, default=32 works nicely
                epochs=EPOCHS, verbose=1,  # verbose=1 for ascii art, verbose=0 for none
                callbacks=mycallbacks,
                validation_data=(X_valid,y_valid) )
        end_time=time.time()
        elapsed_time=(end_time-start_time)                        
        print("Fold %d, %d epochs, %d sec"%(fold,EPOCHS,elapsed_time))
        pd.DataFrame(history.history).plot(figsize=(8,5))
        plt.grid(True)
        plt.gca().set_ylim(0,1)
        plt.show()
        best_model=keras.models.load_model(bestname)
        scores = best_model.evaluate(X_valid, y_valid, verbose=0)
        print("%s: %.2f%%" % (best_model.metrics_names[1], scores[1]*100))
        cv_scores.append(scores[1] * 100)  
    print()
    print("%d-way Cross Validation mean %.2f%% (+/- %.2f%%)" % (fold, np.mean(cv_scores), np.std(cv_scores)))

# %% [markdown]
# ## Train on RNA lengths 200-1Kb

# %%
print ("Compile the model")
model=build_model()
print ("Summarize the model")
print(model.summary())  # Print this only once
#model.save(MODEL_FILE+'.model')
# Out:
# Compile the model
# COMPILE...
# ...COMPILED
# Summarize the model
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_28 (Conv1D)           (None, 2000, 32)          512
# _________________________________________________________________
# conv1d_29 (Conv1D)           (None, 2000, 32)          3104
# _________________________________________________________________
# max_pooling1d_14 (MaxPooling (None, 1000, 32)          0
# _________________________________________________________________
# conv1d_30 (Conv1D)           (None, 1000, 32)          3104
# _________________________________________________________________
# conv1d_31 (Conv1D)           (None, 1000, 32)          3104
# _________________________________________________________________
# max_pooling1d_15 (MaxPooling (None, 500, 32)           0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 16000)             0
# _________________________________________________________________
# dense_21 (Dense)             (None, 32)                512032
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_22 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 522,945
# Trainable params: 522,945
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
print("Load data from files.")
nc_seq=tools.load_fasta(NC_FILENAME,0)
pc_seq=tools.load_fasta(PC_FILENAME,1)
train_set=pd.concat((nc_seq,pc_seq),axis=0)
nc_seq=None
pc_seq=None
print("Ready: train_set")
#train_set
subset=tools.make_slice(train_set,MINLEN,MAXLEN)# One array to two: X and y
(X1,y_train)=tools.separate_X_and_y(subset)
# X1 is pandas df of ("list" of one sequence)
X2=X1.to_numpy()  # numpy ndarray of ("list" of one sequence)
X3=[elem[0] for elem in X2]  # numpy dnarray of str
X4=tools.uniform_length(X3,MAXLEN)
X5= [tools.one_hot(x) for x in X4]
X_train=np.asarray(X5)
y_train=y_train.to_numpy()

subset=None
X1=None
X2=None
X3=None
X4=None
X5=None
# Out:
# Load data from files.
# Ready: train_set

# %%
print ("Cross valiation")
do_cross_validation(X_train,y_train,model)  
print ("Done")
# Out:
# Cross valiation
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/200
# 315/315 [==============================] - 3s 7ms/step - loss: 0.6668 - accuracy: 0.6298 - val_loss: 0.6407 - val_accuracy: 0.6377
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN307.cv.1.best/assets
# Epoch 2/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.6426 - accuracy: 0.6385 - val_loss: 0.6018 - val_accuracy: 0.6825
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN307.cv.1.best/assets
# Epoch 3/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.6123 - accuracy: 0.6730 - val_loss: 0.6055 - val_accuracy: 0.6771
# Epoch 4/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.6001 - accuracy: 0.6866 - val_loss: 0.6159 - val_accuracy: 0.6726
# Epoch 5/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.6214 - accuracy: 0.6687 - val_loss: 0.5848 - val_accuracy: 0.6914
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN307.cv.1.best/assets
# Epoch 6/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.5932 - accuracy: 0.6867 - val_loss: 0.5945 - val_accuracy: 0.7004
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN307.cv.1.best/assets
# Epoch 7/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.5989 - accuracy: 0.6766 - val_loss: 0.6034 - val_accuracy: 0.6807
# Epoch 8/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.6069 - accuracy: 0.6730 - val_loss: 0.5869 - val_accuracy: 0.6887
# Epoch 9/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.5876 - accuracy: 0.6889 - val_loss: 0.5971 - val_accuracy: 0.6825
# Epoch 10/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.6019 - accuracy: 0.6734 - val_loss: 0.6055 - val_accuracy: 0.6771
# Epoch 11/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.6015 - accuracy: 0.6848 - val_loss: 0.5893 - val_accuracy: 0.6762
# Epoch 12/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.5828 - accuracy: 0.6947 - val_loss: 0.5811 - val_accuracy: 0.6834
# Epoch 13/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.5741 - accuracy: 0.7044 - val_loss: 0.5965 - val_accuracy: 0.6771
# Epoch 14/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.5856 - accuracy: 0.6945 - val_loss: 0.5986 - val_accuracy: 0.7021
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN307.cv.1.best/assets
# Epoch 15/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.5841 - accuracy: 0.6905 - val_loss: 0.5802 - val_accuracy: 0.7039
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN307.cv.1.best/assets
# Epoch 16/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.5895 - accuracy: 0.6914 - val_loss: 0.5858 - val_accuracy: 0.7004
# Epoch 17/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.5845 - accuracy: 0.6921 - val_loss: 0.5629 - val_accuracy: 0.7120
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN307.cv.1.best/assets
# Epoch 18/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.
200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.0570 - accuracy: 0.9799 - val_loss: 0.8829 - val_accuracy: 0.7809
# Epoch 46/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.0584 - accuracy: 0.9805 - val_loss: 1.0029 - val_accuracy: 0.7835
# Epoch 47/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.0500 - accuracy: 0.9840 - val_loss: 0.9120 - val_accuracy: 0.7889
# Epoch 48/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.0712 - accuracy: 0.9734 - val_loss: 0.9198 - val_accuracy: 0.7809
# Epoch 49/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.0507 - accuracy: 0.9797 - val_loss: 1.2127 - val_accuracy: 0.7397
# Epoch 50/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.0825 - accuracy: 0.9718 - val_loss: 0.9498 - val_accuracy: 0.7800
# Epoch 51/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.0581 - accuracy: 0.9791 - val_loss: 0.9266 - val_accuracy: 0.7871
# Epoch 52/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.0639 - accuracy: 0.9768 - val_loss: 1.0126 - val_accuracy: 0.7674
# Epoch 53/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.0652 - accuracy: 0.9774 - val_loss: 0.8793 - val_accuracy: 0.7719
# Epoch 54/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.0606 - accuracy: 0.9798 - val_loss: 0.9099 - val_accuracy: 0.7764
# Epoch 00054: early stopping
# Fold 3, 200 epochs, 111 sec
# accuracy: 80.50%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/200
# 315/315 [==============================] - 3s 6ms/step - loss: 0.7228 - accuracy: 0.6116 - val_loss: 0.5878 - val_accuracy: 0.6860
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN307.cv.4.best/assets
# Epoch 2/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.6110 - accuracy: 0.6791 - val_loss: 0.5840 - val_accuracy: 0.6986
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN307.cv.4.best/assets
# Epoch 3/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.6242 - accuracy: 0.6642 - val_loss: 0.5933 - val_accuracy: 0.6887
# Epoch 4/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.6143 - accuracy: 0.6766 - val_loss: 0.5949 - val_accuracy: 0.6753
# Epoch 5/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.5954 - accuracy: 0.6874 - val_loss: 0.5945 - val_accuracy: 0.6825
# Epoch 6/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.5853 - accuracy: 0.6858 - val_loss: 0.5812 - val_accuracy: 0.6995
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN307.cv.4.best/assets
# Epoch 7/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.5860 - accuracy: 0.6981 - val_loss: 0.6065 - val_accuracy: 0.6574
# Epoch 8/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.5841 - accuracy: 0.6895 - val_loss: 0.6035 - val_accuracy: 0.6825
# Epoch 9/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.5850 - accuracy: 0.6926 - val_loss: 0.5599 - val_accuracy: 0.7129
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN307.cv.4.best/assets
# Epoch 10/200
# 315/315 [==============================] - 2s 7ms/step - loss: 0.5659 - accuracy: 0.7065 - val_loss: 0.5744 - val_accuracy: 0.6959
# Epoch 11/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.5646 - accuracy: 0.7052 - val_loss: 0.5691 - val_accuracy: 0.7057
# Epoch 12/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.5656 - accuracy: 0.7079 - val_loss: 0.5938 - val_accuracy: 0.6780
# Epoch 13/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.5570 - accuracy: 0.7182 - val_loss: 0.5673 - val_accuracy: 0.7093
# Epoch 14/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.5439 - accuracy: 0.7251 - val_loss: 0.5304 - val_accuracy: 0.7343
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN307.cv.4.best/assets
# Epoch 15/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.5096 - accuracy: 0.7485 - val_loss: 0.5229 - val_accuracy: 0.7343
# Epoch 16/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.4829 - accuracy: 0.7741 - val_loss: 0.4530 - val_accuracy: 0.7961
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN307.cv.4.best/assets
# Epoch 17/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.4634 - accuracy: 0.7793 - val_loss: 0.4485 - val_accuracy: 0.8023
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN307.cv.4.best/assets
# Epoch 18/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.4378 - accuracy: 0.8000 - val_loss: 0.5025 - val_accuracy: 0.7370
# Epoch 19/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.4234 - accuracy: 0.8091 - val_loss: 0.4094 - val_accuracy: 0.8256
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN307.cv.4.best/assets
# Epoch 20/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.4098 - accuracy: 0.8131 - val_loss: 0.4176 - val_accuracy: 0.8131
# Epoch 21/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.3634 - accuracy: 0.8434 - val_loss: 0.4575 - val_accuracy: 0.7826
# Epoch 22/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.3571 - accuracy: 0.8453 - val_loss: 0.4835 - val_accuracy: 0.7916
# Epoch 23/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.3554 - accuracy: 0.8454 - val_loss: 0.3949 - val_accuracy: 0.8229
# Epoch 24/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.3262 - accuracy: 0.8624 - val_loss: 0.4116 - val_accuracy: 0.8148
# Epoch 25/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.3228 - accuracy: 0.8648 - val_loss: 0.4002 - val_accuracy: 0.8318
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN307.cv.4.best/assets
# Epoch 26/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.2891 - accuracy: 0.8806 - val_loss: 0.4293 - val_accuracy: 0.8166
# Epoch 27/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.2894 - accuracy: 0.8772 - val_loss: 0.4661 - val_accuracy: 0.8077
# Epoch 28/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.2326 - accuracy: 0.9071 - val_loss: 0.4301 - val_accuracy: 0.8292
# Epoch 29/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.2210 - accuracy: 0.9105 - val_loss: 0.4650 - val_accuracy: 0.8229
# Epoch 30/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.2375 - accuracy: 0.9044 - val_loss: 0.5547 - val_accuracy: 0.8005
# Epoch 31/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.1938 - accuracy: 0.9273 - val_loss: 0.4639 - val_accuracy: 0.8247
# Epoch 32/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.1945 - accuracy: 0.9216 - val_loss: 0.5522 - val_accuracy: 0.8157
# Epoch 33/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.1744 - accuracy: 0.9298 - val_loss: 0.4835 - val_accuracy: 0.8283
# Epoch 34/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.1593 - accuracy: 0.9378 - val_loss: 0.4991 - val_accuracy: 0.8327
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN307.cv.4.best/assets
# Epoch 35/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.1546 - accuracy: 0.9440 - val_loss: 0.5043 - val_accuracy: 0.8283
# Epoch 36/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.1259 - accuracy: 0.9526 - val_loss: 0.5434 - val_accuracy: 0.8157
# Epoch 37/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.1256 - accuracy: 0.9555 - val_loss: 0.5658 - val_accuracy: 0.8175
# Epoch 38/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.1414 - accuracy: 0.9477 - val_loss: 0.5629 - val_accuracy: 0.8157
# Epoch 39/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.1038 - accuracy: 0.9634 - val_loss: 0.7593 - val_accuracy: 0.7764
# Epoch 40/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.1252 - accuracy: 0.9547 - val_loss: 0.6461 - val_accuracy: 0.8086
# Epoch 41/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.1189 - accuracy: 0.9561 - val_loss: 0.6110 - val_accuracy: 0.8247
# Epoch 42/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.0966 - accuracy: 0.9671 - val_loss: 0.6851 - val_accuracy: 0.8059
# Epoch 43/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.0995 - accuracy: 0.9685 - val_loss: 0.6161 - val_accuracy: 0.8059
# Epoch 44/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.0935 - accuracy: 0.9680 - val_loss: 0.6803 - val_accuracy: 0.7987
# Epoch 45/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.0977 - accuracy: 0.9662 - val_loss: 0.6821 - val_accuracy: 0.8104
# Epoch 46/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.0941 - accuracy: 0.9663 - val_loss: 0.6169 - val_accuracy: 0.8184
# Epoch 47/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.0951 - accuracy: 0.9650 - val_loss: 0.7541 - val_accuracy: 0.7961
# Epoch 48/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.1136 - accuracy: 0.9603 - val_loss: 0.7316 - val_accuracy: 0.8032
# Epoch 49/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.0752 - accuracy: 0.9759 - val_loss: 0.6832 - val_accuracy: 0.8095
# Epoch 50/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.0825 - accuracy: 0.9707 - val_loss: 0.7061 - val_accuracy: 0.7925
# Epoch 51/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.0812 - accuracy: 0.9724 - val_loss: 0.6527 - val_accuracy: 0.8086
# Epoch 52/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.0754 - accuracy: 0.9729 - val_loss: 0.7800 - val_accuracy: 0.7916
# Epoch 53/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.0814 - accuracy: 0.9705 - val_loss: 0.6832 - val_accuracy: 0.8122
# Epoch 54/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.0979 - accuracy: 0.9635 - val_loss: 0.7522 - val_accuracy: 0.8032
# Epoch 00054: early stopping
# Fold 4, 200 epochs, 114 sec
# accuracy: 83.27%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/200
# 315/315 [==============================] - 3s 6ms/step - loss: 0.6935 - accuracy: 0.5968 - val_loss: 0.6272 - val_accuracy: 0.6995
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN307.cv.5.best/assets
# Epoch 2/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.6416 - accuracy: 0.6432 - val_loss: 0.6307 - val_accuracy: 0.6494
# Epoch 3/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.6258 - accuracy: 0.6631 - val_loss: 0.5876 - val_accuracy: 0.6977
# Epoch 4/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.6335 - accuracy: 0.6528 - val_loss: 0.5922 - val_accuracy: 0.7004
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN307.cv.5.best/assets
# Epoch 5/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.6153 - accuracy: 0.6690 - val_loss: 0.6360 - val_accuracy: 0.6199
# Epoch 6/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.6100 - accuracy: 0.6759 - val_loss: 0.6133 - val_accuracy: 0.7030
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN307.cv.5.best/assets
# Epoch 7/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.6088 - accuracy: 0.6780 - val_loss: 0.5822 - val_accuracy: 0.7021
# Epoch 8/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.5946 - accuracy: 0.6924 - val_loss: 0.5863 - val_accuracy: 0.6995
# Epoch 9/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.6051 - accuracy: 0.6807 - val_loss: 0.5925 - val_accuracy: 0.6914
# Epoch 10/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.6026 - accuracy: 0.6818 - val_loss: 0.6199 - val_accuracy: 0.6530
# Epoch 11/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.6130 - accuracy: 0.6652 - val_loss: 0.5909 - val_accuracy: 0.6860
# Epoch 12/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.6125 - accuracy: 0.6641 - val_loss: 0.5805 - val_accuracy: 0.7102
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN307.cv.5.best/assets
# Epoch 13/200
# 315/315 [==============================] - 2s 6ms/step - loss: 0.6041 - accuracy: 0.6840 - val_loss: 0.6427 - val_accuracy: 0.6565
# Epoch 00013: early stopping
# Fold 5, 200 epochs, 29 sec
# accuracy: 71.02%
#
# 5-way Cross Validation mean 75.90% (+/- 5.06%)
# Done
