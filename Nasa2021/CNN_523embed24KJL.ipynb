# %% [markdown]
# <a href="https://colab.research.google.com/github/ShepherdCode/ShepherdML/blob/master/Nasa2021/CNN_523.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CNN 523
#
# 1. Four layers of CNNS and MaxPooling
# 2. Drop out at 0.2
# 3. Variable filters and dense neurons

# %%
#NC_FILENAME='ncRNA.tiny50.fasta'
#PC_FILENAME='pcRNA.tiny50.fasta'
#NC_FILENAME='ncRNA.gc34.processed.fasta'
#PC_FILENAME='pcRNA.gc34.processed.fasta'
NC_FILENAME='noncod_24000.fasta'  # CHANGE THIS TO 1000, 2000, 4000, etc.
PC_FILENAME='coding_24000.fasta'
NC_VAL_FILE='noncod_validation.fasta'  # 'noncod_validation.fasta'  # CHANGE THIS TO THE UNIFORM VALIDATION FILE
PC_VAL_FILE='coding_validation.fasta'  # 'coding_validation.fasta'

MODEL_FILE='Test_Non_noisy_24K'   # CHANGE THIS IF YOU WANT TO SAVE THE MODEL!
DATAPATH=''

try:
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
except:
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"
NC_FILENAME = DATAPATH+NC_FILENAME
PC_FILENAME = DATAPATH+PC_FILENAME
NC_VAL_FILE = DATAPATH+NC_VAL_FILE
PC_VAL_FILE = DATAPATH+PC_VAL_FILE
MODEL_FILE=DATAPATH+MODEL_FILE

EPOCHS=20  # DECIDE ON SOME AMOUNT AND STICK WITH IT
SPLITS=5
K=1
VOCABULARY_SIZE=4**K+1   # e.g. K=3 => 64 DNA K-mers + 'NNN'
EMBED_DIMEN=2
FILTERS=32
KERNEL=3
NEURONS=24
DROP=0.2
MINLEN=200
MAXLEN=1000    # THIS HAS TO MATCH THE SIMULATION DATA
DENSE_LEN = 1000
ACT="tanh"
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# Load our own tools
# TO DO: don't go to GitHub if the file is already local.
GITHUB = True
if GITHUB:
    #!pip install requests  # Uncomment this if necessary. Seems to be pre-installed.
    import requests
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/ShepherdML/master/Strings/tools_fasta.py')
    with open('tools_fasta.py', 'w') as f:
        f.write(r.text)
    # TO DO: delete the file after import
import tools_fasta as tools
tools.yahoo()  # If this prints "Yahoo!" the the import was successful.

TOOLS_CHANGED = False   # set to True to re-run with a new version of tools
if TOOLS_CHANGED:
  from importlib import reload 
  tools=reload(tools)
  print(dir(tools))   # run this to see EVERYTHING in the tools module
# Out:
# Yahoo!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import StratifiedKFold
import tensorflow as tf
from tensorflow import keras
import time
dt='float32'
tf.keras.backend.set_floatx(dt)

# %% [markdown]
# Build model

# %%
def compile_model(model):
    print("COMPILE...")
    ## learn rate = initial_learning_rate * decay_rate ^ (step / decay_steps)
    #adam_default_learn_rate = 0.001
    #schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    #    initial_learning_rate = adam_default_learn_rate*10,
    #    decay_steps=10000, decay_rate=0.99, staircase=True)
    #alrd = tf.keras.optimizers.Adam(learning_rate=schedule)
    
    ln_rate = tf.keras.optimizers.Adam(learning_rate = 0.0005)
    bc=tf.keras.losses.BinaryCrossentropy(from_logits=False)
    model.compile(loss=bc, optimizer=ln_rate, metrics=["accuracy"])
    print("...COMPILED")
    return model

def build_model():
    #SHAPE=(MAXLEN,5)  
    SHAPE=(MAXLEN,4)  
    # 4 input letters, 4 output dimensions, 1000 letters/RNA
    elayer  = keras.layers.Embedding(4,4,input_length=1000) 

    clayer1 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same",
                                 input_shape=SHAPE)
    clayer2 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer3 = keras.layers.MaxPooling1D(2)
    clayer4 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer5 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer6 = keras.layers.MaxPooling1D(2)
    clayer7 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer8 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer9 = keras.layers.MaxPooling1D(2)
    clayer10 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer11 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer12 = keras.layers.MaxPooling1D(2)

    clayer13 = keras.layers.Flatten()

    dlayer1 = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt, input_shape=[DENSE_LEN])
    dlayer2 = keras.layers.Dropout(DROP)
    dlayer3 = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt)
    dlayer4 = keras.layers.Dropout(DROP)
    output_layer = keras.layers.Dense(1, activation="sigmoid", dtype=dt)

    cnn = keras.models.Sequential()
    cnn.add(elayer)
    cnn.add(clayer1)
    cnn.add(clayer2)
    cnn.add(clayer3)
    cnn.add(clayer4)
    cnn.add(clayer5)
    cnn.add(clayer6)
    cnn.add(clayer7)
    cnn.add(clayer8)
    cnn.add(clayer9)
    cnn.add(clayer10)
    cnn.add(clayer11)
    cnn.add(clayer12)
    cnn.add(clayer13)
    cnn.add(dlayer1)
    cnn.add(dlayer2)
    cnn.add(dlayer3)
    cnn.add(dlayer4)
    cnn.add(output_layer)
    mlpc = compile_model(cnn)
    return mlpc

# %% [markdown]
# Cross validation

# %%
def do_cross_validation(X,y,given_model,X_VALID,Y_VALID):
    cv_scores = []
    fold=0
    splitter = ShuffleSplit(n_splits=SPLITS, test_size=0.1, random_state=37863)
    for train_index,valid_index in splitter.split(X):
        fold += 1
        X_train=X[train_index] # use iloc[] for dataframe
        y_train=y[train_index]
        X_valid=X[valid_index]
        y_valid=y[valid_index]        
        # Avoid continually improving the same model.
        model = compile_model(keras.models.clone_model(given_model))
        bestname=MODEL_FILE+".cv."+str(fold)+".best"
        mycallbacks = [keras.callbacks.ModelCheckpoint(
            filepath=bestname, save_best_only=True, 
            monitor='val_accuracy', mode='max')]   
        print("FIT")
        start_time=time.time()
        history=model.fit(X_train, y_train, 
                epochs=EPOCHS, verbose=1, callbacks=mycallbacks,
                validation_data=(X_valid,y_valid))
        # THE VALIDATION ABOVE IS JUST FOR SHOW
        end_time=time.time()
        elapsed_time=(end_time-start_time)                        
        print("Fold %d, %d epochs, %d sec"%(fold,EPOCHS,elapsed_time))
        pd.DataFrame(history.history).plot(figsize=(8,5))
        plt.grid(True)
        plt.gca().set_ylim(0,1)
        plt.show()
        best_model=keras.models.load_model(bestname)
        # THE VALIDATION BELOW IS FOR KEEPS
        scores = best_model.evaluate(X_VALID, Y_VALID, verbose=0)
        print("%s: %.2f%%" % (best_model.metrics_names[1], scores[1]*100))
        cv_scores.append(scores[1] * 100)  
    print()
    print("%d-way Cross Validation mean %.2f%% (+/- %.2f%%)" % (fold, np.mean(cv_scores), np.std(cv_scores)))

# %% [markdown]
# ## Train on RNA lengths 200-1Kb

# %%
print ("Compile the model")
model=build_model()
print ("Summarize the model")
print(model.summary())  # Print this only once
#model.save(MODEL_FILE+'.model')
# Out:
# Compile the model
# COMPILE...
# ...COMPILED
# Summarize the model
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 1000, 4)           16
# _________________________________________________________________
# conv1d (Conv1D)              (None, 1000, 32)          416
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 1000, 32)          3104
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 500, 32)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 500, 32)           3104
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 500, 32)           3104
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 250, 32)           0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 250, 32)           3104
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 250, 32)           3104
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 125, 32)           0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 125, 32)           3104
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 125, 32)           3104
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 62, 32)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 1984)              0
# _________________________________________________________________
# dense (Dense)                (None, 24)                47640
# _________________________________________________________________
# dropout (Dropout)            (None, 24)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 24)                600
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 24)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 25
# =================================================================
# Total params: 70,425
# Trainable params: 70,425
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
def load_data_from_files(nc_filename,pc_filename):
  FREEMEM=True   # use False for debugging, True for production
  print("Load data from files.")
  nc_seq=tools.load_fasta(nc_filename,0)
  pc_seq=tools.load_fasta(pc_filename,1)
  train_set=pd.concat((nc_seq,pc_seq),axis=0)
  print("Ready: train_set")
  subset=tools.make_slice(train_set,MINLEN,MAXLEN)# One array to two: X and y
  if FREEMEM:
      nc_seq=None
      pc_seq=None
      train_set=None
  (X1,y_train)=tools.separate_X_and_y(subset)
  # X1 is pandas df of ("list" of one sequence)
  X2=X1.to_numpy()  # numpy ndarray of ("list" of one sequence)
  X3=[elem[0] for elem in X2]  # numpy ndarray of ACGT-str
  # X3? It might be faster to use int-array than char-array. Come back to this.
  X4=X3  # no-op
  print("X4",type(X4))
  #print(X4[0])
  if FREEMEM:
      X1=None
      X2=None
      X3=None
  X5=[]
  dna_to_int = {'A':0,'C':1,'G':2,'T':3}
  for x in X4:
      a=[]
      for c in x:
          i = dna_to_int[c]
          a.append(i)
      X5.append(a)
  X5=np.asarray(X5)
  print("X5",type(X5))
  print(X5.shape)
  if FREEMEM:
      X4=None
  X_train=X5
  if FREEMEM:
      X5=None
  print("X_train",type(X_train))
  y_train=y_train.to_numpy()
  print(X_train.shape)
  print(X_train[0].shape)
  print(X_train[0])
  return X_train,y_train

# %%
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_24K.cv.2.best/assets
# Epoch 20/20
# 1350/1350 [==============================] - 8s 6ms/step - loss: 0.0309 - accuracy: 0.9898 - val_loss: 0.0479 - val_accuracy: 0.9887
# Fold 2, 20 epochs, 190 sec
# accuracy: 98.99%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/20
# 1350/1350 [==============================] - 9s 6ms/step - loss: 0.6526 - accuracy: 0.5929 - val_loss: 0.6336 - val_accuracy: 0.6558
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_24K.cv.3.best/assets
# Epoch 2/20
# 1350/1350 [==============================] - 8s 6ms/step - loss: 0.5383 - accuracy: 0.7324 - val_loss: 0.5031 - val_accuracy: 0.7492
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_24K.cv.3.best/assets
# Epoch 3/20
# 1350/1350 [==============================] - 8s 6ms/step - loss: 0.5126 - accuracy: 0.7519 - val_loss: 0.4890 - val_accuracy: 0.7556
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_24K.cv.3.best/assets
# Epoch 4/20
# 1350/1350 [==============================] - 8s 6ms/step - loss: 0.4700 - accuracy: 0.7802 - val_loss: 0.5141 - val_accuracy: 0.7479
# Epoch 5/20
# 1350/1350 [==============================] - 8s 6ms/step - loss: 0.4541 - accuracy: 0.7916 - val_loss: 0.4753 - val_accuracy: 0.7733
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_24K.cv.3.best/assets
# Epoch 6/20
# 1350/1350 [==============================] - 8s 6ms/step - loss: 0.4478 - accuracy: 0.7933 - val_loss: 0.4771 - val_accuracy: 0.7748
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_24K.cv.3.best/assets
# Epoch 7/20
# 1350/1350 [==============================] - 8s 6ms/step - loss: 0.4262 - accuracy: 0.8090 - val_loss: 0.4914 - val_accuracy: 0.7619
# Epoch 8/20
# 1350/1350 [==============================] - 8s 6ms/step - loss: 0.4139 - accuracy: 0.8155 - val_loss: 0.4885 - val_accuracy: 0.7702
# Epoch 9/20
# 1350/1350 [==============================] - 8s 6ms/step - loss: 0.4075 - accuracy: 0.8161 - val_loss: 0.5365 - val_accuracy: 0.7402
# Epoch 10/20
# 1350/1350 [==============================] - 8s 6ms/step - loss: 0.3921 - accuracy: 0.8276 - val_loss: 0.5096 - val_accuracy: 0.7665
# Epoch 11/20
# 1350/1350 [==============================] - 8s 6ms/step - loss: 0.3782 - accuracy: 0.8368 - val_loss: 0.4899 - val_accuracy: 0.7738
# Epoch 12/20
# 1350/1350 [==============================] - 8s 6ms/step - loss: 0.3625 - accuracy: 0.8431 - val_loss: 0.4919 - val_accuracy: 0.7850
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_24K.cv.3.best/assets
# Epoch 13/20
# 1350/1350 [==============================] - 8s 6ms/step - loss: 0.3483 - accuracy: 0.8500 - val_loss: 0.4990 - val_accuracy: 0.7742
# Epoch 14/20
# 1350/1350 [==============================] - 8s 6ms/step - loss: 0.3281 - accuracy: 0.8625 - val_loss: 0.5257 - val_accuracy: 0.7654
# Epoch 15/20
# 1350/1350 [==============================] - 8s 6ms/step - loss: 0.3162 - accuracy: 0.8670 - val_loss: 0.4860 - val_accuracy: 0.7902
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_24K.cv.3.best/assets
# Epoch 16/20
# 1350/1350 [==============================] - 9s 6ms/step - loss: 0.3024 - accuracy: 0.8724 - val_loss: 0.6111 - val_accuracy: 0.7538
# Epoch 17/20
# 1350/1350 [==============================] - 8s 6ms/step - loss: 0.2884 - accuracy: 0.8798 - val_loss: 0.4619 - val_accuracy: 0.8054
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_24K.cv.3.best/assets
# Epoch 18/20
# 1350/1350 [==============================] - 8s 6ms/step - loss: 0.2693 - accuracy: 0.8901 - val_loss: 0.4747 - val_accuracy: 0.7979
# Epoch 19/20
# 1350/1350 [==============================] - 8s 6ms/step - loss: 0.2639 - accuracy: 0.8894 - val_loss: 0.4325 - val_accuracy: 0.8190
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_24K.cv.3.best/assets
# Epoch 20/20
# 1350/1350 [==============================] - 8s 6ms/step - loss: 0.2319 - accuracy: 0.9072 - val_loss: 0.3859 - val_accuracy: 0.8369
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_24K.cv.3.best/assets
# Fold 3, 20 epochs, 181 sec
# accuracy: 84.25%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/20
# 1350/1350 [==============================] - 9s 6ms/step - loss: 0.6518 - accuracy: 0.5842 - val_loss: 0.5179 - val_accuracy: 0.7423
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_24K.cv.4.best/assets
# Epoch 2/20
# 1350/1350 [==============================] - 7s 6ms/step - loss: 0.5223 - accuracy: 0.7441 - val_loss: 0.5063 - val_accuracy: 0.7531
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_24K.cv.4.best/assets
# Epoch 3/20
# 1350/1350 [==============================] - 7s 5ms/step - loss: 0.4925 - accuracy: 0.7643 - val_loss: 0.4796 - val_accuracy: 0.7694
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_24K.cv.4.best/assets
# Epoch 4/20
# 1350/1350 [==============================] - 8s 6ms/step - loss: 0.4615 - accuracy: 0.7856 - val_loss: 0.4763 - val_accuracy: 0.7725
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_24K.cv.4.best/assets
# Epoch 5/20
# 1350/1350 [==============================] - 7s 6ms/step - loss: 0.4342 - accuracy: 0.8021 - val_loss: 0.4314 - val_accuracy: 0.7967
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_24K.cv.4.best/assets
# Epoch 6/20
# 1350/1350 [==============================] - 7s 6ms/step - loss: 0.3859 - accuracy: 0.8300 - val_loss: 0.4025 - val_accuracy: 0.8163
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_24K.cv.4.best/assets
# Epoch 7/20
# 1350/1350 [==============================] - 8s 6ms/step - loss: 0.3466 - accuracy: 0.8511 - val_loss: 0.3618 - val_accuracy: 0.8469
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_24K.cv.4.best/assets
# Epoch 8/20
# 1350/1350 [==============================] - 7s 5ms/step - loss: 0.3108 - accuracy: 0.8692 - val_loss: 0.3243 - val_accuracy: 0.8650
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_24K.cv.4.best/assets
# Epoch 9/20
# 1350/1350 [==============================] - 7s 5ms/step - loss: 0.2420 - accuracy: 0.9007 - val_loss: 0.1468 - val_accuracy: 0.9454
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_24K.cv.4.best/assets
# Epoch 10/20
# 1350/1350 [==============================] - 7s 5ms/step - loss: 0.1347 - accuracy: 0.9498 - val_loss: 0.1711 - val_accuracy: 0.9365
# Epoch 11/20
# 1350/1350 [==============================] - 7s 5ms/step - loss: 0.1046 - accuracy: 0.9623 - val_loss: 0.0957 - val_accuracy: 0.9675
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_24K.cv.4.best/assets
# Epoch 12/20
# 1350/1350 [==============================] - 7s 6ms/step - loss: 0.0752 - accuracy: 0.9739 - val_loss: 0.1221 - val_accuracy: 0.9535
# Epoch 13/20
# 1350/1350 [==============================] - 8s 6ms/step - loss: 0.0699 - accuracy: 0.9759 - val_loss: 0.0808 - val_accuracy: 0.9710
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_24K.cv.4.best/assets
# Epoch 14/20
# 1350/1350 [==============================] - 8s 6ms/step - loss: 0.0597 - accuracy: 0.9801 - val_loss: 0.0555 - val_accuracy: 0.9835
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_24K.cv.4.best/assets
# Epoch 15/20
# 1350/1350 [==============================] - 7s 5ms/step - loss: 0.0514 - accuracy: 0.9831 - val_loss: 0.0615 - val_accuracy: 0.9810
# Epoch 16/20
# 1350/1350 [==============================] - 7s 5ms/step - loss: 0.0417 - accuracy: 0.9864 - val_loss: 0.0519 - val_accuracy: 0.9835
# Epoch 17/20
# 1350/1350 [==============================] - 7s 6ms/step - loss: 0.0412 - accuracy: 0.9862 - val_loss: 0.0497 - val_accuracy: 0.9867
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_24K.cv.4.best/assets
# Epoch 18/20
# 1350/1350 [==============================] - 8s 6ms/step - loss: 0.0346 - accuracy: 0.9878 - val_loss: 0.0573 - val_accuracy: 0.9833
# Epoch 19/20
# 1350/1350 [==============================] - 7s 6ms/step - loss: 0.0339 - accuracy: 0.9877 - val_loss: 0.0461 - val_accuracy: 0.9871
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_24K.cv.4.best/assets
# Epoch 20/20
# 1350/1350 [==============================] - 8s 6ms/step - loss: 0.0276 - accuracy: 0.9915 - val_loss: 0.0484 - val_accuracy: 0.9835
# Fold 4, 20 epochs, 181 sec
# accuracy: 98.85%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/20
# 1350/1350 [==============================] - 9s 6ms/step - loss: 0.6776 - accuracy: 0.5529 - val_loss: 0.5898 - val_accuracy: 0.6996
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_24K.cv.5.best/assets
# Epoch 2/20
# 1350/1350 [==============================] - 8s 6ms/step - loss: 0.5627 - accuracy: 0.7108 - val_loss: 0.6273 - val_accuracy: 0.6656
# Epoch 3/20
# 1350/1350 [==============================] - 8s 6ms/step - loss: 0.5080 - accuracy: 0.7550 - val_loss: 0.5424 - val_accuracy: 0.7269
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_24K.cv.5.best/assets
# Epoch 4/20
# 1350/1350 [==============================] - 8s 6ms/step - loss: 0.4825 - accuracy: 0.7720 - val_loss: 0.4762 - val_accuracy: 0.7729
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_24K.cv.5.best/assets
# Epoch 5/20
# 1350/1350 [==============================] - 8s 6ms/step - loss: 0.4579 - accuracy: 0.7850 - val_loss: 0.4692 - val_accuracy: 0.7792
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_24K.cv.5.best/assets
# Epoch 6/20
# 1350/1350 [==============================] - 8s 6ms/step - loss: 0.4460 - accuracy: 0.7935 - val_loss: 0.4769 - val_accuracy: 0.7744
# Epoch 7/20
# 1350/1350 [==============================] - 8s 6ms/step - loss: 0.4295 - accuracy: 0.8043 - val_loss: 0.5105 - val_accuracy: 0.7490
# Epoch 8/20
# 1350/1350 [==============================] - 8s 6ms/step - loss: 0.3921 - accuracy: 0.8264 - val_loss: 0.4288 - val_accuracy: 0.8040
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_24K.cv.5.best/assets
# Epoch 9/20
# 1350/1350 [==============================] - 8s 6ms/step - loss: 0.3765 - accuracy: 0.8350 - val_loss: 0.4575 - val_accuracy: 0.7852
# Epoch 10/20
# 1350/1350 [==============================] - 7s 5ms/step - loss: 0.3395 - accuracy: 0.8543 - val_loss: 0.3892 - val_accuracy: 0.8252
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_24K.cv.5.best/assets
# Epoch 11/20
# 1350/1350 [==============================] - 7s 6ms/step - loss: 0.3073 - accuracy: 0.8717 - val_loss: 0.4211 - val_accuracy: 0.8150
# Epoch 12/20
# 1350/1350 [==============================] - 7s 6ms/step - loss: 0.2877 - accuracy: 0.8806 - val_loss: 0.3428 - val_accuracy: 0.8506
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_24K.cv.5.best/assets
# Epoch 13/20
# 1350/1350 [==============================] - 8s 6ms/step - loss: 0.2573 - accuracy: 0.8943 - val_loss: 0.2848 - val_accuracy: 0.8800
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_24K.cv.5.best/assets
# Epoch 14/20
# 1350/1350 [==============================] - 7s 6ms/step - loss: 0.2042 - accuracy: 0.9196 - val_loss: 0.1789 - val_accuracy: 0.9317
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_24K.cv.5.best/assets
# Epoch 15/20
# 1350/1350 [==============================] - 7s 5ms/step - loss: 0.1436 - accuracy: 0.9474 - val_loss: 0.1395 - val_accuracy: 0.9494
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_24K.cv.5.best/assets
# Epoch 16/20
# 1350/1350 [==============================] - 7s 5ms/step - loss: 0.1034 - accuracy: 0.9636 - val_loss: 0.1028 - val_accuracy: 0.9644
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_24K.cv.5.best/assets
# Epoch 17/20
# 1350/1350 [==============================] - 7s 6ms/step - loss: 0.0801 - accuracy: 0.9723 - val_loss: 0.0826 - val_accuracy: 0.9721
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_24K.cv.5.best/assets
# Epoch 18/20
# 1350/1350 [==============================] - 7s 6ms/step - loss: 0.0688 - accuracy: 0.9763 - val_loss: 0.0634 - val_accuracy: 0.9765
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_24K.cv.5.best/assets
# Epoch 19/20
# 1350/1350 [==============================] - 8s 6ms/step - loss: 0.0564 - accuracy: 0.9802 - val_loss: 0.0693 - val_accuracy: 0.9777
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/Test_Non_noisy_24K.cv.5.best/assets
# Epoch 20/20
# 1350/1350 [==============================] - 7s 6ms/step - loss: 0.0518 - accuracy: 0.9822 - val_loss: 0.0700 - val_accuracy: 0.9775
# Fold 5, 20 epochs, 183 sec
# accuracy: 97.79%
#
# 5-way Cross Validation mean 95.69% (+/- 5.73%)
# Done
