# %% [markdown]
# <a href="https://colab.research.google.com/github/ShepherdCode/ShepherdML/blob/master/Nasa2021/CNN_523.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CNN 523
#
# 1. Four layers of CNNS and MaxPooling
# 2. Drop out at 0.2
# 3. Variable filters and dense neurons

# %%
#NC_FILENAME='ncRNA.tiny50.fasta'
#PC_FILENAME='pcRNA.tiny50.fasta'
#NC_FILENAME='ncRNA.gc34.processed.fasta'
#PC_FILENAME='pcRNA.gc34.processed.fasta'
NC_FILENAME='ncRNA.gc36.balance.fasta'
PC_FILENAME='pcRNA.gc36.balance.fasta'

MODEL_FILE='CNN523' 
DATAPATH=''

try:
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
except:
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"
NC_FILENAME = DATAPATH+NC_FILENAME
PC_FILENAME = DATAPATH+PC_FILENAME
MODEL_FILE=DATAPATH+MODEL_FILE

EPOCHS=50
SPLITS=5
K=1
VOCABULARY_SIZE=4**K+1   # e.g. K=3 => 64 DNA K-mers + 'NNN'
EMBED_DIMEN=2
FILTERS=32
KERNEL=3
NEURONS=24
DROP=0.2
MINLEN=200
MAXLEN=2000
DENSE_LEN = 1000
ACT="tanh"
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# Load our own tools
# TO DO: don't go to GitHub if the file is already local.
GITHUB = True
if GITHUB:
    #!pip install requests  # Uncomment this if necessary. Seems to be pre-installed.
    import requests
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/ShepherdML/master/Strings/tools_fasta.py')
    with open('tools_fasta.py', 'w') as f:
        f.write(r.text)
    # TO DO: delete the file after import
import tools_fasta as tools
tools.yahoo()  # If this prints "Yahoo!" the the import was successful.

TOOLS_CHANGED = False   # set to True to re-run with a new version of tools
if TOOLS_CHANGED:
  from importlib import reload 
  tools=reload(tools)
  print(dir(tools))   # run this to see EVERYTHING in the tools module
# Out:
# Yahoo!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import StratifiedKFold
import tensorflow as tf
from tensorflow import keras
import time
dt='float32'
tf.keras.backend.set_floatx(dt)

# %% [markdown]
# Build model

# %%
def compile_model(model):
    ## learn rate = initial_learning_rate * decay_rate ^ (step / decay_steps)
    #adam_default_learn_rate = 0.001
    #schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    #    initial_learning_rate = adam_default_learn_rate*10,
    #    decay_steps=10000, decay_rate=0.99, staircase=True)
    #alrd = tf.keras.optimizers.Adam(learning_rate=schedule)
    #model.compile(loss=bc, optimizer=alrd, metrics=["accuracy"])

    print("COMPILE...")
    bc=tf.keras.losses.BinaryCrossentropy(from_logits=False)
    model.compile(loss=bc, optimizer="adam", metrics=["accuracy"])
    print("...COMPILED")
    return model

def build_model():
    SHAPE=(MAXLEN,5)  # 2000 time steps, 5 features
    clayer1 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same",
                                 input_shape=SHAPE)
    clayer2 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer3 = keras.layers.MaxPooling1D(2)
    clayer4 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer5 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer6 = keras.layers.MaxPooling1D(2)
    clayer7 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer8 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer9 = keras.layers.MaxPooling1D(2)
    clayer10 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer11 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer12 = keras.layers.MaxPooling1D(2)

    clayer13 = keras.layers.Flatten()

    dlayer1 = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt, input_shape=[DENSE_LEN])
    dlayer2 = keras.layers.Dropout(DROP)
    dlayer3 = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt)
    dlayer4 = keras.layers.Dropout(DROP)
    output_layer = keras.layers.Dense(1, activation="sigmoid", dtype=dt)

    cnn = keras.models.Sequential()
    cnn.add(clayer1)
    cnn.add(clayer2)
    cnn.add(clayer3)
    cnn.add(clayer4)
    cnn.add(clayer5)
    cnn.add(clayer6)
    cnn.add(clayer7)
    cnn.add(clayer8)
    cnn.add(clayer9)
    cnn.add(clayer10)
    cnn.add(clayer11)
    cnn.add(clayer12)
    cnn.add(clayer13)
    cnn.add(dlayer1)
    cnn.add(dlayer2)
    cnn.add(dlayer3)
    cnn.add(dlayer4)
    cnn.add(output_layer)
    mlpc = compile_model(cnn)
    return mlpc

# %% [markdown]
# Cross validation

# %%
def do_cross_validation(X,y,given_model):
    cv_scores = []
    fold=0
    splitter = ShuffleSplit(n_splits=SPLITS, test_size=0.1, random_state=37863)
    for train_index,valid_index in splitter.split(X):
        fold += 1
        X_train=X[train_index] # use iloc[] for dataframe
        y_train=y[train_index]
        X_valid=X[valid_index]
        y_valid=y[valid_index]        
        # Avoid continually improving the same model.
        model = compile_model(keras.models.clone_model(given_model))
        bestname=MODEL_FILE+".cv."+str(fold)+".best"
        mycallbacks = [keras.callbacks.ModelCheckpoint(
            filepath=bestname, save_best_only=True, 
            monitor='val_accuracy', mode='max')]   
        print("FIT")
        start_time=time.time()
        history=model.fit(X_train, y_train, # batch_size=10, default=32 works nicely
                epochs=EPOCHS, verbose=1,  # verbose=1 for ascii art, verbose=0 for none
                callbacks=mycallbacks,
                validation_data=(X_valid,y_valid) )
        end_time=time.time()
        elapsed_time=(end_time-start_time)                        
        print("Fold %d, %d epochs, %d sec"%(fold,EPOCHS,elapsed_time))
        pd.DataFrame(history.history).plot(figsize=(8,5))
        plt.grid(True)
        plt.gca().set_ylim(0,1)
        plt.show()
        best_model=keras.models.load_model(bestname)
        scores = best_model.evaluate(X_valid, y_valid, verbose=0)
        print("%s: %.2f%%" % (best_model.metrics_names[1], scores[1]*100))
        cv_scores.append(scores[1] * 100)  
    print()
    print("%d-way Cross Validation mean %.2f%% (+/- %.2f%%)" % (fold, np.mean(cv_scores), np.std(cv_scores)))

# %% [markdown]
# ## Train on RNA lengths 200-1Kb

# %%
print ("Compile the model")
model=build_model()
print ("Summarize the model")
print(model.summary())  # Print this only once
#model.save(MODEL_FILE+'.model')
# Out:
# Compile the model
# COMPILE...
# ...COMPILED
# Summarize the model
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_6 (Conv1D)            (None, 2000, 32)          512
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 2000, 32)          3104
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 1000, 32)          0
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 1000, 32)          3104
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 1000, 32)          3104
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 500, 32)           0
# _________________________________________________________________
# conv1d_10 (Conv1D)           (None, 500, 32)           3104
# _________________________________________________________________
# conv1d_11 (Conv1D)           (None, 500, 32)           3104
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 250, 32)           0
# _________________________________________________________________
# conv1d_12 (Conv1D)           (None, 250, 32)           3104
# _________________________________________________________________
# conv1d_13 (Conv1D)           (None, 250, 32)           3104
# _________________________________________________________________
# max_pooling1d_6 (MaxPooling1 (None, 125, 32)           0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4000)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 24)                96024
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 24)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 24)                600
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 24)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 25
# =================================================================
# Total params: 118,889
# Trainable params: 118,889
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#MINLEN=200
#MAXLEN=2000
print("Load data from files.")
nc_seq=tools.load_fasta(NC_FILENAME,0)
pc_seq=tools.load_fasta(PC_FILENAME,1)
train_set=pd.concat((nc_seq,pc_seq),axis=0)
nc_seq=None
pc_seq=None
print("Ready: train_set")
#train_set
subset=tools.make_slice(train_set,MINLEN,MAXLEN)# One array to two: X and y
(X1,y_train)=tools.separate_X_and_y(subset)
# X1 is pandas df of ("list" of one sequence)
X2=X1.to_numpy()  # numpy ndarray of ("list" of one sequence)
X3=[elem[0] for elem in X2]  # numpy dnarray of str
X4=tools.uniform_length(X3,MAXLEN)
X5= [tools.one_hot(x) for x in X4]
X_train=np.asarray(X5)
y_train=y_train.to_numpy()

subset=None
X1=None
X2=None
X3=None
X4=None
X5=None
# Out:
# Load data from files.
# Ready: train_set

# %%
print ("Cross validation")
do_cross_validation(X_train,y_train,model)  
print ("Done")
# Out:
# Cross validation
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.6093 - accuracy: 0.6756 - val_loss: 0.5784 - val_accuracy: 0.7185
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.1.best/assets
# Epoch 2/50
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.5685 - accuracy: 0.7153 - val_loss: 0.4771 - val_accuracy: 0.7774
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.1.best/assets
# Epoch 3/50
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.5211 - accuracy: 0.7470 - val_loss: 0.4614 - val_accuracy: 0.7985
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.1.best/assets
# Epoch 4/50
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.4908 - accuracy: 0.7684 - val_loss: 0.4818 - val_accuracy: 0.7619
# Epoch 5/50
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.4449 - accuracy: 0.7998 - val_loss: 0.4685 - val_accuracy: 0.7788
# Epoch 6/50
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.4036 - accuracy: 0.8224 - val_loss: 0.4022 - val_accuracy: 0.8224
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.1.best/assets
# Epoch 7/50
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.3857 - accuracy: 0.8334 - val_loss: 0.3453 - val_accuracy: 0.8553
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.1.best/assets
# Epoch 8/50
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.3668 - accuracy: 0.8467 - val_loss: 0.3680 - val_accuracy: 0.8320
# Epoch 9/50
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.3592 - accuracy: 0.8485 - val_loss: 0.3324 - val_accuracy: 0.8584
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.1.best/assets
# Epoch 10/50
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.3501 - accuracy: 0.8537 - val_loss: 0.3504 - val_accuracy: 0.8539
# Epoch 11/50
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.3428 - accuracy: 0.8582 - val_loss: 0.3278 - val_accuracy: 0.8666
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.1.best/assets
# Epoch 12/50
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.3526 - accuracy: 0.8562 - val_loss: 0.3608 - val_accuracy: 0.8500
# Epoch 13/50
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.3516 - accuracy: 0.8527 - val_loss: 0.3552 - val_accuracy: 0.8536
# Epoch 14/50
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.3312 - accuracy: 0.8615 - val_loss: 0.3090 - val_accuracy: 0.8717
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.1.best/assets
# Epoch 15/50
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.3187 - accuracy: 0.8690 - val_loss: 0.3076 - val_accuracy: 0.8742
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.1.best/assets
# Epoch 16/50
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.3191 - accuracy: 0.8687 - val_loss: 0.3287 - val_accuracy: 0.8655
# Epoch 17/50
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.3116 - accuracy: 0.8753 - val_loss: 0.3131 - val_accuracy: 0.8669
# Epoch 18/50
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.
50
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.1554 - accuracy: 0.9425 - val_loss: 0.2930 - val_accuracy: 0.8891
# Epoch 46/50
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.1450 - accuracy: 0.9490 - val_loss: 0.3110 - val_accuracy: 0.8973
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.4.best/assets
# Epoch 47/50
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.1475 - accuracy: 0.9464 - val_loss: 0.3110 - val_accuracy: 0.8874
# Epoch 48/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.1523 - accuracy: 0.9444 - val_loss: 0.3218 - val_accuracy: 0.8745
# Epoch 49/50
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.1589 - accuracy: 0.9414 - val_loss: 0.3284 - val_accuracy: 0.8770
# Epoch 50/50
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.2169 - accuracy: 0.9145 - val_loss: 0.3247 - val_accuracy: 0.8824
# Fold 4, 50 epochs, 392 sec
# accuracy: 89.73%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/50
# 1000/1000 [==============================] - 9s 8ms/step - loss: 0.6279 - accuracy: 0.6539 - val_loss: 0.5759 - val_accuracy: 0.6772
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.5.best/assets
# Epoch 2/50
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.5831 - accuracy: 0.7025 - val_loss: 0.6940 - val_accuracy: 0.6093
# Epoch 3/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.5556 - accuracy: 0.7274 - val_loss: 0.5155 - val_accuracy: 0.7591
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.5.best/assets
# Epoch 4/50
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.5258 - accuracy: 0.7437 - val_loss: 0.4641 - val_accuracy: 0.7906
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.5.best/assets
# Epoch 5/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.4704 - accuracy: 0.7835 - val_loss: 0.4010 - val_accuracy: 0.8213
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.5.best/assets
# Epoch 6/50
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.4392 - accuracy: 0.8064 - val_loss: 0.3813 - val_accuracy: 0.8339
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.5.best/assets
# Epoch 7/50
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.4294 - accuracy: 0.8064 - val_loss: 0.3911 - val_accuracy: 0.8255
# Epoch 8/50
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.4146 - accuracy: 0.8183 - val_loss: 0.4112 - val_accuracy: 0.8173
# Epoch 9/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.3981 - accuracy: 0.8291 - val_loss: 0.3554 - val_accuracy: 0.8514
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.5.best/assets
# Epoch 10/50
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.3883 - accuracy: 0.8317 - val_loss: 0.3674 - val_accuracy: 0.8472
# Epoch 11/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.3797 - accuracy: 0.8335 - val_loss: 0.3530 - val_accuracy: 0.8511
# Epoch 12/50
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.3797 - accuracy: 0.8374 - val_loss: 0.3863 - val_accuracy: 0.8410
# Epoch 13/50
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.3840 - accuracy: 0.8337 - val_loss: 0.3361 - val_accuracy: 0.8660
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.5.best/assets
# Epoch 14/50
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.3537 - accuracy: 0.8502 - val_loss: 0.3500 - val_accuracy: 0.8463
# Epoch 15/50
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.3554 - accuracy: 0.8507 - val_loss: 0.3378 - val_accuracy: 0.8601
# Epoch 16/50
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.3508 - accuracy: 0.8536 - val_loss: 0.3778 - val_accuracy: 0.8415
# Epoch 17/50
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.3377 - accuracy: 0.8609 - val_loss: 0.3308 - val_accuracy: 0.8570
# Epoch 18/50
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.3319 - accuracy: 0.8620 - val_loss: 0.3275 - val_accuracy: 0.8660
# Epoch 19/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.3330 - accuracy: 0.8631 - val_loss: 0.3113 - val_accuracy: 0.8764
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.5.best/assets
# Epoch 20/50
# 1000/1000 [==============================] - 7s 8ms/step - loss: 0.3277 - accuracy: 0.8645 - val_loss: 0.3039 - val_accuracy: 0.8733
# Epoch 21/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.3201 - accuracy: 0.8692 - val_loss: 0.3087 - val_accuracy: 0.8764
# Epoch 22/50
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.3310 - accuracy: 0.8631 - val_loss: 0.3059 - val_accuracy: 0.8756
# Epoch 23/50
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.3219 - accuracy: 0.8692 - val_loss: 0.2953 - val_accuracy: 0.8787
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.5.best/assets
# Epoch 24/50
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.3252 - accuracy: 0.8709 - val_loss: 0.3076 - val_accuracy: 0.8669
# Epoch 25/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.3157 - accuracy: 0.8735 - val_loss: 0.2989 - val_accuracy: 0.8826
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.5.best/assets
# Epoch 26/50
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.3050 - accuracy: 0.8784 - val_loss: 0.2969 - val_accuracy: 0.8790
# Epoch 27/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.3100 - accuracy: 0.8724 - val_loss: 0.3431 - val_accuracy: 0.8553
# Epoch 28/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.2988 - accuracy: 0.8791 - val_loss: 0.2906 - val_accuracy: 0.8773
# Epoch 29/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.2938 - accuracy: 0.8820 - val_loss: 0.2945 - val_accuracy: 0.8793
# Epoch 30/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.2934 - accuracy: 0.8822 - val_loss: 0.3020 - val_accuracy: 0.8745
# Epoch 31/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.3010 - accuracy: 0.8772 - val_loss: 0.2915 - val_accuracy: 0.8843
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.5.best/assets
# Epoch 32/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.3038 - accuracy: 0.8767 - val_loss: 0.2939 - val_accuracy: 0.8860
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.5.best/assets
# Epoch 33/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.2946 - accuracy: 0.8830 - val_loss: 0.3391 - val_accuracy: 0.8627
# Epoch 34/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.2846 - accuracy: 0.8885 - val_loss: 0.3507 - val_accuracy: 0.8604
# Epoch 35/50
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.2964 - accuracy: 0.8796 - val_loss: 0.2867 - val_accuracy: 0.8832
# Epoch 36/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.2759 - accuracy: 0.8896 - val_loss: 0.3436 - val_accuracy: 0.8567
# Epoch 37/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.2919 - accuracy: 0.8832 - val_loss: 0.2793 - val_accuracy: 0.8793
# Epoch 38/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.2823 - accuracy: 0.8876 - val_loss: 0.2822 - val_accuracy: 0.8866
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.5.best/assets
# Epoch 39/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.2724 - accuracy: 0.8946 - val_loss: 0.2918 - val_accuracy: 0.8832
# Epoch 40/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.2804 - accuracy: 0.8904 - val_loss: 0.2926 - val_accuracy: 0.8905
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.5.best/assets
# Epoch 41/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.2728 - accuracy: 0.8952 - val_loss: 0.2804 - val_accuracy: 0.8860
# Epoch 42/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.2702 - accuracy: 0.8943 - val_loss: 0.2943 - val_accuracy: 0.8826
# Epoch 43/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.2836 - accuracy: 0.8877 - val_loss: 0.2745 - val_accuracy: 0.8900
# Epoch 44/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.2684 - accuracy: 0.8927 - val_loss: 0.3291 - val_accuracy: 0.8705
# Epoch 45/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.2832 - accuracy: 0.8893 - val_loss: 0.2742 - val_accuracy: 0.8874
# Epoch 46/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.2756 - accuracy: 0.8916 - val_loss: 0.3006 - val_accuracy: 0.8821
# Epoch 47/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.2889 - accuracy: 0.8828 - val_loss: 0.2837 - val_accuracy: 0.8877
# Epoch 48/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.2636 - accuracy: 0.8978 - val_loss: 0.2722 - val_accuracy: 0.8928
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.5.best/assets
# Epoch 49/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.2802 - accuracy: 0.8912 - val_loss: 0.2856 - val_accuracy: 0.8857
# Epoch 50/50
# 1000/1000 [==============================] - 8s 8ms/step - loss: 0.2738 - accuracy: 0.8934 - val_loss: 0.2856 - val_accuracy: 0.8863
# Fold 5, 50 epochs, 402 sec
# accuracy: 89.28%
#
# 5-way Cross Validation mean 89.16% (+/- 0.48%)
# Done
