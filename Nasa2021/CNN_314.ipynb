# %% [markdown]
# # CNN 314
# Rather than partition train/validation sets, use different sets.
# Cut train set down to random LIMIT number of transcripts.
# Use all of the validation set.
# Use fit(shuffle) on the train set.
#
# TO DO:
# Save five best models to same directory to make it easy to delete.

# %%
TRAIN_NC_FILENAME='ncRNA.gc36.all.fasta'
TRAIN_PC_FILENAME='pcRNA.gc36.all.fasta'
VALID_NC_FILENAME='ncRNA.gc36.median.fasta'
VALID_PC_FILENAME='pcRNA.gc36.median.fasta'
#NC_FILENAME='ncRNA.tiny50.fasta'
#PC_FILENAME='pcRNA.tiny50.fasta'
#NC_FILENAME='ncRNA.gc34.processed.fasta'
#PC_FILENAME='pcRNA.gc34.processed.fasta'

MODEL_FILE='JUNK2'  # change this if you want to keep models
DATAPATH=''

try:
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
except:
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"
TRAIN_NC_FILENAME = DATAPATH+TRAIN_NC_FILENAME
TRAIN_PC_FILENAME = DATAPATH+TRAIN_PC_FILENAME
VALID_NC_FILENAME = DATAPATH+VALID_NC_FILENAME
VALID_PC_FILENAME = DATAPATH+VALID_PC_FILENAME
MODEL_FILE=DATAPATH+MODEL_FILE

EPOCHS=200
SPLITS=5
K=1
VOCABULARY_SIZE=4**K+1   # e.g. K=3 => 64 DNA K-mers + 'NNN'
EMBED_DIMEN=2
FILTERS=32
KERNEL=3
NEURONS=32
DROP=0.25
ACT="tanh"
MINLEN=201
MAXLEN=2000
LIMIT=5588    # This is the size of our smallest set (protein coding short)
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# Load our own tools
# TO DO: don't go to GitHub if the file is already local.
GITHUB = True
if GITHUB:
    #!pip install requests  # Uncomment this if necessary. Seems to be pre-installed.
    import requests
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/ShepherdML/master/Strings/tools_fasta.py')
    with open('tools_fasta.py', 'w') as f:
        f.write(r.text)
    # TO DO: delete the file after import
import tools_fasta as tools
tools.yahoo()  # If this prints "Yahoo!" the the import was successful.

TOOLS_CHANGED = False   # set to True to re-run with a new version of tools
if TOOLS_CHANGED:
  from importlib import reload 
  tools=reload(tools)
  print(dir(tools))   # run this to see EVERYTHING in the tools module
# Out:
# Yahoo!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import StratifiedKFold
import tensorflow as tf
from tensorflow import keras
import time
dt='float32'
tf.keras.backend.set_floatx(dt)

# %% [markdown]
# Build model

# %%
def compile_model(model):
    ## learn rate = initial_learning_rate * decay_rate ^ (step / decay_steps)
    #adam_default_learn_rate = 0.001
    #schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    #    initial_learning_rate = adam_default_learn_rate*10,
    #    decay_steps=10000, decay_rate=0.99, staircase=True)
    #alrd = tf.keras.optimizers.Adam(learning_rate=schedule)
    #model.compile(loss=bc, optimizer=alrd, metrics=["accuracy"])

    print("COMPILE...")
    bc=tf.keras.losses.BinaryCrossentropy(from_logits=False)
    model.compile(loss=bc, optimizer="adam", metrics=["accuracy"])
    print("...COMPILED")
    return model

def build_model():
    SHAPE=(MAXLEN,5)  # MAXLEN bases = time steps, 5 features = one hots
    clayer1 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same",
                                 input_shape=SHAPE)
    clayer2 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer3 = keras.layers.MaxPooling1D(2)
    clayer4 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer5 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer6 = keras.layers.MaxPooling1D(2)
    clayer7 = keras.layers.Flatten()

    dlayer1 = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt, input_shape=[1000])
    dlayer2 = keras.layers.Dropout(DROP)
    dlayer3 = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt)
    dlayer4 = keras.layers.Dropout(DROP)
    output_layer = keras.layers.Dense(1, activation="sigmoid", dtype=dt)

    cnn = keras.models.Sequential()
    cnn.add(clayer1)
    cnn.add(clayer2)
    cnn.add(clayer3)
    cnn.add(clayer4)
    cnn.add(clayer5)
    cnn.add(clayer6)
    cnn.add(clayer7)
    cnn.add(dlayer1)
    cnn.add(dlayer2)
    cnn.add(dlayer3)
    cnn.add(dlayer4)
    cnn.add(output_layer)
    mlpc = compile_model(cnn)
    return mlpc

# %% [markdown]
# Cross validation

# %%
def do_cross_validation(X_train,y_train,given_model,X_valid,y_valid):
    cv_scores = []
    fold=0
    # When not using ShuffleSplit, make sure to randomize train data.
    #splitter = ShuffleSplit(n_splits=SPLITS, test_size=0.1, random_state=37863)
    #for train_index,valid_index in splitter.split(X):
    while fold < SPLITS:
        fold += 1
        # Avoid continually improving the same model.
        model = compile_model(keras.models.clone_model(given_model))
        bestname=MODEL_FILE+".cv."+str(fold)+".best"
        es = keras.callbacks.EarlyStopping(monitor='val_loss',  
            patience=10, verbose=1)
        mc = keras.callbacks.ModelCheckpoint(
            filepath=bestname, save_best_only=True, 
            monitor='val_accuracy', mode='max')  
        mycallbacks = [es,mc]  
        print("FIT")
        start_time=time.time()
        history=model.fit(X_train, y_train, # batch_size=10, default=32 works nicely
                epochs=EPOCHS, verbose=1,  # verbose=1 for ascii art, verbose=0 for none
                callbacks=mycallbacks, shuffle=True,
                validation_data=(X_valid,y_valid) )
        end_time=time.time()
        elapsed_time=(end_time-start_time)                        
        print("Fold %d, %d epochs, %d sec"%(fold,EPOCHS,elapsed_time))
        pd.DataFrame(history.history).plot(figsize=(8,5))
        plt.grid(True)
        plt.gca().set_ylim(0,1)
        plt.show()
        best_model=keras.models.load_model(bestname)
        scores = best_model.evaluate(X_valid, y_valid, verbose=0)
        print("%s: %.2f%%" % (best_model.metrics_names[1], scores[1]*100))
        cv_scores.append(scores[1] * 100)  

    print()
    print("%d-way Cross Validation max %.2f%%, mean %.2f%% (+/- %.2f%%)" % 
          (fold, np.amax(cv_scores), np.mean(cv_scores), np.std(cv_scores)))

# %% [markdown]
# ## Train on RNA lengths 200-1Kb

# %%
print ("Compile the model")
model=build_model()
print ("Summarize the model")
print(model.summary())  # Print this only once
#model.save(MODEL_FILE+'.model')
# Out:
# Compile the model
# COMPILE...
# ...COMPILED
# Summarize the model
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_4 (Conv1D)            (None, 2000, 32)          512
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 2000, 32)          3104
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 1000, 32)          0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 1000, 32)          3104
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 1000, 32)          3104
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 500, 32)           0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 16000)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                512032
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 522,945
# Trainable params: 522,945
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
def load_data(nc_filename,pc_filename,limit=None):
  nc_seq=tools.load_fasta(nc_filename,0)
  pc_seq=tools.load_fasta(pc_filename,1)
  if limit is not None:
    # Choose a random subset of size = limit.
    # Side effect: randomizes the data order.
    nfrac=1.0*limit/len(nc_seq)
    pfrac=1.0*limit/len(pc_seq)
    if nfrac<1.0:
      nc_seq=nc_seq.sample(frac=nfrac)
    if pfrac<1.0:
      pc_seq=pc_seq.sample(frac=pfrac)
  train_set=pd.concat((nc_seq,pc_seq),axis=0)
  # May not need to slice by length if input files already sliced
  subset=tools.make_slice(train_set,MINLEN,MAXLEN)
  # randset=subset.sample(frac=1) # unneccessary with fit(shuffle)
  (X1,y1)=tools.separate_X_and_y(subset)
  # X1 is pandas df of ("list" of one sequence)
  X2=X1.to_numpy()  # numpy ndarray of ("list" of one sequence)
  X3=[elem[0] for elem in X2]  # numpy dnarray of str
  X4=tools.uniform_length(X3,MAXLEN)
  X5= [tools.one_hot(x) for x in X4]
  X6=np.asarray(X5)
  y6=y1.to_numpy()
  return X6,y6

print("Load train data from files.")
X_train,y_train = load_data(TRAIN_NC_FILENAME,TRAIN_PC_FILENAME,LIMIT)
print("X_train",X_train.shape)
print("Load valid data from files.")
X_valid,y_valid = load_data(VALID_NC_FILENAME,VALID_PC_FILENAME)
print("X_valid",X_valid.shape)
# Out:
# Load train data from files.
# X_train (11176, 2000, 5)
# Load valid data from files.
# X_valid (18217, 2000, 5)

# %%
print ("Cross valiation")
do_cross_validation(X_train,y_train,model,X_valid,y_valid)  
print ("Done")
# Out:
# Cross valiation
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/200
# 350/350 [==============================] - 4s 11ms/step - loss: 0.7077 - accuracy: 0.5995 - val_loss: 0.6857 - val_accuracy: 0.6005
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.1.best/assets
# Epoch 2/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.6310 - accuracy: 0.6635 - val_loss: 0.5887 - val_accuracy: 0.7000
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.1.best/assets
# Epoch 3/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.6116 - accuracy: 0.6841 - val_loss: 0.5365 - val_accuracy: 0.7399
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.1.best/assets
# Epoch 4/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5819 - accuracy: 0.7030 - val_loss: 0.5593 - val_accuracy: 0.7261
# Epoch 5/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5706 - accuracy: 0.7158 - val_loss: 0.6367 - val_accuracy: 0.6530
# Epoch 6/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5751 - accuracy: 0.7056 - val_loss: 0.5648 - val_accuracy: 0.7320
# Epoch 7/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5503 - accuracy: 0.7334 - val_loss: 0.5095 - val_accuracy: 0.7634
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.1.best/assets
# Epoch 8/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5400 - accuracy: 0.7307 - val_loss: 0.5988 - val_accuracy: 0.7049
# Epoch 9/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5221 - accuracy: 0.7490 - val_loss: 0.5402 - val_accuracy: 0.7253
# Epoch 10/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.4986 - accuracy: 0.7710 - val_loss: 0.4630 - val_accuracy: 0.7960
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.1.best/assets
# Epoch 11/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.4602 - accuracy: 0.7949 - val_loss: 0.4653 - val_accuracy: 0.7883
# Epoch 12/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.4238 - accuracy: 0.8169 - val_loss: 0.5843 - val_accuracy: 0.7192
# Epoch 13/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.4199 - accuracy: 0.8180 - val_loss: 0.3916 - val_accuracy: 0.8365
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.1.best/assets
# Epoch 14/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.3723 - accuracy: 0.8387 - val_loss: 0.3807 - val_accuracy: 0.8408
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.1.best/assets
# Epoch 15/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.3373 - accuracy: 0.8562 - val_loss: 0.5399 - val_accuracy: 0.7675
# Epoch 16/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.3112 - accuracy: 0.8689 - val_loss: 0.3785 - val_accuracy: 0.8443
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.1.best/assets
# Epoch 17/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.2946 - accuracy: 0.8820 - val_loss: 0.3855 - val_accuracy: 0.8499
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.1.best/assets
# Epoch 18/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.2593 - accuracy: 0.8969 - val_loss: 0.4283 - val_accuracy: 0.8378
# Epoch 19/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.2565 - accuracy: 0.8986 - val_loss: 0.4039 - val_accuracy: 0.8474
# Epoch 20/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.2122 - accuracy: 0.9187 - val_loss: 0.4089 - val_accuracy: 0.8567
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.1.best/assets
# Epoch 21/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.1813 - accuracy: 0.9326 - val_loss: 0.4858 - val_accuracy: 0.8329
# Epoch 22/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.1697 - accuracy: 0.9369 - val_loss: 0.4461 - val_accuracy: 0.8473
# Epoch 23/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.1519 - accuracy: 0.9445 - val_loss: 0.4261 - val_accuracy: 0.8576
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.1.best/assets
# Epoch 24/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.1433 - accuracy: 0.9476 - val_loss: 0.4712 - val_accuracy: 0.8512
# Epoch 25/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.1214 - accuracy: 0.9605 - val_loss: 0.5601 - val_accuracy: 0.8242
# Epoch 26/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.1160 - accuracy: 0.9551 - val_loss: 0.4927 - val_accuracy: 0.8572
# Epoch 00026: early stopping
# Fold 1, 200 epochs, 102 sec
# accuracy: 85.76%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/200
# 350/350 [==============================] - 5s 11ms/step - loss: 0.6915 - accuracy: 0.5933 - val_loss: 0.6354 - val_accuracy: 0.6087
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.2.best/assets
# Epoch 2/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.6198 - accuracy: 0.6716 - val_loss: 0.6133 - val_accuracy: 0.6853
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.2.best/assets
# Epoch 3/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5970 - accuracy: 0.6904 - val_loss: 0.5842 - val_accuracy: 0.7313
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.2.best/assets
# Epoch 4/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5900 - accuracy: 0.6995 - val_loss: 0.5882 - val_accuracy: 0.6945
# Epoch 5/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5753 - accuracy: 0.7048 - val_loss: 0.5520 - val_accuracy: 0.7423
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.2.best/assets
# Epoch 6/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5924 - accuracy: 0.6937 - val_loss: 0.6328 - val_accuracy: 0.6967
# Epoch 7/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5710 - accuracy: 0.7157 - val_loss: 0.6071 - val_accuracy: 0.7082
# Epoch 8/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5703 - accuracy: 0.7172 - val_loss: 0.5745 - val_accuracy: 0.7312
# Epoch 9/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5626 - accuracy: 0.7198 - val_loss: 0.5226 - val_accuracy: 0.7557
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.2.best/assets
# Epoch 10/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5361 - accuracy: 0.7365 - val_loss: 0.5319 - val_accuracy: 0.7590
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.2.best/assets
# Epoch 11/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.5221 - accuracy: 0.7485 - val_loss: 0.4857 - val_accuracy: 0.7841
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.2.best/assets
# Epoch 12/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5167 - accuracy: 0.7502 - val_loss: 0.4450 - val_accuracy: 0.8096
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.2.best/assets
# Epoch 13/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.4682 - accuracy: 0.7813 - val_loss: 0.5197 - val_accuracy: 0.7630
# Epoch 14/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.4550 - accuracy: 0.7905 - val_loss: 0.4524 - val_accuracy: 0.8028
# Epoch 15/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.4288 - accuracy: 0.8077 - val_loss: 0.5995 - val_accuracy: 0.6917
# Epoch 16/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.4256 - accuracy: 0.8109 - val_loss: 0.4414 - val_accuracy: 0.8078
# Epoch 17/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.3928 - accuracy: 0.8247 - val_loss: 0.4340 - val_accuracy: 0.8112
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.2.best/assets
# Epoch 18/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.3983 - accuracy: 0.8248 - val_loss: 0.5003 - val_accuracy: 0.7719
# Epoch 19/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.3395 - accuracy: 0.8584 - val_loss: 0.4175 - val_accuracy: 0.8217
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.2.best/assets
# Epoch 20/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.3373 - accuracy: 0.8554 - val_loss: 0.4877 - val_accuracy: 0.7863
# Epoch 21/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.3193 - accuracy: 0.8674 - val_loss: 0.4418 - val_accuracy: 0.8194
# Epoch 22/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.3140 - accuracy: 0.8733 - val_loss: 0.4510 - val_accuracy: 0.8179
# Epoch 23/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.2859 - accuracy: 0.8876 - val_loss: 0.4917 - val_accuracy: 0.8025
# Epoch 24/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.2385 - accuracy: 0.9071 - val_loss: 0.3782 - val_accuracy: 0.8526
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.2.best/assets
# Epoch 25/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.2440 - accuracy: 0.8994 - val_loss: 0.4888 - val_accuracy: 0.8179
# Epoch 26/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.2426 - accuracy: 0.8999 - val_loss: 0.4336 - val_accuracy: 0.8442
# Epoch 27/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.2061 - accuracy: 0.9242 - val_loss: 0.4493 - val_accuracy: 0.8381
# Epoch 28/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.1897 - accuracy: 0.9262 - val_loss: 0.4121 - val_accuracy: 0.8579
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.2.best/assets
# Epoch 29/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.1743 - accuracy: 0.9307 - val_loss: 0.4186 - val_accuracy: 0.8599
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.2.best/assets
# Epoch 30/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.1632 - accuracy: 0.9389 - val_loss: 0.4426 - val_accuracy: 0.8555
# Epoch 31/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.1573 - accuracy: 0.9441 - val_loss: 0.4184 - val_accuracy: 0.8664
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.2.best/assets
# Epoch 32/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.1408 - accuracy: 0.9515 - val_loss: 0.4214 - val_accuracy: 0.8650
# Epoch 33/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.1348 - accuracy: 0.9517 - val_loss: 0.4457 - val_accuracy: 0.8624
# Epoch 34/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.1145 - accuracy: 0.9599 - val_loss: 0.4755 - val_accuracy: 0.8510
# Epoch 00034: early stopping
# Fold 2, 200 epochs, 134 sec
# accuracy: 86.64%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.7464 - accuracy: 0.5654 - val_loss: 0.7246 - val_accuracy: 0.5148
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.3.best/assets
# Epoch 2/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.6344 - accuracy: 0.6550 - val_loss: 0.5961 - val_accuracy: 0.7207
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.3.best/assets
# Epoch 3/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.6046 - accuracy: 0.6861 - val_loss: 0.5368 - val_accuracy: 0.7471
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.3.best/assets
# Epoch 4/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5985 - accuracy: 0.6814 - val_loss: 0.6245 - val_accuracy: 0.6752
# Epoch 5/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5890 - accuracy: 0.6937 - val_loss: 0.5473 - val_accuracy: 0.7473
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.3.best/assets
# Epoch 6/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.6041 - accuracy: 0.6753 - val_loss: 0.6623 - val_accuracy: 0.6114
# Epoch 7/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5866 - accuracy: 0.6929 - val_loss: 0.5562 - val_accuracy: 0.7553
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.3.best/assets
# Epoch 8/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5917 - accuracy: 0.6829 - val_loss: 0.5982 - val_accuracy: 0.7326
# Epoch 9/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5849 - accuracy: 0.6934 - val_loss: 0.5760 - val_accuracy: 0.7309
# Epoch 10/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.5832 - accuracy: 0.6984 - val_loss: 0.5911 - val_accuracy: 0.7384
# Epoch 11/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5824 - accuracy: 0.6990 - val_loss: 0.5555 - val_accuracy: 0.7104
# Epoch 12/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5765 - accuracy: 0.7096 - val_loss: 0.5953 - val_accuracy: 0.6769
# Epoch 13/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5966 - accuracy: 0.6860 - val_loss: 0.5628 - val_accuracy: 0.7419
# Epoch 00013: early stopping
# Fold 3, 200 epochs, 50 sec
# accuracy: 75.53%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.7032 - accuracy: 0.5853 - val_loss: 0.6803 - val_accuracy: 0.5873
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.4.best/assets
# Epoch 2/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.6117 - accuracy: 0.6758 - val_loss: 0.5781 - val_accuracy: 0.7470
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.4.best/assets
# Epoch 3/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.6003 - accuracy: 0.6897 - val_loss: 0.5510 - val_accuracy: 0.7266
# Epoch 4/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5763 - accuracy: 0.7095 - val_loss: 0.5299 - val_accuracy: 0.7452
# Epoch 5/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5658 - accuracy: 0.7103 - val_loss: 0.6144 - val_accuracy: 0.6770
# Epoch 6/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5448 - accuracy: 0.7328 - val_loss: 0.5535 - val_accuracy: 0.7326
# Epoch 7/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5315 - accuracy: 0.7431 - val_loss: 0.4515 - val_accuracy: 0.8040
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.4.best/assets
# Epoch 8/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.4832 - accuracy: 0.7739 - val_loss: 0.4638 - val_accuracy: 0.7888
# Epoch 9/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.4708 - accuracy: 0.7868 - val_loss: 0.4287 - val_accuracy: 0.8156
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.4.best/assets
# Epoch 10/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.4383 - accuracy: 0.7969 - val_loss: 0.5336 - val_accuracy: 0.7613
# Epoch 11/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.3886 - accuracy: 0.8290 - val_loss: 0.4020 - val_accuracy: 0.8310
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.4.best/assets
# Epoch 12/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.3523 - accuracy: 0.8472 - val_loss: 0.4746 - val_accuracy: 0.7941
# Epoch 13/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.3185 - accuracy: 0.8649 - val_loss: 0.4491 - val_accuracy: 0.8222
# Epoch 14/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.2995 - accuracy: 0.8744 - val_loss: 0.4411 - val_accuracy: 0.8191
# Epoch 15/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.2465 - accuracy: 0.8996 - val_loss: 0.5192 - val_accuracy: 0.8023
# Epoch 16/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.2525 - accuracy: 0.8964 - val_loss: 0.4953 - val_accuracy: 0.8195
# Epoch 17/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.2130 - accuracy: 0.9169 - val_loss: 0.5705 - val_accuracy: 0.8001
# Epoch 18/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.2000 - accuracy: 0.9212 - val_loss: 0.4786 - val_accuracy: 0.8336
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.4.best/assets
# Epoch 19/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.1642 - accuracy: 0.9398 - val_loss: 0.4926 - val_accuracy: 0.8382
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.4.best/assets
# Epoch 20/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.1443 - accuracy: 0.9459 - val_loss: 0.4884 - val_accuracy: 0.8443
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.4.best/assets
# Epoch 21/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.1466 - accuracy: 0.9428 - val_loss: 0.4438 - val_accuracy: 0.8571
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.4.best/assets
# Epoch 00021: early stopping
# Fold 4, 200 epochs, 81 sec
# accuracy: 85.71%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.7852 - accuracy: 0.5511 - val_loss: 0.6113 - val_accuracy: 0.6829
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.5.best/assets
# Epoch 2/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.6434 - accuracy: 0.6448 - val_loss: 0.6655 - val_accuracy: 0.7087
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.5.best/assets
# Epoch 3/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.6527 - accuracy: 0.6302 - val_loss: 0.6574 - val_accuracy: 0.6847
# Epoch 4/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.6045 - accuracy: 0.6824 - val_loss: 0.5764 - val_accuracy: 0.7173
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.5.best/assets
# Epoch 5/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5877 - accuracy: 0.6957 - val_loss: 0.6159 - val_accuracy: 0.6797
# Epoch 6/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.6189 - accuracy: 0.6646 - val_loss: 0.5575 - val_accuracy: 0.7430
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.5.best/assets
# Epoch 7/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5914 - accuracy: 0.6866 - val_loss: 0.6145 - val_accuracy: 0.6816
# Epoch 8/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5927 - accuracy: 0.6950 - val_loss: 0.5977 - val_accuracy: 0.7152
# Epoch 9/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.5928 - accuracy: 0.6857 - val_loss: 0.5745 - val_accuracy: 0.7039
# Epoch 10/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.5913 - accuracy: 0.6868 - val_loss: 0.5977 - val_accuracy: 0.6838
# Epoch 11/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.5955 - accuracy: 0.6801 - val_loss: 0.5708 - val_accuracy: 0.7309
# Epoch 12/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.6105 - accuracy: 0.6713 - val_loss: 0.5848 - val_accuracy: 0.7315
# Epoch 13/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.6189 - accuracy: 0.6719 - val_loss: 0.5750 - val_accuracy: 0.7360
# Epoch 14/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.6286 - accuracy: 0.6502 - val_loss: 0.6199 - val_accuracy: 0.6171
# Epoch 15/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5826 - accuracy: 0.7061 - val_loss: 0.6268 - val_accuracy: 0.6288
# Epoch 16/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5654 - accuracy: 0.7160 - val_loss: 0.5428 - val_accuracy: 0.7466
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.5.best/assets
# Epoch 17/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.6030 - accuracy: 0.6832 - val_loss: 0.6002 - val_accuracy: 0.6823
# Epoch 18/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.6014 - accuracy: 0.6826 - val_loss: 0.5946 - val_accuracy: 0.6992
# Epoch 19/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5864 - accuracy: 0.7064 - val_loss: 0.6206 - val_accuracy: 0.6646
# Epoch 20/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5779 - accuracy: 0.7025 - val_loss: 0.5769 - val_accuracy: 0.7146
# Epoch 21/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5952 - accuracy: 0.6877 - val_loss: 0.5362 - val_accuracy: 0.7408
# Epoch 22/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5843 - accuracy: 0.7034 - val_loss: 0.5790 - val_accuracy: 0.7026
# Epoch 23/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5563 - accuracy: 0.7276 - val_loss: 0.5412 - val_accuracy: 0.7505
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.5.best/assets
# Epoch 24/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5579 - accuracy: 0.7226 - val_loss: 0.6509 - val_accuracy: 0.6563
# Epoch 25/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5572 - accuracy: 0.7181 - val_loss: 0.5649 - val_accuracy: 0.7420
# Epoch 26/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5596 - accuracy: 0.7167 - val_loss: 0.5656 - val_accuracy: 0.7066
# Epoch 27/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5597 - accuracy: 0.7119 - val_loss: 0.6012 - val_accuracy: 0.6853
# Epoch 28/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5745 - accuracy: 0.7021 - val_loss: 0.6471 - val_accuracy: 0.6619
# Epoch 29/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5620 - accuracy: 0.7232 - val_loss: 0.5407 - val_accuracy: 0.7601
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.5.best/assets
# Epoch 30/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5487 - accuracy: 0.7315 - val_loss: 0.5348 - val_accuracy: 0.7613
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.5.best/assets
# Epoch 31/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5570 - accuracy: 0.7233 - val_loss: 0.5723 - val_accuracy: 0.7374
# Epoch 32/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5413 - accuracy: 0.7381 - val_loss: 0.5248 - val_accuracy: 0.7635
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.5.best/assets
# Epoch 33/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5664 - accuracy: 0.7184 - val_loss: 0.5607 - val_accuracy: 0.7248
# Epoch 34/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5525 - accuracy: 0.7229 - val_loss: 0.5515 - val_accuracy: 0.7350
# Epoch 35/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5576 - accuracy: 0.7194 - val_loss: 0.5660 - val_accuracy: 0.7726
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.5.best/assets
# Epoch 36/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5750 - accuracy: 0.7189 - val_loss: 0.5518 - val_accuracy: 0.7595
# Epoch 37/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5623 - accuracy: 0.7131 - val_loss: 0.5190 - val_accuracy: 0.7479
# Epoch 38/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5454 - accuracy: 0.7338 - val_loss: 0.5448 - val_accuracy: 0.7515
# Epoch 39/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5412 - accuracy: 0.7339 - val_loss: 0.5394 - val_accuracy: 0.7661
# Epoch 40/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5350 - accuracy: 0.7381 - val_loss: 0.4935 - val_accuracy: 0.7774
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.5.best/assets
# Epoch 41/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5436 - accuracy: 0.7310 - val_loss: 0.5195 - val_accuracy: 0.7579
# Epoch 42/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.5349 - accuracy: 0.7401 - val_loss: 0.6108 - val_accuracy: 0.7115
# Epoch 43/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5364 - accuracy: 0.7409 - val_loss: 0.5506 - val_accuracy: 0.7671
# Epoch 44/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5318 - accuracy: 0.7456 - val_loss: 0.5197 - val_accuracy: 0.7635
# Epoch 45/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5330 - accuracy: 0.7401 - val_loss: 0.6264 - val_accuracy: 0.7018
# Epoch 46/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5242 - accuracy: 0.7485 - val_loss: 0.5211 - val_accuracy: 0.7437
# Epoch 47/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5344 - accuracy: 0.7381 - val_loss: 0.4951 - val_accuracy: 0.7793
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/JUNK2.cv.5.best/assets
# Epoch 48/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5201 - accuracy: 0.7468 - val_loss: 0.5004 - val_accuracy: 0.7713
# Epoch 49/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5483 - accuracy: 0.7272 - val_loss: 0.6407 - val_accuracy: 0.6109
# Epoch 50/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5313 - accuracy: 0.7374 - val_loss: 0.5100 - val_accuracy: 0.7708
# Epoch 00050: early stopping
# Fold 5, 200 epochs, 182 sec
# accuracy: 77.93%
#
# 5-way Cross Validation max 86.64%, mean 82.32% (+/- 4.63%)
# Done
