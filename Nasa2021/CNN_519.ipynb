# %% [markdown]
# <a href="https://colab.research.google.com/github/ShepherdCode/ShepherdML/blob/master/Nasa2021/CNN_519.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CNN 519
#
# Three layers of CNNS and MaxPooling

# %%
#NC_FILENAME='ncRNA.tiny50.fasta'
#PC_FILENAME='pcRNA.tiny50.fasta'
#NC_FILENAME='ncRNA.gc34.processed.fasta'
#PC_FILENAME='pcRNA.gc34.processed.fasta'
NC_FILENAME='ncRNA.gc36.balance.fasta'
PC_FILENAME='pcRNA.gc36.balance.fasta'

MODEL_FILE='CNN519' 
DATAPATH=''

try:
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
except:
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"
NC_FILENAME = DATAPATH+NC_FILENAME
PC_FILENAME = DATAPATH+PC_FILENAME
MODEL_FILE=DATAPATH+MODEL_FILE

EPOCHS=20
SPLITS=5
K=1
VOCABULARY_SIZE=4**K+1   # e.g. K=3 => 64 DNA K-mers + 'NNN'
EMBED_DIMEN=2
FILTERS=32
KERNEL=3
NEURONS=16
DROP=0.2
MINLEN=200
MAXLEN=2000
DENSE_LEN = 1000
ACT="tanh"
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# Load our own tools
# TO DO: don't go to GitHub if the file is already local.
GITHUB = True
if GITHUB:
    #!pip install requests  # Uncomment this if necessary. Seems to be pre-installed.
    import requests
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/ShepherdML/master/Strings/tools_fasta.py')
    with open('tools_fasta.py', 'w') as f:
        f.write(r.text)
    # TO DO: delete the file after import
import tools_fasta as tools
tools.yahoo()  # If this prints "Yahoo!" the the import was successful.

TOOLS_CHANGED = False   # set to True to re-run with a new version of tools
if TOOLS_CHANGED:
  from importlib import reload 
  tools=reload(tools)
  print(dir(tools))   # run this to see EVERYTHING in the tools module
# Out:
# Yahoo!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import StratifiedKFold
import tensorflow as tf
from tensorflow import keras
import time
dt='float32'
tf.keras.backend.set_floatx(dt)

# %% [markdown]
# Build model

# %%
def compile_model(model):
    ## learn rate = initial_learning_rate * decay_rate ^ (step / decay_steps)
    #adam_default_learn_rate = 0.001
    #schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    #    initial_learning_rate = adam_default_learn_rate*10,
    #    decay_steps=10000, decay_rate=0.99, staircase=True)
    #alrd = tf.keras.optimizers.Adam(learning_rate=schedule)
    #model.compile(loss=bc, optimizer=alrd, metrics=["accuracy"])

    print("COMPILE...")
    bc=tf.keras.losses.BinaryCrossentropy(from_logits=False)
    model.compile(loss=bc, optimizer="adam", metrics=["accuracy"])
    print("...COMPILED")
    return model

def build_model():
    SHAPE=(MAXLEN,5)  # 2000 time steps, 5 features
    clayer1 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same",
                                 input_shape=SHAPE)
    clayer2 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer3 = keras.layers.MaxPooling1D(2)
    clayer4 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer5 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer6 = keras.layers.MaxPooling1D(2)
    clayer8 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer9 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer10 = keras.layers.MaxPooling1D(2)

    clayer7 = keras.layers.Flatten()

    dlayer1 = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt, input_shape=[DENSE_LEN])
    dlayer2 = keras.layers.Dropout(DROP)
    dlayer3 = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt)
    dlayer4 = keras.layers.Dropout(DROP)
    output_layer = keras.layers.Dense(1, activation="sigmoid", dtype=dt)

    cnn = keras.models.Sequential()
    cnn.add(clayer1)
    cnn.add(clayer2)
    cnn.add(clayer3)
    cnn.add(clayer4)
    cnn.add(clayer5)
    cnn.add(clayer6)
    cnn.add(clayer8)
    cnn.add(clayer9)
    cnn.add(clayer10)
    cnn.add(clayer7)
    cnn.add(dlayer1)
    cnn.add(dlayer2)
    cnn.add(dlayer3)
    cnn.add(dlayer4)
    cnn.add(output_layer)
    mlpc = compile_model(cnn)
    return mlpc

# %% [markdown]
# Cross validation

# %%
def do_cross_validation(X,y,given_model):
    cv_scores = []
    fold=0
    splitter = ShuffleSplit(n_splits=SPLITS, test_size=0.1, random_state=37863)
    for train_index,valid_index in splitter.split(X):
        fold += 1
        X_train=X[train_index] # use iloc[] for dataframe
        y_train=y[train_index]
        X_valid=X[valid_index]
        y_valid=y[valid_index]        
        # Avoid continually improving the same model.
        model = compile_model(keras.models.clone_model(given_model))
        bestname=MODEL_FILE+".cv."+str(fold)+".best"
        mycallbacks = [keras.callbacks.ModelCheckpoint(
            filepath=bestname, save_best_only=True, 
            monitor='val_accuracy', mode='max')]   
        print("FIT")
        start_time=time.time()
        history=model.fit(X_train, y_train, # batch_size=10, default=32 works nicely
                epochs=EPOCHS, verbose=1,  # verbose=1 for ascii art, verbose=0 for none
                callbacks=mycallbacks,
                validation_data=(X_valid,y_valid) )
        end_time=time.time()
        elapsed_time=(end_time-start_time)                        
        print("Fold %d, %d epochs, %d sec"%(fold,EPOCHS,elapsed_time))
        pd.DataFrame(history.history).plot(figsize=(8,5))
        plt.grid(True)
        plt.gca().set_ylim(0,1)
        plt.show()
        best_model=keras.models.load_model(bestname)
        scores = best_model.evaluate(X_valid, y_valid, verbose=0)
        print("%s: %.2f%%" % (best_model.metrics_names[1], scores[1]*100))
        cv_scores.append(scores[1] * 100)  
    print()
    print("%d-way Cross Validation mean %.2f%% (+/- %.2f%%)" % (fold, np.mean(cv_scores), np.std(cv_scores)))

# %% [markdown]
# ## Train on RNA lengths 200-1Kb

# %%
print ("Compile the model")
model=build_model()
print ("Summarize the model")
print(model.summary())  # Print this only once
#model.save(MODEL_FILE+'.model')
# Out:
# Compile the model
# COMPILE...
# ...COMPILED
# Summarize the model
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 2000, 32)          512
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 2000, 32)          3104
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 1000, 32)          0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 1000, 32)          3104
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 1000, 32)          3104
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 500, 32)           0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 500, 32)           3104
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 500, 32)           3104
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 250, 32)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 8000)              0
# _________________________________________________________________
# dense (Dense)                (None, 16)                128016
# _________________________________________________________________
# dropout (Dropout)            (None, 16)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                272
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 144,337
# Trainable params: 144,337
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#MINLEN=200
#MAXLEN=2000
print("Load data from files.")
nc_seq=tools.load_fasta(NC_FILENAME,0)
pc_seq=tools.load_fasta(PC_FILENAME,1)
train_set=pd.concat((nc_seq,pc_seq),axis=0)
nc_seq=None
pc_seq=None
print("Ready: train_set")
#train_set
subset=tools.make_slice(train_set,MINLEN,MAXLEN)# One array to two: X and y
(X1,y_train)=tools.separate_X_and_y(subset)
# X1 is pandas df of ("list" of one sequence)
X2=X1.to_numpy()  # numpy ndarray of ("list" of one sequence)
X3=[elem[0] for elem in X2]  # numpy dnarray of str
X4=tools.uniform_length(X3,MAXLEN)
X5= [tools.one_hot(x) for x in X4]
X_train=np.asarray(X5)
y_train=y_train.to_numpy()

subset=None
X1=None
X2=None
X3=None
X4=None
X5=None
# Out:
# Load data from files.
# Ready: train_set

# %%
print ("Cross validation")
do_cross_validation(X_train,y_train,model)  
print ("Done")
# Out:
# Cross validation
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/20
# 1000/1000 [==============================] - 8s 6ms/step - loss: 0.6462 - accuracy: 0.6373 - val_loss: 0.5939 - val_accuracy: 0.6958
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN519.cv.1.best/assets
# Epoch 2/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6010 - accuracy: 0.6895 - val_loss: 0.5898 - val_accuracy: 0.6758
# Epoch 3/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.6000 - accuracy: 0.6878 - val_loss: 0.5587 - val_accuracy: 0.7191
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN519.cv.1.best/assets
# Epoch 4/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5747 - accuracy: 0.7122 - val_loss: 0.5553 - val_accuracy: 0.7245
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN519.cv.1.best/assets
# Epoch 5/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5752 - accuracy: 0.7077 - val_loss: 0.5850 - val_accuracy: 0.6941
# Epoch 6/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5734 - accuracy: 0.7114 - val_loss: 0.5801 - val_accuracy: 0.6927
# Epoch 7/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5722 - accuracy: 0.7140 - val_loss: 0.5979 - val_accuracy: 0.7090
# Epoch 8/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5614 - accuracy: 0.7216 - val_loss: 0.5604 - val_accuracy: 0.7157
# Epoch 9/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5609 - accuracy: 0.7200 - val_loss: 0.5564 - val_accuracy: 0.7360
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN519.cv.1.best/assets
# Epoch 10/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5518 - accuracy: 0.7291 - val_loss: 0.5325 - val_accuracy: 0.7498
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN519.cv.1.best/assets
# Epoch 11/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5600 - accuracy: 0.7198 - val_loss: 0.5343 - val_accuracy: 0.7360
# Epoch 12/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5416 - accuracy: 0.7382 - val_loss: 0.5482 - val_accuracy: 0.7363
# Epoch 13/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5364 - accuracy: 0.7470 - val_loss: 0.5329 - val_accuracy: 0.7551
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN519.cv.1.best/assets
# Epoch 14/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5347 - accuracy: 0.7400 - val_loss: 0.5222 - val_accuracy: 0.7225
# Epoch 15/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5443 - accuracy: 0.7337 - val_loss: 0.5222 - val_accuracy: 0.7501
# Epoch 16/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5312 - accuracy: 0.7461 - val_loss: 0.5622 - val_accuracy: 0.7287
# Epoch 17/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5277 - accuracy: 0.7443 - val_loss: 0.5616 - val_accuracy: 0.7380
# Epoch 18/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5135 - accuracy: 0.7622 - val_loss: 0.5115 - val_accuracy: 0.7461
# Epoch 19/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5899 - accuracy: 0.7034 - val_loss: 0.4954 - val_accuracy: 0.7712
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN519.cv.1.best/assets
# Epoch 20/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5288 - accuracy: 0.7506 - val_loss: 0.5025 - val_accuracy: 0.7644
# Fold 1, 20 epochs, 126 sec
# accuracy: 77.12%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/20
# 1000/1000 [==============================] - 7s 6ms/step - loss: 0.5938 - accuracy: 0.6903 - val_loss: 0.4546 - val_accuracy: 0.7948
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN519.cv.2.best/assets
# Epoch 2/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.4703 - accuracy: 0.7801 - val_loss: 0.5237 - val_accuracy: 0.7484
# Epoch 3/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.4096 - accuracy: 0.8195 - val_loss: 0.3774 - val_accuracy: 0.8370
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN519.cv.2.best/assets
# Epoch 4/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.3590 - accuracy: 0.8467 - val_loss: 0.5404 - val_accuracy: 0.7456
# Epoch 5/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.3453 - accuracy: 0.8525 - val_loss: 0.3682 - val_accuracy: 0.8520
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN519.cv.2.best/assets
# Epoch 6/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.3229 - accuracy: 0.8681 - val_loss: 0.3516 - val_accuracy: 0.8567
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN519.cv.2.best/assets
# Epoch 7/20
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.2953 - accuracy: 0.8809 - val_loss: 0.3972 - val_accuracy: 0.8314
# Epoch 8/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.2595 - accuracy: 0.8991 - val_loss: 0.4266 - val_accuracy: 0.8255
# Epoch 9/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.2630 - accuracy: 0.8951 - val_loss: 0.3695 - val_accuracy: 0.8508
# Epoch 10/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.2432 - accuracy: 0.9058 - val_loss: 0.3781 - val_accuracy: 0.8522
# Epoch 11/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.2355 - accuracy: 0.9082 - val_loss: 0.3697 - val_accuracy: 0.8508
# Epoch 12/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.2238 - accuracy: 0.9140 - val_loss: 0.3796 - val_accuracy: 0.8542
# Epoch 13/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.2147 - accuracy: 0.9187 - val_loss: 0.3854 - val_accuracy: 0.8584
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN519.cv.2.best/assets
# Epoch 14/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.2019 - accuracy: 0.9259 - val_loss: 0.3764 - val_accuracy: 0.8548
# Epoch 15/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.2034 - accuracy: 0.9231 - val_loss: 0.4180 - val_accuracy: 0.8475
# Epoch 16/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.1978 - accuracy: 0.9233 - val_loss: 0.3918 - val_accuracy: 0.8514
# Epoch 17/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.1927 - accuracy: 0.9263 - val_loss: 0.3837 - val_accuracy: 0.8508
# Epoch 18/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.1779 - accuracy: 0.9336 - val_loss: 0.4433 - val_accuracy: 0.8446
# Epoch 19/20
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.1868 - accuracy: 0.9285 - val_loss: 0.3975 - val_accuracy: 0.8503
# Epoch 20/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.1773 - accuracy: 0.9346 - val_loss: 0.3980 - val_accuracy: 0.8576
# Fold 2, 20 epochs, 133 sec
# accuracy: 85.84%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/20
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.6082 - accuracy: 0.6796 - val_loss: 0.5675 - val_accuracy: 0.7228
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN519.cv.3.best/assets
# Epoch 2/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5316 - accuracy: 0.7415 - val_loss: 0.4292 - val_accuracy: 0.8109
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN519.cv.3.best/assets
# Epoch 3/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.4430 - accuracy: 0.8011 - val_loss: 0.3866 - val_accuracy: 0.8342
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN519.cv.3.best/assets
# Epoch
20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5383 - accuracy: 0.7429 - val_loss: 0.5082 - val_accuracy: 0.7630
# Epoch 15/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5345 - accuracy: 0.7460 - val_loss: 0.5120 - val_accuracy: 0.7779
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN519.cv.4.best/assets
# Epoch 16/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5358 - accuracy: 0.7398 - val_loss: 0.5153 - val_accuracy: 0.7613
# Epoch 17/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5431 - accuracy: 0.7366 - val_loss: 0.5481 - val_accuracy: 0.7166
# Epoch 18/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5300 - accuracy: 0.7478 - val_loss: 0.4851 - val_accuracy: 0.7793
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN519.cv.4.best/assets
# Epoch 19/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5255 - accuracy: 0.7477 - val_loss: 0.4855 - val_accuracy: 0.7838
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN519.cv.4.best/assets
# Epoch 20/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5259 - accuracy: 0.7552 - val_loss: 0.4923 - val_accuracy: 0.7785
# Fold 4, 20 epochs, 143 sec
# accuracy: 78.38%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/20
# 1000/1000 [==============================] - 7s 6ms/step - loss: 0.6255 - accuracy: 0.6663 - val_loss: 0.5220 - val_accuracy: 0.7475
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN519.cv.5.best/assets
# Epoch 2/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.5182 - accuracy: 0.7542 - val_loss: 0.4251 - val_accuracy: 0.8055
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN519.cv.5.best/assets
# Epoch 3/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.4169 - accuracy: 0.8176 - val_loss: 0.3857 - val_accuracy: 0.8308
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN519.cv.5.best/assets
# Epoch 4/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.3750 - accuracy: 0.8424 - val_loss: 0.3735 - val_accuracy: 0.8387
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN519.cv.5.best/assets
# Epoch 5/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.3466 - accuracy: 0.8552 - val_loss: 0.3605 - val_accuracy: 0.8449
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN519.cv.5.best/assets
# Epoch 6/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.3195 - accuracy: 0.8717 - val_loss: 0.3825 - val_accuracy: 0.8263
# Epoch 7/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.3014 - accuracy: 0.8791 - val_loss: 0.3765 - val_accuracy: 0.8421
# Epoch 8/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.2823 - accuracy: 0.8884 - val_loss: 0.3745 - val_accuracy: 0.8384
# Epoch 9/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.2645 - accuracy: 0.8964 - val_loss: 0.3641 - val_accuracy: 0.8460
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN519.cv.5.best/assets
# Epoch 10/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.2522 - accuracy: 0.9012 - val_loss: 0.3688 - val_accuracy: 0.8480
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN519.cv.5.best/assets
# Epoch 11/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.2370 - accuracy: 0.9072 - val_loss: 0.3979 - val_accuracy: 0.8325
# Epoch 12/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.2311 - accuracy: 0.9110 - val_loss: 0.3870 - val_accuracy: 0.8432
# Epoch 13/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.2311 - accuracy: 0.9112 - val_loss: 0.3870 - val_accuracy: 0.8435
# Epoch 14/20
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.2178 - accuracy: 0.9168 - val_loss: 0.4011 - val_accuracy: 0.8441
# Epoch 15/20
# 1000/1000 [==============================] - 7s 7ms/step - loss: 0.2099 - accuracy: 0.9192 - val_loss: 0.4162 - val_accuracy: 0.8323
# Epoch 16/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.2012 - accuracy: 0.9202 - val_loss: 0.4194 - val_accuracy: 0.8399
# Epoch 17/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.1982 - accuracy: 0.9278 - val_loss: 0.4231 - val_accuracy: 0.8404
# Epoch 18/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.1982 - accuracy: 0.9227 - val_loss: 0.4145 - val_accuracy: 0.8384
# Epoch 19/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.1976 - accuracy: 0.9239 - val_loss: 0.4261 - val_accuracy: 0.8382
# Epoch 20/20
# 1000/1000 [==============================] - 6s 6ms/step - loss: 0.1922 - accuracy: 0.9269 - val_loss: 0.4437 - val_accuracy: 0.8345
# Fold 5, 20 epochs, 136 sec
# accuracy: 84.80%
#
# 5-way Cross Validation mean 82.58% (+/- 4.01%)
# Done
