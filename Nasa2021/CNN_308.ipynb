# %% [markdown]
# # CNN 308
# Start with CNN 307 which overfits most of the time but uses early stopping. Here, rather than partition train/validation sets, use different sets such as long/short.

# %%
TRAIN_NC_FILENAME='ncRNA.gc36.long.fasta'
TRAIN_PC_FILENAME='pcRNA.gc36.long.fasta'
VALID_NC_FILENAME='ncRNA.gc36.short.fasta'
VALID_PC_FILENAME='pcRNA.gc36.short.fasta'
#NC_FILENAME='ncRNA.tiny50.fasta'
#PC_FILENAME='pcRNA.tiny50.fasta'
#NC_FILENAME='ncRNA.gc34.processed.fasta'
#PC_FILENAME='pcRNA.gc34.processed.fasta'

MODEL_FILE='CNN308'  
DATAPATH=''

try:
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
except:
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"
TRAIN_NC_FILENAME = DATAPATH+TRAIN_NC_FILENAME
TRAIN_PC_FILENAME = DATAPATH+TRAIN_PC_FILENAME
VALID_NC_FILENAME = DATAPATH+VALID_NC_FILENAME
VALID_PC_FILENAME = DATAPATH+VALID_PC_FILENAME
MODEL_FILE=DATAPATH+MODEL_FILE

EPOCHS=200
SPLITS=5
K=1
VOCABULARY_SIZE=4**K+1   # e.g. K=3 => 64 DNA K-mers + 'NNN'
EMBED_DIMEN=2
FILTERS=32
KERNEL=3
NEURONS=32
DROP=0.25
ACT="tanh"
MINLEN=201
MAXLEN=2000
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# Load our own tools
# TO DO: don't go to GitHub if the file is already local.
GITHUB = True
if GITHUB:
    #!pip install requests  # Uncomment this if necessary. Seems to be pre-installed.
    import requests
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/ShepherdML/master/Strings/tools_fasta.py')
    with open('tools_fasta.py', 'w') as f:
        f.write(r.text)
    # TO DO: delete the file after import
import tools_fasta as tools
tools.yahoo()  # If this prints "Yahoo!" the the import was successful.

TOOLS_CHANGED = False   # set to True to re-run with a new version of tools
if TOOLS_CHANGED:
  from importlib import reload 
  tools=reload(tools)
  print(dir(tools))   # run this to see EVERYTHING in the tools module
# Out:
# Yahoo!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import StratifiedKFold
import tensorflow as tf
from tensorflow import keras
import time
dt='float32'
tf.keras.backend.set_floatx(dt)

# %% [markdown]
# Build model

# %%
def compile_model(model):
    ## learn rate = initial_learning_rate * decay_rate ^ (step / decay_steps)
    #adam_default_learn_rate = 0.001
    #schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    #    initial_learning_rate = adam_default_learn_rate*10,
    #    decay_steps=10000, decay_rate=0.99, staircase=True)
    #alrd = tf.keras.optimizers.Adam(learning_rate=schedule)
    #model.compile(loss=bc, optimizer=alrd, metrics=["accuracy"])

    print("COMPILE...")
    bc=tf.keras.losses.BinaryCrossentropy(from_logits=False)
    model.compile(loss=bc, optimizer="adam", metrics=["accuracy"])
    print("...COMPILED")
    return model

def build_model():
    SHAPE=(MAXLEN,5)  # MAXLEN bases = time steps, 5 features = one hots
    clayer1 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same",
                                 input_shape=SHAPE)
    clayer2 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer3 = keras.layers.MaxPooling1D(2)
    clayer4 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer5 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer6 = keras.layers.MaxPooling1D(2)
    clayer7 = keras.layers.Flatten()

    dlayer1 = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt, input_shape=[1000])
    dlayer2 = keras.layers.Dropout(DROP)
    dlayer3 = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt)
    dlayer4 = keras.layers.Dropout(DROP)
    output_layer = keras.layers.Dense(1, activation="sigmoid", dtype=dt)

    cnn = keras.models.Sequential()
    cnn.add(clayer1)
    cnn.add(clayer2)
    cnn.add(clayer3)
    cnn.add(clayer4)
    cnn.add(clayer5)
    cnn.add(clayer6)
    cnn.add(clayer7)
    cnn.add(dlayer1)
    cnn.add(dlayer2)
    cnn.add(dlayer3)
    cnn.add(dlayer4)
    cnn.add(output_layer)
    mlpc = compile_model(cnn)
    return mlpc

# %% [markdown]
# Cross validation

# %%
def do_cross_validation(X_train,y_train,given_model,X_valid,y_valid):
    cv_scores = []
    fold=1
    # Problem: train set needs to be randomized
    #splitter = ShuffleSplit(n_splits=SPLITS, test_size=0.1, random_state=37863)
    #for train_index,valid_index in splitter.split(X):
    while fold <= SPLITS:
        # Avoid continually improving the same model.
        model = compile_model(keras.models.clone_model(given_model))
        bestname=MODEL_FILE+".cv."+str(fold)+".best"
        es = keras.callbacks.EarlyStopping(monitor='loss',  
            patience=5, verbose=1)
        mc = keras.callbacks.ModelCheckpoint(
            filepath=bestname, save_best_only=True, 
            monitor='val_accuracy', mode='max')  
        mycallbacks = [es,mc]  
        print("FIT")
        start_time=time.time()
        history=model.fit(X_train, y_train, # batch_size=10, default=32 works nicely
                epochs=EPOCHS, verbose=1,  # verbose=1 for ascii art, verbose=0 for none
                callbacks=mycallbacks,
                validation_data=(X_valid,y_valid) )
        end_time=time.time()
        elapsed_time=(end_time-start_time)                        
        print("Fold %d, %d epochs, %d sec"%(fold,EPOCHS,elapsed_time))
        pd.DataFrame(history.history).plot(figsize=(8,5))
        plt.grid(True)
        plt.gca().set_ylim(0,1)
        plt.show()
        best_model=keras.models.load_model(bestname)
        scores = best_model.evaluate(X_valid, y_valid, verbose=0)
        print("%s: %.2f%%" % (best_model.metrics_names[1], scores[1]*100))
        cv_scores.append(scores[1] * 100)  
        fold += 1

    print()
    print("%d-way Cross Validation mean %.2f%% (+/- %.2f%%)" % (fold, np.mean(cv_scores), np.std(cv_scores)))

# %% [markdown]
# ## Train on RNA lengths 200-1Kb

# %%
print ("Compile the model")
model=build_model()
print ("Summarize the model")
print(model.summary())  # Print this only once
#model.save(MODEL_FILE+'.model')
# Out:
# Compile the model
# COMPILE...
# ...COMPILED
# Summarize the model
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_36 (Conv1D)           (None, 2000, 32)          512
# _________________________________________________________________
# conv1d_37 (Conv1D)           (None, 2000, 32)          3104
# _________________________________________________________________
# max_pooling1d_18 (MaxPooling (None, 1000, 32)          0
# _________________________________________________________________
# conv1d_38 (Conv1D)           (None, 1000, 32)          3104
# _________________________________________________________________
# conv1d_39 (Conv1D)           (None, 1000, 32)          3104
# _________________________________________________________________
# max_pooling1d_19 (MaxPooling (None, 500, 32)           0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 16000)             0
# _________________________________________________________________
# dense_27 (Dense)             (None, 32)                512032
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_28 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_29 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 522,945
# Trainable params: 522,945
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
def load_data(nc_filename,pc_filename):
  nc_seq=tools.load_fasta(nc_filename,0)
  pc_seq=tools.load_fasta(pc_filename,1)
  train_set=pd.concat((nc_seq,pc_seq),axis=0)
  nc_seq=None
  pc_seq=None
  # May not need make_slide here
  subset=tools.make_slice(train_set,MINLEN,MAXLEN)
  (X1,y1)=tools.separate_X_and_y(subset)
  # X1 is pandas df of ("list" of one sequence)
  X2=X1.to_numpy()  # numpy ndarray of ("list" of one sequence)
  X3=[elem[0] for elem in X2]  # numpy dnarray of str
  X4=tools.uniform_length(X3,MAXLEN)
  X5= [tools.one_hot(x) for x in X4]
  X6=np.asarray(X5)
  y6=y1.to_numpy()
  return X6,y6

print("Load train data from files.")
X_train,y_train = load_data(TRAIN_NC_FILENAME,TRAIN_PC_FILENAME)
print("Load valid data from files.")
X_valid,y_valid = load_data(VALID_NC_FILENAME,VALID_PC_FILENAME)
print("Data loaded from files.")
# Out:
# Load train data from files.
# Load valid data from files.
# Data loaded from files.

# %%
print ("Cross valiation")
do_cross_validation(X_train,y_train,model,X_valid,y_valid)  
print ("Done")
# Out:
# Cross valiation
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/200
# 350/350 [==============================] - 4s 9ms/step - loss: 0.6481 - accuracy: 0.6680 - val_loss: 0.7241 - val_accuracy: 0.5880
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.1.best/assets
# Epoch 2/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.6089 - accuracy: 0.6910 - val_loss: 0.7134 - val_accuracy: 0.5943
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.1.best/assets
# Epoch 3/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5955 - accuracy: 0.6987 - val_loss: 0.6721 - val_accuracy: 0.5883
# Epoch 4/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5984 - accuracy: 0.6852 - val_loss: 0.6992 - val_accuracy: 0.5954
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.1.best/assets
# Epoch 5/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5780 - accuracy: 0.7047 - val_loss: 0.7323 - val_accuracy: 0.6121
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.1.best/assets
# Epoch 6/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5702 - accuracy: 0.7199 - val_loss: 0.6826 - val_accuracy: 0.6110
# Epoch 7/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5692 - accuracy: 0.7170 - val_loss: 0.6930 - val_accuracy: 0.5957
# Epoch 8/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5701 - accuracy: 0.7071 - val_loss: 0.7217 - val_accuracy: 0.5742
# Epoch 9/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5705 - accuracy: 0.7103 - val_loss: 0.6627 - val_accuracy: 0.6500
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.1.best/assets
# Epoch 10/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5578 - accuracy: 0.7146 - val_loss: 0.6973 - val_accuracy: 0.6126
# Epoch 11/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5475 - accuracy: 0.7300 - val_loss: 0.6790 - val_accuracy: 0.5976
# Epoch 12/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.
200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.3903 - accuracy: 0.8241 - val_loss: 0.5351 - val_accuracy: 0.7707
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.4.best/assets
# Epoch 15/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.3524 - accuracy: 0.8487 - val_loss: 0.4773 - val_accuracy: 0.7877
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.4.best/assets
# Epoch 16/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.3279 - accuracy: 0.8580 - val_loss: 0.4919 - val_accuracy: 0.7919
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.4.best/assets
# Epoch 17/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.2913 - accuracy: 0.8795 - val_loss: 0.4933 - val_accuracy: 0.7981
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.4.best/assets
# Epoch 18/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.2813 - accuracy: 0.8834 - val_loss: 0.5203 - val_accuracy: 0.8032
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.4.best/assets
# Epoch 19/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.2621 - accuracy: 0.8899 - val_loss: 0.5520 - val_accuracy: 0.7902
# Epoch 20/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.2311 - accuracy: 0.9056 - val_loss: 0.5470 - val_accuracy: 0.8015
# Epoch 21/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.1991 - accuracy: 0.9226 - val_loss: 0.5265 - val_accuracy: 0.8081
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.4.best/assets
# Epoch 22/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.1945 - accuracy: 0.9218 - val_loss: 0.5173 - val_accuracy: 0.8051
# Epoch 23/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.1804 - accuracy: 0.9290 - val_loss: 0.6884 - val_accuracy: 0.7817
# Epoch 24/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.1624 - accuracy: 0.9373 - val_loss: 0.6365 - val_accuracy: 0.8065
# Epoch 25/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.1539 - accuracy: 0.9401 - val_loss: 0.6277 - val_accuracy: 0.8035
# Epoch 26/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.1363 - accuracy: 0.9497 - val_loss: 0.5849 - val_accuracy: 0.8209
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.4.best/assets
# Epoch 27/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.1484 - accuracy: 0.9445 - val_loss: 0.5834 - val_accuracy: 0.8253
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.4.best/assets
# Epoch 28/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.1249 - accuracy: 0.9557 - val_loss: 0.7590 - val_accuracy: 0.7944
# Epoch 29/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.1217 - accuracy: 0.9564 - val_loss: 0.6650 - val_accuracy: 0.8235
# Epoch 30/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.1206 - accuracy: 0.9557 - val_loss: 0.7112 - val_accuracy: 0.8117
# Epoch 31/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.1170 - accuracy: 0.9587 - val_loss: 0.6509 - val_accuracy: 0.8220
# Epoch 32/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.1090 - accuracy: 0.9605 - val_loss: 0.6183 - val_accuracy: 0.8280
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.4.best/assets
# Epoch 33/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.0863 - accuracy: 0.9675 - val_loss: 0.6613 - val_accuracy: 0.8220
# Epoch 34/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.0836 - accuracy: 0.9713 - val_loss: 0.8102 - val_accuracy: 0.8009
# Epoch 35/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.1199 - accuracy: 0.9568 - val_loss: 0.7040 - val_accuracy: 0.8216
# Epoch 36/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.0824 - accuracy: 0.9708 - val_loss: 0.7879 - val_accuracy: 0.8091
# Epoch 37/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.0957 - accuracy: 0.9653 - val_loss: 0.7544 - val_accuracy: 0.8134
# Epoch 38/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.0886 - accuracy: 0.9691 - val_loss: 0.9775 - val_accuracy: 0.7832
# Epoch 39/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.0973 - accuracy: 0.9634 - val_loss: 0.6955 - val_accuracy: 0.8132
# Epoch 40/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.0963 - accuracy: 0.9637 - val_loss: 0.6576 - val_accuracy: 0.8167
# Epoch 41/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.0844 - accuracy: 0.9696 - val_loss: 0.7111 - val_accuracy: 0.8169
# Epoch 42/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.0775 - accuracy: 0.9719 - val_loss: 0.7589 - val_accuracy: 0.8193
# Epoch 43/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.0801 - accuracy: 0.9717 - val_loss: 0.7865 - val_accuracy: 0.8172
# Epoch 44/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.0778 - accuracy: 0.9715 - val_loss: 0.7284 - val_accuracy: 0.8254
# Epoch 45/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.0622 - accuracy: 0.9790 - val_loss: 0.8529 - val_accuracy: 0.8123
# Epoch 46/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.0671 - accuracy: 0.9774 - val_loss: 0.8968 - val_accuracy: 0.8048
# Epoch 47/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.0712 - accuracy: 0.9733 - val_loss: 0.7432 - val_accuracy: 0.8225
# Epoch 48/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.0755 - accuracy: 0.9733 - val_loss: 0.7190 - val_accuracy: 0.8199
# Epoch 49/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.0726 - accuracy: 0.9744 - val_loss: 0.7988 - val_accuracy: 0.8172
# Epoch 50/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.0781 - accuracy: 0.9718 - val_loss: 0.7651 - val_accuracy: 0.8210
# Epoch 51/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.0731 - accuracy: 0.9747 - val_loss: 0.7684 - val_accuracy: 0.8196
# Epoch 00051: early stopping
# Fold 4, 200 epochs, 174 sec
# accuracy: 82.80%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/200
# 350/350 [==============================] - 4s 9ms/step - loss: 0.6463 - accuracy: 0.6491 - val_loss: 0.7157 - val_accuracy: 0.6144
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.5.best/assets
# Epoch 2/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5740 - accuracy: 0.7058 - val_loss: 0.6914 - val_accuracy: 0.5999
# Epoch 3/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5611 - accuracy: 0.7167 - val_loss: 0.7199 - val_accuracy: 0.5874
# Epoch 4/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5543 - accuracy: 0.7153 - val_loss: 0.6397 - val_accuracy: 0.6244
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.5.best/assets
# Epoch 5/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5531 - accuracy: 0.7180 - val_loss: 0.6901 - val_accuracy: 0.5923
# Epoch 6/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5504 - accuracy: 0.7176 - val_loss: 0.6455 - val_accuracy: 0.6300
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.5.best/assets
# Epoch 7/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5403 - accuracy: 0.7233 - val_loss: 0.6460 - val_accuracy: 0.6411
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.5.best/assets
# Epoch 8/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5345 - accuracy: 0.7366 - val_loss: 0.6992 - val_accuracy: 0.6231
# Epoch 9/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5458 - accuracy: 0.7198 - val_loss: 0.6341 - val_accuracy: 0.6551
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.5.best/assets
# Epoch 10/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5604 - accuracy: 0.7127 - val_loss: 0.6282 - val_accuracy: 0.6586
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.5.best/assets
# Epoch 11/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5433 - accuracy: 0.7171 - val_loss: 0.7217 - val_accuracy: 0.6049
# Epoch 12/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5303 - accuracy: 0.7267 - val_loss: 0.6400 - val_accuracy: 0.6419
# Epoch 13/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5446 - accuracy: 0.7239 - val_loss: 0.6126 - val_accuracy: 0.6714
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.5.best/assets
# Epoch 14/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5376 - accuracy: 0.7206 - val_loss: 0.7361 - val_accuracy: 0.6017
# Epoch 15/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5504 - accuracy: 0.7235 - val_loss: 0.6430 - val_accuracy: 0.6556
# Epoch 16/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5432 - accuracy: 0.7214 - val_loss: 0.7463 - val_accuracy: 0.6204
# Epoch 17/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5358 - accuracy: 0.7239 - val_loss: 0.6709 - val_accuracy: 0.6297
# Epoch 00017: early stopping
# Fold 5, 200 epochs, 62 sec
# accuracy: 67.14%
#
# 6-way Cross Validation mean 73.19% (+/- 8.49%)
# Done
