# %% [markdown]
# # CNN 308
# Rather than partition train/validation sets, use different sets. Also use fit(shuffle) on the train set.
# Here train=long, valid=short.

# %%
TRAIN_NC_FILENAME='ncRNA.gc36.long.fasta'
TRAIN_PC_FILENAME='pcRNA.gc36.long.fasta'
VALID_NC_FILENAME='ncRNA.gc36.short.fasta'
VALID_PC_FILENAME='pcRNA.gc36.short.fasta'
#NC_FILENAME='ncRNA.tiny50.fasta'
#PC_FILENAME='pcRNA.tiny50.fasta'
#NC_FILENAME='ncRNA.gc34.processed.fasta'
#PC_FILENAME='pcRNA.gc34.processed.fasta'

MODEL_FILE='CNN308'  
DATAPATH=''

try:
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
except:
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"
TRAIN_NC_FILENAME = DATAPATH+TRAIN_NC_FILENAME
TRAIN_PC_FILENAME = DATAPATH+TRAIN_PC_FILENAME
VALID_NC_FILENAME = DATAPATH+VALID_NC_FILENAME
VALID_PC_FILENAME = DATAPATH+VALID_PC_FILENAME
MODEL_FILE=DATAPATH+MODEL_FILE

EPOCHS=200
SPLITS=5
K=1
VOCABULARY_SIZE=4**K+1   # e.g. K=3 => 64 DNA K-mers + 'NNN'
EMBED_DIMEN=2
FILTERS=32
KERNEL=3
NEURONS=32
DROP=0.25
ACT="tanh"
MINLEN=201
MAXLEN=2000
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# Load our own tools
# TO DO: don't go to GitHub if the file is already local.
GITHUB = True
if GITHUB:
    #!pip install requests  # Uncomment this if necessary. Seems to be pre-installed.
    import requests
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/ShepherdML/master/Strings/tools_fasta.py')
    with open('tools_fasta.py', 'w') as f:
        f.write(r.text)
    # TO DO: delete the file after import
import tools_fasta as tools
tools.yahoo()  # If this prints "Yahoo!" the the import was successful.

TOOLS_CHANGED = False   # set to True to re-run with a new version of tools
if TOOLS_CHANGED:
  from importlib import reload 
  tools=reload(tools)
  print(dir(tools))   # run this to see EVERYTHING in the tools module
# Out:
# Yahoo!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import StratifiedKFold
import tensorflow as tf
from tensorflow import keras
import time
dt='float32'
tf.keras.backend.set_floatx(dt)

# %% [markdown]
# Build model

# %%
def compile_model(model):
    ## learn rate = initial_learning_rate * decay_rate ^ (step / decay_steps)
    #adam_default_learn_rate = 0.001
    #schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    #    initial_learning_rate = adam_default_learn_rate*10,
    #    decay_steps=10000, decay_rate=0.99, staircase=True)
    #alrd = tf.keras.optimizers.Adam(learning_rate=schedule)
    #model.compile(loss=bc, optimizer=alrd, metrics=["accuracy"])

    print("COMPILE...")
    bc=tf.keras.losses.BinaryCrossentropy(from_logits=False)
    model.compile(loss=bc, optimizer="adam", metrics=["accuracy"])
    print("...COMPILED")
    return model

def build_model():
    SHAPE=(MAXLEN,5)  # MAXLEN bases = time steps, 5 features = one hots
    clayer1 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same",
                                 input_shape=SHAPE)
    clayer2 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer3 = keras.layers.MaxPooling1D(2)
    clayer4 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer5 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer6 = keras.layers.MaxPooling1D(2)
    clayer7 = keras.layers.Flatten()

    dlayer1 = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt, input_shape=[1000])
    dlayer2 = keras.layers.Dropout(DROP)
    dlayer3 = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt)
    dlayer4 = keras.layers.Dropout(DROP)
    output_layer = keras.layers.Dense(1, activation="sigmoid", dtype=dt)

    cnn = keras.models.Sequential()
    cnn.add(clayer1)
    cnn.add(clayer2)
    cnn.add(clayer3)
    cnn.add(clayer4)
    cnn.add(clayer5)
    cnn.add(clayer6)
    cnn.add(clayer7)
    cnn.add(dlayer1)
    cnn.add(dlayer2)
    cnn.add(dlayer3)
    cnn.add(dlayer4)
    cnn.add(output_layer)
    mlpc = compile_model(cnn)
    return mlpc

# %% [markdown]
# Cross validation

# %%
def do_cross_validation(X_train,y_train,given_model,X_valid,y_valid):
    cv_scores = []
    fold=0
    # When not using ShuffleSplit, make sure to randomize train data.
    #splitter = ShuffleSplit(n_splits=SPLITS, test_size=0.1, random_state=37863)
    #for train_index,valid_index in splitter.split(X):
    while fold < SPLITS:
        fold += 1
        # Avoid continually improving the same model.
        model = compile_model(keras.models.clone_model(given_model))
        bestname=MODEL_FILE+".cv."+str(fold)+".best"
        es = keras.callbacks.EarlyStopping(monitor='val_loss',  
            patience=10, verbose=1)
        mc = keras.callbacks.ModelCheckpoint(
            filepath=bestname, save_best_only=True, 
            monitor='val_accuracy', mode='max')  
        mycallbacks = [es,mc]  
        print("FIT")
        start_time=time.time()
        history=model.fit(X_train, y_train, # batch_size=10, default=32 works nicely
                epochs=EPOCHS, verbose=1,  # verbose=1 for ascii art, verbose=0 for none
                callbacks=mycallbacks, shuffle=True,
                validation_data=(X_valid,y_valid) )
        end_time=time.time()
        elapsed_time=(end_time-start_time)                        
        print("Fold %d, %d epochs, %d sec"%(fold,EPOCHS,elapsed_time))
        pd.DataFrame(history.history).plot(figsize=(8,5))
        plt.grid(True)
        plt.gca().set_ylim(0,1)
        plt.show()
        best_model=keras.models.load_model(bestname)
        scores = best_model.evaluate(X_valid, y_valid, verbose=0)
        print("%s: %.2f%%" % (best_model.metrics_names[1], scores[1]*100))
        cv_scores.append(scores[1] * 100)  

    print()
    print("%d-way Cross Validation max %.2f%%, mean %.2f%% (+/- %.2f%%)" % 
          (fold, np.amax(cv_scores), np.mean(cv_scores), np.std(cv_scores)))

# %% [markdown]
# ## Train on RNA lengths 200-1Kb

# %%
print ("Compile the model")
model=build_model()
print ("Summarize the model")
print(model.summary())  # Print this only once
#model.save(MODEL_FILE+'.model')
# Out:
# Compile the model
# COMPILE...
# ...COMPILED
# Summarize the model
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_52 (Conv1D)           (None, 2000, 32)          512
# _________________________________________________________________
# conv1d_53 (Conv1D)           (None, 2000, 32)          3104
# _________________________________________________________________
# max_pooling1d_26 (MaxPooling (None, 1000, 32)          0
# _________________________________________________________________
# conv1d_54 (Conv1D)           (None, 1000, 32)          3104
# _________________________________________________________________
# conv1d_55 (Conv1D)           (None, 1000, 32)          3104
# _________________________________________________________________
# max_pooling1d_27 (MaxPooling (None, 500, 32)           0
# _________________________________________________________________
# flatten_13 (Flatten)         (None, 16000)             0
# _________________________________________________________________
# dense_39 (Dense)             (None, 32)                512032
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_40 (Dense)             (None, 32)                1056
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_41 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 522,945
# Trainable params: 522,945
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
def load_data(nc_filename,pc_filename):
  nc_seq=tools.load_fasta(nc_filename,0)
  pc_seq=tools.load_fasta(pc_filename,1)
  train_set=pd.concat((nc_seq,pc_seq),axis=0)
  # May not need to slice by length if input files already sliced
  subset=tools.make_slice(train_set,MINLEN,MAXLEN)
  # randset=subset.sample(frac=1) # unneccessary with fit(shuffle)
  (X1,y1)=tools.separate_X_and_y(subset)
  # X1 is pandas df of ("list" of one sequence)
  X2=X1.to_numpy()  # numpy ndarray of ("list" of one sequence)
  X3=[elem[0] for elem in X2]  # numpy dnarray of str
  X4=tools.uniform_length(X3,MAXLEN)
  X5= [tools.one_hot(x) for x in X4]
  X6=np.asarray(X5)
  y6=y1.to_numpy()
  return X6,y6

print("Load train data from files.")
X_train,y_train = load_data(TRAIN_NC_FILENAME,TRAIN_PC_FILENAME)
print("Load valid data from files.")
X_valid,y_valid = load_data(VALID_NC_FILENAME,VALID_PC_FILENAME)
print("Data loaded from files.")
# Out:
# Load train data from files.
# Load valid data from files.
# Data loaded from files.

# %%
print ("Cross valiation")
do_cross_validation(X_train,y_train,model,X_valid,y_valid)  
print ("Done")
# Out:
# Cross valiation
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/200
# 350/350 [==============================] - 4s 9ms/step - loss: 0.6470 - accuracy: 0.6577 - val_loss: 0.7463 - val_accuracy: 0.6018
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.1.best/assets
# Epoch 2/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5996 - accuracy: 0.6967 - val_loss: 0.7464 - val_accuracy: 0.5895
# Epoch 3/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.6067 - accuracy: 0.6932 - val_loss: 0.7563 - val_accuracy: 0.6161
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.1.best/assets
# Epoch 4/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5995 - accuracy: 0.7026 - val_loss: 0.7542 - val_accuracy: 0.5838
# Epoch 5/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5941 - accuracy: 0.6948 - val_loss: 0.6652 - val_accuracy: 0.5985
# Epoch 6/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5773 - accuracy: 0.7002 - val_loss: 0.6851 - val_accuracy: 0.6104
# Epoch 7/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5681 - accuracy: 0.7161 - val_loss: 0.6803 - val_accuracy: 0.6062
# Epoch 8/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5680 - accuracy: 0.7104 - val_loss: 0.7396 - val_accuracy: 0.5826
# Epoch 9/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/200
# 350/350 [==============================] - 4s 10ms/step - loss: 0.6358 - accuracy: 0.6764 - val_loss: 0.8075 - val_accuracy: 0.5810
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.5.best/assets
# Epoch 2/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.6152 - accuracy: 0.6784 - val_loss: 0.6660 - val_accuracy: 0.5812
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.5.best/assets
# Epoch 3/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.6155 - accuracy: 0.6796 - val_loss: 0.6981 - val_accuracy: 0.5572
# Epoch 4/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5831 - accuracy: 0.6954 - val_loss: 0.7286 - val_accuracy: 0.5922
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.5.best/assets
# Epoch 5/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5823 - accuracy: 0.7043 - val_loss: 0.6852 - val_accuracy: 0.5931
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.5.best/assets
# Epoch 6/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5763 - accuracy: 0.7043 - val_loss: 0.6648 - val_accuracy: 0.6126
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.5.best/assets
# Epoch 7/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5797 - accuracy: 0.7033 - val_loss: 0.6836 - val_accuracy: 0.6144
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.5.best/assets
# Epoch 8/200
# 350/350 [==============================] - 3s 10ms/step - loss: 0.5717 - accuracy: 0.7118 - val_loss: 0.7114 - val_accuracy: 0.5855
# Epoch 9/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5778 - accuracy: 0.7035 - val_loss: 0.6536 - val_accuracy: 0.5951
# Epoch 10/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5605 - accuracy: 0.7183 - val_loss: 0.6852 - val_accuracy: 0.5798
# Epoch 11/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5565 - accuracy: 0.7189 - val_loss: 0.6709 - val_accuracy: 0.6224
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.5.best/assets
# Epoch 12/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5581 - accuracy: 0.7175 - val_loss: 0.7290 - val_accuracy: 0.5856
# Epoch 13/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5701 - accuracy: 0.7124 - val_loss: 0.6534 - val_accuracy: 0.6160
# Epoch 14/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5850 - accuracy: 0.6985 - val_loss: 0.7039 - val_accuracy: 0.5951
# Epoch 15/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5778 - accuracy: 0.7116 - val_loss: 0.7125 - val_accuracy: 0.5951
# Epoch 16/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5609 - accuracy: 0.7219 - val_loss: 0.6433 - val_accuracy: 0.6450
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.5.best/assets
# Epoch 17/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5739 - accuracy: 0.7035 - val_loss: 0.6321 - val_accuracy: 0.6568
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN308.cv.5.best/assets
# Epoch 18/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5609 - accuracy: 0.7179 - val_loss: 0.6942 - val_accuracy: 0.6253
# Epoch 19/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5484 - accuracy: 0.7332 - val_loss: 0.6694 - val_accuracy: 0.6244
# Epoch 20/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5460 - accuracy: 0.7211 - val_loss: 0.6841 - val_accuracy: 0.6027
# Epoch 21/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5444 - accuracy: 0.7311 - val_loss: 0.6688 - val_accuracy: 0.6287
# Epoch 22/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5512 - accuracy: 0.7284 - val_loss: 0.6839 - val_accuracy: 0.6383
# Epoch 23/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5404 - accuracy: 0.7300 - val_loss: 0.6759 - val_accuracy: 0.6258
# Epoch 24/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5452 - accuracy: 0.7246 - val_loss: 0.6417 - val_accuracy: 0.6377
# Epoch 25/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5496 - accuracy: 0.7213 - val_loss: 0.6630 - val_accuracy: 0.6211
# Epoch 26/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5516 - accuracy: 0.7186 - val_loss: 0.6812 - val_accuracy: 0.6292
# Epoch 27/200
# 350/350 [==============================] - 3s 9ms/step - loss: 0.5514 - accuracy: 0.7256 - val_loss: 0.6627 - val_accuracy: 0.6228
# Epoch 00027: early stopping
# Fold 5, 200 epochs, 97 sec
# accuracy: 65.68%
#
# 5-way Cross Validation max 82.41%, mean 69.08% (+/- 6.70%)
# Done
