# %% [markdown]
# <a href="https://colab.research.google.com/github/ShepherdCode/ShepherdML/blob/master/Nasa2021/CNN_512.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CNN 512
# Start with CNN 304 which uses Conv1D layers.
#
# No need for K-mers with convolution. End reliance on make_kmers().
#
# Higher levels of filters then dense neurons can create totally non-learning models

# %%
#NC_FILENAME='ncRNA.tiny50.fasta'
#PC_FILENAME='pcRNA.tiny50.fasta'
NC_FILENAME='ncRNA.gc34.processed.fasta'
PC_FILENAME='pcRNA.gc34.processed.fasta'

MODEL_FILE='CNN512'  
DATAPATH=''

try:
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
except:
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"
NC_FILENAME = DATAPATH+NC_FILENAME
PC_FILENAME = DATAPATH+PC_FILENAME
MODEL_FILE=DATAPATH+MODEL_FILE

EPOCHS=100
SPLITS=5
K=1
VOCABULARY_SIZE=4**K+1   # e.g. K=3 => 64 DNA K-mers + 'NNN'
EMBED_DIMEN=2
FILTERS=80
KERNEL=3
NEURONS=40
DROP=0.5
ACT="tanh"
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# Load our own tools
# TO DO: don't go to GitHub if the file is already local.
GITHUB = True
if GITHUB:
    #!pip install requests  # Uncomment this if necessary. Seems to be pre-installed.
    import requests
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/ShepherdML/master/Strings/tools_fasta.py')
    with open('tools_fasta.py', 'w') as f:
        f.write(r.text)
    # TO DO: delete the file after import
import tools_fasta as tools
tools.yahoo()  # If this prints "Yahoo!" the the import was successful.

TOOLS_CHANGED = False   # set to True to re-run with a new version of tools
if TOOLS_CHANGED:
  from importlib import reload 
  tools=reload(tools)
  print(dir(tools))   # run this to see EVERYTHING in the tools module
# Out:
# Yahoo!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import StratifiedKFold
import tensorflow as tf
from tensorflow import keras
import time
dt='float32'
tf.keras.backend.set_floatx(dt)

# %% [markdown]
# Build model

# %%
def compile_model(model):
    ## learn rate = initial_learning_rate * decay_rate ^ (step / decay_steps)
    #adam_default_learn_rate = 0.001
    #schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    #    initial_learning_rate = adam_default_learn_rate*10,
    #    decay_steps=10000, decay_rate=0.99, staircase=True)
    #alrd = tf.keras.optimizers.Adam(learning_rate=schedule)
    #model.compile(loss=bc, optimizer=alrd, metrics=["accuracy"])

    print("COMPILE...")
    bc=tf.keras.losses.BinaryCrossentropy(from_logits=False)
    model.compile(loss=bc, optimizer="adam", metrics=["accuracy"])
    print("...COMPILED")
    return model

def build_model():
    SHAPE=(1000,5)  # 1000 time steps, 5 features
    clayer1 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same",
                                 input_shape=SHAPE)
    clayer2 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer3 = keras.layers.MaxPooling1D(2)
    clayer4 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer5 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer6 = keras.layers.MaxPooling1D(2)
    clayer7 = keras.layers.Flatten()

    dlayer1 = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt, input_shape=[1000])
    dlayer2 = keras.layers.Dropout(DROP)
    dlayer3 = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt)
    dlayer4 = keras.layers.Dropout(DROP)
    output_layer = keras.layers.Dense(1, activation="sigmoid", dtype=dt)

    cnn = keras.models.Sequential()
    cnn.add(clayer1)
    cnn.add(clayer2)
    cnn.add(clayer3)
    cnn.add(clayer4)
    cnn.add(clayer5)
    cnn.add(clayer6)
    cnn.add(clayer7)
    cnn.add(dlayer1)
    cnn.add(dlayer2)
    cnn.add(dlayer3)
    cnn.add(dlayer4)
    cnn.add(output_layer)
    mlpc = compile_model(cnn)
    return mlpc

# %% [markdown]
# Cross validation

# %%
def do_cross_validation(X,y,given_model):
    cv_scores = []
    fold=0
    splitter = ShuffleSplit(n_splits=SPLITS, test_size=0.1, random_state=37863)
    for train_index,valid_index in splitter.split(X):
        fold += 1
        X_train=X[train_index] # use iloc[] for dataframe
        y_train=y[train_index]
        X_valid=X[valid_index]
        y_valid=y[valid_index]        
        # Avoid continually improving the same model.
        model = compile_model(keras.models.clone_model(given_model))
        bestname=MODEL_FILE+".cv."+str(fold)+".best"
        mycallbacks = [keras.callbacks.ModelCheckpoint(
            filepath=bestname, save_best_only=True, 
            monitor='val_accuracy', mode='max')]   
        print("FIT")
        start_time=time.time()
        history=model.fit(X_train, y_train, # batch_size=10, default=32 works nicely
                epochs=EPOCHS, verbose=1,  # verbose=1 for ascii art, verbose=0 for none
                callbacks=mycallbacks,
                validation_data=(X_valid,y_valid) )
        end_time=time.time()
        elapsed_time=(end_time-start_time)                        
        print("Fold %d, %d epochs, %d sec"%(fold,EPOCHS,elapsed_time))
        pd.DataFrame(history.history).plot(figsize=(8,5))
        plt.grid(True)
        plt.gca().set_ylim(0,1)
        plt.show()
        best_model=keras.models.load_model(bestname)
        scores = best_model.evaluate(X_valid, y_valid, verbose=0)
        print("%s: %.2f%%" % (best_model.metrics_names[1], scores[1]*100))
        cv_scores.append(scores[1] * 100)  
    print()
    print("%d-way Cross Validation mean %.2f%% (+/- %.2f%%)" % (fold, np.mean(cv_scores), np.std(cv_scores)))

# %% [markdown]
# ## Train on RNA lengths 200-1Kb

# %%
print ("Compile the model")
model=build_model()
print ("Summarize the model")
print(model.summary())  # Print this only once
#model.save(MODEL_FILE+'.model')
# Out:
# Compile the model
# COMPILE...
# ...COMPILED
# Summarize the model
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_8 (Conv1D)            (None, 1000, 80)          1280
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 1000, 80)          19280
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 500, 80)           0
# _________________________________________________________________
# conv1d_10 (Conv1D)           (None, 500, 80)           19280
# _________________________________________________________________
# conv1d_11 (Conv1D)           (None, 500, 80)           19280
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 250, 80)           0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 20000)             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 40)                800040
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 40)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 40)                1640
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 40)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 41
# =================================================================
# Total params: 860,841
# Trainable params: 860,841
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
MINLEN=200
MAXLEN=1000
print("Load data from files.")
nc_seq=tools.load_fasta(NC_FILENAME,0)
pc_seq=tools.load_fasta(PC_FILENAME,1)
train_set=pd.concat((nc_seq,pc_seq),axis=0)
nc_seq=None
pc_seq=None
print("Ready: train_set")
#train_set
subset=tools.make_slice(train_set,MINLEN,MAXLEN)# One array to two: X and y
(X1,y_train)=tools.separate_X_and_y(subset)
# X1 is pandas df of ("list" of one sequence)
X2=X1.to_numpy()  # numpy ndarray of ("list" of one sequence)
X3=[elem[0] for elem in X2]  # numpy dnarray of str
X4=tools.uniform_length(X3,MAXLEN)
X5= [tools.one_hot(x) for x in X4]
X_train=np.asarray(X5)
y_train=y_train.to_numpy()

subset=None
X1=None
X2=None
X3=None
X4=None
X5=None
# Out:
# Load data from files.
# Ready: train_set

# %%
print ("Cross valiation")
do_cross_validation(X_train,y_train,model)  
print ("Done")
# Out:
# Cross valiation
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/100
# 453/453 [==============================] - 4s 8ms/step - loss: 0.7129 - accuracy: 0.6238 - val_loss: 0.5827 - val_accuracy: 0.7052
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN512.cv.1.best/assets
# Epoch 2/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.6899 - accuracy: 0.6034 - val_loss: 0.6463 - val_accuracy: 0.6530
# Epoch 3/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.6649 - accuracy: 0.6268 - val_loss: 0.6458 - val_accuracy: 0.6530
# Epoch 4/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.6575 - accuracy: 0.6405 - val_loss: 0.6457 - val_accuracy: 0.6530
# Epoch 5/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.6552 - accuracy: 0.6426 - val_loss: 0.6456 - val_accuracy: 0.6530
# Epoch 6/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.6577 - accuracy: 0.6384 - val_loss: 0.6464 - val_accuracy: 0.6530
# Epoch 7/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.6563 - accuracy: 0.6382 - val_loss: 0.6457 - val_accuracy: 0.6530
# Epoch 8/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.6548 - accuracy: 0.6415 - val_loss: 0.6456 - val_accuracy: 0.6530
# Epoch 9/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.6575 - accuracy: 0.6353 - val_loss: 0.6463 - val_accuracy: 0.6530
# Epoch 10/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.6566 - accuracy: 0.6379 - val_loss: 0.6456 - val_accuracy: 0.6530
# Epoch 11/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.6569 - accuracy: 0.6376 - val_loss: 0.6464 - val_accuracy: 0.6530
# Epoch 12/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.6556 - accuracy: 0.6409 - val_loss: 0.6474 - val_accuracy: 0.6530
# Epoch 13/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.6569 - accuracy: 0.6364 - val_loss: 0.6456 - val_accuracy: 0.6530
# Epoch 14/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.6564 - accuracy: 0.6376 - val_loss: 0.6459 - val_accuracy: 0.6530
# Epoch 15/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.6577 - accuracy: 0.6346 - val_loss: 0.6456 - val_accuracy: 0.6530
# Epoch 16/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.6549 - accuracy: 0.6401 - val_loss: 0.6459 - val_accuracy: 0.6530
# Epoch 17/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.6526 - accuracy: 0.6441 - val_loss: 0.6462 - val_accuracy: 0.6530
# Epoch 18/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.6546 - accuracy: 0.6404 - val_loss: 0.6460 - val_accuracy: 0.6530
# Epoch 19/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.6543 - accuracy: 0.6403 - val_loss: 0.6457 - val_accuracy: 0.6530
# Epoch 20/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.6541 - accuracy: 0.6416 - val_loss: 0.6456 - val_accuracy: 0.6530
# Epoch 21/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.6548 - accuracy: 0.6404 - val_loss: 0.6456 - val_accuracy: 0.6530
# Epoch 22/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.6545 - accuracy: 0.6408 - val_loss: 0.6482 - val_accuracy: 0.6530
# Epoch 23/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.6529 - accuracy: 0.6424 - val_loss: 0.6459 - val_accuracy: 0.6530
# Epoch 24/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.6515 - accuracy: 0.6444 - val_loss: 0.6464 - val_accuracy: 0.6530
# Epoch 25/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.6531 - accuracy: 0.6426 - val_loss: 0.6463 - val_accuracy: 0.6530
# Epoch 26/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.6590 - accuracy: 0.6326 - val_loss: 0.6456 - val_accuracy: 0.6530
# Epoch 27/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.6538 - accuracy: 0.6411 - val_loss: 0.6456 - val_accuracy: 0.6530
# Epoch 28/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.6558 - accuracy: 0.6384 - val_loss: 0.6458 - val_accuracy: 0.6530
# Epoch 29/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.6520 - accuracy: 0.6436 - val_loss: 0.6459 - val_accuracy: 0.6530
# Epoch 30/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.6593 - accuracy: 0.6317 - val_loss: 0.6456 - val_accuracy: 0.6530
# Epoch 31/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.6524 - accuracy: 0.6434 - val_loss: 0.6456 - val_accuracy: 0.6530
# Epoch 32/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.6570 - accuracy: 0.6347 - val_loss: 0.6456 - val_accuracy: 0.6530
# Epoch 33/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.6528 - accuracy: 0.6431 - val_loss: 0.6471 - val_accuracy: 0.6530
# Epoch 34/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.6514 - accuracy: 0.6460 - val_loss: 0.6501 - val_accuracy: 0.6530
# Epoch 35/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.6548 - accuracy: 0.6398 - val_loss: 0.6456 - val_accuracy: 0.6530
# Epoch 36/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.6570 - accuracy: 0.6348 - val_loss: 0.6456 - val_accuracy: 0.6530
# Epoch 37/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.

# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/100
# 453/453 [==============================] - 4s 8ms/step - loss: 0.6929 - accuracy: 0.6339 - val_loss: 0.5782 - val_accuracy: 0.6903
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN512.cv.3.best/assets
# Epoch 2/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.6249 - accuracy: 0.6637 - val_loss: 0.5837 - val_accuracy: 0.7089
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN512.cv.3.best/assets
# Epoch 3/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.6062 - accuracy: 0.6811 - val_loss: 0.5583 - val_accuracy: 0.7169
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN512.cv.3.best/assets
# Epoch 4/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5734 - accuracy: 0.7079 - val_loss: 0.5484 - val_accuracy: 0.7213
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN512.cv.3.best/assets
# Epoch 5/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5669 - accuracy: 0.7160 - val_loss: 0.5543 - val_accuracy: 0.7232
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN512.cv.3.best/assets
# Epoch 6/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5716 - accuracy: 0.7035 - val_loss: 0.5529 - val_accuracy: 0.7238
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN512.cv.3.best/assets
# Epoch 7/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5693 - accuracy: 0.7089 - val_loss: 0.5469 - val_accuracy: 0.7163
# Epoch 8/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5705 - accuracy: 0.7044 - val_loss: 0.5515 - val_accuracy: 0.7176
# Epoch 9/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5718 - accuracy: 0.6973 - val_loss: 0.5567 - val_accuracy: 0.7089
# Epoch 10/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5635 - accuracy: 0.7086 - val_loss: 0.5409 - val_accuracy: 0.7318
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN512.cv.3.best/assets
# Epoch 11/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5574 - accuracy: 0.7200 - val_loss: 0.5441 - val_accuracy: 0.7207
# Epoch 12/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5539 - accuracy: 0.7179 - val_loss: 0.5468 - val_accuracy: 0.7219
# Epoch 13/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5613 - accuracy: 0.7104 - val_loss: 0.5438 - val_accuracy: 0.7225
# Epoch 14/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5589 - accuracy: 0.7176 - val_loss: 0.5369 - val_accuracy: 0.7374
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN512.cv.3.best/assets
# Epoch 15/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5596 - accuracy: 0.7132 - val_loss: 0.5430 - val_accuracy: 0.7306
# Epoch 16/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5474 - accuracy: 0.7286 - val_loss: 0.5375 - val_accuracy: 0.7300
# Epoch 17/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5559 - accuracy: 0.7199 - val_loss: 0.5342 - val_accuracy: 0.7387
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN512.cv.3.best/assets
# Epoch 18/100
# 453/453 [==============================] - 3s 8ms/step - loss: 0.5469 - accuracy: 0.7265 - val_loss: 0.5332 - val_accuracy: 0.7362
# Epoch 19/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5558 - accuracy: 0.7192 - val_loss: 0.5368 - val_accuracy: 0.7269
# Epoch 20/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5407 - accuracy: 0.7288 - val_loss: 0.5355 - val_accuracy: 0.7337
# Epoch 21/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5492 - accuracy: 0.7272 - val_loss: 0.5361 - val_accuracy: 0.7424
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN512.cv.3.best/assets
# Epoch 22/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5561 - accuracy: 0.7172 - val_loss: 0.5401 - val_accuracy: 0.7436
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN512.cv.3.best/assets
# Epoch 23/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5554 - accuracy: 0.7252 - val_loss: 0.5438 - val_accuracy: 0.7225
# Epoch 24/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5494 - accuracy: 0.7214 - val_loss: 0.5497 - val_accuracy: 0.7281
# Epoch 25/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5464 - accuracy: 0.7263 - val_loss: 0.5401 - val_accuracy: 0.7269
# Epoch 26/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5502 - accuracy: 0.7266 - val_loss: 0.5386 - val_accuracy: 0.7412
# Epoch 27/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5404 - accuracy: 0.7336 - val_loss: 0.5364 - val_accuracy: 0.7368
# Epoch 28/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5418 - accuracy: 0.7339 - val_loss: 0.5468 - val_accuracy: 0.7356
# Epoch 29/100
# 453/453 [==============================] - 3s 8ms/step - loss: 0.5437 - accuracy: 0.7294 - val_loss: 0.5410 - val_accuracy: 0.7368
# Epoch 30/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5512 - accuracy: 0.7293 - val_loss: 0.5459 - val_accuracy: 0.7424
# Epoch 31/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5527 - accuracy: 0.7250 - val_loss: 0.5391 - val_accuracy: 0.7325
# Epoch 32/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5492 - accuracy: 0.7265 - val_loss: 0.5415 - val_accuracy: 0.7250
# Epoch 33/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5428 - accuracy: 0.7295 - val_loss: 0.5408 - val_accuracy: 0.7287
# Epoch 34/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5465 - accuracy: 0.7316 - val_loss: 0.5411 - val_accuracy: 0.7381
# Epoch 35/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5441 - accuracy: 0.7271 - val_loss: 0.5401 - val_accuracy: 0.7300
# Epoch 36/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5495 - accuracy: 0.7136 - val_loss: 0.5399 - val_accuracy: 0.7349
# Epoch 37/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5492 - accuracy: 0.7268 - val_loss: 0.5387 - val_accuracy: 0.7331
# Epoch 38/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5484 - accuracy: 0.7276 - val_loss: 0.5397 - val_accuracy: 0.7337
# Epoch 39/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5430 - accuracy: 0.7322 - val_loss: 0.5349 - val_accuracy: 0.7387
# Epoch 40/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5394 - accuracy: 0.7322 - val_loss: 0.5363 - val_accuracy: 0.7343
# Epoch 41/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5437 - accuracy: 0.7311 - val_loss: 0.5366 - val_accuracy: 0.7368
# Epoch 42/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5506 - accuracy: 0.7221 - val_loss: 0.5354 - val_accuracy: 0.7393
# Epoch 43/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5417 - accuracy: 0.7345 - val_loss: 0.5369 - val_accuracy: 0.7256
# Epoch 44/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5372 - accuracy: 0.7410 - val_loss: 0.5343 - val_accuracy: 0.7343
# Epoch 45/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5476 - accuracy: 0.7282 - val_loss: 0.5324 - val_accuracy: 0.7418
# Epoch 46/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5482 - accuracy: 0.7228 - val_loss: 0.5378 - val_accuracy: 0.7263
# Epoch 47/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5459 - accuracy: 0.7272 - val_loss: 0.5383 - val_accuracy: 0.7294
# Epoch 48/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5410 - accuracy: 0.7328 - val_loss: 0.5350 - val_accuracy: 0.7368
# Epoch 49/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5421 - accuracy: 0.7251 - val_loss: 0.5316 - val_accuracy: 0.7312
# Epoch 50/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5911 - accuracy: 0.6804 - val_loss: 0.6027 - val_accuracy: 0.6872
# Epoch 51/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.6081 - accuracy: 0.6702 - val_loss: 0.5789 - val_accuracy: 0.7101
# Epoch 52/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.6025 - accuracy: 0.6719 - val_loss: 0.5794 - val_accuracy: 0.7095
# Epoch 53/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5980 - accuracy: 0.6840 - val_loss: 0.5645 - val_accuracy: 0.7194
# Epoch 54/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5877 - accuracy: 0.6967 - val_loss: 0.5542 - val_accuracy: 0.7281
# Epoch 55/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5780 - accuracy: 0.7121 - val_loss: 0.5560 - val_accuracy: 0.7294
# Epoch 56/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5717 - accuracy: 0.7061 - val_loss: 0.5499 - val_accuracy: 0.7343
# Epoch 57/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5696 - accuracy: 0.7131 - val_loss: 0.5510 - val_accuracy: 0.7281
# Epoch 58/100
# 453/453 [==============================] - 3s 7ms/step - loss: 0.5704 - accuracy: 0.7069 - val_loss: 0.5550 - val_accuracy: 0.7287
# Epoch 59/100
# 378/453 [========================>.....] - ETA: 0s - loss: 0.5681 - accuracy: 0.7181
