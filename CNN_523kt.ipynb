# %% [markdown]
# <a href="https://colab.research.google.com/github/ShepherdCode/ShepherdML/blob/master/CNN_523kt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CNN 523
#
# 1. Four layers of CNNS and MaxPooling
# 2. Drop out at 0.2
# 3. Variable filters and dense neurons

# %%
#NC_FILENAME='ncRNA.tiny50.fasta'
#PC_FILENAME='pcRNA.tiny50.fasta'
#NC_FILENAME='ncRNA.gc34.processed.fasta'
#PC_FILENAME='pcRNA.gc34.processed.fasta'
#NC_FILENAME='ncRNA.gc36.balance.fasta'
#PC_FILENAME='pcRNA.gc36.balance.fasta'
NC_FILENAME='noncod_30k.fasta'
PC_FILENAME='coding_30k.fasta'

MODEL_FILE='CNN523' 
DATAPATH=''

try:
    from google.colab import drive
    IN_COLAB = True
    PATH='/content/drive/'
    drive.mount(PATH)
    DATAPATH=PATH+'My Drive/data/'  # must end in "/"
except:
    IN_COLAB = False
    DATAPATH='data/'  # must end in "/"
NC_FILENAME = DATAPATH+NC_FILENAME
PC_FILENAME = DATAPATH+PC_FILENAME
MODEL_FILE=DATAPATH+MODEL_FILE

EPOCHS=50
SPLITS=5
K=1
VOCABULARY_SIZE=4**K+1   # e.g. K=3 => 64 DNA K-mers + 'NNN'
EMBED_DIMEN=2
FILTERS=32
KERNEL=3
NEURONS=24
DROP=0.2
MINLEN=200
MAXLEN=1000
DENSE_LEN = 1000
ACT="tanh"
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# Load our own tools
# TO DO: don't go to GitHub if the file is already local.
GITHUB = True
if GITHUB:
    #!pip install requests  # Uncomment this if necessary. Seems to be pre-installed.
    import requests
    r = requests.get('https://raw.githubusercontent.com/ShepherdCode/ShepherdML/master/Strings/tools_fasta.py')
    with open('tools_fasta.py', 'w') as f:
        f.write(r.text)
    # TO DO: delete the file after import
import tools_fasta as tools
tools.yahoo()  # If this prints "Yahoo!" the the import was successful.

TOOLS_CHANGED = False   # set to True to re-run with a new version of tools
if TOOLS_CHANGED:
  from importlib import reload 
  tools=reload(tools)
  print(dir(tools))   # run this to see EVERYTHING in the tools module
# Out:
# Yahoo!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import StratifiedKFold
import tensorflow as tf
from tensorflow import keras
import time
dt='float32'
tf.keras.backend.set_floatx(dt)

# %% [markdown]
# Build model

# %%
def compile_model(model):
    ## learn rate = initial_learning_rate * decay_rate ^ (step / decay_steps)
    #adam_default_learn_rate = 0.001
    #schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    #    initial_learning_rate = adam_default_learn_rate*10,
    #    decay_steps=10000, decay_rate=0.99, staircase=True)
    #alrd = tf.keras.optimizers.Adam(learning_rate=schedule)
    #model.compile(loss=bc, optimizer=alrd, metrics=["accuracy"])

    print("COMPILE...")
    bc=tf.keras.losses.BinaryCrossentropy(from_logits=False)
    model.compile(loss=bc, optimizer="adam", metrics=["accuracy"])
    print("...COMPILED")
    return model

def build_model():
    SHAPE=(MAXLEN,5)  # 2000 time steps, 5 features
    clayer1 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same",
                                 input_shape=SHAPE)
    clayer2 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer3 = keras.layers.MaxPooling1D(2)
    clayer4 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer5 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer6 = keras.layers.MaxPooling1D(2)
    clayer7 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer8 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer9 = keras.layers.MaxPooling1D(2)
    clayer10 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer11 = keras.layers.Conv1D(FILTERS,KERNEL,activation=ACT,padding="same")
    clayer12 = keras.layers.MaxPooling1D(2)

    clayer13 = keras.layers.Flatten()

    dlayer1 = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt, input_shape=[DENSE_LEN])
    dlayer2 = keras.layers.Dropout(DROP)
    dlayer3 = keras.layers.Dense(NEURONS, activation=ACT,dtype=dt)
    dlayer4 = keras.layers.Dropout(DROP)
    output_layer = keras.layers.Dense(1, activation="sigmoid", dtype=dt)

    cnn = keras.models.Sequential()
    cnn.add(clayer1)
    cnn.add(clayer2)
    cnn.add(clayer3)
    cnn.add(clayer4)
    cnn.add(clayer5)
    cnn.add(clayer6)
    cnn.add(clayer7)
    cnn.add(clayer8)
    cnn.add(clayer9)
    cnn.add(clayer10)
    cnn.add(clayer11)
    cnn.add(clayer12)
    cnn.add(clayer13)
    cnn.add(dlayer1)
    cnn.add(dlayer2)
    cnn.add(dlayer3)
    cnn.add(dlayer4)
    cnn.add(output_layer)
    mlpc = compile_model(cnn)
    return mlpc

# %% [markdown]
# Cross validation

# %%
def do_cross_validation(X,y,given_model):
    cv_scores = []
    fold=0
    splitter = ShuffleSplit(n_splits=SPLITS, test_size=0.1, random_state=37863)
    for train_index,valid_index in splitter.split(X):
        fold += 1
        X_train=X[train_index] # use iloc[] for dataframe
        y_train=y[train_index]
        X_valid=X[valid_index]
        y_valid=y[valid_index]        
        # Avoid continually improving the same model.
        model = compile_model(keras.models.clone_model(given_model))
        bestname=MODEL_FILE+".cv."+str(fold)+".best"
        mycallbacks = [keras.callbacks.ModelCheckpoint(
            filepath=bestname, save_best_only=True, 
            monitor='val_accuracy', mode='max')]   
        print("FIT")
        start_time=time.time()
        history=model.fit(X_train, y_train, # batch_size=10, default=32 works nicely
                epochs=EPOCHS, verbose=1,  # verbose=1 for ascii art, verbose=0 for none
                callbacks=mycallbacks,
                validation_data=(X_valid,y_valid) )
        end_time=time.time()
        elapsed_time=(end_time-start_time)                        
        print("Fold %d, %d epochs, %d sec"%(fold,EPOCHS,elapsed_time))
        pd.DataFrame(history.history).plot(figsize=(8,5))
        plt.grid(True)
        plt.gca().set_ylim(0,1)
        plt.show()
        best_model=keras.models.load_model(bestname)
        scores = best_model.evaluate(X_valid, y_valid, verbose=0)
        print("%s: %.2f%%" % (best_model.metrics_names[1], scores[1]*100))
        cv_scores.append(scores[1] * 100)  
    print()
    print("%d-way Cross Validation mean %.2f%% (+/- %.2f%%)" % (fold, np.mean(cv_scores), np.std(cv_scores)))

# %% [markdown]
# ## Train on RNA lengths 200-1Kb

# %%
print ("Compile the model")
model=build_model()
print ("Summarize the model")
print(model.summary())  # Print this only once
#model.save(MODEL_FILE+'.model')
# Out:
# Compile the model
# COMPILE...
# ...COMPILED
# Summarize the model
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 1000, 32)          512
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 1000, 32)          3104
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 500, 32)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 500, 32)           3104
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 500, 32)           3104
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 250, 32)           0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 250, 32)           3104
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 250, 32)           3104
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 125, 32)           0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 125, 32)           3104
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 125, 32)           3104
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 62, 32)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 1984)              0
# _________________________________________________________________
# dense (Dense)                (None, 24)                47640
# _________________________________________________________________
# dropout (Dropout)            (None, 24)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 24)                600
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 24)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 25
# =================================================================
# Total params: 70,505
# Trainable params: 70,505
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#MINLEN=200
#MAXLEN=2000
print("Load data from files.")
nc_seq=tools.load_fasta(NC_FILENAME,0)
pc_seq=tools.load_fasta(PC_FILENAME,1)
train_set=pd.concat((nc_seq,pc_seq),axis=0)
nc_seq=None
pc_seq=None
print("Ready: train_set")
#train_set
subset=tools.make_slice(train_set,MINLEN,MAXLEN)# One array to two: X and y
(X1,y_train)=tools.separate_X_and_y(subset)
# X1 is pandas df of ("list" of one sequence)
X2=X1.to_numpy()  # numpy ndarray of ("list" of one sequence)
X3=[elem[0] for elem in X2]  # numpy dnarray of str
X4=tools.uniform_length(X3,MAXLEN)
X5= [tools.one_hot(x) for x in X4]
X_train=np.asarray(X5)
y_train=y_train.to_numpy()

subset=None
X1=None
X2=None
X3=None
X4=None
X5=None
# Out:
# Load data from files.
# Ready: train_set

# %%
print ("Cross validation")
do_cross_validation(X_train,y_train,model)  
print ("Done")
# Out:
# Cross validation
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/50
# 1125/1125 [==============================] - 11s 6ms/step - loss: 0.5818 - accuracy: 0.7439 - val_loss: 0.5248 - val_accuracy: 0.7502
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.1.best/assets
# Epoch 2/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5366 - accuracy: 0.7491 - val_loss: 0.4756 - val_accuracy: 0.7830
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.1.best/assets
# Epoch 3/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.4628 - accuracy: 0.7896 - val_loss: 0.4229 - val_accuracy: 0.8058
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.1.best/assets
# Epoch 4/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.4222 - accuracy: 0.8108 - val_loss: 0.4068 - val_accuracy: 0.8217
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.1.best/assets
# Epoch 5/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.4040 - accuracy: 0.8226 - val_loss: 0.4052 - val_accuracy: 0.8235
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.1.best/assets
# Epoch 6/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.3942 - accuracy: 0.8274 - val_loss: 0.3978 - val_accuracy: 0.8240
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.1.best/assets
# Epoch 7/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.3859 - accuracy: 0.8315 - val_loss: 0.3956 - val_accuracy: 0.8267
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.1.best/assets
# Epoch 8/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.3839 - accuracy: 0.8320 - val_loss: 0.3968 - val_accuracy: 0.8255
# Epoch 9/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.3719 - accuracy: 0.8399 - val_loss: 0.3891 - val_accuracy: 0.8365
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.1.best/assets
# Epoch 10/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.3691 - accuracy: 0.8404 - val_loss: 0.3910 - val_accuracy: 0.8388
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.1.best/assets
# Epoch 11/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.3183 - accuracy: 0.8674 - val_loss: 0.2143 - val_accuracy: 0.9195
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.1.best/assets
# Epoch 12/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.1657 - accuracy: 0.9398 - val_loss: 0.0822 - val_accuracy: 0.9725
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.1.best/assets
# Epoch 13/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0691 - accuracy: 0.9776 - val_loss: 0.0356 - val_accuracy: 0.9908
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.1.best/assets
# Epoch 14/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0466 - accuracy: 0.9849 - val_loss: 0.0354 - val_accuracy: 0.9902
# Epoch 15/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0367 - accuracy: 0.9891 - val_loss: 0.0363 - val_accuracy: 0.9898
# Epoch 16/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0345 - accuracy: 0.9905 - val_loss: 0.0285 - val_accuracy: 0.9920
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.1.best/assets
# Epoch 17/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0326 - accuracy: 0.9906 - val_loss: 0.0354 - val_accuracy: 0.9920
# Epoch 18/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0253 - accuracy: 0.9926 - val_loss: 0.0375 - val_accuracy: 0.9912
# Epoch 19/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0286 - accuracy: 0.9905 - val_loss: 0.0279 - val_accuracy: 0.9940
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.1.best/assets
# Epoch 20/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0201 - accuracy: 0.9942 - val_loss: 0.0248 - val_accuracy: 0.9937
# Epoch 21/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0257 - accuracy: 0.9926 - val_loss: 0.0237 - val_accuracy: 0.9933
# Epoch 22/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0193 - accuracy: 0.9943 - val_loss: 0.0280 - val_accuracy: 0.9927
# Epoch 23/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0229 - accuracy: 0.9932 - val_loss: 0.0320 - val_accuracy: 0.9933
# Epoch 24/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0199 - accuracy: 0.9941 - val_loss: 0.0260 - val_accuracy: 0.9942
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.1.best/assets
# Epoch 25/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0150 - accuracy: 0.9957 - val_loss: 0.0254 - val_accuracy: 0.9930
# Epoch 26/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0202 - accuracy: 0.9943 - val_loss: 0.0248 - val_accuracy: 0.9950
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.1.best/assets
# Epoch 27/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0223 - accuracy: 0.9926 - val_loss: 0.0427 - val_accuracy: 0.9923
# Epoch 28/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0179 - accuracy: 0.9950 - val_loss: 0.0348 - val_accuracy: 0.9925
# Epoch 29/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0191 - accuracy: 0.9944 - val_loss: 0.0236 - val_accuracy: 0.9952
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.1.best/assets
# Epoch 30/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0165 - accuracy: 0.9955 - val_loss: 0.0314 - val_accuracy: 0.9935
# Epoch 31/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0170 - accuracy: 0.9950 - val_loss: 0.0371 - val_accuracy: 0.9930
# Epoch 32/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0172 - accuracy: 0.9951 - val_loss: 0.0283 - val_accuracy: 0.9945
# Epoch 33/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0148 - accuracy: 0.9961 - val_loss: 0.0307 - val_accuracy: 0.9940
# Epoch 34/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0117 - accuracy: 0.9971 - val_loss: 0.0275 - val_accuracy: 0.9960
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.1.best/assets
# Epoch 35/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0149 - accuracy: 0.9956 - val_loss: 0.0228 - val_accuracy: 0.9950
# Epoch 36/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0168 - accuracy: 0.9955 - val_loss: 0.0283 - val_accuracy: 0.9935
# Epoch 37/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0156 - accuracy: 0.9957 - val_loss: 0.0298 - val_accuracy: 0.9937
# Epoch 38/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0139 - accuracy: 0.9961 - val_loss: 0.0243 - val_accuracy: 0.9948
# Epoch 39/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0182 - accuracy: 0.9951 - val_loss: 0.0841 - val_accuracy: 0.9743
# Epoch 40/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0768 - accuracy: 0.9774 - val_loss: 0.0699 - val_accuracy: 0.9830
# Epoch 41/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0669 - accuracy: 0.9814 - val_loss: 0.0735 - val_accuracy: 0.9830
# Epoch 42/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0607 - accuracy: 0.9832 - val_loss: 0.0747 - val_accuracy: 0.9837
# Epoch 43/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0545 - accuracy: 0.9850 - val_loss: 0.0230 - val_accuracy: 0.9952
# Epoch 44/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0167 - accuracy: 0.9961 - val_loss: 0.0167 - val_accuracy: 0.9948
# Epoch 45/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0117 - accuracy: 0.9966 - val_loss: 0.0200 - val_accuracy: 0.9960
# Epoch 46/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0141 - accuracy: 0.9959 - val_loss: 0.0207 - val_accuracy: 0.9960
# Epoch 47/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0143 - accuracy: 0.9960 - val_loss: 0.0277 - val_accuracy: 0.9952
# Epoch 48/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0126 - accuracy: 0.9966 - val_loss: 0.0218 - val_accuracy: 0.9955
# Epoch 49/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0136 - accuracy: 0.9965 - val_loss: 0.0205 - val_accuracy: 0.9962
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.1.best/assets
# Epoch 50/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0139 - accuracy: 0.9963 - val_loss: 0.0217 - val_accuracy: 0.9955
# Fold 1, 50 epochs, 340 sec
# accuracy: 99.62%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/50
# 1125/1125 [==============================] - 7s 5ms/step - loss: 0.5572 - accuracy: 0.7482 - val_loss: 0.5336 - val_accuracy: 0.7703
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.2.best/assets
# Epoch 2/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.4440 - accuracy: 0.8022 - val_loss: 0.3506 - val_accuracy: 0.8580
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.2.best/assets
# Epoch 3/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.2959 - accuracy: 0.8808 - val_loss: 0.0788 - val_accuracy: 0.9737
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.2.best/assets
# Epoch 4/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0684 - accuracy: 0.9798 - val_loss: 0.0331 - val_accuracy: 0.9905
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.2.best/assets
# Epoch 5/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0376 - accuracy: 0.9880 - val_loss: 0.0368 - val_accuracy: 0.9915
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.2.best/assets
# Epoch 6/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0285 - accuracy: 0.9908 - val_loss: 0.0185 - val_accuracy: 0.9955
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.2.best/assets
# Epoch 7/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0292 - accuracy: 0.9922 - val_loss: 0.0257 - val_accuracy: 0.9937
# Epoch 8/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0250 - accuracy: 0.9937 - val_loss: 0.0321 - val_accuracy: 0.9918
# Epoch 9/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0229 - accuracy: 0.9931 - val_loss: 0.0240 - val_accuracy: 0.9950
# Epoch 10/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0179 - accuracy: 0.9946 - val_loss: 0.0237 - val_accuracy: 0.9950
# Epoch 11/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0176 - accuracy: 0.9953 - val_loss: 0.0229 - val_accuracy: 0.9945
# Epoch 12/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0158 - accuracy: 0.9951 - val_loss: 0.0163 - val_accuracy: 0.9965
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.2.best/assets
# Epoch 13/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0188 - accuracy: 0.9947 - val_loss: 0.0190 - val_accuracy: 0.9950
# Epoch 14/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0172 - accuracy: 0.9947 - val_loss: 0.0172 - val_accuracy: 0.9960
# Epoch 15/50
# 1125/1125 [==============================] - 6s 6ms/step - loss: 0.0180 - accuracy: 0.9950 - val_loss: 0.0261 - val_accuracy: 0.9940
# Epoch 16/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0179 - accuracy: 0.9951 - val_loss: 0.0207 - val_accuracy: 0.9952
# Epoch 17/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0122 - accuracy: 0.9964 - val_loss: 0.0199 - val_accuracy: 0.9962
# Epoch 18/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0145 - accuracy: 0.9957 - val_loss: 0.0221 - val_accuracy: 0.9950
# Epoch 19/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0150 - accuracy: 0.9959 - val_loss: 0.0229 - val_accuracy: 0.9952
# Epoch 20/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0153 - accuracy: 0.9953 - val_loss: 0.0277 - val_accuracy: 0.9945
# Epoch 21/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0115 - accuracy: 0.9969 - val_loss: 0.0268 - val_accuracy: 0.9940
# Epoch 22/50
# 1125/1125 [==============================] - 6s 6ms/step - loss: 0.0147 - accuracy: 0.9960 - val_loss: 0.0271 - val_accuracy: 0.9948
# Epoch 23/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0152 - accuracy: 0.9958 - val_loss: 0.0201 - val_accuracy: 0.9962
# Epoch 24/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0109 - accuracy: 0.9970 - val_loss: 0.0192 - val_accuracy: 0.9960
# Epoch 25/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0150 - accuracy: 0.9962 - val_loss: 0.0252 - val_accuracy: 0.9945
# Epoch 26/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0152 - accuracy: 0.9957 - val_loss: 0.0339 - val_accuracy: 0.9923
# Epoch 27/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0259 - accuracy: 0.9931 - val_loss: 0.0207 - val_accuracy: 0.9950
# Epoch 28/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0104 - accuracy: 0.9968 - val_loss: 0.0231 - val_accuracy: 0.9952
# Epoch 29/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0109 - accuracy: 0.9971 - val_loss: 0.0243 - val_accuracy: 0.9955
# Epoch 30/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0104 - accuracy: 0.9969 - val_loss: 0.0223 - val_accuracy: 0.9950
# Epoch 31/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0122 - accuracy: 0.9967 - val_loss: 0.0330 - val_accuracy: 0.9937
# Epoch 32/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0093 - accuracy: 0.9976 - val_loss: 0.0276 - val_accuracy: 0.9940
# Epoch 33/50
# 1125/1125 [==============================] - 6s 6ms/step - loss: 0.0110 - accuracy: 0.9966 - val_loss: 0.0262 - val_accuracy: 0.9937
# Epoch 34/50
# 1125/1125 [==============================] - 7s 6ms/step - loss: 0.0111 - accuracy: 0.9969 - val_loss: 0.0193 - val_accuracy: 0.9967
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.2.best/assets
# Epoch 35/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0094 - accuracy: 0.9972 - val_loss: 0.0236 - val_accuracy: 0.9958
# Epoch 36/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0121 - accuracy: 0.9968 - val_loss: 0.0283 - val_accuracy: 0.9935
# Epoch 37/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0121 - accuracy: 0.9967 - val_loss: 0.0196 - val_accuracy: 0.9960
# Epoch 38/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0123 - accuracy: 0.9965 - val_loss: 0.0200 - val_accuracy: 0.9965
# Epoch 39/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0076 - accuracy: 0.9980 - val_loss: 0.0189 - val_accuracy: 0.9965
# Epoch 40/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0082 - accuracy: 0.9979 - val_loss: 0.0275 - val_accuracy: 0.9952
# Epoch 41/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0090 - accuracy: 0.9975 - val_loss: 0.0188 - val_accuracy: 0.9962
# Epoch 42/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0126 - accuracy: 0.9969 - val_loss: 0.0228 - val_accuracy: 0.9955
# Epoch 43/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0081 - accuracy: 0.9981 - val_loss: 0.0200 - val_accuracy: 0.9958
# Epoch 44/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0077 - accuracy: 0.9976 - val_loss: 0.0200 - val_accuracy: 0.9965
# Epoch 45/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0090 - accuracy: 0.9977 - val_loss: 0.0155 - val_accuracy: 0.9973
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.2.best/assets
# Epoch 46/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0129 - accuracy: 0.9962 - val_loss: 0.0214 - val_accuracy: 0.9950
# Epoch 47/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0108 - accuracy: 0.9967 - val_loss: 0.0170 - val_accuracy: 0.9965
# Epoch 48/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0067 - accuracy: 0.9982 - val_loss: 0.0313 - val_accuracy: 0.9940
# Epoch 49/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0087 - accuracy: 0.9972 - val_loss: 0.0164 - val_accuracy: 0.9962
# Epoch 50/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0085 - accuracy: 0.9976 - val_loss: 0.0129 - val_accuracy: 0.9970
# Fold 2, 50 epochs, 327 sec
# accuracy: 99.73%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/50
# 1125/1125 [==============================] - 7s 6ms/step - loss: 0.5870 - accuracy: 0.7418 - val_loss: 0.5738 - val_accuracy: 0.7452
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.3.best/assets
# Epoch 2/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5691 - accuracy: 0.7514 - val_loss: 0.5698 - val_accuracy: 0.7452
# Epoch 3/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5692 - accuracy: 0.7483 - val_loss: 0.5698 - val_accuracy: 0.7452
# Epoch 4/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5631 - accuracy: 0.7529 - val_loss: 0.5685 - val_accuracy: 0.7452
# Epoch 5/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5602 - accuracy: 0.7538 - val_loss: 0.5688 - val_accuracy: 0.7452
# Epoch 6/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5678 - accuracy: 0.7470 - val_loss: 0.5675 - val_accuracy: 0.7452
# Epoch 7/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5658 - accuracy: 0.7476 - val_loss: 0.5675 - val_accuracy: 0.7452
# Epoch 8/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5624 - accuracy: 0.7509 - val_loss: 0.5685 - val_accuracy: 0.7452
# Epoch 9/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5616 - accuracy: 0.7525 - val_loss: 0.5675 - val_accuracy: 0.7452
# Epoch 10/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5662 - accuracy: 0.7477 - val_loss: 0.5675 - val_accuracy: 0.7452
# Epoch 11/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5624 - accuracy: 0.7510 - val_loss: 0.5679 - val_accuracy: 0.7452
# Epoch 12/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5605 - accuracy: 0.7527 - val_loss: 0.5684 - val_accuracy: 0.7452
# Epoch 13/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5608 - accuracy: 0.7528 - val_loss: 0.5676 - val_accuracy: 0.7452
# Epoch 14/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5639 - accuracy: 0.7495 - val_loss: 0.5676 - val_accuracy: 0.7452
# Epoch 15/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5597 - accuracy: 0.7534 - val_loss: 0.5675 - val_accuracy: 0.7452
# Epoch 16/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5614 - accuracy: 0.7514 - val_loss: 0.5675 - val_accuracy: 0.7452
# Epoch 17/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5596 - accuracy: 0.7526 - val_loss: 0.5693 - val_accuracy: 0.7452
# Epoch 18/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5642 - accuracy: 0.7494 - val_loss: 0.5684 - val_accuracy: 0.7452
# Epoch 19/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5621 - accuracy: 0.7509 - val_loss: 0.5675 - val_accuracy: 0.7452
# Epoch 20/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5668 - accuracy: 0.7468 - val_loss: 0.5682 - val_accuracy: 0.7452
# Epoch 21/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5644 - accuracy: 0.7486 - val_loss: 0.5682 - val_accuracy: 0.7452
# Epoch 22/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5626 - accuracy: 0.7510 - val_loss: 0.5675 - val_accuracy: 0.7452
# Epoch 23/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5673 - accuracy: 0.7461 - val_loss: 0.5680 - val_accuracy: 0.7452
# Epoch 24/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5589 - accuracy: 0.7537 - val_loss: 0.5675 - val_accuracy: 0.7452
# Epoch 25/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5633 - accuracy: 0.7500 - val_loss: 0.5676 - val_accuracy: 0.7452
# Epoch 26/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5625 - accuracy: 0.7501 - val_loss: 0.5680 - val_accuracy: 0.7452
# Epoch 27/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5657 - accuracy: 0.7477 - val_loss: 0.5679 - val_accuracy: 0.7452
# Epoch 28/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5609 - accuracy: 0.7522 - val_loss: 0.5675 - val_accuracy: 0.7452
# Epoch 29/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5631 - accuracy: 0.7503 - val_loss: 0.5679 - val_accuracy: 0.7452
# Epoch 30/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5607 - accuracy: 0.7521 - val_loss: 0.5675 - val_accuracy: 0.7452
# Epoch 31/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5616 - accuracy: 0.7511 - val_loss: 0.5694 - val_accuracy: 0.7452
# Epoch 32/50
# 1125/1125 [==============================] - 6s 6ms/step - loss: 0.5659 - accuracy: 0.7474 - val_loss: 0.5675 - val_accuracy: 0.7452
# Epoch 33/50
# 1125/1125 [==============================] - 7s 6ms/step - loss: 0.5625 - accuracy: 0.7503 - val_loss: 0.5676 - val_accuracy: 0.7452
# Epoch 34/50
# 1125/1125 [==============================] - 6s 6ms/step - loss: 0.5618 - accuracy: 0.7511 - val_loss: 0.5680 - val_accuracy: 0.7452
# Epoch 35/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5658 - accuracy: 0.7473 - val_loss: 0.5675 - val_accuracy: 0.7452
# Epoch 36/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5650 - accuracy: 0.7480 - val_loss: 0.5675 - val_accuracy: 0.7452
# Epoch 37/50
# 1125/1125 [==============================] - 6s 6ms/step - loss: 0.5587 - accuracy: 0.7536 - val_loss: 0.5679 - val_accuracy: 0.7452
# Epoch 38/50
# 1125/1125 [==============================] - 6s 6ms/step - loss: 0.5628 - accuracy: 0.7497 - val_loss: 0.5680 - val_accuracy: 0.7452
# Epoch 39/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5643 - accuracy: 0.7485 - val_loss: 0.5675 - val_accuracy: 0.7452
# Epoch 40/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5627 - accuracy: 0.7500 - val_loss: 0.5677 - val_accuracy: 0.7452
# Epoch 41/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5642 - accuracy: 0.7487 - val_loss: 0.5675 - val_accuracy: 0.7452
# Epoch 42/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5644 - accuracy: 0.7484 - val_loss: 0.5675 - val_accuracy: 0.7452
# Epoch 43/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5631 - accuracy: 0.7498 - val_loss: 0.5675 - val_accuracy: 0.7452
# Epoch 44/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5591 - accuracy: 0.7533 - val_loss: 0.5678 - val_accuracy: 0.7452
# Epoch 45/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5645 - accuracy: 0.7484 - val_loss: 0.5679 - val_accuracy: 0.7452
# Epoch 46/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5614 - accuracy: 0.7512 - val_loss: 0.5675 - val_accuracy: 0.7452
# Epoch 47/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5678 - accuracy: 0.7453 - val_loss: 0.5675 - val_accuracy: 0.7452
# Epoch 48/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5604 - accuracy: 0.7519 - val_loss: 0.5678 - val_accuracy: 0.7452
# Epoch 49/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5616 - accuracy: 0.7512 - val_loss: 0.5676 - val_accuracy: 0.7452
# Epoch 50/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5647 - accuracy: 0.7480 - val_loss: 0.5684 - val_accuracy: 0.7452
# Fold 3, 50 epochs, 310 sec
# accuracy: 74.52%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/50
# 1125/1125 [==============================] - 7s 6ms/step - loss: 0.5907 - accuracy: 0.7381 - val_loss: 0.5568 - val_accuracy: 0.7527
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.4.best/assets
# Epoch 2/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5744 - accuracy: 0.7476 - val_loss: 0.5594 - val_accuracy: 0.7527
# Epoch 3/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5642 - accuracy: 0.7523 - val_loss: 0.5593 - val_accuracy: 0.7527
# Epoch 4/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5650 - accuracy: 0.7503 - val_loss: 0.5605 - val_accuracy: 0.7527
# Epoch 5/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5682 - accuracy: 0.7474 - val_loss: 0.5594 - val_accuracy: 0.7527
# Epoch 6/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5672 - accuracy: 0.7477 - val_loss: 0.5593 - val_accuracy: 0.7527
# Epoch 7/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5628 - accuracy: 0.7506 - val_loss: 0.5601 - val_accuracy: 0.7527
# Epoch 8/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5686 - accuracy: 0.7454 - val_loss: 0.5593 - val_accuracy: 0.7527
# Epoch 9/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5607 - accuracy: 0.7526 - val_loss: 0.5597 - val_accuracy: 0.7527
# Epoch 10/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5629 - accuracy: 0.7506 - val_loss: 0.5595 - val_accuracy: 0.7527
# Epoch 11/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5647 - accuracy: 0.7493 - val_loss: 0.5594 - val_accuracy: 0.7527
# Epoch 12/50
# 1125/1125 [==============================] - 6s 6ms/step - loss: 0.5612 - accuracy: 0.7515 - val_loss: 0.5603 - val_accuracy: 0.7527
# Epoch 13/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5666 - accuracy: 0.7474 - val_loss: 0.5598 - val_accuracy: 0.7527
# Epoch 14/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5630 - accuracy: 0.7500 - val_loss: 0.5593 - val_accuracy: 0.7527
# Epoch 15/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5609 - accuracy: 0.7523 - val_loss: 0.5593 - val_accuracy: 0.7527
# Epoch 16/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5626 - accuracy: 0.7502 - val_loss: 0.5627 - val_accuracy: 0.7527
# Epoch 17/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5655 - accuracy: 0.7481 - val_loss: 0.5596 - val_accuracy: 0.7527
# Epoch 18/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5656 - accuracy: 0.7477 - val_loss: 0.5598 - val_accuracy: 0.7527
# Epoch 19/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5605 - accuracy: 0.7525 - val_loss: 0.5596 - val_accuracy: 0.7527
# Epoch 20/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5620 - accuracy: 0.7509 - val_loss: 0.5593 - val_accuracy: 0.7527
# Epoch 21/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5641 - accuracy: 0.7492 - val_loss: 0.5604 - val_accuracy: 0.7527
# Epoch 22/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5612 - accuracy: 0.7515 - val_loss: 0.5595 - val_accuracy: 0.7527
# Epoch 23/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5648 - accuracy: 0.7479 - val_loss: 0.5597 - val_accuracy: 0.7527
# Epoch 24/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5602 - accuracy: 0.7523 - val_loss: 0.5597 - val_accuracy: 0.7527
# Epoch 25/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5639 - accuracy: 0.7494 - val_loss: 0.5593 - val_accuracy: 0.7527
# Epoch 26/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5618 - accuracy: 0.7511 - val_loss: 0.5593 - val_accuracy: 0.7527
# Epoch 27/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5661 - accuracy: 0.7469 - val_loss: 0.5593 - val_accuracy: 0.7527
# Epoch 28/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5618 - accuracy: 0.7511 - val_loss: 0.5617 - val_accuracy: 0.7527
# Epoch 29/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5609 - accuracy: 0.7520 - val_loss: 0.5596 - val_accuracy: 0.7527
# Epoch 30/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5625 - accuracy: 0.7504 - val_loss: 0.5596 - val_accuracy: 0.7527
# Epoch 31/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5617 - accuracy: 0.7514 - val_loss: 0.5600 - val_accuracy: 0.7527
# Epoch 32/50
# 1125/1125 [==============================] - 6s 6ms/step - loss: 0.5626 - accuracy: 0.7503 - val_loss: 0.5593 - val_accuracy: 0.7527
# Epoch 33/50
# 1125/1125 [==============================] - 7s 6ms/step - loss: 0.5654 - accuracy: 0.7478 - val_loss: 0.5598 - val_accuracy: 0.7527
# Epoch 34/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5607 - accuracy: 0.7519 - val_loss: 0.5593 - val_accuracy: 0.7527
# Epoch 35/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5591 - accuracy: 0.7532 - val_loss: 0.5593 - val_accuracy: 0.7527
# Epoch 36/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5592 - accuracy: 0.7533 - val_loss: 0.5616 - val_accuracy: 0.7527
# Epoch 37/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5628 - accuracy: 0.7500 - val_loss: 0.5593 - val_accuracy: 0.7527
# Epoch 38/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5634 - accuracy: 0.7495 - val_loss: 0.5593 - val_accuracy: 0.7527
# Epoch 39/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5625 - accuracy: 0.7502 - val_loss: 0.5593 - val_accuracy: 0.7527
# Epoch 40/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5638 - accuracy: 0.7489 - val_loss: 0.5607 - val_accuracy: 0.7527
# Epoch 41/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5636 - accuracy: 0.7494 - val_loss: 0.5593 - val_accuracy: 0.7527
# Epoch 42/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5652 - accuracy: 0.7476 - val_loss: 0.5593 - val_accuracy: 0.7527
# Epoch 43/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5674 - accuracy: 0.7458 - val_loss: 0.5598 - val_accuracy: 0.7527
# Epoch 44/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5638 - accuracy: 0.7491 - val_loss: 0.5595 - val_accuracy: 0.7527
# Epoch 45/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5627 - accuracy: 0.7501 - val_loss: 0.5594 - val_accuracy: 0.7527
# Epoch 46/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5641 - accuracy: 0.7488 - val_loss: 0.5597 - val_accuracy: 0.7527
# Epoch 47/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5631 - accuracy: 0.7498 - val_loss: 0.5599 - val_accuracy: 0.7527
# Epoch 48/50
# 1125/1125 [==============================] - 6s 6ms/step - loss: 0.5581 - accuracy: 0.7541 - val_loss: 0.5593 - val_accuracy: 0.7527
# Epoch 49/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5673 - accuracy: 0.7460 - val_loss: 0.5606 - val_accuracy: 0.7527
# Epoch 50/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5636 - accuracy: 0.7492 - val_loss: 0.5593 - val_accuracy: 0.7527
# Fold 4, 50 epochs, 307 sec
# accuracy: 75.27%
# COMPILE...
# ...COMPILED
# FIT
# Epoch 1/50
# 1125/1125 [==============================] - 7s 6ms/step - loss: 0.5810 - accuracy: 0.7438 - val_loss: 0.5585 - val_accuracy: 0.7535
# INFO:tensorflow:Assets written to: /content/drive/My Drive/data/CNN523.cv.5.best/assets
# Epoch 2/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5699 - accuracy: 0.7491 - val_loss: 0.5592 - val_accuracy: 0.7535
# Epoch 3/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5689 - accuracy: 0.7474 - val_loss: 0.5585 - val_accuracy: 0.7535
# Epoch 4/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5647 - accuracy: 0.7506 - val_loss: 0.5598 - val_accuracy: 0.7535
# Epoch 5/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5667 - accuracy: 0.7478 - val_loss: 0.5585 - val_accuracy: 0.7535
# Epoch 6/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5610 - accuracy: 0.7523 - val_loss: 0.5588 - val_accuracy: 0.7535
# Epoch 7/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5605 - accuracy: 0.7534 - val_loss: 0.5589 - val_accuracy: 0.7535
# Epoch 8/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5591 - accuracy: 0.7549 - val_loss: 0.5585 - val_accuracy: 0.7535
# Epoch 9/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5643 - accuracy: 0.7496 - val_loss: 0.5585 - val_accuracy: 0.7535
# Epoch 10/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5643 - accuracy: 0.7492 - val_loss: 0.5591 - val_accuracy: 0.7535
# Epoch 11/50
# 1125/1125 [==============================] - 6s 6ms/step - loss: 0.5636 - accuracy: 0.7499 - val_loss: 0.5612 - val_accuracy: 0.7535
# Epoch 12/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5625 - accuracy: 0.7509 - val_loss: 0.5586 - val_accuracy: 0.7535
# Epoch 13/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5664 - accuracy: 0.7475 - val_loss: 0.5587 - val_accuracy: 0.7535
# Epoch 14/50
# 1125/1125 [==============================] - 6s 6ms/step - loss: 0.5649 - accuracy: 0.7486 - val_loss: 0.5589 - val_accuracy: 0.7535
# Epoch 15/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5671 - accuracy: 0.7466 - val_loss: 0.5585 - val_accuracy: 0.7535
# Epoch 16/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5645 - accuracy: 0.7491 - val_loss: 0.5585 - val_accuracy: 0.7535
# Epoch 17/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5581 - accuracy: 0.7545 - val_loss: 0.5586 - val_accuracy: 0.7535
# Epoch 18/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5636 - accuracy: 0.7497 - val_loss: 0.5586 - val_accuracy: 0.7535
# Epoch 19/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5615 - accuracy: 0.7518 - val_loss: 0.5599 - val_accuracy: 0.7535
# Epoch 20/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5643 - accuracy: 0.7490 - val_loss: 0.5585 - val_accuracy: 0.7535
# Epoch 21/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5612 - accuracy: 0.7518 - val_loss: 0.5601 - val_accuracy: 0.7535
# Epoch 22/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5577 - accuracy: 0.7552 - val_loss: 0.5591 - val_accuracy: 0.7535
# Epoch 23/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5632 - accuracy: 0.7499 - val_loss: 0.5586 - val_accuracy: 0.7535
# Epoch 24/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5605 - accuracy: 0.7525 - val_loss: 0.5588 - val_accuracy: 0.7535
# Epoch 25/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5619 - accuracy: 0.7510 - val_loss: 0.5586 - val_accuracy: 0.7535
# Epoch 26/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5649 - accuracy: 0.7483 - val_loss: 0.5587 - val_accuracy: 0.7535
# Epoch 27/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5633 - accuracy: 0.7500 - val_loss: 0.5585 - val_accuracy: 0.7535
# Epoch 28/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5610 - accuracy: 0.7517 - val_loss: 0.5585 - val_accuracy: 0.7535
# Epoch 29/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5615 - accuracy: 0.7513 - val_loss: 0.5586 - val_accuracy: 0.7535
# Epoch 30/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5654 - accuracy: 0.7477 - val_loss: 0.5585 - val_accuracy: 0.7535
# Epoch 31/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5635 - accuracy: 0.7492 - val_loss: 0.5586 - val_accuracy: 0.7535
# Epoch 32/50
# 1125/1125 [==============================] - 7s 6ms/step - loss: 0.5697 - accuracy: 0.7437 - val_loss: 0.5588 - val_accuracy: 0.7535
# Epoch 33/50
# 1125/1125 [==============================] - 7s 6ms/step - loss: 0.5622 - accuracy: 0.7504 - val_loss: 0.5588 - val_accuracy: 0.7535
# Epoch 34/50
# 1125/1125 [==============================] - 6s 6ms/step - loss: 0.5632 - accuracy: 0.7496 - val_loss: 0.5595 - val_accuracy: 0.7535
# Epoch 35/50
# 1125/1125 [==============================] - 6s 6ms/step - loss: 0.5649 - accuracy: 0.7483 - val_loss: 0.5592 - val_accuracy: 0.7535
# Epoch 36/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5680 - accuracy: 0.7452 - val_loss: 0.5587 - val_accuracy: 0.7535
# Epoch 37/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5670 - accuracy: 0.7462 - val_loss: 0.5592 - val_accuracy: 0.7535
# Epoch 38/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5615 - accuracy: 0.7514 - val_loss: 0.5586 - val_accuracy: 0.7535
# Epoch 39/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5638 - accuracy: 0.7490 - val_loss: 0.5585 - val_accuracy: 0.7535
# Epoch 40/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5630 - accuracy: 0.7498 - val_loss: 0.5586 - val_accuracy: 0.7535
# Epoch 41/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5658 - accuracy: 0.7475 - val_loss: 0.5590 - val_accuracy: 0.7535
# Epoch 42/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5655 - accuracy: 0.7477 - val_loss: 0.5585 - val_accuracy: 0.7535
# Epoch 43/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5637 - accuracy: 0.7493 - val_loss: 0.5597 - val_accuracy: 0.7535
# Epoch 44/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5630 - accuracy: 0.7499 - val_loss: 0.5587 - val_accuracy: 0.7535
# Epoch 45/50
# 1125/1125 [==============================] - 6s 6ms/step - loss: 0.5626 - accuracy: 0.7503 - val_loss: 0.5585 - val_accuracy: 0.7535
# Epoch 46/50
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.5643 - accuracy: 0.7487 - val_loss: 0.5590 - val_accuracy: 0.7535
# Epoch 47/50
# 1125/1125 [==============================] - 6s 6ms/step - loss: 0.5651 - accuracy: 0.7478 - val_loss: 0.5588 - val_accuracy: 0.7535
# Epoch 48/50
# 1125/1125 [==============================] - 6s 6ms/step - loss: 0.5615 - accuracy: 0.7515 - val_loss: 0.5585 - val_accuracy: 0.7535
# Epoch 49/50
# 1125/1125 [==============================] - 6s 6ms/step - loss: 0.5572 - accuracy: 0.7551 - val_loss: 0.5590 - val_accuracy: 0.7535
# Epoch 50/50
# 1125/1125 [==============================] - 6s 6ms/step - loss: 0.5597 - accuracy: 0.7531 - val_loss: 0.5587 - val_accuracy: 0.7535
# Fold 5, 50 epochs, 312 sec
# accuracy: 75.35%
#
# 5-way Cross Validation mean 84.90% (+/- 12.07%)
# Done
