# %% [markdown]
# # Random Forest 08
# To reduce overfitting, use 1/10 of patches, restrict tree depth, and add trees. Patch-level accuracy increased to 73%.
#
# This ran on Air.

# %%
import datetime
print(datetime.datetime.now())
from platform import python_version
print('Python',python_version())
import csv
import numpy as np
import pandas as pd
import matplotlib as plt
import random
import sklearn   # pip install --upgrade scikit-learn
print('sklearn',sklearn.__version__)
# Out:
# 2022-07-23 11:20:43.210723
# Python 3.8.10
# sklearn 1.0.2

# %%
# Shuffle X,y in tandem -- can cause shape problems
from sklearn.utils import shuffle
# The model
from sklearn.ensemble import RandomForestClassifier

# %%
# Our input is the output from the Data notebooks.
# These csv files were filtered to remove give-away columns and bad rows.
BASE_PATH='/Users/jasonmiller/Downloads/CellProfilerFiltered/'   # air
BASE_PATH='/home/jrm/Adjeroh/Naved/July_Run/CellProfilerFiltered/'  # alien
# This is the patch-level csv file: one row per patch, with nucleus totals.
# Later, incorporate the nucleus-specific csv files.
FILENAME='Process100_Image.csv'
# This directory contains lists of patch filenames,
# divided into 5 folds of train/valid splits.
# Notice patch filename [0:19] is case ID, [0:23] is WSI ID,
# and last column is the 6-way cancer class (zero to five) of the case.
# For example, fold0_train.txt starts:
# TCGA-06-0129-01Z-00-DX1_5400_5100.png, 0
# TCGA-06-0129-01Z-00-DX1_5700_6000.png, 0
LEN_PATIENT_ID = 19
SPLITS_BASE='/Users/jasonmiller/Downloads/TrainTestSplit/'    #air
SPLITS_BASE='/home/jrm/Adjeroh/Naved/July_Run/TrainTestSplit/'  # alien
SPLITS_FILES = [
    ('fold0_train.txt','fold0_test.txt'),
    ('fold1_train.txt','fold1_test.txt'),
    ('fold2_train.txt','fold2_test.txt'),
    ('fold3_train.txt','fold3_test.txt'),
    ('fold4_train.txt','fold4_test.txt'),
]
NUM_FOLDS = 5
PATIENT_TO_CANCER = {}  # hash case ID to class number

# %% [markdown]
# ## Data loading functions

# %%
# sklearn can do this but we were stumbling on shape & type problems
def list_shuffle(X):   
    L = len(X)
    for i in range(L):
        r = random.randrange(0,L)
        if i!=r:
            temp = X[i]
            X[i] = X[r]
            X[r] = temp
    return X

# %%
# Given a case ID = patient name = directory, load the csv file.
# Expect a value like p='TCGA-S9-A6UB-01Z-00'
def load_patient_data(p):
    filepath=BASE_PATH+p+'/'+FILENAME
    df = pd.read_csv(filepath)
    return df

# %%
# Given fold, load the case/patient IDs separated into training and validation.
# Fold should be an in between 0 and 4 for 5-fold cross validation.
# The returned list has unique strings like  TCGA-06-0129-01Z-00
def _load_patient_names(filename):
    patients=[]
    with open(filename) as infile:
        rows = csv.reader(infile)
        for row in rows:
            patient = row[0][:LEN_PATIENT_ID]
            cancer_class = int(row[1])
            if patient in PATIENT_TO_CANCER:
                if PATIENT_TO_CANCER[patient] != cancer_class:
                    raise Exception('One patient in two classes:',patient)
            else:
                PATIENT_TO_CANCER[patient] = cancer_class
            patients.append(patient)
    patients = list(np.unique(patients))
    return patients
def load_patient_names(fold):
    filenames = SPLITS_FILES[fold]  # tuple of train,valid
    train_patients = _load_patient_names(SPLITS_BASE+filenames[0])
    valid_patients = _load_patient_names(SPLITS_BASE+filenames[1])
    return train_patients,valid_patients

# %%
# Read csv into pandas dataframes and concatenate dataframes.
# This is too slow! Like 10 min per invocation.
def _load_train_valid_set1(patients):
    X = None  # instances with features
    y = None  # labels = cancer class
    z = []  # patient_id for aggregation
    for patient in patients:
        df = load_patient_data(patient)
        label = PATIENT_TO_CANCER[patient]
        if X is None:
            X = df 
            y = np.full(shape=len(df), fill_value=label, dtype=np.int8)
        else:
            X = pd.concat( (X, df) )
            more = np.full(shape=len(df), fill_value=label, dtype=np.int8)
            y = np.concatenate( (y, more) )
        z = z + [patient]*len(df)  # same ID for all patches from one patient
    return X,y,z

# %%
# Read csv into list and hold off building the dataframe till the end.
# This runs out of memory!
def _load_train_valid_set2(patients):
    X = []  # instances with features
    y = []  # labels = cancer class
    z = []  # patient_id for aggregation
    header = None
    patient_count = 0
    for patient in patients:
        row_count = 0
        patient_count += 1
        filepath=BASE_PATH+patient+'/'+FILENAME
        label = PATIENT_TO_CANCER[patient]
        with open(filepath) as infile:
            rows = csv.reader(infile)
            for row in rows:
                if row_count == 0:
                    if header is None:
                        header = row
                else:
                    X.append(row)
                    y.append(label)
                    z.append(patient)
                row_count += 1
        print('Patients:',patient_count,'Rows:',row_count)
    X = pd.DataFrame(X)
    X.columns = header
    return X,y,z

# %%
# Slurp csv into numpy array.
# This works!
def _load_train_valid_set3(patients,save_mem=False):
    X = None  # instances with features
    y = None  # labels = cancer class
    z = None  # patient_id for aggregation
    for patient in patients:
        filepath=BASE_PATH+patient+'/'+FILENAME
        label = PATIENT_TO_CANCER[patient]
        Xall = np.loadtxt(filepath,skiprows=1,delimiter=',')
        if (save_mem):
            Xi = Xall[0::10].copy()  # every tenth row
        else:
            Xi = Xall
        yi = np.full(shape=len(Xi), fill_value=label, dtype=np.int8)
        zi = [patient]*len(Xi)  # same ID for all patches from one patient
        if X is None:
            X = Xi
            y = yi
            z = zi
        else:
            X = np.concatenate( (X, Xi) )
            y = np.concatenate( (y, yi) )
            z = np.concatenate( (z, zi) )
    X = pd.DataFrame(X)
    # DataFrame column headers are not required for the machine learning.
    # We'll add them just for debugging. Arbitrarily use first row of first file.
    patient = patients[0]
    filepath=BASE_PATH+patient+'/'+FILENAME
    with open(filepath) as infile:
        rows = csv.reader(infile)
        for row in rows:
            header = row
            break
    X.columns = header
    return X,y,z

# %%
# Load csv rows for one set of train+valid patient names.
# This is slow, probably due to concatenating dataframes.
# Consider a rewrite that concatenates csv before constructing a dataframe.
def load_train_valid_set(train_patient_names,valid_patient_names):
    X_train,y_train,z_train = _load_train_valid_set3(train_patient_names,True)
    print('Loaded lengths X,y,z:',X_train.shape,len(y_train),len(z_train))
    X_valid,y_valid,z_valid = _load_train_valid_set3(valid_patient_names,True)
    print('Loaded lengths X,y,z:',X_valid.shape,len(y_valid),len(z_valid))
    
    # TO DO: raise exception if any valid patient is also a train patient
    return X_train,y_train,z_train,X_valid,y_valid,z_valid

# %% [markdown]
# ## Aggregation functions

# %%
# Later, weight each patch label by the confidence i.e. score
def aggregate_accuracy(y_pred,z_valid):
    L = len(y_pred)
    if L != len(z_valid):
        raise Exception('Lengths of y and z do not match')
    correct = {}
    incorrect = {}
    patients = np.unique(z_valid)
    for patient in patients:
        correct[patient]=0
        incorrect[patient]=0
    for i in range(L):
        patient = z_valid[i]
        label = PATIENT_TO_CANCER[patient]
        pred = y_pred[i]
        if pred == label:
            correct[patient] += 1
        else:
            incorrect[patient] += 1
    numerator = 0
    denominator = 0
    for patient in patients:
        denominator += 1
        if correct[patient]>incorrect[patient]:
            numerator += 1
    accuracy = float(0)
    if denominator>0:
        accuracy = 100.0*numerator/denominator 
    return accuracy

# %% [markdown]
# ## Main loop: Load, Classify, Report

# %%
def important_features(model):
        # Prereqs: fit().
        names = model.feature_names_in_
        importances = model.feature_importances_
        pairs = np.column_stack( (names,importances) )
        top_array = sorted(pairs, key = lambda e:e[1], reverse=True)
        # There must be a way to do this witout a loop!
        top_list = []
        for i in top_array:
             top_list.append((i[1],i[0]))  # 0=feature_name, 1=importance
        top_df = pd.DataFrame(top_list)
        return top_df

# %%
patch_accuracies = []   # summary statistics
patient_accuracies = [] # summary statistics

for fold in range(NUM_FOLDS):
    print()
    print(datetime.datetime.now(),'Fold',fold,'Loading...')
    train_patients,valid_patients = load_patient_names(fold)  
    X_train,y_train,z_train,X_valid,y_valid,z_valid = \
        load_train_valid_set(train_patients,valid_patients)    
    # print('Fold',fold,'patients train',train_patients,'patients valid',valid_patients)
    # print('Fold:',fold,'patches train',X_train.shape,'patches valid',X_valid.shape)

    # This shuffle is pro forma, not strictly necessary.
    # CNN models are sensitive to train set order but RF models are not. 
    print(datetime.datetime.now(),'Shuffle...')
    X_train,y_train = shuffle(X_train,y_train)

    print(datetime.datetime.now(),'Train...')
    # min_samples_leaf=1 (default) led to overfitting
    rfc = RandomForestClassifier(max_depth=5,n_estimators=500)
    rfc.fit(X_train,y_train)  # slow
    
    print(datetime.datetime.now(),'Ranked feature imporances...')
    top = important_features(rfc)
    #pd.set_option('display.max_rows', None)
    print(top.loc[:10])
    
    print(datetime.datetime.now(),'Evaluate...')
    y_pred = rfc.predict(X_train)
    matches = np.count_nonzero(y_train==y_pred)
    accuracy = 100.0 * matches / len(y_pred)
    print('Fold',fold,'Patch-level Training Accuracy:',accuracy)
    
    print(datetime.datetime.now(),'Validate...')
    y_pred = rfc.predict(X_valid)
    matches = np.count_nonzero(y_valid==y_pred)
    accuracy = 100.0 * matches / len(y_pred)
    print('Fold',fold,'Patch-level Validation Accuracy:',accuracy)
    patch_accuracies.append(accuracy)
    
    accuracy = aggregate_accuracy(y_pred,z_valid)
    patient_accuracies.append(accuracy)
    print('Fold',fold,'Patient-level Validation Accuracy:',accuracy)
    
    # This shouldn't be necessary but it seems to reduce memory footprint.
    X_train=None
    X_valid=None
    y_train=None
    y_valid=None
    z_train=None
    z_valid=None
    rfc = None
    y_pred = None
    matches = None
# Out:
# 2022-07-23 11:20:43.650735 Fold 0 Loading...
# Loaded lengths X,y,z: (6035, 5302) 6035 6035
# Loaded lengths X,y,z: (1590, 5302) 1590 1590
# 2022-07-23 11:21:35.182371 Shuffle...
# 2022-07-23 11:21:35.287305 Train...
# 2022-07-23 11:22:18.121539 Ranked feature imporances...
#            0                                                  1
# 0   0.020385                Mean_Nucleus_AreaShape_MedianRadius
# 1   0.016207              Median_Nucleus_AreaShape_MedianRadius
# 2   0.011609             Median_Nucleus_AreaShape_MaximumRadius
# 3   0.011454             Mean_Nucleus_AreaShape_MinorAxisLength
# 4   0.011254                  Mean_Nucleus_AreaShape_MeanRadius
# 5   0.011047  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_3...
# 6   0.011037  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_7...
# 7   0.010281  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_7...
# 8   0.010254  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_5...
# 9   0.009902  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_7_0...
# 10  0.009501  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_4_0...
# 2022-07-23 11:22:18.154662 Evaluate...
# Fold 0 Patch-level Training Accuracy: 73.65368682684341
# 2022-07-23 11:22:18.471366 Validate...
# Fold 0 Patch-level Validation Accuracy: 51.320754716981135
# Fold 0 Patient-level Validation Accuracy: 48.0
#
# 2022-07-23 11:22:18.577874 Fold 1 Loading...
# Loaded lengths X,y,z: (5643, 5302) 5643 5643
# Loaded lengths X,y,z: (1982, 5302) 1982 1982
# 2022-07-23 11:23:10.213287 Shuffle...
# 2022-07-23 11:23:10.331498 Train...
# 2022-07-23 11:23:50.386829 Ranked feature imporances...
#            0                                                  1
# 0   0.014656               Mean_Nucleus_AreaShape_MaximumRadius
# 1   0.013164  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_5...
# 2   0.012392  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_4_0...
# 3   0.011930                Mean_Nucleus_AreaShape_MedianRadius
# 4   0.011601  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_7_0...
# 5   0.011559  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_5...
# 6   0.011478  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_7...
# 7   0.011252                  Mean_Nucleus_AreaShape_MeanRadius
# 8   0.011084  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_7_0...
# 9   0.010665  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_3...
# 10  0.010458  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_4...
# 2022-07-23 11:23:50.417469 Evaluate...
# Fold 1 Patch-level Training Accuracy: 72.10703526493
# 2022-07-23 11:23:50.735561 Validate...
# Fold 1 Patch-level Validation Accuracy: 66.75075681130171
# Fold 1 Patient-level Validation Accuracy: 48.0
#
# 2022-07-23 11:23:50.866508 Fold 2 Loading...
# Loaded lengths X,y,z: (6023, 5302) 6023 6023
# Loaded lengths X,y,z: (1602, 5302) 1602 1602
# 2022-07-23 11:24:42.876391 Shuffle...
# 2022-07-23 11:24:42.998392 Train...
# 2022-07-23 11:25:26.170370 Ranked feature imporances...
#            0                                                  1
# 0   0.016433                Median_Nucleus_AreaShape_MeanRadius
# 1   0.012127  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_7...
# 2   0.011792              Median_Nucleus_AreaShape_MedianRadius
# 3   0.011713      Median_Nucleus_Texture_Entropy_Eosin_5_03_256
# 4   0.011560  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_5_0...
# 5   0.011289  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_4_0...
# 6   0.011059  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_7_0...
# 7   0.010859  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_5...
# 8   0.010364                Mean_Nucleus_AreaShape_MedianRadius
# 9   0.010144      Median_Nucleus_Texture_Entropy_Eosin_5_02_256
# 10  0.009920           Median_Nucleus_AreaShape_MinorAxisLength
# 2022-07-23 11:25:26.213999 Evaluate...
# Fold 2 Patch-level Training Accuracy: 76.70596048480823
# 2022-07-23 11:25:26.542404 Validate...
# Fold 2 Patch-level Validation Accuracy: 40.574282147315856
# Fold 2 Patient-level Validation Accuracy: 32.0
#
# 2022-07-23 11:25:26.655442 Fold 3 Loading...
# Loaded lengths X,y,z: (5906, 5302) 5906 5906
# Loaded lengths X,y,z: (1719, 5302) 1719 1719
# 2022-07-23 11:26:18.780683 Shuffle...
# 2022-07-23 11:26:18.905933 Train...
# 2022-07-23 11:27:00.931272 Ranked feature imporances...
#            0                                                  1
# 0   0.016390              Median_Nucleus_AreaShape_MedianRadius
# 1   0.015022                  Mean_Nucleus_AreaShape_MeanRadius
# 2   0.013030  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_5...
# 3   0.012651                Mean_Nucleus_AreaShape_MedianRadius
# 4   0.010546  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_4_0...
# 5   0.010482                Median_Nucleus_AreaShape_MeanRadius
# 6   0.010411             Median_Nucleus_AreaShape_MaximumRadius
# 7   0.010254  Median_Nucleus_Texture_AngularSecondMoment_Eos...
# 8   0.010072  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_3...
# 9   0.009528  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_7...
# 10  0.009295  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_3...
# 2022-07-23 11:27:00.967961 Evaluate...
# Fold 3 Patch-level Training Accuracy: 73.46766000677277
# 2022-07-23 11:27:01.283529 Validate...
# Fold 3 Patch-level Validation Accuracy: 57.12623618382781
# Fold 3 Patient-level Validation Accuracy: 44.0
#
# 2022-07-23 11:27:01.399697 Fold 4 Loading...
# Loaded lengths X,y,z: (6127, 5302) 6127 6127
# Loaded lengths X,y,z: (1498, 5302) 1498 1498
# 2022-07-23 11:27:53.905897 Shuffle...
# 2022-07-23 11:27:54.032121 Train...
# 2022-07-23 11:28:37.862147 Ranked feature imporances...
#            0                                                  1
# 0   0.018610                  Mean_Nucleus_AreaShape_MeanRadius
# 1   0.012130  Median_Nucleus_AreaShape_InertiaTensorEigenval...
# 2   0.011914               Mean_Nucleus_AreaShape_MaximumRadius
# 3   0.011785  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_7...
# 4   0.011608                Median_Nucleus_AreaShape_MeanRadius
# 5   0.011432  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_7...
# 6   0.011407             Median_Nucleus_AreaShape_MaximumRadius
# 7   0.011083  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_4_0...
# 8   0.010466  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_5_0...
# 9   0.010304              Median_Nucleus_AreaShape_MedianRadius
# 10  0.008757  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_5...
# 2022-07-23 11:28:37.899537 Evaluate...
# Fold 4 Patch-level Training Accuracy: 72.49877590990697
# 2022-07-23 11:28:38.243750 Validate...
# Fold 4 Patch-level Validation Accuracy: 59.879839786381844
# Fold 4 Patient-level Validation Accuracy: 48.0

# %%
print(datetime.datetime.now())
print('Cross validation patch-level accuracy:',patch_accuracies)
print('mean:',np.mean(patch_accuracies),'std:',np.std(patch_accuracies))
print('Cross validation patient-level accuracy:',patient_accuracies)
print('mean:',np.mean(patient_accuracies),'std:',np.std(patient_accuracies))
# Out:
# 2022-07-23 11:28:38.396883
# Cross validation patch-level accuracy: [51.320754716981135, 66.75075681130171, 40.574282147315856, 57.12623618382781, 59.879839786381844]
# mean: 55.13037392916168 std: 8.80871383232954
# Cross validation patient-level accuracy: [48.0, 48.0, 32.0, 44.0, 48.0]
# mean: 44.0 std: 6.196773353931867
