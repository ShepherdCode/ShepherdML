# %% [markdown]
# # Process CellProfiler Image.csv
# Here, we filtered Image.csv files to have...
#
# * fewer columns (e.g. remove strings)
# * fewer rows (e.g. remove high-RBC patches).
#
# Assume there is one Image.csv file per patient (output from previous notebook).
#
# Our hypothesis is that the slimmed CSVs are better substrate for learning.

# %%
import numpy as np
import pandas as pd
import os

# %%
from datetime import datetime
print(datetime.now())
# Out:
# 2022-07-19 14:21:51.246047

# %%
BASE_PATH_IN='/home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/'
BASE_PATH_OUT='/home/jrm/Adjeroh/Naved/July_Run/CellProfilerFiltered/'
FILENAMES=[
'Process100_Image.csv',
'Process100_Cells.csv',
'Process100_ExpandCells.csv',
'Process100_Experiment.csv',
'Process100_MergeRBC.csv',
'Process100_Nucleus.csv',
'Process100_RBC.csv',
'Process100_ShrinkRBC.csv',
'Process100_Tissue.csv']

# %%
ALL_PATIENTS = os.listdir(BASE_PATH_IN)

# %%
def drop_cols(df,cols):
    if len(cols)>0:
        df = df.drop(columns=cols) 
    return df

# %%
def drop_bad_cols(df):
    # Timing stats give away classes if classes were processed differently. 
    bad_cols = [c for c in df.columns if c.startswith('ExecutionTime_')]
    df = drop_cols(df,bad_cols)
    # These columns are 100% uniform -- total area of the patch.
    bad_cols = [c for c in df.columns if c.startswith('AreaOccupied_TotalArea_')]
    df = drop_cols(df,bad_cols)
    # These columns are mostly empty except for FileName_Tumor.
    bad_cols = [c for c in df.columns if c.endswith('_Tumor')]
    df = drop_cols(df,bad_cols)
    # String columns with filenames or directory names can give away the class.
    # Patient was added by us in the previous notebook.
    bad_cols = [
        'Group_Index','Group_Number','ImageSet_ImageSet',
        'Patient','Metadata_FileLocation']
    # Oddly, we don't have this column: 'ProcessingStatus'
    df = drop_cols(df,bad_cols)
    return df

# %%
# By removing bad patches, we can improve accuracy at patch level.
# Assume we would then aggregate patch predictions to WSI level.
# Thresholds were chosen by looking for elbows in these histograms:
# pd.DataFrame.hist(df,column='AreaOccupied_AreaOccupied_MergeRBC')
# pd.DataFrame.hist(df,column='AreaOccupied_AreaOccupied_Tissue')
# See notebook Data 03
def drop_bad_rows(df):
    # This filter would remove entirely one WSI. See odd case below.
    # df = df[df.AreaOccupied_AreaOccupied_Tissue>30000]
    df = df[df.AreaOccupied_AreaOccupied_MergeRBC<5000]    
    return df

# %%
def drop_bad_vals(df):
    # Expect nan for mean_RBC_diameter where #RBC=0
    df.fillna(0,inplace=True)
    df.fillna(0,inplace=True)
    nan = df.isna().sum().sum()
    temp_df=df.select_dtypes(include='object')
    inf = np.isinf(df).values.sum()
    if nan>0 or len(temp_df.columns)>0 or inf>0:
        raise Exception('Non-numeric values in df')
    return df

# %%
def save_file(df,directory,filename):
    try:
        os.mkdir(BASE_PATH_OUT+directory)
    except FileExistsError:
        print('Directory',directory,'already exists. Will overwrite files in there.')
    output = BASE_PATH_OUT+directory+'/'+filename
    df.to_csv(output,index=False)

# %%
infile = FILENAMES[0]  # So far, we only process Image.csv
print(datetime.now())
for directory in ALL_PATIENTS:
    input =  BASE_PATH_IN+ directory+'/'+infile
    print('Reading from',input)
    df = pd.read_csv(input)
    shape1 = df.shape
    df = drop_bad_cols(df)
    df = drop_bad_rows(df)
    df = drop_bad_vals(df)
    shape2 = df.shape
    print('Shape change from',shape1,'to',shape2)
    save_file(df,directory,infile)
# Out:
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-HT-7483-01Z-00/Process100_Image.csv
# Shape change from (1267, 5347) to (829, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-02-0025-01Z-00/Process100_Image.csv
# Shape change from (797, 5347) to (698, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-DH-A66B-01Z-00/Process100_Image.csv
# Shape change from (391, 5347) to (389, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-08-0517-01Z-00/Process100_Image.csv
# Shape change from (393, 5347) to (368, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-26-5139-01Z-00/Process100_Image.csv
# Shape change from (402, 5347) to (391, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-S9-A6WE-01Z-00/Process100_Image.csv
# Shape change from (405, 5347) to (405, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-15-1446-01Z-00/Process100_Image.csv
# Shape change from (806, 5347) to (780, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-S9-A6U9-01Z-00/Process100_Image.csv
# Shape change from (394, 5347) to (389, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-02-0033-01Z-00/Process100_Image.csv
# Shape change from (396, 5347) to (393, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-DB-5270-01Z-00/Process100_Image.csv
# Shape change from (803, 5347) to (768, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-14-0786-01Z-00/Process100_Image.csv
# Shape change from (1198, 5347) to (1068, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-HT-7676-01Z-00/Process100_Image.csv
# Shape change from (373, 5347) to (343, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-HT-A618-01Z-00/Process100_Image.csv
# Shape change from (410, 5347) to (406, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-06-5412-01Z-00/Process100_Image.csv
# Shape change from (348, 5347) to (305, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-S9-A6WO-01Z-00/Process100_Image.csv
# Shape change from (400, 5347) to (360, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-02-0338-01Z-00/Process100_Image.csv
# Shape change from (398, 5347) to (292, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-HT-7854-01Z-00/Process100_Image.csv
# Shape change from (801, 5347) to (747, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-DU-8164-01Z-00/Process100_Image.csv
# Shape change from (377, 5347) to (377, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-DB-5274-01Z-00/Process100_Image.csv
# Shape change from (790, 5347) to (725, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-DU-7009-01Z-00/Process100_Image.csv
# Shape change from (401, 5347) to (401, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-HT-7693-01Z-00/Process100_Image.csv
# Shape change from (1136, 5347) to (1064, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-15-1447-01Z-00/Process100_Image.csv
# Shape change from (791, 5347) to (724, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-TM-A7CF-01Z-00/Process100_Image.csv
# Shape change from (562, 5347) to (514, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-FG-7636-01Z-00/Process100_Image.csv
# Shape change from (401, 5347) to (312, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-06-0209-01Z-00/Process100_Image.csv
# Shape change from (3139, 5347) to (2387, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-CS-5397-01Z-00/Process100_Image.csv
# Shape change from (386, 5347) to (353, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-06-0190-01Z-00/Process100_Image.csv
# Shape change from (400, 5347) to (368, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-CS-4943-01Z-00/Process100_Image.csv
# Shape change from (401, 5347) to (289, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-DB-A4XF-01Z-00/Process100_Image.csv
# Shape change from (803, 5347) to (802, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-S9-A7IQ-01Z-00/Process100_Image.csv
# Shape change from (401, 5347) to (176, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-14-0787-01Z-00/Process100_Image.csv
# Shape change from (623, 5347) to (572, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-DU-7299-01Z-00/Process100_Image.csv
# Shape change from (396, 5347) to (396, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-FG-7643-01Z-00/Process100_Image.csv
# Shape change from (382, 5347) to (380, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-06-0241-01Z-00/Process100_Image.csv
# Shape change from (403, 5347) to (383, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-HT-7603-01Z-00/Process100_Image.csv
# Shape change from (1194, 5347) to (1112, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-S9-A7J1-01Z-00/Process100_Image.csv
# Shape change from (390, 5347) to (351, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-02-0446-01Z-00/Process100_Image.csv
# Shape change from (391, 5347) to (391, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-28-1749-01Z-00/Process100_Image.csv
# Shape change from (339, 5347) to (338, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-S9-A7QY-01Z-00/Process100_Image.csv
# Shape change from (409, 5347) to (143, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-QH-A6XA-01Z-00/Process100_Image.csv
# Shape change from (397, 5347) to (397, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-DB-A4XG-01Z-00/Process100_Image.csv
# Shape change from (790, 5347) to (763, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-02-0430-01Z-00/Process100_Image.csv
# Shape change from (395, 5347) to (395, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-14-1829-01Z-00/Process100_Image.csv
# Shape change from (3164, 5347) to (3110, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-HT-7902-01Z-00/Process100_Image.csv
# Shape change from (778, 5347) to (773, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-06-1801-01Z-00/Process100_Image.csv
# Shape change from (789, 5347) to (788, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-HT-7681-01Z-00/Process100_Image.csv
# Shape change from (1615, 5347) to (1303, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-HW-7487-01Z-00/Process100_Image.csv
# Shape change from (401, 5347) to (358, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-HT-7616-01Z-00/Process100_Image.csv
# Shape change from (790, 5347) to (655, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-41-5651-01Z-00/Process100_Image.csv
# Shape change from (372, 5347) to (366, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-HT-A5R9-01Z-00/Process100_Image.csv
# Shape change from (396, 5347) to (350, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-S9-A6U6-01Z-00/Process100_Image.csv
# Shape change from (406, 5347) to (96, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-DB-A4XE-01Z-00/Process100_Image.csv
# Shape change from (788, 5347) to (780, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-14-1453-01Z-00/Process100_Image.csv
# Shape change from (1482, 5347) to (1344, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-06-0878-01Z-00/Process100_Image.csv
# Shape change from (738, 5347) to (689, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-DU-7015-01Z-00/Process100_Image.csv
# Shape change from (381, 5347) to (381, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-HT-7873-01Z-00/Process100_Image.csv
# Shape change from (861, 5347) to (769, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-26-5134-01Z-00/Process100_Image.csv
# Shape change from (398, 5347) to (389, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-HT-8104-01Z-00/Process100_Image.csv
# Shape change from (399, 5347) to (393, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-HT-A617-01Z-00/Process100_Image.csv
# Shape change from (400, 5347) to (394, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-S9-A6WL-01Z-00/Process100_Image.csv
# Shape change from (388, 5347) to (386, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-HT-7881-01Z-00/Process100_Image.csv
# Shape change from (1918, 5347) to (1650, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-QH-A6CU-01Z-00/Process100_Image.csv
# Shape change from (405, 5347) to (405, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-QH-A65Z-01Z-00/Process100_Image.csv
# Shape change from (408, 5347) to (408, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-06-0211-01Z-00/Process100_Image.csv
# Shape change from (788, 5347) to (699, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-DU-5874-01Z-00/Process100_Image.csv
# Shape change from (402, 5347) to (401, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-06-0125-01Z-00/Process100_Image.csv
# Shape change from (659, 5347) to (638, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-26-5133-01Z-00/Process100_Image.csv
# Shape change from (406, 5347) to (357, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-DU-6408-01Z-00/Process100_Image.csv
# Shape change from (401, 5347) to (401, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-HW-7491-01Z-00/Process100_Image.csv
# Shape change from (409, 5347) to (382, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-14-1452-01Z-00/Process100_Image.csv
# Shape change from (1592, 5347) to (1591, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-02-0285-01Z-00/Process100_Image.csv
# Shape change from (404, 5347) to (379, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-06-0879-01Z-00/Process100_Image.csv
# Shape change from (526, 5347) to (457, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-HT-7605-01Z-00/Process100_Image.csv
# Shape change from (1537, 5347) to (1487, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-28-1746-01Z-00/Process100_Image.csv
# Shape change from (407, 5347) to (177, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-27-1831-01Z-00/Process100_Image.csv
# Shape change from (1567, 5347) to (1537, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-HT-A5RA-01Z-00/Process100_Image.csv
# Shape change from (405, 5347) to (382, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-02-0004-01Z-00/Process100_Image.csv
# Shape change from (396, 5347) to (385, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-06-0189-01Z-00/Process100_Image.csv
# Shape change from (1553, 5347) to (1346, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-06-0216-01Z-00/Process100_Image.csv
# Shape change from (1894, 5347) to (1596, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-FG-5963-01Z-00/Process100_Image.csv
# Shape change from (396, 5347) to (391, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-DU-8167-01Z-00/Process100_Image.csv
# Shape change from (394, 5347) to (393, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-HT-7884-01Z-00/Process100_Image.csv
# Shape change from (289, 5347) to (287, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-DU-5854-01Z-00/Process100_Image.csv
# Shape change from (338, 5347) to (334, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-QH-A6CZ-01Z-00/Process100_Image.csv
# Shape change from (394, 5347) to (392, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-FG-A60L-01Z-00/Process100_Image.csv
# Shape change from (406, 5347) to (401, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-S9-A6UB-01Z-00/Process100_Image.csv
# Shape change from (392, 5347) to (383, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-DU-8165-01Z-00/Process100_Image.csv
# Shape change from (381, 5347) to (380, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-06-1084-01Z-00/Process100_Image.csv
# Shape change from (617, 5347) to (547, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-08-0518-01Z-00/Process100_Image.csv
# Shape change from (3196, 5347) to (2889, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-DB-A64L-01Z-00/Process100_Image.csv
# Shape change from (405, 5347) to (390, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-02-0010-01Z-00/Process100_Image.csv
# Shape change from (1588, 5347) to (1563, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-14-1401-01Z-00/Process100_Image.csv
# Shape change from (774, 5347) to (759, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-DU-6402-01Z-00/Process100_Image.csv
# Shape change from (393, 5347) to (393, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-14-0789-01Z-00/Process100_Image.csv
# Shape change from (2612, 5347) to (2402, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-S9-A6WI-01Z-00/Process100_Image.csv
# Shape change from (396, 5347) to (374, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-06-0129-01Z-00/Process100_Image.csv
# Shape change from (1111, 5347) to (1100, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-DU-7014-01Z-00/Process100_Image.csv
# Shape change from (406, 5347) to (406, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-06-0214-01Z-00/Process100_Image.csv
# Shape change from (1197, 5347) to (1108, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-14-1795-01Z-00/Process100_Image.csv
# Shape change from (2818, 5347) to (2604, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-08-0520-01Z-00/Process100_Image.csv
# Shape change from (396, 5347) to (365, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-DU-6404-01Z-00/Process100_Image.csv
# Shape change from (394, 5347) to (392, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-06-0185-01Z-00/Process100_Image.csv
# Shape change from (397, 5347) to (392, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-06-0645-01Z-00/Process100_Image.csv
# Shape change from (330, 5347) to (327, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-06-0201-01Z-00/Process100_Image.csv
# Shape change from (782, 5347) to (744, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-02-0439-01Z-00/Process100_Image.csv
# Shape change from (794, 5347) to (788, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-HT-7606-01Z-00/Process100_Image.csv
# Shape change from (796, 5347) to (605, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-HT-7482-01Z-00/Process100_Image.csv
# Shape change from (3480, 5347) to (3214, 5302)
# Reading from /home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-HW-7495-01Z-00/Process100_Image.csv
# Shape change from (396, 5347) to (396, 5302)

# %%
print(datetime.now())
# Out:
# 2022-07-19 14:27:06.220264

# %%
df = pd.read_csv('/home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-HW-7495-01Z-00/Process100_Image.csv')
df.shape
# Out:
# (396, 5347)

# %%
for c in df.columns:
    if c.startswith('Area'):
        print(c)
# Out:
# AreaOccupied_AreaOccupied_ExpandCells
# AreaOccupied_AreaOccupied_MergeRBC
# AreaOccupied_AreaOccupied_Nucleus
# AreaOccupied_AreaOccupied_Tissue
# AreaOccupied_Perimeter_ExpandCells
# AreaOccupied_Perimeter_MergeRBC
# AreaOccupied_Perimeter_Nucleus
# AreaOccupied_Perimeter_Tissue
# AreaOccupied_TotalArea_ExpandCells
# AreaOccupied_TotalArea_MergeRBC
# AreaOccupied_TotalArea_Nucleus
# AreaOccupied_TotalArea_Tissue

# %% [markdown]
# We seem to have one WSI with very low tissue count, though the WSI looks fine at
# [TCGA](https://portal.gdc.cancer.gov/files/6d237796-dfd7-4a00-b44d-78ea26ec3a49).

# %%
col=df[['AreaOccupied_AreaOccupied_Nucleus','AreaOccupied_AreaOccupied_ExpandCells','AreaOccupied_AreaOccupied_Tissue']]
col.describe()
# Out:
#        AreaOccupied_AreaOccupied_Nucleus  \
# count                         396.000000
# mean                         5169.277778
# std                          1993.628727
# min                           317.000000
# 25%                          3876.000000
# 50%                          5159.000000
# 75%                          6418.750000
# max                         12466.000000
#
#        AreaOccupied_AreaOccupied_ExpandCells  AreaOccupied_AreaOccupied_Tissue
# count                             396.000000                        396.000000
# mean                            89998.934343                       1052.719697
# std                                21.206298                       2824.147793
# min                             89578.000000                          0.000000
# 25%                             90000.000000                          0.000000
# 50%                             90000.000000                         52.000000
# 75%                             90000.000000                        779.750000
# max                             90000.000000                      24920.000000

# %% [markdown]
# For comparison, here is some other WSI.

# %%
df = pd.read_csv('/home/jrm/Adjeroh/Naved/July_Run/CellProfilerOutputs/TCGA-HT-7482-01Z-00/Process100_Image.csv')
df.shape
# Out:
# (3480, 5347)

# %%
col=df[['AreaOccupied_AreaOccupied_Nucleus','AreaOccupied_AreaOccupied_ExpandCells','AreaOccupied_AreaOccupied_Tissue']]
col.describe()
# Out:
#        AreaOccupied_AreaOccupied_Nucleus  \
# count                        3480.000000
# mean                         9421.950862
# std                         10096.498242
# min                             0.000000
# 25%                          3983.750000
# 50%                          6374.500000
# 75%                          9906.250000
# max                         71679.000000
#
#        AreaOccupied_AreaOccupied_ExpandCells  AreaOccupied_AreaOccupied_Tissue
# count                            3480.000000                       3480.000000
# mean                            89969.141667                      73694.986782
# std                              1529.511260                      26367.658635
# min                                 0.000000                          0.000000
# 25%                             90000.000000                      63920.500000
# 50%                             90000.000000                      89927.000000
# 75%                             90000.000000                      90000.000000
# max                             90000.000000                      90000.000000
