# %% [markdown]
# # Feature Elimination
# Try binary classification.

# %%
MAX_DEPTH = 10
N_ESTIMATORS = 1000
CHOOSE_EVERY = 10

# %%
from datetime import datetime
print(datetime.now())
from platform import python_version
print('Python',python_version())
import csv
import numpy as np
import pandas as pd
import matplotlib as plt
import random
import sklearn   # pip install --upgrade scikit-learn
print('sklearn',sklearn.__version__)
# Out:
# 2022-07-26 05:56:04.111876
# Python 3.8.10
# sklearn 1.0.2

# %%
# from sklearn.utils import shuffle
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import RFE

# %%
# Our input is the output from the Data notebooks.
# These csv files were filtered to remove give-away columns and bad rows.
BASE_PATH='/Users/jasonmiller/Downloads/CellProfilerFiltered/'   # air
BASE_PATH='/home/jrm/Adjeroh/Naved/July_Run/CellProfilerFiltered/'  # alien
# This is the patch-level csv file: one row per patch, with nucleus totals.
# Later, incorporate the nucleus-specific csv files.
FILENAME='Process100_Image.csv'
# This directory contains lists of patch filenames,
# divided into 5 folds of train/valid splits.
# Notice patch filename [0:19] is case ID, [0:23] is WSI ID,
# and last column is the 6-way cancer class (zero to five) of the case.
# For example, fold0_train.txt starts:
# TCGA-06-0129-01Z-00-DX1_5400_5100.png, 0
# TCGA-06-0129-01Z-00-DX1_5700_6000.png, 0
LEN_PATIENT_ID = 19
SPLITS_BASE='/Users/jasonmiller/Downloads/TrainTestSplit/'    #air
SPLITS_BASE='/home/jrm/Adjeroh/Naved/July_Run/TrainTestSplit/'  # alien
SPLITS_FILES = [
    ('fold0_train.txt','fold0_test.txt'),
    ('fold1_train.txt','fold1_test.txt'),
    ('fold2_train.txt','fold2_test.txt'),
    ('fold3_train.txt','fold3_test.txt'),
    ('fold4_train.txt','fold4_test.txt'),
]
NUM_FOLDS = 5
PATIENT_TO_CANCER = {}  # hash case ID to class number

# %% [markdown]
# ## Data loading functions

# %%
# Given a case ID = patient name = directory, load the csv file.
# Expect a value like p='TCGA-S9-A6UB-01Z-00'
def load_patient_data(p):
    filepath=BASE_PATH+p+'/'+FILENAME
    df = pd.read_csv(filepath)
    return df

# %%
# Given fold, load the case/patient IDs separated into training and validation.
# Fold should be an in between 0 and 4 for 5-fold cross validation.
# The returned list has unique strings like  TCGA-06-0129-01Z-00
def _load_patient_names(filename):
    patients=[]
    with open(filename) as infile:
        rows = csv.reader(infile)
        for row in rows:
            patient = row[0][:LEN_PATIENT_ID]
            cancer_class = int(row[1])
            if cancer_class>1:    # binary GBM vs LGG
                cancer_class=1    # reduce all LGG subclasses to one
            PATIENT_TO_CANCER[patient] = cancer_class
            patients.append(patient)
    patients = list(np.unique(patients))
    return patients
def load_patient_names(fold):
    filenames = SPLITS_FILES[fold]  # tuple of train,valid
    train_patients = _load_patient_names(SPLITS_BASE+filenames[0])
    valid_patients = _load_patient_names(SPLITS_BASE+filenames[1])
    return train_patients,valid_patients

# %%
# Slurp csv into numpy array.
def _load_train_valid_set3(patients,save_mem=False):
    X = None  # instances with features
    y = None  # labels = cancer class
    z = None  # patient_id for aggregation
    for patient in patients:
        filepath=BASE_PATH+patient+'/'+FILENAME
        label = PATIENT_TO_CANCER[patient]
        Xall = np.loadtxt(filepath,skiprows=1,delimiter=',')
        if (save_mem):
            Xi = Xall[0::CHOOSE_EVERY].copy()  # e.g. choose every tenth row
        else:
            Xi = Xall
        yi = np.full(shape=len(Xi), fill_value=label, dtype=np.int8)
        zi = [patient]*len(Xi)  # same ID for all patches from one patient
        if X is None:
            X = Xi
            y = yi
            z = zi
        else:
            X = np.concatenate( (X, Xi) )
            y = np.concatenate( (y, yi) )
            z = np.concatenate( (z, zi) )
    X = pd.DataFrame(X)
    # DataFrame column headers are not required for the machine learning.
    # We'll add them just for debugging. Arbitrarily use first row of first file.
    patient = patients[0]
    filepath=BASE_PATH+patient+'/'+FILENAME
    with open(filepath) as infile:
        rows = csv.reader(infile)
        for row in rows:
            header = row
            break
    X.columns = header
    return X,y,z

# %%
# Load csv rows for one set of train+valid patient names.
# This is slow, probably due to concatenating dataframes.
# Consider a rewrite that concatenates csv before constructing a dataframe.
def load_train_valid_set(train_patient_names,valid_patient_names):
    X_train,y_train,z_train = _load_train_valid_set3(train_patient_names,True)
    print('Train lengths X,y,z:',X_train.shape,len(y_train),len(z_train))
    X_valid,y_valid,z_valid = _load_train_valid_set3(valid_patient_names,False)
    print('Valid lengths X,y,z:',X_valid.shape,len(y_valid),len(z_valid))
    
    # TO DO: raise exception if any valid patient is also a train patient
    return X_train,y_train,z_train,X_valid,y_valid,z_valid

# %% [markdown]
# ## Aggregation functions

# %%
# Later, weight each patch label by the confidence i.e. score
def aggregate_accuracy(y_pred,z_valid):
    L = len(y_pred)
    if L != len(z_valid):
        raise Exception('Lengths of y and z do not match')
    correct = {}
    incorrect = {}
    patients = np.unique(z_valid)
    for patient in patients:
        correct[patient]=0
        incorrect[patient]=0
    for i in range(L):
        patient = z_valid[i]
        label = PATIENT_TO_CANCER[patient]
        pred = y_pred[i]
        if pred == label:
            correct[patient] += 1
        else:
            incorrect[patient] += 1
    numerator = 0
    denominator = 0
    for patient in patients:
        denominator += 1
        if correct[patient]>incorrect[patient]:
            numerator += 1
    accuracy = float(0)
    if denominator>0:
        accuracy = 100.0*numerator/denominator 
    return accuracy

# %% [markdown]
# ## Main loop: Load, Classify, Report

# %%
def important_features(model):
        # Prereqs: fit().
        names = model.feature_names_in_
        importances = model.feature_importances_
        pairs = np.column_stack( (names,importances) )
        top_array = sorted(pairs, key = lambda e:e[1], reverse=True)
        # There must be a way to do this witout a loop!
        top_list = []
        for i in top_array:
             top_list.append((i[1],i[0]))  # 0=feature_name, 1=importance
        top_df = pd.DataFrame(top_list)
        return top_df

# %%
patch_accuracies = []   # summary statistics
patient_accuracies = [] # summary statistics
last_model = None
for fold in range(NUM_FOLDS):
    print()
    print(datetime.now(),'Fold',fold,'Loading...')
    train_patients,valid_patients = load_patient_names(fold)  
    X_train,y_train,z_train,X_valid,y_valid,z_valid = \
        load_train_valid_set(train_patients,valid_patients)    
    # print('Fold',fold,'patients train',train_patients,'patients valid',valid_patients)
    # print('Fold:',fold,'patches train',X_train.shape,'patches valid',X_valid.shape)

    # This shuffle is pro forma, not strictly necessary.
    # CNN models are sensitive to train set order but RF models are not. 
    # print(datetime.now(),'Shuffle...')
    # X_train,y_train = shuffle(X_train,y_train)
    
    print(datetime.now(),'Feature elimination...')
    fts = 5302 - 10
    rfc = RandomForestClassifier(max_depth=MAX_DEPTH,n_estimators=N_ESTIMATORS)
    # Random Forest feature Elimination model
    rfe = RFE(rfc,n_features_to_select=fts,verbose=2)  
    rfe.fit(X_train,y_train) # This is slow! Uses 100% cpu but 0% gpu.
    print('Ranking',rfe.ranking_) # Selected features get rank=1. Large numbers mean not selected.
    support = rfe.support_
    no_support = np.invert(rfe.support_)
    selected = rfe.feature_names_in_[rfe.support_]
    not_selected = rfe.feature_names_in_[no_support]
    X_valid_reduced = X_valid.drop(not_selected,axis=1)
    X_train_reduced = X_train.drop(not_selected,axis=1)    
    print('Features ruled out:',not_selected)
    print('Original X_train',X_train.shape,'X_valid',X_valid.shape)
    X_valid = X_valid_reduced
    X_train = X_train_reduced
    print('Reduced X_train',X_train.shape,'X_valid',X_valid.shape)
    
    print(datetime.now(),'Train...')
    # min_samples_leaf=1 (default) led to overfitting
    rfc = RandomForestClassifier(max_depth=MAX_DEPTH,n_estimators=N_ESTIMATORS)
    rfc.fit(X_train,y_train)  # slow
    
    print(datetime.now(),'Ranked feature imporances...')
    top = important_features(rfc)
    #pd.set_option('display.max_rows', None)
    print(top.loc[:10])
    
    print(datetime.now(),'Evaluate...')
    y_pred = rfc.predict(X_train)
    matches = np.count_nonzero(y_train==y_pred)
    accuracy_t = 100.0 * matches / len(y_pred)
    print('Fold',fold,'Patch-level Training Accuracy:',accuracy_t)
    
    print(datetime.now(),'Validate...')
    y_pred = rfc.predict(X_valid)
    matches = np.count_nonzero(y_valid==y_pred)
    accuracy_v = 100.0 * matches / len(y_pred)
    print('Fold',fold,'Patch-level Validation Accuracy:',accuracy_v)
    patch_accuracies.append(accuracy_v)
    
    accuracy_p = aggregate_accuracy(y_pred,z_valid)
    patient_accuracies.append(accuracy_p)
    print('Fold',fold,'Patient-level Validation Accuracy:',accuracy_p)
    
    # This shouldn't be necessary but it seems to reduce memory footprint.
    X_train=None
    X_valid=None
    y_train=None
    y_valid=None
    z_train=None
    z_valid=None
    y_pred = None
    matches = None
    last_model = rfc  # for testing outside the loop
# Out:
# 2022-07-26 05:56:04.622704 Fold 0 Loading...
# Train lengths X,y,z: (6035, 5302) 6035 6035
# Valid lengths X,y,z: (15773, 5302) 15773 15773
# 2022-07-26 05:57:02.050085 Feature elimination...
# Fitting estimator with 5302 features.
# Fitting estimator with 5301 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5299 features.
# Fitting estimator with 5298 features.
# Fitting estimator with 5297 features.
# Fitting estimator with 5296 features.
# Fitting estimator with 5295 features.
# Fitting estimator with 5294 features.
# Fitting estimator with 5293 features.
# Ranking [6 1 1 ... 1 1 1]
# Features ruled out: ['AreaOccupied_AreaOccupied_ExpandCells'
#  'Mean_Tissue_AreaShape_CentralMoment_0_1'
#  'Mean_Tissue_Location_MaxIntensity_Z_Eosin'
#  'Median_Cells_Location_Center_Z'
#  'Median_MergeRBC_Location_CenterMassIntensity_Z_Eosin'
#  'Median_RBC_Location_Center_Z' 'ModuleError_19MeasureGranularity'
#  'StDev_ExpandCells_AreaShape_NormalizedMoment_1_0'
#  'StDev_Tissue_AreaShape_CentralMoment_0_1'
#  'StDev_Tissue_AreaShape_NormalizedMoment_1_0']
# Original X_train (6035, 5302) X_valid (15773, 5302)
# Reduced X_train (6035, 5292) X_valid (15773, 5292)
# 2022-07-26 06:22:32.374742 Train...
# 2022-07-26 06:24:58.326540 Ranked feature imporances...
#            0                                                  1
# 0   0.012013  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_7...
# 1   0.010933                  Mean_Nucleus_AreaShape_MeanRadius
# 2   0.009747                Median_Nucleus_AreaShape_MeanRadius
# 3   0.009697  Median_Nucleus_AreaShape_InertiaTensorEigenval...
# 4   0.009660              Median_Nucleus_AreaShape_MedianRadius
# 5   0.009292               Mean_Nucleus_AreaShape_MaximumRadius
# 6   0.009026  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_7_0...
# 7   0.008683  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_7...
# 8   0.008179  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_7...
# 9   0.008108  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_5...
# 10  0.008060           Median_Nucleus_AreaShape_MinorAxisLength
# 2022-07-26 06:24:58.403917 Evaluate...
# Fold 0 Patch-level Training Accuracy: 97.29908864954433
# 2022-07-26 06:24:59.218061 Validate...
# Fold 0 Patch-level Validation Accuracy: 90.59151714955938
# Fold 0 Patient-level Validation Accuracy: 100.0
#
# 2022-07-26 06:25:01.347956 Fold 1 Loading...
# Train lengths X,y,z: (5643, 5302) 5643 5643
# Valid lengths X,y,z: (19697, 5302) 19697 19697
# 2022-07-26 06:25:58.523777 Feature elimination...
# Fitting estimator with 5302 features.
# Fitting estimator with 5301 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5299 features.
# Fitting estimator with 5298 features.
# Fitting estimator with 5297 features.
# Fitting estimator with 5296 features.
# Fitting estimator with 5295 features.
# Fitting estimator with 5294 features.
# Fitting estimator with 5293 features.
# Ranking [11  1  1 ...  1  1  1]
# Features ruled out: ['AreaOccupied_AreaOccupied_ExpandCells'
#  'Mean_ExpandCells_Location_MaxIntensity_Z_Eosin'
#  'Median_ExpandCells_Location_MaxIntensity_Z_Eosin'
#  'Median_Nucleus_AreaShape_EulerNumber'
#  'Median_Nucleus_AreaShape_NormalizedMoment_0_1' 'ModuleError_07Smooth'
#  'StDev_ExpandCells_AreaShape_CentralMoment_1_0'
#  'StDev_ExpandCells_Location_CenterMassIntensity_Z_Eosin'
#  'StDev_MergeRBC_AreaShape_CentralMoment_0_1'
#  'StDev_Tissue_Location_MaxIntensity_Z_Eosin']
# Original X_train (5643, 5302) X_valid (19697, 5302)
# Reduced X_train (5643, 5292) X_valid (19697, 5292)
# 2022-07-26 06:49:51.342880 Train...
# 2022-07-26 06:52:08.687086 Ranked feature imporances...
#            0                                                  1
# 0   0.012762  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_5_0...
# 1   0.011222                Median_Nucleus_AreaShape_MeanRadius
# 2   0.010975                  Mean_Nucleus_AreaShape_MeanRadius
# 3   0.010916  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_5...
# 4   0.010657  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_4...
# 5   0.010532  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_7...
# 6   0.010109                Mean_Nucleus_AreaShape_MedianRadius
# 7   0.009982  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_4_0...
# 8   0.008993  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_4_0...
# 9   0.008782               Mean_Nucleus_AreaShape_MaximumRadius
# 10  0.008484  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_5...
# 2022-07-26 06:52:08.754923 Evaluate...
# Fold 1 Patch-level Training Accuracy: 96.88109161793372
# 2022-07-26 06:52:09.485116 Validate...
# Fold 1 Patch-level Validation Accuracy: 88.45001776920343
# Fold 1 Patient-level Validation Accuracy: 84.0
#
# 2022-07-26 06:52:12.190782 Fold 2 Loading...
# Train lengths X,y,z: (6023, 5302) 6023 6023
# Valid lengths X,y,z: (15936, 5302) 15936 15936
# 2022-07-26 06:53:08.123221 Feature elimination...
# Fitting estimator with 5302 features.
# Fitting estimator with 5301 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5299 features.
# Fitting estimator with 5298 features.
# Fitting estimator with 5297 features.
# Fitting estimator with 5296 features.
# Fitting estimator with 5295 features.
# Fitting estimator with 5294 features.
# Fitting estimator with 5293 features.
# Ranking [7 1 1 ... 1 1 1]
# Features ruled out: ['AreaOccupied_AreaOccupied_ExpandCells'
#  'Mean_ExpandCells_AreaShape_NormalizedMoment_1_0'
#  'Mean_MergeRBC_Location_CenterMassIntensity_Z_Eosin'
#  'Mean_Nucleus_Children_Cells_Count' 'Median_Nucleus_Location_Center_Z'
#  'Median_Tissue_AreaShape_NormalizedMoment_1_0'
#  'ModuleError_23MeasureObjectIntensityDistribution'
#  'StDev_RBC_Location_Center_Z' 'StDev_Tissue_Location_Center_Z'
#  'StDev_Tissue_Location_MaxIntensity_Z_Eosin']
# Original X_train (6023, 5302) X_valid (15936, 5302)
# Reduced X_train (6023, 5292) X_valid (15936, 5292)
# 2022-07-26 07:18:34.869303 Train...
# 2022-07-26 07:21:00.711430 Ranked feature imporances...
#            0                                                  1
# 0   0.017247                Median_Nucleus_AreaShape_MeanRadius
# 1   0.013779  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_5...
# 2   0.011433                  Mean_Nucleus_AreaShape_MeanRadius
# 3   0.011219                Mean_Nucleus_AreaShape_MedianRadius
# 4   0.010755              Median_Nucleus_AreaShape_MedianRadius
# 5   0.010559             Median_Nucleus_AreaShape_MaximumRadius
# 6   0.009962  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_5_0...
# 7   0.009633               Mean_Nucleus_AreaShape_MaximumRadius
# 8   0.008858  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_7...
# 9   0.007709  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_5_0...
# 10  0.007525  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_7_0...
# 2022-07-26 07:21:00.790949 Evaluate...
# Fold 2 Patch-level Training Accuracy: 98.05744645525486
# 2022-07-26 07:21:01.589806 Validate...
# Fold 2 Patch-level Validation Accuracy: 86.97916666666667
# Fold 2 Patient-level Validation Accuracy: 88.0
#
# 2022-07-26 07:21:03.792627 Fold 3 Loading...
# Train lengths X,y,z: (5906, 5302) 5906 5906
# Valid lengths X,y,z: (17077, 5302) 17077 17077
# 2022-07-26 07:21:59.995830 Feature elimination...
# Fitting estimator with 5302 features.
# Fitting estimator with 5301 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5299 features.
# Fitting estimator with 5298 features.
# Fitting estimator with 5297 features.
# Fitting estimator with 5296 features.
# Fitting estimator with 5295 features.
# Fitting estimator with 5294 features.
# Fitting estimator with 5293 features.
# Ranking [7 1 1 ... 1 1 1]
# Features ruled out: ['AreaOccupied_AreaOccupied_ExpandCells'
#  'Mean_MergeRBC_Location_MaxIntensity_Z_Eosin'
#  'Mean_Nucleus_Children_Cells_Count'
#  'Mean_Nucleus_Location_CenterMassIntensity_Z_Hematoxylin'
#  'Mean_Nucleus_RadialDistribution_ZernikePhase_Hematoxylin_0_0'
#  'Median_Nucleus_AreaShape_CentralMoment_1_0'
#  'Median_Tissue_AreaShape_NormalizedMoment_0_0'
#  'StDev_MergeRBC_AreaShape_CentralMoment_1_0'
#  'StDev_Tissue_AreaShape_NormalizedMoment_1_0'
#  'StDev_Tissue_Location_MaxIntensity_Z_Eosin']
# Original X_train (5906, 5302) X_valid (17077, 5302)
# Reduced X_train (5906, 5292) X_valid (17077, 5292)
# 2022-07-26 07:46:46.056994 Train...
# 2022-07-26 07:49:07.960105 Ranked feature imporances...
#            0                                                  1
# 0   0.012778  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_7...
# 1   0.011225  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_5...
# 2   0.011054  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_7...
# 3   0.010564                Median_Nucleus_AreaShape_MeanRadius
# 4   0.010014                  Mean_Nucleus_AreaShape_MeanRadius
# 5   0.009757  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_7_0...
# 6   0.009374  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_5...
# 7   0.009022              Median_Nucleus_AreaShape_MedianRadius
# 8   0.008497               Mean_Nucleus_AreaShape_MaximumRadius
# 9   0.008310  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_7...
# 10  0.008193  Median_Nucleus_Intensity_IntegratedIntensity_H...
# 2022-07-26 07:49:08.036861 Evaluate...
# Fold 3 Patch-level Training Accuracy: 97.3078225533356
# 2022-07-26 07:49:08.832589 Validate...
# Fold 3 Patch-level Validation Accuracy: 91.53247057445687
# Fold 3 Patient-level Validation Accuracy: 92.0
#
# 2022-07-26 07:49:11.235274 Fold 4 Loading...
# Train lengths X,y,z: (6127, 5302) 6127 6127
# Valid lengths X,y,z: (14869, 5302) 14869 14869
# 2022-07-26 07:50:07.180460 Feature elimination...
# Fitting estimator with 5302 features.
# Fitting estimator with 5301 features.
# Fitting estimator with 5300 features.
# Fitting estimator with 5299 features.
# Fitting estimator with 5298 features.
# Fitting estimator with 5297 features.
# Fitting estimator with 5296 features.
# Fitting estimator with 5295 features.
# Fitting estimator with 5294 features.
# Fitting estimator with 5293 features.
# Ranking [5 1 1 ... 1 1 1]
# Features ruled out: ['AreaOccupied_AreaOccupied_ExpandCells'
#  'Mean_ExpandCells_AreaShape_NormalizedMoment_1_0'
#  'Mean_ExpandCells_RadialDistribution_ZernikePhase_Eosin_0_0'
#  'Median_Nucleus_AreaShape_NormalizedMoment_0_1'
#  'StDev_ExpandCells_Location_CenterMassIntensity_Z_Eosin'
#  'StDev_ExpandCells_Location_MaxIntensity_Z_Eosin'
#  'StDev_MergeRBC_AreaShape_CentralMoment_2_2'
#  'StDev_MergeRBC_AreaShape_NormalizedMoment_1_0'
#  'StDev_Nucleus_Location_Center_Z'
#  'StDev_Tissue_AreaShape_CentralMoment_1_0']
# Original X_train (6127, 5302) X_valid (14869, 5302)
# Reduced X_train (6127, 5292) X_valid (14869, 5292)
# 2022-07-26 08:16:00.403348 Train...
# 2022-07-26 08:18:28.162332 Ranked feature imporances...
#            0                                                  1
# 0   0.013371  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_5_0...
# 1   0.012127                  Mean_Nucleus_AreaShape_MeanRadius
# 2   0.010734             Median_Nucleus_AreaShape_MaximumRadius
# 3   0.010278                Mean_Nucleus_AreaShape_MedianRadius
# 4   0.010091                Median_Nucleus_AreaShape_MeanRadius
# 5   0.009978  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_4_0...
# 6   0.009623  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_5...
# 7   0.009234              Median_Nucleus_AreaShape_MedianRadius
# 8   0.009153               Mean_Nucleus_AreaShape_MaximumRadius
# 9   0.008618  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_5...
# 10  0.008339  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_4_0...
# 2022-07-26 08:18:28.330944 Evaluate...
# Fold 4 Patch-level Training Accuracy: 97.12746858168761
# 2022-07-26 08:18:29.163101 Validate...
# Fold 4 Patch-level Validation Accuracy: 93.14681552222746
# Fold 4 Patient-level Validation Accuracy: 96.0

# %%
print(datetime.now())
print('Cross validation patch-level accuracy:',patch_accuracies)
print('mean:',np.mean(patch_accuracies),'std:',np.std(patch_accuracies))
print('Cross validation patient-level accuracy:',patient_accuracies)
print('mean:',np.mean(patient_accuracies),'std:',np.std(patient_accuracies))
# Out:
# 2022-07-26 08:18:31.306095
# Cross validation patch-level accuracy: [90.59151714955938, 88.45001776920343, 86.97916666666667, 91.53247057445687, 93.14681552222746]
# mean: 90.13999753642277 std: 2.192290533814865
# Cross validation patient-level accuracy: [100.0, 84.0, 88.0, 92.0, 96.0]
# mean: 92.0 std: 5.656854249492381

# %%
pd.set_option('display.max_rows', None)
top = important_features(rfc)
print('Ranked features for last model')
print(top)
# Out:
# Ranked features for last model
#                  0                                                  1
# 0     1.337112e-02  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_5_0...
# 1     1.212688e-02                  Mean_Nucleus_AreaShape_MeanRadius
# 2     1.073395e-02             Median_Nucleus_AreaShape_MaximumRadius
# 3     1.027778e-02                Mean_Nucleus_AreaShape_MedianRadius
# 4     1.009072e-02                Median_Nucleus_AreaShape_MeanRadius
# 5     9.978214e-03  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_4_0...
# 6     9.622596e-03  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_5...
# 7     9.234188e-03              Median_Nucleus_AreaShape_MedianRadius
# 8     9.152861e-03               Mean_Nucleus_AreaShape_MaximumRadius
# 9     8.618111e-03  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_5...
# 10    8.338818e-03  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_4_0...
# 11    8.102971e-03  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_7...
# 12    7.818949e-03  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_7...
# 13    7.563322e-03  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_4...
# 14    7.452530e-03  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_7...
# 15    7.434434e-03  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_4...
# 16    7.286450e-03  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_4...
# 17    6.716432e-03  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_7...
# 18    6.316609e-03  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_3_0...
# 19    6.261717e-03  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_7_0...
# 20    6.165797e-03  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_4...
# 21    6.153995e-03  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_7_0...
# 22    6.147239e-03  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_7_0...
# 23    6.102930e-03  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_3_0...
# 24    5.841042e-03  Median_Nucleus_AreaShape_InertiaTensorEigenval...
# 25    5.754836e-03  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_3...
# 26    5.381732e-03  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_3_0...
# 27    5.358803e-03  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_4_0...
# 28    5.350822e-03  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_5...
# 29    5.163015e-03  Median_Nucleus_Texture_InfoMeas2_Hematoxylin_7...
# 30    5.121931e-03      Median_Nucleus_Texture_Entropy_Eosin_4_02_256
# 31    5.107005e-03  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_3...
# 32    5.078466e-03  Median_Nucleus_Texture_AngularSecondMoment_Eos...
# 33    4.880050e-03  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_3...
# 34    4.698221e-03  Median_Nucleus_Intensity_IntegratedIntensity_H...
# 35    4.652032e-03  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_7_0...
# 36    4.646273e-03  Median_Nucleus_Texture_InfoMeas2_Hematoxylin_7...
# 37    4.615307e-03             Mean_Nucleus_AreaShape_MinorAxisLength
# 38    4.603160e-03      Median_Nucleus_Texture_Entropy_Eosin_5_01_256
# 39    4.529480e-03           Median_Nucleus_AreaShape_MinorAxisLength
# 40    4.504840e-03  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_5_0...
# 41    4.483572e-03  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_3...
# 42    4.395769e-03  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_5_0...
# 43    4.364098e-03  Mean_Nucleus_Intensity_IntegratedIntensity_Hem...
# 44    4.238155e-03      Median_Nucleus_Texture_Entropy_Eosin_5_02_256
# 45    4.078156e-03  Median_Nucleus_Texture_AngularSecondMoment_Eos...
# 46    4.004757e-03  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_3_0...
# 47    3.981103e-03  Median_Nucleus_Texture_AngularSecondMoment_Eos...
# 48    3.823783e-03          Median_Nucleus_AreaShape_MinFeretDiameter
# 49    3.802392e-03  Median_Nucleus_Texture_AngularSecondMoment_Eos...
# 50    3.715210e-03  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_4_0...
# 51    3.656520e-03        Mean_Nucleus_Texture_Entropy_Eosin_5_02_256
# 52    3.619783e-03  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_5_0...
# 53    3.513498e-03  Median_Nucleus_Texture_InfoMeas2_Hematoxylin_4...
# 54    3.446037e-03  Median_Nucleus_Texture_AngularSecondMoment_Eos...
# 55    3.409495e-03      Median_Nucleus_Texture_Entropy_Eosin_7_03_256
# 56    3.372156e-03             Mean_Nucleus_Granularity_3_Hematoxylin
# 57    3.369234e-03      Median_Nucleus_Texture_Entropy_Eosin_7_02_256
# 58    3.337174e-03  Median_Nucleus_Texture_Entropy_Hematoxylin_7_0...
# 59    3.284582e-03  Median_Nucleus_Texture_AngularSecondMoment_Eos...
# 60    3.225873e-03      Median_Nucleus_Texture_Entropy_Eosin_4_03_256
# 61    3.171698e-03  Mean_Nucleus_Texture_InfoMeas2_Hematoxylin_5_0...
# 62    3.155233e-03      Median_Nucleus_Texture_Entropy_Eosin_3_02_256
# 63    3.103572e-03                          Granularity_2_Hematoxylin
# 64    3.017371e-03      Median_Nucleus_Texture_Entropy_Eosin_4_00_256
# 65    3.011547e-03      Median_Nucleus_Texture_Entropy_Eosin_3_00_256
# 66    2.983685e-03  Mean_Nucleus_Texture_AngularSecondMoment_Eosin...
# 67    2.977104e-03      Median_Nucleus_Texture_Entropy_Eosin_5_00_256
# 68    2.847252e-03  Mean_Nucleus_Texture_InfoMeas2_Hematoxylin_5_0...
# 69    2.839126e-03        Mean_Nucleus_Texture_Entropy_Eosin_3_00_256
# 70    2.790172e-03  Mean_Nucleus_Texture_InfoMeas2_Hematoxylin_4_0...
# 71    2.742825e-03  Mean_Nucleus_Texture_InfoMeas2_Hematoxylin_4_0...
# 72    2.707372e-03        Mean_Nucleus_Texture_Entropy_Eosin_5_00_256
# 73    2.701509e-03  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_5...
# 74    2.680795e-03  Median_Nucleus_Texture_AngularSecondMoment_Eos...
# 75    2.643115e-03           Median_Nucleus_Granularity_3_Hematoxylin
# 76    2.631722e-03  Median_Nucleus_Texture_InfoMeas2_Hematoxylin_4...
# 77    2.623684e-03      Median_Nucleus_Texture_Entropy_Eosin_3_01_256
# 78    2.620561e-03  Median_Nucleus_Texture_AngularSecondMoment_Eos...
# 79    2.606380e-03  Median_Nucleus_Texture_InfoMeas2_Hematoxylin_5...
# 80    2.560773e-03  Median_Nucleus_Texture_InfoMeas2_Hematoxylin_5...
# 81    2.528061e-03      Median_Nucleus_Texture_Entropy_Eosin_4_01_256
# 82    2.514999e-03  Median_Nucleus_Texture_InfoMeas2_Hematoxylin_5...
# 83    2.484619e-03      Median_Nucleus_Texture_Entropy_Eosin_7_00_256
# 84    2.457969e-03  Mean_Nucleus_Texture_AngularSecondMoment_Eosin...
# 85    2.438222e-03        Mean_Nucleus_Texture_Entropy_Eosin_4_02_256
# 86    2.381055e-03  Mean_Nucleus_Texture_Contrast_Hematoxylin_5_03...
# 87    2.354191e-03  Median_Nucleus_Texture_InfoMeas2_Hematoxylin_3...
# 88    2.346574e-03        Mean_Nucleus_Texture_Entropy_Eosin_4_01_256
# 89    2.289416e-03         Median_Nucleus_AreaShape_CentralMoment_0_0
# 90    2.277751e-03  Mean_Nucleus_Texture_AngularSecondMoment_Eosin...
# 91    2.221072e-03  Mean_Nucleus_Texture_AngularSecondMoment_Eosin...
# 92    2.216792e-03        Mean_Nucleus_Texture_Entropy_Eosin_5_03_256
# 93    2.210128e-03                      Median_Nucleus_AreaShape_Area
# 94    2.198117e-03  Median_Nucleus_Texture_InfoMeas2_Hematoxylin_5...
# 95    2.177417e-03      Median_Nucleus_Texture_Entropy_Eosin_3_03_256
# 96    2.166059e-03        Mean_Nucleus_Texture_Entropy_Eosin_4_03_256
# 97    2.165344e-03        Mean_Nucleus_Texture_Entropy_Eosin_7_02_256
# 98    2.163335e-03        Mean_Nucleus_Texture_Entropy_Eosin_7_03_256
# 99    2.128615e-03  Mean_Nucleus_Texture_InfoMeas2_Hematoxylin_4_0...
# 100   2.054036e-03  Median_Nucleus_Texture_AngularSecondMoment_Eos...
# 101   2.016645e-03  Median_Nucleus_Texture_AngularSecondMoment_Eos...
# 102   2.016048e-03  Median_Nucleus_Texture_AngularSecondMoment_Eos...
# 103   2.007883e-03        Mean_Nucleus_Texture_Entropy_Eosin_5_01_256
# 104   1.989141e-03  Median_Nucleus_Texture_InfoMeas2_Hematoxylin_7...
# 105   1.979221e-03  Median_Nucleus_Texture_AngularSecondMoment_Hem...
# 106   1.976492e-03  Mean_Nucleus_Texture_InfoMeas2_Hematoxylin_5_0...
# 107   1.934136e-03        Mean_Nucleus_Texture_Entropy_Eosin_3_03_256
# 108   1.900334e-03         Median_Nucleus_AreaShape_SpatialMoment_0_0
# 109   1.881506e-03  Mean_Nucleus_Texture_Contrast_Hematoxylin_7_02...
# 110   1.794480e-03  Mean_Nucleus_Texture_AngularSecondMoment_Eosin...
# 111   1.737697e-03        Mean_Nucleus_Texture_Entropy_Eosin_3_02_256
# 112   1.680140e-03        Mean_Nucleus_Texture_Entropy_Eosin_7_01_256
# 113   1.664397e-03  Median_Nucleus_Texture_Entropy_Hematoxylin_7_0...
# 114   1.593834e-03  Mean_Nucleus_AreaShape_InertiaTensorEigenvalues_1
# 115   1.592509e-03      Median_Nucleus_Texture_Entropy_Eosin_5_03_256
# 116   1.569485e-03  Median_Nucleus_Texture_InfoMeas2_Hematoxylin_7...
# 117   1.553309e-03  StDev_Nucleus_Texture_Contrast_Hematoxylin_3_0...
# 118   1.543483e-03     Mean_Nucleus_Texture_SumEntropy_Eosin_7_01_256
# 119   1.537791e-03  Median_Nucleus_Texture_AngularSecondMoment_Eos...
# 120   1.530880e-03  Median_Nucleus_Texture_InfoMeas2_Hematoxylin_3...
# 121   1.529537e-03  Mean_Nucleus_Texture_AngularSecondMoment_Eosin...
# 122   1.527659e-03     Mean_Nucleus_Texture_SumEntropy_Eosin_7_03_256
# 123   1.516119e-03  Mean_Nucleus_Texture_Entropy_Hematoxylin_7_01_256
# 124   1.510624e-03  Mean_Nucleus_Texture_InfoMeas2_Hematoxylin_4_0...
# 125   1.482039e-03            Mean_Nucleus_AreaShape_MinFeretDiameter
# 126   1.440525e-03  Mean_Nucleus_Texture_AngularSecondMoment_Eosin...
# 127   1.426974e-03  Mean_Nucleus_Texture_Contrast_Hematoxylin_5_02...
# 128   1.424339e-03        Mean_Nucleus_Texture_Entropy_Eosin_7_00_256
# 129   1.421305e-03  Mean_Nucleus_Texture_Contrast_Hematoxylin_3_03...
# 130   1.419013e-03  StDev_Nucleus_Texture_Contrast_Hematoxylin_4_0...
# 131   1.416632e-03  Mean_Nucleus_Texture_AngularSecondMoment_Eosin...
# 132   1.411067e-03  Median_Nucleus_Texture_Entropy_Hematoxylin_7_0...
# 133   1.401013e-03  Median_Nucleus_Texture_AngularSecondMoment_Eos...
# 134   1.370389e-03  Median_Nucleus_Texture_Entropy_Hematoxylin_5_0...
# 135   1.327274e-03  Median_Nucleus_Texture_Variance_Hematoxylin_4_...
# 136   1.308781e-03                Median_Nucleus_AreaShape_ConvexArea
# 137   1.307695e-03  Mean_Nucleus_Texture_InfoMeas2_Hematoxylin_3_0...
# 138   1.293620e-03  Mean_Nucleus_Texture_Entropy_Hematoxylin_4_01_256
# 139   1.292428e-03  Mean_Nucleus_Texture_Contrast_Hematoxylin_4_03...
# 140   1.290191e-03  Median_Nucleus_Texture_InfoMeas2_Hematoxylin_3...
# 141   1.234219e-03        Median_Nucleus_AreaShape_EquivalentDiameter
# 142   1.223332e-03  StDev_Nucleus_Texture_InfoMeas2_Hematoxylin_5_...
# 143   1.186464e-03                                        ImageNumber
# 144   1.176390e-03        Mean_Nucleus_Texture_Entropy_Eosin_3_01_256
# 145   1.175244e-03  Mean_Nucleus_Texture_AngularSecondMoment_Eosin...
# 146   1.172687e-03  Median_Nucleus_Texture_InfoMeas2_Hematoxylin_4...
# 147   1.162408e-03   Median_Nucleus_Texture_SumEntropy_Eosin_7_01_256
# 148   1.155840e-03  Mean_Nucleus_Texture_Contrast_Hematoxylin_4_01...
# 149   1.146098e-03  Median_Nucleus_Texture_Entropy_Hematoxylin_4_0...
# 150   1.145823e-03  Mean_Nucleus_Texture_Variance_Hematoxylin_4_01...
# 151   1.138282e-03  Mean_Nucleus_Texture_AngularSecondMoment_Eosin...
# 152   1.127657e-03  Mean_Nucleus_Texture_AngularSecondMoment_Eosin...
# 153   1.126699e-03  Mean_Nucleus_Texture_Entropy_Hematoxylin_5_01_256
# 154   1.112342e-03         Median_Nucleus_AreaShape_SpatialMoment_1_0
# 155   1.102707e-03   Median_Nucleus_Texture_SumEntropy_Eosin_7_03_256
# 156   1.097761e-03            StDev_Nucleus_Granularity_3_Hematoxylin
# 157   1.092874e-03  Mean_Nucleus_Texture_AngularSecondMoment_Eosin...
# 158   1.091743e-03           Mean_Nucleus_AreaShape_CentralMoment_0_0
# 159   1.088315e-03  Mean_Nucleus_Texture_Entropy_Hematoxylin_7_02_256
# 160   1.071300e-03  Median_Nucleus_Texture_InfoMeas2_Hematoxylin_4...
# 161   1.068209e-03      Median_Nucleus_Texture_Entropy_Eosin_7_01_256
# 162   1.067022e-03  Median_Nucleus_Texture_Contrast_Hematoxylin_4_...
# 163   1.060320e-03  Mean_Nucleus_Texture_InfoMeas2_Hematoxylin_3_0...
# 164   1.045752e-03  Mean_Nucleus_Texture_Variance_Hematoxylin_4_00...
# 165   1.004271e-03        Mean_Nucleus_Texture_Entropy_Eosin_4_00_256
# 166   9.813378e-04  Mean_Nucleus_Texture_Contrast_Hematoxylin_5_01...
# 167   9.755322e-04  Mean_Nucleus_Texture_Contrast_Hematoxylin_5_00...
# 168   9.644531e-04             Mean_Nucleus_Granularity_1_Hematoxylin
# 169   9.585096e-04  Median_Nucleus_Texture_Variance_Hematoxylin_4_...
# 170   9.492978e-04  Median_ExpandCells_Texture_Correlation_Hematox...
# 171   9.469579e-04  Mean_Nucleus_Texture_SumVariance_Hematoxylin_3...
# 172   9.458016e-04  Mean_Nucleus_Texture_Variance_Hematoxylin_3_03...
# 173   9.426346e-04                        Mean_Nucleus_AreaShape_Area
# 174   9.158076e-04  Mean_Nucleus_Texture_Contrast_Hematoxylin_4_02...
# 175   9.154337e-04  Mean_Nucleus_RadialDistribution_MeanFrac_Hemat...
# 176   8.875031e-04  Mean_Nucleus_Texture_AngularSecondMoment_Eosin...
# 177   8.834391e-04  Median_Nucleus_Texture_Entropy_Hematoxylin_5_0...
# 178   8.805122e-04  Median_Nucleus_Texture_Entropy_Hematoxylin_4_0...
# 179   8.722177e-04  Mean_Nucleus_Texture_SumVariance_Hematoxylin_4...
# 180   8.487732e-04  Mean_ExpandCells_Texture_Correlation_Hematoxyl...
# 181   8.370681e-04  Median_Nucleus_Texture_Entropy_Hematoxylin_7_0...
# 182   8.345278e-04                  Median_Nucleus_AreaShape_Solidity
# 183   8.321246e-04  Mean_Nucleus_Texture_AngularSecondMoment_Hemat...
# 184   8.266834e-04  Median_ExpandCells_Texture_Correlation_Hematox...
# 185   8.126020e-04  StDev_Nucleus_Texture_Contrast_Hematoxylin_3_0...
# 186   8.064247e-04  Mean_Nucleus_Texture_DifferenceEntropy_Eosin_7...
# 187   8.029649e-04  Mean_Nucleus_Texture_SumVariance_Hematoxylin_3...
# 188   8.015448e-04  Mean_Nucleus_Texture_Entropy_Hematoxylin_5_03_256
# 189   7.983934e-04  Median_Nucleus_Texture_Contrast_Hematoxylin_5_...
# 190   7.926235e-04  StDev_Nucleus_Texture_InfoMeas2_Hematoxylin_3_...
# 191   7.921152e-04  Median_Nucleus_Texture_AngularSecondMoment_Eos...
# 192   7.802043e-04  Mean_Nucleus_Texture_Variance_Hematoxylin_7_03...
# 193   7.778221e-04  Mean_Nucleus_Texture_Variance_Hematoxylin_4_02...
# 194   7.777233e-04  StDev_Nucleus_Texture_Contrast_Hematoxylin_4_0...
# 195   7.754936e-04            StDev_Nucleus_Granularity_4_Hematoxylin
# 196   7.568728e-04  Mean_Nucleus_Texture_InverseDifferenceMoment_H...
# 197   7.551928e-04  Mean_Nucleus_Texture_Contrast_Hematoxylin_4_00...
# 198   7.528220e-04               Mean_ExpandCells_AreaShape_Perimeter
# 199   7.494085e-04  Mean_Nucleus_Texture_Contrast_Hematoxylin_7_00...
# 200   7.459890e-04  Mean_Nucleus_Texture_SumVariance_Hematoxylin_3...
# 201   7.445412e-04  Median_Nucleus_Texture_Contrast_Hematoxylin_7_...
# 202   7.416070e-04  Mean_Nucleus_Texture_SumVariance_Hematoxylin_3...
# 203   7.395211e-04  Mean_Nucleus_Texture_Variance_Hematoxylin_3_01...
# 204   7.244078e-04  Mean_Nucleus_Texture_SumVariance_Hematoxylin_4...
# 205   7.164518e-04  Mean_Nucleus_Texture_Variance_Hematoxylin_4_03...
# 206   7.111441e-04  Mean_Nucleus_Texture_Variance_Hematoxylin_3_02...
# 207   6.993679e-04  Mean_Nucleus_Texture_Entropy_Hematoxylin_5_02_256
# 208   6.912878e-04  Median_Nucleus_Texture_SumVariance_Hematoxylin...
# 209   6.737429e-04  Median_Nucleus_Texture_InverseDifferenceMoment...
# 210   6.717701e-04             Mean_ExpandCells_AreaShape_Compactness
# 211   6.661074e-04  Mean_Nucleus_Texture_AngularSecondMoment_Eosin...
# 212   6.615950e-04  Median_Nucleus_Texture_InfoMeas2_Hematoxylin_3...
# 213   6.587545e-04  StDev_Nucleus_Texture_Contrast_Hematoxylin_5_0...
# 214   6.565987e-04  Median_Nucleus_Texture_Variance_Hematoxylin_5_...
# 215   6.564681e-04  Median_Nucleus_Texture_SumVariance_Hematoxylin...
# 216   6.546940e-04  Mean_Nucleus_Texture_Variance_Hematoxylin_5_01...
# 217   6.463803e-04  Mean_ExpandCells_Texture_Correlation_Hematoxyl...
# 218   6.318588e-04  Median_Nucleus_Texture_InverseDifferenceMoment...
# 219   6.273280e-04    Median_ExpandCells_Intensity_MaxIntensity_Eosin
# 220   6.254907e-04  Mean_Nucleus_Texture_SumVariance_Hematoxylin_5...
# 221   6.239102e-04  StDev_Nucleus_Texture_InfoMeas2_Hematoxylin_5_...
# 222   6.238295e-04  Mean_Nucleus_Texture_Variance_Hematoxylin_5_00...
# 223   6.180239e-04  Mean_Nucleus_Texture_Variance_Hematoxylin_3_00...
# 224   6.020348e-04           Mean_Nucleus_AreaShape_SpatialMoment_0_0
# 225   5.974020e-04  Mean_Nucleus_RadialDistribution_MeanFrac_Hemat...
# 226   5.972581e-04  Median_Nucleus_Texture_Entropy_Hematoxylin_4_0...
# 227   5.964714e-04  Mean_Nucleus_Texture_Variance_Hematoxylin_7_00...
# 228   5.952041e-04  Median_Nucleus_Texture_SumVariance_Hematoxylin...
# 229   5.942162e-04                    Mean_Nucleus_AreaShape_Solidity
# 230   5.927128e-04  Median_Nucleus_Texture_Variance_Hematoxylin_3_...
# 231   5.900904e-04   Median_Nucleus_Texture_SumEntropy_Eosin_7_00_256
# 232   5.885807e-04  Mean_Nucleus_Texture_SumVariance_Hematoxylin_4...
# 233   5.873994e-04  Mean_Nucleus_Texture_Contrast_Hematoxylin_3_02...
# 234   5.848037e-04  Mean_Nucleus_Texture_InfoMeas2_Hematoxylin_3_0...
# 235   5.808322e-04  Median_Nucleus_Texture_Variance_Hematoxylin_5_...
# 236   5.733779e-04  Mean_Nucleus_Texture_AngularSecondMoment_Eosin...
# 237   5.703399e-04  Median_Nucleus_Texture_Variance_Hematoxylin_3_...
# 238   5.573211e-04      Mean_ExpandCells_Intensity_MaxIntensity_Eosin
# 239   5.546000e-04         Median_Nucleus_AreaShape_CentralMoment_2_0
# 240   5.540194e-04  StDev_Nucleus_Texture_InfoMeas2_Hematoxylin_4_...
# 241   5.513269e-04  Mean_Nucleus_Texture_InverseDifferenceMoment_H...
# 242   5.506096e-04         Median_Nucleus_AreaShape_SpatialMoment_1_2
# 243   5.495387e-04  Mean_Nucleus_Texture_Variance_Hematoxylin_7_02...
# 244   5.490341e-04  Median_Nucleus_Texture_Contrast_Hematoxylin_3_...
# 245   5.466917e-04  Mean_Nucleus_Texture_Entropy_Hematoxylin_5_00_256
# 246   5.377177e-04  Mean_Nucleus_Texture_Variance_Hematoxylin_5_02...
# 247   5.373718e-04  Mean_Nucleus_Texture_Contrast_Hematoxylin_7_01...
# 248   5.357094e-04  Mean_Nucleus_Texture_InverseDifferenceMoment_H...
# 249   5.340459e-04  Median_Nucleus_Texture_Entropy_Hematoxylin_5_0...
# 250   5.290730e-04  Median_Nucleus_Texture_Variance_Hematoxylin_7_...
# 251   5.278385e-04  Mean_Nucleus_Texture_SumVariance_Hematoxylin_5...
# 252   5.250945e-04  Median_Nucleus_Texture_AngularSecondMoment_Hem...
# 253   5.203136e-04  Median_Nucleus_Texture_Contrast_Hematoxylin_4_...
# 254   5.148077e-04         Median_Nucleus_AreaShape_SpatialMoment_2_3
# 255   5.142533e-04  Median_Nucleus_Texture_SumVariance_Hematoxylin...
# 256   5.128055e-04  Median_Nucleus_Texture_SumVariance_Hematoxylin...
# 257   5.109298e-04  StDev_Nucleus_Texture_Contrast_Hematoxylin_3_0...
# 258   5.085728e-04  Mean_Nucleus_Intensity_StdIntensityEdge_Hemato...
# 259   5.032230e-04    Mean_Nucleus_Intensity_StdIntensity_Hematoxylin
# 260   5.015043e-04  Mean_Nucleus_Texture_Variance_Hematoxylin_7_01...
# 261   4.975231e-04  Median_Nucleus_Texture_Variance_Hematoxylin_7_...
# 262   4.950857e-04  Median_Nucleus_Intensity_MADIntensity_Hematoxylin
# 263   4.947399e-04              Mean_ExpandCells_AreaShape_ConvexArea
# 264   4.934836e-04  Median_Nucleus_Texture_InverseDifferenceMoment...
# 265   4.931825e-04           Median_Nucleus_Granularity_1_Hematoxylin
# 266   4.885742e-04  Median_Nucleus_Texture_SumVariance_Hematoxylin...
# 267   4.843236e-04  Mean_Nucleus_Texture_Variance_Hematoxylin_5_03...
# 268   4.776301e-04  Median_Nucleus_Texture_Contrast_Hematoxylin_5_...
# 269   4.767535e-04              StDev_ExpandCells_AreaShape_Perimeter
# 270   4.760909e-04  StDev_ExpandCells_Intensity_MaxIntensityEdge_E...
# 271   4.739188e-04  Mean_Nucleus_Texture_SumVariance_Hematoxylin_4...
# 272   4.734202e-04  Median_Nucleus_Texture_AngularSecondMoment_Hem...
# 273   4.721270e-04     StDev_ExpandCells_Intensity_MaxIntensity_Eosin
# 274   4.638002e-04  StDev_Nucleus_Texture_InfoMeas2_Hematoxylin_5_...
# 275   4.588613e-04  Mean_Nucleus_RadialDistribution_RadialCV_Hemat...
# 276   4.569632e-04  Median_Nucleus_Texture_Variance_Hematoxylin_5_...
# 277   4.562540e-04  Median_Nucleus_Texture_AngularSecondMoment_Eos...
# 278   4.556855e-04  Mean_Nucleus_Texture_Contrast_Hematoxylin_3_01...
# 279   4.514611e-04  Median_Nucleus_Texture_Variance_Hematoxylin_3_...
# 280   4.448558e-04  Median_Nucleus_Intensity_StdIntensityEdge_Hema...
# 281   4.405896e-04   Median_Nucleus_Texture_SumEntropy_Eosin_5_03_256
# 282   4.390151e-04  Median_Nucleus_Texture_Contrast_Hematoxylin_5_...
# 283   4.388876e-04  Median_Nucleus_Texture_Entropy_Hematoxylin_3_0...
# 284   4.381697e-04  Median_Nucleus_Texture_Contrast_Hematoxylin_7_...
# 285   4.346728e-04  Median_Nucleus_Texture_Variance_Hematoxylin_5_...
# 286   4.341361e-04  Median_Nucleus_Texture_Contrast_Hematoxylin_3_...
# 287   4.297783e-04  Mean_Nucleus_Texture_InverseDifferenceMoment_H...
# 288   4.294286e-04  Mean_Nucleus_Texture_SumVariance_Hematoxylin_5...
# 289   4.182472e-04  Mean_ExpandCells_AreaShape_InertiaTensorEigenv...
# 290   4.165400e-04                    Mean_Tissue_Granularity_1_Eosin
# 291   4.159570e-04  StDev_Nucleus_Texture_InfoMeas2_Hematoxylin_3_...
# 292   4.136146e-04           Median_ExpandCells_AreaShape_Compactness
# 293   4.071346e-04  Median_Nucleus_Texture_AngularSecondMoment_Hem...
# 294   3.983403e-04       StDev_ExpandCells_AreaShape_MinFeretDiameter
# 295   3.969419e-04  Mean_ExpandCells_AreaShape_InertiaTensorEigenv...
# 296   3.925009e-04  Mean_Nucleus_Texture_SumAverage_Hematoxylin_5_...
# 297   3.922820e-04  StDev_Nucleus_Intensity_MeanIntensity_Hematoxylin
# 298   3.908498e-04  Median_Nucleus_Texture_Contrast_Hematoxylin_7_...
# 299   3.900213e-04  Median_ExpandCells_Texture_Entropy_Eosin_5_03_256
# 300   3.877501e-04  Median_Nucleus_Texture_SumVariance_Hematoxylin...
# 301   3.861611e-04  Mean_Nucleus_Neighbors_SecondClosestDistance_E...
# 302   3.819800e-04    Mean_Nucleus_Texture_Correlation_Eosin_3_00_256
# 303   3.815529e-04  StDev_Nucleus_RadialDistribution_ZernikeMagnit...
# 304   3.807031e-04  Median_Nucleus_Intensity_MaxIntensity_Hematoxylin
# 305   3.801897e-04  Mean_Nucleus_RadialDistribution_ZernikeMagnitu...
# 306   3.785090e-04                  Median_Tissue_Granularity_1_Eosin
# 307   3.747761e-04  Mean_Nucleus_Texture_AngularSecondMoment_Hemat...
# 308   3.736767e-04  Median_Nucleus_Texture_SumVariance_Hematoxylin...
# 309   3.733802e-04  Median_Nucleus_Intensity_MinIntensity_Hematoxylin
# 310   3.726401e-04    Mean_Nucleus_Intensity_MADIntensity_Hematoxylin
# 311   3.726053e-04   Median_Nucleus_Texture_SumEntropy_Eosin_4_03_256
# 312   3.697691e-04  Median_Nucleus_Texture_Variance_Hematoxylin_7_...
# 313   3.667309e-04   Median_Nucleus_Texture_SumEntropy_Eosin_7_02_256
# 314   3.649302e-04  Mean_Nucleus_Texture_AngularSecondMoment_Hemat...
# 315   3.646099e-04   Median_Nucleus_Texture_SumEntropy_Eosin_5_01_256
# 316   3.634744e-04  Median_Nucleus_Texture_Entropy_Hematoxylin_3_0...
# 317   3.633082e-04  StDev_Nucleus_Neighbors_SecondClosestObjectNum...
# 318   3.614232e-04  Median_Nucleus_Texture_InverseDifferenceMoment...
# 319   3.596970e-04  Median_Nucleus_Texture_Contrast_Hematoxylin_7_...
# 320   3.588706e-04  Mean_Nucleus_Texture_InfoMeas2_Hematoxylin_5_0...
# 321   3.587801e-04   Median_Nucleus_Texture_SumAverage_Eosin_5_02_256
# 322   3.587124e-04  Mean_Nucleus_RadialDistribution_MeanFrac_Hemat...
# 323   3.586321e-04  Mean_Nucleus_Neighbors_FirstClosestDistance_Ex...
# 324   3.586121e-04  Median_ExpandCells_Texture_Entropy_Eosin_3_01_256
# 325   3.586062e-04    Mean_Nucleus_Intensity_MinIntensity_Hematoxylin
# 326   3.580203e-04  Median_Nucleus_Texture_DifferenceEntropy_Eosin...
# 327   3.556157e-04               Mean_ExpandCells_Granularity_1_Eosin
# 328   3.546904e-04  Median_ExpandCells_Texture_Entropy_Eosin_7_03_256
# 329   3.546562e-04  Median_ExpandCells_Texture_Entropy_Eosin_7_00_256
# 330   3.540448e-04   Median_Nucleus_Texture_SumAverage_Eosin_5_03_256
# 331   3.532955e-04  Median_Nucleus_Texture_InverseDifferenceMoment...
# 332   3.516255e-04  Mean_Nucleus_Texture_DifferenceVariance_Eosin_...
# 333   3.500257e-04  Median_Nucleus_Texture_AngularSecondMoment_Hem...
# 334   3.491991e-04         Mean_ExpandCells_AreaShape_BoundingBoxArea
# 335   3.490687e-04  Mean_Nucleus_RadialDistribution_MeanFrac_Hemat...
# 336   3.479033e-04  Mean_Nucleus_Texture_Entropy_Hematoxylin_7_03_256
# 337   3.457389e-04       Mean_ExpandCells_AreaShape_SpatialMoment_2_1
# 338   3.454320e-04  Median_ExpandCells_Texture_Entropy_Eosin_5_00_256
# 339   3.450686e-04  Median_Nucleus_Texture_SumVariance_Hematoxylin...
# 340   3.450191e-04  Median_ExpandCells_Texture_Entropy_Eosin_7_01_256
# 341   3.445398e-04  Median_Nucleus_RadialDistribution_MeanFrac_Hem...
# 342   3.429451e-04   Median_Nucleus_Texture_SumEntropy_Eosin_3_03_256
# 343   3.427087e-04    Mean_ExpandCells_Texture_Entropy_Eosin_5_03_256
# 344   3.411753e-04  Mean_Nucleus_Texture_Entropy_Hematoxylin_3_03_256
# 345   3.368705e-04            Texture_SumAverage_Hematoxylin_7_00_256
# 346   3.367860e-04       Mean_ExpandCells_AreaShape_SpatialMoment_1_0
# 347   3.362202e-04    Mean_Nucleus_Texture_SumVariance_Eosin_7_01_256
# 348   3.356324e-04  Mean_Nucleus_Texture_InverseDifferenceMoment_H...
# 349   3.354719e-04  Mean_Nucleus_Texture_DifferenceEntropy_Eosin_7...
# 350   3.350572e-04     Mean_Nucleus_Texture_SumEntropy_Eosin_5_03_256
# 351   3.344132e-04   Median_Nucleus_Texture_SumEntropy_Eosin_4_01_256
# 352   3.343226e-04             Median_ExpandCells_Granularity_1_Eosin
# 353   3.328056e-04         Median_Nucleus_AreaShape_SpatialMoment_2_0
# 354   3.289812e-04        Mean_ExpandCells_AreaShape_MinFeretDiameter
# 355   3.274086e-04  Mean_Nucleus_Texture_InverseDifferenceMoment_H...
# 356   3.259109e-04  StDev_ExpandCells_Texture_SumVariance_Hematoxy...
# 357   3.254335e-04  Mean_Nucleus_Texture_AngularSecondMoment_Eosin...
# 358   3.226559e-04  Mean_Nucleus_Texture_DifferenceEntropy_Eosin_3...
# 359   3.215794e-04  Median_Nucleus_Texture_Variance_Hematoxylin_4_...
# 360   3.191296e-04  Median_Nucleus_RadialDistribution_MeanFrac_Hem...
# 361   3.185340e-04            Texture_SumAverage_Hematoxylin_3_03_256
# 362   3.162440e-04     StDev_ExpandCells_AreaShape_EquivalentDiameter
# 363   3.155993e-04  Median_Nucleus_Texture_AngularSecondMoment_Eos...
# 364   3.146837e-04  StDev_ExpandCells_Texture_SumVariance_Hematoxy...
# 365   3.140835e-04  StDev_ExpandCells_Texture_SumVariance_Hematoxy...
# 366   3.140099e-04  Median_ExpandCells_Texture_Entropy_Eosin_5_01_256
# 367   3.130118e-04       Mean_ExpandCells_AreaShape_CentralMoment_2_0
# 368   3.129108e-04  Median_ExpandCells_Texture_Entropy_Eosin_5_02_256
# 369   3.122271e-04  Median_Nucleus_Texture_AngularSecondMoment_Hem...
# 370   3.115311e-04  StDev_Nucleus_Texture_Contrast_Hematoxylin_3_0...
# 371   3.113174e-04    Mean_ExpandCells_Texture_Entropy_Eosin_4_03_256
# 372   3.110544e-04            Texture_SumAverage_Hematoxylin_5_01_256
# 373   3.100630e-04  Mean_Nucleus_RadialDistribution_ZernikePhase_H...
# 374   3.086716e-04  Median_Nucleus_Texture_InverseDifferenceMoment...
# 375   3.084922e-04    Mean_Nucleus_Intensity_MaxIntensity_Hematoxylin
# 376   3.084055e-04  Median_ExpandCells_Texture_Entropy_Eosin_3_02_256
# 377   3.060917e-04                Median_Nucleus_AreaShape_HuMoment_0
# 378   3.059517e-04  StDev_Nucleus_Texture_SumAverage_Hematoxylin_3...
# 379   3.055426e-04                   Threshold_WeightedVariance_Cells
# 380   3.049873e-04  Median_ExpandCells_Texture_Entropy_Eosin_4_03_256
# 381   3.046598e-04  StDev_Nucleus_Texture_SumAverage_Hematoxylin_4...
# 382   3.042222e-04  Median_Nucleus_Texture_Variance_Hematoxylin_4_...
# 383   3.041297e-04  Mean_ExpandCells_Neighbors_SecondClosestDistan...
# 384   3.039484e-04  Median_Nucleus_Texture_SumAverage_Hematoxylin_...
# 385   3.030322e-04    Mean_Nucleus_Texture_SumVariance_Eosin_7_03_256
# 386   3.024940e-04            Texture_SumAverage_Hematoxylin_4_02_256
# 387   3.012896e-04  Mean_Nucleus_Texture_SumVariance_Hematoxylin_7...
# 388   3.007273e-04  Median_Nucleus_RadialDistribution_RadialCV_Hem...
# 389   2.998870e-04  Mean_Nucleus_Texture_SumEntropy_Hematoxylin_7_...
# 390   2.982764e-04       Mean_ExpandCells_AreaShape_SpatialMoment_0_0
# 391   2.967455e-04                      Mean_Nucleus_AreaShape_Extent
# 392   2.962746e-04                 StDev_Nucleus_AreaShape_MeanRadius
# 393   2.958621e-04  StDev_ExpandCells_Texture_SumVariance_Hematoxy...
# 394   2.948071e-04       Mean_ExpandCells_AreaShape_SpatialMoment_0_1
# 395   2.940811e-04  Mean_Nucleus_Texture_DifferenceVariance_Eosin_...
# 396   2.937046e-04  StDev_Nucleus_Texture_SumAverage_Hematoxylin_5...
# 397   2.926443e-04  StDev_Nucleus_Texture_Contrast_Hematoxylin_4_0...
# 398   2.925489e-04  Mean_Nucleus_Texture_Entropy_Hematoxylin_3_02_256
# 399   2.916119e-04   Median_Nucleus_Texture_SumAverage_Eosin_4_00_256
# 400   2.913766e-04  Median_Nucleus_Intensity_LowerQuartileIntensit...
# 401   2.907528e-04   Median_Nucleus_Texture_SumAverage_Eosin_3_03_256
# 402   2.907257e-04  Median_ExpandCells_Texture_Entropy_Eosin_7_02_256
# 403   2.906210e-04  Median_Nucleus_Texture_InverseDifferenceMoment...
# 404   2.866801e-04   Median_Nucleus_Texture_SumAverage_Eosin_7_03_256
# 405   2.864785e-04    Mean_ExpandCells_Texture_Entropy_Eosin_5_00_256
# 406   2.863000e-04  Median_ExpandCells_Intensity_MinIntensityEdge_...
# 407   2.862253e-04  StDev_Nucleus_Texture_Contrast_Hematoxylin_7_0...
# 408   2.858588e-04            Median_ExpandCells_AreaShape_FormFactor
# 409   2.856965e-04   Median_Nucleus_Texture_SumAverage_Eosin_5_01_256
# 410   2.852711e-04  StDev_ExpandCells_Texture_SumVariance_Hematoxy...
# 411   2.846580e-04    Mean_ExpandCells_Texture_Entropy_Eosin_7_02_256
# 412   2.846207e-04  Mean_Nucleus_Intensity_MaxIntensityEdge_Hemato...
# 413   2.845205e-04  Median_Nucleus_Texture_Correlation_Eosin_3_00_256
# 414   2.843691e-04    Mean_Nucleus_Neighbors_PercentTouching_Expanded
# 415   2.835507e-04   Median_Nucleus_Texture_SumAverage_Eosin_7_01_256
# 416   2.831867e-04  Median_Nucleus_RadialDistribution_MeanFrac_Hem...
# 417   2.828392e-04            Texture_SumAverage_Hematoxylin_3_00_256
# 418   2.821991e-04                    Median_Nucleus_AreaShape_Extent
# 419   2.804114e-04  Mean_Nucleus_Texture_AngularSecondMoment_Hemat...
# 420   2.803179e-04       Mean_ExpandCells_AreaShape_SpatialMoment_2_0
# 421   2.793445e-04  Median_Nucleus_Texture_Variance_Hematoxylin_3_...
# 422   2.792476e-04  Median_Nucleus_Texture_Contrast_Hematoxylin_5_...
# 423   2.791693e-04       Mean_ExpandCells_AreaShape_SpatialMoment_0_3
# 424   2.788077e-04  Median_ExpandCells_Texture_Entropy_Eosin_4_01_256
# 425   2.780395e-04  StDev_Nucleus_Texture_Contrast_Hematoxylin_5_0...
# 426   2.775485e-04  Median_ExpandCells_Texture_Entropy_Eosin_3_03_256
# 427   2.754735e-04  Median_Nucleus_Intensity_MinIntensityEdge_Hema...
# 428   2.749154e-04  StDev_Nucleus_Texture_SumAverage_Hematoxylin_5...
# 429   2.741810e-04    Mean_ExpandCells_Texture_Entropy_Eosin_5_01_256
# 430   2.740389e-04    Mean_ExpandCells_Texture_Entropy_Eosin_3_01_256
# 431   2.739098e-04                 Mean_Nucleus_AreaShape_Zernike_0_0
# 432   2.736048e-04             StDev_ExpandCells_AreaShape_ConvexArea
# 433   2.732352e-04  Median_Nucleus_Neighbors_SecondClosestDistance...
# 434   2.731743e-04  Median_Nucleus_Texture_Entropy_Hematoxylin_5_0...
# 435   2.711948e-04  Median_Nucleus_Texture_SumAverage_Hematoxylin_...
# 436   2.711900e-04    Mean_ExpandCells_Texture_Entropy_Eosin_3_02_256
# 437   2.711599e-04          Mean_Nucleus_AreaShape_EquivalentDiameter
# 438   2.698626e-04               Median_Nucleus_AreaShape_Zernike_0_0
# 439   2.698332e-04  StDev_Nucleus_Texture_SumAverage_Hematoxylin_5...
# 440   2.697606e-04              Mean_ExpandCells_AreaShape_FormFactor
# 441   2.697606e-04       Mean_ExpandCells_AreaShape_SpatialMoment_1_1
# 442   2.696896e-04     Mean_Nucleus_Texture_SumAverage_Eosin_4_03_256
# 443   2.695155e-04   Median_Nucleus_Texture_SumAverage_Eosin_3_01_256
# 444   2.694458e-04  StDev_Nucleus_Texture_Contrast_Hematoxylin_7_0...
# 445   2.693453e-04                 Mean_Nucleus_AreaShape_Compactness
# 446   2.688101e-04  Mean_Nucleus_Intensity_MinIntensityEdge_Hemato...
# 447   2.685321e-04  StDev_Nucleus_Texture_SumAverage_Hematoxylin_4...
# 448   2.677570e-04  StDev_Nucleus_Texture_SumAverage_Hematoxylin_4...
# 449   2.672407e-04  Mean_Nucleus_Texture_Entropy_Hematoxylin_4_02_256
# 450   2.671409e-04     Mean_Nucleus_Texture_SumEntropy_Eosin_3_01_256
# 451   2.665870e-04  Median_ExpandCells_Neighbors_FirstClosestDista...
# 452   2.655607e-04     Mean_Nucleus_Texture_SumAverage_Eosin_4_01_256
# 453   2.650812e-04  StDev_Nucleus_Texture_Contrast_Hematoxylin_5_0...
# 454   2.648374e-04  StDev_Nucleus_Texture_Contrast_Hematoxylin_5_0...
# 455   2.645377e-04  Mean_Nucleus_Texture_DifferenceVariance_Eosin_...
# 456   2.642079e-04             Mean_Nucleus_AreaShape_MajorAxisLength
# 457   2.638959e-04  Mean_Nucleus_Texture_DifferenceVariance_Hemato...
# 458   2.634185e-04  StDev_Nucleus_Texture_InfoMeas2_Hematoxylin_5_...
# 459   2.625006e-04  StDev_ExpandCells_Neighbors_FirstClosestObject...
# 460   2.622271e-04               Median_Nucleus_AreaShape_Compactness
# 461   2.617986e-04  Mean_Nucleus_Neighbors_SecondClosestObjectNumb...
# 462   2.615267e-04   Median_Nucleus_Texture_SumAverage_Eosin_4_01_256
# 463   2.612291e-04         Median_Tissue_Intensity_MaxIntensity_Eosin
# 464   2.610055e-04  Median_Nucleus_Texture_SumAverage_Hematoxylin_...
# 465   2.608537e-04  StDev_Nucleus_Texture_SumAverage_Hematoxylin_4...
# 466   2.604706e-04  Median_Nucleus_Texture_Entropy_Hematoxylin_3_0...
# 467   2.599798e-04  Mean_Nucleus_Texture_DifferenceVariance_Eosin_...
# 468   2.592554e-04  Median_Nucleus_RadialDistribution_MeanFrac_Hem...
# 469   2.581770e-04  StDev_Nucleus_Texture_SumVariance_Hematoxylin_...
# 470   2.570333e-04       Mean_ExpandCells_AreaShape_InertiaTensor_1_1
# 471   2.563915e-04  Mean_Nucleus_Texture_DifferenceVariance_Eosin_...
# 472   2.559934e-04   Median_Nucleus_Texture_SumEntropy_Eosin_5_00_256
# 473   2.552361e-04  Mean_Nucleus_RadialDistribution_RadialCV_Hemat...
# 474   2.539890e-04  StDev_ExpandCells_AreaShape_InertiaTensorEigen...
# 475   2.532351e-04  Mean_Nucleus_Texture_Entropy_Hematoxylin_4_00_256
# 476   2.529941e-04  Median_Nucleus_Texture_SumAverage_Hematoxylin_...
# 477   2.529448e-04  Mean_Nucleus_Neighbors_NumberOfNeighbors_Expanded
# 478   2.524332e-04  Mean_Nucleus_Texture_Entropy_Hematoxylin_7_00_256
# 479   2.522224e-04  Median_Nucleus_Texture_SumAverage_Hematoxylin_...
# 480   2.518119e-04    Mean_ExpandCells_Texture_Entropy_Eosin_7_01_256
# 481   2.512813e-04  StDev_Nucleus_Texture_SumAverage_Hematoxylin_5...
# 482   2.510099e-04  Median_Nucleus_Intensity_StdIntensity_Hematoxylin
# 483   2.496204e-04  Median_Nucleus_Texture_Variance_Hematoxylin_7_...
# 484   2.486806e-04  Mean_Nucleus_Texture_Contrast_Hematoxylin_7_03...
# 485   2.477408e-04  Median_Nucleus_Neighbors_FirstClosestDistance_...
# 486   2.476535e-04  Median_ExpandCells_Texture_Entropy_Eosin_4_02_256
# 487   2.474468e-04  Mean_Nucleus_RadialDistribution_MeanFrac_Hemat...
# 488   2.474062e-04         Mean_ExpandCells_AreaShape_MajorAxisLength
# 489   2.463343e-04            Texture_SumAverage_Hematoxylin_7_03_256
# 490   2.459657e-04     Mean_Nucleus_Texture_SumEntropy_Eosin_5_01_256
# 491   2.454645e-04  StDev_Nucleus_Texture_Contrast_Hematoxylin_4_0...
# 492   2.446888e-04     Mean_Nucleus_Texture_SumAverage_Eosin_5_03_256
# 493   2.443945e-04  Mean_Nucleus_Texture_SumVariance_Hematoxylin_5...
# 494   2.442772e-04  Mean_Nucleus_Texture_Entropy_Hematoxylin_3_01_256
# 495   2.439617e-04                 Mean_Nucleus_AreaShape_Zernike_4_4
# 496   2.433026e-04    Mean_ExpandCells_Texture_Entropy_Eosin_5_02_256
# 497   2.431247e-04  Median_Nucleus_Texture_AngularSecondMoment_Hem...
# 498   2.421797e-04  Median_Nucleus_Texture_SumAverage_Hematoxylin_...
# 499   2.417057e-04     Mean_Nucleus_Texture_SumAverage_Eosin_7_02_256
# 500   2.408121e-04  StDev_ExpandCells_Texture_SumVariance_Hematoxy...
# 501   2.407253e-04   Median_Nucleus_Texture_SumAverage_Eosin_7_00_256
# 502   2.406096e-04  StDev_Nucleus_Texture_SumAverage_Hematoxylin_3...
# 503   2.394407e-04  Median_Nucleus_Texture_Contrast_Hematoxylin_4_...
# 504   2.392259e-04  Median_Nucleus_Texture_SumAverage_Hematoxylin_...
# 505   2.388904e-04      StDev_ExpandCells_AreaShape_SpatialMoment_2_3
# 506   2.387589e-04     Mean_Nucleus_Texture_SumAverage_Eosin_4_02_256
# 507   2.381842e-04       Mean_ExpandCells_AreaShape_SpatialMoment_0_2
# 508   2.379577e-04       Mean_ExpandCells_AreaShape_SpatialMoment_2_2
# 509   2.378381e-04            Texture_SumAverage_Hematoxylin_4_01_256
# 510   2.374442e-04            Texture_SumAverage_Hematoxylin_4_03_256
# 511   2.372691e-04       StDev_Nucleus_Texture_Entropy_Eosin_4_02_256
# 512   2.371270e-04  Mean_Nucleus_Texture_DifferenceEntropy_Eosin_5...
# 513   2.368829e-04            Texture_SumAverage_Hematoxylin_5_02_256
# 514   2.358681e-04       Mean_Nucleus_Texture_Contrast_Eosin_3_00_256
# 515   2.353995e-04        StDev_ExpandCells_AreaShape_BoundingBoxArea
# 516   2.346477e-04     Mean_Nucleus_Texture_SumAverage_Eosin_7_01_256
# 517   2.343421e-04            Texture_SumAverage_Hematoxylin_5_00_256
# 518   2.343053e-04         Median_Nucleus_AreaShape_CentralMoment_2_2
# 519   2.342297e-04   Mean_ExpandCells_Texture_Contrast_Eosin_3_03_256
# 520   2.339662e-04  StDev_Nucleus_Texture_SumAverage_Hematoxylin_3...
# 521   2.334821e-04  Mean_Nucleus_RadialDistribution_FracAtD_Hemato...
# 522   2.331605e-04    Mean_ExpandCells_Texture_Entropy_Eosin_7_03_256
# 523   2.326080e-04       Mean_Nucleus_Texture_Contrast_Eosin_3_03_256
# 524   2.324802e-04  Median_Nucleus_Texture_SumAverage_Hematoxylin_...
# 525   2.312364e-04            Texture_SumAverage_Hematoxylin_5_03_256
# 526   2.309778e-04                                  Count_ExpandCells
# 527   2.308064e-04                   Texture_InfoMeas1_Eosin_3_00_256
# 528   2.306867e-04      StDev_ExpandCells_AreaShape_SpatialMoment_1_1
# 529   2.304344e-04     Mean_Nucleus_Texture_SumEntropy_Eosin_5_00_256
# 530   2.299683e-04  StDev_ExpandCells_Texture_SumVariance_Hematoxy...
# 531   2.292906e-04                  Mean_Nucleus_AreaShape_FormFactor
# 532   2.281540e-04  Mean_Nucleus_Texture_AngularSecondMoment_Hemat...
# 533   2.280078e-04                Median_Nucleus_AreaShape_FormFactor
# 534   2.278453e-04     Mean_Nucleus_Texture_SumAverage_Eosin_4_00_256
# 535   2.276565e-04  Median_Nucleus_Texture_SumVariance_Hematoxylin...
# 536   2.270600e-04    Mean_ExpandCells_Texture_Entropy_Eosin_4_02_256
# 537   2.264748e-04  StDev_ExpandCells_Texture_Correlation_Hematoxy...
# 538   2.262044e-04  Median_Nucleus_Texture_AngularSecondMoment_Hem...
# 539   2.253053e-04  Mean_Nucleus_Texture_DifferenceVariance_Hemato...
# 540   2.252458e-04    Mean_ExpandCells_Texture_Entropy_Eosin_4_01_256
# 541   2.247092e-04  Mean_Nucleus_Texture_DifferenceEntropy_Eosin_3...
# 542   2.246991e-04  Median_Nucleus_Texture_SumVariance_Hematoxylin...
# 543   2.243966e-04  Median_Nucleus_Texture_AngularSecondMoment_Hem...
# 544   2.243620e-04       StDev_Nucleus_Texture_Entropy_Eosin_5_00_256
# 545   2.240906e-04                  Mean_Nucleus_AreaShape_HuMoment_0
# 546   2.240495e-04  Median_ExpandCells_Texture_Entropy_Eosin_3_00_256
# 547   2.231738e-04            Texture_SumAverage_Hematoxylin_7_02_256
# 548   2.214040e-04   Median_Nucleus_Texture_SumAverage_Eosin_3_02_256
# 549   2.208142e-04  Mean_Nucleus_Texture_AngularSecondMoment_Hemat...
# 550   2.205645e-04  StDev_Nucleus_Texture_Variance_Hematoxylin_3_0...
# 551   2.204715e-04       Mean_ExpandCells_AreaShape_CentralMoment_0_2
# 552   2.202079e-04       Mean_ExpandCells_AreaShape_SpatialMoment_1_2
# 553   2.200105e-04  Median_Nucleus_Texture_SumVariance_Hematoxylin...
# 554   2.197233e-04  Mean_Nucleus_Texture_AngularSecondMoment_Hemat...
# 555   2.194533e-04   Mean_ExpandCells_Texture_Contrast_Eosin_4_02_256
# 556   2.193627e-04  Median_Nucleus_Texture_AngularSecondMoment_Hem...
# 557   2.190285e-04  Median_ExpandCells_Texture_Contrast_Hematoxyli...
# 558   2.188267e-04  StDev_ExpandCells_Texture_Correlation_Hematoxy...
# 559   2.186311e-04  Mean_Nucleus_Intensity_LowerQuartileIntensity_...
# 560   2.181154e-04  Median_ExpandCells_Neighbors_FirstClosestObjec...
# 561   2.180966e-04                     Threshold_SumOfEntropies_Cells
# 562   2.168239e-04       Mean_Nucleus_Texture_Variance_Eosin_5_01_256
# 563   2.165443e-04  Mean_ExpandCells_Texture_SumAverage_Hematoxyli...
# 564   2.163076e-04   Median_Nucleus_Texture_SumAverage_Eosin_4_02_256
# 565   2.159445e-04  Median_Nucleus_Texture_SumAverage_Hematoxylin_...
# 566   2.156962e-04       Mean_ExpandCells_AreaShape_SpatialMoment_2_3
# 567   2.155991e-04  StDev_ExpandCells_AreaShape_InertiaTensorEigen...
# 568   2.153876e-04  Median_Nucleus_Texture_SumAverage_Hematoxylin_...
# 569   2.152181e-04  Median_Nucleus_Texture_SumAverage_Hematoxylin_...
# 570   2.152112e-04  Mean_Nucleus_Texture_AngularSecondMoment_Hemat...
# 571   2.150233e-04  Mean_Nucleus_Texture_SumAverage_Hematoxylin_4_...
# 572   2.149278e-04     Mean_Nucleus_Texture_SumEntropy_Eosin_4_03_256
# 573   2.149071e-04  StDev_ExpandCells_Texture_InfoMeas2_Hematoxyli...
# 574   2.148527e-04  Median_Nucleus_Texture_DifferenceVariance_Eosi...
# 575   2.146907e-04            Mean_Nucleus_AreaShape_MaxFeretDiameter
# 576   2.142257e-04            Texture_SumAverage_Hematoxylin_7_01_256
# 577   2.135321e-04   Median_Nucleus_Texture_SumAverage_Eosin_4_03_256
# 578   2.134085e-04  StDev_Nucleus_Texture_SumAverage_Hematoxylin_3...
# 579   2.130839e-04       Mean_ExpandCells_AreaShape_CentralMoment_0_0
# 580   2.124586e-04  Median_Nucleus_Texture_AngularSecondMoment_Hem...
# 581   2.123934e-04  Median_Nucleus_Texture_DifferenceVariance_Eosi...
# 582   2.117459e-04  Mean_Nucleus_Texture_DifferenceEntropy_Eosin_4...
# 583   2.113840e-04  Mean_Nucleus_Texture_SumAverage_Hematoxylin_4_...
# 584   2.106881e-04  StDev_ExpandCells_Texture_SumVariance_Hematoxy...
# 585   2.104949e-04       StDev_Nucleus_Texture_Entropy_Eosin_5_02_256
# 586   2.104541e-04  Median_Nucleus_Intensity_MedianIntensity_Hemat...
# 587   2.103933e-04  Mean_Nucleus_Texture_Contrast_Hematoxylin_3_00...
# 588   2.103691e-04            Texture_SumAverage_Hematoxylin_4_00_256
# 589   2.089716e-04   Median_Nucleus_Texture_SumAverage_Eosin_3_00_256
# 590   2.089304e-04          Median_Nucleus_AreaShape_MaxFeretDiameter
# 591   2.088904e-04      StDev_ExpandCells_AreaShape_InertiaTensor_1_1
# 592   2.080977e-04  Median_Nucleus_Texture_Entropy_Hematoxylin_3_0...
# 593   2.074292e-04   Mean_ExpandCells_Texture_Contrast_Eosin_3_02_256
# 594   2.071998e-04  Median_Nucleus_Texture_DifferenceVariance_Eosi...
# 595   2.068118e-04                  Mean_Nucleus_AreaShape_HuMoment_1
# 596   2.065154e-04     Mean_Nucleus_Texture_SumEntropy_Eosin_4_00_256
# 597   2.057753e-04     Mean_Nucleus_Texture_SumEntropy_Eosin_4_01_256
# 598   2.053292e-04       Mean_ExpandCells_AreaShape_CentralMoment_2_2
# 599   2.053078e-04                 Mean_Nucleus_AreaShape_Zernike_2_2
# 600   2.047501e-04  Median_Nucleus_RadialDistribution_ZernikeMagni...
# 601   2.030806e-04      StDev_ExpandCells_AreaShape_SpatialMoment_0_0
# 602   2.030479e-04  Mean_Nucleus_Texture_InfoMeas2_Hematoxylin_3_0...
# 603   2.025227e-04  Median_ExpandCells_Texture_Contrast_Hematoxyli...
# 604   2.025142e-04  StDev_Nucleus_Texture_Variance_Hematoxylin_5_0...
# 605   2.014287e-04  Mean_Nucleus_Texture_DifferenceVariance_Hemato...
# 606   2.007103e-04  Median_ExpandCells_Texture_Correlation_Hematox...
# 607   2.006234e-04  Mean_Nucleus_Texture_SumAverage_Hematoxylin_7_...
# 608   2.003208e-04                          Mean_Cells_Parent_Nucleus
# 609   2.001574e-04  Median_Nucleus_Texture_DifferenceVariance_Eosi...
# 610   2.000600e-04       Mean_ExpandCells_AreaShape_SpatialMoment_1_3
# 611   1.999935e-04  Mean_Nucleus_Texture_DifferenceVariance_Eosin_...
# 612   1.992183e-04  Mean_Nucleus_RadialDistribution_ZernikeMagnitu...
# 613   1.990035e-04        StDev_ExpandCells_AreaShape_MinorAxisLength
# 614   1.985910e-04   Median_Nucleus_Texture_SumAverage_Eosin_7_02_256
# 615   1.984287e-04  Mean_ExpandCells_Neighbors_SecondClosestObject...
# 616   1.983365e-04   Median_Nucleus_Texture_SumAverage_Eosin_5_00_256
# 617   1.982284e-04      Mean_ExpandCells_AreaShape_EquivalentDiameter
# 618   1.980742e-04     Mean_Nucleus_Texture_SumAverage_Eosin_7_00_256
# 619   1.978095e-04  Median_Nucleus_Texture_SumVariance_Hematoxylin...
# 620   1.967158e-04                                        Count_Cells
# 621   1.966326e-04  Median_ExpandCells_Texture_Correlation_Hematox...
# 622   1.965161e-04  Median_ExpandCells_Neighbors_SecondClosestDist...
# 623   1.964308e-04  StDev_ExpandCells_Texture_Correlation_Hematoxy...
# 624   1.963323e-04  StDev_ExpandCells_Texture_Correlation_Hematoxy...
# 625   1.959984e-04  Mean_Nucleus_Texture_AngularSecondMoment_Hemat...
# 626   1.952382e-04  StDev_ExpandCells_Texture_Correlation_Hematoxy...
# 627   1.944669e-04  Median_Nucleus_Texture_SumAverage_Hematoxylin_...
# 628   1.943734e-04      StDev_ExpandCells_AreaShape_CentralMoment_2_1
# 629   1.941599e-04       Mean_Nucleus_Texture_Contrast_Eosin_3_01_256
# 630   1.937785e-04            Texture_SumAverage_Hematoxylin_3_02_256
# 631   1.934318e-04  Mean_Nucleus_Texture_DifferenceVariance_Eosin_...
# 632   1.932461e-04  Median_Nucleus_Texture_SumVariance_Eosin_7_02_256
# 633   1.930404e-04  Mean_Nucleus_Texture_InverseDifferenceMoment_H...
# 634   1.928966e-04     Mean_Nucleus_Texture_SumAverage_Eosin_3_00_256
# 635   1.928804e-04                Median_Nucleus_AreaShape_HuMoment_2
# 636   1.928281e-04  Median_Nucleus_Texture_SumAverage_Hematoxylin_...
# 637   1.922395e-04  Median_ExpandCells_Texture_AngularSecondMoment...
# 638   1.916615e-04  Median_Nucleus_Texture_SumAverage_Hematoxylin_...
# 639   1.915973e-04  Mean_Nucleus_Texture_DifferenceVariance_Hemato...
# 640   1.915573e-04     Mean_Nucleus_Texture_SumAverage_Eosin_5_02_256
# 641   1.914006e-04  Median_ExpandCells_Texture_AngularSecondMoment...
# 642   1.911357e-04    Mean_ExpandCells_Texture_Entropy_Eosin_3_03_256
# 643   1.907758e-04  Mean_ExpandCells_Neighbors_FirstClosestDistanc...
# 644   1.901979e-04  Median_Nucleus_Texture_Entropy_Hematoxylin_4_0...
# 645   1.901607e-04      StDev_ExpandCells_AreaShape_SpatialMoment_1_0
# 646   1.900973e-04  Median_ExpandCells_Texture_SumAverage_Hematoxy...
# 647   1.898537e-04  Median_ExpandCells_Texture_SumAverage_Hematoxy...
# 648   1.895957e-04   Mean_ExpandCells_Texture_Contrast_Eosin_4_00_256
# 649   1.892055e-04  Median_Nucleus_Texture_DifferenceVariance_Eosi...
# 650   1.890601e-04         Mean_ExpandCells_AreaShape_MinorAxisLength
# 651   1.889161e-04     Mean_Nucleus_Texture_SumAverage_Eosin_5_01_256
# 652   1.888919e-04  Mean_Nucleus_Texture_DifferenceVariance_Eosin_...
# 653   1.887497e-04  Median_Nucleus_Texture_SumVariance_Hematoxylin...
# 654   1.886945e-04                    Mean_ExpandCells_AreaShape_Area
# 655   1.879936e-04  Median_Nucleus_Intensity_MeanIntensity_Hematox...
# 656   1.861309e-04  Mean_Nucleus_Texture_DifferenceVariance_Eosin_...
# 657   1.859882e-04  Median_ExpandCells_Texture_Contrast_Eosin_3_02...
# 658   1.859380e-04  Mean_Nucleus_Intensity_UpperQuartileIntensity_...
# 659   1.857539e-04  Median_Nucleus_RadialDistribution_ZernikeMagni...
# 660   1.849059e-04     Mean_Nucleus_Texture_SumEntropy_Eosin_5_02_256
# 661   1.848292e-04  Median_ExpandCells_Texture_AngularSecondMoment...
# 662   1.847937e-04     Mean_Nucleus_Texture_SumAverage_Eosin_3_02_256
# 663   1.847074e-04  Median_Nucleus_Texture_Contrast_Hematoxylin_4_...
# 664   1.846546e-04  StDev_Nucleus_Texture_InfoMeas2_Hematoxylin_4_...
# 665   1.845881e-04  Median_Nucleus_Texture_DifferenceVariance_Eosi...
# 666   1.841578e-04  Mean_Nucleus_Texture_DifferenceEntropy_Hematox...
# 667   1.839821e-04                Mean_ExpandCells_AreaShape_Solidity
# 668   1.839026e-04  StDev_ExpandCells_Neighbors_SecondClosestObjec...
# 669   1.838838e-04  StDev_ExpandCells_Texture_Correlation_Hematoxy...
# 670   1.835478e-04       StDev_Nucleus_Texture_Entropy_Eosin_4_00_256
# 671   1.821538e-04     Mean_Nucleus_Texture_SumEntropy_Eosin_3_03_256
# 672   1.821082e-04    Median_ExpandCells_Intensity_MinIntensity_Eosin
# 673   1.818829e-04      Mean_ExpandCells_Intensity_MinIntensity_Eosin
# 674   1.818826e-04    Mean_ExpandCells_Texture_Entropy_Eosin_7_00_256
# 675   1.815183e-04              Median_ExpandCells_AreaShape_Solidity
# 676   1.814475e-04  Mean_Nucleus_Texture_AngularSecondMoment_Hemat...
# 677   1.811463e-04                         StDev_Cells_Parent_Nucleus
# 678   1.810667e-04  StDev_Nucleus_Intensity_MedianIntensity_Hemato...
# 679   1.810118e-04  StDev_Nucleus_Texture_DifferenceVariance_Eosin...
# 680   1.803527e-04     Mean_Nucleus_Texture_SumAverage_Eosin_3_03_256
# 681   1.800878e-04       Mean_Nucleus_Texture_Variance_Eosin_7_02_256
# 682   1.799340e-04            Texture_SumAverage_Hematoxylin_3_01_256
# 683   1.795859e-04          StDev_ExpandCells_AreaShape_MaximumRadius
# ...
# 5064  4.762612e-06                Mean_MergeRBC_AreaShape_Zernike_3_1
# 5065  4.741517e-06                                    Count_ShrinkRBC
# 5066  4.656078e-06      StDev_MergeRBC_AreaShape_NormalizedMoment_3_0
# 5067  4.636819e-06               StDev_MergeRBC_AreaShape_Zernike_6_6
# 5068  4.574420e-06               StDev_MergeRBC_AreaShape_Zernike_7_7
# 5069  4.553190e-06         StDev_MergeRBC_AreaShape_SpatialMoment_2_3
# 5070  4.548598e-06        Median_MergeRBC_AreaShape_SpatialMoment_0_0
# 5071  4.539616e-06        Median_MergeRBC_AreaShape_CentralMoment_2_1
# 5072  4.479273e-06        Median_MergeRBC_AreaShape_InertiaTensor_1_1
# 5073  4.479088e-06      StDev_MergeRBC_AreaShape_NormalizedMoment_3_3
# 5074  4.453787e-06                StDev_MergeRBC_AreaShape_ConvexArea
# 5075  4.412418e-06  Median_MergeRBC_Location_CenterMassIntensity_Y...
# 5076  4.380940e-06  Mean_MergeRBC_AreaShape_InertiaTensorEigenvalu...
# 5077  4.371240e-06          Mean_MergeRBC_AreaShape_SpatialMoment_1_3
# 5078  4.355655e-06         StDev_MergeRBC_AreaShape_CentralMoment_1_2
# 5079  4.343062e-06                Mean_MergeRBC_AreaShape_Zernike_8_4
# 5080  4.341126e-06                    Mean_MergeRBC_Location_Center_X
# 5081  4.334424e-06        StDev_MergeRBC_AreaShape_EquivalentDiameter
# 5082  4.320105e-06         StDev_MergeRBC_AreaShape_SpatialMoment_0_1
# 5083  4.300826e-06                StDev_MergeRBC_Granularity_11_Eosin
# 5084  4.258979e-06        Median_MergeRBC_AreaShape_CentralMoment_2_2
# 5085  4.223219e-06    StDev_MergeRBC_Intensity_StdIntensityEdge_Eosin
# 5086  4.185077e-06                                     Count_MergeRBC
# 5087  4.155676e-06       Mean_MergeRBC_AreaShape_NormalizedMoment_2_1
# 5088  4.152877e-06               StDev_MergeRBC_AreaShape_Zernike_4_0
# 5089  4.139588e-06  Median_ExpandCells_RadialDistribution_ZernikeP...
# 5090  4.122866e-06                  Mean_MergeRBC_AreaShape_Perimeter
# 5091  4.088511e-06               StDev_MergeRBC_AreaShape_Zernike_6_4
# 5092  4.038324e-06          StDev_MergeRBC_AreaShape_MaxFeretDiameter
# 5093  4.012492e-06                 StDev_Tissue_AreaShape_EulerNumber
# 5094  3.990019e-06               StDev_MergeRBC_AreaShape_Zernike_2_2
# 5095  3.958163e-06     Mean_MergeRBC_Intensity_MassDisplacement_Eosin
# 5096  3.910216e-06          Mean_MergeRBC_AreaShape_InertiaTensor_0_0
# 5097  3.893033e-06    StDev_MergeRBC_Intensity_MaxIntensityEdge_Eosin
# 5098  3.826814e-06              Median_MergeRBC_AreaShape_Zernike_6_0
# 5099  3.762816e-06          Mean_MergeRBC_AreaShape_SpatialMoment_0_3
# 5100  3.670399e-06                StDev_MergeRBC_Granularity_13_Eosin
# 5101  3.641450e-06                     Mean_MergeRBC_AreaShape_Extent
# 5102  3.614743e-06              Median_MergeRBC_AreaShape_Orientation
# 5103  3.601404e-06  StDev_MergeRBC_AreaShape_InertiaTensorEigenval...
# 5104  3.442077e-06        Median_MergeRBC_AreaShape_CentralMoment_0_0
# 5105  3.379287e-06              Median_MergeRBC_AreaShape_Zernike_6_2
# 5106  3.285281e-06      StDev_MergeRBC_AreaShape_NormalizedMoment_2_2
# 5107  3.283077e-06        Median_MergeRBC_AreaShape_SpatialMoment_2_1
# 5108  3.189260e-06  Median_Nucleus_RadialDistribution_ZernikePhase...
# 5109  3.185108e-06               Median_MergeRBC_AreaShape_HuMoment_6
# 5110  3.174609e-06          Mean_MergeRBC_AreaShape_SpatialMoment_1_0
# 5111  3.156080e-06                 Mean_MergeRBC_AreaShape_HuMoment_2
# 5112  3.138279e-06              Mean_MergeRBC_AreaShape_MaximumRadius
# 5113  3.121358e-06           Mean_MergeRBC_AreaShape_MaxFeretDiameter
# 5114  3.116609e-06               StDev_MergeRBC_AreaShape_Zernike_2_0
# 5115  2.993021e-06          Median_MergeRBC_AreaShape_MinorAxisLength
# 5116  2.988151e-06  Mean_MergeRBC_AreaShape_InertiaTensorEigenvalu...
# 5117  2.917560e-06                Median_MergeRBC_Granularity_6_Eosin
# 5118  2.902891e-06   StDev_MergeRBC_Intensity_MeanIntensityEdge_Eosin
# 5119  2.854379e-06     Median_MergeRBC_AreaShape_BoundingBoxMaximum_Y
# 5120  2.845095e-06  Median_ExpandCells_RadialDistribution_ZernikeP...
# 5121  2.804127e-06         StDev_MergeRBC_AreaShape_CentralMoment_2_0
# 5122  2.722144e-06             StDev_MergeRBC_AreaShape_MaximumRadius
# 5123  2.718596e-06             Mean_ShrinkRBC_Children_MergeRBC_Count
# 5124  2.683298e-06               StDev_MergeRBC_AreaShape_Zernike_6_2
# 5125  2.666047e-06        Median_MergeRBC_AreaShape_SpatialMoment_0_3
# 5126  2.652608e-06                 StDev_MergeRBC_Granularity_9_Eosin
# 5127  2.644563e-06                StDev_MergeRBC_AreaShape_HuMoment_6
# 5128  2.643751e-06  Median_ExpandCells_RadialDistribution_ZernikeP...
# 5129  2.554515e-06                Median_Nucleus_AreaShape_HuMoment_4
# 5130  2.504703e-06                 StDev_MergeRBC_Granularity_6_Eosin
# 5131  2.458707e-06  Median_MergeRBC_Intensity_IntegratedIntensityE...
# 5132  2.310093e-06                StDev_MergeRBC_AreaShape_HuMoment_2
# 5133  2.201663e-06          Mean_MergeRBC_AreaShape_InertiaTensor_1_1
# 5134  2.194534e-06    StDev_MergeRBC_Intensity_MassDisplacement_Eosin
# 5135  2.189461e-06                Mean_MergeRBC_AreaShape_Zernike_6_2
# 5136  2.146674e-06                     Mean_MergeRBC_Parent_ShrinkRBC
# 5137  2.141867e-06                 Mean_Nucleus_AreaShape_EulerNumber
# 5138  2.089301e-06        Mean_MergeRBC_Location_MaxIntensity_X_Eosin
# 5139  2.051551e-06                StDev_MergeRBC_AreaShape_HuMoment_4
# 5140  2.044742e-06               StDev_MergeRBC_AreaShape_Zernike_5_1
# 5141  2.010816e-06                 Mean_MergeRBC_AreaShape_HuMoment_0
# 5142  2.009176e-06                    StDev_MergeRBC_AreaShape_Extent
# 5143  1.899674e-06                StDev_MergeRBC_AreaShape_MeanRadius
# 5144  1.445018e-06          Median_MergeRBC_AreaShape_MajorAxisLength
# 5145  1.409379e-06           StDev_MergeRBC_AreaShape_MajorAxisLength
# 5146  1.384889e-06         StDev_MergeRBC_AreaShape_CentralMoment_1_3
# 5147  1.378777e-06        Median_MergeRBC_AreaShape_SpatialMoment_0_2
# 5148  1.364986e-06                StDev_MergeRBC_Granularity_14_Eosin
# 5149  1.215873e-06                 Mean_MergeRBC_Granularity_11_Eosin
# 5150  1.215022e-06  StDev_MergeRBC_AreaShape_InertiaTensorEigenval...
# 5151  9.124866e-07         StDev_MergeRBC_AreaShape_SpatialMoment_2_1
# 5152  7.419256e-07      StDev_MergeRBC_AreaShape_NormalizedMoment_1_2
# 5153  7.186957e-07                Median_Nucleus_AreaShape_HuMoment_6
# 5154  7.117263e-07              Median_MergeRBC_AreaShape_EulerNumber
# 5155  7.040850e-07           StDev_MergeRBC_AreaShape_MinorAxisLength
# 5156  6.684050e-07         StDev_MergeRBC_AreaShape_SpatialMoment_1_1
# 5157  6.601105e-07  Median_ExpandCells_RadialDistribution_ZernikeP...
# 5158  6.520479e-07               StDev_MergeRBC_AreaShape_Zernike_6_0
# 5159  4.896984e-07               Mean_MergeRBC_AreaShape_Eccentricity
# 5160  0.000000e+00                       Mean_Cells_Location_Center_Z
# 5161  0.000000e+00       Mean_ExpandCells_AreaShape_CentralMoment_0_1
# 5162  0.000000e+00       Mean_ExpandCells_AreaShape_CentralMoment_1_0
# 5163  0.000000e+00    Mean_ExpandCells_AreaShape_NormalizedMoment_0_0
# 5164  0.000000e+00    Mean_ExpandCells_AreaShape_NormalizedMoment_0_1
# 5165  0.000000e+00  Mean_ExpandCells_Location_CenterMassIntensity_...
# 5166  0.000000e+00     Mean_ExpandCells_Location_MaxIntensity_Z_Eosin
# 5167  0.000000e+00          Mean_MergeRBC_AreaShape_CentralMoment_0_1
# 5168  0.000000e+00          Mean_MergeRBC_AreaShape_CentralMoment_1_0
# 5169  0.000000e+00       Mean_MergeRBC_AreaShape_NormalizedMoment_0_0
# 5170  0.000000e+00       Mean_MergeRBC_AreaShape_NormalizedMoment_0_1
# 5171  0.000000e+00       Mean_MergeRBC_AreaShape_NormalizedMoment_1_0
# 5172  0.000000e+00  Mean_MergeRBC_Location_CenterMassIntensity_Z_E...
# 5173  0.000000e+00        Mean_MergeRBC_Location_MaxIntensity_Z_Eosin
# 5174  0.000000e+00           Mean_Nucleus_AreaShape_CentralMoment_0_1
# 5175  0.000000e+00           Mean_Nucleus_AreaShape_CentralMoment_1_0
# 5176  0.000000e+00        Mean_Nucleus_AreaShape_NormalizedMoment_0_0
# 5177  0.000000e+00        Mean_Nucleus_AreaShape_NormalizedMoment_0_1
# 5178  0.000000e+00        Mean_Nucleus_AreaShape_NormalizedMoment_1_0
# 5179  0.000000e+00                  Mean_Nucleus_Children_Cells_Count
# 5180  0.000000e+00  Mean_Nucleus_Location_CenterMassIntensity_Z_He...
# 5181  0.000000e+00                     Mean_Nucleus_Location_Center_Z
# 5182  0.000000e+00   Mean_Nucleus_Location_MaxIntensity_Z_Hematoxylin
# 5183  0.000000e+00  Mean_Nucleus_RadialDistribution_ZernikePhase_H...
# 5184  0.000000e+00                         Mean_RBC_Location_Center_Z
# 5185  0.000000e+00            Mean_Tissue_AreaShape_CentralMoment_0_1
# 5186  0.000000e+00            Mean_Tissue_AreaShape_CentralMoment_1_0
# 5187  0.000000e+00         Mean_Tissue_AreaShape_NormalizedMoment_0_0
# 5188  0.000000e+00         Mean_Tissue_AreaShape_NormalizedMoment_0_1
# 5189  0.000000e+00         Mean_Tissue_AreaShape_NormalizedMoment_1_0
# 5190  0.000000e+00   Mean_Tissue_Location_CenterMassIntensity_Z_Eosin
# 5191  0.000000e+00                      Mean_Tissue_Location_Center_Z
# 5192  0.000000e+00          Mean_Tissue_Location_MaxIntensity_Z_Eosin
# 5193  0.000000e+00                     Median_Cells_Location_Center_Z
# 5194  0.000000e+00     Median_ExpandCells_AreaShape_CentralMoment_0_1
# 5195  0.000000e+00     Median_ExpandCells_AreaShape_CentralMoment_1_0
# 5196  0.000000e+00           Median_ExpandCells_AreaShape_EulerNumber
# 5197  0.000000e+00  Median_ExpandCells_AreaShape_NormalizedMoment_0_0
# 5198  0.000000e+00  Median_ExpandCells_AreaShape_NormalizedMoment_0_1
# 5199  0.000000e+00  Median_ExpandCells_AreaShape_NormalizedMoment_1_0
# 5200  0.000000e+00  Median_ExpandCells_Location_CenterMassIntensit...
# 5201  0.000000e+00   Median_ExpandCells_Location_MaxIntensity_Z_Eosin
# 5202  0.000000e+00  Median_ExpandCells_RadialDistribution_ZernikeP...
# 5203  0.000000e+00        Median_MergeRBC_AreaShape_CentralMoment_0_1
# 5204  0.000000e+00        Median_MergeRBC_AreaShape_CentralMoment_1_0
# 5205  0.000000e+00     Median_MergeRBC_AreaShape_NormalizedMoment_0_0
# 5206  0.000000e+00     Median_MergeRBC_AreaShape_NormalizedMoment_0_1
# 5207  0.000000e+00     Median_MergeRBC_AreaShape_NormalizedMoment_1_0
# 5208  0.000000e+00              Median_MergeRBC_AreaShape_Zernike_7_1
# 5209  0.000000e+00  Median_MergeRBC_Location_CenterMassIntensity_Z...
# 5210  0.000000e+00      Median_MergeRBC_Location_MaxIntensity_Z_Eosin
# 5211  0.000000e+00         Median_Nucleus_AreaShape_CentralMoment_0_1
# 5212  0.000000e+00         Median_Nucleus_AreaShape_CentralMoment_1_0
# 5213  0.000000e+00               Median_Nucleus_AreaShape_EulerNumber
# 5214  0.000000e+00      Median_Nucleus_AreaShape_NormalizedMoment_0_0
# 5215  0.000000e+00      Median_Nucleus_AreaShape_NormalizedMoment_1_0
# 5216  0.000000e+00                Median_Nucleus_Children_Cells_Count
# 5217  0.000000e+00  Median_Nucleus_Location_CenterMassIntensity_Z_...
# 5218  0.000000e+00                   Median_Nucleus_Location_Center_Z
# 5219  0.000000e+00  Median_Nucleus_Location_MaxIntensity_Z_Hematox...
# 5220  0.000000e+00  Median_Nucleus_RadialDistribution_ZernikePhase...
# 5221  0.000000e+00  Median_Nucleus_RadialDistribution_ZernikePhase...
# 5222  0.000000e+00                       Median_RBC_Location_Center_Z
# 5223  0.000000e+00          Median_Tissue_AreaShape_CentralMoment_0_1
# 5224  0.000000e+00          Median_Tissue_AreaShape_CentralMoment_1_0
# 5225  0.000000e+00       Median_Tissue_AreaShape_NormalizedMoment_0_0
# 5226  0.000000e+00       Median_Tissue_AreaShape_NormalizedMoment_0_1
# 5227  0.000000e+00       Median_Tissue_AreaShape_NormalizedMoment_1_0
# 5228  0.000000e+00  Median_Tissue_Location_CenterMassIntensity_Z_E...
# 5229  0.000000e+00                    Median_Tissue_Location_Center_Z
# 5230  0.000000e+00        Median_Tissue_Location_MaxIntensity_Z_Eosin
# 5231  0.000000e+00                                     Metadata_Frame
# 5232  0.000000e+00                                    Metadata_Series
# 5233  0.000000e+00                               ModuleError_01Images
# 5234  0.000000e+00                             ModuleError_02Metadata
# 5235  0.000000e+00                        ModuleError_03NamesAndTypes
# 5236  0.000000e+00                               ModuleError_04Groups
# 5237  0.000000e+00                          ModuleError_05UnmixColors
# 5238  0.000000e+00                               ModuleError_06Smooth
# 5239  0.000000e+00                               ModuleError_07Smooth
# 5240  0.000000e+00               ModuleError_08IdentifyPrimaryObjects
# 5241  0.000000e+00               ModuleError_09IdentifyPrimaryObjects
# 5242  0.000000e+00                ModuleError_10ExpandOrShrinkObjects
# 5243  0.000000e+00                  ModuleError_11SplitOrMergeObjects
# 5244  0.000000e+00                            ModuleError_12MaskImage
# 5245  0.000000e+00               ModuleError_13IdentifyPrimaryObjects
# 5246  0.000000e+00             ModuleError_14IdentifySecondaryObjects
# 5247  0.000000e+00                ModuleError_15ExpandOrShrinkObjects
# 5248  0.000000e+00               ModuleError_16MeasureObjectSizeShape
# 5249  0.000000e+00             ModuleError_17MeasureImageAreaOccupied
# 5250  0.000000e+00                   ModuleError_18MeasureGranularity
# 5251  0.000000e+00                   ModuleError_19MeasureGranularity
# 5252  0.000000e+00               ModuleError_20MeasureObjectIntensity
# 5253  0.000000e+00               ModuleError_21MeasureObjectIntensity
# 5254  0.000000e+00   ModuleError_22MeasureObjectIntensityDistribution
# 5255  0.000000e+00   ModuleError_23MeasureObjectIntensityDistribution
# 5256  0.000000e+00               ModuleError_24MeasureObjectNeighbors
# 5257  0.000000e+00               ModuleError_25MeasureObjectNeighbors
# 5258  0.000000e+00                       ModuleError_26MeasureTexture
# 5259  0.000000e+00                      StDev_Cells_Location_Center_Z
# 5260  0.000000e+00      StDev_ExpandCells_AreaShape_CentralMoment_0_1
# 5261  0.000000e+00      StDev_ExpandCells_AreaShape_CentralMoment_1_0
# 5262  0.000000e+00   StDev_ExpandCells_AreaShape_NormalizedMoment_0_0
# 5263  0.000000e+00   StDev_ExpandCells_AreaShape_NormalizedMoment_0_1
# 5264  0.000000e+00   StDev_ExpandCells_AreaShape_NormalizedMoment_1_0
# 5265  0.000000e+00  StDev_ExpandCells_RadialDistribution_ZernikePh...
# 5266  0.000000e+00         StDev_MergeRBC_AreaShape_CentralMoment_0_1
# 5267  0.000000e+00         StDev_MergeRBC_AreaShape_CentralMoment_1_0
# 5268  0.000000e+00      StDev_MergeRBC_AreaShape_NormalizedMoment_0_0
# 5269  0.000000e+00      StDev_MergeRBC_AreaShape_NormalizedMoment_0_1
# 5270  0.000000e+00  StDev_MergeRBC_Location_CenterMassIntensity_Z_...
# 5271  0.000000e+00       StDev_MergeRBC_Location_MaxIntensity_Z_Eosin
# 5272  0.000000e+00          StDev_Nucleus_AreaShape_CentralMoment_0_1
# 5273  0.000000e+00          StDev_Nucleus_AreaShape_CentralMoment_1_0
# 5274  0.000000e+00       StDev_Nucleus_AreaShape_NormalizedMoment_0_0
# 5275  0.000000e+00       StDev_Nucleus_AreaShape_NormalizedMoment_0_1
# 5276  0.000000e+00       StDev_Nucleus_AreaShape_NormalizedMoment_1_0
# 5277  0.000000e+00                 StDev_Nucleus_Children_Cells_Count
# 5278  0.000000e+00  StDev_Nucleus_Location_CenterMassIntensity_Z_H...
# 5279  0.000000e+00  StDev_Nucleus_Location_MaxIntensity_Z_Hematoxylin
# 5280  0.000000e+00  StDev_Nucleus_RadialDistribution_ZernikePhase_...
# 5281  0.000000e+00                        StDev_RBC_Location_Center_Z
# 5282  0.000000e+00           StDev_Tissue_AreaShape_CentralMoment_0_1
# 5283  0.000000e+00        StDev_Tissue_AreaShape_NormalizedMoment_0_0
# 5284  0.000000e+00        StDev_Tissue_AreaShape_NormalizedMoment_0_1
# 5285  0.000000e+00        StDev_Tissue_AreaShape_NormalizedMoment_1_0
# 5286  0.000000e+00  StDev_Tissue_Location_CenterMassIntensity_Z_Eosin
# 5287  0.000000e+00                     StDev_Tissue_Location_Center_Z
# 5288  0.000000e+00         StDev_Tissue_Location_MaxIntensity_Z_Eosin
# 5289  0.000000e+00                       Threshold_FinalThreshold_RBC
# 5290  0.000000e+00                    Threshold_FinalThreshold_Tissue
# 5291  0.000000e+00                     Threshold_OrigThreshold_Tissue
