# %% [markdown]
# # Color Analysis - Nucleus rollup
# Rollup the nucleus statistics per patch. Class 5.

# %% [markdown]
# ## Overall Plan
# * Run CellProfiler on 80K patches. Make CSV files.
# * Record bounding box of every nucleus of every patch.
# * Run CNN on 80K patches.
# * For each class c, label correctly classified patches c_Cor.
# * For each class c, label in correctly classified patches c_Inc.
# * Run CNN attention on 80K patches. Make heatmaps.
# * Compute average heatmap color per nucleus bounding box.
# * Set aside test set: 20% of images (and all their patch data) per class.
# * Possibly set aside patches with too little tissue, too many RBC, or too few nuclei.
# * Remove useless columns such as XY locations.
# * Add dispersion columns such as deciles.
# * Train a Cor/Inc binary classifier for each class.
# * Evaluate the model by cross-validation over training data.
# * If the model is accurate, extract important features.

# %%
import datetime
print(datetime.datetime.now())
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import sklearn
print('scikit-learn version',sklearn.__version__)
# Out:
# 2022-06-02 15:56:16.322842
# scikit-learn version 1.0.2

# %%
THIS_CLASS=5   
NUM_CLASSES=6
FILEPATHS=['path']*NUM_CLASSES
FILEPATHS[4]='/home/jrm/Adjeroh/Naved/CP_80K/Output4/' #'/Users/jasonmiller/WVU/Output4/'
FILEPATHS[5]='/home/jrm/Adjeroh/Naved/CP_80K/Output5/' #'/Users/jasonmiller/WVU/Output5/'

# %%
from CellProfiler_Util import CP_Util
cputil = CP_Util(FILEPATHS[THIS_CLASS])
cputil.train_test_split() 
cputil.validate_split()
train_set=cputil.get_train_patches()
nuc = cputil.get_nuclei()

# %%
print(datetime.datetime.now())
rollup = nuc.groupby(['PatchNumber']).describe() ## this is slow
print(datetime.datetime.now())
rollup.columns=rollup.columns.map('_'.join)  ## helps random forest code
print(datetime.datetime.now())
rollup
# Out:
# 2022-06-02 15:56:21.380345
# 2022-06-02 16:04:45.893891
# 2022-06-02 16:04:45.898147
#              ObjectNumber_count  ObjectNumber_mean  ObjectNumber_std  \
# PatchNumber
# 1                          16.0                8.5          4.760952
# 2                          10.0                5.5          3.027650
# 3                          29.0               15.0          8.514693
# 4                          34.0               17.5          9.958246
# 5                          27.0               14.0          7.937254
# ...                         ...                ...               ...
# 1587                        7.0                4.0          2.160247
# 1588                       17.0                9.0          5.049752
# 1589                       19.0               10.0          5.627314
# 1590                       33.0               17.0          9.669540
# 1591                        4.0                2.5          1.290994
#
#              ObjectNumber_min  ObjectNumber_25%  ObjectNumber_50%  \
# PatchNumber
# 1                         1.0              4.75               8.5
# 2                         1.0              3.25               5.5
# 3                         1.0              8.00              15.0
# 4                         1.0              9.25              17.5
# 5                         1.0              7.50              14.0
# ...                       ...               ...               ...
# 1587                      1.0              2.50               4.0
# 1588                      1.0              5.00               9.0
# 1589                      1.0              5.50              10.0
# 1590                      1.0              9.00              17.0
# 1591                      1.0              1.75               2.5
#
#              ObjectNumber_75%  ObjectNumber_max  AreaShape_Area_count  \
# PatchNumber
# 1                       12.25              16.0                  16.0
# 2                        7.75              10.0                  10.0
# 3                       22.00              29.0                  29.0
# 4                       25.75              34.0                  34.0
# 5                       20.50              27.0                  27.0
# ...                       ...               ...                   ...
# 1587                     5.50               7.0                   7.0
# 1588                    13.00              17.0                  17.0
# 1589                    14.50              19.0                  19.0
# 1590                    25.00              33.0                  33.0
# 1591                     3.25               4.0                   4.0
#
#              AreaShape_Area_mean  ...  \
# PatchNumber                       ...
# 1                     613.375000  ...
# 2                     584.700000  ...
# 3                     651.931034  ...
# 4                     500.735294  ...
# 5                     558.814815  ...
# ...                          ...  ...
# 1587                  368.285714  ...
# 1588                  519.352941  ...
# 1589                  388.315789  ...
# 1590                  444.454545  ...
# 1591                  514.500000  ...
#
#              Texture_Variance_Hematoxylin_7_02_256_75%  \
# PatchNumber
# 1                                           515.499745
# 2                                           514.366296
# 3                                          1367.814844
# 4                                          1013.044074
# 5                                          1167.610251
# ...                                                ...
# 1587                                       2645.755171
# 1588                                       2697.422264
# 1589                                       2196.200883
# 1590                                       1931.452617
# 1591                                       1668.924588
#
#              Texture_Variance_Hematoxylin_7_02_256_max  \
# PatchNumber
# 1                                           806.931279
# 2                                          1228.802695
# 3                                          2246.295589
# 4                                          1326.400294
# 5                                          1776.780209
# ...                                                ...
# 1587                                       5002.663831
# 1588                                       3144.417339
# 1589                                       2971.276407
# 1590                                       2672.847178
# 1591                                       1945.555556
#
#              Texture_Variance_Hematoxylin_7_03_256_count  \
# PatchNumber
# 1                                                   16.0
# 2                                                   10.0
# 3                                                   29.0
# 4                                                   34.0
# 5                                                   27.0
# ...                                                  ...
# 1587                                                 7.0
# 1588                                                17.0
# 1589                                                19.0
# 1590                                                33.0
# 1591                                                 4.0
#
#              Texture_Variance_Hematoxylin_7_03_256_mean  \
# PatchNumber
# 1                                            408.618560
# 2                                            483.101182
# 3                                           1170.234328
# 4                                            796.924000
# 5                                            872.023588
# ...                                                 ...
# 1587                                        2072.810441
# 1588                                        2120.125661
# 1589                                        1731.620347
# 1590                                        1330.902406
# 1591                                        1208.209780
#
#              Texture_Variance_Hematoxylin_7_03_256_std  \
# PatchNumber
# 1                                           214.781603
# 2                                           350.161055
# 3                                           419.840252
# 4                                           305.644800
# 5                                           465.019642
# ...                                                ...
# 1587                                       1442.119639
# 1588                                        784.452285
# 1589                                        639.473204
# 1590                                        667.821030
# 1591                                        285.284892
#
#              Texture_Variance_Hematoxylin_7_03_256_min  \
# PatchNumber
# 1                                           154.695633
# 2                                            67.633510
# 3                                           319.085600
# 4                                           323.922906
# 5                                           146.843737
# ...                                                ...
# 1587                                        682.306939
# 1588                                        435.222222
# 1589                                        677.151060
# 1590                                        479.463374
# 1591                                        781.383551
#
#              Texture_Variance_Hematoxylin_7_03_256_25%  \
# PatchNumber
# 1                                           258.212905
# 2                                           269.218502
# 3                                           851.541558
# 4                                           556.227842
# 5                                           573.465876
# ...                                                ...
# 1587                                        946.916962
# 1588                                       1636.718754
# 1589                                       1348.982274
# 1590                                        800.137069
# 1591                                       1190.544387
#
#              Texture_Variance_Hematoxylin_7_03_256_50%  \
# PatchNumber
# 1                                           402.843399
# 2                                           376.585665
# 3                                          1151.797133
# 4                                           739.282772
# 5                                           781.263463
# ...                                                ...
# 1587                                       2007.931412
# 1588                                       2149.951462
# 1589                                       1626.336416
# 1590                                       1102.353972
# 1591                                       1337.327564
#
#              Texture_Variance_Hematoxylin_7_03_256_75%  \
# PatchNumber
# 1                                           513.465007
# 2                                           664.029826
# 3                                          1449.717124
# 4                                          1108.957455
# 5                                          1084.113804
# ...                                                ...
# 1587                                       2641.212717
# 1588                                       2783.133279
# 1589                                       2185.555700
# 1590                                       1578.432099
# 1591                                       1354.992958
#
#              Texture_Variance_Hematoxylin_7_03_256_max
# PatchNumber
# 1                                           947.381911
# 2                                          1054.690208
# 3                                          2063.316367
# 4                                          1368.495121
# 5                                          2280.150933
# ...                                                ...
# 1587                                       4643.175378
# 1588                                       3362.958125
# 1589                                       2992.328549
# 1590                                       2878.275735
# 1591                                       1376.800442
#
# [1195 rows x 5192 columns]

# %%
# Alien
rollup.to_csv('Nucleus_Rollup_5.csv')
