# %% [markdown]
# # Random Forest
# Train on 6-class cancer classification.
# Input is the nucleus+RBC rollup, training set only.
# Run 5-fold cross validation.
# Print the mean accuracy.

# %%
import datetime
print(datetime.datetime.now())
from platform import python_version
print('Python',python_version())
import numpy as np
import pandas as pd
import sklearn   # pip install --upgrade scikit-learn
print('sklearn',sklearn.__version__)
#import tensorflow as tf
#tf.config.list_physical_devices('GPU')
# Out:
# 2022-06-13 09:36:30.705615
# Python 3.9.6
# sklearn 1.1.1

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.utils import shuffle
from sklearn.feature_selection import RFE
import joblib # used to dump/load sklearn models
from CellProfiler_Util import CP_Util
from RandomForestUtil import RF_Util

# %%
BASE_DIR='/home/jrm/Adjeroh/Naved/CP_80K/'  # Alien
BASE_DIR='D:\\Adjeroh\\Naved\\CP_80K\\'  # Windows
CLASSES=range(0,6)  # use all 6 classes
#CLASSES=[5]  # JUST FOR TESTING
MODELS_DIR='/home/jrm/Adjeroh/Naved/CP_80K/models/RandomForest.32'  # Alien
MODELS_DIR='D:\\Adjeroh\\Naved\\CP_80K\\models\\RandomForest.32'  # Windows

# %%
# These patches were used to tune the CellProfiler pipeline
EXCLUDE = [ [311], [12], [30,41], [87], [67], [26,46] ]

# %%
print(datetime.datetime.now())
PREFIX='abc_'
def set_prefix(prefix):
    global PREFIX
    PREFIX=prefix
def get_prefix(col_name):
    global PREFIX
    return PREFIX+col_name  # hard coded for now
def load_all_classes():
    X = None
    y = None
    for i in CLASSES:
        print(datetime.datetime.now())
        print("Process class",i)
        exclude = list(EXCLUDE[i])
        print('Exclude',exclude)
        FULL_PATH=BASE_DIR+'Output'+str(i)+'/'
        cp = CP_Util(FULL_PATH)
        cp.train_test_split()
        Xnuc = cp.get_nucleus_rollup()
        Xnuc = Xnuc.drop( Xnuc.index[exclude] )
        set_prefix('Nuc_')
        Xnuc.rename(get_prefix,axis='columns',inplace=True)
        Xrbc = cp.get_RBC_rollup()
        Xrbc = Xrbc.drop( Xrbc.index[exclude] )
        set_prefix('Rbc_')
        Xrbc.rename(get_prefix,axis='columns',inplace=True)
        Xi = Xnuc.join(Xrbc,how='outer')
        size = len(Xi)
        yi = np.ones(size) * i   # e.g. class 3
        if X is None:
            X = Xi
            y = yi
        else:
            X = pd.concat( (X,Xi) )
            y = np.concatenate( (y,yi) )
    X.fillna(0,inplace=True)  
    return X,y
Xtrain,ytrain=load_all_classes()
Xtrain
# Out:
# 2022-06-13 09:36:31.939673
# 2022-06-13 09:36:31.939673
# Process class 0
# Exclude [311]
# Train: 37 participants, 98 WSI, 37561 patches.
# Test: 9 participants, 19 WSI, 7405 patches.
# 2022-06-13 09:37:36.800801
# Process class 1
# Exclude [12]
# Train: 17 participants, 28 WSI, 10925 patches.
# Test: 4 participants, 5 WSI, 1977 patches.
# 2022-06-13 09:37:56.347538
# Process class 2
# Exclude [30, 41]
# Train: 14 participants, 30 WSI, 11138 patches.
# Test: 3 participants, 7 WSI, 2812 patches.
# 2022-06-13 09:38:17.606755
# Process class 3
# Exclude [87]
# Train: 11 participants, 13 WSI, 5006 patches.
# Test: 3 participants, 4 WSI, 1358 patches.
# 2022-06-13 09:38:27.977731
# Process class 4
# Exclude [67]
# Train: 6 participants, 7 WSI, 2809 patches.
# Test: 1 participants, 1 WSI, 388 patches.
# 2022-06-13 09:38:33.215059
# Process class 5
# Exclude [26, 46]
# Train: 2 participants, 3 WSI, 1195 patches.
# Test: 1 participants, 1 WSI, 396 patches.
#              Nuc_ObjectNumber_count  Nuc_ObjectNumber_mean  \
# PatchNumber
# 1985                           19.0                   10.0
# 1986                           15.0                    8.0
# 1987                            5.0                    3.0
# 1988                            4.0                    2.5
# 1989                           19.0                   10.0
# ...                             ...                    ...
# 1587                            7.0                    4.0
# 1588                           17.0                    9.0
# 1589                           19.0                   10.0
# 1590                           33.0                   17.0
# 1591                            4.0                    2.5
#
#              Nuc_ObjectNumber_std  Nuc_ObjectNumber_min  Nuc_ObjectNumber_25%  \
# PatchNumber
# 1985                     5.627314                   1.0                  5.50
# 1986                     4.472136                   1.0                  4.50
# 1987                     1.581139                   1.0                  2.00
# 1988                     1.290994                   1.0                  1.75
# 1989                     5.627314                   1.0                  5.50
# ...                           ...                   ...                   ...
# 1587                     2.160247                   1.0                  2.50
# 1588                     5.049752                   1.0                  5.00
# 1589                     5.627314                   1.0                  5.50
# 1590                     9.669540                   1.0                  9.00
# 1591                     1.290994                   1.0                  1.75
#
#              Nuc_ObjectNumber_50%  Nuc_ObjectNumber_75%  Nuc_ObjectNumber_max  \
# PatchNumber
# 1985                         10.0                 14.50                  19.0
# 1986                          8.0                 11.50                  15.0
# 1987                          3.0                  4.00                   5.0
# 1988                          2.5                  3.25                   4.0
# 1989                         10.0                 14.50                  19.0
# ...                           ...                   ...                   ...
# 1587                          4.0                  5.50                   7.0
# 1588                          9.0                 13.00                  17.0
# 1589                         10.0                 14.50                  19.0
# 1590                         17.0                 25.00                  33.0
# 1591                          2.5                  3.25                   4.0
#
#              Nuc_AreaShape_Area_count  Nuc_AreaShape_Area_mean  ...  \
# PatchNumber                                                     ...
# 1985                             19.0               268.526316  ...
# 1986                             15.0               239.533333  ...
# 1987                              5.0               223.000000  ...
# 1988                              4.0               242.250000  ...
# 1989                             19.0               250.736842  ...
# ...                               ...                      ...  ...
# 1587                              7.0               368.285714  ...
# 1588                             17.0               519.352941  ...
# 1589                             19.0               388.315789  ...
# 1590                             33.0               444.454545  ...
# 1591                              4.0               514.500000  ...
#
#              Rbc_Number_Object_Number_75%  Rbc_Number_Object_Number_max  \
# PatchNumber
# 1985                                 0.00                           0.0
# 1986                                 0.00                           0.0
# 1987                                 0.00                           0.0
# 1988                                10.00                          13.0
# 1989                                 0.00                           0.0
# ...                                   ...                           ...
# 1587                                 0.00                           0.0
# 1588                                 0.00                           0.0
# 1589                                 1.75                           2.0
# 1590                                 0.00                           0.0
# 1591                                 0.00                           0.0
#
#              Rbc_Parent_ShrinkRBC_count  Rbc_Parent_ShrinkRBC_mean  \
# PatchNumber
# 1985                                0.0                   0.000000
# 1986                                0.0                   0.000000
# 1987                                0.0                   0.000000
# 1988                               13.0                   8.923077
# 1989                                0.0                   0.000000
# ...                                 ...                        ...
# 1587                                0.0                   0.000000
# 1588                                0.0                   0.000000
# 1589                                2.0                   1.500000
# 1590                                0.0                   0.000000
# 1591                                0.0                   0.000000
#
#              Rbc_Parent_ShrinkRBC_std  Rbc_Parent_ShrinkRBC_min  \
# PatchNumber
# 1985                         0.000000                       0.0
# 1986                         0.000000                       0.0
# 1987                         0.000000                       0.0
# 1988                         5.155281                       1.0
# 1989                         0.000000                       0.0
# ...                               ...                       ...
# 1587                         0.000000                       0.0
# 1588                         0.000000                       0.0
# 1589                         0.707107                       1.0
# 1590                         0.000000                       0.0
# 1591                         0.000000                       0.0
#
#              Rbc_Parent_ShrinkRBC_25%  Rbc_Parent_ShrinkRBC_50%  \
# PatchNumber
# 1985                             0.00                       0.0
# 1986                             0.00                       0.0
# 1987                             0.00                       0.0
# 1988                             4.00                      10.0
# 1989                             0.00                       0.0
# ...                               ...                       ...
# 1587                             0.00                       0.0
# 1588                             0.00                       0.0
# 1589                             1.25                       1.5
# 1590                             0.00                       0.0
# 1591                             0.00                       0.0
#
#              Rbc_Parent_ShrinkRBC_75%  Rbc_Parent_ShrinkRBC_max
# PatchNumber
# 1985                             0.00                       0.0
# 1986                             0.00                       0.0
# 1987                             0.00                       0.0
# 1988                            13.00                      16.0
# 1989                             0.00                       0.0
# ...                               ...                       ...
# 1587                             0.00                       0.0
# 1588                             0.00                       0.0
# 1589                             1.75                       2.0
# 1590                             0.00                       0.0
# 1591                             0.00                       0.0
#
# [55029 rows x 6392 columns]

# %%
print(datetime.datetime.now())
print("Shuffle...")
Xtrain,ytrain=shuffle(Xtrain,ytrain)  #set random_state for reproducibility
# Out:
# 2022-06-13 09:38:38.035970
# Shuffle...

# %%
# Note we tried this but always got "has no attribute oob_score_":
# model = RandomForestClassifier(bootstrap=True,oob_score=True)  # out-of-bag score to estimate generalizability
# <train>
# print('oob_score',model.oob_score_)

# %%
print(datetime.datetime.now())
print('Cross-validation...')
rf1 = RF_Util()
rf1.set_train(Xtrain,ytrain)
cv_scores = rf1.cross_validation()
print(cv_scores)
print('mean %.4f +/- %.4f' % (cv_scores.mean(),cv_scores.std()))
# Out:
# 2022-06-13 09:38:39.270456
# Cross-validation...
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] END .................................................... total time= 6.3min
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  6.3min remaining:    0.0s
# [CV] END .................................................... total time= 6.3min

# %%
print(datetime.datetime.now())
model = rf1.get_model()
joblib.dump(model,MODELS_DIR)
