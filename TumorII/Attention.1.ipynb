# %% [markdown]
# # Attention
# Class = 1.
#
# Integrate (1) Nucleus features as recored by CellProfiler Proces100
# and (2) attention level recorded by the CNN.
# Use Random Forest to say what CP features are predictive of attention.
# Here, we do the analysis per class, just because that is easiest.

# %%
import datetime
import numpy as np
import pandas as pd
from RandomForestUtil import RF_Util
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

# %%
ATTFILEPATH='/home/jrm/Adjeroh/Naved/CP_80K/attention_nucleus/' # Alien
ATTFILENAME='class1_avg_temp.csv'
NUCFILEPATH='/home/jrm/Adjeroh/Naved/CP_80K/Output1/'
NUCFILENAME='Process100_Nucleus.csv'

# %% [markdown]
# ## Load labels
# The labels are the temperatures of the CNN attention heatmap,
# specifically an average across the bounding box of each nucleus.

# %%
att_df=pd.read_csv(ATTFILEPATH+ATTFILENAME)
cols={'ImageNumber':'PatchNumber',' ObjectNumber':'ObjectNumber',' AvgTemp':'AvgTemp'}
att_df.rename(columns=cols,inplace=True)
att_df.sort_values(by=['PatchNumber','ObjectNumber'],axis=0,inplace=True)
att_df.reset_index(drop=True,inplace=True)

# %%
# Later, try the RandomForestRegressor. For now use bins and classification.
bins = [0, 0.3, 0.45, 0.6, 0.75, 1.0]
labels = ['to30%', 'to45%', 'to60%', 'to75%', 'to100%']
att_df['bin'] = pd.cut(att_df['AvgTemp'], bins=bins, labels=labels)
att_df
# Out:
#         PatchNumber  ObjectNumber   AvgTemp     bin
# 0                 1             1  0.282182   to30%
# 1                 1             2  0.296874   to30%
# 2                 1             3  0.320143   to45%
# 3                 1             4  0.171113   to30%
# 4                 1             5  0.357959   to45%
# ...             ...           ...       ...     ...
# 248485        12900             9  0.614003   to75%
# 248486        12900            10  0.773111  to100%
# 248487        12901             1  0.449821   to45%
# 248488        12902             1  0.805303  to100%
# 248489        12902             2  0.907113  to100%
#
# [248490 rows x 4 columns]

# %%
ytrain = att_df['bin'] 
ytrain.value_counts()
# Out:
# to30%     54393
# to100%    52680
# to60%     52542
# to45%     48277
# to75%     40598
# Name: bin, dtype: int64

# %% [markdown]
# ## Load features
# These are features of nuclei as determined by our "Process100" pipeline for CellProfiler.
# These are the nuclei used to set the bounding boxes for the temperature lables.
# Other than that, the features and temperatures were each derived independently.

# %%
nuc_df=pd.read_csv(NUCFILEPATH+NUCFILENAME)
cols={'ImageNumber':'PatchNumber'}
nuc_df.rename(columns=cols,inplace=True)
nuc_df.sort_values(by=['PatchNumber','ObjectNumber'],axis=0,inplace=True)
nuc_df.reset_index(drop=True,inplace=True)

# %%
Xtrain = nuc_df.drop(columns=['PatchNumber','ObjectNumber'])
Xtrain
# Out:
#         AreaShape_Area  AreaShape_BoundingBoxArea  \
# 0                  828                       1000
# 1                  559                        960
# 2                  460                        660
# 3                  469                        680
# 4                  265                        448
# ...                ...                        ...
# 248485             312                        630
# 248486             591                        812
# 248487             390                        506
# 248488             323                        441
# 248489             181                        272
#
#         AreaShape_BoundingBoxMaximum_X  AreaShape_BoundingBoxMaximum_Y  \
# 0                                  243                              25
# 1                                  196                              48
# 2                                  211                              48
# 3                                  116                              49
# 4                                  196                              51
# ...                                ...                             ...
# 248485                             119                             300
# 248486                             235                             300
# 248487                             193                              71
# 248488                              21                             126
# 248489                              31                             245
#
#         AreaShape_BoundingBoxMinimum_X  AreaShape_BoundingBoxMinimum_Y  \
# 0                                  203                               0
# 1                                  166                              16
# 2                                  189                              18
# 3                                   82                              29
# 4                                  168                              35
# ...                                ...                             ...
# 248485                              89                             279
# 248486                             206                             272
# 248487                             170                              49
# 248488                               0                             105
# 248489                              15                             228
#
#         AreaShape_Center_X  AreaShape_Center_Y  AreaShape_CentralMoment_0_0  \
# 0               221.247585           10.449275                        828.0
# 1               178.508050           27.883721                        559.0
# 2               199.397826           31.791304                        460.0
# 3                98.315565           38.153518                        469.0
# 4               182.384906           43.886792                        265.0
# ...                    ...                 ...                          ...
# 248485          101.141026          288.506410                        312.0
# 248486          219.456853          286.974619                        591.0
# 248487          179.912821           59.484615                        390.0
# 248488            9.786378          115.789474                        323.0
# 248489           22.950276          235.232044                        181.0
#
#         AreaShape_CentralMoment_0_1  ...  \
# 0                     -1.506351e-12  ...
# 1                     -2.486900e-14  ...
# 2                     -2.433609e-13  ...
# 3                      2.273737e-13  ...
# 4                     -8.881784e-14  ...
# ...                             ...  ...
# 248485                -4.973799e-14  ...
# 248486                -6.750156e-13  ...
# 248487                -5.968559e-13  ...
# 248488                -2.131628e-13  ...
# 248489                 1.953993e-14  ...
#
#         Texture_Variance_Hematoxylin_4_02_256  \
# 0                                  660.780936
# 1                                  968.722014
# 2                                 1466.518307
# 3                                  956.563266
# 4                                 1145.633232
# ...                                       ...
# 248485                            3464.480569
# 248486                            1500.882734
# 248487                            2362.205989
# 248488                            1393.836400
# 248489                            2832.499981
#
#         Texture_Variance_Hematoxylin_4_03_256  \
# 0                                  735.169789
# 1                                  966.869445
# 2                                 1486.244337
# 3                                  830.863645
# 4                                 1252.419379
# ...                                       ...
# 248485                            3908.449427
# 248486                            1474.259521
# 248487                            2456.127629
# 248488                            1383.672418
# 248489                            3317.758310
#
#         Texture_Variance_Hematoxylin_5_00_256  \
# 0                                  683.696726
# 1                                  890.918845
# 2                                 1431.984322
# 3                                  984.361014
# 4                                  899.905323
# ...                                       ...
# 248485                            3760.882618
# 248486                            1575.219312
# 248487                            2316.716582
# 248488                            1250.161006
# 248489                            3010.665997
#
#         Texture_Variance_Hematoxylin_5_01_256  \
# 0                                  710.438215
# 1                                  997.055721
# 2                                 1479.225124
# 3                                 1130.531320
# 4                                  795.795898
# ...                                       ...
# 248485                            3530.157049
# 248486                            1681.106641
# 248487                            2360.786953
# 248488                            1418.162355
# 248489                            3273.274937
#
#         Texture_Variance_Hematoxylin_5_02_256  \
# 0                                  660.816968
# 1                                  957.845085
# 2                                 1452.123712
# 3                                  938.975235
# 4                                 1261.046374
# ...                                       ...
# 248485                            3616.401475
# 248486                            1502.956763
# 248487                            2387.990461
# 248488                            1359.291995
# 248489                            2873.903595
#
#         Texture_Variance_Hematoxylin_5_03_256  \
# 0                                  744.997807
# 1                                  972.602567
# 2                                 1518.000593
# 3                                  793.983588
# 4                                 1371.643344
# ...                                       ...
# 248485                            3886.624114
# 248486                            1468.299830
# 248487                            2256.902238
# 248488                            1338.906038
# 248489                            3440.340780
#
#         Texture_Variance_Hematoxylin_7_00_256  \
# 0                                  688.634959
# 1                                  896.622657
# 2                                 1585.057170
# 3                                  957.319994
# 4                                  957.799648
# ...                                       ...
# 248485                            3755.405100
# 248486                            1547.554339
# 248487                            2375.598925
# 248488                            1279.663899
# 248489                            3263.530273
#
#         Texture_Variance_Hematoxylin_7_01_256  \
# 0                                  707.175777
# 1                                 1091.533923
# 2                                 1436.823849
# 3                                 1104.739661
# 4                                  730.771488
# ...                                       ...
# 248485                            3757.063020
# 248486                            1742.616703
# 248487                            2525.959704
# 248488                            1904.470085
# 248489                            3158.611042
#
#         Texture_Variance_Hematoxylin_7_02_256  \
# 0                                  672.827808
# 1                                  930.761389
# 2                                 1420.359612
# 3                                  900.719530
# 4                                 1491.493975
# ...                                       ...
# 248485                            3979.526033
# 248486                            1542.471534
# 248487                            2475.763970
# 248488                            1319.920812
# 248489                            2949.973733
#
#         Texture_Variance_Hematoxylin_7_03_256
# 0                                  731.769250
# 1                                  918.591865
# 2                                 1586.742416
# 3                                  847.637257
# 4                                 1604.096659
# ...                                       ...
# 248485                            3774.403946
# 248486                            1668.649398
# 248487                            2385.981756
# 248488                            1271.221273
# 248489                            3404.595556
#
# [248490 rows x 648 columns]

# %%
att_df=None
nuc_df=None
print('Count Nan before:',Xtrain.isna().sum().sum())
Xtrain.fillna(0,inplace=True)
print('Count Nan after:',Xtrain.isna().sum().sum())
# Out:
# Count Nan before: 745864
# Count Nan after: 0

# %% [markdown]
# ## Measure agreement (with a random forest classifier)
# Can the RF predict the temperature of each nucleus given only the CellProfiler features?

# %%
print(datetime.datetime.now())
print("Shuffle...")
Xtrain,ytrain=shuffle(Xtrain,ytrain)  #set random_state for reproducibility
# Out:
# 2022-06-09 09:21:01.103097
# Shuffle...

# %%
print(datetime.datetime.now())
print('Cross validation...')
rf1 = RF_Util()
rf1.set_train(Xtrain,ytrain)
cv_scores = rf1.cross_validation()
print(cv_scores)
print('Accuracy mean %.4f +/- %.4f' % (cv_scores.mean(),cv_scores.std()))
# Out:
# 2022-06-09 09:21:01.650376
# Cross validation...
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] END .................................................... total time= 7.1min
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  7.1min remaining:    0.0s
# [CV] END .................................................... total time= 7.1min
# [CV] END .................................................... total time= 7.1min
# [CV] END .................................................... total time= 7.1min
# [CV] END .................................................... total time= 7.1min
# [0.93667753 0.93955491 0.94023904 0.94080245 0.94386092]
# Accuracy mean 0.9402 +/- 0.0023
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed: 35.5min finished

# %% [markdown]
# ## Measure feature importance

# %%
print(datetime.datetime.now())
print('Re-train on full training set...')
rf1 = None
rf2 = RF_Util()
rf2.set_train(Xtrain,ytrain)
rf2.fit()
print(datetime.datetime.now())
print('...and rank the features by importance.')
top = rf2.important_features()
pd.set_option('display.max_rows', None)
top.loc[:200]
# Out:
# 2022-06-09 09:56:29.422868
# Re-train on full training set...
# 2022-06-09 10:05:31.742524
# ...and rank the features by importance.
#             0                                                  1
# 0    0.078421                                  Location_Center_X
# 1    0.071820                     AreaShape_BoundingBoxMaximum_X
# 2    0.071027         Location_CenterMassIntensity_X_Hematoxylin
# 3    0.068814                                 AreaShape_Center_X
# 4    0.064103                     AreaShape_BoundingBoxMinimum_X
# 5    0.058265                Location_MaxIntensity_X_Hematoxylin
# 6    0.042054                                  Location_Center_Y
# 7    0.040315                     AreaShape_BoundingBoxMinimum_Y
# 8    0.038398                     AreaShape_BoundingBoxMaximum_Y
# 9    0.037996         Location_CenterMassIntensity_Y_Hematoxylin
# 10   0.037180                                 AreaShape_Center_Y
# 11   0.032693                Location_MaxIntensity_Y_Hematoxylin
# 12   0.017165                 Neighbors_PercentTouching_Expanded
# 13   0.007834               Neighbors_NumberOfNeighbors_Expanded
# 14   0.007576                               Number_Object_Number
# 15   0.005100        Neighbors_FirstClosestObjectNumber_Expanded
# 16   0.004828       Neighbors_SecondClosestObjectNumber_Expanded
# 17   0.002025      Intensity_IntegratedIntensityEdge_Hematoxylin
# 18   0.001683           Neighbors_SecondClosestDistance_Expanded
# 19   0.001552                     AreaShape_NormalizedMoment_1_2
# 20   0.001360        RadialDistribution_FracAtD_Hematoxylin_1of5
# 21   0.001358           Neighbors_AngleBetweenNeighbors_Expanded
# 22   0.001323                     AreaShape_NormalizedMoment_0_2
# 23   0.001282                     AreaShape_NormalizedMoment_2_1
# 24   0.001277                                   AreaShape_Extent
# 25   0.001214            Neighbors_FirstClosestDistance_Expanded
# 26   0.001150                        AreaShape_SpatialMoment_0_3
# 27   0.001142                          Granularity_1_Hematoxylin
# 28   0.001117                     AreaShape_NormalizedMoment_2_2
# 29   0.001112        RadialDistribution_FracAtD_Hematoxylin_2of5
# 30   0.001087                        AreaShape_InertiaTensor_0_0
# 31   0.001075                     AreaShape_NormalizedMoment_2_0
# 32   0.001061                        AreaShape_SpatialMoment_0_2
# 33   0.001013                        AreaShape_SpatialMoment_2_0
# 34   0.001012                     AreaShape_NormalizedMoment_3_0
# 35   0.000991                        AreaShape_CentralMoment_1_2
# 36   0.000978        RadialDistribution_FracAtD_Hematoxylin_3of5
# 37   0.000972                        AreaShape_InertiaTensor_1_1
# 38   0.000952                               AreaShape_HuMoment_2
# 39   0.000945                        AreaShape_SpatialMoment_1_3
# 40   0.000932    RadialDistribution_ZernikePhase_Hematoxylin_4_2
# 41   0.000931                        AreaShape_SpatialMoment_0_1
# 42   0.000920                        AreaShape_CentralMoment_0_3
# 43   0.000914                     AreaShape_NormalizedMoment_0_3
# 44   0.000902    RadialDistribution_ZernikePhase_Hematoxylin_2_2
# 45   0.000900                     AreaShape_NormalizedMoment_3_2
# 46   0.000898                     AreaShape_NormalizedMoment_2_3
# 47   0.000892                        AreaShape_CentralMoment_2_1
# 48   0.000892        RadialDistribution_FracAtD_Hematoxylin_4of5
# 49   0.000885                        AreaShape_SpatialMoment_1_0
# 50   0.000861                                 AreaShape_Solidity
# 51   0.000852    RadialDistribution_ZernikePhase_Hematoxylin_1_1
# 52   0.000832        RadialDistribution_FracAtD_Hematoxylin_5of5
# 53   0.000817                              AreaShape_Compactness
# 54   0.000794    RadialDistribution_ZernikePhase_Hematoxylin_3_1
# 55   0.000785    RadialDistribution_ZernikePhase_Hematoxylin_4_4
# 56   0.000785                              AreaShape_Orientation
# 57   0.000775    RadialDistribution_ZernikePhase_Hematoxylin_6_4
# 58   0.000774                               AreaShape_FormFactor
# 59   0.000772    RadialDistribution_ZernikePhase_Hematoxylin_3_3
# 60   0.000768    RadialDistribution_ZernikePhase_Hematoxylin_6_6
# 61   0.000767                        AreaShape_CentralMoment_2_3
# 62   0.000766    RadialDistribution_ZernikePhase_Hematoxylin_7_7
# 63   0.000766    RadialDistribution_ZernikePhase_Hematoxylin_9_9
# 64   0.000764    RadialDistribution_ZernikePhase_Hematoxylin_9_1
# 65   0.000761                              AreaShape_Zernike_2_2
# 66   0.000761    RadialDistribution_ZernikePhase_Hematoxylin_9_7
# 67   0.000760    RadialDistribution_ZernikePhase_Hematoxylin_5_3
# 68   0.000760    RadialDistribution_ZernikePhase_Hematoxylin_5_1
# 69   0.000760                              AreaShape_Zernike_8_8
# 70   0.000760  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 71   0.000758    RadialDistribution_ZernikePhase_Hematoxylin_8_8
# 72   0.000758                              AreaShape_Zernike_0_0
# 73   0.000757    RadialDistribution_ZernikePhase_Hematoxylin_6_2
# 74   0.000756  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 75   0.000755  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 76   0.000754                          Granularity_2_Hematoxylin
# 77   0.000749    RadialDistribution_ZernikePhase_Hematoxylin_8_6
# 78   0.000749                              AreaShape_Zernike_9_9
# 79   0.000749                              AreaShape_Zernike_8_6
# 80   0.000748                              AreaShape_Zernike_4_4
# 81   0.000748                              AreaShape_Zernike_6_6
# 82   0.000746    RadialDistribution_ZernikePhase_Hematoxylin_9_5
# 83   0.000746    RadialDistribution_ZernikePhase_Hematoxylin_7_3
# 84   0.000745    RadialDistribution_ZernikePhase_Hematoxylin_8_4
# 85   0.000745                              AreaShape_Zernike_9_7
# 86   0.000744    RadialDistribution_ZernikePhase_Hematoxylin_7_1
# 87   0.000744                              AreaShape_Zernike_8_2
# 88   0.000740  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 89   0.000738    RadialDistribution_ZernikePhase_Hematoxylin_7_5
# 90   0.000736                        AreaShape_SpatialMoment_2_1
# 91   0.000736  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 92   0.000735                              AreaShape_Zernike_7_1
# 93   0.000734                              AreaShape_Zernike_7_7
# 94   0.000733  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 95   0.000732                              AreaShape_Zernike_5_5
# 96   0.000732                              AreaShape_Zernike_9_5
# 97   0.000732                        AreaShape_SpatialMoment_1_2
# 98   0.000732                              AreaShape_Zernike_9_1
# 99   0.000730    RadialDistribution_ZernikePhase_Hematoxylin_9_3
# 100  0.000729                              AreaShape_Zernike_1_1
# 101  0.000728    RadialDistribution_ZernikePhase_Hematoxylin_8_2
# 102  0.000727                              AreaShape_Zernike_5_3
# 103  0.000724  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 104  0.000724                              AreaShape_Zernike_7_5
# 105  0.000723                              AreaShape_Zernike_6_2
# 106  0.000720                              AreaShape_Zernike_8_4
# 107  0.000720    RadialDistribution_ZernikePhase_Hematoxylin_5_5
# 108  0.000720                              AreaShape_Zernike_3_3
# 109  0.000719                              AreaShape_Zernike_2_0
# 110  0.000718  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 111  0.000718                              AreaShape_Zernike_9_3
# 112  0.000717                              AreaShape_Zernike_6_4
# 113  0.000715  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 114  0.000714                        AreaShape_SpatialMoment_2_3
# 115  0.000714  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 116  0.000712                              AreaShape_Zernike_3_1
# 117  0.000712                              AreaShape_Zernike_4_0
# 118  0.000710  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 119  0.000708                              AreaShape_Zernike_6_0
# 120  0.000708                        AreaShape_CentralMoment_0_2
# 121  0.000707  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 122  0.000707  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 123  0.000705                              AreaShape_Zernike_7_3
# 124  0.000703  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 125  0.000702  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 126  0.000702  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 127  0.000699                              AreaShape_Zernike_5_1
# 128  0.000699  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 129  0.000698                              AreaShape_Zernike_8_0
# 130  0.000697                        AreaShape_CentralMoment_2_0
# 131  0.000696  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 132  0.000694  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 133  0.000692                              AreaShape_Zernike_4_2
# 134  0.000690                 Texture_Correlation_Eosin_7_02_256
# 135  0.000687  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 136  0.000686  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 137  0.000682  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 138  0.000682           Texture_Correlation_Hematoxylin_7_03_256
# 139  0.000682  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 140  0.000681                          Granularity_3_Hematoxylin
# 141  0.000681           Texture_Correlation_Hematoxylin_7_02_256
# 142  0.000680                               AreaShape_HuMoment_0
# 143  0.000677  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 144  0.000676                 Texture_Correlation_Eosin_7_00_256
# 145  0.000676                 Texture_Correlation_Eosin_3_00_256
# 146  0.000676                 Texture_Correlation_Eosin_7_03_256
# 147  0.000675           Texture_Correlation_Hematoxylin_7_01_256
# 148  0.000674                 Texture_Correlation_Eosin_7_01_256
# 149  0.000672  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 150  0.000670  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 151  0.000668       RadialDistribution_MeanFrac_Hematoxylin_3of5
# 152  0.000668           Texture_Correlation_Hematoxylin_7_00_256
# 153  0.000667                 Texture_Correlation_Eosin_5_02_256
# 154  0.000667           Texture_Correlation_Hematoxylin_3_02_256
# 155  0.000667           Texture_Correlation_Hematoxylin_5_03_256
# 156  0.000664                 Texture_Correlation_Eosin_3_02_256
# 157  0.000663  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 158  0.000662                 Texture_Correlation_Eosin_3_03_256
# 159  0.000659       RadialDistribution_MeanFrac_Hematoxylin_1of5
# 160  0.000659                 Texture_Correlation_Eosin_4_00_256
# 161  0.000659           Texture_Correlation_Hematoxylin_3_00_256
# 162  0.000655                 Texture_Correlation_Eosin_4_02_256
# 163  0.000655       RadialDistribution_MeanFrac_Hematoxylin_2of5
# 164  0.000654                 Texture_Correlation_Eosin_5_00_256
# 165  0.000654                 Texture_Correlation_Eosin_5_01_256
# 166  0.000653             Intensity_MassDisplacement_Hematoxylin
# 167  0.000650       RadialDistribution_MeanFrac_Hematoxylin_4of5
# 168  0.000648                 Texture_Correlation_Eosin_4_03_256
# 169  0.000647                 Texture_Correlation_Eosin_3_01_256
# 170  0.000645                          AreaShape_BoundingBoxArea
# 171  0.000644                 Texture_Correlation_Eosin_5_03_256
# 172  0.000641           Texture_Correlation_Hematoxylin_4_01_256
# 173  0.000640  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 174  0.000638           Texture_Correlation_Hematoxylin_5_02_256
# 175  0.000638           Texture_Correlation_Hematoxylin_4_02_256
# 176  0.000637           Texture_Correlation_Hematoxylin_4_00_256
# 177  0.000635           Texture_Correlation_Hematoxylin_3_03_256
# 178  0.000634                 Texture_Correlation_Eosin_4_01_256
# 179  0.000634           Texture_Correlation_Hematoxylin_4_03_256
# 180  0.000632                               AreaShape_HuMoment_1
# 181  0.000630           Texture_Correlation_Hematoxylin_3_01_256
# 182  0.000629           Texture_Correlation_Hematoxylin_5_01_256
# 183  0.000626           Texture_Correlation_Hematoxylin_5_00_256
# 184  0.000624       RadialDistribution_RadialCV_Hematoxylin_5of5
# 185  0.000623       RadialDistribution_MeanFrac_Hematoxylin_5of5
# 186  0.000622                     AreaShape_NormalizedMoment_1_1
# 187  0.000620                             AreaShape_Eccentricity
# 188  0.000614                          Granularity_4_Hematoxylin
# 189  0.000612  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 190  0.000611       RadialDistribution_RadialCV_Hematoxylin_1of5
# 191  0.000610                          Granularity_6_Hematoxylin
# 192  0.000605                          Granularity_5_Hematoxylin
# 193  0.000600                        AreaShape_CentralMoment_1_3
# 194  0.000598                          AreaShape_MajorAxisLength
# 195  0.000595                        AreaShape_SpatialMoment_2_2
# 196  0.000595                          Granularity_7_Hematoxylin
# 197  0.000589             Intensity_MaxIntensityEdge_Hematoxylin
# 198  0.000588       RadialDistribution_RadialCV_Hematoxylin_4of5
# 199  0.000587                     AreaShape_NormalizedMoment_3_3
# 200  0.000587  Texture_InverseDifferenceMoment_Hematoxylin_7_...
