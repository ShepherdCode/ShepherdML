# %% [markdown]
# # RBC rollup
# Rollup the RBC statistics per patch. All classes.

# %%
import datetime
print(datetime.datetime.now())
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import sklearn
print('scikit-learn version',sklearn.__version__)
# Out:
# 2022-06-07 09:56:09.040273
# scikit-learn version 1.0.2

# %%
CLASSES=[0,1,2,3,4,5]
FILEPATHS=[0,1,2,3,4,5]
FILEPATHS[0]='/home/jrm/Adjeroh/Naved/CP_80K/Output0/' 
FILEPATHS[1]='/home/jrm/Adjeroh/Naved/CP_80K/Output1/' 
FILEPATHS[2]='/home/jrm/Adjeroh/Naved/CP_80K/Output2/' 
FILEPATHS[3]='/home/jrm/Adjeroh/Naved/CP_80K/Output3/' 
FILEPATHS[4]='/home/jrm/Adjeroh/Naved/CP_80K/Output4/' 
FILEPATHS[5]='/home/jrm/Adjeroh/Naved/CP_80K/Output5/'

# %%
from CellProfiler_Util import CP_Util
for c in CLASSES:
    print(datetime.datetime.now())
    outfile = f'RBC_Rollup_%1d.csv'%c
    cputil = CP_Util(FILEPATHS[c])
    print('Process',FILEPATHS[c],'to',outfile)
    cputil.train_test_split() 
    cputil.validate_split()
    train_set=cputil.get_train_patches()
    rbc = cputil.get_RBC()
    rollup = rbc.groupby(['PatchNumber']).describe() ## this is slow
    rollup.columns=rollup.columns.map('_'.join)  ## helps random forest code
    rollup.to_csv(outfile)
print(datetime.datetime.now())
print("Done")
# Out:
# 2022-06-07 09:56:09.504061
# Process /home/jrm/Adjeroh/Naved/CP_80K/Output0/ to RBC_Rollup_0.csv
# 2022-06-07 10:10:21.477976
# Process /home/jrm/Adjeroh/Naved/CP_80K/Output1/ to RBC_Rollup_1.csv
# 2022-06-07 10:14:29.261868
# Process /home/jrm/Adjeroh/Naved/CP_80K/Output2/ to RBC_Rollup_2.csv
# 2022-06-07 10:20:23.112782
# Process /home/jrm/Adjeroh/Naved/CP_80K/Output3/ to RBC_Rollup_3.csv
# 2022-06-07 10:23:11.797801
# Process /home/jrm/Adjeroh/Naved/CP_80K/Output4/ to RBC_Rollup_4.csv
# 2022-06-07 10:24:09.230371
# Process /home/jrm/Adjeroh/Naved/CP_80K/Output5/ to RBC_Rollup_5.csv
# 2022-06-07 10:24:30.996850
# Done

# %%
df=pd.read_csv('RBC_Rollup_5.csv')
df
# Out:
#      PatchNumber  ObjectNumber_count  ObjectNumber_mean  ObjectNumber_std  \
# 0              3                 2.0                1.5          0.707107
# 1              4                 1.0                1.0               NaN
# 2              8                 3.0                2.0          1.000000
# 3              9                 6.0                3.5          1.870829
# 4             10                 2.0                1.5          0.707107
# ..           ...                 ...                ...               ...
# 214         1413                 1.0                1.0               NaN
# 215         1476                 2.0                1.5          0.707107
# 216         1534                 1.0                1.0               NaN
# 217         1573                 1.0                1.0               NaN
# 218         1589                 2.0                1.5          0.707107
#
#      ObjectNumber_min  ObjectNumber_25%  ObjectNumber_50%  ObjectNumber_75%  \
# 0                 1.0              1.25               1.5              1.75
# 1                 1.0              1.00               1.0              1.00
# 2                 1.0              1.50               2.0              2.50
# 3                 1.0              2.25               3.5              4.75
# 4                 1.0              1.25               1.5              1.75
# ..                ...               ...               ...               ...
# 214               1.0              1.00               1.0              1.00
# 215               1.0              1.25               1.5              1.75
# 216               1.0              1.00               1.0              1.00
# 217               1.0              1.00               1.0              1.00
# 218               1.0              1.25               1.5              1.75
#
#      ObjectNumber_max  AreaShape_Area_count  ...  Number_Object_Number_75%  \
# 0                 2.0                   2.0  ...                      1.75
# 1                 1.0                   1.0  ...                      1.00
# 2                 3.0                   3.0  ...                      2.50
# 3                 6.0                   6.0  ...                      4.75
# 4                 2.0                   2.0  ...                      1.75
# ..                ...                   ...  ...                       ...
# 214               1.0                   1.0  ...                      1.00
# 215               2.0                   2.0  ...                      1.75
# 216               1.0                   1.0  ...                      1.00
# 217               1.0                   1.0  ...                      1.00
# 218               2.0                   2.0  ...                      1.75
#
#      Number_Object_Number_max  Parent_ShrinkRBC_count  Parent_ShrinkRBC_mean  \
# 0                         2.0                     2.0               2.000000
# 1                         1.0                     1.0               1.000000
# 2                         3.0                     3.0               2.333333
# 3                         6.0                     6.0               3.666667
# 4                         2.0                     2.0               2.500000
# ..                        ...                     ...                    ...
# 214                       1.0                     1.0               1.000000
# 215                       2.0                     2.0               4.500000
# 216                       1.0                     1.0               1.000000
# 217                       1.0                     1.0               1.000000
# 218                       2.0                     2.0               1.500000
#
#      Parent_ShrinkRBC_std  Parent_ShrinkRBC_min  Parent_ShrinkRBC_25%  \
# 0                1.414214                   1.0                  1.50
# 1                     NaN                   1.0                  1.00
# 2                1.527525                   1.0                  1.50
# 3                2.160247                   1.0                  2.25
# 4                2.121320                   1.0                  1.75
# ..                    ...                   ...                   ...
# 214                   NaN                   1.0                  1.00
# 215              2.121320                   3.0                  3.75
# 216                   NaN                   1.0                  1.00
# 217                   NaN                   1.0                  1.00
# 218              0.707107                   1.0                  1.25
#
#      Parent_ShrinkRBC_50%  Parent_ShrinkRBC_75%  Parent_ShrinkRBC_max
# 0                     2.0                  2.50                   3.0
# 1                     1.0                  1.00                   1.0
# 2                     2.0                  3.00                   4.0
# 3                     3.5                  4.75                   7.0
# 4                     2.5                  3.25                   4.0
# ..                    ...                   ...                   ...
# 214                   1.0                  1.00                   1.0
# 215                   4.5                  5.25                   6.0
# 216                   1.0                  1.00                   1.0
# 217                   1.0                  1.00                   1.0
# 218                   1.5                  1.75                   2.0
#
# [219 rows x 1201 columns]
