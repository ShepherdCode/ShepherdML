# %% [markdown]
# # Random Forest

# %% [markdown]
# ## Prior Progress
# Random Forest 14 got 70% accuracy on 5 classes (we didn't have class 0 yet).
#
# ## Next Task
# Do the 6-way classification using Nucleus plus RBC.

# %%
import datetime
print(datetime.datetime.now())
from platform import python_version
print('Python',python_version())
import numpy as np
import pandas as pd
import sklearn   # pip install --upgrade scikit-learn
print('sklearn',sklearn.__version__)
import tensorflow as tf
tf.config.list_physical_devices('GPU')
# Out:
# 2022-06-08 19:34:02.388153
# Python 3.8.10
# sklearn 1.0.2
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.utils import shuffle
from sklearn.feature_selection import RFE
import joblib # used to dump/load sklearn models
from CellProfiler_Util import CP_Util
from RandomForestUtil import RF_Util

# %%
BASE_DIR='/home/jrm/ShepherdML/TumorII/'
NUCLEUS_FILES=[
    'Nucleus_Rollup_0.csv',
    'Nucleus_Rollup_1.csv',
    'Nucleus_Rollup_2.csv',
    'Nucleus_Rollup_3.csv',
    'Nucleus_Rollup_4.csv',
    'Nucleus_Rollup_5.csv']
RBC_FILES=[
    'RBC_Rollup_0.csv',
    'RBC_Rollup_1.csv',
    'RBC_Rollup_2.csv',
    'RBC_Rollup_3.csv',
    'RBC_Rollup_4.csv',
    'RBC_Rollup_5.csv']
CLASSES=range(0,6)   # for the first time, use all 6 classes
MODELS_DIR='/home/jrm/Adjeroh/Naved/models/RandomForest.18/'

# %%
print(datetime.datetime.now())
PREFIX='abc_'
def set_prefix(prefix):
    global PREFIX
    PREFIX=prefix
def get_prefix(col_name):
    global PREFIX
    return PREFIX+col_name  # hard coded for now
def load_all_classes():
    X = None
    y = None
    for i in CLASSES:
        print(datetime.datetime.now())
        print("Loading class",i)
        Xnuc = pd.read_csv(BASE_DIR+NUCLEUS_FILES[i])
        Xnuc.set_index(['PatchNumber'],inplace=True)
        set_prefix('Nuc_')
        Xnuc.rename(get_prefix,axis='columns',inplace=True)
        Xrbc = pd.read_csv(BASE_DIR+RBC_FILES[i])
        Xrbc.set_index(['PatchNumber'],inplace=True)
        set_prefix('Rbc_')
        Xrbc.rename(get_prefix,axis='columns',inplace=True)
        Xi = Xnuc.join(Xrbc,how='outer')
        #Xi.drop(columns=['PatchNumber'],inplace=True)
        size = len(Xi)
        yi = np.ones(size) * i   # e.g. class 3
        if X is None:
            X = Xi
            y = yi
        else:
            X = pd.concat( (X,Xi) )
            y = np.concatenate( (y,yi) )
    X.fillna(0,inplace=True)  
    return X,y
Xtrain,ytrain=load_all_classes()
Xtrain
# Out:
# 2022-06-08 19:34:04.180857
# 2022-06-08 19:34:04.181162
# Loading class 0
# 2022-06-08 19:34:28.393230
# Loading class 1
# 2022-06-08 19:34:36.876751
# Loading class 2
# 2022-06-08 19:34:46.838128
# Loading class 3
# 2022-06-08 19:34:54.337176
# Loading class 4
# 2022-06-08 19:35:00.642470
# Loading class 5
#              Nuc_ObjectNumber_count  Nuc_ObjectNumber_mean  \
# PatchNumber
# 397                             7.0                    4.0
# 398                             1.0                    1.0
# 399                             1.0                    1.0
# 400                             4.0                    2.5
# 401                             4.0                    2.5
# ...                             ...                    ...
# 1587                            7.0                    4.0
# 1588                           17.0                    9.0
# 1589                           19.0                   10.0
# 1590                           33.0                   17.0
# 1591                            4.0                    2.5
#
#              Nuc_ObjectNumber_std  Nuc_ObjectNumber_min  Nuc_ObjectNumber_25%  \
# PatchNumber
# 397                      2.160247                   1.0                  2.50
# 398                      0.000000                   1.0                  1.00
# 399                      0.000000                   1.0                  1.00
# 400                      1.290994                   1.0                  1.75
# 401                      1.290994                   1.0                  1.75
# ...                           ...                   ...                   ...
# 1587                     2.160247                   1.0                  2.50
# 1588                     5.049752                   1.0                  5.00
# 1589                     5.627314                   1.0                  5.50
# 1590                     9.669540                   1.0                  9.00
# 1591                     1.290994                   1.0                  1.75
#
#              Nuc_ObjectNumber_50%  Nuc_ObjectNumber_75%  Nuc_ObjectNumber_max  \
# PatchNumber
# 397                           4.0                  5.50                   7.0
# 398                           1.0                  1.00                   1.0
# 399                           1.0                  1.00                   1.0
# 400                           2.5                  3.25                   4.0
# 401                           2.5                  3.25                   4.0
# ...                           ...                   ...                   ...
# 1587                          4.0                  5.50                   7.0
# 1588                          9.0                 13.00                  17.0
# 1589                         10.0                 14.50                  19.0
# 1590                         17.0                 25.00                  33.0
# 1591                          2.5                  3.25                   4.0
#
#              Nuc_AreaShape_Area_count  Nuc_AreaShape_Area_mean  ...  \
# PatchNumber                                                     ...
# 397                               7.0               216.000000  ...
# 398                               1.0               200.000000  ...
# 399                               1.0               181.000000  ...
# 400                               4.0               239.250000  ...
# 401                               4.0               237.500000  ...
# ...                               ...                      ...  ...
# 1587                              7.0               368.285714  ...
# 1588                             17.0               519.352941  ...
# 1589                             19.0               388.315789  ...
# 1590                             33.0               444.454545  ...
# 1591                              4.0               514.500000  ...
#
#              Rbc_Number_Object_Number_75%  Rbc_Number_Object_Number_max  \
# PatchNumber
# 397                                  0.00                           0.0
# 398                                  0.00                           0.0
# 399                                  0.00                           0.0
# 400                                  0.00                           0.0
# 401                                  0.00                           0.0
# ...                                   ...                           ...
# 1587                                 0.00                           0.0
# 1588                                 0.00                           0.0
# 1589                                 1.75                           2.0
# 1590                                 0.00                           0.0
# 1591                                 0.00                           0.0
#
#              Rbc_Parent_ShrinkRBC_count  Rbc_Parent_ShrinkRBC_mean  \
# PatchNumber
# 397                                 0.0                        0.0
# 398                                 0.0                        0.0
# 399                                 0.0                        0.0
# 400                                 0.0                        0.0
# 401                                 0.0                        0.0
# ...                                 ...                        ...
# 1587                                0.0                        0.0
# 1588                                0.0                        0.0
# 1589                                2.0                        1.5
# 1590                                0.0                        0.0
# 1591                                0.0                        0.0
#
#              Rbc_Parent_ShrinkRBC_std  Rbc_Parent_ShrinkRBC_min  \
# PatchNumber
# 397                          0.000000                       0.0
# 398                          0.000000                       0.0
# 399                          0.000000                       0.0
# 400                          0.000000                       0.0
# 401                          0.000000                       0.0
# ...                               ...                       ...
# 1587                         0.000000                       0.0
# 1588                         0.000000                       0.0
# 1589                         0.707107                       1.0
# 1590                         0.000000                       0.0
# 1591                         0.000000                       0.0
#
#              Rbc_Parent_ShrinkRBC_25%  Rbc_Parent_ShrinkRBC_50%  \
# PatchNumber
# 397                              0.00                       0.0
# 398                              0.00                       0.0
# 399                              0.00                       0.0
# 400                              0.00                       0.0
# 401                              0.00                       0.0
# ...                               ...                       ...
# 1587                             0.00                       0.0
# 1588                             0.00                       0.0
# 1589                             1.25                       1.5
# 1590                             0.00                       0.0
# 1591                             0.00                       0.0
#
#              Rbc_Parent_ShrinkRBC_75%  Rbc_Parent_ShrinkRBC_max
# PatchNumber
# 397                              0.00                       0.0
# 398                              0.00                       0.0
# 399                              0.00                       0.0
# 400                              0.00                       0.0
# 401                              0.00                       0.0
# ...                               ...                       ...
# 1587                             0.00                       0.0
# 1588                             0.00                       0.0
# 1589                             1.75                       2.0
# 1590                             0.00                       0.0
# 1591                             0.00                       0.0
#
# [66182 rows x 6392 columns]

# %%
print(datetime.datetime.now())
print('Do a one-time train/valid split...')
Xt,Xv,yt,yv = train_test_split(Xtrain, ytrain.ravel()) 
        # ,random_state=42) # add this for reproducibility
Xtrain=None
Ytrain=None
print('Xtrain',Xt.shape,'ytrain',yt.shape,'non-zero:',np.count_nonzero(yt))
print('Xvalid',Xv.shape,'yvalid',yv.shape,'non-zero:',np.count_nonzero(yv))
print('Do a one-time fit and evaluate...')
rf1 = RF_Util()
rf1.set_train(Xt,yt)
rf1.set_validation(Xv,yv)
print(datetime.datetime.now())
rf1.fit()
print(datetime.datetime.now())
print('Accuracy:',rf1.validation_accuracy())
print('Confusion:')
print(rf1.validation_confusion())
# Out:
# 2022-06-08 19:35:23.552854
# Do a one-time train/valid split...
# Xtrain (49636, 6392) ytrain (49636,) non-zero: 22652
# Xvalid (16546, 6392) yvalid (16546,) non-zero: 7535
# Do a one-time fit and evaluate...
# 2022-06-08 19:35:25.823212
# 2022-06-08 19:41:17.956718
# Accuracy: 81.49401668076877
# Confusion:
# [[8715  128  135   30    2    1]
#  [ 314 1736  417   49    6    0]
#  [ 249  436 2041   50    9    9]
#  [ 151  280  282  593    2    0]
#  [  87  112  152   19  233    0]
#  [  50   30   49   13    0  166]]

# %%
pd.set_option('display.max_rows', None)
top = rf1.important_features()
top.loc[:100]
# Out:
#             0                                                  1
# 0    0.007199                    Nuc_AreaShape_MaximumRadius_50%
# 1    0.006719    Nuc_Texture_InfoMeas1_Hematoxylin_5_03_256_mean
# 2    0.006383     Nuc_Texture_InfoMeas1_Hematoxylin_7_01_256_75%
# 3    0.006320                      Nuc_AreaShape_MeanRadius_mean
# 4    0.005746                       Nuc_AreaShape_MeanRadius_50%
# 5    0.004994     Nuc_Texture_InfoMeas1_Hematoxylin_7_01_256_50%
# 6    0.004884    Nuc_Texture_InfoMeas1_Hematoxylin_4_03_256_mean
# 7    0.004429     Nuc_Texture_InfoMeas1_Hematoxylin_5_01_256_25%
# 8    0.004406     Nuc_Texture_InfoMeas1_Hematoxylin_4_03_256_75%
# 9    0.004322     Nuc_Texture_InfoMeas1_Hematoxylin_4_01_256_50%
# 10   0.004306     Nuc_Texture_InfoMeas1_Hematoxylin_4_02_256_50%
# 11   0.004282     Nuc_Texture_InfoMeas1_Hematoxylin_4_03_256_25%
# 12   0.004047     Nuc_Texture_InfoMeas2_Hematoxylin_7_02_256_50%
# 13   0.003890  Nuc_Texture_AngularSecondMoment_Eosin_7_02_256...
# 14   0.003783             Nuc_Texture_Entropy_Eosin_4_01_256_50%
# 15   0.003450     Nuc_Texture_InfoMeas1_Hematoxylin_7_02_256_50%
# 16   0.003328                    Nuc_AreaShape_MedianRadius_mean
# 17   0.003081     Nuc_Texture_InfoMeas1_Hematoxylin_7_01_256_25%
# 18   0.003019                     Nuc_AreaShape_MedianRadius_50%
# 19   0.002862     Nuc_Texture_InfoMeas1_Hematoxylin_7_00_256_25%
# 20   0.002765     Nuc_Texture_InfoMeas1_Hematoxylin_4_03_256_50%
# 21   0.002753                 Nuc_Granularity_3_Hematoxylin_mean
# 22   0.002747     Nuc_Texture_InfoMeas1_Hematoxylin_5_03_256_50%
# 23   0.002668     Nuc_Texture_InfoMeas1_Hematoxylin_7_02_256_75%
# 24   0.002548                 Nuc_AreaShape_MinFeretDiameter_50%
# 25   0.002547    Nuc_Texture_InfoMeas1_Hematoxylin_7_00_256_mean
# 26   0.002529     Nuc_Texture_InfoMeas2_Hematoxylin_5_01_256_50%
# 27   0.002515     Nuc_Texture_InfoMeas1_Hematoxylin_5_03_256_25%
# 28   0.002509    Nuc_Texture_InfoMeas1_Hematoxylin_4_00_256_mean
# 29   0.002441    Nuc_Texture_InfoMeas1_Hematoxylin_5_02_256_mean
# 30   0.002424     Nuc_Texture_InfoMeas1_Hematoxylin_7_03_256_50%
# 31   0.002405                 Nuc_AreaShape_MinorAxisLength_mean
# 32   0.002391                             Nuc_AreaShape_Area_50%
# 33   0.002376     Nuc_Texture_InfoMeas1_Hematoxylin_5_02_256_50%
# 34   0.002368     Nuc_Texture_InfoMeas1_Hematoxylin_5_01_256_50%
# 35   0.002360                Nuc_AreaShape_SpatialMoment_0_0_50%
# 36   0.002346            Nuc_Texture_Entropy_Eosin_3_03_256_mean
# 37   0.002323    Nuc_Texture_InfoMeas1_Hematoxylin_7_01_256_mean
# 38   0.002317     Nuc_Texture_InfoMeas1_Hematoxylin_7_00_256_75%
# 39   0.002306             Nuc_Texture_Entropy_Eosin_5_00_256_50%
# 40   0.002288     Nuc_Texture_InfoMeas1_Hematoxylin_5_00_256_50%
# 41   0.002285                  Nuc_Granularity_3_Hematoxylin_75%
# 42   0.002279                Nuc_AreaShape_SpatialMoment_0_0_25%
# 43   0.002262     Nuc_Texture_InfoMeas1_Hematoxylin_4_01_256_75%
# 44   0.002259                       Nuc_AreaShape_MeanRadius_25%
# 45   0.002256     Nuc_Texture_InfoMeas1_Hematoxylin_4_01_256_25%
# 46   0.002251               Nuc_AreaShape_EquivalentDiameter_25%
# 47   0.002248     Nuc_Texture_InfoMeas1_Hematoxylin_3_03_256_75%
# 48   0.002247     Nuc_Texture_InfoMeas2_Hematoxylin_7_00_256_25%
# 49   0.002240  Nuc_Texture_AngularSecondMoment_Eosin_3_02_256...
# 50   0.002200             Nuc_Texture_Entropy_Eosin_5_01_256_50%
# 51   0.002198            Nuc_Texture_Entropy_Eosin_7_02_256_mean
# 52   0.002197     Nuc_Texture_InfoMeas1_Hematoxylin_3_03_256_50%
# 53   0.002191     Nuc_Texture_InfoMeas1_Hematoxylin_3_02_256_50%
# 54   0.002175       Nuc_Texture_Entropy_Hematoxylin_7_01_256_50%
# 55   0.002175     Nuc_Texture_InfoMeas1_Hematoxylin_5_02_256_25%
# 56   0.002157    Nuc_Texture_InfoMeas1_Hematoxylin_3_00_256_mean
# 57   0.002152    Nuc_Texture_InfoMeas1_Hematoxylin_3_02_256_mean
# 58   0.002149     Nuc_Texture_InfoMeas1_Hematoxylin_3_00_256_50%
# 59   0.002131                  Nuc_AreaShape_MinorAxisLength_50%
# 60   0.002111     Nuc_Texture_InfoMeas1_Hematoxylin_4_02_256_25%
# 61   0.002107  Nuc_Intensity_IntegratedIntensity_Hematoxylin_...
# 62   0.002100     Nuc_Texture_InfoMeas1_Hematoxylin_4_00_256_25%
# 63   0.002095     Nuc_Texture_InfoMeas2_Hematoxylin_5_01_256_25%
# 64   0.002064     Nuc_Texture_InfoMeas2_Hematoxylin_4_01_256_25%
# 65   0.002033     Nuc_Texture_Contrast_Hematoxylin_7_02_256_mean
# 66   0.002033     Nuc_Texture_InfoMeas2_Hematoxylin_3_01_256_75%
# 67   0.002024  Nuc_Texture_AngularSecondMoment_Eosin_5_03_256...
# 68   0.002015     Nuc_Texture_InfoMeas2_Hematoxylin_4_03_256_25%
# 69   0.001990     Nuc_Texture_InfoMeas2_Hematoxylin_5_02_256_25%
# 70   0.001973             Nuc_Texture_Entropy_Eosin_7_03_256_50%
# 71   0.001963     Nuc_Texture_InfoMeas2_Hematoxylin_5_02_256_50%
# 72   0.001961  Nuc_Texture_AngularSecondMoment_Eosin_4_00_256...
# 73   0.001950  Nuc_Texture_AngularSecondMoment_Eosin_7_03_256...
# 74   0.001932     Nuc_Texture_InfoMeas2_Hematoxylin_3_03_256_25%
# 75   0.001927  Nuc_Texture_AngularSecondMoment_Eosin_5_02_256...
# 76   0.001924     Nuc_Texture_InfoMeas2_Hematoxylin_3_03_256_50%
# 77   0.001905  Nuc_Texture_AngularSecondMoment_Eosin_4_02_256...
# 78   0.001884     Nuc_Texture_InfoMeas2_Hematoxylin_4_00_256_25%
# 79   0.001881            Nuc_Texture_Entropy_Eosin_5_00_256_mean
# 80   0.001879             Nuc_Texture_Entropy_Eosin_3_02_256_25%
# 81   0.001864      Nuc_Texture_Contrast_Hematoxylin_3_02_256_75%
# 82   0.001860             Nuc_Texture_Entropy_Eosin_5_01_256_25%
# 83   0.001854            Nuc_Texture_Entropy_Eosin_7_03_256_mean
# 84   0.001790  Nuc_Texture_AngularSecondMoment_Eosin_4_01_256...
# 85   0.001776                   Nuc_AreaShape_MaximumRadius_mean
# 86   0.001390          Nuc_Texture_SumAverage_Eosin_7_02_256_50%
# 87   0.001331                    Nuc_AreaShape_MaximumRadius_75%
# 88   0.001249                  Nuc_Granularity_3_Hematoxylin_25%
# 89   0.001244                  Nuc_Granularity_3_Hematoxylin_50%
# 90   0.001060         Nuc_Texture_SumAverage_Eosin_4_01_256_mean
# 91   0.001019          Nuc_Texture_SumAverage_Eosin_4_01_256_25%
# 92   0.001004          Nuc_Texture_SumAverage_Eosin_5_02_256_75%
# 93   0.000999                       Nuc_AreaShape_MeanRadius_75%
# 94   0.000992  Nuc_Texture_InverseDifferenceMoment_Hematoxyli...
# 95   0.000987                  Nuc_Granularity_3_Hematoxylin_max
# 96   0.000983        Nuc_Texture_Correlation_Eosin_3_00_256_mean
# 97   0.000977                     Nuc_AreaShape_MedianRadius_std
# 98   0.000955          Nuc_Texture_SumAverage_Eosin_5_02_256_25%
# 99   0.000948                             Nuc_AreaShape_Area_25%
# 100  0.000939         Nuc_Texture_Correlation_Eosin_3_00_256_50%

# %%
print(datetime.datetime.now())
joblib.dump(rf1.get_mode(),MODELS_DIR)
# Out:
# 2022-06-08 19:41:21.569472
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-debf4fcd6991> in <module>
#       1 print(datetime.datetime.now())
# ----> 2 joblib.dump(rf1.get_mode(),MODELS_DIR)
#
# AttributeError: 'RF_Util' object has no attribute 'get_mode'
