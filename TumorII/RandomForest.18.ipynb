# %% [markdown]
# # Random Forest
# Train on 6-class cancer classification.
# Input is the nucleus+RBC rollup, training set only.
# Train on one train/test split.
# Print the confusion matrix.

# %%
import datetime
print(datetime.datetime.now())
from platform import python_version
print('Python',python_version())
import numpy as np
import pandas as pd
import sklearn   # pip install --upgrade scikit-learn
print('sklearn',sklearn.__version__)
import tensorflow as tf
tf.config.list_physical_devices('GPU')
# Out:
# 2022-06-09 11:11:29.035383
# Python 3.8.10
# sklearn 1.0.2
# []

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.utils import shuffle
from sklearn.feature_selection import RFE
import joblib # used to dump/load sklearn models
from CellProfiler_Util import CP_Util
from RandomForestUtil import RF_Util

# %%
BASE_DIR='/home/jrm/Adjeroh/Naved/CP_80K/'  # append Output0/ etc
CLASSES=range(0,6)  # use all 6 classes
#CLASSES=[5]  # JUST FOR TESTING
MODELS_DIR='/home/jrm/Adjeroh/Naved/CP_80K/models/RandomForest.18'

# %%
print(datetime.datetime.now())
PREFIX='abc_'
def set_prefix(prefix):
    global PREFIX
    PREFIX=prefix
def get_prefix(col_name):
    global PREFIX
    return PREFIX+col_name  # hard coded for now
def load_all_classes():
    X = None
    y = None
    for i in CLASSES:
        print(datetime.datetime.now())
        print("Process class",i)
        FULL_PATH=BASE_DIR+'Output'+str(i)+'/'
        cp = CP_Util(FULL_PATH)
        cp.train_test_split()
        Xnuc = cp.get_nucleus_rollup()
        set_prefix('Nuc_')
        Xnuc.rename(get_prefix,axis='columns',inplace=True)
        Xrbc = cp.get_RBC_rollup()
        set_prefix('Rbc_')
        Xrbc.rename(get_prefix,axis='columns',inplace=True)
        Xi = Xnuc.join(Xrbc,how='outer')
        size = len(Xi)
        yi = np.ones(size) * i   # e.g. class 3
        if X is None:
            X = Xi
            y = yi
        else:
            X = pd.concat( (X,Xi) )
            y = np.concatenate( (y,yi) )
    X.fillna(0,inplace=True)  
    return X,y
Xtrain,ytrain=load_all_classes()
Xtrain
# Out:
# 2022-06-09 11:11:31.285508
# 2022-06-09 11:11:31.285724
# Process class 0
# Num tumors in test/train sets: 23 94
# Num patches in test/train sets: 8803 36163
# 2022-06-09 11:12:10.491577
# Process class 1
# Num tumors in test/train sets: 7 26
# Num patches in test/train sets: 2734 10168
# 2022-06-09 11:12:24.112251
# Process class 2
# Num tumors in test/train sets: 7 30
# Num patches in test/train sets: 2769 11181
# 2022-06-09 11:12:40.017765
# Process class 3
# Num tumors in test/train sets: 3 14
# Num patches in test/train sets: 1091 5273
# 2022-06-09 11:12:52.642467
# Process class 4
# Num tumors in test/train sets: 2 6
# Num patches in test/train sets: 813 2384
# 2022-06-09 11:12:59.958056
# Process class 5
# Num tumors in test/train sets: 1 3
# Num patches in test/train sets: 396 1195
#              Nuc_ObjectNumber_count  Nuc_ObjectNumber_mean  \
# PatchNumber
# 397                             7.0                    4.0
# 398                             1.0                    1.0
# 399                             1.0                    1.0
# 400                             4.0                    2.5
# 401                             4.0                    2.5
# ...                             ...                    ...
# 1587                            7.0                    4.0
# 1588                           17.0                    9.0
# 1589                           19.0                   10.0
# 1590                           33.0                   17.0
# 1591                            4.0                    2.5
#
#              Nuc_ObjectNumber_std  Nuc_ObjectNumber_min  Nuc_ObjectNumber_25%  \
# PatchNumber
# 397                      2.160247                   1.0                  2.50
# 398                      0.000000                   1.0                  1.00
# 399                      0.000000                   1.0                  1.00
# 400                      1.290994                   1.0                  1.75
# 401                      1.290994                   1.0                  1.75
# ...                           ...                   ...                   ...
# 1587                     2.160247                   1.0                  2.50
# 1588                     5.049752                   1.0                  5.00
# 1589                     5.627314                   1.0                  5.50
# 1590                     9.669540                   1.0                  9.00
# 1591                     1.290994                   1.0                  1.75
#
#              Nuc_ObjectNumber_50%  Nuc_ObjectNumber_75%  Nuc_ObjectNumber_max  \
# PatchNumber
# 397                           4.0                  5.50                   7.0
# 398                           1.0                  1.00                   1.0
# 399                           1.0                  1.00                   1.0
# 400                           2.5                  3.25                   4.0
# 401                           2.5                  3.25                   4.0
# ...                           ...                   ...                   ...
# 1587                          4.0                  5.50                   7.0
# 1588                          9.0                 13.00                  17.0
# 1589                         10.0                 14.50                  19.0
# 1590                         17.0                 25.00                  33.0
# 1591                          2.5                  3.25                   4.0
#
#              Nuc_AreaShape_Area_count  Nuc_AreaShape_Area_mean  ...  \
# PatchNumber                                                     ...
# 397                               7.0               216.000000  ...
# 398                               1.0               200.000000  ...
# 399                               1.0               181.000000  ...
# 400                               4.0               239.250000  ...
# 401                               4.0               237.500000  ...
# ...                               ...                      ...  ...
# 1587                              7.0               368.285714  ...
# 1588                             17.0               519.352941  ...
# 1589                             19.0               388.315789  ...
# 1590                             33.0               444.454545  ...
# 1591                              4.0               514.500000  ...
#
#              Rbc_Number_Object_Number_75%  Rbc_Number_Object_Number_max  \
# PatchNumber
# 397                                  0.00                           0.0
# 398                                  0.00                           0.0
# 399                                  0.00                           0.0
# 400                                  0.00                           0.0
# 401                                  0.00                           0.0
# ...                                   ...                           ...
# 1587                                 0.00                           0.0
# 1588                                 0.00                           0.0
# 1589                                 1.75                           2.0
# 1590                                 0.00                           0.0
# 1591                                 0.00                           0.0
#
#              Rbc_Parent_ShrinkRBC_count  Rbc_Parent_ShrinkRBC_mean  \
# PatchNumber
# 397                                 0.0                        0.0
# 398                                 0.0                        0.0
# 399                                 0.0                        0.0
# 400                                 0.0                        0.0
# 401                                 0.0                        0.0
# ...                                 ...                        ...
# 1587                                0.0                        0.0
# 1588                                0.0                        0.0
# 1589                                2.0                        1.5
# 1590                                0.0                        0.0
# 1591                                0.0                        0.0
#
#              Rbc_Parent_ShrinkRBC_std  Rbc_Parent_ShrinkRBC_min  \
# PatchNumber
# 397                          0.000000                       0.0
# 398                          0.000000                       0.0
# 399                          0.000000                       0.0
# 400                          0.000000                       0.0
# 401                          0.000000                       0.0
# ...                               ...                       ...
# 1587                         0.000000                       0.0
# 1588                         0.000000                       0.0
# 1589                         0.707107                       1.0
# 1590                         0.000000                       0.0
# 1591                         0.000000                       0.0
#
#              Rbc_Parent_ShrinkRBC_25%  Rbc_Parent_ShrinkRBC_50%  \
# PatchNumber
# 397                              0.00                       0.0
# 398                              0.00                       0.0
# 399                              0.00                       0.0
# 400                              0.00                       0.0
# 401                              0.00                       0.0
# ...                               ...                       ...
# 1587                             0.00                       0.0
# 1588                             0.00                       0.0
# 1589                             1.25                       1.5
# 1590                             0.00                       0.0
# 1591                             0.00                       0.0
#
#              Rbc_Parent_ShrinkRBC_75%  Rbc_Parent_ShrinkRBC_max
# PatchNumber
# 397                              0.00                       0.0
# 398                              0.00                       0.0
# 399                              0.00                       0.0
# 400                              0.00                       0.0
# 401                              0.00                       0.0
# ...                               ...                       ...
# 1587                             0.00                       0.0
# 1588                             0.00                       0.0
# 1589                             1.75                       2.0
# 1590                             0.00                       0.0
# 1591                             0.00                       0.0
#
# [66182 rows x 6392 columns]

# %%
print(datetime.datetime.now())
print("Shuffle...")
Xtrain,ytrain=shuffle(Xtrain,ytrain)  #set random_state for reproducibility
# Out:
# 2022-06-09 11:13:20.088449
# Shuffle...

# %%
print(datetime.datetime.now())
print('Do a one-time train/valid split...')
Xt,Xv,yt,yv = train_test_split(Xtrain, ytrain.ravel()) 
        # ,random_state=42) # add this for reproducibility
Xtrain=None
Ytrain=None
print(datetime.datetime.now())
print('Do a one-time fit and evaluate...')
rf1 = RF_Util()
rf1.set_train(Xt,yt)
rf1.set_validation(Xv,yv)
rf1.fit()
print(datetime.datetime.now())
print('Accuracy:',rf1.validation_accuracy())
print('Confusion:')
print(rf1.validation_confusion())
# Out:
# 2022-06-09 11:13:21.980248
# Do a one-time train/valid split...
# 2022-06-09 11:13:57.667147
# Do a one-time fit and evaluate...
# 2022-06-09 11:19:44.477881
# Accuracy: 80.82315967605463
# Confusion:
# [[8672  130  147   35    1    2]
#  [ 304 1732  408   64    9    2]
#  [ 281  400 2008   60   19   21]
#  [ 162  274  301  584    4    0]
#  [  78  117  179   26  225    2]
#  [  51   41   49    6    0  152]]

# %%
print('Rank the features by importance.')
top = rf1.important_features()
pd.set_option('display.max_rows', None)
top.loc[:200]
# Out:
# Rank the features by importance.
#             0                                                  1
# 0    0.010052                    Nuc_AreaShape_MaximumRadius_75%
# 1    0.006728                 Nuc_AreaShape_MinorAxisLength_mean
# 2    0.006388     Nuc_Texture_InfoMeas1_Hematoxylin_7_00_256_25%
# 3    0.006382    Nuc_Texture_InfoMeas1_Hematoxylin_3_02_256_mean
# 4    0.006200                       Nuc_AreaShape_MeanRadius_50%
# 5    0.006186     Nuc_Texture_InfoMeas1_Hematoxylin_4_02_256_25%
# 6    0.005721                     Nuc_AreaShape_MedianRadius_75%
# 7    0.005498                      Nuc_AreaShape_MeanRadius_mean
# 8    0.004916     Nuc_Texture_InfoMeas1_Hematoxylin_7_00_256_50%
# 9    0.004796     Nuc_Texture_InfoMeas1_Hematoxylin_4_03_256_50%
# 10   0.004707    Nuc_Texture_InfoMeas1_Hematoxylin_5_03_256_mean
# 11   0.004701    Nuc_Texture_InfoMeas1_Hematoxylin_7_02_256_mean
# 12   0.004653                   Nuc_AreaShape_MaximumRadius_mean
# 13   0.004612     Nuc_Texture_InfoMeas1_Hematoxylin_7_03_256_25%
# 14   0.004456     Nuc_Texture_InfoMeas1_Hematoxylin_7_02_256_25%
# 15   0.004422     Nuc_Texture_InfoMeas1_Hematoxylin_7_01_256_75%
# 16   0.004399     Nuc_Texture_InfoMeas1_Hematoxylin_4_03_256_75%
# 17   0.004266     Nuc_Texture_InfoMeas1_Hematoxylin_4_02_256_50%
# 18   0.004085     Nuc_Texture_InfoMeas2_Hematoxylin_7_02_256_50%
# 19   0.003753                       Nuc_AreaShape_MeanRadius_75%
# 20   0.003154                    Nuc_AreaShape_MaximumRadius_50%
# 21   0.003064     Nuc_Texture_InfoMeas1_Hematoxylin_7_03_256_50%
# 22   0.002841     Nuc_Texture_InfoMeas1_Hematoxylin_7_01_256_50%
# 23   0.002803     Nuc_Texture_InfoMeas1_Hematoxylin_4_01_256_50%
# 24   0.002744                    Nuc_AreaShape_MedianRadius_mean
# 25   0.002623    Nuc_Texture_InfoMeas1_Hematoxylin_7_01_256_mean
# 26   0.002608     Nuc_Texture_InfoMeas1_Hematoxylin_7_02_256_50%
# 27   0.002466  Nuc_Texture_AngularSecondMoment_Eosin_5_00_256...
# 28   0.002410     Nuc_Texture_InfoMeas1_Hematoxylin_4_00_256_50%
# 29   0.002400    Nuc_Texture_InfoMeas1_Hematoxylin_7_03_256_mean
# 30   0.002400    Nuc_Texture_InfoMeas1_Hematoxylin_7_00_256_mean
# 31   0.002395      Nuc_Texture_Contrast_Hematoxylin_3_01_256_max
# 32   0.002390     Nuc_Texture_InfoMeas1_Hematoxylin_5_03_256_50%
# 33   0.002372    Nuc_Texture_InfoMeas1_Hematoxylin_5_00_256_mean
# 34   0.002372     Nuc_Texture_InfoMeas1_Hematoxylin_3_03_256_75%
# 35   0.002371               Nuc_AreaShape_EquivalentDiameter_25%
# 36   0.002333     Nuc_Texture_InfoMeas1_Hematoxylin_5_01_256_25%
# 37   0.002290    Nuc_Texture_InfoMeas1_Hematoxylin_4_01_256_mean
# 38   0.002285     Nuc_Texture_InfoMeas2_Hematoxylin_5_03_256_50%
# 39   0.002256             Nuc_Texture_Entropy_Eosin_3_03_256_50%
# 40   0.002253     Nuc_Texture_InfoMeas1_Hematoxylin_5_00_256_50%
# 41   0.002218     Nuc_Texture_InfoMeas1_Hematoxylin_3_03_256_50%
# 42   0.002212     Nuc_Texture_InfoMeas1_Hematoxylin_7_00_256_75%
# 43   0.002188             Nuc_Texture_Entropy_Eosin_5_02_256_50%
# 44   0.002184                             Nuc_AreaShape_Area_50%
# 45   0.002173  Nuc_Intensity_IntegratedIntensity_Hematoxylin_50%
# 46   0.002155  Nuc_Intensity_IntegratedIntensity_Hematoxylin_25%
# 47   0.002149  Nuc_Intensity_IntegratedIntensity_Hematoxylin_...
# 48   0.002146                       Nuc_AreaShape_ConvexArea_25%
# 49   0.002142     Nuc_Texture_InfoMeas2_Hematoxylin_5_03_256_25%
# 50   0.002140      Nuc_Texture_Contrast_Hematoxylin_4_03_256_max
# 51   0.002140                 Nuc_Granularity_3_Hematoxylin_mean
# 52   0.002108     Nuc_Texture_InfoMeas1_Hematoxylin_4_00_256_75%
# 53   0.002107    Nuc_Texture_InfoMeas1_Hematoxylin_3_01_256_mean
# 54   0.002075  Nuc_Texture_AngularSecondMoment_Eosin_4_01_256...
# 55   0.002070             Nuc_Texture_Entropy_Eosin_4_03_256_50%
# 56   0.002061     Nuc_Texture_InfoMeas1_Hematoxylin_3_00_256_75%
# 57   0.002050     Nuc_Texture_InfoMeas2_Hematoxylin_5_00_256_50%
# 58   0.002045             Nuc_Texture_Entropy_Eosin_5_03_256_50%
# 59   0.002038     Nuc_Texture_InfoMeas1_Hematoxylin_3_00_256_25%
# 60   0.002029       Nuc_Texture_Entropy_Hematoxylin_7_02_256_25%
# 61   0.002023      Nuc_Texture_Entropy_Hematoxylin_7_03_256_mean
# 62   0.002017     Nuc_Texture_InfoMeas2_Hematoxylin_4_03_256_25%
# 63   0.002011  Nuc_Texture_AngularSecondMoment_Eosin_3_03_256...
# 64   0.002008                  Nuc_Granularity_3_Hematoxylin_75%
# 65   0.002001     Nuc_Texture_InfoMeas2_Hematoxylin_4_01_256_25%
# 66   0.001994     Nuc_Texture_InfoMeas2_Hematoxylin_3_03_256_25%
# 67   0.001949  Nuc_Texture_AngularSecondMoment_Eosin_3_03_256...
# 68   0.001941            Nuc_Texture_Entropy_Eosin_5_03_256_mean
# 69   0.001940            Nuc_Texture_Entropy_Eosin_3_00_256_mean
# 70   0.001938            Nuc_Texture_Entropy_Eosin_5_01_256_mean
# 71   0.001935              Nuc_AreaShape_EquivalentDiameter_mean
# 72   0.001925             Nuc_Texture_Entropy_Eosin_7_02_256_25%
# 73   0.001898                Nuc_AreaShape_MinFeretDiameter_mean
# 74   0.001892     Nuc_Texture_InfoMeas2_Hematoxylin_4_00_256_50%
# 75   0.001859       Nuc_Texture_Entropy_Hematoxylin_7_01_256_25%
# 76   0.001850  Nuc_Texture_AngularSecondMoment_Eosin_5_02_256...
# 77   0.001740     Nuc_Texture_InfoMeas2_Hematoxylin_3_02_256_25%
# 78   0.001656  Nuc_Texture_AngularSecondMoment_Hematoxylin_5_...
# 79   0.001340                  Nuc_Granularity_3_Hematoxylin_50%
# 80   0.001184        Nuc_Texture_Correlation_Eosin_3_00_256_mean
# 81   0.001175          Nuc_Texture_SumAverage_Eosin_5_03_256_50%
# 82   0.001120      Nuc_Texture_Contrast_Hematoxylin_5_01_256_max
# 83   0.001108       Nuc_AreaShape_InertiaTensorEigenvalues_1_25%
# 84   0.001106     Nuc_Texture_Contrast_Hematoxylin_5_01_256_mean
# 85   0.001067         Nuc_Texture_SumAverage_Eosin_3_02_256_mean
# 86   0.001037          Nuc_Texture_SumAverage_Eosin_7_01_256_75%
# 87   0.001028          Nuc_Texture_SumAverage_Eosin_4_01_256_25%
# 88   0.001019         Nuc_Texture_SumAverage_Eosin_5_01_256_mean
# 89   0.001012          Nuc_Texture_SumAverage_Eosin_3_00_256_50%
# 90   0.000994          Nuc_Texture_SumAverage_Eosin_7_02_256_25%
# 91   0.000992          Nuc_Texture_SumAverage_Eosin_7_00_256_50%
# 92   0.000989          Nuc_Texture_SumAverage_Eosin_5_01_256_50%
# 93   0.000971         Nuc_Texture_SumAverage_Eosin_4_03_256_mean
# 94   0.000951          Nuc_Texture_SumAverage_Eosin_7_03_256_75%
# 95   0.000944      Nuc_Texture_Variance_Hematoxylin_5_03_256_max
# 96   0.000936                  Nuc_Granularity_3_Hematoxylin_max
# 97   0.000911          Nuc_Texture_SumAverage_Eosin_5_03_256_25%
# 98   0.000876          Nuc_Texture_SumAverage_Eosin_3_02_256_25%
# 99   0.000870          Nuc_Texture_SumAverage_Eosin_4_00_256_25%
# 100  0.000867          Nuc_Texture_SumAverage_Eosin_7_02_256_50%
# 101  0.000856         Nuc_Texture_Correlation_Eosin_3_00_256_25%
# 102  0.000853         Nuc_Texture_Correlation_Eosin_3_00_256_75%
# 103  0.000840          Nuc_Texture_SumAverage_Eosin_3_02_256_50%
# 104  0.000837          Nuc_Texture_SumAverage_Eosin_3_01_256_25%
# 105  0.000823         Nuc_Texture_Correlation_Eosin_3_00_256_50%
# 106  0.000807          Nuc_Texture_SumAverage_Eosin_7_00_256_75%
# 107  0.000800  Nuc_Texture_AngularSecondMoment_Eosin_4_01_256...
# 108  0.000797          Nuc_Texture_SumAverage_Eosin_4_03_256_50%
# 109  0.000796                  Nuc_Granularity_1_Hematoxylin_max
# 110  0.000792          Nuc_Texture_SumAverage_Eosin_5_02_256_75%
# 111  0.000787                 Nuc_AreaShape_MinFeretDiameter_50%
# 112  0.000773  Nuc_Texture_AngularSecondMoment_Eosin_3_02_256...
# 113  0.000770  Nuc_RadialDistribution_MeanFrac_Hematoxylin_2o...
# 114  0.000768                 Nuc_AreaShape_MinFeretDiameter_25%
# 115  0.000764          Nuc_Texture_SumAverage_Eosin_3_00_256_75%
# 116  0.000763                  Nuc_Granularity_3_Hematoxylin_25%
# 117  0.000761         Nuc_Texture_SumAverage_Eosin_3_03_256_mean
# 118  0.000755         Nuc_Texture_SumAverage_Eosin_4_00_256_mean
# 119  0.000753          Nuc_Texture_SumAverage_Eosin_3_02_256_75%
# 120  0.000749         Nuc_Texture_SumAverage_Eosin_7_01_256_mean
# 121  0.000741          Nuc_Texture_SumAverage_Eosin_5_00_256_50%
# 122  0.000733                  Nuc_Granularity_3_Hematoxylin_std
# 123  0.000731         Nuc_Texture_SumAverage_Eosin_7_03_256_mean
# 124  0.000728                  Nuc_AreaShape_MinorAxisLength_25%
# 125  0.000720         Nuc_Texture_SumAverage_Eosin_7_00_256_mean
# 126  0.000718         Nuc_Texture_SumAverage_Eosin_7_02_256_mean
# 127  0.000712          Nuc_Texture_SumAverage_Eosin_3_03_256_75%
# 128  0.000708         Nuc_Texture_SumAverage_Eosin_3_00_256_mean
# 129  0.000698          Nuc_Texture_SumAverage_Eosin_7_00_256_25%
# 130  0.000698                         Nuc_AreaShape_Solidity_75%
# 131  0.000695          Nuc_Texture_SumAverage_Eosin_5_01_256_75%
# 132  0.000693          Nuc_Texture_SumAverage_Eosin_5_02_256_50%
# 133  0.000692                Nuc_AreaShape_CentralMoment_0_0_25%
# 134  0.000690          Nuc_Texture_SumAverage_Eosin_7_01_256_25%
# 135  0.000683         Nuc_Texture_SumAverage_Eosin_5_03_256_mean
# 136  0.000677          Nuc_Texture_SumAverage_Eosin_3_03_256_25%
# 137  0.000668         Nuc_Intensity_MaxIntensity_Hematoxylin_75%
# 138  0.000664                  Nuc_Granularity_4_Hematoxylin_std
# 139  0.000661          Nuc_Texture_SumAverage_Eosin_3_03_256_50%
# 140  0.000659          Nuc_Texture_SumAverage_Eosin_4_01_256_50%
# 141  0.000659          Nuc_Texture_SumAverage_Eosin_5_02_256_25%
# 142  0.000658         Nuc_Texture_SumAverage_Eosin_4_02_256_mean
# 143  0.000651                         Nuc_AreaShape_Solidity_50%
# 144  0.000651  Nuc_Texture_InverseDifferenceMoment_Hematoxyli...
# 145  0.000646          Nuc_Texture_SumAverage_Eosin_3_01_256_75%
# 146  0.000644          Nuc_Texture_SumAverage_Eosin_4_01_256_75%
# 147  0.000642  Nuc_Neighbors_SecondClosestDistance_Expanded_mean
# 148  0.000641          Nuc_Texture_SumAverage_Eosin_3_01_256_50%
# 149  0.000641     Nuc_Texture_InfoMeas1_Hematoxylin_7_02_256_75%
# 150  0.000633                Nuc_AreaShape_CentralMoment_0_0_50%
# 151  0.000632     Nuc_Texture_InfoMeas1_Hematoxylin_5_00_256_25%
# 152  0.000631     Nuc_Texture_InfoMeas1_Hematoxylin_7_01_256_25%
# 153  0.000627         Nuc_Texture_SumAverage_Eosin_3_01_256_mean
# 154  0.000627          Nuc_Texture_SumAverage_Eosin_7_01_256_50%
# 155  0.000623          Nuc_Texture_SumAverage_Eosin_4_03_256_75%
# 156  0.000622          Nuc_Texture_SumAverage_Eosin_5_00_256_25%
# 157  0.000616         Nuc_Texture_SumAverage_Eosin_5_02_256_mean
# 158  0.000611          Nuc_Texture_SumAverage_Eosin_5_03_256_75%
# 159  0.000609  Nuc_RadialDistribution_MeanFrac_Hematoxylin_2o...
# 160  0.000603                             Nuc_AreaShape_Area_25%
# 161  0.000602                  Nuc_Granularity_1_Hematoxylin_50%
# 162  0.000600          Nuc_Texture_SumAverage_Eosin_7_03_256_50%
# 163  0.000600          Nuc_Texture_SumAverage_Eosin_5_01_256_25%
# 164  0.000599          Nuc_Texture_SumAverage_Eosin_4_02_256_25%
# 165  0.000598                  Nuc_Granularity_1_Hematoxylin_25%
# 166  0.000597     Nuc_Texture_InfoMeas2_Hematoxylin_5_02_256_75%
# 167  0.000597  Nuc_RadialDistribution_MeanFrac_Hematoxylin_3o...
# 168  0.000592          Nuc_Texture_SumAverage_Eosin_4_02_256_min
# 169  0.000591       Nuc_AreaShape_InertiaTensorEigenvalues_1_50%
# 170  0.000586    Nuc_Texture_InfoMeas1_Hematoxylin_4_03_256_mean
# 171  0.000585     Nuc_Texture_InfoMeas1_Hematoxylin_5_01_256_50%
# 172  0.000581     Nuc_Texture_InfoMeas1_Hematoxylin_4_00_256_25%
# 173  0.000576  Nuc_RadialDistribution_RadialCV_Hematoxylin_1o...
# 174  0.000573  Nuc_Texture_DifferenceVariance_Eosin_3_00_256_...
# 175  0.000571          Nuc_Texture_SumAverage_Eosin_4_00_256_50%
# 176  0.000571          Nuc_Texture_SumAverage_Eosin_3_00_256_25%
# 177  0.000569         Nuc_Texture_SumAverage_Eosin_5_00_256_mean
# 178  0.000567        Nuc_Intensity_MeanIntensity_Hematoxylin_25%
# 179  0.000561          Nuc_Texture_SumAverage_Eosin_4_02_256_75%
# 180  0.000560      Nuc_Texture_Contrast_Hematoxylin_3_00_256_max
# 181  0.000555  Nuc_Texture_InverseDifferenceMoment_Hematoxyli...
# 182  0.000551      Nuc_Texture_Variance_Hematoxylin_3_03_256_max
# 183  0.000551         Nuc_Texture_SumAverage_Eosin_4_01_256_mean
# 184  0.000550          Nuc_Texture_SumAverage_Eosin_7_03_256_25%
# 185  0.000549      Nuc_Texture_Variance_Hematoxylin_5_01_256_75%
# 186  0.000548  Nuc_Texture_AngularSecondMoment_Hematoxylin_7_...
# 187  0.000547     Nuc_Texture_InfoMeas1_Hematoxylin_5_00_256_75%
# 188  0.000545      Nuc_Texture_Contrast_Hematoxylin_5_01_256_75%
# 189  0.000545     Nuc_Texture_InfoMeas1_Hematoxylin_5_02_256_50%
# 190  0.000544       Nuc_Texture_Entropy_Hematoxylin_7_02_256_50%
# 191  0.000544          Nuc_Texture_SumEntropy_Eosin_7_01_256_50%
# 192  0.000543         Nuc_Intensity_MaxIntensity_Hematoxylin_max
# 193  0.000543      Nuc_Texture_Contrast_Hematoxylin_4_00_256_max
# 194  0.000542      Nuc_Texture_Contrast_Hematoxylin_3_02_256_max
# 195  0.000539          Nuc_Texture_SumAverage_Eosin_4_03_256_25%
# 196  0.000528          Nuc_Texture_SumAverage_Eosin_3_02_256_min
# 197  0.000521          Nuc_Texture_SumAverage_Eosin_5_00_256_75%
# 198  0.000521   Nuc_Neighbors_SecondClosestDistance_Expanded_50%
# 199  0.000520          Nuc_Texture_SumAverage_Eosin_4_00_256_75%
# 200  0.000518     Nuc_Texture_InfoMeas2_Hematoxylin_3_00_256_50%

# %%
print(datetime.datetime.now())
joblib.dump(rf1.get_model(),MODELS_DIR)
# Out:
# 2022-06-09 11:25:06.276193
# ['/home/jrm/Adjeroh/Naved/CP_80K/models/RandomForest.18']
