# %% [markdown]
# # Random Forest
# Train again. This time use all the patches (don't save memory) and more trees.
#
# No improvement to accuracy.

# %%
MAX_DEPTH = 8
N_ESTIMATORS = 1000
CHOOSE_EVERY = 1   # also redundantly set save_mem to False below
SAVE_MEM = False

# %%
# if you run this again, fix import datetime

# %%
from datetime import datetime
print(datetime.now())
from platform import python_version
print('Python',python_version())
import csv
import numpy as np
import pandas as pd
import matplotlib as plt
import random
import sklearn   # pip install --upgrade scikit-learn
print('sklearn',sklearn.__version__)
# The model
from sklearn.ensemble import RandomForestClassifier
# Out:
# 2022-08-01 16:56:05.038648
# Python 3.8.10
# sklearn 1.0.2

# %%
# Patch data.
# This is the patch-level csv file: one row per patch, with nucleus totals from CellProfiler.
FILENAME='Process100_Image.csv'
# This directory contains one Image.csv file per patient.
# These csv files were slimmed to remove give-away columns.
# These csv files do contain high-RBC patches; consider filtering them.
BASE_PATH='/home/jrm/Adjeroh/Glioma/August_Run/CellProfilerPerPatient/'  # alien

# Patient data.
# Each patch filename indicates patient/case [0:19] and WSI [0:23].
# For example: TCGA-06-0129-01Z-00-DX1_5400_5100.png
LEN_PATIENT_ID = 19
FOLDS_META_FILE = '/home/jrm/Adjeroh/Glioma/August_Run/TrainValidSplits/aug_train_valid_splits.csv'
NUM_FOLDS = 5

# %% [markdown]
# ## Data loading functions

# %%
METADATA = pd.read_csv(FOLDS_META_FILE)
METADATA
# Out:
#      Fold  Split                 Case  Class
# 0       0  Train  TCGA-02-0004-01Z-00      0
# 1       0  Train  TCGA-02-0010-01Z-00      0
# 2       0  Train  TCGA-14-0789-01Z-00      0
# 3       0  Train  TCGA-02-0025-01Z-00      0
# 4       0  Train  TCGA-02-0033-01Z-00      0
# ..    ...    ...                  ...    ...
# 630     4  Valid  TCGA-S9-A7J2-01Z-00      5
# 631     4  Valid  TCGA-02-0430-01Z-00      0
# 632     4  Valid  TCGA-28-1746-01Z-00      0
# 633     4  Valid  TCGA-HT-7676-01Z-00      1
# 634     4  Valid  TCGA-CS-5397-01Z-00      3
#
# [635 rows x 4 columns]

# %%
def get_metadata_one_fold(fold,is_train):
    df = METADATA.loc[METADATA['Fold']==fold]
    if is_train:
        df = df.loc[df['Split']=='Train']
    else:
        df = df.loc[df['Split']=='Valid']
    patients = df['Case'].tolist()
    labels = df['Class'].tolist()
    return patients,labels

# %%
# Given a patient name, load the Image.csv file.
# Expect a string that matches a directory name, like 'TCGA-S9-A6UB-01Z-00'
# Returns a numpy array.
def load_one_patient_data(filepath):
    # Reading csv file, skip row 1 = column headers
    ary = np.loadtxt(filepath,skiprows=1,delimiter=',')
    return ary

# %%
def load_all_patients_data(patients,labels,save_mem=False):
    X = None  # dataframe with 5000 feature columns, one row per patch
    y = None  # list of labels = cancer class for each row
    z = None  # list of patient name for each row
    count=0
    for patient in patients:
        label = labels[count]
        count += 1
        directory = patient+'/'
        filepath=BASE_PATH+directory+FILENAME
        Xall = load_one_patient_data(filepath)
        if (save_mem):
            Xi = Xall[0::CHOOSE_EVERY].copy()  # e.g. choose every tenth patch
        else:
            Xi = Xall
        yi = np.full(shape=len(Xi), fill_value=label, dtype=np.int8)
        zi = [patient]*len(Xi)  # same ID for all patches from one patient
        if X is None:
            X = Xi
            y = yi
            z = zi
        else:
            X = np.concatenate( (X, Xi) )
            y = np.concatenate( (y, yi) )
            z = np.concatenate( (z, zi) )
    # X combines all patches of all WSI for all patients requested.
    # For debugging, we'll add column headers to the dataframe.
    X = pd.DataFrame(X)
    directory = patients[0] + '/'   # first patient is as good as any
    filepath=BASE_PATH+directory+FILENAME
    with open(filepath) as infile:
        rows = csv.reader(infile)
        for row in rows:
            header = row    # first row has column headers
            break
    X.columns = header
    if 'ImageNumber' in X.columns:
        X = X.drop(columns=['ImageNumber'])
    return X,y,z   # patch data, patch labels, patch patient names

# %%
# This is slow, probably due to concatenating dataframes.
# Consider a rewrite that concatenates csv before constructing a dataframe.
def load_train_valid_set(fold):
    patients,labels = get_metadata_one_fold(fold,True) # True=train
    X_train,y_train,z_train = load_all_patients_data(patients,labels,SAVE_MEM) 
    print('Train lengths X,y,z:',X_train.shape,len(y_train),len(z_train))
    patients,labels = get_metadata_one_fold(fold,False) # False=valid
    X_valid,y_valid,z_valid = load_all_patients_data(patients,labels,False) # should be always False
    print('Valid lengths X,y,z:',X_valid.shape,len(y_valid),len(z_valid))
    return X_train,y_train,z_train,X_valid,y_valid,z_valid

# %% [markdown]
# ## Aggregation functions

# %%
# Each patch votes on the class for its WSI.
# Later, weight each patch label by the confidence i.e. score
def aggregate_accuracy(y_pred,y_valid,z_valid):
    L = len(y_pred)
    if L != len(y_valid) or L != len(z_valid):
        raise Exception('Lengths do not match')
    correct = {}
    incorrect = {}
    patients = np.unique(z_valid)
    for patient in patients:
        correct[patient]=0  # accumulate correct votes on patches
        incorrect[patient]=0  # accumulate incorrect votes
    for i in range(L):
        patient = z_valid[i]
        label =   y_valid[i]
        pred =    y_pred[i]
        if pred == label:
            correct[patient] += 1
        else:
            incorrect[patient] += 1
    numerator = 0
    denominator = 0
    for patient in patients:
        denominator += 1
        if correct[patient]>incorrect[patient]:
            numerator += 1
    accuracy = float(0)
    if denominator>0:
        accuracy = 100.0*numerator/denominator 
    return accuracy

# %% [markdown]
# ## Main loop: Load, Classify, Report

# %%
def important_features(model):
        # Prereqs: fit().
        names = model.feature_names_in_
        importances = model.feature_importances_
        pairs = np.column_stack( (names,importances) )
        top_array = sorted(pairs, key = lambda e:e[1], reverse=True)
        # There must be a way to do this witout a loop!
        top_list = []
        for i in top_array:
             top_list.append((i[1],i[0]))  # 0=feature_name, 1=importance
        top_df = pd.DataFrame(top_list)
        return top_df

# %%
patch_accuracies = []   # summary statistics
patient_accuracies = [] # summary statistics

for fold in range(NUM_FOLDS):
    print()
    print(datetime.now(),'Fold',fold,'Loading...')
    X_train,y_train,z_train,X_valid,y_valid,z_valid = load_train_valid_set(fold)    

    # The shuffle is not strictly necessary with RF.
    # CNN models are sensitive to train set order but RF models are not. 
    # print(datetime.now(),'Shuffle...')
    # X_train,y_train = sklearn.shuffle(X_train,y_train)

    print(datetime.now(),'Fold',fold,'Train...')
    # min_samples_leaf=1 (default) led to overfitting
    rfc = RandomForestClassifier(max_depth=MAX_DEPTH,n_estimators=N_ESTIMATORS)
    rfc.fit(X_train,y_train)  # slow
    
    print(datetime.now(),'Fold',fold,'Ranked feature imporances...')
    top = important_features(rfc)
    #pd.set_option('display.max_rows', None)
    print(top.loc[:10])
    
    print(datetime.now(),'Fold',fold,'Evaluate...')
    y_pred = rfc.predict(X_train)
    matches = np.count_nonzero(y_train==y_pred)
    accuracy_t = 100.0 * matches / len(y_pred)
    print('Fold',fold,'Patch-level Training Accuracy:',accuracy_t)
    
    print(datetime.now(),'Fold',fold,'Validate...')
    y_pred = rfc.predict(X_valid)
    matches = np.count_nonzero(y_valid==y_pred)
    accuracy_v = 100.0 * matches / len(y_pred)
    print('Fold',fold,'Patch-level Validation Accuracy:',accuracy_v)
    patch_accuracies.append(accuracy_v)
    
    accuracy_p = aggregate_accuracy(y_pred,y_valid,z_valid)
    patient_accuracies.append(accuracy_p)
    print('Fold',fold,'Patient-level Validation Accuracy:',accuracy_p)
    
    # This shouldn't be necessary but it seems to reduce memory footprint.
    X_train=None
    X_valid=None
    y_train=None
    y_valid=None
    z_train=None
    z_valid=None
    rfc = None
    y_pred = None
    matches = None
# Out:
# 2022-08-01 16:56:05.639829 Fold 0 Loading...
# Train lengths X,y,z: (75448, 5301) 75448 75448
# Valid lengths X,y,z: (15500, 5301) 15500 15500
# 2022-08-01 16:58:13.199773 Fold 0 Train...
# 2022-08-01 17:29:50.112231 Fold 0 Ranked feature imporances...
#            0                                                  1
# 0   0.012647                  Mean_Nucleus_AreaShape_MeanRadius
# 1   0.011271                Median_Nucleus_AreaShape_MeanRadius
# 2   0.009873              Median_Nucleus_AreaShape_MedianRadius
# 3   0.008909  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_5...
# 4   0.008592  Median_Nucleus_AreaShape_InertiaTensorEigenval...
# 5   0.008142                      Median_Nucleus_AreaShape_Area
# 6   0.008102             Median_Nucleus_AreaShape_MaximumRadius
# 7   0.007765           Median_Nucleus_AreaShape_MinorAxisLength
# 8   0.007394               Mean_Nucleus_AreaShape_MaximumRadius
# 9   0.007370  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_5_0...
# 10  0.007251  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_5...
# 2022-08-01 17:29:50.247192 Fold 0 Evaluate...
# Fold 0 Patch-level Training Accuracy: 74.56526349273672
# 2022-08-01 17:30:00.898767 Fold 0 Validate...
# Fold 0 Patch-level Validation Accuracy: 55.10322580645161
# Fold 0 Patient-level Validation Accuracy: 42.30769230769231
#
# 2022-08-01 17:30:03.024294 Fold 1 Loading...
# Train lengths X,y,z: (64485, 5301) 64485 64485
# Valid lengths X,y,z: (26463, 5301) 26463 26463
# 2022-08-01 17:31:56.973187 Fold 1 Train...
# 2022-08-01 17:58:51.107978 Fold 1 Ranked feature imporances...
#            0                                                  1
# 0   0.012993                  Mean_Nucleus_AreaShape_MeanRadius
# 1   0.011044                Median_Nucleus_AreaShape_MeanRadius
# 2   0.010150              Median_Nucleus_AreaShape_MedianRadius
# 3   0.010129               Mean_Nucleus_AreaShape_MaximumRadius
# 4   0.009796                Mean_Nucleus_AreaShape_MedianRadius
# 5   0.009393             Median_Nucleus_AreaShape_MaximumRadius
# 6   0.009083  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_3...
# 7   0.009068           Median_Nucleus_AreaShape_MinorAxisLength
# 8   0.008945  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_5_0...
# 9   0.007757  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_5...
# 10  0.007646  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_5...
# 2022-08-01 17:58:51.210776 Fold 1 Evaluate...
# Fold 1 Patch-level Training Accuracy: 76.20376831821353
# 2022-08-01 17:59:00.444914 Fold 1 Validate...
# Fold 1 Patch-level Validation Accuracy: 57.5104863394173
# Fold 1 Patient-level Validation Accuracy: 26.923076923076923
#
# 2022-08-01 17:59:04.362964 Fold 2 Loading...
# Train lengths X,y,z: (71643, 5301) 71643 71643
# Valid lengths X,y,z: (19305, 5301) 19305 19305
# 2022-08-01 18:01:05.257250 Fold 2 Train...
# 2022-08-01 18:30:47.286653 Fold 2 Ranked feature imporances...
#            0                                                  1
# 0   0.010670                Mean_Nucleus_AreaShape_MedianRadius
# 1   0.010228  Median_Nucleus_AreaShape_InertiaTensorEigenval...
# 2   0.009841             Median_Nucleus_AreaShape_MaximumRadius
# 3   0.009474                  Mean_Nucleus_AreaShape_MeanRadius
# 4   0.008071           Median_Nucleus_AreaShape_MinorAxisLength
# 5   0.008055                Median_Nucleus_AreaShape_MeanRadius
# 6   0.007428              Median_Nucleus_AreaShape_MedianRadius
# 7   0.007345               Mean_Nucleus_AreaShape_MaximumRadius
# 8   0.007213  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_7...
# 9   0.007054          Median_Nucleus_AreaShape_MinFeretDiameter
# 10  0.006997  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_7...
# 2022-08-01 18:30:47.437055 Fold 2 Evaluate...
# Fold 2 Patch-level Training Accuracy: 75.52168390491744
# 2022-08-01 18:30:57.631896 Fold 2 Validate...
# Fold 2 Patch-level Validation Accuracy: 55.37943537943538
# Fold 2 Patient-level Validation Accuracy: 36.0
#
# 2022-08-01 18:31:00.380284 Fold 3 Loading...
# Train lengths X,y,z: (74477, 5301) 74477 74477
# Valid lengths X,y,z: (16471, 5301) 16471 16471
# 2022-08-01 18:33:03.481651 Fold 3 Train...
# 2022-08-01 19:04:17.663981 Fold 3 Ranked feature imporances...
#            0                                                  1
# 0   0.012086             Median_Nucleus_AreaShape_MaximumRadius
# 1   0.011509               Mean_Nucleus_AreaShape_MaximumRadius
# 2   0.010295                  Mean_Nucleus_AreaShape_MeanRadius
# 3   0.009960                Median_Nucleus_AreaShape_MeanRadius
# 4   0.009705              Median_Nucleus_AreaShape_MedianRadius
# 5   0.008985                Mean_Nucleus_AreaShape_MedianRadius
# 6   0.008907          Median_Nucleus_AreaShape_MinFeretDiameter
# 7   0.008754           Median_Nucleus_AreaShape_MinorAxisLength
# 8   0.007956  Median_Nucleus_AreaShape_InertiaTensorEigenval...
# 9   0.007135  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_7_0...
# 10  0.006789  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_7...
# 2022-08-01 19:04:17.782598 Fold 3 Evaluate...
# Fold 3 Patch-level Training Accuracy: 74.4632571129342
# 2022-08-01 19:04:28.388013 Fold 3 Validate...
# Fold 3 Patch-level Validation Accuracy: 57.039645437435496
# Fold 3 Patient-level Validation Accuracy: 44.0
#
# 2022-08-01 19:04:30.699168 Fold 4 Loading...
# Train lengths X,y,z: (77739, 5301) 77739 77739
# Valid lengths X,y,z: (13209, 5301) 13209 13209
# 2022-08-01 19:06:36.497671 Fold 4 Train...
# 2022-08-01 19:39:11.112541 Fold 4 Ranked feature imporances...
#            0                                                  1
# 0   0.011891             Median_Nucleus_AreaShape_MaximumRadius
# 1   0.010431                  Mean_Nucleus_AreaShape_MeanRadius
# 2   0.009383                Mean_Nucleus_AreaShape_MedianRadius
# 3   0.009077  Median_Nucleus_AreaShape_InertiaTensorEigenval...
# 4   0.008694  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_7...
# 5   0.008444  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_7...
# 6   0.008348           Median_Nucleus_AreaShape_MinorAxisLength
# 7   0.007973  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_5_0...
# 8   0.007410              Median_Nucleus_AreaShape_MedianRadius
# 9   0.006762  Mean_Nucleus_Texture_InfoMeas1_Hematoxylin_5_0...
# 10  0.006638  Median_Nucleus_Texture_InfoMeas1_Hematoxylin_7...
# 2022-08-01 19:39:11.215579 Fold 4 Evaluate...
# Fold 4 Patch-level Training Accuracy: 75.88983650419995
# 2022-08-01 19:39:21.775901 Fold 4 Validate...
# Fold 4 Patch-level Validation Accuracy: 45.12075100310395
# Fold 4 Patient-level Validation Accuracy: 36.0

# %%
print(datetime.now())
print('Cross validation patch-level accuracy:',patch_accuracies)
print('mean:',np.mean(patch_accuracies),'std:',np.std(patch_accuracies))
print('Cross validation patient-level accuracy:',patient_accuracies)
print('mean:',np.mean(patient_accuracies),'std:',np.std(patient_accuracies))
# Out:
# 2022-08-01 19:39:23.702366
# Cross validation patch-level accuracy: [55.10322580645161, 57.5104863394173, 55.37943537943538, 57.039645437435496, 45.12075100310395]
# mean: 54.03070879316874 std: 4.550148469437165
# Cross validation patient-level accuracy: [42.30769230769231, 26.923076923076923, 36.0, 44.0, 36.0]
# mean: 37.04615384615384 std: 6.011743930737353
