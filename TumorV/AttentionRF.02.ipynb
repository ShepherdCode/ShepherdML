# %% [markdown]
# # Random Forest
# Predict CNN attention per nucleus.
# Switch from numpy array loadtxt() to pandas dataframe read_csv().

# %%
MAX_DEPTH = 8
N_ESTIMATORS = 500
CHOOSE_EVERY = 10
SAVE_MEM = True

# %%
import datetime
print(datetime.datetime.now())
from platform import python_version
print('Python',python_version())
import csv
import numpy as np
import pandas as pd
import matplotlib as plt
import random
import sklearn   # pip install --upgrade scikit-learn
print('sklearn',sklearn.__version__)
# The model
from sklearn.ensemble import RandomForestClassifier
# Out:
# 2022-08-11 14:44:24.814066
# Python 3.8.10
# sklearn 1.0.2

# %%
# Patch data.
# This is the nucleus-level csv file: one row per nucleus from CellProfiler.
FILENAME='Process100_Nucleus.csv'
# This directory contains one Nucleus.csv file per patient.
BASE_PATH='D:\\Adjeroh\\Glioma\\August_Run\\CellProfilerPerPatient\\'   # Windows
BASE_PATH='/home/jrm/Adjeroh/Glioma/August_Run/CellProfilerPerPatient/'  # Alien

# Patient data.
# Each patch filename indicates patient/case [0:19] and WSI [0:23].
# For example: TCGA-06-0129-01Z-00-DX1_5400_5100.png
LEN_PATIENT_ID = 19
FOLDS_META_FILE = 'D:\\Adjeroh\\Glioma\\August_Run\\TrainValidSplits\\aug_train_valid_splits.csv'  # Windows
FOLDS_META_FILE = '/home/jrm/Adjeroh/Glioma/August_Run/TrainValidSplits/aug_train_valid_splits.csv'  # Alien
# Cross validation
NUM_FOLDS = 5

# These bin thresholds yield nucleus temperature bins of about equal weight.
# See AT_PerPatient 01 notebook.
BIN_MAX = [0.40,0.65,0.75,0.85,1.0]
BIN_LABEL = [1,2,3,4,5]

# %% [markdown]
# ## Data loading functions

# %%
METADATA = pd.read_csv(FOLDS_META_FILE)

# %%
def get_patient_attention(fold,is_train,patient):
    cls = 'mcls'
    filename = f"Attention_{cls}_fold{fold}.csv"
    filepath = BASE_PATH + patient + '/' + filename
    df = pd.read_csv(filepath)
    return df

# %%
def get_metadata_one_fold(fold,is_train):
    df = METADATA.loc[METADATA['Fold']==fold]
    if is_train:
        df = df.loc[df['Split']=='Train']
    else:
        df = df.loc[df['Split']=='Valid']
    patients = df['Case'].tolist()
    labels = df['Class'].tolist()
    return patients,labels

# %%
def drop_columns(df):
    bad_cols = ['ImageNumber','ObjectNumber','Number_Object_Number',
                'AreaShape_Orientation','Children_Cells_Count']
    df = df.drop(columns=bad_cols)
    bad_cols = [c for c in df.columns 
                if c.startswith('Location_') 
                or c.startswith('AreaShape_BoundingBoxM')
                or c.startswith('AreaShape_Center')
                or c.startswith('Neighbors_')]
    df = df.drop(columns=bad_cols)
    return df

# %%
def load_one_patient_attention(fold,multiclass,patient):
    filepath=BASE_PATH+patient+'/'+FILENAME
    X = pd.read_csv(filepath)
    cls='bcls'
    if multiclass:
        cls='mcls'
    att_filename = f"Attention_{cls}_fold{fold}.csv"
    att_path = BASE_PATH+patient+'/'+att_filename
    att_df = pd.read_csv(att_path)
    thermometer = {}
    for ndx,row in att_df.iterrows():
        key = (row['ImageNumber'],row['ObjectNumber'])
        value = row['AvgTemp']
        thermometer[key]=value
    every_temp = np.zeros(len(X),dtype=float)
    i = 0
    for ndx,row in X.iterrows():
        key = (row['ImageNumber'],row['ObjectNumber'])
        value = thermometer[key]
        every_temp[i] = value
        i += 1
    binned = np.digitize(every_temp,BIN_MAX,right=True)
    Y = list(binned) 
    return X,Y

# %%
def load_all_patients_data(fold,patients,save_mem=False):
    X = None  # dataframe with 600 feature columns, one row per nucleus
    y = None  # list of labels = attention for each row
    z = None  # list of patient name for each row
    is_multiclass = True
    count=0
    for patient in patients:
        print('.',end='')
        count += 1
        directory = patient+'/'
        Xall,yall = load_one_patient_attention(fold,is_multiclass,patient)
        if (save_mem):
            Xi = Xall.iloc[0::CHOOSE_EVERY] # e.g. choose every tenth patch
            yi = yall[0::CHOOSE_EVERY].copy()  # e.g. choose every tenth patch
        else:
            Xi = Xall
            yi = yall
        zi = [patient]*len(Xi)  # same ID for all patches from one patient
        if X is None:
            X = Xi
            y = yi
            z = zi
        else:
            X = pd.concat( (X, Xi) )
            y = np.concatenate( (y, yi) )
            z = np.concatenate( (z, zi) )
    print()
    X = drop_columns(X)
    return X,y,z   # nucleus data, nucleus attention bin, patient name

# %%
# This is slow, probably due to concatenating dataframes.
# Consider a rewrite that concatenates csv before constructing a dataframe.
def load_train_valid_set(fold):
    is_train = True # training set
    patients,cancers = get_metadata_one_fold(fold,is_train) 
    X_train,y_train,z_train = load_all_patients_data(fold,patients,SAVE_MEM) 
    print('Train lengths X,y,z:',X_train.shape,len(y_train),len(z_train))
    is_train = False # validation set
    patients,cancers = get_metadata_one_fold(fold,is_train) 
    X_valid,y_valid,z_valid = load_all_patients_data(fold,patients,SAVE_MEM) # reduces validation size
    print('Valid lengths X,y,z:',X_valid.shape,len(y_valid),len(z_valid))
    return X_train,y_train,z_train,X_valid,y_valid,z_valid

# %% [markdown]
# ## Aggregation functions

# %%
# Each patch votes on the class for its WSI.
# Later, weight each patch label by the confidence i.e. score
def aggregate_accuracy(y_pred,y_valid,z_valid):
    L = len(y_pred)
    if L != len(y_valid) or L != len(z_valid):
        raise Exception('Lengths do not match')
    correct = {}
    incorrect = {}
    patients = np.unique(z_valid)
    for patient in patients:
        correct[patient]=0  # accumulate correct votes on patches
        incorrect[patient]=0  # accumulate incorrect votes
    for i in range(L):
        patient = z_valid[i]
        label =   y_valid[i]
        pred =    y_pred[i]
        if pred == label:
            correct[patient] += 1
        else:
            incorrect[patient] += 1
    numerator = 0
    denominator = 0
    for patient in patients:
        denominator += 1
        if correct[patient]>incorrect[patient]:
            numerator += 1
    accuracy = float(0)
    if denominator>0:
        accuracy = 100.0*numerator/denominator 
    return accuracy

# %% [markdown]
# ## Main loop: Load, Classify, Report

# %%
def important_features(model):
    # Prereqs: fit().
    names = model.feature_names_in_
    importances = model.feature_importances_
    pairs = np.column_stack( (names,importances) )
    top_array = sorted(pairs, key = lambda e:e[1], reverse=True)
    # There must be a way to do this witout a loop!
    top_list = []
    for i in top_array:
         top_list.append((i[1],i[0]))  # 0=feature_name, 1=importance
    top_df = pd.DataFrame(top_list)
    return top_df

# %%
patch_accuracies = []   # summary statistics
patient_accuracies = [] # summary statistics

for fold in range(NUM_FOLDS):
    print()
    print(datetime.datetime.now(),'Fold',fold,'Loading...')
    X_train,y_train,z_train,X_valid,y_valid,z_valid = load_train_valid_set(fold)    

    # The shuffle is not strictly necessary with RF.
    # CNN models are sensitive to train set order but RF models are not. 
    # print(datetime.datetime.now(),'Shuffle...')
    # X_train,y_train = sklearn.shuffle(X_train,y_train)

    print(datetime.datetime.now(),'Train...')
    # min_samples_leaf=1 (default) led to overfitting
    rfc = RandomForestClassifier(max_depth=MAX_DEPTH,n_estimators=N_ESTIMATORS)
    rfc.fit(X_train,y_train)  # slow
    
    print(datetime.datetime.now(),'Ranked feature imporances...')
    top = important_features(rfc)
    #pd.set_option('display.max_rows', None)
    print(top.loc[:10])
    
    print(datetime.datetime.now(),'Evaluate...')
    y_pred = rfc.predict(X_train)
    matches = np.count_nonzero(y_train==y_pred)
    accuracy_t = 100.0 * matches / len(y_pred)
    print('Fold',fold,'Nucleus-level Training Accuracy:',accuracy_t)
    
    print(datetime.datetime.now(),'Validate...')
    y_pred = rfc.predict(X_valid)
    matches = np.count_nonzero(y_valid==y_pred)
    accuracy_v = 100.0 * matches / len(y_pred)
    print('Fold',fold,'Nucleus-level Validation Accuracy:',accuracy_v)
    patch_accuracies.append(accuracy_v)
    
    accuracy_p = aggregate_accuracy(y_pred,y_valid,z_valid)
    patient_accuracies.append(accuracy_p)
    print('Fold',fold,'Patient-level Validation Accuracy:',accuracy_p)
    
    # This shouldn't be necessary but it seems to reduce memory footprint.
    X_train=None
    X_valid=None
    y_train=None
    y_valid=None
    z_train=None
    z_valid=None
    y_pred = None
    matches = None
# Out:
# 2022-08-11 14:44:25.267312 Fold 0 Loading...
# .....................................................................................................
# Train lengths X,y,z: (148324, 623) 148324 148324
# ..........................
# Valid lengths X,y,z: (36559, 623) 36559 36559
# 2022-08-11 14:47:45.925471 Train...
# 2022-08-11 14:58:53.146430 Ranked feature imporances...
#            0                                              1
# 0   0.044774  Intensity_IntegratedIntensityEdge_Hematoxylin
# 1   0.031891                      Granularity_1_Hematoxylin
# 2   0.020164    RadialDistribution_FracAtD_Hematoxylin_2of5
# 3   0.016182                 AreaShape_NormalizedMoment_2_2
# 4   0.013779                               AreaShape_Extent
# 5   0.013604              Texture_SumAverage_Eosin_5_01_256
# 6   0.013032    RadialDistribution_FracAtD_Hematoxylin_1of5
# 7   0.012616        Intensity_MeanIntensityEdge_Hematoxylin
# 8   0.011882              Texture_SumAverage_Eosin_7_03_256
# 9   0.011577                 AreaShape_NormalizedMoment_2_1
# 10  0.011284              Texture_SumAverage_Eosin_7_00_256
# 2022-08-11 14:58:53.174837 Evaluate...
# Fold 0 Nucleus-level Training Accuracy: 33.341873196515735
# 2022-08-11 14:58:58.523170 Validate...
# Fold 0 Nucleus-level Validation Accuracy: 30.08561503323395
# Fold 0 Patient-level Validation Accuracy: 0.0
#
# 2022-08-11 14:58:59.757475 Fold 1 Loading...
# .....................................................................................................
# Train lengths X,y,z: (131619, 623) 131619 131619
# ..........................
# Valid lengths X,y,z: (53264, 623) 53264 53264
# 2022-08-11 15:02:17.160171 Train...
# 2022-08-11 15:12:09.901800 Ranked feature imporances...
#            0                                              1
# 0   0.044854  Intensity_IntegratedIntensityEdge_Hematoxylin
# 1   0.031863                      Granularity_1_Hematoxylin
# 2   0.015172    RadialDistribution_FracAtD_Hematoxylin_2of5
# 3   0.013652                 AreaShape_NormalizedMoment_2_2
# 4   0.013507                               AreaShape_Extent
# 5   0.011444        Intensity_MeanIntensityEdge_Hematoxylin
# 6   0.011308    RadialDistribution_FracAtD_Hematoxylin_1of5
# 7   0.010659              Texture_SumAverage_Eosin_4_00_256
# 8   0.010547                 AreaShape_NormalizedMoment_2_1
# 9   0.010478              Texture_SumAverage_Eosin_7_03_256
# 10  0.009926              Texture_SumAverage_Eosin_3_00_256
# 2022-08-11 15:12:09.923534 Evaluate...
# Fold 1 Nucleus-level Training Accuracy: 35.36267560154689
# 2022-08-11 15:12:14.591433 Validate...
# Fold 1 Nucleus-level Validation Accuracy: 32.15492640432562
# Fold 1 Patient-level Validation Accuracy: 0.0
#
# 2022-08-11 15:12:16.469012 Fold 2 Loading...
# ......................................................................................................
# Train lengths X,y,z: (149464, 623) 149464 149464
# .........................
# Valid lengths X,y,z: (35419, 623) 35419 35419
# 2022-08-11 15:15:33.274067 Train...
# 2022-08-11 15:26:52.673403 Ranked feature imporances...
#            0                                                  1
# 0   0.042397      Intensity_IntegratedIntensityEdge_Hematoxylin
# 1   0.018342            Intensity_MeanIntensityEdge_Hematoxylin
# 2   0.015392        RadialDistribution_FracAtD_Hematoxylin_2of5
# 3   0.012562                          Granularity_1_Hematoxylin
# 4   0.010472            Texture_SumAverage_Hematoxylin_3_00_256
# 5   0.010380  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 6   0.009840                                   AreaShape_Extent
# 7   0.009719             Intensity_MaxIntensityEdge_Hematoxylin
# 8   0.009561                  Texture_SumAverage_Eosin_5_03_256
# 9   0.009449                  Texture_SumAverage_Eosin_4_03_256
# 10  0.009327                  Texture_SumAverage_Eosin_4_02_256
# 2022-08-11 15:26:52.694701 Evaluate...
# Fold 2 Nucleus-level Training Accuracy: 40.49336295027565
# 2022-08-11 15:26:58.244799 Validate...
# Fold 2 Nucleus-level Validation Accuracy: 39.00448911601118
# Fold 2 Patient-level Validation Accuracy: 8.0
#
# 2022-08-11 15:26:59.540963 Fold 3 Loading...
# ......................................................................................................
# Train lengths X,y,z: (151864, 623) 151864 151864
# .........................
# Valid lengths X,y,z: (33019, 623) 33019 33019
# 2022-08-11 15:30:20.067493 Train...
# 2022-08-11 15:41:52.696660 Ranked feature imporances...
#            0                                                  1
# 0   0.011971      Intensity_IntegratedIntensityEdge_Hematoxylin
# 1   0.008835            Texture_SumAverage_Hematoxylin_3_00_256
# 2   0.008441                Intensity_MeanIntensity_Hematoxylin
# 3   0.008316            Texture_SumAverage_Hematoxylin_5_01_256
# 4   0.008197  RadialDistribution_ZernikeMagnitude_Hematoxyli...
# 5   0.007842            Texture_SumAverage_Hematoxylin_4_01_256
# 6   0.007640            Texture_SumAverage_Hematoxylin_3_01_256
# 7   0.007571            Texture_SumAverage_Hematoxylin_5_00_256
# 8   0.007322       Intensity_LowerQuartileIntensity_Hematoxylin
# 9   0.007164                          Granularity_1_Hematoxylin
# 10  0.007032            Texture_SumAverage_Hematoxylin_7_03_256
# 2022-08-11 15:41:52.724671 Evaluate...
# Fold 3 Nucleus-level Training Accuracy: 46.78133066427856
# 2022-08-11 15:41:58.192240 Validate...
# Fold 3 Nucleus-level Validation Accuracy: 42.25143099427602
# Fold 3 Patient-level Validation Accuracy: 0.0
#
# 2022-08-11 15:41:59.376807 Fold 4 Loading...
# ......................................................................................................
# Train lengths X,y,z: (158261, 623) 158261 158261
# .........................
# Valid lengths X,y,z: (26622, 623) 26622 26622
# 2022-08-11 15:45:21.333900 Train...
# 2022-08-11 15:57:25.565883 Ranked feature imporances...
#            0                                              1
# 0   0.050295  Intensity_IntegratedIntensityEdge_Hematoxylin
# 1   0.028265                               AreaShape_Extent
# 2   0.022933    RadialDistribution_FracAtD_Hematoxylin_2of5
# 3   0.019573                 AreaShape_NormalizedMoment_2_2
# 4   0.015905    RadialDistribution_FracAtD_Hematoxylin_1of5
# 5   0.015809                      Granularity_1_Hematoxylin
# 6   0.015063                 AreaShape_NormalizedMoment_1_2
# 7   0.011468              Texture_SumAverage_Eosin_7_03_256
# 8   0.011272                    AreaShape_SpatialMoment_1_0
# 9   0.010972              Texture_SumAverage_Eosin_3_00_256
# 10  0.010720              Texture_SumAverage_Eosin_5_01_256
# 2022-08-11 15:57:25.594214 Evaluate...
# Fold 4 Nucleus-level Training Accuracy: 36.284997567309695
# 2022-08-11 15:57:31.456973 Validate...
# Fold 4 Nucleus-level Validation Accuracy: 35.86507399894824
# Fold 4 Patient-level Validation Accuracy: 0.0

# %%
print(datetime.datetime.now())
if SAVE_MEM:
    print('Sampling every',CHOOSE_EVERY,'th record.')
print('Cross validation nucleus-level accuracy:',patch_accuracies)
print('mean:',np.mean(patch_accuracies),'pop std:',np.std(patch_accuracies,ddof=1))
print('Cross validation patient-level accuracy:',patient_accuracies)
print('mean:',np.mean(patient_accuracies),'pop std:',np.std(patient_accuracies,ddof=1))
# Out:
# 2022-08-11 15:57:32.404774
# Sampling every 10 th record.
# Cross validation nucleus-level accuracy: [30.08561503323395, 32.15492640432562, 39.00448911601118, 42.25143099427602, 35.86507399894824]
# mean: 35.872307109359 pop std: 4.944910577296712
# Cross validation patient-level accuracy: [0.0, 0.0, 8.0, 0.0, 0.0]
# mean: 1.6 pop std: 3.5777087639996643
