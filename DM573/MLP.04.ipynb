# %% [markdown]
# # Neural Network
# This notebook applies a simple model to simple data.
# Data = Iris.
# Model = Fully Connected aka Dense aka Multi-Layer Perceptron (MLP).
# This notebook added added more layers to notebook 03. There was no change to accuracy.

# %%
import datetime
print(datetime.datetime.now())
from platform import python_version
print('Python',python_version())
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# 2022-09-03 13:20:57.892716
# Python 3.10.0

# %%
from tensorflow import keras
from keras import layers

# %%
from sklearn import datasets
from sklearn.utils import shuffle
iris = datasets.load_iris()
print('shape',iris.data.shape)
print('features',iris.feature_names)
print('labels',iris.target_names)
X = iris.data
y = iris.target
# At start, all species=0 come first and all species=2 come last.
# Important to shuffle rows before doing train/test split and train/valid split.
# Another way is using the sklearn train_test_split class.
X, y = shuffle(X, y, random_state=0)
print('X shape',X.shape)
print('y shape',y.shape)
num_instances = X.shape[0]
num_features =  X.shape[1]
# Out:
# shape (150, 4)
# features ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# labels ['setosa' 'versicolor' 'virginica']
# X shape (150, 4)
# y shape (150,)

# %%
X
# Out:
# array([[5.8, 2.8, 5.1, 2.4],
#        [6. , 2.2, 4. , 1. ],
#        [5.5, 4.2, 1.4, 0.2],
#        [7.3, 2.9, 6.3, 1.8],
#        [5. , 3.4, 1.5, 0.2],
#        [6.3, 3.3, 6. , 2.5],
#        [5. , 3.5, 1.3, 0.3],
#        [6.7, 3.1, 4.7, 1.5],
#        [6.8, 2.8, 4.8, 1.4],
#        [6.1, 2.8, 4. , 1.3],
#        [6.1, 2.6, 5.6, 1.4],
#        [6.4, 3.2, 4.5, 1.5],
#        [6.1, 2.8, 4.7, 1.2],
#        [6.5, 2.8, 4.6, 1.5],
#        [6.1, 2.9, 4.7, 1.4],
#        [4.9, 3.6, 1.4, 0.1],
#        [6. , 2.9, 4.5, 1.5],
#        [5.5, 2.6, 4.4, 1.2],
#        [4.8, 3. , 1.4, 0.3],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.6, 2.8, 4.9, 2. ],
#        [5.6, 3. , 4.5, 1.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [6.2, 2.8, 4.8, 1.8],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.8, 1.9, 0.4],
#        [6.2, 2.9, 4.3, 1.3],
#        [5. , 2.3, 3.3, 1. ],
#        [5. , 3.4, 1.6, 0.4],
#        [6.4, 3.1, 5.5, 1.8],
#        [5.4, 3. , 4.5, 1.5],
#        [5.2, 3.5, 1.5, 0.2],
#        [6.1, 3. , 4.9, 1.8],
#        [6.4, 2.8, 5.6, 2.2],
#        [5.2, 2.7, 3.9, 1.4],
#        [5.7, 3.8, 1.7, 0.3],
#        [6. , 2.7, 5.1, 1.6],
#        [5.9, 3. , 4.2, 1.5],
#        [5.8, 2.6, 4. , 1.2],
#        [6.8, 3. , 5.5, 2.1],
#        [4.7, 3.2, 1.3, 0.2],
#        [6.9, 3.1, 5.1, 2.3],
#        [5. , 3.5, 1.6, 0.6],
#        [5.4, 3.7, 1.5, 0.2],
#        [5. , 2. , 3.5, 1. ],
#        [6.5, 3. , 5.5, 1.8],
#        [6.7, 3.3, 5.7, 2.5],
#        [6. , 2.2, 5. , 1.5],
#        [6.7, 2.5, 5.8, 1.8],
#        [5.6, 2.5, 3.9, 1.1],
#        [7.7, 3. , 6.1, 2.3],
#        [6.3, 3.3, 4.7, 1.6],
#        [5.5, 2.4, 3.8, 1.1],
#        [6.3, 2.7, 4.9, 1.8],
#        [6.3, 2.8, 5.1, 1.5],
#        [4.9, 2.5, 4.5, 1.7],
#        [6.3, 2.5, 5. , 1.9],
#        [7. , 3.2, 4.7, 1.4],
#        [6.5, 3. , 5.2, 2. ],
#        [6. , 3.4, 4.5, 1.6],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.8, 2.7, 5.1, 1.9],
#        [5.6, 2.7, 4.2, 1.3],
#        [5.6, 2.9, 3.6, 1.3],
#        [5.5, 2.5, 4. , 1.3],
#        [6.1, 3. , 4.6, 1.4],
#        [7.2, 3.2, 6. , 1.8],
#        [5.3, 3.7, 1.5, 0.2],
#        [4.3, 3. , 1.1, 0.1],
#        [6.4, 2.7, 5.3, 1.9],
#        [5.7, 3. , 4.2, 1.2],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [6.9, 3.1, 4.9, 1.5],
#        [4.6, 3.1, 1.5, 0.2],
#        [5.9, 3. , 5.1, 1.8],
#        [5.1, 2.5, 3. , 1.1],
#        [4.6, 3.4, 1.4, 0.3],
#        [6.2, 2.2, 4.5, 1.5],
#        [7.2, 3.6, 6.1, 2.5],
#        [5.7, 2.9, 4.2, 1.3],
#        [4.8, 3. , 1.4, 0.1],
#        [7.1, 3. , 5.9, 2.1],
#        [6.9, 3.2, 5.7, 2.3],
#        [6.5, 3. , 5.8, 2.2],
#        [6.4, 2.8, 5.6, 2.1],
#        [5.1, 3.8, 1.6, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [6.5, 3.2, 5.1, 2. ],
#        [6.7, 3.3, 5.7, 2.1],
#        [4.5, 2.3, 1.3, 0.3],
#        [6.2, 3.4, 5.4, 2.3],
#        [4.9, 3. , 1.4, 0.2],
#        [5.7, 2.5, 5. , 2. ],
#        [6.9, 3.1, 5.4, 2.1],
#        [4.4, 3.2, 1.3, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [7.2, 3. , 5.8, 1.6],
#        [5.1, 3.5, 1.4, 0.3],
#        [4.4, 3. , 1.3, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [5.5, 2.3, 4. , 1.3],
#        [6.8, 3.2, 5.9, 2.3],
#        [7.6, 3. , 6.6, 2.1],
#        [5.1, 3.5, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [5.7, 2.8, 4.5, 1.3],
#        [6.6, 3. , 4.4, 1.4],
#        [5. , 3.2, 1.2, 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [6.4, 2.9, 4.3, 1.3],
#        [5.4, 3.4, 1.5, 0.4],
#        [7.7, 2.6, 6.9, 2.3],
#        [4.9, 2.4, 3.3, 1. ],
#        [7.9, 3.8, 6.4, 2. ],
#        [6.7, 3.1, 4.4, 1.4],
#        [5.2, 4.1, 1.5, 0.1],
#        [6. , 3. , 4.8, 1.8],
#        [5.8, 4. , 1.2, 0.2],
#        [7.7, 2.8, 6.7, 2. ],
#        [5.1, 3.8, 1.5, 0.3],
#        [4.7, 3.2, 1.6, 0.2],
#        [7.4, 2.8, 6.1, 1.9],
#        [5. , 3.3, 1.4, 0.2],
#        [6.3, 3.4, 5.6, 2.4],
#        [5.7, 2.8, 4.1, 1.3],
#        [5.8, 2.7, 3.9, 1.2],
#        [5.7, 2.6, 3.5, 1. ],
#        [6.4, 3.2, 5.3, 2.3],
#        [6.7, 3. , 5.2, 2.3],
#        [6.3, 2.5, 4.9, 1.5],
#        [6.7, 3. , 5. , 1.7],
#        [5. , 3. , 1.6, 0.2],
#        [5.5, 2.4, 3.7, 1. ],
#        [6.7, 3.1, 5.6, 2.4],
#        [5.8, 2.7, 5.1, 1.9],
#        [5.1, 3.4, 1.5, 0.2],
#        [6.6, 2.9, 4.6, 1.3],
#        [5.6, 3. , 4.1, 1.3],
#        [5.9, 3.2, 4.8, 1.8],
#        [6.3, 2.3, 4.4, 1.3],
#        [5.5, 3.5, 1.3, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.9, 3.1, 1.5, 0.1],
#        [6.3, 2.9, 5.6, 1.8],
#        [5.8, 2.7, 4.1, 1. ],
#        [7.7, 3.8, 6.7, 2.2],
#        [4.6, 3.2, 1.4, 0.2]])

# %%
y
# Out:
# array([2, 1, 0, 2, 0, 2, 0, 1, 1, 1, 2, 1, 1, 1, 1, 0, 1, 1, 0, 0, 2, 1,
#        0, 0, 2, 0, 0, 1, 1, 0, 2, 1, 0, 2, 2, 1, 0, 1, 1, 1, 2, 0, 2, 0,
#        0, 1, 2, 2, 2, 2, 1, 2, 1, 1, 2, 2, 2, 2, 1, 2, 1, 0, 2, 1, 1, 1,
#        1, 2, 0, 0, 2, 1, 0, 0, 1, 0, 2, 1, 0, 1, 2, 1, 0, 2, 2, 2, 2, 0,
#        0, 2, 2, 0, 2, 0, 2, 2, 0, 0, 2, 0, 0, 0, 1, 2, 2, 0, 0, 0, 1, 1,
#        0, 0, 1, 0, 2, 1, 2, 1, 0, 2, 0, 2, 0, 0, 2, 0, 2, 1, 1, 1, 2, 2,
#        1, 1, 0, 1, 2, 2, 0, 1, 1, 1, 1, 0, 0, 0, 2, 1, 2, 0])

# %% [markdown]
# Without normalization, the feature with biggest variance dominates.
# Unfortunately, on these data, normalization reduces the attainable accuracy.
# We use the Keras Normalization class:
# 1. Constructor takes axis, mean, var. By default, axis = -1 (the last axis), mean=0, var=1.
# 1. The adapt() method tunes the scaling parameters to the given data.
# 1. From then on, the object scales any given data.
# 1. Importantly, we adapt() to the training data and apply to the test data.

# %%
X_train = X[:125]
normalizer = layers.Normalization() 
normalizer.adapt(X_train)
X = normalizer(X)
X
# Out:
# 2022-09-03 13:21:09.711222: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# <tf.Tensor: shape=(150, 4), dtype=float32, numpy=
# array([[-0.04254734, -0.59698707,  0.7644368 ,  1.5982144 ],
#        [ 0.19382802, -1.9456023 ,  0.146869  , -0.25034815],
#        [-0.39711094,  2.549782  , -1.3128369 , -1.3066696 ],
#        [ 1.7302696 , -0.37221748,  1.4381473 ,  0.8059732 ],
#        [-0.9880499 ,  0.75162876, -1.2566942 , -1.3066696 ],
#        [ 0.54839164,  0.52685916,  1.2697196 ,  1.7302544 ],
#        [-0.9880499 ,  0.9763978 , -1.3689793 , -1.1746293 ],
#        [ 1.0211424 ,  0.07732059,  0.5398666 ,  0.4098527 ],
#        [ 1.1393306 , -0.59698707,  0.5960094 ,  0.2778125 ],
#        [ 0.3120157 , -0.59698707,  0.146869  ,  0.14577231],
#        [ 0.3120157 , -1.0465256 ,  1.0451494 ,  0.2778125 ],
#        [ 0.6665793 ,  0.30209017,  0.42758167,  0.4098527 ],
#        [ 0.3120157 , -0.59698707,  0.5398666 ,  0.01373225],
#        [ 0.784767  , -0.59698707,  0.48372412,  0.4098527 ],
#        [ 0.3120157 , -0.37221748,  0.5398666 ,  0.2778125 ],
#        [-1.1062376 ,  1.2011669 , -1.3128369 , -1.4387097 ],
#        [ 0.19382802, -0.37221748,  0.42758167,  0.4098527 ],
#        [-0.39711094, -1.0465256 ,  0.3714392 ,  0.01373225],
#        [-1.2244253 , -0.14744844, -1.3128369 , -1.1746293 ],
#        [-0.5152986 ,  1.875475  , -1.3689793 , -1.0425892 ],
#        [-0.27892327, -0.59698707,  0.6521518 ,  1.0700536 ],
#        [-0.27892327, -0.14744844,  0.42758167,  0.4098527 ],
#        [-1.2244253 ,  0.75162876, -1.0321242 , -1.3066696 ],
#        [-1.6971766 , -0.37221748, -1.3128369 , -1.3066696 ],
#        [ 0.43020338, -0.59698707,  0.5960094 ,  0.8059732 ],
#        [-1.4608012 ,  1.2011669 , -1.5374069 , -1.3066696 ],
#        [-0.86986226,  1.6507055 , -1.0321242 , -1.0425892 ],
#        [ 0.43020338, -0.37221748,  0.3152967 ,  0.14577231],
#        [ 2.2030203 , -1.0465256 ,  1.7750025 ,  1.466174  ],
#        [-1.1062376 , -1.4960637 , -0.24612874, -0.25034815],
#        [ 2.4393961 ,  1.6507055 ,  1.4942898 ,  1.0700536 ],
#        [ 1.0211424 ,  0.07732059,  0.3714392 ,  0.2778125 ],
#        [-0.75167453,  2.3250132 , -1.2566942 , -1.4387097 ],
#        [ 0.19382802, -0.14744844,  0.5960094 ,  0.8059732 ],
#        [-0.04254734,  2.100244  , -1.4251218 , -1.3066696 ],
#        [ 2.2030203 , -0.59698707,  1.6627172 ,  1.0700536 ],
#        [-0.86986226,  1.6507055 , -1.2566942 , -1.1746293 ],
#        [-1.3426136 ,  0.30209017, -1.2005516 , -1.3066696 ],
#        [ 1.8484572 , -0.59698707,  1.325862  ,  0.9380134 ],
#        [-0.9880499 ,  0.52685916, -1.3128369 , -1.3066696 ],
#        [ 0.54839164,  0.75162876,  1.0451494 ,  1.5982144 ],
#        [-0.16073559, -0.59698707,  0.20301148,  0.14577231],
#        [-0.04254734, -0.82175606,  0.09072652,  0.01373225],
#        [-0.16073559, -1.0465256 , -0.13384365, -0.25034815],
#        [ 0.6665793 ,  0.30209017,  0.876722  ,  1.466174  ],
#        [ 1.0211424 , -0.14744844,  0.82057923,  1.466174  ],
#        [ 0.54839164, -1.2712947 ,  0.6521518 ,  0.4098527 ],
#        [ 1.0211424 , -0.14744844,  0.70829433,  0.67393315],
#        [-0.9880499 , -0.14744844, -1.2005516 , -1.3066696 ],
#        [-0.39711094, -1.4960637 , -0.02155856, -0.25034815],
#        [ 1.0211424 ,  0.07732059,  1.0451494 ,  1.5982144 ],
#        [-0.04254734, -0.82175606,  0.7644368 ,  0.9380134 ],
#        [-0.86986226,  0.75162876, -1.2566942 , -1.3066696 ],
#        [ 0.9029547 , -0.37221748,  0.48372412,  0.14577231],
#        [-0.27892327, -0.14744844,  0.20301148,  0.14577231],
#        [ 0.07564034,  0.30209017,  0.5960094 ,  0.8059732 ],
#        [ 0.54839164, -1.7208333 ,  0.3714392 ,  0.14577231],
#        [-0.39711094,  0.9763978 , -1.3689793 , -1.3066696 ],
#        [-0.86986226,  1.4259363 , -1.2566942 , -1.0425892 ],
#        [-1.1062376 ,  0.07732059, -1.2566942 , -1.4387097 ],
#        [ 0.54839164, -0.37221748,  1.0451494 ,  0.8059732 ],
#        [-0.04254734, -0.82175606,  0.20301148, -0.25034815],
#        [ 2.2030203 ,  1.6507055 ,  1.6627172 ,  1.334134  ],
#        [-1.4608012 ,  0.30209017, -1.3128369 , -1.3066696 ]],
#       dtype=float32)>

# %%
X_train = X[:125]
y_train = y[:125]
X_test  = X[125:]
y_test  = y[125:]

# %% [markdown]
# Keras offers 2 means of building a model.
# 1. The [Sequential class](https://keras.io/api/models/sequential/#sequential-class) is simple. It has an add(layer) method. It maintains layers in the order they were added. It allows linear models only. Every layer has one input and one output.
# 1. The [Functional API](https://keras.io/guides/functional_api/) is complex. It allows DAG models. Layers can be skipped, reused, and multiply connected.
#
# The Dense layer has these constructor options.
# 1. num units
# 1. activation. Default=linear. Choices are relu, elu, softplus (smooth relu), softmax, sigmoid, tanh, exponential. There is an API so you can build your own.
# 1. use_bias. Default=True
# 1. kernel_initializer. Default="glorot_uniform"
# 1. regularizers for the bias, kernel, and activity. Default=None.

# %%
inputs = keras.Input(shape=(num_features,))
inputs
# Out:
# <KerasTensor: shape=(None, 4) dtype=float32 (created by layer 'input_1')>

# %%
# Keras output layer raises exception unless #neurons == #labels in Y.
dense1 =  layers.Dense(8, activation="relu")   (inputs)
dense2 =  layers.Dense(8, activation="relu")   (dense1)
outputs = layers.Dense(3)                      (dense2)
outputs
# Out:
# <KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'dense_2')>

# %%
model = keras.Model(inputs=inputs, outputs=outputs, name="MLP_1")
model.summary()
# Out:
# Model: "MLP_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 4)]               0
#
#  dense (Dense)               (None, 8)                 40
#
#  dense_1 (Dense)             (None, 8)                 72
#
#  dense_2 (Dense)             (None, 3)                 27
#
# =================================================================
# Total params: 139
# Trainable params: 139
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Explain the number of trainable parameters:
# 1. Dense_0: (4 input + 1 bias) * 8 out = 40
# 1. Dense_0: (8 input + 1 bias) * 8 out = 72
# 1. Dense_2: (8 input + 1 bias) * 3 out = 27

# %%
model.compile(
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer=keras.optimizers.RMSprop(),
    metrics=["accuracy"],
)

# %% [markdown]
# Note on model.fit() and model.evaluate():
# Both methods are written to be customized.
# By default, [model.fit()](https://keras.io/api/models/model_training_apis/#fit-method)
# has shuffle=True within each batch.

# %%
EPOCHS=100
# Re-running this cell continues training same model! Must re-compile to start over.
history = model.fit(X_train, y_train, batch_size=25, epochs=EPOCHS, validation_split=0.2)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 1s 60ms/step - loss: 1.2331 - accuracy: 0.3300 - val_loss: 1.2587 - val_accuracy: 0.2400
# Epoch 2/100
# 4/4 [==============================] - 0s 13ms/step - loss: 1.1980 - accuracy: 0.3300 - val_loss: 1.2210 - val_accuracy: 0.2400
# Epoch 3/100
# 4/4 [==============================] - 0s 15ms/step - loss: 1.1746 - accuracy: 0.3300 - val_loss: 1.1901 - val_accuracy: 0.2800
# Epoch 4/100
# 4/4 [==============================] - 0s 14ms/step - loss: 1.1549 - accuracy: 0.3200 - val_loss: 1.1632 - val_accuracy: 0.2800
# Epoch 5/100
# 4/4 [==============================] - 0s 18ms/step - loss: 1.1378 - accuracy: 0.3300 - val_loss: 1.1383 - val_accuracy: 0.2800
# Epoch 6/100
# 4/4 [==============================] - 0s 19ms/step - loss: 1.1215 - accuracy: 0.3200 - val_loss: 1.1154 - val_accuracy: 0.2800
# Epoch 7/100
# 4/4 [==============================] - 0s 12ms/step - loss: 1.1064 - accuracy: 0.3200 - val_loss: 1.0937 - val_accuracy: 0.3200
# Epoch 8/100
# 4/4 [==============================] - 0s 13ms/step - loss: 1.0924 - accuracy: 0.3600 - val_loss: 1.0738 - val_accuracy: 0.3200
# Epoch 9/100
# 4/4 [==============================] - 0s 15ms/step - loss: 1.0790 - accuracy: 0.3900 - val_loss: 1.0536 - val_accuracy: 0.5200
# Epoch 10/100
# 4/4 [==============================] - 0s 12ms/step - loss: 1.0660 - accuracy: 0.4700 - val_loss: 1.0344 - val_accuracy: 0.5600
# Epoch 11/100
# 4/4 [==============================] - 0s 22ms/step - loss: 1.0532 - accuracy: 0.5000 - val_loss: 1.0162 - val_accuracy: 0.5600
# Epoch 12/100
# 4/4 [==============================] - 0s 17ms/step - loss: 1.0409 - accuracy: 0.5100 - val_loss: 0.9981 - val_accuracy: 0.6000
# Epoch 13/100
# 4/4 [==============================] - 0s 17ms/step - loss: 1.0288 - accuracy: 0.5100 - val_loss: 0.9810 - val_accuracy: 0.6400
# Epoch 14/100
# 4/4 [==============================] - 0s 14ms/step - loss: 1.0173 - accuracy: 0.5300 - val_loss: 0.9650 - val_accuracy: 0.6400
# Epoch 15/100
# 4/4 [==============================] - 0s 14ms/step - loss: 1.0064 - accuracy: 0.5500 - val_loss: 0.9495 - val_accuracy: 0.6800
# Epoch 16/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.9952 - accuracy: 0.5600 - val_loss: 0.9336 - val_accuracy: 0.7200
# Epoch 17/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.9840 - accuracy: 0.5700 - val_loss: 0.9177 - val_accuracy: 0.7200
# Epoch 18/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.9729 - accuracy: 0.6000 - val_loss: 0.9022 - val_accuracy: 0.7200
# Epoch 19/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.9623 - accuracy: 0.5800 - val_loss: 0.8872 - val_accuracy: 0.7200
# Epoch 20/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.9513 - accuracy: 0.5800 - val_loss: 0.8721 - val_accuracy: 0.7200
# Epoch 21/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.9408 - accuracy: 0.5800 - val_loss: 0.8569 - val_accuracy: 0.7200
# Epoch 22/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.9299 - accuracy: 0.5800 - val_loss: 0.8423 - val_accuracy: 0.7200
# Epoch 23/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.9195 - accuracy: 0.5900 - val_loss: 0.8273 - val_accuracy: 0.7200
# Epoch 24/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.9089 - accuracy: 0.5800 - val_loss: 0.8129 - val_accuracy: 0.7200
# Epoch 25/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.8986 - accuracy: 0.5900 - val_loss: 0.7987 - val_accuracy: 0.7200
# Epoch 26/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.8883 - accuracy: 0.5900 - val_loss: 0.7845 - val_accuracy: 0.7200
# Epoch 27/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.8780 - accuracy: 0.5900 - val_loss: 0.7702 - val_accuracy: 0.7200
# Epoch 28/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.8678 - accuracy: 0.5900 - val_loss: 0.7564 - val_accuracy: 0.7200
# Epoch 29/100
# 4/4 [==============================] - 0s 40ms/step - loss: 0.8580 - accuracy: 0.5900 - val_loss: 0.7433 - val_accuracy: 0.7200
# Epoch 30/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.8486 - accuracy: 0.5900 - val_loss: 0.7301 - val_accuracy: 0.7200
# Epoch 31/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.8387 - accuracy: 0.5900 - val_loss: 0.7174 - val_accuracy: 0.7200
# Epoch 32/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.8296 - accuracy: 0.5900 - val_loss: 0.7048 - val_accuracy: 0.7200
# Epoch 33/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.8205 - accuracy: 0.5900 - val_loss: 0.6926 - val_accuracy: 0.7200
# Epoch 34/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.8117 - accuracy: 0.5900 - val_loss: 0.6811 - val_accuracy: 0.7200
# Epoch 35/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.8029 - accuracy: 0.5900 - val_loss: 0.6695 - val_accuracy: 0.7200
# Epoch 36/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.7945 - accuracy: 0.5900 - val_loss: 0.6582 - val_accuracy: 0.7200
# Epoch 37/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.7866 - accuracy: 0.5900 - val_loss: 0.6482 - val_accuracy: 0.7200
# Epoch 38/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.7789 - accuracy: 0.5900 - val_loss: 0.6382 - val_accuracy: 0.7200
# Epoch 39/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.7710 - accuracy: 0.5900 - val_loss: 0.6284 - val_accuracy: 0.7200
# Epoch 40/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.7637 - accuracy: 0.5900 - val_loss: 0.6192 - val_accuracy: 0.7200
# Epoch 41/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.7561 - accuracy: 0.5900 - val_loss: 0.6102 - val_accuracy: 0.7200
# Epoch 42/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.7490 - accuracy: 0.5900 - val_loss: 0.6013 - val_accuracy: 0.7200
# Epoch 43/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.7420 - accuracy: 0.5900 - val_loss: 0.5931 - val_accuracy: 0.7200
# Epoch 44/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.7352 - accuracy: 0.6000 - val_loss: 0.5852 - val_accuracy: 0.7200
# Epoch 45/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.7284 - accuracy: 0.6000 - val_loss: 0.5775 - val_accuracy: 0.7200
# Epoch 46/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.7222 - accuracy: 0.6100 - val_loss: 0.5702 - val_accuracy: 0.7200
# Epoch 47/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.7159 - accuracy: 0.6100 - val_loss: 0.5631 - val_accuracy: 0.7200
# Epoch 48/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.7098 - accuracy: 0.6100 - val_loss: 0.5563 - val_accuracy: 0.7200
# Epoch 49/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.7039 - accuracy: 0.6100 - val_loss: 0.5499 - val_accuracy: 0.7200
# Epoch 50/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6983 - accuracy: 0.6200 - val_loss: 0.5437 - val_accuracy: 0.7200
# Epoch 51/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6929 - accuracy: 0.6200 - val_loss: 0.5378 - val_accuracy: 0.7200
# Epoch 52/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6875 - accuracy: 0.6300 - val_loss: 0.5323 - val_accuracy: 0.7200
# Epoch 53/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.6825 - accuracy: 0.6300 - val_loss: 0.5271 - val_accuracy: 0.7200
# Epoch 54/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6774 - accuracy: 0.6300 - val_loss: 0.5221 - val_accuracy: 0.7200
# Epoch 55/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.6725 - accuracy: 0.6300 - val_loss: 0.5173 - val_accuracy: 0.7200
# Epoch 56/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6674 - accuracy: 0.6300 - val_loss: 0.5126 - val_accuracy: 0.7200
# Epoch 57/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6630 - accuracy: 0.6300 - val_loss: 0.5083 - val_accuracy: 0.7200
# Epoch 58/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.6582 - accuracy: 0.6300 - val_loss: 0.5041 - val_accuracy: 0.7200
# Epoch 59/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6538 - accuracy: 0.6300 - val_loss: 0.4999 - val_accuracy: 0.7200
# Epoch 60/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6494 - accuracy: 0.6300 - val_loss: 0.4960 - val_accuracy: 0.7200
# Epoch 61/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6451 - accuracy: 0.6300 - val_loss: 0.4921 - val_accuracy: 0.7200
# Epoch 62/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.6405 - accuracy: 0.6300 - val_loss: 0.4883 - val_accuracy: 0.7200
# Epoch 63/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6361 - accuracy: 0.6300 - val_loss: 0.4846 - val_accuracy: 0.7200
# Epoch 64/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.6319 - accuracy: 0.6300 - val_loss: 0.4811 - val_accuracy: 0.7200
# Epoch 65/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6276 - accuracy: 0.6400 - val_loss: 0.4776 - val_accuracy: 0.7200
# Epoch 66/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6231 - accuracy: 0.6400 - val_loss: 0.4742 - val_accuracy: 0.7200
# Epoch 67/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6188 - accuracy: 0.6400 - val_loss: 0.4709 - val_accuracy: 0.7200
# Epoch 68/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6145 - accuracy: 0.6400 - val_loss: 0.4677 - val_accuracy: 0.7200
# Epoch 69/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6103 - accuracy: 0.6400 - val_loss: 0.4646 - val_accuracy: 0.7200
# Epoch 70/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.6060 - accuracy: 0.6500 - val_loss: 0.4613 - val_accuracy: 0.7200
# Epoch 71/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6014 - accuracy: 0.6500 - val_loss: 0.4580 - val_accuracy: 0.7200
# Epoch 72/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.5966 - accuracy: 0.6600 - val_loss: 0.4546 - val_accuracy: 0.7600
# Epoch 73/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.5921 - accuracy: 0.6600 - val_loss: 0.4512 - val_accuracy: 0.7600
# Epoch 74/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5874 - accuracy: 0.6500 - val_loss: 0.4476 - val_accuracy: 0.7600
# Epoch 75/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.5824 - accuracy: 0.6400 - val_loss: 0.4439 - val_accuracy: 0.7600
# Epoch 76/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.5780 - accuracy: 0.6500 - val_loss: 0.4405 - val_accuracy: 0.7600
# Epoch 77/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5731 - accuracy: 0.6700 - val_loss: 0.4369 - val_accuracy: 0.8000
# Epoch 78/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5679 - accuracy: 0.6900 - val_loss: 0.4331 - val_accuracy: 0.8000
# Epoch 79/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5634 - accuracy: 0.7000 - val_loss: 0.4289 - val_accuracy: 0.8000
# Epoch 80/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5583 - accuracy: 0.7300 - val_loss: 0.4245 - val_accuracy: 0.8000
# Epoch 81/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5534 - accuracy: 0.7700 - val_loss: 0.4201 - val_accuracy: 0.7600
# Epoch 82/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.5489 - accuracy: 0.7900 - val_loss: 0.4158 - val_accuracy: 0.7600
# Epoch 83/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.5440 - accuracy: 0.7800 - val_loss: 0.4113 - val_accuracy: 0.7200
# Epoch 84/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.5395 - accuracy: 0.7800 - val_loss: 0.4066 - val_accuracy: 0.7200
# Epoch 85/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5348 - accuracy: 0.8100 - val_loss: 0.4019 - val_accuracy: 0.8000
# Epoch 86/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5303 - accuracy: 0.8100 - val_loss: 0.3974 - val_accuracy: 0.8000
# Epoch 87/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.5254 - accuracy: 0.8200 - val_loss: 0.3929 - val_accuracy: 0.8000
# Epoch 88/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5209 - accuracy: 0.8400 - val_loss: 0.3885 - val_accuracy: 0.8800
# Epoch 89/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5168 - accuracy: 0.8200 - val_loss: 0.3842 - val_accuracy: 0.8800
# Epoch 90/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5117 - accuracy: 0.8300 - val_loss: 0.3801 - val_accuracy: 0.8800
# Epoch 91/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5073 - accuracy: 0.8100 - val_loss: 0.3760 - val_accuracy: 0.8800
# Epoch 92/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5028 - accuracy: 0.8200 - val_loss: 0.3719 - val_accuracy: 0.8800
# Epoch 93/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.4985 - accuracy: 0.8100 - val_loss: 0.3679 - val_accuracy: 0.8800
# Epoch 94/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.4939 - accuracy: 0.8200 - val_loss: 0.3637 - val_accuracy: 0.8800
# Epoch 95/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4895 - accuracy: 0.8200 - val_loss: 0.3598 - val_accuracy: 0.8800
# Epoch 96/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.4858 - accuracy: 0.8200 - val_loss: 0.3560 - val_accuracy: 0.8800
# Epoch 97/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.4811 - accuracy: 0.8200 - val_loss: 0.3521 - val_accuracy: 0.8800
# Epoch 98/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4771 - accuracy: 0.8100 - val_loss: 0.3481 - val_accuracy: 0.8800
# Epoch 99/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4729 - accuracy: 0.8200 - val_loss: 0.3441 - val_accuracy: 0.8800
# Epoch 100/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.4688 - accuracy: 0.8200 - val_loss: 0.3402 - val_accuracy: 0.8400

# %%
pd.DataFrame(history.history).plot(figsize=(8,5))
plt.show()

# %%
test_scores = model.evaluate(X_test, y_test, verbose=2)
print("Test loss:", test_scores[0])
print("Test accuracy:", test_scores[1])
# Out:
# 1/1 - 0s - loss: 0.4721 - accuracy: 0.8400 - 115ms/epoch - 115ms/step
# Test loss: 0.4721044600009918
# Test accuracy: 0.8399999737739563
