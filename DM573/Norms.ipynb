# %% [markdown]
# # Norms

# %% [markdown]
# L1 norm := Manhattan distance pof point to origin = sum of abs of X & Y.
# L1 regularization tends to drop the lesser variables.
# In figure, line is likely to intersect corner of the diamond e.g. 1,0.
#
# L2 norm := Euclidian distance of point to origin = sqrt of sum of X & Y sqared.
# L2 regularization tends to reduce coefficients of all variables.
# In figure, line is likely to intersect a bulge e.g.
#
#
# L-infinity norm := absolute value of larger of X & Y.
#
#
# Mahalanobis distance := from point to distribution (multivariate gaussian).

# %% [markdown]
# ![image.png](attachment:image.png)
