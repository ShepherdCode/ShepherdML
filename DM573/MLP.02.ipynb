# %% [markdown]
# # Neural Network
# This notebook applies a simple model to simple data.
# Data = Iris.
# Model = Fully Connected aka Dense aka Multi-Layer Perceptron (MLP).
# Notebook 02: Here, we normalize the data. However, the results are just as bad. Overfits.

# %%
import datetime
print(datetime.datetime.now())
from platform import python_version
print('Python',python_version())
import csv
import numpy as np
import pandas as pd
import matplotlib as plt
import random
# Out:
# 2022-09-03 11:44:45.038146
# Python 3.10.0

# %%
from tensorflow import keras
from keras import layers

# %%
from sklearn import datasets
iris = datasets.load_iris()
print('shape',iris.data.shape)
print('features',iris.feature_names)
print('labels',iris.target_names)
X = iris.data
y = iris.target
print('X shape',X.shape)
print('y shape',y.shape)
num_instances = X.shape[0]
num_features =  X.shape[1]
# Out:
# shape (150, 4)
# features ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# labels ['setosa' 'versicolor' 'virginica']
# X shape (150, 4)
# y shape (150,)

# %%
X
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
#        [5.2, 4.1, 1.5, 0.1],
#        [5.5, 4.2, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.2],
#        [5. , 3.2, 1.2, 0.2],
#        [5.5, 3.5, 1.3, 0.2],
#        [4.9, 3.6, 1.4, 0.1],
#        [4.4, 3. , 1.3, 0.2],
#        [5.1, 3.4, 1.5, 0.2],
#        [5. , 3.5, 1.3, 0.3],
#        [4.5, 2.3, 1.3, 0.3],
#        [4.4, 3.2, 1.3, 0.2],
#        [5. , 3.5, 1.6, 0.6],
#        [5.1, 3.8, 1.9, 0.4],
#        [4.8, 3. , 1.4, 0.3],
#        [5.1, 3.8, 1.6, 0.2],
#        [4.6, 3.2, 1.4, 0.2],
#        [5.3, 3.7, 1.5, 0.2],
#        [5. , 3.3, 1.4, 0.2],
#        [7. , 3.2, 4.7, 1.4],
#        [6.4, 3.2, 4.5, 1.5],
#        [6.9, 3.1, 4.9, 1.5],
#        [5.5, 2.3, 4. , 1.3],
#        [6.5, 2.8, 4.6, 1.5],
#        [5.7, 2.8, 4.5, 1.3],
#        [6.3, 3.3, 4.7, 1.6],
#        [4.9, 2.4, 3.3, 1. ],
#        [6.6, 2.9, 4.6, 1.3],
#        [5.2, 2.7, 3.9, 1.4],
#        [5. , 2. , 3.5, 1. ],
#        [5.9, 3. , 4.2, 1.5],
#        [6. , 2.2, 4. , 1. ],
#        [6.1, 2.9, 4.7, 1.4],
#        [5.6, 2.9, 3.6, 1.3],
#        [6.7, 3.1, 4.4, 1.4],
#        [5.6, 3. , 4.5, 1.5],
#        [5.8, 2.7, 4.1, 1. ],
#        [6.2, 2.2, 4.5, 1.5],
#        [5.6, 2.5, 3.9, 1.1],
#        [5.9, 3.2, 4.8, 1.8],
#        [6.1, 2.8, 4. , 1.3],
#        [6.3, 2.5, 4.9, 1.5],
#        [6.1, 2.8, 4.7, 1.2],
#        [6.4, 2.9, 4.3, 1.3],
#        [6.6, 3. , 4.4, 1.4],
#        [6.8, 2.8, 4.8, 1.4],
#        [6.7, 3. , 5. , 1.7],
#        [6. , 2.9, 4.5, 1.5],
#        [5.7, 2.6, 3.5, 1. ],
#        [5.5, 2.4, 3.8, 1.1],
#        [5.5, 2.4, 3.7, 1. ],
#        [5.8, 2.7, 3.9, 1.2],
#        [6. , 2.7, 5.1, 1.6],
#        [5.4, 3. , 4.5, 1.5],
#        [6. , 3.4, 4.5, 1.6],
#        [6.7, 3.1, 4.7, 1.5],
#        [6.3, 2.3, 4.4, 1.3],
#        [5.6, 3. , 4.1, 1.3],
#        [5.5, 2.5, 4. , 1.3],
#        [5.5, 2.6, 4.4, 1.2],
#        [6.1, 3. , 4.6, 1.4],
#        [5.8, 2.6, 4. , 1.2],
#        [5. , 2.3, 3.3, 1. ],
#        [5.6, 2.7, 4.2, 1.3],
#        [5.7, 3. , 4.2, 1.2],
#        [5.7, 2.9, 4.2, 1.3],
#        [6.2, 2.9, 4.3, 1.3],
#        [5.1, 2.5, 3. , 1.1],
#        [5.7, 2.8, 4.1, 1.3],
#        [6.3, 3.3, 6. , 2.5],
#        [5.8, 2.7, 5.1, 1.9],
#        [7.1, 3. , 5.9, 2.1],
#        [6.3, 2.9, 5.6, 1.8],
#        [6.5, 3. , 5.8, 2.2],
#        [7.6, 3. , 6.6, 2.1],
#        [4.9, 2.5, 4.5, 1.7],
#        [7.3, 2.9, 6.3, 1.8],
#        [6.7, 2.5, 5.8, 1.8],
#        [7.2, 3.6, 6.1, 2.5],
#        [6.5, 3.2, 5.1, 2. ],
#        [6.4, 2.7, 5.3, 1.9],
#        [6.8, 3. , 5.5, 2.1],
#        [5.7, 2.5, 5. , 2. ],
#        [5.8, 2.8, 5.1, 2.4],
#        [6.4, 3.2, 5.3, 2.3],
#        [6.5, 3. , 5.5, 1.8],
#        [7.7, 3.8, 6.7, 2.2],
#        [7.7, 2.6, 6.9, 2.3],
#        [6. , 2.2, 5. , 1.5],
#        [6.9, 3.2, 5.7, 2.3],
#        [5.6, 2.8, 4.9, 2. ],
#        [7.7, 2.8, 6.7, 2. ],
#        [6.3, 2.7, 4.9, 1.8],
#        [6.7, 3.3, 5.7, 2.1],
#        [7.2, 3.2, 6. , 1.8],
#        [6.2, 2.8, 4.8, 1.8],
#        [6.1, 3. , 4.9, 1.8],
#        [6.4, 2.8, 5.6, 2.1],
#        [7.2, 3. , 5.8, 1.6],
#        [7.4, 2.8, 6.1, 1.9],
#        [7.9, 3.8, 6.4, 2. ],
#        [6.4, 2.8, 5.6, 2.2],
#        [6.3, 2.8, 5.1, 1.5],
#        [6.1, 2.6, 5.6, 1.4],
#        [7.7, 3. , 6.1, 2.3],
#        [6.3, 3.4, 5.6, 2.4],
#        [6.4, 3.1, 5.5, 1.8],
#        [6. , 3. , 4.8, 1.8],
#        [6.9, 3.1, 5.4, 2.1],
#        [6.7, 3.1, 5.6, 2.4],
#        [6.9, 3.1, 5.1, 2.3],
#        [5.8, 2.7, 5.1, 1.9],
#        [6.8, 3.2, 5.9, 2.3],
#        [6.7, 3.3, 5.7, 2.5],
#        [6.7, 3. , 5.2, 2.3],
#        [6.3, 2.5, 5. , 1.9],
#        [6.5, 3. , 5.2, 2. ],
#        [6.2, 3.4, 5.4, 2.3],
#        [5.9, 3. , 5.1, 1.8]])

# %% [markdown]
# The Keras Normalization class:
# 1. Constructor takes axis, mean, var. By default, axis = -1 (the last axis), mean=0, var=1.
# 1. The adapt() method tunes the scaling parameters to the given data.
# 1. From then on, the object scales any given data.
# 1. Importantly, we adapt() to the training data and apply to the test data.

# %%
X_train = X[:125]
normalizer = layers.Normalization() 
normalizer.adapt(X_train)
X = normalizer(X)
X
# Out:
# 2022-09-03 11:44:51.149113: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# <tf.Tensor: shape=(150, 4), dtype=float32, numpy=
# array([[-0.750525  ,  0.9468912 , -1.1683092 , -1.1630348 ],
#        [-1.0040804 , -0.14098878, -1.1683092 , -1.1630348 ],
#        [-1.2576365 ,  0.29416332, -1.2262383 , -1.1630348 ],
#        [-1.3844143 ,  0.07658701, -1.1103804 , -1.1630348 ],
#        [-0.8773027 ,  1.164467  , -1.1683092 , -1.1630348 ],
#        [-0.37019113,  1.8171953 , -0.9945227 , -0.88532835],
#        [-1.3844143 ,  0.7293154 , -1.1683092 , -1.0241815 ],
#        [-0.8773027 ,  0.7293154 , -1.1103804 , -1.1630348 ],
#        [-1.6379697 , -0.35856456, -1.1683092 , -1.1630348 ],
#        [-1.0040804 ,  0.07658701, -1.1103804 , -1.301888  ],
#        [-0.37019113,  1.3820432 , -1.1103804 , -1.1630348 ],
#        [-1.1308582 ,  0.7293154 , -1.0524516 , -1.1630348 ],
#        [-1.1308582 , -0.14098878, -1.1683092 , -1.301888  ],
#        [-1.7647475 , -0.14098878, -1.342096  , -1.301888  ],
#        [ 0.13692045,  2.0347712 , -1.284167  , -1.1630348 ],
#        [ 0.0101421 ,  2.9050753 , -1.1103804 , -0.88532835],
#        [-0.37019113,  1.8171953 , -1.2262383 , -0.88532835],
#        [-0.750525  ,  0.9468912 , -1.1683092 , -1.0241815 ],
#        [ 0.0101421 ,  1.599619  , -0.9945227 , -1.0241815 ],
#        [-0.750525  ,  1.599619  , -1.1103804 , -1.0241815 ],
#        [-0.37019113,  0.7293154 , -0.9945227 , -1.1630348 ],
#        [-0.750525  ,  1.3820432 , -1.1103804 , -0.88532835],
#        [-1.3844143 ,  1.164467  , -1.4000248 , -1.1630348 ],
#        [-0.11663564, -0.35856456,  0.10612561,  0.36435077],
#        [ 1.2779207 ,  0.07658701,  0.56955665,  0.50320405],
#        [-0.11663564, -0.14098878,  0.62748545,  0.6420573 ],
#        [ 0.13692045, -0.7937166 ,  0.39576992, -0.05220887],
#        [ 0.6440314 , -1.8815966 ,  0.62748545,  0.6420573 ],
#        [-0.11663564, -1.2288687 ,  0.27991232,  0.0866444 ],
#        [ 0.2636982 ,  0.29416332,  0.80127215,  1.058617  ],
#        [ 0.5172537 , -0.5761409 ,  0.33784112,  0.36435077],
#        [ 0.77080977, -1.2288687 ,  0.85920095,  0.6420573 ],
#        [ 0.5172537 , -0.5761409 ,  0.74334306,  0.22549766],
#        [ 0.89758754, -0.35856456,  0.5116278 ,  0.36435077],
#        [ 1.151143  , -0.14098878,  0.56955665,  0.50320405],
#        [ 1.4046991 , -0.5761409 ,  0.80127215,  0.50320405],
#        [ 1.2779207 , -0.14098878,  0.91712976,  0.91976386],
#        [ 0.39047593, -0.35856456,  0.62748545,  0.6420573 ],
#        [ 0.0101421 , -1.0112929 ,  0.0481968 , -0.05220887],
#        [-0.24341339, -1.4464445 ,  0.22198336,  0.0866444 ],
#        [-0.24341339, -1.4464445 ,  0.16405456, -0.05220887],
#        [ 0.13692045, -0.7937166 ,  0.27991232,  0.22549766],
#        [ 0.39047593, -0.7937166 ,  0.97505856,  0.7809106 ],
#        [-0.37019113, -0.14098878,  0.62748545,  0.6420573 ],
#        [ 0.39047593,  0.7293154 ,  0.62748545,  0.7809106 ],
#        [ 1.2779207 ,  0.07658701,  0.74334306,  0.6420573 ],
#        [ 0.77080977, -1.6640208 ,  0.56955665,  0.36435077],
#        [-0.11663564, -0.14098878,  0.39576992,  0.36435077],
#        [-0.24341339, -1.2288687 ,  0.33784112,  0.36435077],
#        [-0.24341339, -1.0112929 ,  0.56955665,  0.22549766],
#        [ 0.5172537 , -0.14098878,  0.68541425,  0.50320405],
#        [ 0.13692045, -1.0112929 ,  0.33784112,  0.22549766],
#        [-0.8773027 , -1.6640208 , -0.06766095, -0.05220887],
#        [-0.11663564, -0.7937166 ,  0.45369872,  0.36435077],
#        [ 0.0101421 , -0.14098878,  0.45369872,  0.22549766],
#        [ 0.0101421 , -0.35856456,  0.45369872,  0.36435077],
#        [ 0.6440314 , -0.35856456,  0.5116278 ,  0.36435077],
#        [-0.750525  , -1.2288687 , -0.24144751,  0.0866444 ],
#        [ 0.0101421 , -0.5761409 ,  0.39576992,  0.36435077],
#        [ 0.77080977,  0.5117391 ,  1.4964184 ,  2.0305896 ],
#        [ 0.13692045, -0.7937166 ,  0.97505856,  1.1974702 ],
#        [ 1.7850324 , -0.14098878,  1.4384896 ,  1.4751766 ],
#        [ 0.77080977, -0.35856456,  1.2647029 ,  1.058617  ],
#        [ 1.0243653 , -0.14098878,  1.3805608 ,  1.61403   ],
#        [ 2.4189217 , -0.14098878,  1.8439915 ,  1.4751766 ],
#        [ 0.77080977, -1.2288687 ,  0.91712976,  1.1974702 ],
#        [ 1.0243653 , -0.14098878,  1.0329874 ,  1.3363235 ],
#        [ 0.6440314 ,  0.7293154 ,  1.1488453 ,  1.7528832 ],
#        [ 0.2636982 , -0.14098878,  0.97505856,  1.058617  ]],
#       dtype=float32)>

# %%
X_train = X[:125]
y_train = y[:125]
X_test  = X[125:]
y_test  = y[125:]

# %% [markdown]
# Keras offers 2 means of building a model.
# 1. The [Sequential class](https://keras.io/api/models/sequential/#sequential-class) is simple. It has an add(layer) method. It maintains layers in the order they were added. It allows linear models only. Every layer has one input and one output.
# 1. The [Functional API](https://keras.io/guides/functional_api/) is complex. It allows DAG models. Layers can be skipped, reused, and multiply connected.
#
# The Dense layer has these constructor options.
# 1. num units
# 1. activation. Default=linear. Choices are relu, elu, softplus (smooth relu), softmax, sigmoid, tanh, exponential. There is an API so you can build your own.
# 1. use_bias. Default=True
# 1. kernel_initializer. Default="glorot_uniform"
# 1. regularizers for the bias, kernel, and activity. Default=None.

# %%
inputs = keras.Input(shape=(num_features,))
inputs
# Out:
# <KerasTensor: shape=(None, 4) dtype=float32 (created by layer 'input_1')>

# %%
dense1 = layers.Dense(64, activation="relu")(inputs)
dense2 = layers.Dense(64, activation="relu")(dense1)
outputs = layers.Dense(3)(dense2)
outputs
# Out:
# <KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'dense_2')>

# %%
model = keras.Model(inputs=inputs, outputs=outputs, name="MLP_1")
model.summary()
# Out:
# Model: "MLP_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 4)]               0
#
#  dense (Dense)               (None, 64)                320
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 4,675
# Trainable params: 4,675
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Explain the number of trainable parameters:
# 1. Dense_0: 5 in * 64 out = 320
# 1. Dense_1: 64 in * 64 out + 64 bias = 4096 + 64 = 4160
# 1. Dense_2: 64 in * 3 out + 3 bias = 192 + 3 = 195

# %%
model.compile(
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer=keras.optimizers.RMSprop(),
    metrics=["accuracy"],
)

# %% [markdown]
# Note on model.fit() and model.evaluate()
# Both methods are written to be customized.

# %%
EPOCHS=5
# Re-running this cell continues training! Must re-compile to start over.
history = model.fit(X_train, y_train, batch_size=64, epochs=EPOCHS, validation_split=0.2)
# Out:
# Epoch 1/5
# 2/2 [==============================] - 1s 182ms/step - loss: 1.0273 - accuracy: 0.3900 - val_loss: 1.0512 - val_accuracy: 0.5600
# Epoch 2/5
# 2/2 [==============================] - 0s 35ms/step - loss: 0.8307 - accuracy: 0.7800 - val_loss: 1.1910 - val_accuracy: 0.0400
# Epoch 3/5
# 2/2 [==============================] - 0s 33ms/step - loss: 0.7111 - accuracy: 0.9700 - val_loss: 1.3185 - val_accuracy: 0.0000e+00
# Epoch 4/5
# 2/2 [==============================] - 0s 34ms/step - loss: 0.6195 - accuracy: 0.9900 - val_loss: 1.4661 - val_accuracy: 0.0000e+00
# Epoch 5/5
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5439 - accuracy: 1.0000 - val_loss: 1.6394 - val_accuracy: 0.0000e+00

# %%
test_scores = model.evaluate(X_test, y_test, verbose=2)
print("Test loss:", test_scores[0])
print("Test accuracy:", test_scores[1])
# Out:
# 1/1 - 0s - loss: 1.5480 - accuracy: 0.0000e+00 - 17ms/epoch - 17ms/step
# Test loss: 1.5479896068572998
# Test accuracy: 0.0
